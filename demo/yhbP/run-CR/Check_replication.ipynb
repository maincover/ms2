# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/TA_yhbP-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/TA_yhbP-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/TA_yhbP-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP']
#
# out_name_s  ['TA_yhbP-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/TA_yhbP-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/TA_yhbP-1_analysis_metadata.pickle
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 53-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 54-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 59-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 66-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 67-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 68-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 69-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 52-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 54-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 59-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 66-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 67-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 68-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 69-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 53-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 54-1.tif.mortality.tab ------ MAX_02062014 Position 59-1.tif.mortality.tab
# MAX_02062014 Position 54-1.tif.mortality.tab ------ MAX_02062014 Position 66-1.tif.mortality.tab
# MAX_02062014 Position 54-1.tif.mortality.tab ------ MAX_02062014 Position 67-1.tif.mortality.tab
# MAX_02062014 Position 54-1.tif.mortality.tab ------ MAX_02062014 Position 68-1.tif.mortality.tab
# MAX_02062014 Position 54-1.tif.mortality.tab ------ MAX_02062014 Position 69-1.tif.mortality.tab
# MAX_02062014 Position 54-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 54-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 59-1.tif.mortality.tab ------ MAX_02062014 Position 66-1.tif.mortality.tab
# MAX_02062014 Position 59-1.tif.mortality.tab ------ MAX_02062014 Position 67-1.tif.mortality.tab
# MAX_02062014 Position 59-1.tif.mortality.tab ------ MAX_02062014 Position 68-1.tif.mortality.tab
# MAX_02062014 Position 59-1.tif.mortality.tab ------ MAX_02062014 Position 69-1.tif.mortality.tab
# MAX_02062014 Position 59-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 59-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 66-1.tif.mortality.tab ------ MAX_02062014 Position 67-1.tif.mortality.tab
# MAX_02062014 Position 66-1.tif.mortality.tab ------ MAX_02062014 Position 68-1.tif.mortality.tab
# MAX_02062014 Position 66-1.tif.mortality.tab ------ MAX_02062014 Position 69-1.tif.mortality.tab
# MAX_02062014 Position 66-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 66-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 67-1.tif.mortality.tab ------ MAX_02062014 Position 68-1.tif.mortality.tab
# MAX_02062014 Position 67-1.tif.mortality.tab ------ MAX_02062014 Position 69-1.tif.mortality.tab
# MAX_02062014 Position 67-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 67-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 68-1.tif.mortality.tab ------ MAX_02062014 Position 69-1.tif.mortality.tab
# MAX_02062014 Position 68-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 68-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 69-1.tif.mortality.tab ------ MAX_02062014 Position 71-1.tif.mortality.tab
# MAX_02062014 Position 69-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# MAX_02062014 Position 71-1.tif.mortality.tab ------ MAX_02062014 Position 72-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_dentrogram-all-files.eps
# [['MAX_02062014 Position 54-1.tif.mortality.tab', 'MAX_02062014 Position 59-1.tif.mortality.tab', 'MAX_02062014 Position 72-1.tif.mortality.tab'], ['MAX_02062014 Position 52-1.tif.mortality.tab', 'MAX_02062014 Position 53-1.tif.mortality.tab', 'MAX_02062014 Position 66-1.tif.mortality.tab', 'MAX_02062014 Position 67-1.tif.mortality.tab', 'MAX_02062014 Position 68-1.tif.mortality.tab', 'MAX_02062014 Position 69-1.tif.mortality.tab', 'MAX_02062014 Position 71-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.02438   sv2= 0.04978565   df= 11.15294   lambda= 281.6953
# phi= 14.21691   sv2= 0.0100643   df= 5.291426   lambda= 1412.607
# phi= 14.4314   sv2= 0.00485618   df= 3.795394   lambda= 2971.759
# phi= 14.55786   sv2= 0.003251249   df= 3.293953   lambda= 4477.62
# phi= 14.62776   sv2= 0.002565025   df= 3.061523   lambda= 5702.773
# phi= 14.66883   sv2= 0.002216439   df= 2.937778   lambda= 6618.197
# phi= 14.69415   sv2= 0.002020167   df= 2.866294   lambda= 7273.733
# phi= 14.71025   sv2= 0.001902362   df= 2.822742   lambda= 7732.622
# phi= 14.72069   sv2= 0.001828723   df= 2.795265   lambda= 8049.71
# phi= 14.72755   sv2= 0.001781464   df= 2.777527   lambda= 8267.107
# phi= 14.73211   sv2= 0.001750607   df= 2.7659   lambda= 8415.428
# phi= 14.73515   sv2= 0.001730228   df= 2.758202   lambda= 8516.305
# phi= 14.73719   sv2= 0.001716666   df= 2.75307   lambda= 8584.773
# phi= 14.73856   sv2= 0.001707594   df= 2.749634   lambda= 8631.183
# phi= 14.73948   sv2= 0.001701505   df= 2.747325   lambda= 8662.612
# phi= 14.7401   sv2= 0.001697409   df= 2.745771   lambda= 8683.883
# phi= 14.74052   sv2= 0.001694649   df= 2.744724   lambda= 8698.274
# phi= 14.7408   sv2= 0.001692787   df= 2.744018   lambda= 8708.007
# phi= 14.74099   sv2= 0.001691531   df= 2.743541   lambda= 8714.589
# phi= 14.74112   sv2= 0.001690682   df= 2.743218   lambda= 8719.039
# phi= 14.74121   sv2= 0.001690109   df= 2.743001   lambda= 8722.048
# phi= 14.74127   sv2= 0.001689721   df= 2.742854   lambda= 8724.082
# phi= 14.74131   sv2= 0.00168946   df= 2.742754   lambda= 8725.457
# phi= 14.74134   sv2= 0.001689283   df= 2.742687   lambda= 8726.387
# phi= 14.74135   sv2= 0.001689163   df= 2.742642   lambda= 8727.015
# Iterations: relative error in phi-hat = 1e-04
# phi= 1.830648   sv2= 0.03881559   df= 9.207928   lambda= 47.16271
# phi= 1.851002   sv2= 0.01202327   df= 6.588521   lambda= 153.9516
# phi= 1.866456   sv2= 0.005648099   df= 5.162246   lambda= 330.4574
# phi= 1.882657   sv2= 0.003216846   df= 4.437022   lambda= 585.2493
# phi= 1.896993   sv2= 0.002083293   df= 3.97688   lambda= 910.5745
# phi= 1.908081   sv2= 0.001543754   df= 3.664081   lambda= 1236.001
# phi= 1.915587   sv2= 0.001294354   df= 3.468052   lambda= 1479.956
# phi= 1.920026   sv2= 0.001180457   df= 3.359735   lambda= 1626.511
# phi= 1.922385   sv2= 0.001128153   df= 3.305004   lambda= 1704.01
# phi= 1.92356   sv2= 0.001103938   df= 3.27853   lambda= 1742.454
# phi= 1.924127   sv2= 0.001092665   df= 3.265957   lambda= 1760.949
# phi= 1.924396   sv2= 0.001087402   df= 3.260033   lambda= 1769.72
# phi= 1.924523   sv2= 0.00108494   df= 3.257251   lambda= 1773.852
# phi= 1.924583   sv2= 0.001083789   df= 3.255947   lambda= 1775.792
# phi= 1.924611   sv2= 0.001083249   df= 3.255336   lambda= 1776.701
# phi= 1.924624   sv2= 0.001082997   df= 3.25505   lambda= 1777.128
# phi= 1.92463   sv2= 0.001082879   df= 3.254916   lambda= 1777.327
# phi= 1.924633   sv2= 0.001082824   df= 3.254853   lambda= 1777.421
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/CR-TA_yhbP-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.13647   sv2= 0.04864305   df= 11.75873   lambda= 208.3848
# phi= 10.27497   sv2= 0.01145646   df= 5.925392   lambda= 896.8708
# phi= 10.40565   sv2= 0.005814605   df= 4.368461   lambda= 1789.571
# phi= 10.47778   sv2= 0.004022018   df= 3.809559   lambda= 2605.106
# phi= 10.51517   sv2= 0.003271418   df= 3.545759   lambda= 3214.254
# phi= 10.53505   sv2= 0.00291241   df= 3.409662   lambda= 3617.297
# phi= 10.5459   sv2= 0.002727685   df= 3.33664   lambda= 3866.245
# phi= 10.55191   sv2= 0.002628613   df= 3.29658   lambda= 4014.251
# phi= 10.55528   sv2= 0.002574209   df= 3.274308   lambda= 4100.398
# phi= 10.55717   sv2= 0.002543928   df= 3.261827   lambda= 4149.949
# phi= 10.55824   sv2= 0.002526946   df= 3.254801   lambda= 4178.262
# phi= 10.55885   sv2= 0.00251738   df= 3.250834   lambda= 4194.379
# phi= 10.55919   sv2= 0.002511979   df= 3.248592   lambda= 4203.534
# phi= 10.55938   sv2= 0.002508925   df= 3.247323   lambda= 4208.728
# phi= 10.55949   sv2= 0.002507196   df= 3.246605   lambda= 4211.674
# phi= 10.55955   sv2= 0.002506218   df= 3.246198   lambda= 4213.343
# phi= 10.55959   sv2= 0.002505663   df= 3.245968   lambda= 4214.289
# phi= 10.55961   sv2= 0.00250535   df= 3.245837   lambda= 4214.824
# phi= 10.55962   sv2= 0.002505172   df= 3.245763   lambda= 4215.128
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  93.014846  91.191513  93.253917  0.000251}
