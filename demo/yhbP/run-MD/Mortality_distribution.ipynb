# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/TA_yhbP-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/TA_yhbP-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.13647   sv2= 0.04864305   df= 11.75873   lambda= 208.3848
# phi= 10.27497   sv2= 0.01145646   df= 5.925392   lambda= 896.8708
# phi= 10.40565   sv2= 0.005814605   df= 4.368461   lambda= 1789.571
# phi= 10.47778   sv2= 0.004022018   df= 3.809559   lambda= 2605.106
# phi= 10.51517   sv2= 0.003271418   df= 3.545759   lambda= 3214.254
# phi= 10.53505   sv2= 0.00291241   df= 3.409662   lambda= 3617.297
# phi= 10.5459   sv2= 0.002727685   df= 3.33664   lambda= 3866.245
# phi= 10.55191   sv2= 0.002628613   df= 3.29658   lambda= 4014.251
# phi= 10.55528   sv2= 0.002574209   df= 3.274308   lambda= 4100.398
# phi= 10.55717   sv2= 0.002543928   df= 3.261827   lambda= 4149.949
# phi= 10.55824   sv2= 0.002526946   df= 3.254801   lambda= 4178.262
# phi= 10.55885   sv2= 0.00251738   df= 3.250834   lambda= 4194.379
# phi= 10.55919   sv2= 0.002511979   df= 3.248592   lambda= 4203.534
# phi= 10.55938   sv2= 0.002508925   df= 3.247323   lambda= 4208.728
# phi= 10.55949   sv2= 0.002507196   df= 3.246605   lambda= 4211.674
# phi= 10.55955   sv2= 0.002506218   df= 3.246198   lambda= 4213.343
# phi= 10.55959   sv2= 0.002505663   df= 3.245968   lambda= 4214.289
# phi= 10.55961   sv2= 0.00250535   df= 3.245837   lambda= 4214.824
# phi= 10.55962   sv2= 0.002505172   df= 3.245763   lambda= 4215.128
# save file prefixed name is : TA_yhbP-1_df_relative_timegrid-vs-TA_yhbP-1_timeseries_dataframe
# biName is :  TA_yhbP-1_df_relative_timegrid-vs-TA_yhbP-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yhbP/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yhbP-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yhbP/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yhbP/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yhbP-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.13647   sv2= 0.04864305   df= 11.75873   lambda= 208.3848
# phi= 10.27497   sv2= 0.01145646   df= 5.925392   lambda= 896.8708
# phi= 10.40565   sv2= 0.005814605   df= 4.368461   lambda= 1789.571
# phi= 10.47778   sv2= 0.004022018   df= 3.809559   lambda= 2605.106
# phi= 10.51517   sv2= 0.003271418   df= 3.545759   lambda= 3214.254
# phi= 10.53505   sv2= 0.00291241   df= 3.409662   lambda= 3617.297
# phi= 10.5459   sv2= 0.002727685   df= 3.33664   lambda= 3866.245
# phi= 10.55191   sv2= 0.002628613   df= 3.29658   lambda= 4014.251
# phi= 10.55528   sv2= 0.002574209   df= 3.274308   lambda= 4100.398
# phi= 10.55717   sv2= 0.002543928   df= 3.261827   lambda= 4149.949
# phi= 10.55824   sv2= 0.002526946   df= 3.254801   lambda= 4178.262
# phi= 10.55885   sv2= 0.00251738   df= 3.250834   lambda= 4194.379
# phi= 10.55919   sv2= 0.002511979   df= 3.248592   lambda= 4203.534
# phi= 10.55938   sv2= 0.002508925   df= 3.247323   lambda= 4208.728
# phi= 10.55949   sv2= 0.002507196   df= 3.246605   lambda= 4211.674
# phi= 10.55955   sv2= 0.002506218   df= 3.246198   lambda= 4213.343
# phi= 10.55959   sv2= 0.002505663   df= 3.245968   lambda= 4214.289
# phi= 10.55961   sv2= 0.00250535   df= 3.245837   lambda= 4214.824
# phi= 10.55962   sv2= 0.002505172   df= 3.245763   lambda= 4215.128
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yhbP/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhbP-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yhbP-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/MD-TA_yhbP-1_df_relative_timegrid-vs-TA_yhbP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yhbP-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7368.888947)
#                 est         L95%         U95%           se
# rate       0.088054     0.077336     0.100258     0.005831
# beta    3780.712409  1903.197862  7510.404781  1324.000694
# s          1.057030     0.723029     1.545322     0.204814
# lambda     0.000074     0.000007     0.000792     0.000089
#                 est       L95%       U95%       var
# lifespan  93.014846  91.191513  93.253917  0.000251
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbP/MD-TA_yhbP-1_df_relative_timegrid-vs-TA_yhbP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhbP-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yhbP/run-MD
