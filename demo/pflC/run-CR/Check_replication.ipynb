# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/TA_pflC-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/TA_pflC-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/TA_pflC-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC']
#
# out_name_s  ['TA_pflC-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/TA_pflC-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/TA_pflC-1_analysis_metadata.pickle
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 37-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 38-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 47-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 50-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 51-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 52-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 53-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 36-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 38-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 47-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 50-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 51-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 52-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 53-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 37-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 38-1.tif.mortality.tab ------ MAX_16012014 Position 47-1.tif.mortality.tab
# MAX_16012014 Position 38-1.tif.mortality.tab ------ MAX_16012014 Position 50-1.tif.mortality.tab
# MAX_16012014 Position 38-1.tif.mortality.tab ------ MAX_16012014 Position 51-1.tif.mortality.tab
# MAX_16012014 Position 38-1.tif.mortality.tab ------ MAX_16012014 Position 52-1.tif.mortality.tab
# MAX_16012014 Position 38-1.tif.mortality.tab ------ MAX_16012014 Position 53-1.tif.mortality.tab
# MAX_16012014 Position 38-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 38-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 47-1.tif.mortality.tab ------ MAX_16012014 Position 50-1.tif.mortality.tab
# MAX_16012014 Position 47-1.tif.mortality.tab ------ MAX_16012014 Position 51-1.tif.mortality.tab
# MAX_16012014 Position 47-1.tif.mortality.tab ------ MAX_16012014 Position 52-1.tif.mortality.tab
# MAX_16012014 Position 47-1.tif.mortality.tab ------ MAX_16012014 Position 53-1.tif.mortality.tab
# MAX_16012014 Position 47-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 47-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 50-1.tif.mortality.tab ------ MAX_16012014 Position 51-1.tif.mortality.tab
# MAX_16012014 Position 50-1.tif.mortality.tab ------ MAX_16012014 Position 52-1.tif.mortality.tab
# MAX_16012014 Position 50-1.tif.mortality.tab ------ MAX_16012014 Position 53-1.tif.mortality.tab
# MAX_16012014 Position 50-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 50-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 51-1.tif.mortality.tab ------ MAX_16012014 Position 52-1.tif.mortality.tab
# MAX_16012014 Position 51-1.tif.mortality.tab ------ MAX_16012014 Position 53-1.tif.mortality.tab
# MAX_16012014 Position 51-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 51-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 52-1.tif.mortality.tab ------ MAX_16012014 Position 53-1.tif.mortality.tab
# MAX_16012014 Position 52-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 52-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 53-1.tif.mortality.tab ------ MAX_16012014 Position 93A-1.tif.mortality.tab
# MAX_16012014 Position 53-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# MAX_16012014 Position 93A-1.tif.mortality.tab ------ MAX_16012014 Position 94A-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_dentrogram-all-files.eps
# [['MAX_16012014 Position 51-1.tif.mortality.tab', 'MAX_16012014 Position 52-1.tif.mortality.tab', 'MAX_16012014 Position 53-1.tif.mortality.tab'], ['MAX_16012014 Position 36-1.tif.mortality.tab', 'MAX_16012014 Position 37-1.tif.mortality.tab', 'MAX_16012014 Position 38-1.tif.mortality.tab', 'MAX_16012014 Position 47-1.tif.mortality.tab', 'MAX_16012014 Position 50-1.tif.mortality.tab', 'MAX_16012014 Position 94A-1.tif.mortality.tab'], ['MAX_16012014 Position 93A-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 31.10641   sv2= 0.07548175   df= 13.1023   lambda= 412.1051
# phi= 31.85749   sv2= 0.00410759   df= 5.761648   lambda= 7755.762
# phi= 32.54991   sv2= 0.002637419   df= 3.261913   lambda= 12341.58
# Iterations: relative error in phi-hat = 1e-04
# phi= 126.2631   sv2= 0.08559541   df= 13.12597   lambda= 1475.116
# phi= 131.029   sv2= 0.00391693   df= 4.465859   lambda= 33451.96
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.52169   sv2= 0.108254   df= 14.72546   lambda= 346.608
# phi= 38.45255   sv2= 0.005536267   df= 6.716062   lambda= 6945.575
# phi= 39.51368   sv2= 0.003399484   df= 3.65091   lambda= 11623.43
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  85.320527  84.307048  85.725242  0.000138}
