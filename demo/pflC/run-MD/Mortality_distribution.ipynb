# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/TA_pflC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/TA_pflC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.12574   sv2= 0.1045513   df= 14.14873   lambda= 326.4018
# phi= 34.62374   sv2= 0.008351631   df= 6.385246   lambda= 4145.746
# phi= 35.42282   sv2= 0.004804788   df= 3.771931   lambda= 7372.399
# phi= 35.77286   sv2= 0.004366492   df= 3.402231   lambda= 8192.585
# phi= 35.8487   sv2= 0.004272028   df= 3.341052   lambda= 8391.495
# phi= 35.86652   sv2= 0.004249837   df= 3.327404   lambda= 8439.505
# phi= 35.87078   sv2= 0.00424452   df= 3.324172   lambda= 8451.082
# phi= 35.87181   sv2= 0.00424324   df= 3.323396   lambda= 8453.873
# phi= 35.87206   sv2= 0.004242932   df= 3.323209   lambda= 8454.546
# save file prefixed name is : TA_pflC-1_df_relative_timegrid-vs-TA_pflC-1_timeseries_dataframe
# biName is :  TA_pflC-1_df_relative_timegrid-vs-TA_pflC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/pflC/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_pflC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/pflC/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/pflC/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_pflC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.12574   sv2= 0.1045513   df= 14.14873   lambda= 326.4018
# phi= 34.62374   sv2= 0.008351631   df= 6.385246   lambda= 4145.746
# phi= 35.42282   sv2= 0.004804788   df= 3.771931   lambda= 7372.399
# phi= 35.77286   sv2= 0.004366492   df= 3.402231   lambda= 8192.585
# phi= 35.8487   sv2= 0.004272028   df= 3.341052   lambda= 8391.495
# phi= 35.86652   sv2= 0.004249837   df= 3.327404   lambda= 8439.505
# phi= 35.87078   sv2= 0.00424452   df= 3.324172   lambda= 8451.082
# phi= 35.87181   sv2= 0.00424324   df= 3.323396   lambda= 8453.873
# phi= 35.87206   sv2= 0.004242932   df= 3.323209   lambda= 8454.546
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/pflC/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pflC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_pflC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/MD-TA_pflC-1_df_relative_timegrid-vs-TA_pflC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_pflC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=16696.651728)
#                  est          L95%          U95%           se
# rate    1.045080e-01  9.606134e-02      0.113697     0.004494
# beta    6.724667e+03  4.152014e+03  10891.378201  1654.398170
# s       8.831580e-01  7.161177e-01      1.089162     0.094472
# lambda  3.227657e-07  3.361730e-16    309.893141     0.000003
#                 est       L95%     U95%       var
# lifespan  85.725242  85.320527  86.4482  0.000124
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/MD-TA_pflC-1_df_relative_timegrid-vs-TA_pflC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pflC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/pflC/run-MD
