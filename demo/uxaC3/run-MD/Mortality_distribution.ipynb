# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3'
ref_df_path = '/app/src/ms2/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/TA_uxaC3-1_df_relative_timegrid.pickle']]
# []
# [['/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/TA_uxaC3-1_timeseries_dataframe.pickle']]
# /app/src/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /app/src/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.32831027777777
# files will be written into :  /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3
# Iterations: relative error in phi-hat = 1e-04
# phi= 139.2151   sv2= 3.514856   df= 15.8838   lambda= 39.60762
# phi= 163.7264   sv2= 1.471048   df= 12.2304   lambda= 111.2992
# phi= 193.763   sv2= 0.6585785   df= 10.0281   lambda= 294.2139
# phi= 234.1618   sv2= 0.2583725   df= 8.276738   lambda= 906.2953
# phi= 285.7084   sv2= 0.06945121   df= 6.574647   lambda= 4113.8
# phi= 333.8059   sv2= 0.01132524   df= 4.8323   lambda= 29474.51
# save file prefixed name is : TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe
# biName is :  TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe
# getGGMfit_dict--(1) /app/src/ms2/demo/uxaC3/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_uxaC3-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /app/src/ms2/demo/uxaC3/run-MD
# getKMNABSfits_dict-- /app/src/ms2/demo/uxaC3/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_uxaC3-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 139.2151   sv2= 3.514856   df= 15.8838   lambda= 39.60762
# phi= 163.7264   sv2= 1.471048   df= 12.2304   lambda= 111.2992
# phi= 193.763   sv2= 0.6585785   df= 10.0281   lambda= 294.2139
# phi= 234.1618   sv2= 0.2583725   df= 8.276738   lambda= 906.2953
# phi= 285.7084   sv2= 0.06945121   df= 6.574647   lambda= 4113.8
# phi= 333.8059   sv2= 0.01132524   df= 4.8323   lambda= 29474.51
# getKMNABSfits_dict-- /app/src/ms2/demo/uxaC3/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_uxaC3-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_uxaC3-1_df_relative_timegrid.pickle
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/MD-TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_uxaC3-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=25112.098343)
#                est        L95%        U95%          se
# rate      0.065518    0.054604    0.078614    0.006091
# beta    501.703789  254.298991  989.806101  173.935499
# s         0.646962    0.445257    0.940041    0.123333
# lambda    0.003733    0.003338    0.004175    0.000213
#                 est       L95%       U95%       var
# lifespan  90.997408  90.976158  91.962034  0.000095
#
#
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/MD-TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_uxaC3-1_df_relative_timegrid.pickle
# working directory is :  /app/src/ms2/demo/uxaC3/run-MD
