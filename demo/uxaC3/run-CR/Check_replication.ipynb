# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3'
path_ref_folder ='/app/src/ms2/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /app/src/ms2/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /app/src/ms2/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /app/src/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /app/src/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/TA_uxaC3-1_mortality_dataframe.pickle']]
# meta_paths:  [['/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/TA_uxaC3-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/TA_uxaC3-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3']
#
# out_name_s  ['TA_uxaC3-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/TA_uxaC3-1_mortality_dataframe.pickle
# path meta  /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/TA_uxaC3-1_analysis_metadata.pickle
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 157-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 171-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 175-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 176-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 177-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 181-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 185-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 171-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 175-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 176-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 177-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 181-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 185-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 157-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 175-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 176-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 177-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 181-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 185-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 171-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 176-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 177-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 181-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 185-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 175-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 176-1.tif.mortality.tab ------ MAX_12072018 Position 177-1.tif.mortality.tab
# MAX_12072018 Position 176-1.tif.mortality.tab ------ MAX_12072018 Position 181-1.tif.mortality.tab
# MAX_12072018 Position 176-1.tif.mortality.tab ------ MAX_12072018 Position 185-1.tif.mortality.tab
# MAX_12072018 Position 176-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 176-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 176-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 176-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 177-1.tif.mortality.tab ------ MAX_12072018 Position 181-1.tif.mortality.tab
# MAX_12072018 Position 177-1.tif.mortality.tab ------ MAX_12072018 Position 185-1.tif.mortality.tab
# MAX_12072018 Position 177-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 177-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 177-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 177-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 181-1.tif.mortality.tab ------ MAX_12072018 Position 185-1.tif.mortality.tab
# MAX_12072018 Position 181-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 181-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 181-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 181-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 185-1.tif.mortality.tab ------ MAX_12072018 Position 192-1.tif.mortality.tab
# MAX_12072018 Position 185-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 185-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 185-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 192-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 192-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 192-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# dendrogram will be saved to :  /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3
# save eps to :  /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_dentrogram-all-files.eps
# [['MAX_12072018 Position 219-1.tif.mortality.tab', 'MAX_12072018 Position 220-1.tif.mortality.tab'], ['MAX_12072018 Position 157-1.tif.mortality.tab'], ['MAX_12072018 Position 181-1.tif.mortality.tab'], ['MAX_12072018 Position 185-1.tif.mortality.tab'], ['MAX_12072018 Position 177-1.tif.mortality.tab'], ['MAX_12072018 Position 111-1.tif.mortality.tab', 'MAX_12072018 Position 217-1.tif.mortality.tab'], ['MAX_12072018 Position 171-1.tif.mortality.tab'], ['MAX_12072018 Position 175-1.tif.mortality.tab'], ['MAX_12072018 Position 192-1.tif.mortality.tab'], ['MAX_12072018 Position 176-1.tif.mortality.tab']]
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_colomap_all_files_cluster0.png
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_mortality_orig_dataframe_cluster0.pickle
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 348.458   sv2= 0.09320802   df= 10.58309   lambda= 3738.498
# phi= 406.1617   sv2= 0.00285211   df= 3.225614   lambda= 142407.5
# No error in flxsrv_fit
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_mortality_dataframe_cluster0.pickle
# 10 --c-- 1
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_relative_timegrid_cluster0.pickle
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_timeseries_dataframe_cluster0.pickle
# /app/src/ms2/dataset/MS 2 part 9 version 2 correct/uxaC3/CR-TA_uxaC3-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 348.458   sv2= 0.09320802   df= 10.58309   lambda= 3738.498
# phi= 406.1617   sv2= 0.00285211   df= 3.225614   lambda= 142407.5
# No error in flxsrv_fit
# {0:                  est        L95%       U95%       var
# lifespan  126.119658  123.127794  129.12861  0.000624}
