# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/TA_sugE-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/TA_sugE-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/TA_sugE-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE']
#
# out_name_s  ['TA_sugE-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/TA_sugE-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/TA_sugE-1_analysis_metadata.pickle
# MAX_18102018 Position 142-1.tif.mortality.tab ------ MAX_18102018 Position 143-1.tif.mortality.tab
# MAX_18102018 Position 142-1.tif.mortality.tab ------ MAX_18102018 Position 144-1.tif.mortality.tab
# MAX_18102018 Position 142-1.tif.mortality.tab ------ MAX_18102018 Position 145-1.tif.mortality.tab
# MAX_18102018 Position 142-1.tif.mortality.tab ------ MAX_18102018 Position 191-1.tif.mortality.tab
# MAX_18102018 Position 142-1.tif.mortality.tab ------ MAX_18102018 Position 192-1.tif.mortality.tab
# MAX_18102018 Position 142-1.tif.mortality.tab ------ MAX_18102018 Position 282-1.tif.mortality.tab
# MAX_18102018 Position 142-1.tif.mortality.tab ------ MAX_18102018 Position 93-1.tif.mortality.tab
# MAX_18102018 Position 143-1.tif.mortality.tab ------ MAX_18102018 Position 144-1.tif.mortality.tab
# MAX_18102018 Position 143-1.tif.mortality.tab ------ MAX_18102018 Position 145-1.tif.mortality.tab
# MAX_18102018 Position 143-1.tif.mortality.tab ------ MAX_18102018 Position 191-1.tif.mortality.tab
# MAX_18102018 Position 143-1.tif.mortality.tab ------ MAX_18102018 Position 192-1.tif.mortality.tab
# MAX_18102018 Position 143-1.tif.mortality.tab ------ MAX_18102018 Position 282-1.tif.mortality.tab
# MAX_18102018 Position 143-1.tif.mortality.tab ------ MAX_18102018 Position 93-1.tif.mortality.tab
# MAX_18102018 Position 144-1.tif.mortality.tab ------ MAX_18102018 Position 145-1.tif.mortality.tab
# MAX_18102018 Position 144-1.tif.mortality.tab ------ MAX_18102018 Position 191-1.tif.mortality.tab
# MAX_18102018 Position 144-1.tif.mortality.tab ------ MAX_18102018 Position 192-1.tif.mortality.tab
# MAX_18102018 Position 144-1.tif.mortality.tab ------ MAX_18102018 Position 282-1.tif.mortality.tab
# MAX_18102018 Position 144-1.tif.mortality.tab ------ MAX_18102018 Position 93-1.tif.mortality.tab
# MAX_18102018 Position 145-1.tif.mortality.tab ------ MAX_18102018 Position 191-1.tif.mortality.tab
# MAX_18102018 Position 145-1.tif.mortality.tab ------ MAX_18102018 Position 192-1.tif.mortality.tab
# MAX_18102018 Position 145-1.tif.mortality.tab ------ MAX_18102018 Position 282-1.tif.mortality.tab
# MAX_18102018 Position 145-1.tif.mortality.tab ------ MAX_18102018 Position 93-1.tif.mortality.tab
# MAX_18102018 Position 191-1.tif.mortality.tab ------ MAX_18102018 Position 192-1.tif.mortality.tab
# MAX_18102018 Position 191-1.tif.mortality.tab ------ MAX_18102018 Position 282-1.tif.mortality.tab
# MAX_18102018 Position 191-1.tif.mortality.tab ------ MAX_18102018 Position 93-1.tif.mortality.tab
# MAX_18102018 Position 192-1.tif.mortality.tab ------ MAX_18102018 Position 282-1.tif.mortality.tab
# MAX_18102018 Position 192-1.tif.mortality.tab ------ MAX_18102018 Position 93-1.tif.mortality.tab
# MAX_18102018 Position 282-1.tif.mortality.tab ------ MAX_18102018 Position 93-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_dentrogram-all-files.eps
# [['MAX_18102018 Position 143-1.tif.mortality.tab'], ['MAX_18102018 Position 282-1.tif.mortality.tab'], ['MAX_18102018 Position 192-1.tif.mortality.tab'], ['MAX_18102018 Position 93-1.tif.mortality.tab'], ['MAX_18102018 Position 142-1.tif.mortality.tab', 'MAX_18102018 Position 191-1.tif.mortality.tab'], ['MAX_18102018 Position 144-1.tif.mortality.tab', 'MAX_18102018 Position 145-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 552.0997   sv2= 0.260511   df= 14.12815   lambda= 2119.295
# phi= 645.2979   sv2= 0.006738197   df= 4.558418   lambda= 95767.14
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.6739   sv2= 0.2222774   df= 12.897   lambda= 48.0206
# phi= 11.69672   sv2= 0.06392727   df= 9.12965   lambda= 182.9692
# phi= 12.61788   sv2= 0.02347886   df= 6.842816   lambda= 537.4146
# phi= 13.45386   sv2= 0.009482881   df= 5.459835   lambda= 1418.753
# phi= 14.17288   sv2= 0.00346692   df= 4.481237   lambda= 4088.033
# phi= 14.74818   sv2= 0.001068527   df= 3.645149   lambda= 13802.35
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_mortality_dataframe_cluster0.pickle
# 6 --c-- 5
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_mortality_dataframe_cluster1.pickle
# 6 --c-- 4
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/sugE/CR-TA_sugE-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 552.0997   sv2= 0.260511   df= 14.12815   lambda= 2119.295
# phi= 645.2979   sv2= 0.006738197   df= 4.558418   lambda= 95767.14
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.6739   sv2= 0.2222774   df= 12.897   lambda= 48.0206
# phi= 11.69672   sv2= 0.06392727   df= 9.12965   lambda= 182.9692
# phi= 12.61788   sv2= 0.02347886   df= 6.842816   lambda= 537.4146
# phi= 13.45386   sv2= 0.009482881   df= 5.459835   lambda= 1418.753
# phi= 14.17288   sv2= 0.00346692   df= 4.481237   lambda= 4088.033
# phi= 14.74818   sv2= 0.001068527   df= 3.645149   lambda= 13802.35
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  106.353109  106.348557  108.830468  0.000204, 1:                  est        L95%        U95%       var
# lifespan  106.340116  103.875994  113.748071  0.000352}
