# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspF'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspF/TA_gspF-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspF/TA_gspF-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspF
# Iterations: relative error in phi-hat = 1e-04
# phi= 121.8039   sv2= 0.417118   df= 17.68074   lambda= 292.0131
# phi= 136.1865   sv2= 0.03232922   df= 8.485306   lambda= 4212.489
# phi= 151.7578   sv2= 0.002488921   df= 4.852438   lambda= 60973.31
# save file prefixed name is : TA_gspF-1_df_relative_timegrid-vs-TA_gspF-1_timeseries_dataframe
# biName is :  TA_gspF-1_df_relative_timegrid-vs-TA_gspF-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/gspF/run-MD
# No error in flxsrv_fit
# TA_gspF-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/gspF/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gspF/run-MD
# TA_gspF-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 121.8039   sv2= 0.417118   df= 17.68074   lambda= 292.0131
# phi= 136.1865   sv2= 0.03232922   df= 8.485306   lambda= 4212.489
# phi= 151.7578   sv2= 0.002488921   df= 4.852438   lambda= 60973.31
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gspF/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gspF-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_gspF-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspF/MD-TA_gspF-1_df_relative_timegrid-vs-TA_gspF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_gspF-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=28815.992674)
#                  est          L95%          U95%            se
# rate    7.213938e-02  6.819104e-02  7.631634e-02  2.071725e-03
# beta    7.204774e+06  3.568638e-07  1.454582e+20  1.126177e+08
# s       1.796544e+03  8.372052e-11  3.855173e+16  2.813766e+04
# lambda  2.487509e-03  2.239502e-03  2.762982e-03  1.332982e-04
#                est        L95%        U95%       var
# lifespan  103.7292  102.744071  103.962642  0.000074
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspF/MD-TA_gspF-1_df_relative_timegrid-vs-TA_gspF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gspF-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/gspF/run-MD
