# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/TA_citT-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/TA_citT-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/TA_citT-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT']
#
# out_name_s  ['TA_citT-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/TA_citT-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/TA_citT-1_analysis_metadata.pickle
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 143-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 145-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 146-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 24-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 25-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 31-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 33-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 142-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 145-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 146-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 24-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 25-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 31-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 33-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 143-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 146-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 24-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 25-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 31-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 33-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 145-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 24-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 25-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 31-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 33-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 146-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 25-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 31-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 33-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 24-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 31-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 33-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 25-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 31-1.tif.mortality.tab ------ MAX_30112014 Position 33-1.tif.mortality.tab
# MAX_30112014 Position 31-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 31-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 31-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 31-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 31-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 31-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 33-1.tif.mortality.tab ------ MAX_30112014 Position 50-1.tif.mortality.tab
# MAX_30112014 Position 33-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 33-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 33-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 33-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 33-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 50-1.tif.mortality.tab ------ MAX_30112014 Position 51-1.tif.mortality.tab
# MAX_30112014 Position 50-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 50-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 50-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 50-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 51-1.tif.mortality.tab ------ MAX_30112014 Position 73-1.tif.mortality.tab
# MAX_30112014 Position 51-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 51-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 51-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 73-1.tif.mortality.tab ------ MAX_30112014 Position 76-1.tif.mortality.tab
# MAX_30112014 Position 73-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 73-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 76-1.tif.mortality.tab ------ MAX_30112014 Position 86-1.tif.mortality.tab
# MAX_30112014 Position 76-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# MAX_30112014 Position 86-1.tif.mortality.tab ------ MAX_30112014 Position 87-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_dentrogram-all-files.eps
# 4 [3 2 1 1]
# [['MAX_30112014 Position 143-1.tif.mortality.tab', 'MAX_30112014 Position 145-1.tif.mortality.tab', 'MAX_30112014 Position 146-1.tif.mortality.tab', 'MAX_30112014 Position 73-1.tif.mortality.tab', 'MAX_30112014 Position 76-1.tif.mortality.tab'], ['MAX_30112014 Position 142-1.tif.mortality.tab', 'MAX_30112014 Position 25-1.tif.mortality.tab', 'MAX_30112014 Position 50-1.tif.mortality.tab', 'MAX_30112014 Position 51-1.tif.mortality.tab'], ['MAX_30112014 Position 24-1.tif.mortality.tab', 'MAX_30112014 Position 31-1.tif.mortality.tab', 'MAX_30112014 Position 33-1.tif.mortality.tab', 'MAX_30112014 Position 86-1.tif.mortality.tab', 'MAX_30112014 Position 87-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 102.599   sv2= 0.2275561   df= 12.74655   lambda= 450.8735
# phi= 108.6392   sv2= 0.02144349   df= 5.663255   lambda= 5066.303
# phi= 119.2739   sv2= 0.007395623   df= 3.475437   lambda= 16127.63
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.293317   sv2= 0.07817485   df= 11.05746   lambda= 93.29493
# phi= 7.621975   sv2= 0.0214507   df= 6.833804   lambda= 355.3252
# phi= 7.886977   sv2= 0.01034828   df= 5.181043   lambda= 762.1535
# phi= 8.071113   sv2= 0.007174289   df= 4.451296   lambda= 1125.005
# phi= 8.183774   sv2= 0.005816957   df= 4.127935   lambda= 1406.882
# phi= 8.254654   sv2= 0.005077746   df= 3.955323   lambda= 1625.653
# phi= 8.302552   sv2= 0.004616427   df= 3.848422   lambda= 1798.48
# phi= 8.336828   sv2= 0.004303028   df= 3.775774   lambda= 1937.433
# phi= 8.362412   sv2= 0.004077593   df= 3.723321   lambda= 2050.821
# phi= 8.382118   sv2= 0.003908693   df= 3.683827   lambda= 2144.481
# phi= 8.397666   sv2= 0.003778273   df= 3.653172   lambda= 2222.62
# phi= 8.410163   sv2= 0.003675214   df= 3.628827   lambda= 2288.347
# phi= 8.420359   sv2= 0.003592288   df= 3.609148   lambda= 2344.01
# phi= 8.428778   sv2= 0.003524592   df= 3.593016   lambda= 2391.42
# phi= 8.435798   sv2= 0.003468677   df= 3.579642   lambda= 2431.993
# phi= 8.441698   sv2= 0.003422047   df= 3.568451   lambda= 2466.856
# phi= 8.446691   sv2= 0.003382849   df= 3.559017   lambda= 2496.917
# phi= 8.450941   sv2= 0.003349677   df= 3.551013   lambda= 2522.912
# phi= 8.454575   sv2= 0.003321447   df= 3.544186   lambda= 2545.449
# phi= 8.457695   sv2= 0.003297308   df= 3.538336   lambda= 2565.03
# phi= 8.460384   sv2= 0.003276583   df= 3.533305   lambda= 2582.075
# phi= 8.462708   sv2= 0.003258727   df= 3.528964   lambda= 2596.937
# phi= 8.464721   sv2= 0.003243296   df= 3.525207   lambda= 2609.913
# phi= 8.46647   sv2= 0.003229927   df= 3.521948   lambda= 2621.257
# phi= 8.467991   sv2= 0.003218319   df= 3.519116   lambda= 2631.185
# phi= 8.469317   sv2= 0.00320822   df= 3.516649   lambda= 2639.881
# phi= 8.470474   sv2= 0.003199419   df= 3.514498   lambda= 2647.504
# phi= 8.471486   sv2= 0.003191738   df= 3.512619   lambda= 2654.192
# phi= 8.47237   sv2= 0.003185025   df= 3.510977   lambda= 2660.064
# phi= 8.473145   sv2= 0.003179154   df= 3.509539   lambda= 2665.22
# phi= 8.473824   sv2= 0.003174012   df= 3.508279   lambda= 2669.752
# phi= 8.47442   sv2= 0.003169505   df= 3.507174   lambda= 2673.736
# phi= 8.474943   sv2= 0.003165553   df= 3.506205   lambda= 2677.239
# phi= 8.475402   sv2= 0.003162084   df= 3.505354   lambda= 2680.321
# phi= 8.475805   sv2= 0.003159038   df= 3.504607   lambda= 2683.034
# phi= 8.47616   sv2= 0.003156362   df= 3.50395   lambda= 2685.421
# phi= 8.476471   sv2= 0.003154009   df= 3.503373   lambda= 2687.523
# phi= 8.476746   sv2= 0.003151941   df= 3.502865   lambda= 2689.374
# phi= 8.476987   sv2= 0.003150121   df= 3.502418   lambda= 2691.004
# phi= 8.477199   sv2= 0.00314852   df= 3.502025   lambda= 2692.439
# phi= 8.477386   sv2= 0.003147111   df= 3.501679   lambda= 2693.704
# phi= 8.477551   sv2= 0.003145871   df= 3.501374   lambda= 2694.819
# phi= 8.477696   sv2= 0.003144778   df= 3.501106   lambda= 2695.801
# phi= 8.477824   sv2= 0.003143817   df= 3.500869   lambda= 2696.666
# phi= 8.477936   sv2= 0.003142969   df= 3.500661   lambda= 2697.429
# phi= 8.478035   sv2= 0.003142223   df= 3.500478   lambda= 2698.101
# phi= 8.478123   sv2= 0.003141566   df= 3.500316   lambda= 2698.693
# phi= 8.4782   sv2= 0.003140986   df= 3.500174   lambda= 2699.216
# phi= 8.478267   sv2= 0.003140476   df= 3.500048   lambda= 2699.676
# phi= 8.478327   sv2= 0.003140026   df= 3.499937   lambda= 2700.082
# phi= 8.47838   sv2= 0.003139629   df= 3.49984   lambda= 2700.44
# phi= 8.478426   sv2= 0.00313928   df= 3.499754   lambda= 2700.755
# phi= 8.478467   sv2= 0.003138972   df= 3.499678   lambda= 2701.033
# phi= 8.478503   sv2= 0.0031387   df= 3.499612   lambda= 2701.278
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.25684   sv2= 0.06954581   df= 10.49563   lambda= 564.4745
# phi= 40.58583   sv2= 0.004111031   df= 4.443785   lambda= 9872.421
# phi= 42.5703   sv2= 0.001407708   df= 2.578473   lambda= 30240.87
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/citT/CR-TA_citT-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 77.33327   sv2= 0.2207597   df= 13.06212   lambda= 350.3051
# phi= 82.0685   sv2= 0.02162437   df= 6.102419   lambda= 3795.185
# phi= 89.07439   sv2= 0.00843664   df= 3.758203   lambda= 10558.04
# Iterations: relative error in phi-hat = 1e-04
# phi= 23.33365   sv2= 0.09588992   df= 12.1701   lambda= 243.3379
# phi= 24.06667   sv2= 0.01087788   df= 6.077626   lambda= 2212.442
# phi= 24.42875   sv2= 0.002841125   df= 3.903461   lambda= 8598.267
# phi= 24.73988   sv2= 0.001001222   df= 3.028752   lambda= 24709.68
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est        L95%        U95%       var
# lifespan  103.92177  102.737427  105.916743  0.000184, 1:                  est        L95%        U95%       var
# lifespan  114.970655  111.982655  116.542772  0.000291}
