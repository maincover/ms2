# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/atoS'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/atoS/TA_atoS-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/atoS/TA_atoS-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/atoS
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.46614   sv2= 0.1696419   df= 13.379   lambda= 173.6961
# phi= 30.63608   sv2= 0.03033249   df= 7.184471   lambda= 1010.009
# phi= 31.09922   sv2= 0.01379268   df= 5.062364   lambda= 2254.762
# phi= 31.55957   sv2= 0.009743341   df= 4.366214   lambda= 3239.091
# phi= 31.87609   sv2= 0.008548219   df= 4.093018   lambda= 3728.975
# phi= 32.02012   sv2= 0.008182221   df= 3.992904   lambda= 3913.378
# phi= 32.07242   sv2= 0.008068276   df= 3.959346   lambda= 3975.127
# phi= 32.08971   sv2= 0.008032515   df= 3.948543   lambda= 3994.977
# phi= 32.09525   sv2= 0.008021258   df= 3.945114   lambda= 4001.274
# phi= 32.09701   sv2= 0.00801771   df= 3.944031   lambda= 4003.263
# phi= 32.09756   sv2= 0.008016592   df= 3.943689   lambda= 4003.891
# phi= 32.09773   sv2= 0.008016239   df= 3.943581   lambda= 4004.089
# save file prefixed name is : TA_atoS-1_df_relative_timegrid-vs-TA_atoS-1_timeseries_dataframe
# biName is :  TA_atoS-1_df_relative_timegrid-vs-TA_atoS-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/atoS/run-MD
# No error in flxsrv_fit
# TA_atoS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/atoS/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/atoS/run-MD
# TA_atoS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.46614   sv2= 0.1696419   df= 13.379   lambda= 173.6961
# phi= 30.63608   sv2= 0.03033249   df= 7.184471   lambda= 1010.009
# phi= 31.09922   sv2= 0.01379268   df= 5.062364   lambda= 2254.762
# phi= 31.55957   sv2= 0.009743341   df= 4.366214   lambda= 3239.091
# phi= 31.87609   sv2= 0.008548219   df= 4.093018   lambda= 3728.975
# phi= 32.02012   sv2= 0.008182221   df= 3.992904   lambda= 3913.378
# phi= 32.07242   sv2= 0.008068276   df= 3.959346   lambda= 3975.127
# phi= 32.08971   sv2= 0.008032515   df= 3.948543   lambda= 3994.977
# phi= 32.09525   sv2= 0.008021258   df= 3.945114   lambda= 4001.274
# phi= 32.09701   sv2= 0.00801771   df= 3.944031   lambda= 4003.263
# phi= 32.09756   sv2= 0.008016592   df= 3.943689   lambda= 4003.891
# phi= 32.09773   sv2= 0.008016239   df= 3.943581   lambda= 4004.089
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/atoS/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_atoS-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_atoS-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/atoS/MD-TA_atoS-1_df_relative_timegrid-vs-TA_atoS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_atoS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=9789.669137)
#                  est          L95%          U95%            se
# rate    1.584181e-01  1.290503e-01  1.944691e-01  1.657242e-02
# beta    8.883890e+08  1.889330e+07  4.177327e+10  1.745355e+09
# s       2.983467e-01  2.106706e-01  4.225115e-01  5.296671e-02
# lambda  2.438744e-03  2.159448e-03  2.754163e-03  1.513424e-04
#                 est      L95%        U95%       var
# lifespan  135.97935  134.3021  138.253011  0.000208
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/atoS/MD-TA_atoS-1_df_relative_timegrid-vs-TA_atoS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_atoS-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/atoS/run-MD
