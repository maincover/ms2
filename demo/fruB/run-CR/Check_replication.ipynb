# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/TA_fruB-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/TA_fruB-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/TA_fruB-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB']
#
# out_name_s  ['TA_fruB-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/TA_fruB-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/TA_fruB-1_analysis_metadata.pickle
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 16-1.tif.mortality.tab
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 17-1.tif.mortality.tab
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 18-1.tif.mortality.tab
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 21-1.tif.mortality.tab
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 23-1.tif.mortality.tab
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 46-1.tif.mortality.tab
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 6-1.tif.mortality.tab
# MAX_10092018 Position 15-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# MAX_10092018 Position 16-1.tif.mortality.tab ------ MAX_10092018 Position 17-1.tif.mortality.tab
# MAX_10092018 Position 16-1.tif.mortality.tab ------ MAX_10092018 Position 18-1.tif.mortality.tab
# MAX_10092018 Position 16-1.tif.mortality.tab ------ MAX_10092018 Position 21-1.tif.mortality.tab
# MAX_10092018 Position 16-1.tif.mortality.tab ------ MAX_10092018 Position 23-1.tif.mortality.tab
# MAX_10092018 Position 16-1.tif.mortality.tab ------ MAX_10092018 Position 46-1.tif.mortality.tab
# MAX_10092018 Position 16-1.tif.mortality.tab ------ MAX_10092018 Position 6-1.tif.mortality.tab
# MAX_10092018 Position 16-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# MAX_10092018 Position 17-1.tif.mortality.tab ------ MAX_10092018 Position 18-1.tif.mortality.tab
# MAX_10092018 Position 17-1.tif.mortality.tab ------ MAX_10092018 Position 21-1.tif.mortality.tab
# MAX_10092018 Position 17-1.tif.mortality.tab ------ MAX_10092018 Position 23-1.tif.mortality.tab
# MAX_10092018 Position 17-1.tif.mortality.tab ------ MAX_10092018 Position 46-1.tif.mortality.tab
# MAX_10092018 Position 17-1.tif.mortality.tab ------ MAX_10092018 Position 6-1.tif.mortality.tab
# MAX_10092018 Position 17-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# MAX_10092018 Position 18-1.tif.mortality.tab ------ MAX_10092018 Position 21-1.tif.mortality.tab
# MAX_10092018 Position 18-1.tif.mortality.tab ------ MAX_10092018 Position 23-1.tif.mortality.tab
# MAX_10092018 Position 18-1.tif.mortality.tab ------ MAX_10092018 Position 46-1.tif.mortality.tab
# MAX_10092018 Position 18-1.tif.mortality.tab ------ MAX_10092018 Position 6-1.tif.mortality.tab
# MAX_10092018 Position 18-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# MAX_10092018 Position 21-1.tif.mortality.tab ------ MAX_10092018 Position 23-1.tif.mortality.tab
# MAX_10092018 Position 21-1.tif.mortality.tab ------ MAX_10092018 Position 46-1.tif.mortality.tab
# MAX_10092018 Position 21-1.tif.mortality.tab ------ MAX_10092018 Position 6-1.tif.mortality.tab
# MAX_10092018 Position 21-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# MAX_10092018 Position 23-1.tif.mortality.tab ------ MAX_10092018 Position 46-1.tif.mortality.tab
# MAX_10092018 Position 23-1.tif.mortality.tab ------ MAX_10092018 Position 6-1.tif.mortality.tab
# MAX_10092018 Position 23-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# MAX_10092018 Position 46-1.tif.mortality.tab ------ MAX_10092018 Position 6-1.tif.mortality.tab
# MAX_10092018 Position 46-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# MAX_10092018 Position 6-1.tif.mortality.tab ------ MAX_10092018 Position 8-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_dentrogram-all-files.eps
# 4 [1 1 2 3]
# [['MAX_10092018 Position 15-1.tif.mortality.tab', 'MAX_10092018 Position 16-1.tif.mortality.tab', 'MAX_10092018 Position 21-1.tif.mortality.tab'], ['MAX_10092018 Position 17-1.tif.mortality.tab', 'MAX_10092018 Position 18-1.tif.mortality.tab', 'MAX_10092018 Position 6-1.tif.mortality.tab'], ['MAX_10092018 Position 23-1.tif.mortality.tab', 'MAX_10092018 Position 46-1.tif.mortality.tab', 'MAX_10092018 Position 8-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 289.3813   sv2= 0.3811417   df= 15.6182   lambda= 759.2485
# phi= 340.2909   sv2= 0.01015781   df= 6.092184   lambda= 33500.41
# Iterations: relative error in phi-hat = 1e-04
# phi= 197.2405   sv2= 0.2075813   df= 14.74783   lambda= 950.1842
# phi= 224.879   sv2= 0.007089321   df= 5.49994   lambda= 31720.82
# Iterations: relative error in phi-hat = 1e-04
# phi= 32.55773   sv2= 0.214551   df= 13.7912   lambda= 151.7482
# phi= 35.81804   sv2= 0.03431789   df= 7.567407   lambda= 1043.713
# phi= 38.63047   sv2= 0.005380566   df= 5.050545   lambda= 7179.629
# phi= 40.01347   sv2= 0.0004693131   df= 3.469088   lambda= 85259.64
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/CR-TA_fruB-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 113.8859   sv2= 0.1815249   df= 15.68161   lambda= 627.3844
# phi= 126.7022   sv2= 0.0112133   df= 6.339025   lambda= 11299.28
# Iterations: relative error in phi-hat = 1e-04
# phi= 289.3813   sv2= 0.3811417   df= 15.6182   lambda= 759.2485
# phi= 340.2909   sv2= 0.01015781   df= 6.092184   lambda= 33500.41
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  78.541919  73.699392  82.583457  0.000165, 1:                est       L95%       U95%       var
# lifespan  90.57545  90.571051  91.575694  0.000168}
