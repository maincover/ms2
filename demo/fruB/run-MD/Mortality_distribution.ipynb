# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/TA_fruB-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/TA_fruB-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB
# Iterations: relative error in phi-hat = 1e-04
# phi= 123.6886   sv2= 0.3776675   df= 18.63735   lambda= 327.5066
# phi= 134.681   sv2= 0.04147473   df= 8.700116   lambda= 3247.301
# phi= 144.5707   sv2= 0.005090303   df= 5.353351   lambda= 28401.21
# save file prefixed name is : TA_fruB-1_df_relative_timegrid-vs-TA_fruB-1_timeseries_dataframe
# biName is :  TA_fruB-1_df_relative_timegrid-vs-TA_fruB-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/fruB/run-MD
# No error in flxsrv_fit
# TA_fruB-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/fruB/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fruB/run-MD
# TA_fruB-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 123.6886   sv2= 0.3776675   df= 18.63735   lambda= 327.5066
# phi= 134.681   sv2= 0.04147473   df= 8.700116   lambda= 3247.301
# phi= 144.5707   sv2= 0.005090303   df= 5.353351   lambda= 28401.21
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fruB/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fruB-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_fruB-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/MD-TA_fruB-1_df_relative_timegrid-vs-TA_fruB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_fruB-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=31644.971914)
#                   est          L95%          U95%            se
# rate         0.047945  4.461367e-02  5.152597e-02  1.761850e-03
# beta    715569.484998  9.113748e-05  5.618322e+15  8.318274e+06
# s         7495.834927  9.453577e-07  5.943522e+13  8.717436e+04
# lambda       0.001786  1.301728e-03  2.451778e-03  2.885423e-04
#                 est       L95%       U95%       var
# lifespan  85.578954  83.604942  86.582827  0.000071
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruB/MD-TA_fruB-1_df_relative_timegrid-vs-TA_fruB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fruB-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/fruB/run-MD
