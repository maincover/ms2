# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/TA_yafV-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/TA_yafV-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/TA_yafV-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV']
#
# out_name_s  ['TA_yafV-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/TA_yafV-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/TA_yafV-1_analysis_metadata.pickle
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 71-1.tif.mortality.tab
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 79-1.tif.mortality.tab
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 83-1.tif.mortality.tab
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 85-1.tif.mortality.tab
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 86-1.tif.mortality.tab
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 91-1.tif.mortality.tab
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 94-1.tif.mortality.tab
# MAX_01112018 Position 69-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# MAX_01112018 Position 71-1.tif.mortality.tab ------ MAX_01112018 Position 79-1.tif.mortality.tab
# MAX_01112018 Position 71-1.tif.mortality.tab ------ MAX_01112018 Position 83-1.tif.mortality.tab
# MAX_01112018 Position 71-1.tif.mortality.tab ------ MAX_01112018 Position 85-1.tif.mortality.tab
# MAX_01112018 Position 71-1.tif.mortality.tab ------ MAX_01112018 Position 86-1.tif.mortality.tab
# MAX_01112018 Position 71-1.tif.mortality.tab ------ MAX_01112018 Position 91-1.tif.mortality.tab
# MAX_01112018 Position 71-1.tif.mortality.tab ------ MAX_01112018 Position 94-1.tif.mortality.tab
# MAX_01112018 Position 71-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# MAX_01112018 Position 79-1.tif.mortality.tab ------ MAX_01112018 Position 83-1.tif.mortality.tab
# MAX_01112018 Position 79-1.tif.mortality.tab ------ MAX_01112018 Position 85-1.tif.mortality.tab
# MAX_01112018 Position 79-1.tif.mortality.tab ------ MAX_01112018 Position 86-1.tif.mortality.tab
# MAX_01112018 Position 79-1.tif.mortality.tab ------ MAX_01112018 Position 91-1.tif.mortality.tab
# MAX_01112018 Position 79-1.tif.mortality.tab ------ MAX_01112018 Position 94-1.tif.mortality.tab
# MAX_01112018 Position 79-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# MAX_01112018 Position 83-1.tif.mortality.tab ------ MAX_01112018 Position 85-1.tif.mortality.tab
# MAX_01112018 Position 83-1.tif.mortality.tab ------ MAX_01112018 Position 86-1.tif.mortality.tab
# MAX_01112018 Position 83-1.tif.mortality.tab ------ MAX_01112018 Position 91-1.tif.mortality.tab
# MAX_01112018 Position 83-1.tif.mortality.tab ------ MAX_01112018 Position 94-1.tif.mortality.tab
# MAX_01112018 Position 83-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# MAX_01112018 Position 85-1.tif.mortality.tab ------ MAX_01112018 Position 86-1.tif.mortality.tab
# MAX_01112018 Position 85-1.tif.mortality.tab ------ MAX_01112018 Position 91-1.tif.mortality.tab
# MAX_01112018 Position 85-1.tif.mortality.tab ------ MAX_01112018 Position 94-1.tif.mortality.tab
# MAX_01112018 Position 85-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# MAX_01112018 Position 86-1.tif.mortality.tab ------ MAX_01112018 Position 91-1.tif.mortality.tab
# MAX_01112018 Position 86-1.tif.mortality.tab ------ MAX_01112018 Position 94-1.tif.mortality.tab
# MAX_01112018 Position 86-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# MAX_01112018 Position 91-1.tif.mortality.tab ------ MAX_01112018 Position 94-1.tif.mortality.tab
# MAX_01112018 Position 91-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# MAX_01112018 Position 94-1.tif.mortality.tab ------ MAX_01112018 Position 95-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_dentrogram-all-files.eps
# [['MAX_01112018 Position 85-1.tif.mortality.tab', 'MAX_01112018 Position 86-1.tif.mortality.tab', 'MAX_01112018 Position 91-1.tif.mortality.tab', 'MAX_01112018 Position 94-1.tif.mortality.tab'], ['MAX_01112018 Position 69-1.tif.mortality.tab', 'MAX_01112018 Position 71-1.tif.mortality.tab', 'MAX_01112018 Position 79-1.tif.mortality.tab', 'MAX_01112018 Position 83-1.tif.mortality.tab', 'MAX_01112018 Position 95-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 31.98242   sv2= 0.09945567   df= 10.83643   lambda= 321.5747
# phi= 31.37805   sv2= 0.01120284   df= 5.155577   lambda= 2800.901
# phi= 32.2841   sv2= 0.001363395   df= 3.413051   lambda= 23679.19
# Iterations: relative error in phi-hat = 1e-04
# phi= 80.66249   sv2= 0.1611988   df= 11.04304   lambda= 500.3914
# phi= 102.3183   sv2= 0.004460071   df= 4.82798   lambda= 22940.95
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.45108   sv2= 0.1508721   df= 11.92548   lambda= 394.0497
# phi= 67.58387   sv2= 0.01240325   df= 5.394415   lambda= 5448.882
# phi= 72.09377   sv2= 0.0008032783   df= 3.257403   lambda= 89749.43
# Iterations: relative error in phi-hat = 1e-04
# phi= 15.51654   sv2= 0.04935496   df= 8.922652   lambda= 314.3866
# phi= 17.0081   sv2= 0.004372954   df= 4.402359   lambda= 3889.384
# phi= 17.68665   sv2= 0.0005831624   df= 2.832656   lambda= 30328.86
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  113.479029  110.906208  115.917441  0.000317, 1:                  est        L95%        U95%       var
# lifespan  122.116656  118.343344  128.372968  0.001262}
