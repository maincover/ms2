# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/TA_yafV-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/TA_yafV-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.70629   sv2= 0.1529577   df= 12.45437   lambda= 311.8919
# phi= 50.41454   sv2= 0.01590539   df= 5.889654   lambda= 3169.651
# phi= 53.4558   sv2= 0.001921432   df= 3.72919   lambda= 27820.82
# save file prefixed name is : TA_yafV-1_df_relative_timegrid-vs-TA_yafV-1_timeseries_dataframe
# biName is :  TA_yafV-1_df_relative_timegrid-vs-TA_yafV-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yafV/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yafV-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yafV/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yafV/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yafV-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.70629   sv2= 0.1529577   df= 12.45437   lambda= 311.8919
# phi= 50.41454   sv2= 0.01590539   df= 5.889654   lambda= 3169.651
# phi= 53.4558   sv2= 0.001921432   df= 3.72919   lambda= 27820.82
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yafV/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yafV-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yafV-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/MD-TA_yafV-1_df_relative_timegrid-vs-TA_yafV-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yafV-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7949.152641)
#                  est          L95%         U95%         se
# rate    4.671941e-02  4.120575e-02     0.052971   0.002993
# beta    3.999627e+02  2.602611e+02   614.652717  87.684476
# s       1.744814e+00  9.137386e-01     3.331781   0.575852
# lambda  4.804727e-07  7.061014e-17  3269.417090   0.000006
#                  est        L95%        U95%       var
# lifespan  114.727744  112.228249  118.445237  0.000253
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/MD-TA_yafV-1_df_relative_timegrid-vs-TA_yafV-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yafV-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yafV/run-MD
