# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/TA_dnaT-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/TA_dnaT-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/TA_dnaT-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT']
#
# out_name_s  ['TA_dnaT-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/TA_dnaT-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/TA_dnaT-1_analysis_metadata.pickle
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 119-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 81-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 83-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 86-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 87-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 88-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 90-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 118-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 81-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 83-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 86-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 87-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 88-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 90-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 119-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 81-1.tif.mortality.tab ------ MAX_02082015 Position 83-1.tif.mortality.tab
# MAX_02082015 Position 81-1.tif.mortality.tab ------ MAX_02082015 Position 86-1.tif.mortality.tab
# MAX_02082015 Position 81-1.tif.mortality.tab ------ MAX_02082015 Position 87-1.tif.mortality.tab
# MAX_02082015 Position 81-1.tif.mortality.tab ------ MAX_02082015 Position 88-1.tif.mortality.tab
# MAX_02082015 Position 81-1.tif.mortality.tab ------ MAX_02082015 Position 90-1.tif.mortality.tab
# MAX_02082015 Position 81-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 81-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 83-1.tif.mortality.tab ------ MAX_02082015 Position 86-1.tif.mortality.tab
# MAX_02082015 Position 83-1.tif.mortality.tab ------ MAX_02082015 Position 87-1.tif.mortality.tab
# MAX_02082015 Position 83-1.tif.mortality.tab ------ MAX_02082015 Position 88-1.tif.mortality.tab
# MAX_02082015 Position 83-1.tif.mortality.tab ------ MAX_02082015 Position 90-1.tif.mortality.tab
# MAX_02082015 Position 83-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 83-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 86-1.tif.mortality.tab ------ MAX_02082015 Position 87-1.tif.mortality.tab
# MAX_02082015 Position 86-1.tif.mortality.tab ------ MAX_02082015 Position 88-1.tif.mortality.tab
# MAX_02082015 Position 86-1.tif.mortality.tab ------ MAX_02082015 Position 90-1.tif.mortality.tab
# MAX_02082015 Position 86-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 86-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 87-1.tif.mortality.tab ------ MAX_02082015 Position 88-1.tif.mortality.tab
# MAX_02082015 Position 87-1.tif.mortality.tab ------ MAX_02082015 Position 90-1.tif.mortality.tab
# MAX_02082015 Position 87-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 87-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 88-1.tif.mortality.tab ------ MAX_02082015 Position 90-1.tif.mortality.tab
# MAX_02082015 Position 88-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 88-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 90-1.tif.mortality.tab ------ MAX_02082015 Position 91-1.tif.mortality.tab
# MAX_02082015 Position 90-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# MAX_02082015 Position 91-1.tif.mortality.tab ------ MAX_02082015 Position 92-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_dentrogram-all-files.eps
# [['MAX_02082015 Position 118-1.tif.mortality.tab', 'MAX_02082015 Position 119-1.tif.mortality.tab', 'MAX_02082015 Position 88-1.tif.mortality.tab', 'MAX_02082015 Position 92-1.tif.mortality.tab'], ['MAX_02082015 Position 81-1.tif.mortality.tab', 'MAX_02082015 Position 86-1.tif.mortality.tab', 'MAX_02082015 Position 87-1.tif.mortality.tab', 'MAX_02082015 Position 91-1.tif.mortality.tab'], ['MAX_02082015 Position 90-1.tif.mortality.tab'], ['MAX_02082015 Position 83-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.90477   sv2= 0.1549436   df= 11.60507   lambda= 160.7345
# phi= 28.4946   sv2= 0.02412158   df= 6.445696   lambda= 1181.29
# phi= 30.86651   sv2= 0.007787997   df= 4.384773   lambda= 3963.345
# phi= 32.77523   sv2= 0.003115648   df= 3.53069   lambda= 10519.56
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.76532   sv2= 0.09456677   df= 8.85514   lambda= 536.8198
# phi= 61.45068   sv2= 0.007186748   df= 4.032939   lambda= 8550.554
# phi= 65.72094   sv2= 0.001294879   df= 2.562752   lambda= 50754.5
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/CR-TA_dnaT-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.90477   sv2= 0.1549436   df= 11.60507   lambda= 160.7345
# phi= 28.4946   sv2= 0.02412158   df= 6.445696   lambda= 1181.29
# phi= 30.86651   sv2= 0.007787997   df= 4.384773   lambda= 3963.345
# phi= 32.77523   sv2= 0.003115648   df= 3.53069   lambda= 10519.56
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.76532   sv2= 0.09456677   df= 8.85514   lambda= 536.8198
# phi= 61.45068   sv2= 0.007186748   df= 4.032939   lambda= 8550.554
# phi= 65.72094   sv2= 0.001294879   df= 2.562752   lambda= 50754.5
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%      U95%       var
# lifespan  81.808578  78.297636  84.03346  0.000485, 1:                  est        L95%        U95%     var
# lifespan  110.488991  101.514938  115.107755  0.0011}
