# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/TA_dnaT-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/TA_dnaT-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.01519   sv2= 0.2191338   df= 13.33556   lambda= 155.2257
# phi= 38.10958   sv2= 0.03871195   df= 7.405185   lambda= 984.4396
# phi= 41.01586   sv2= 0.01441068   df= 5.123942   lambda= 2846.213
# phi= 43.15085   sv2= 0.007588083   df= 4.207929   lambda= 5686.66
# phi= 44.85917   sv2= 0.004516012   df= 3.718875   lambda= 9933.359
# phi= 46.32624   sv2= 0.002739813   df= 3.374765   lambda= 16908.54
# save file prefixed name is : TA_dnaT-1_df_relative_timegrid-vs-TA_dnaT-1_timeseries_dataframe
# biName is :  TA_dnaT-1_df_relative_timegrid-vs-TA_dnaT-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/dnaT/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_dnaT-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/dnaT/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/dnaT/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_dnaT-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.01519   sv2= 0.2191338   df= 13.33556   lambda= 155.2257
# phi= 38.10958   sv2= 0.03871195   df= 7.405185   lambda= 984.4396
# phi= 41.01586   sv2= 0.01441068   df= 5.123942   lambda= 2846.213
# phi= 43.15085   sv2= 0.007588083   df= 4.207929   lambda= 5686.66
# phi= 44.85917   sv2= 0.004516012   df= 3.718875   lambda= 9933.359
# phi= 46.32624   sv2= 0.002739813   df= 3.374765   lambda= 16908.54
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/dnaT/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_dnaT-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_dnaT-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/MD-TA_dnaT-1_df_relative_timegrid-vs-TA_dnaT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_dnaT-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=8477.875405)
#                  est          L95%          U95%            se
# rate    3.438113e-01  2.229419e-01  5.302108e-01  7.598749e-02
# beta    1.536311e+11  2.846666e+06  8.291287e+15  8.540920e+11
# s       4.609680e-02  2.791750e-02  7.611408e-02  1.179464e-02
# lambda  6.628694e-03  5.973569e-03  7.355667e-03  3.519470e-04
#                 est       L95%       U95%       var
# lifespan  82.888378  81.787758  86.338201  0.000248
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dnaT/MD-TA_dnaT-1_df_relative_timegrid-vs-TA_dnaT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_dnaT-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/dnaT/run-MD
