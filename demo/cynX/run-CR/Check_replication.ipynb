# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/TA_cynX-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/TA_cynX-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/TA_cynX-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX']
#
# out_name_s  ['TA_cynX-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/TA_cynX-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/TA_cynX-1_analysis_metadata.pickle
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 132-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 23-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 28-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 29-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 32-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 34-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 35-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 131-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 23-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 28-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 29-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 32-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 34-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 35-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 132-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 28-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 29-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 32-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 34-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 35-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 23-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 29-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 32-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 34-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 35-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 28-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 32-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 34-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 35-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 29-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 34-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 35-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 32-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 35-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 34-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 36-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 35-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 36-1.tif.mortality.tab ------ MAX_30112014 Position 37-1.tif.mortality.tab
# MAX_30112014 Position 36-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 36-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 36-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 36-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 36-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 36-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 37-1.tif.mortality.tab ------ MAX_30112014 Position 38-1.tif.mortality.tab
# MAX_30112014 Position 37-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 37-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 37-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 37-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 37-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 38-1.tif.mortality.tab ------ MAX_30112014 Position 40-1.tif.mortality.tab
# MAX_30112014 Position 38-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 38-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 38-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 38-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 40-1.tif.mortality.tab ------ MAX_30112014 Position 42-1.tif.mortality.tab
# MAX_30112014 Position 40-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 40-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 40-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 42-1.tif.mortality.tab ------ MAX_30112014 Position 44-1.tif.mortality.tab
# MAX_30112014 Position 42-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 42-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 44-1.tif.mortality.tab ------ MAX_30112014 Position 52-1.tif.mortality.tab
# MAX_30112014 Position 44-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# MAX_30112014 Position 52-1.tif.mortality.tab ------ MAX_30112014 Position 68-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_dentrogram-all-files.eps
# 9 [3 1 2 4 5 7 8 6 6]
# [['MAX_30112014 Position 28-1.tif.mortality.tab', 'MAX_30112014 Position 35-1.tif.mortality.tab'], ['MAX_30112014 Position 29-1.tif.mortality.tab'], ['MAX_30112014 Position 131-1.tif.mortality.tab', 'MAX_30112014 Position 132-1.tif.mortality.tab'], ['MAX_30112014 Position 34-1.tif.mortality.tab', 'MAX_30112014 Position 52-1.tif.mortality.tab'], ['MAX_30112014 Position 40-1.tif.mortality.tab'], ['MAX_30112014 Position 36-1.tif.mortality.tab', 'MAX_30112014 Position 38-1.tif.mortality.tab', 'MAX_30112014 Position 44-1.tif.mortality.tab', 'MAX_30112014 Position 68-1.tif.mortality.tab'], ['MAX_30112014 Position 23-1.tif.mortality.tab', 'MAX_30112014 Position 37-1.tif.mortality.tab'], ['MAX_30112014 Position 32-1.tif.mortality.tab', 'MAX_30112014 Position 42-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_orig_timegrid_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_colomap_all_files_cluster4.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_orig_dataframe_cluster4.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_orig_timegrid_cluster4.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_colomap_all_files_cluster5.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_orig_dataframe_cluster5.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_orig_timegrid_cluster5.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 95.61601   sv2= 0.3675124   df= 17.41127   lambda= 260.1708
# phi= 99.7361   sv2= 0.01619822   df= 8.492288   lambda= 6157.227
# phi= 102.5032   sv2= 0.001554912   df= 4.329636   lambda= 65922.19
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.00096   sv2= 0.1473895   df= 15.68651   lambda= 196.7641
# phi= 30.07799   sv2= 0.01012982   df= 8.095251   lambda= 2969.252
# phi= 31.38431   sv2= 0.002143523   df= 4.546078   lambda= 14641.46
# Iterations: relative error in phi-hat = 1e-04
# phi= 90.35193   sv2= 0.1603593   df= 15.81168   lambda= 563.4342
# phi= 95.27419   sv2= 0.006133202   df= 6.437531   lambda= 15534.17
# Iterations: relative error in phi-hat = 1e-04
# phi= 35.58546   sv2= 0.09561803   df= 15.15546   lambda= 372.1626
# phi= 36.44289   sv2= 0.007587125   df= 6.749875   lambda= 4803.254
# phi= 37.72039   sv2= 0.001592693   df= 4.009375   lambda= 23683.4
# Iterations: relative error in phi-hat = 1e-04
# phi= 178.1908   sv2= 0.1091672   df= 12.33899   lambda= 1632.274
# phi= 194.1103   sv2= 0.007323229   df= 4.219247   lambda= 26506.11
# Iterations: relative error in phi-hat = 1e-04
# phi= 4.571222   sv2= 0.08674105   df= 11.02297   lambda= 52.69964
# phi= 4.776963   sv2= 0.02241076   df= 7.574882   lambda= 213.1549
# phi= 4.870191   sv2= 0.01367905   df= 5.501727   lambda= 356.0328
# phi= 4.887255   sv2= 0.01312392   df= 4.944652   lambda= 372.3929
# phi= 4.88874   sv2= 0.01308926   df= 4.899975   lambda= 373.4925
# phi= 4.888838   sv2= 0.01308702   df= 4.897064   lambda= 373.564
# phi= 4.888844   sv2= 0.01308687   df= 4.896875   lambda= 373.5686
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_dataframe_cluster0.pickle
# 7 --c-- 5
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_dataframe_cluster1.pickle
# 7 --c-- 6
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_dataframe_cluster2.pickle
# 7 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_cluster2_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_dataframe_cluster3.pickle
# 7 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_timegrid_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_timeseries_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_cluster3_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_mortality_dataframe_cluster4.pickle
# 7 --c-- 3
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_relative_timegrid_cluster4.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_timeseries_dataframe_cluster4.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cynX/CR-TA_cynX-1_cluster4_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.35611   sv2= 0.2176202   df= 17.78961   lambda= 235.9896
# phi= 53.53323   sv2= 0.01123278   df= 8.856303   lambda= 4765.807
# phi= 55.00037   sv2= 0.00258534   df= 4.6611   lambda= 21273.95
# Iterations: relative error in phi-hat = 1e-04
# phi= 111.6804   sv2= 0.3605787   df= 17.27777   lambda= 309.7255
# phi= 116.5848   sv2= 0.01525752   df= 8.090646   lambda= 7641.139
# phi= 120.1584   sv2= 0.001486239   df= 4.119469   lambda= 80847.31
# Iterations: relative error in phi-hat = 1e-04
# phi= 90.35193   sv2= 0.1603593   df= 15.81168   lambda= 563.4342
# phi= 95.27419   sv2= 0.006133202   df= 6.437531   lambda= 15534.17
# Iterations: relative error in phi-hat = 1e-04
# phi= 178.1908   sv2= 0.1091672   df= 12.33899   lambda= 1632.274
# phi= 194.1103   sv2= 0.007323229   df= 4.219247   lambda= 26506.11
# Iterations: relative error in phi-hat = 1e-04
# phi= 4.903955   sv2= 0.09596699   df= 12.04574   lambda= 51.10043
# phi= 5.16491   sv2= 0.02507011   df= 8.486664   lambda= 206.0187
# phi= 5.34009   sv2= 0.0100931   df= 6.268552   lambda= 529.0831
# phi= 5.412545   sv2= 0.007721426   df= 5.111095   lambda= 700.9774
# phi= 5.428332   sv2= 0.007479405   df= 4.817533   lambda= 725.7706
# phi= 5.430145   sv2= 0.007457304   df= 4.782876   lambda= 728.1646
# phi= 5.430315   sv2= 0.007455283   df= 4.779611   lambda= 728.3848
# phi= 5.430331   sv2= 0.007455098   df= 4.779311   lambda= 728.405
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  82.038516  80.734764  84.360101  0.000082, 1:                 est       L95%       U95%       var
# lifespan  86.883782  85.674662  88.090587  0.000088, 2:                 est      L95%       U95%       var
# lifespan  69.897052  66.32055  72.363124  0.000153, 3:                 est       L95%       U95%       var
# lifespan  71.829474  69.402821  74.238401  0.000351, 4:                 est       L95%       U95%       var
# lifespan  85.884386  83.463105  87.091931  0.000383}
