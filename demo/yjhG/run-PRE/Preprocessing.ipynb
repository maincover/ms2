# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  817  Filtered files length (after MD5 check) :  30
# check line duplication(open file) :  50 / 817
# check line duplication(open file) :  100 / 817
# check line duplication(open file) :  150 / 817
# check line duplication(open file) :  200 / 817
# check line duplication(open file) :  250 / 817
# check line duplication(open file) :  300 / 817
# check line duplication(open file) :  350 / 817
# check line duplication(open file) :  400 / 817
# check line duplication(open file) :  450 / 817
# check line duplication(open file) :  500 / 817
# check line duplication(open file) :  550 / 817
# check line duplication(open file) :  600 / 817
# check line duplication(open file) :  650 / 817
# check line duplication(open file) :  700 / 817
# check line duplication(open file) :  750 / 817
# check line duplication(open file) :  800 / 817
# check line duplication:  0 / 817
# check line duplication:  50 / 817
# check line duplication:  100 / 817
# check line duplication:  150 / 817
# check line duplication:  200 / 817
# check line duplication:  250 / 817
# check line duplication:  300 / 817
# check line duplication:  350 / 817
# check line duplication:  400 / 817
# check line duplication:  450 / 817
# check line duplication:  500 / 817
# check line duplication:  550 / 817
# check line duplication:  600 / 817
# check line duplication:  650 / 817
# check line duplication:  700 / 817
# check line duplication:  750 / 817
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 109-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 21-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 23-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 47-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 51-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 53-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 54-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 55-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 62-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 65-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 66-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 69-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 70-1.tif.mortality.tab
# check line duplication:  800 / 817
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 72-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 76-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 79-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 80-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 81-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 82-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 83-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 84-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 85-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 86-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 87-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 88-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 89-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 90-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 91-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 92-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MAX_21062015 Position 93-1.tif.mortality.tab
