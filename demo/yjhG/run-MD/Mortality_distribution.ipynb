# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/TA_yjhG-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/TA_yjhG-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG
# Iterations: relative error in phi-hat = 1e-04
# phi= 11.47184   sv2= 0.1428803   df= 17.23521   lambda= 80.28987
# phi= 11.86041   sv2= 0.0261112   df= 10.86752   lambda= 454.2268
# phi= 12.17416   sv2= 0.003662996   df= 7.378662   lambda= 3323.553
# phi= 12.34263   sv2= 0.0003793187   df= 4.836477   lambda= 32538.94
# save file prefixed name is : TA_yjhG-1_df_relative_timegrid-vs-TA_yjhG-1_timeseries_dataframe
# biName is :  TA_yjhG-1_df_relative_timegrid-vs-TA_yjhG-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yjhG/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yjhG-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yjhG/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjhG/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yjhG-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 11.47184   sv2= 0.1428803   df= 17.23521   lambda= 80.28987
# phi= 11.86041   sv2= 0.0261112   df= 10.86752   lambda= 454.2268
# phi= 12.17416   sv2= 0.003662996   df= 7.378662   lambda= 3323.553
# phi= 12.34263   sv2= 0.0003793187   df= 4.836477   lambda= 32538.94
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjhG/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjhG-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yjhG-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MD-TA_yjhG-1_df_relative_timegrid-vs-TA_yjhG-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yjhG-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=24198.591562)
#                   est      L95%          U95%            se
# rate         0.050167  0.046973  5.357676e-02  1.683354e-03
# beta    216834.668918  0.000360  1.306895e+14  2.236642e+06
# s         1236.889261  0.000002  7.736515e+11  1.278187e+04
# lambda       0.000944  0.000655  1.360647e-03  1.759693e-04
#                 est       L95%       U95%       var
# lifespan  92.715352  92.561591  93.659257  0.000084
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjhG/MD-TA_yjhG-1_df_relative_timegrid-vs-TA_yjhG-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjhG-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yjhG/run-MD
