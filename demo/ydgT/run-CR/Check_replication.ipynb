# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/TA_ydgT-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/TA_ydgT-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/TA_ydgT-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT']
#
# out_name_s  ['TA_ydgT-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/TA_ydgT-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/TA_ydgT-1_analysis_metadata.pickle
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 105-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 31-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 38-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 77-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 82-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 85-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 93-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 100-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 31-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 38-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 77-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 82-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 85-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 93-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 105-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 31-1.tif.mortality.tab ------ MAX_07042016 Position 38-1.tif.mortality.tab
# MAX_07042016 Position 31-1.tif.mortality.tab ------ MAX_07042016 Position 77-1.tif.mortality.tab
# MAX_07042016 Position 31-1.tif.mortality.tab ------ MAX_07042016 Position 82-1.tif.mortality.tab
# MAX_07042016 Position 31-1.tif.mortality.tab ------ MAX_07042016 Position 85-1.tif.mortality.tab
# MAX_07042016 Position 31-1.tif.mortality.tab ------ MAX_07042016 Position 93-1.tif.mortality.tab
# MAX_07042016 Position 31-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 31-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 38-1.tif.mortality.tab ------ MAX_07042016 Position 77-1.tif.mortality.tab
# MAX_07042016 Position 38-1.tif.mortality.tab ------ MAX_07042016 Position 82-1.tif.mortality.tab
# MAX_07042016 Position 38-1.tif.mortality.tab ------ MAX_07042016 Position 85-1.tif.mortality.tab
# MAX_07042016 Position 38-1.tif.mortality.tab ------ MAX_07042016 Position 93-1.tif.mortality.tab
# MAX_07042016 Position 38-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 38-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 77-1.tif.mortality.tab ------ MAX_07042016 Position 82-1.tif.mortality.tab
# MAX_07042016 Position 77-1.tif.mortality.tab ------ MAX_07042016 Position 85-1.tif.mortality.tab
# MAX_07042016 Position 77-1.tif.mortality.tab ------ MAX_07042016 Position 93-1.tif.mortality.tab
# MAX_07042016 Position 77-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 77-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 82-1.tif.mortality.tab ------ MAX_07042016 Position 85-1.tif.mortality.tab
# MAX_07042016 Position 82-1.tif.mortality.tab ------ MAX_07042016 Position 93-1.tif.mortality.tab
# MAX_07042016 Position 82-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 82-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 85-1.tif.mortality.tab ------ MAX_07042016 Position 93-1.tif.mortality.tab
# MAX_07042016 Position 85-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 85-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 93-1.tif.mortality.tab ------ MAX_07042016 Position 94-1.tif.mortality.tab
# MAX_07042016 Position 93-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# MAX_07042016 Position 94-1.tif.mortality.tab ------ MAX_07042016 Position 98-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_dentrogram-all-files.eps
# [['MAX_07042016 Position 85-1.tif.mortality.tab'], ['MAX_07042016 Position 94-1.tif.mortality.tab'], ['MAX_07042016 Position 77-1.tif.mortality.tab', 'MAX_07042016 Position 98-1.tif.mortality.tab'], ['MAX_07042016 Position 38-1.tif.mortality.tab'], ['MAX_07042016 Position 105-1.tif.mortality.tab', 'MAX_07042016 Position 31-1.tif.mortality.tab'], ['MAX_07042016 Position 82-1.tif.mortality.tab', 'MAX_07042016 Position 93-1.tif.mortality.tab'], ['MAX_07042016 Position 100-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.60027   sv2= 0.4282734   df= 11.72435   lambda= 141.499
# phi= 60.49624   sv2= 0.04024243   df= 6.64413   lambda= 1503.295
# phi= 62.04967   sv2= 0.01636094   df= 4.023601   lambda= 3792.549
# phi= 65.10125   sv2= 0.00956044   df= 3.275401   lambda= 6809.441
# phi= 68.00055   sv2= 0.006168515   df= 2.913112   lambda= 11023.81
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.020544   sv2= 0.2473855   df= 11.94316   lambda= 28.37896
# phi= 7.348128   sv2= 0.09828231   df= 9.543982   lambda= 74.76552
# phi= 7.489847   sv2= 0.04775171   df= 7.767493   lambda= 156.8498
# phi= 7.521809   sv2= 0.03546583   df= 6.661163   lambda= 212.0861
# phi= 7.525234   sv2= 0.03343203   df= 6.265052   lambda= 225.0906
# phi= 7.525799   sv2= 0.03314008   df= 6.190384   lambda= 227.0905
# phi= 7.525887   sv2= 0.03309904   df= 6.179381   lambda= 227.3748
# phi= 7.5259   sv2= 0.03309328   df= 6.177826   lambda= 227.4147
# phi= 7.525901   sv2= 0.03309247   df= 6.177608   lambda= 227.4203
# Iterations: relative error in phi-hat = 1e-04
# phi= 19.47292   sv2= 0.3637406   df= 12.02474   lambda= 53.53519
# phi= 21.54146   sv2= 0.05806671   df= 8.394488   lambda= 370.9777
# phi= 22.696   sv2= 0.01961092   df= 5.639188   lambda= 1157.315
# phi= 23.57944   sv2= 0.01579203   df= 4.55256   lambda= 1493.122
# phi= 23.88857   sv2= 0.01470465   df= 4.350984   lambda= 1624.558
# phi= 24.0027   sv2= 0.01431608   df= 4.287051   lambda= 1676.626
# phi= 24.04693   sv2= 0.01416746   df= 4.263486   lambda= 1697.335
# phi= 24.06438   sv2= 0.01410917   df= 4.254364   lambda= 1705.584
# phi= 24.0713   sv2= 0.01408608   df= 4.25077   lambda= 1708.872
# phi= 24.07406   sv2= 0.0140769   df= 4.249343   lambda= 1710.182
# phi= 24.07515   sv2= 0.01407324   df= 4.248775   lambda= 1710.705
# phi= 24.07559   sv2= 0.01407178   df= 4.248549   lambda= 1710.913
# phi= 24.07577   sv2= 0.0140712   df= 4.248459   lambda= 1710.996
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in solve.default(opt$hessian) :
#   system is computationally singular: reciprocal condition number = 2.00396e-19
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 50 or more warnings (use warnings() to see the first 50)
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# Error in writeGGMtoFile
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_mortality_dataframe_cluster0.pickle
# 7 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_mortality_dataframe_cluster1.pickle
# 7 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_mortality_dataframe_cluster2.pickle
# 7 --c-- 3
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/CR-TA_ydgT-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.60027   sv2= 0.4282734   df= 11.72435   lambda= 141.499
# phi= 60.49624   sv2= 0.04024243   df= 6.64413   lambda= 1503.295
# phi= 62.04967   sv2= 0.01636094   df= 4.023601   lambda= 3792.549
# phi= 65.10125   sv2= 0.00956044   df= 3.275401   lambda= 6809.441
# phi= 68.00055   sv2= 0.006168515   df= 2.913112   lambda= 11023.81
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.020544   sv2= 0.2473855   df= 11.94316   lambda= 28.37896
# phi= 7.348128   sv2= 0.09828231   df= 9.543982   lambda= 74.76552
# phi= 7.489847   sv2= 0.04775171   df= 7.767493   lambda= 156.8498
# phi= 7.521809   sv2= 0.03546583   df= 6.661163   lambda= 212.0861
# phi= 7.525234   sv2= 0.03343203   df= 6.265052   lambda= 225.0906
# phi= 7.525799   sv2= 0.03314008   df= 6.190384   lambda= 227.0905
# phi= 7.525887   sv2= 0.03309904   df= 6.179381   lambda= 227.3748
# phi= 7.5259   sv2= 0.03309328   df= 6.177826   lambda= 227.4147
# phi= 7.525901   sv2= 0.03309247   df= 6.177608   lambda= 227.4203
# Iterations: relative error in phi-hat = 1e-04
# phi= 19.47292   sv2= 0.3637406   df= 12.02474   lambda= 53.53519
# phi= 21.54146   sv2= 0.05806671   df= 8.394488   lambda= 370.9777
# phi= 22.696   sv2= 0.01961092   df= 5.639188   lambda= 1157.315
# phi= 23.57944   sv2= 0.01579203   df= 4.55256   lambda= 1493.122
# phi= 23.88857   sv2= 0.01470465   df= 4.350984   lambda= 1624.558
# phi= 24.0027   sv2= 0.01431608   df= 4.287051   lambda= 1676.626
# phi= 24.04693   sv2= 0.01416746   df= 4.263486   lambda= 1697.335
# phi= 24.06438   sv2= 0.01410917   df= 4.254364   lambda= 1705.584
# phi= 24.0713   sv2= 0.01408608   df= 4.25077   lambda= 1708.872
# phi= 24.07406   sv2= 0.0140769   df= 4.249343   lambda= 1710.182
# phi= 24.07515   sv2= 0.01407324   df= 4.248775   lambda= 1710.705
# phi= 24.07559   sv2= 0.01407178   df= 4.248549   lambda= 1710.913
# phi= 24.07577   sv2= 0.0140712   df= 4.248459   lambda= 1710.996
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est      L95%        U95%       var
# lifespan  99.542534  98.47233  101.475312  0.000217, 1:                 est      L95%       U95%       var
# lifespan  97.621576  95.62325  97.621576  0.000268, 2:                 est       L95%        U95%       var
# lifespan  99.575473  99.575473  100.440769  0.000314}
