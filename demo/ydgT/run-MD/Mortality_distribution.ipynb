# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/TA_ydgT-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/TA_ydgT-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT
# Iterations: relative error in phi-hat = 1e-04
# phi= 73.54624   sv2= 0.2057211   df= 16.92456   lambda= 357.5046
# phi= 76.9013   sv2= 0.0153967   df= 7.901449   lambda= 4994.66
# phi= 77.29289   sv2= 0.01440003   df= 4.613131   lambda= 5367.551
# phi= 77.32587   sv2= 0.01417874   df= 4.550658   lambda= 5453.65
# phi= 77.33379   sv2= 0.01412723   df= 4.536992   lambda= 5474.095
# phi= 77.33569   sv2= 0.01411498   df= 4.533786   lambda= 5478.979
# phi= 77.33615   sv2= 0.01411206   df= 4.533022   lambda= 5480.147
# phi= 77.33626   sv2= 0.01411136   df= 4.53284   lambda= 5480.427
# save file prefixed name is : TA_ydgT-1_df_relative_timegrid-vs-TA_ydgT-1_timeseries_dataframe
# biName is :  TA_ydgT-1_df_relative_timegrid-vs-TA_ydgT-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ydgT/run-MD
# No error in flxsrv_fit
# TA_ydgT-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ydgT/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ydgT/run-MD
# TA_ydgT-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 73.54624   sv2= 0.2057211   df= 16.92456   lambda= 357.5046
# phi= 76.9013   sv2= 0.0153967   df= 7.901449   lambda= 4994.66
# phi= 77.29289   sv2= 0.01440003   df= 4.613131   lambda= 5367.551
# phi= 77.32587   sv2= 0.01417874   df= 4.550658   lambda= 5453.65
# phi= 77.33379   sv2= 0.01412723   df= 4.536992   lambda= 5474.095
# phi= 77.33569   sv2= 0.01411498   df= 4.533786   lambda= 5478.979
# phi= 77.33615   sv2= 0.01411206   df= 4.533022   lambda= 5480.147
# phi= 77.33626   sv2= 0.01411136   df= 4.53284   lambda= 5480.427
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ydgT/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydgT-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ydgT-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/MD-TA_ydgT-1_df_relative_timegrid-vs-TA_ydgT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ydgT-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=39154.640966)
#                  est  L95%  U95%  se
# rate    8.089723e-02   NaN   NaN NaN
# beta    7.102287e+10   NaN   NaN NaN
# s       1.195914e+07   NaN   NaN NaN
# lambda  5.188997e-04   NaN   NaN NaN
#                 est       L95%        U95%       var
# lifespan  100.49218  99.575473  100.550332  0.000052
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydgT/MD-TA_ydgT-1_df_relative_timegrid-vs-TA_ydgT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydgT-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ydgT/run-MD
