# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/TA_ybdK-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/TA_ybdK-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/TA_ybdK-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK']
#
# out_name_s  ['TA_ybdK-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/TA_ybdK-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/TA_ybdK-1_analysis_metadata.pickle
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 20-1.tif.mortality.tab
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 22-1.tif.mortality.tab
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 23-1.tif.mortality.tab
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 25-1.tif.mortality.tab
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 36-1.tif.mortality.tab
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 41-1.tif.mortality.tab
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 46-1.tif.mortality.tab
# MAX_01112018 Position 17-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# MAX_01112018 Position 20-1.tif.mortality.tab ------ MAX_01112018 Position 22-1.tif.mortality.tab
# MAX_01112018 Position 20-1.tif.mortality.tab ------ MAX_01112018 Position 23-1.tif.mortality.tab
# MAX_01112018 Position 20-1.tif.mortality.tab ------ MAX_01112018 Position 25-1.tif.mortality.tab
# MAX_01112018 Position 20-1.tif.mortality.tab ------ MAX_01112018 Position 36-1.tif.mortality.tab
# MAX_01112018 Position 20-1.tif.mortality.tab ------ MAX_01112018 Position 41-1.tif.mortality.tab
# MAX_01112018 Position 20-1.tif.mortality.tab ------ MAX_01112018 Position 46-1.tif.mortality.tab
# MAX_01112018 Position 20-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# MAX_01112018 Position 22-1.tif.mortality.tab ------ MAX_01112018 Position 23-1.tif.mortality.tab
# MAX_01112018 Position 22-1.tif.mortality.tab ------ MAX_01112018 Position 25-1.tif.mortality.tab
# MAX_01112018 Position 22-1.tif.mortality.tab ------ MAX_01112018 Position 36-1.tif.mortality.tab
# MAX_01112018 Position 22-1.tif.mortality.tab ------ MAX_01112018 Position 41-1.tif.mortality.tab
# MAX_01112018 Position 22-1.tif.mortality.tab ------ MAX_01112018 Position 46-1.tif.mortality.tab
# MAX_01112018 Position 22-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# MAX_01112018 Position 23-1.tif.mortality.tab ------ MAX_01112018 Position 25-1.tif.mortality.tab
# MAX_01112018 Position 23-1.tif.mortality.tab ------ MAX_01112018 Position 36-1.tif.mortality.tab
# MAX_01112018 Position 23-1.tif.mortality.tab ------ MAX_01112018 Position 41-1.tif.mortality.tab
# MAX_01112018 Position 23-1.tif.mortality.tab ------ MAX_01112018 Position 46-1.tif.mortality.tab
# MAX_01112018 Position 23-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# MAX_01112018 Position 25-1.tif.mortality.tab ------ MAX_01112018 Position 36-1.tif.mortality.tab
# MAX_01112018 Position 25-1.tif.mortality.tab ------ MAX_01112018 Position 41-1.tif.mortality.tab
# MAX_01112018 Position 25-1.tif.mortality.tab ------ MAX_01112018 Position 46-1.tif.mortality.tab
# MAX_01112018 Position 25-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# MAX_01112018 Position 36-1.tif.mortality.tab ------ MAX_01112018 Position 41-1.tif.mortality.tab
# MAX_01112018 Position 36-1.tif.mortality.tab ------ MAX_01112018 Position 46-1.tif.mortality.tab
# MAX_01112018 Position 36-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# MAX_01112018 Position 41-1.tif.mortality.tab ------ MAX_01112018 Position 46-1.tif.mortality.tab
# MAX_01112018 Position 41-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# MAX_01112018 Position 46-1.tif.mortality.tab ------ MAX_01112018 Position 6-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_dentrogram-all-files.eps
# [['MAX_01112018 Position 20-1.tif.mortality.tab', 'MAX_01112018 Position 22-1.tif.mortality.tab'], ['MAX_01112018 Position 17-1.tif.mortality.tab', 'MAX_01112018 Position 23-1.tif.mortality.tab', 'MAX_01112018 Position 25-1.tif.mortality.tab', 'MAX_01112018 Position 36-1.tif.mortality.tab', 'MAX_01112018 Position 41-1.tif.mortality.tab'], ['MAX_01112018 Position 46-1.tif.mortality.tab', 'MAX_01112018 Position 6-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.74648   sv2= 0.1240247   df= 12.7618   lambda= 304.3464
# phi= 41.11632   sv2= 0.007244776   df= 5.961289   lambda= 5675.306
# phi= 44.5358   sv2= 0.001687816   df= 3.327268   lambda= 26386.64
# Iterations: relative error in phi-hat = 1e-04
# phi= 140.3312   sv2= 0.09281592   df= 12.80788   lambda= 1511.931
# phi= 152.4917   sv2= 0.002542053   df= 4.288648   lambda= 59987.65
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.77864   sv2= 0.07447459   df= 10.4611   lambda= 144.7291
# phi= 12.27869   sv2= 0.004629643   df= 5.863397   lambda= 2652.19
# phi= 13.42385   sv2= 0.0002797913   df= 3.318676   lambda= 47978.06
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybdK/CR-TA_ybdK-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 26.95672   sv2= 0.1212961   df= 13.61945   lambda= 222.239
# phi= 28.60478   sv2= 0.009564974   df= 6.846095   lambda= 2990.575
# phi= 30.12423   sv2= 0.001651216   df= 3.986848   lambda= 18243.66
# Iterations: relative error in phi-hat = 1e-04
# phi= 140.3312   sv2= 0.09281592   df= 12.80788   lambda= 1511.931
# phi= 152.4917   sv2= 0.002542053   df= 4.288648   lambda= 59987.65
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%        U95%       var
# lifespan  99.818226  98.547334  102.304668  0.000202, 1:                 est       L95%       U95%       var
# lifespan  89.827307  84.897716  92.328885  0.000336}
