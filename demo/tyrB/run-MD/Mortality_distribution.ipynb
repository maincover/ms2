# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/TA_tyrB-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/TA_tyrB-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.96163   sv2= 0.07993717   df= 15.16389   lambda= 312.2656
# phi= 24.32507   sv2= 0.007638984   df= 7.056268   lambda= 3184.333
# phi= 23.86856   sv2= 0.003597148   df= 4.31283   lambda= 6635.411
# phi= 23.71354   sv2= 0.00274199   df= 3.726055   lambda= 8648.295
# phi= 23.67156   sv2= 0.002435049   df= 3.54119   lambda= 9721.187
# phi= 23.65561   sv2= 0.002303793   df= 3.463899   lambda= 10268.11
# save file prefixed name is : TA_tyrB-1_df_relative_timegrid-vs-TA_tyrB-1_timeseries_dataframe
# biName is :  TA_tyrB-1_df_relative_timegrid-vs-TA_tyrB-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/tyrB/run-MD
# No error in flxsrv_fit
# TA_tyrB-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/tyrB/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/tyrB/run-MD
# TA_tyrB-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.96163   sv2= 0.07993717   df= 15.16389   lambda= 312.2656
# phi= 24.32507   sv2= 0.007638984   df= 7.056268   lambda= 3184.333
# phi= 23.86856   sv2= 0.003597148   df= 4.31283   lambda= 6635.411
# phi= 23.71354   sv2= 0.00274199   df= 3.726055   lambda= 8648.295
# phi= 23.67156   sv2= 0.002435049   df= 3.54119   lambda= 9721.187
# phi= 23.65561   sv2= 0.002303793   df= 3.463899   lambda= 10268.11
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/tyrB/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_tyrB-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_tyrB-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/MD-TA_tyrB-1_df_relative_timegrid-vs-TA_tyrB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_tyrB-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=17079.591069)
#                   est  L95%  U95%  se
# rate         0.042131   NaN   NaN NaN
# beta    158654.593830   NaN   NaN NaN
# s         1227.675734   NaN   NaN NaN
# lambda       0.000010   NaN   NaN NaN
#                 est        L95%        U95%       var
# lifespan  103.06309  101.938756  104.186774  0.000123
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/MD-TA_tyrB-1_df_relative_timegrid-vs-TA_tyrB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_tyrB-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/tyrB/run-MD
