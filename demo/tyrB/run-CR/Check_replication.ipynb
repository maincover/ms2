# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/TA_tyrB-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/TA_tyrB-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/TA_tyrB-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB']
#
# out_name_s  ['TA_tyrB-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/TA_tyrB-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/TA_tyrB-1_analysis_metadata.pickle
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 32-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 36-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 37-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 38-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 39-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 40-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 41-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 31-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 36-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 37-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 38-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 39-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 40-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 41-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 32-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 37-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 38-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 39-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 40-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 41-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 36-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 38-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 39-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 40-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 41-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 37-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 39-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 40-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 41-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 38-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 40-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 41-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 39-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 41-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 40-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 42-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 41-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 46-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 42-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 48-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 46-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 48-1.tif.mortality.tab ------ MAX_07112014 Position 50-1.tif.mortality.tab
# MAX_07112014 Position 48-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 48-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 48-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 48-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 48-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 48-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 50-1.tif.mortality.tab ------ MAX_07112014 Position 51-1.tif.mortality.tab
# MAX_07112014 Position 50-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 50-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 50-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 50-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 50-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 51-1.tif.mortality.tab ------ MAX_07112014 Position 53-1.tif.mortality.tab
# MAX_07112014 Position 51-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 51-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 51-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 51-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 53-1.tif.mortality.tab ------ MAX_07112014 Position 54-1.tif.mortality.tab
# MAX_07112014 Position 53-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 53-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 53-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 54-1.tif.mortality.tab ------ MAX_07112014 Position 55-1.tif.mortality.tab
# MAX_07112014 Position 54-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 54-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 55-1.tif.mortality.tab ------ MAX_07112014 Position 56-1.tif.mortality.tab
# MAX_07112014 Position 55-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# MAX_07112014 Position 56-1.tif.mortality.tab ------ MAX_07112014 Position 57-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_dentrogram-all-files.eps
# 5 [1 2 3 3 4]
# [['MAX_07112014 Position 48-1.tif.mortality.tab', 'MAX_07112014 Position 53-1.tif.mortality.tab'], ['MAX_07112014 Position 42-1.tif.mortality.tab', 'MAX_07112014 Position 54-1.tif.mortality.tab', 'MAX_07112014 Position 55-1.tif.mortality.tab', 'MAX_07112014 Position 56-1.tif.mortality.tab', 'MAX_07112014 Position 57-1.tif.mortality.tab'], ['MAX_07112014 Position 32-1.tif.mortality.tab', 'MAX_07112014 Position 36-1.tif.mortality.tab', 'MAX_07112014 Position 37-1.tif.mortality.tab', 'MAX_07112014 Position 38-1.tif.mortality.tab', 'MAX_07112014 Position 39-1.tif.mortality.tab', 'MAX_07112014 Position 40-1.tif.mortality.tab', 'MAX_07112014 Position 41-1.tif.mortality.tab', 'MAX_07112014 Position 46-1.tif.mortality.tab', 'MAX_07112014 Position 50-1.tif.mortality.tab', 'MAX_07112014 Position 51-1.tif.mortality.tab'], ['MAX_07112014 Position 31-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 28.13512   sv2= 0.05873598   df= 12.74639   lambda= 479.0101
# phi= 28.53772   sv2= 0.007911847   df= 5.401382   lambda= 3606.96
# phi= 29.43553   sv2= 0.003770932   df= 3.571818   lambda= 7805.903
# phi= 29.97747   sv2= 0.002310316   df= 3.093187   lambda= 12975.49
# Iterations: relative error in phi-hat = 1e-04
# phi= 78.34218   sv2= 0.05045784   df= 12.24952   lambda= 1552.627
# phi= 76.32384   sv2= 0.001026791   df= 4.126658   lambda= 74332.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 12.38417   sv2= 0.08145534   df= 8.59713   lambda= 152.0363
# phi= 12.21446   sv2= 0.0165852   df= 4.8836   lambda= 736.4676
# phi= 12.33028   sv2= 0.006994531   df= 3.467302   lambda= 1762.845
# phi= 12.39042   sv2= 0.005127713   df= 2.992716   lambda= 2416.363
# phi= 12.43589   sv2= 0.004494527   df= 2.851065   lambda= 2766.896
# phi= 12.46143   sv2= 0.004220628   df= 2.794293   lambda= 2952.506
# phi= 12.47499   sv2= 0.004089337   df= 2.76791   lambda= 3050.615
# phi= 12.48214   sv2= 0.004023306   df= 2.754828   lambda= 3102.46
# phi= 12.48592   sv2= 0.003989294   df= 2.748136   lambda= 3129.856
# phi= 12.48791   sv2= 0.00397156   df= 2.744658   lambda= 3144.333
# phi= 12.48896   sv2= 0.003962254   df= 2.742837   lambda= 3151.983
# phi= 12.48951   sv2= 0.003957354   df= 2.741879   lambda= 3156.026
# phi= 12.4898   sv2= 0.00395477   df= 2.741373   lambda= 3158.162
# phi= 12.48996   sv2= 0.003953406   df= 2.741107   lambda= 3159.291
# phi= 12.49004   sv2= 0.003952685   df= 2.740966   lambda= 3159.888
# phi= 12.49008   sv2= 0.003952304   df= 2.740892   lambda= 3160.203
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tyrB/CR-TA_tyrB-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.58441   sv2= 0.05853892   df= 12.95777   lambda= 1017.86
# phi= 59.07   sv2= 0.001940903   df= 4.726116   lambda= 30434.29
# Iterations: relative error in phi-hat = 1e-04
# phi= 28.13512   sv2= 0.05873598   df= 12.74639   lambda= 479.0101
# phi= 28.53772   sv2= 0.007911847   df= 5.401382   lambda= 3606.96
# phi= 29.43553   sv2= 0.003770932   df= 3.571818   lambda= 7805.903
# phi= 29.97747   sv2= 0.002310316   df= 3.093187   lambda= 12975.49
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  112.011427  109.779747  114.226214  0.000227, 1:                 est      L95%       U95%       var
# lifespan  96.314408  95.15783  98.479529  0.000285}
