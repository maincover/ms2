# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/TA_yhbW-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/TA_yhbW-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW
# Iterations: relative error in phi-hat = 1e-04
# phi= 5.374171   sv2= 0.03846531   df= 11.60746   lambda= 139.7148
# phi= 5.502717   sv2= 0.01188155   df= 6.465573   lambda= 463.1312
# phi= 5.531967   sv2= 0.005913681   df= 4.993475   lambda= 935.4524
# phi= 5.514348   sv2= 0.003739035   df= 4.309505   lambda= 1474.805
# phi= 5.492106   sv2= 0.002695483   df= 3.925353   lambda= 2037.522
# phi= 5.474668   sv2= 0.002089621   df= 3.677982   lambda= 2619.934
# phi= 5.461619   sv2= 0.001689315   df= 3.499347   lambda= 3233.038
# phi= 5.451606   sv2= 0.001400365   df= 3.358871   lambda= 3892.991
# phi= 5.443656   sv2= 0.001178496   df= 3.241342   lambda= 4619.157
# phi= 5.437154   sv2= 0.001000498   df= 3.138445   lambda= 5434.448
# phi= 5.431718   sv2= 0.0008531843   df= 3.045296   lambda= 6366.406
# phi= 5.427101   sv2= 0.0007286014   df= 2.958888   lambda= 7448.656
# phi= 5.423146   sv2= 0.0006217311   df= 2.877341   lambda= 8722.654
# phi= 5.419748   sv2= 0.0005292858   df= 2.799515   lambda= 10239.74
# save file prefixed name is : TA_yhbW-1_df_relative_timegrid-vs-TA_yhbW-1_timeseries_dataframe
# biName is :  TA_yhbW-1_df_relative_timegrid-vs-TA_yhbW-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yhbW/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yhbW-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yhbW/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yhbW/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yhbW-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 5.374171   sv2= 0.03846531   df= 11.60746   lambda= 139.7148
# phi= 5.502717   sv2= 0.01188155   df= 6.465573   lambda= 463.1312
# phi= 5.531967   sv2= 0.005913681   df= 4.993475   lambda= 935.4524
# phi= 5.514348   sv2= 0.003739035   df= 4.309505   lambda= 1474.805
# phi= 5.492106   sv2= 0.002695483   df= 3.925353   lambda= 2037.522
# phi= 5.474668   sv2= 0.002089621   df= 3.677982   lambda= 2619.934
# phi= 5.461619   sv2= 0.001689315   df= 3.499347   lambda= 3233.038
# phi= 5.451606   sv2= 0.001400365   df= 3.358871   lambda= 3892.991
# phi= 5.443656   sv2= 0.001178496   df= 3.241342   lambda= 4619.157
# phi= 5.437154   sv2= 0.001000498   df= 3.138445   lambda= 5434.448
# phi= 5.431718   sv2= 0.0008531843   df= 3.045296   lambda= 6366.406
# phi= 5.427101   sv2= 0.0007286014   df= 2.958888   lambda= 7448.656
# phi= 5.423146   sv2= 0.0006217311   df= 2.877341   lambda= 8722.654
# phi= 5.419748   sv2= 0.0005292858   df= 2.799515   lambda= 10239.74
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yhbW/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhbW-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yhbW-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/MD-TA_yhbW-1_df_relative_timegrid-vs-TA_yhbW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yhbW-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=6463.744684)
#                 est         L95%          U95%           se
# rate       0.088615     0.075827      0.103559     0.007046
# beta    6990.628330  3041.364365  16068.079513  2968.447329
# s          1.050458     0.617339      1.787448     0.284895
# lambda     0.000271     0.000124      0.000595     0.000109
#                 est       L95%       U95%       var
# lifespan  98.278489  97.153118  99.154341  0.000266
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/MD-TA_yhbW-1_df_relative_timegrid-vs-TA_yhbW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhbW-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yhbW/run-MD
