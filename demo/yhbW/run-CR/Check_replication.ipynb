# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/TA_yhbW-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/TA_yhbW-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/TA_yhbW-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW']
#
# out_name_s  ['TA_yhbW-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/TA_yhbW-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/TA_yhbW-1_analysis_metadata.pickle
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 38-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 40-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 50-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 55-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 56-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 57-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 60-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 29-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 40-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 50-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 55-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 56-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 57-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 60-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 38-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 40-1.tif.mortality.tab ------ MAX_02062014 Position 50-1.tif.mortality.tab
# MAX_02062014 Position 40-1.tif.mortality.tab ------ MAX_02062014 Position 55-1.tif.mortality.tab
# MAX_02062014 Position 40-1.tif.mortality.tab ------ MAX_02062014 Position 56-1.tif.mortality.tab
# MAX_02062014 Position 40-1.tif.mortality.tab ------ MAX_02062014 Position 57-1.tif.mortality.tab
# MAX_02062014 Position 40-1.tif.mortality.tab ------ MAX_02062014 Position 60-1.tif.mortality.tab
# MAX_02062014 Position 40-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 40-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 50-1.tif.mortality.tab ------ MAX_02062014 Position 55-1.tif.mortality.tab
# MAX_02062014 Position 50-1.tif.mortality.tab ------ MAX_02062014 Position 56-1.tif.mortality.tab
# MAX_02062014 Position 50-1.tif.mortality.tab ------ MAX_02062014 Position 57-1.tif.mortality.tab
# MAX_02062014 Position 50-1.tif.mortality.tab ------ MAX_02062014 Position 60-1.tif.mortality.tab
# MAX_02062014 Position 50-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 50-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 55-1.tif.mortality.tab ------ MAX_02062014 Position 56-1.tif.mortality.tab
# MAX_02062014 Position 55-1.tif.mortality.tab ------ MAX_02062014 Position 57-1.tif.mortality.tab
# MAX_02062014 Position 55-1.tif.mortality.tab ------ MAX_02062014 Position 60-1.tif.mortality.tab
# MAX_02062014 Position 55-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 55-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 56-1.tif.mortality.tab ------ MAX_02062014 Position 57-1.tif.mortality.tab
# MAX_02062014 Position 56-1.tif.mortality.tab ------ MAX_02062014 Position 60-1.tif.mortality.tab
# MAX_02062014 Position 56-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 56-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 57-1.tif.mortality.tab ------ MAX_02062014 Position 60-1.tif.mortality.tab
# MAX_02062014 Position 57-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 57-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 60-1.tif.mortality.tab ------ MAX_02062014 Position 65-1.tif.mortality.tab
# MAX_02062014 Position 60-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# MAX_02062014 Position 65-1.tif.mortality.tab ------ MAX_02062014 Position 70-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_dentrogram-all-files.eps
# [['MAX_02062014 Position 40-1.tif.mortality.tab', 'MAX_02062014 Position 50-1.tif.mortality.tab', 'MAX_02062014 Position 55-1.tif.mortality.tab', 'MAX_02062014 Position 56-1.tif.mortality.tab', 'MAX_02062014 Position 57-1.tif.mortality.tab', 'MAX_02062014 Position 60-1.tif.mortality.tab', 'MAX_02062014 Position 70-1.tif.mortality.tab'], ['MAX_02062014 Position 29-1.tif.mortality.tab', 'MAX_02062014 Position 38-1.tif.mortality.tab', 'MAX_02062014 Position 65-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.732607   sv2= 0.03924802   df= 10.83335   lambda= 197.0191
# phi= 8.238294   sv2= 0.009569821   df= 5.644906   lambda= 860.8618
# phi= 8.436654   sv2= 0.00307107   df= 4.12877   lambda= 2747.139
# phi= 8.471163   sv2= 0.001122025   df= 3.280155   lambda= 7549.891
# phi= 8.492189   sv2= 0.0004352039   df= 2.740261   lambda= 19513.13
# Iterations: relative error in phi-hat = 1e-04
# phi= 2.198416   sv2= 0.03351458   df= 9.015574   lambda= 65.59581
# phi= 2.249331   sv2= 0.009417158   df= 6.002849   lambda= 238.8545
# phi= 2.270744   sv2= 0.005929828   df= 4.58376   lambda= 382.9359
# phi= 2.282866   sv2= 0.004861699   df= 4.160694   lambda= 469.5615
# phi= 2.289685   sv2= 0.004384698   df= 3.991119   lambda= 522.199
# phi= 2.293646   sv2= 0.004135094   df= 3.905791   lambda= 554.6782
# phi= 2.296019   sv2= 0.003993665   df= 3.858244   lambda= 574.9153
# phi= 2.297469   sv2= 0.003909921   df= 3.830318   lambda= 587.6
# phi= 2.298368   sv2= 0.00385904   df= 3.813423   lambda= 595.5801
# phi= 2.298929   sv2= 0.003827644   df= 3.803024   lambda= 600.612
# phi= 2.29928   sv2= 0.003808084   df= 3.796555   lambda= 603.7893
# phi= 2.299502   sv2= 0.003795827   df= 3.792504   lambda= 605.7973
# phi= 2.299642   sv2= 0.003788118   df= 3.789958   lambda= 607.0671
# phi= 2.29973   sv2= 0.003783257   df= 3.788353   lambda= 607.8704
# phi= 2.299786   sv2= 0.003780188   df= 3.78734   lambda= 608.3787
# phi= 2.299821   sv2= 0.003778249   df= 3.786699   lambda= 608.7003
# phi= 2.299843   sv2= 0.003777022   df= 3.786295   lambda= 608.9038
# phi= 2.299857   sv2= 0.003776246   df= 3.786039   lambda= 609.0327
# phi= 2.299866   sv2= 0.003775756   df= 3.785877   lambda= 609.1142
# phi= 2.299872   sv2= 0.003775445   df= 3.785774   lambda= 609.1658
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhbW/CR-TA_yhbW-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 5.374171   sv2= 0.03846531   df= 11.60746   lambda= 139.7148
# phi= 5.502717   sv2= 0.01188155   df= 6.465573   lambda= 463.1312
# phi= 5.531967   sv2= 0.005913681   df= 4.993475   lambda= 935.4524
# phi= 5.514348   sv2= 0.003739035   df= 4.309505   lambda= 1474.805
# phi= 5.492106   sv2= 0.002695483   df= 3.925353   lambda= 2037.522
# phi= 5.474668   sv2= 0.002089621   df= 3.677982   lambda= 2619.934
# phi= 5.461619   sv2= 0.001689315   df= 3.499347   lambda= 3233.038
# phi= 5.451606   sv2= 0.001400365   df= 3.358871   lambda= 3892.991
# phi= 5.443656   sv2= 0.001178496   df= 3.241342   lambda= 4619.157
# phi= 5.437154   sv2= 0.001000498   df= 3.138445   lambda= 5434.448
# phi= 5.431718   sv2= 0.0008531843   df= 3.045296   lambda= 6366.406
# phi= 5.427101   sv2= 0.0007286014   df= 2.958888   lambda= 7448.656
# phi= 5.423146   sv2= 0.0006217311   df= 2.877341   lambda= 8722.654
# phi= 5.419748   sv2= 0.0005292858   df= 2.799515   lambda= 10239.74
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  98.278489  97.153118  99.154341  0.000266}
