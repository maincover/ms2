# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/TA_gspM-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/TA_gspM-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/TA_gspM-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM']
#
# out_name_s  ['TA_gspM-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/TA_gspM-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/TA_gspM-1_analysis_metadata.pickle
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 110-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 111-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 112-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 113-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 114-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 121-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 122-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 108-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 111-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 112-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 113-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 114-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 121-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 122-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 110-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 112-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 113-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 114-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 121-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 122-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 111-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 113-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 114-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 121-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 122-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 112-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 114-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 121-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 122-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 113-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 114-1.tif.mortality.tab ------ MAX_10092018 Position 121-1.tif.mortality.tab
# MAX_10092018 Position 114-1.tif.mortality.tab ------ MAX_10092018 Position 122-1.tif.mortality.tab
# MAX_10092018 Position 114-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 114-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 114-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 114-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 114-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 121-1.tif.mortality.tab ------ MAX_10092018 Position 122-1.tif.mortality.tab
# MAX_10092018 Position 121-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 121-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 121-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 121-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 121-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 122-1.tif.mortality.tab ------ MAX_10092018 Position 48-1.tif.mortality.tab
# MAX_10092018 Position 122-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 122-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 122-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 122-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 48-1.tif.mortality.tab ------ MAX_10092018 Position 49-1.tif.mortality.tab
# MAX_10092018 Position 48-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 48-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 48-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 49-1.tif.mortality.tab ------ MAX_10092018 Position 58-1.tif.mortality.tab
# MAX_10092018 Position 49-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 49-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 58-1.tif.mortality.tab ------ MAX_10092018 Position 62-1.tif.mortality.tab
# MAX_10092018 Position 58-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# MAX_10092018 Position 62-1.tif.mortality.tab ------ MAX_10092018 Position 71-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_dentrogram-all-files.eps
# 7 [1 2 3 4 5 5 6]
# [['MAX_10092018 Position 113-1.tif.mortality.tab'], ['MAX_10092018 Position 114-1.tif.mortality.tab'], ['MAX_10092018 Position 48-1.tif.mortality.tab', 'MAX_10092018 Position 49-1.tif.mortality.tab'], ['MAX_10092018 Position 110-1.tif.mortality.tab', 'MAX_10092018 Position 111-1.tif.mortality.tab', 'MAX_10092018 Position 112-1.tif.mortality.tab'], ['MAX_10092018 Position 121-1.tif.mortality.tab', 'MAX_10092018 Position 122-1.tif.mortality.tab', 'MAX_10092018 Position 58-1.tif.mortality.tab', 'MAX_10092018 Position 62-1.tif.mortality.tab', 'MAX_10092018 Position 71-1.tif.mortality.tab'], ['MAX_10092018 Position 108-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.01506   sv2= 0.2742515   df= 14.50063   lambda= 142.2602
# phi= 43.1285   sv2= 0.07398058   df= 8.135587   lambda= 582.9705
# phi= 46.1644   sv2= 0.02624344   df= 6.082092   lambda= 1759.084
# phi= 48.75349   sv2= 0.008816608   df= 4.876492   lambda= 5529.733
# phi= 51.00803   sv2= 0.00269258   df= 3.915116   lambda= 18943.92
# Iterations: relative error in phi-hat = 1e-04
# phi= 277.527   sv2= 0.4410431   df= 12.3804   lambda= 629.2513
# phi= 322.0023   sv2= 0.01329553   df= 5.245022   lambda= 24218.84
# Iterations: relative error in phi-hat = 1e-04
# phi= 206.4494   sv2= 0.07239143   df= 9.514134   lambda= 2851.848
# phi= 252.3895   sv2= 0.004645319   df= 3.195595   lambda= 54332.01
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_mortality_dataframe_cluster0.pickle
# 6 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_mortality_dataframe_cluster1.pickle
# 6 --c-- 4
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_mortality_dataframe_cluster2.pickle
# 6 --c-- 3
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/CR-TA_gspM-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.01506   sv2= 0.2742515   df= 14.50063   lambda= 142.2602
# phi= 43.1285   sv2= 0.07398058   df= 8.135587   lambda= 582.9705
# phi= 46.1644   sv2= 0.02624344   df= 6.082092   lambda= 1759.084
# phi= 48.75349   sv2= 0.008816608   df= 4.876492   lambda= 5529.733
# phi= 51.00803   sv2= 0.00269258   df= 3.915116   lambda= 18943.92
# Iterations: relative error in phi-hat = 1e-04
# phi= 277.527   sv2= 0.4410431   df= 12.3804   lambda= 629.2513
# phi= 322.0023   sv2= 0.01329553   df= 5.245022   lambda= 24218.84
# Iterations: relative error in phi-hat = 1e-04
# phi= 206.4494   sv2= 0.07239143   df= 9.514134   lambda= 2851.848
# phi= 252.3895   sv2= 0.004645319   df= 3.195595   lambda= 54332.01
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  85.626634  82.628958  86.628474  0.000197, 1:                  est        L95%        U95%       var
# lifespan  102.834994  100.842157  104.829434  0.000301, 2:                  est       L95%        U95%       var
# lifespan  100.572284  96.575142  102.573734  0.000894}
