# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/TA_gspM-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/TA_gspM-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.82671   sv2= 0.4282504   df= 17.44671   lambda= 139.7003
# phi= 65.10806   sv2= 0.09306672   df= 9.858328   lambda= 699.5847
# phi= 69.89329   sv2= 0.0351197   df= 7.005136   lambda= 1990.145
# phi= 73.41833   sv2= 0.01540879   df= 5.667601   lambda= 4764.705
# phi= 76.17091   sv2= 0.007872089   df= 4.779165   lambda= 9676.073
# phi= 78.39523   sv2= 0.005200174   df= 4.183719   lambda= 15075.5
# save file prefixed name is : TA_gspM-1_df_relative_timegrid-vs-TA_gspM-1_timeseries_dataframe
# biName is :  TA_gspM-1_df_relative_timegrid-vs-TA_gspM-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/gspM/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_gspM-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/gspM/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gspM/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_gspM-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.82671   sv2= 0.4282504   df= 17.44671   lambda= 139.7003
# phi= 65.10806   sv2= 0.09306672   df= 9.858328   lambda= 699.5847
# phi= 69.89329   sv2= 0.0351197   df= 7.005136   lambda= 1990.145
# phi= 73.41833   sv2= 0.01540879   df= 5.667601   lambda= 4764.705
# phi= 76.17091   sv2= 0.007872089   df= 4.779165   lambda= 9676.073
# phi= 78.39523   sv2= 0.005200174   df= 4.183719   lambda= 15075.5
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gspM/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gspM-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_gspM-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/MD-TA_gspM-1_df_relative_timegrid-vs-TA_gspM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_gspM-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=28933.381600)
#                   est          L95%           U95%             se
# rate         0.119259      0.107194       0.132682       0.006490
# beta    187070.898193  64313.570417  544138.985344  101909.414636
# s            0.596106      0.472388       0.752225       0.070749
# lambda       0.004009      0.003728       0.004312       0.000149
#                est       L95%       U95%       var
# lifespan  99.63428  97.839364  99.857804  0.000073
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspM/MD-TA_gspM-1_df_relative_timegrid-vs-TA_gspM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gspM-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/gspM/run-MD
