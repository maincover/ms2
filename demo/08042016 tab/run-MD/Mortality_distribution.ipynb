# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/ms2/dataset/08042016 tab'
ref_df_path = '/home/xsong/ms2/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/ms2/dataset/08042016 tab/TA_08042016 tab-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/ms2/dataset/08042016 tab/TA_08042016 tab-1_timeseries_dataframe.pickle']]
# /home/xsong/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/ms2/dataset/08042016 tab
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.66639   sv2= 1.018966   df= 22.97901   lambda= 22.24449
# phi= 22.79965   sv2= 0.5981554   df= 20.34897   lambda= 38.1166
# phi= 22.91264   sv2= 0.4013961   df= 18.54051   lambda= 57.08238
# phi= 23.00397   sv2= 0.2960555   df= 17.19651   lambda= 77.70154
# phi= 23.0746   sv2= 0.2358699   df= 16.19071   lambda= 97.82764
# phi= 23.12681   sv2= 0.2001898   df= 15.45666   lambda= 115.5244
# phi= 23.16396   sv2= 0.1784818   df= 14.93792   lambda= 129.7833
# phi= 23.18965   sv2= 0.1650044   df= 14.58107   lambda= 140.5396
# phi= 23.20708   sv2= 0.1565037   df= 14.3401   lambda= 148.2845
# phi= 23.21876   sv2= 0.1510785   df= 14.17925   lambda= 153.6867
# phi= 23.22652   sv2= 0.1475864   df= 14.07265   lambda= 157.3758
# phi= 23.23166   sv2= 0.1453253   df= 14.0023   lambda= 159.8597
# phi= 23.23505   sv2= 0.1438554   df= 13.95598   lambda= 161.5167
# phi= 23.23728   sv2= 0.1428971   df= 13.92555   lambda= 162.6154
# phi= 23.23874   sv2= 0.1422713   df= 13.90556   lambda= 163.341
# phi= 23.2397   sv2= 0.1418621   df= 13.89245   lambda= 163.8189
# phi= 23.24033   sv2= 0.1415944   df= 13.88385   lambda= 164.1332
# phi= 23.24075   sv2= 0.1414191   df= 13.87821   lambda= 164.3396
# phi= 23.24102   sv2= 0.1413042   df= 13.87451   lambda= 164.475
# phi= 23.24119   sv2= 0.141229   df= 13.87209   lambda= 164.5639
# phi= 23.24131   sv2= 0.1411797   df= 13.8705   lambda= 164.6221
# phi= 23.24139   sv2= 0.1411474   df= 13.86946   lambda= 164.6603
# phi= 23.24144   sv2= 0.1411263   df= 13.86878   lambda= 164.6854
# phi= 23.24147   sv2= 0.1411124   df= 13.86833   lambda= 164.7018
# save file prefixed name is : TA_08042016 tab-1_df_relative_timegrid-vs-TA_08042016 tab-1_timeseries_dataframe
# biName is :  TA_08042016 tab-1_df_relative_timegrid-vs-TA_08042016 tab-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/ms2/demo/08042016 tab/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_08042016 tab-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/ms2/demo/08042016 tab/run-MD
# getKMNABSfits_dict-- /home/xsong/ms2/demo/08042016 tab/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_08042016 tab-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.66639   sv2= 1.018966   df= 22.97901   lambda= 22.24449
# phi= 22.79965   sv2= 0.5981554   df= 20.34897   lambda= 38.1166
# phi= 22.91264   sv2= 0.4013961   df= 18.54051   lambda= 57.08238
# phi= 23.00397   sv2= 0.2960555   df= 17.19651   lambda= 77.70154
# phi= 23.0746   sv2= 0.2358699   df= 16.19071   lambda= 97.82764
# phi= 23.12681   sv2= 0.2001898   df= 15.45666   lambda= 115.5244
# phi= 23.16396   sv2= 0.1784818   df= 14.93792   lambda= 129.7833
# phi= 23.18965   sv2= 0.1650044   df= 14.58107   lambda= 140.5396
# phi= 23.20708   sv2= 0.1565037   df= 14.3401   lambda= 148.2845
# phi= 23.21876   sv2= 0.1510785   df= 14.17925   lambda= 153.6867
# phi= 23.22652   sv2= 0.1475864   df= 14.07265   lambda= 157.3758
# phi= 23.23166   sv2= 0.1453253   df= 14.0023   lambda= 159.8597
# phi= 23.23505   sv2= 0.1438554   df= 13.95598   lambda= 161.5167
# phi= 23.23728   sv2= 0.1428971   df= 13.92555   lambda= 162.6154
# phi= 23.23874   sv2= 0.1422713   df= 13.90556   lambda= 163.341
# phi= 23.2397   sv2= 0.1418621   df= 13.89245   lambda= 163.8189
# phi= 23.24033   sv2= 0.1415944   df= 13.88385   lambda= 164.1332
# phi= 23.24075   sv2= 0.1414191   df= 13.87821   lambda= 164.3396
# phi= 23.24102   sv2= 0.1413042   df= 13.87451   lambda= 164.475
# phi= 23.24119   sv2= 0.141229   df= 13.87209   lambda= 164.5639
# phi= 23.24131   sv2= 0.1411797   df= 13.8705   lambda= 164.6221
# phi= 23.24139   sv2= 0.1411474   df= 13.86946   lambda= 164.6603
# phi= 23.24144   sv2= 0.1411263   df= 13.86878   lambda= 164.6854
# phi= 23.24147   sv2= 0.1411124   df= 13.86833   lambda= 164.7018
# getKMNABSfits_dict-- /home/xsong/ms2/demo/08042016 tab/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_08042016 tab-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_08042016 tab-1_df_relative_timegrid.pickle
# /home/xsong/ms2/dataset/08042016 tab/MD-TA_08042016 tab-1_df_relative_timegrid-vs-TA_08042016 tab-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_08042016 tab-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=216284.347232)
#                   est           L95%           U95%            se
# rate         0.123016       0.119792       0.126326      0.001666
# beta    468057.880910  362618.357960  604156.339779  60953.967067
# s            1.124112       1.038374       1.216930      0.045503
# lambda       0.001030       0.000980       0.001082      0.000026
#                  est        L95%        U95%       var
# lifespan  103.574653  102.928163  103.795732  0.000009
#
#
# /home/xsong/ms2/dataset/08042016 tab/MD-TA_08042016 tab-1_df_relative_timegrid-vs-TA_08042016 tab-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_08042016 tab-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/ms2/demo/08042016 tab/run-MD
