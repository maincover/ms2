# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/ms2/dataset/08042016 tab'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  876  Filtered files length (after MD5 check) :  89
# check line duplication(open file) :  50 / 876
# check line duplication(open file) :  100 / 876
# check line duplication(open file) :  150 / 876
# check line duplication(open file) :  200 / 876
# check line duplication(open file) :  250 / 876
# check line duplication(open file) :  300 / 876
# check line duplication(open file) :  350 / 876
# check line duplication(open file) :  400 / 876
# check line duplication(open file) :  450 / 876
# check line duplication(open file) :  500 / 876
# check line duplication(open file) :  550 / 876
# check line duplication(open file) :  600 / 876
# check line duplication(open file) :  650 / 876
# check line duplication(open file) :  700 / 876
# check line duplication(open file) :  750 / 876
# check line duplication(open file) :  800 / 876
# check line duplication(open file) :  850 / 876
# check line duplication:  0 / 876
# check line duplication:  50 / 876
# check line duplication:  100 / 876
# check line duplication:  150 / 876
# check line duplication:  200 / 876
# check line duplication:  250 / 876
# check line duplication:  300 / 876
# check line duplication:  350 / 876
# check line duplication:  400 / 876
# check line duplication:  450 / 876
# check line duplication:  500 / 876
# check line duplication:  550 / 876
# check line duplication:  600 / 876
# check line duplication:  650 / 876
# check line duplication:  700 / 876
# check line duplication:  750 / 876
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 100-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 101-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 102-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 104-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 105-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 106-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 107-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 109-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 110-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 111-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 112-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 113-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 114-1.tif.mortality.tab
# check line duplication:  800 / 876
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 115-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 116-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 117-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 118-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 119-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 120-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 122-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 123-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 124-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 125-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 126-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 127-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 128-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 16-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 18-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 19-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 24-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 26-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 28-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 30-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 31-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 32-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 33-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 34-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 35-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 36-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 37-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 38-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 39-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 40-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 41-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 42-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 43-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 44-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 45-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 46-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 53-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 54-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 60-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 61-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 62-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 63-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 64-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 65-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 66-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 67-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 68-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 69-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 70-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 71-1.tif.mortality.tab
# check line duplication:  850 / 876
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 72-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 73-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 74-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 76-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 77-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 78-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 79-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 80-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 81-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 82-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 83-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 84-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 85-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 86-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 88-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 89-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 90-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 91-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 92-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 93-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 94-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 95-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 96-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 97-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 98-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/08042016 tab/MAX_08042016 Position 99-1.tif.mortality.tab
