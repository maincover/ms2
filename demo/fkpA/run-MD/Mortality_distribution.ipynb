# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fkpA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fkpA/TA_fkpA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fkpA/TA_fkpA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fkpA
# Iterations: relative error in phi-hat = 1e-04
# phi= 136.555   sv2= 1.007714   df= 21.9819   lambda= 135.5097
# phi= 146.3304   sv2= 0.2161493   df= 12.99897   lambda= 676.9877
# phi= 156.7457   sv2= 0.04787359   df= 9.087017   lambda= 3274.159
# phi= 164.7735   sv2= 0.007732832   df= 6.432392   lambda= 21308.3
# save file prefixed name is : TA_fkpA-1_df_relative_timegrid-vs-TA_fkpA-1_timeseries_dataframe
# biName is :  TA_fkpA-1_df_relative_timegrid-vs-TA_fkpA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/fkpA/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_fkpA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/fkpA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fkpA/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_fkpA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 136.555   sv2= 1.007714   df= 21.9819   lambda= 135.5097
# phi= 146.3304   sv2= 0.2161493   df= 12.99897   lambda= 676.9877
# phi= 156.7457   sv2= 0.04787359   df= 9.087017   lambda= 3274.159
# phi= 164.7735   sv2= 0.007732832   df= 6.432392   lambda= 21308.3
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fkpA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fkpA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_fkpA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fkpA/MD-TA_fkpA-1_df_relative_timegrid-vs-TA_fkpA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_fkpA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=87561.557336)
#                  est          L95%        U95%        se
# rate    5.746779e-02  5.502751e-02    0.060016  0.001272
# beta    1.049452e+02  9.605689e+01  114.655900  4.738545
# s       1.382993e+00  1.215800e+00    1.573177  0.090917
# lambda  1.129636e-07  1.899141e-17  671.923372  0.000001
#                 est       L95%       U95%       var
# lifespan  73.212082  73.096911  74.038453  0.000026
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fkpA/MD-TA_fkpA-1_df_relative_timegrid-vs-TA_fkpA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fkpA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/fkpA/run-MD
