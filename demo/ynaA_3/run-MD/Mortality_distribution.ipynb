# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/ynaA_3'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/ynaA_3/TA_ynaA_3-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/ynaA_3/TA_ynaA_3-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/ynaA_3
# Iterations: relative error in phi-hat = 1e-04
# phi= 100.099   sv2= 0.2682664   df= 15.36602   lambda= 373.1328
# phi= 106.4158   sv2= 0.03507729   df= 7.008544   lambda= 3033.752
# phi= 109.7218   sv2= 0.01692136   df= 4.553908   lambda= 6484.219
# phi= 112.6015   sv2= 0.01189648   df= 3.928718   lambda= 9465.108
# phi= 114.8488   sv2= 0.009355736   df= 3.648031   lambda= 12275.76
# save file prefixed name is : TA_ynaA_3-1_df_relative_timegrid-vs-TA_ynaA_3-1_timeseries_dataframe
# biName is :  TA_ynaA_3-1_df_relative_timegrid-vs-TA_ynaA_3-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ynaA_3/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ynaA_3-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ynaA_3/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ynaA_3/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ynaA_3-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 100.099   sv2= 0.2682664   df= 15.36602   lambda= 373.1328
# phi= 106.4158   sv2= 0.03507729   df= 7.008544   lambda= 3033.752
# phi= 109.7218   sv2= 0.01692136   df= 4.553908   lambda= 6484.219
# phi= 112.6015   sv2= 0.01189648   df= 3.928718   lambda= 9465.108
# phi= 114.8488   sv2= 0.009355736   df= 3.648031   lambda= 12275.76
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ynaA_3/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA_3-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ynaA_3-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/MD-TA_ynaA_3-1_df_relative_timegrid-vs-TA_ynaA_3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ynaA_3-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=20644.832938)
#                  est          L95%          U95%            se
# rate    1.479720e-01  1.342942e-01  1.630430e-01  7.322525e-03
# beta    8.202471e+06  2.121981e+06  3.170647e+07  5.658493e+06
# s       8.405408e-01  7.027398e-01  1.005363e+00  7.679030e-02
# lambda  9.671529e-04  8.079308e-04  1.157754e-03  8.876268e-05
#                  est        L95%        U95%     var
# lifespan  107.001241  106.939591  107.096792  0.0001
#
#
# /home/xsong/mg-wt/dataset/ynaA_3/MD-TA_ynaA_3-1_df_relative_timegrid-vs-TA_ynaA_3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA_3-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ynaA_3/run-MD
