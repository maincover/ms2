# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/ynaA_3'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/ynaA_3/TA_ynaA_3-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/ynaA_3/TA_ynaA_3-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/ynaA_3/TA_ynaA_3-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/ynaA_3']
#
# out_name_s  ['TA_ynaA_3-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/ynaA_3/TA_ynaA_3-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/ynaA_3/TA_ynaA_3-1_analysis_metadata.pickle
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 17-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 2-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 20-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 21-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 2-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 20-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 21-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 20-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 21-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 21-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 4-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 4-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 4-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 4-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 6-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 6-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 6-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 7-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 7-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 8-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/ynaA_3
# save eps to :  /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_dentrogram-all-files.eps
# [['MAX_08062016 Position 17-1.tif.mortality.tab', 'MAX_08062016 Position 22-1.tif.mortality.tab'], ['MAX_08062016 Position 8-1.tif.mortality.tab'], ['MAX_08062016 Position 21-1.tif.mortality.tab'], ['MAX_08062016 Position 2-1.tif.mortality.tab', 'MAX_08062016 Position 7-1.tif.mortality.tab'], ['MAX_08062016 Position 6-1.tif.mortality.tab'], ['MAX_08062016 Position 10-1.tif.mortality.tab'], ['MAX_08062016 Position 20-1.tif.mortality.tab'], ['MAX_08062016 Position 9-1.tif.mortality.tab'], ['MAX_08062016 Position 4-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 55.89836   sv2= 0.2160478   df= 11.46286   lambda= 258.7314
# phi= 58.51612   sv2= 0.01863555   df= 5.678642   lambda= 3140.026
# phi= 63.44062   sv2= 0.006748129   df= 3.478452   lambda= 9401.216
# phi= 68.33375   sv2= 0.002762395   df= 2.799396   lambda= 24737.14
# Iterations: relative error in phi-hat = 1e-04
# phi= 143.3719   sv2= 0.1984154   df= 9.770182   lambda= 722.5844
# phi= 152.4228   sv2= 0.005386999   df= 4.185432   lambda= 28294.56
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_mortality_dataframe_cluster0.pickle
# 9 --c-- 4
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_mortality_dataframe_cluster1.pickle
# 9 --c-- 5
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/ynaA_3/CR-TA_ynaA_3-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 55.89836   sv2= 0.2160478   df= 11.46286   lambda= 258.7314
# phi= 58.51612   sv2= 0.01863555   df= 5.678642   lambda= 3140.026
# phi= 63.44062   sv2= 0.006748129   df= 3.478452   lambda= 9401.216
# phi= 68.33375   sv2= 0.002762395   df= 2.799396   lambda= 24737.14
# Iterations: relative error in phi-hat = 1e-04
# phi= 143.3719   sv2= 0.1984154   df= 9.770182   lambda= 722.5844
# phi= 152.4228   sv2= 0.005386999   df= 4.185432   lambda= 28294.56
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  106.983695  106.939591  109.501172  0.000422, 1:                  est        L95%        U95%       var
# lifespan  114.784028  110.907892  118.060492  0.000789}
