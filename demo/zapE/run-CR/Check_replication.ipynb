# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/TA_zapE-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/TA_zapE-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/TA_zapE-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE']
#
# out_name_s  ['TA_zapE-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/TA_zapE-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/TA_zapE-1_analysis_metadata.pickle
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 31-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 33-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 36-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 48-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 50-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 52-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 53-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 30-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 33-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 36-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 48-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 50-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 52-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 53-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 31-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 33-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 36-1.tif.mortality.tab
# MAX_28072014 mRFP Position 33-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 48-1.tif.mortality.tab
# MAX_28072014 mRFP Position 33-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 50-1.tif.mortality.tab
# MAX_28072014 mRFP Position 33-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 52-1.tif.mortality.tab
# MAX_28072014 mRFP Position 33-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 53-1.tif.mortality.tab
# MAX_28072014 mRFP Position 33-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 33-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 36-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 48-1.tif.mortality.tab
# MAX_28072014 mRFP Position 36-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 50-1.tif.mortality.tab
# MAX_28072014 mRFP Position 36-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 52-1.tif.mortality.tab
# MAX_28072014 mRFP Position 36-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 53-1.tif.mortality.tab
# MAX_28072014 mRFP Position 36-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 36-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 48-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 50-1.tif.mortality.tab
# MAX_28072014 mRFP Position 48-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 52-1.tif.mortality.tab
# MAX_28072014 mRFP Position 48-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 53-1.tif.mortality.tab
# MAX_28072014 mRFP Position 48-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 48-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 50-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 52-1.tif.mortality.tab
# MAX_28072014 mRFP Position 50-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 53-1.tif.mortality.tab
# MAX_28072014 mRFP Position 50-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 50-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 52-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 53-1.tif.mortality.tab
# MAX_28072014 mRFP Position 52-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 52-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 53-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 54-1.tif.mortality.tab
# MAX_28072014 mRFP Position 53-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# MAX_28072014 mRFP Position 54-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 55-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_dentrogram-all-files.eps
# [['MAX_28072014 mRFP Position 30-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 31-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 33-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 50-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 48-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 52-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 36-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 53-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 54-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 55-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 52.2649   sv2= 0.05960051   df= 16.11838   lambda= 876.9204
# phi= 52.1436   sv2= 0.001473467   df= 5.9129   lambda= 35388.39
# Iterations: relative error in phi-hat = 1e-04
# phi= 124.5811   sv2= 0.04669575   df= 12.39526   lambda= 2667.933
# phi= 130.9593   sv2= 0.0007362255   df= 3.690824   lambda= 177879.3
# Iterations: relative error in phi-hat = 1e-04
# phi= 5.048816   sv2= 0.02381872   df= 11.79826   lambda= 211.9684
# phi= 5.09597   sv2= 0.003884836   df= 5.998433   lambda= 1311.759
# phi= 5.241203   sv2= 0.000748749   df= 4.094538   lambda= 6999.947
# phi= 5.292212   sv2= 0.0001312613   df= 2.97543   lambda= 40318.15
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.49549   sv2= 0.1600088   df= 11.70068   lambda= 534.3173
# phi= 92.33793   sv2= 0.00674312   df= 4.936469   lambda= 13693.65
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_mortality_dataframe_cluster2.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/zapE/CR-TA_zapE-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.16325   sv2= 0.09383389   df= 16.80844   lambda= 481.3106
# phi= 45.30362   sv2= 0.004244001   df= 7.060914   lambda= 10674.74
# Iterations: relative error in phi-hat = 1e-04
# phi= 124.5811   sv2= 0.04669575   df= 12.39526   lambda= 2667.933
# phi= 130.9593   sv2= 0.0007362255   df= 3.690824   lambda= 177879.3
# Iterations: relative error in phi-hat = 1e-04
# phi= 5.048816   sv2= 0.02381872   df= 11.79826   lambda= 211.9684
# phi= 5.09597   sv2= 0.003884836   df= 5.998433   lambda= 1311.759
# phi= 5.241203   sv2= 0.000748749   df= 4.094538   lambda= 6999.947
# phi= 5.292212   sv2= 0.0001312613   df= 2.97543   lambda= 40318.15
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%      var
# lifespan  92.339354  90.523587  92.339354  0.00007, 1:                 est       L95%       U95%       var
# lifespan  89.284862  87.282926  90.284013  0.000303, 2:                 est       L95%        U95%       var
# lifespan  97.446155  96.444117  100.445114  0.000365}
