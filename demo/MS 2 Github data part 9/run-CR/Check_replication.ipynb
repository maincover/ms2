# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/app/src/ms2/dataset/MS 2 Github data part 9'
path_ref_folder ='/app/src/ms2/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /app/src/ms2/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /app/src/ms2/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/TA_uxuR3-1_mortality_dataframe.pickle'], ['/app/src/ms2/dataset/MS 2 Github data part 9/pgi3/TA_pgi3-1_mortality_dataframe.pickle']]
# meta_paths:  [['/app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/TA_uxuR3-1_analysis_metadata.pickle'], ['/app/src/ms2/dataset/MS 2 Github data part 9/pgi3/TA_pgi3-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/TA_uxuR3-1_timeseries_dataframe.pickle'], ['/app/src/ms2/dataset/MS 2 Github data part 9/pgi3/TA_pgi3-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/app/src/ms2/dataset/MS 2 Github data part 9/uxuR3', '/app/src/ms2/dataset/MS 2 Github data part 9/pgi3']
#
# out_name_s  ['TA_uxuR3-1_', 'TA_pgi3-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/TA_uxuR3-1_mortality_dataframe.pickle
# path meta  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/TA_uxuR3-1_analysis_metadata.pickle
# path df  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/TA_pgi3-1_mortality_dataframe.pickle
# path meta  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/TA_pgi3-1_analysis_metadata.pickle
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 217-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 221-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 222-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 225-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 237-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 111-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 219-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 221-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 222-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 225-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 237-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 217-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 220-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 221-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 222-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 225-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 237-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 219-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 221-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 222-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 225-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 237-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 220-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 222-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 225-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 237-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 221-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 222-1.tif.mortality.tab ------ MAX_12072018 Position 225-1.tif.mortality.tab
# MAX_12072018 Position 222-1.tif.mortality.tab ------ MAX_12072018 Position 237-1.tif.mortality.tab
# MAX_12072018 Position 222-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 222-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 222-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 222-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 222-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 225-1.tif.mortality.tab ------ MAX_12072018 Position 237-1.tif.mortality.tab
# MAX_12072018 Position 225-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 225-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 225-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 225-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 225-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 237-1.tif.mortality.tab ------ MAX_12072018 Position 244-1.tif.mortality.tab
# MAX_12072018 Position 237-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 237-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 237-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 237-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 244-1.tif.mortality.tab ------ MAX_12072018 Position 246-1.tif.mortality.tab
# MAX_12072018 Position 244-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 244-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 244-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 246-1.tif.mortality.tab ------ MAX_12072018 Position 250-1.tif.mortality.tab
# MAX_12072018 Position 246-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 246-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 250-1.tif.mortality.tab ------ MAX_12072018 Position 252-1.tif.mortality.tab
# MAX_12072018 Position 250-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 252-1.tif.mortality.tab ------ MAX_12072018 Position 255-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 106-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 107-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 110-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 178-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 179-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 180-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 182-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 105-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 107-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 110-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 178-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 179-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 180-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 182-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 106-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 110-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 178-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 179-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 180-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 182-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 107-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 178-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 179-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 180-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 182-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 110-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 179-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 180-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 182-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 178-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 180-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 182-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 179-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 182-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 180-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 183-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 182-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 209-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 183-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 211-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 209-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 215-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 211-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 224-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 215-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 226-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 224-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 227-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 226-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 227-1.tif.mortality.tab ------ MAX_12072018 Position 228-1.tif.mortality.tab
# MAX_12072018 Position 227-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 227-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 227-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 227-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 227-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 227-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 228-1.tif.mortality.tab ------ MAX_12072018 Position 230-1.tif.mortality.tab
# MAX_12072018 Position 228-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 228-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 228-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 228-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 228-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 230-1.tif.mortality.tab ------ MAX_12072018 Position 231-1.tif.mortality.tab
# MAX_12072018 Position 230-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 230-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 230-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 230-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 231-1.tif.mortality.tab ------ MAX_12072018 Position 232-1.tif.mortality.tab
# MAX_12072018 Position 231-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 231-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 231-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 232-1.tif.mortality.tab ------ MAX_12072018 Position 236-1.tif.mortality.tab
# MAX_12072018 Position 232-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 232-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 236-1.tif.mortality.tab ------ MAX_12072018 Position 245-1.tif.mortality.tab
# MAX_12072018 Position 236-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# MAX_12072018 Position 245-1.tif.mortality.tab ------ MAX_12072018 Position 251-1.tif.mortality.tab
# dendrogram will be saved to :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3
# save eps to :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_dentrogram-all-files.eps
# dendrogram will be saved to :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3
# save eps to :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/CR-TA_pgi3-1_dentrogram-all-files.eps
# [['MAX_12072018 Position 220-1.tif.mortality.tab', 'MAX_12072018 Position 221-1.tif.mortality.tab', 'MAX_12072018 Position 222-1.tif.mortality.tab', 'MAX_12072018 Position 225-1.tif.mortality.tab'], ['MAX_12072018 Position 111-1.tif.mortality.tab', 'MAX_12072018 Position 217-1.tif.mortality.tab', 'MAX_12072018 Position 219-1.tif.mortality.tab', 'MAX_12072018 Position 237-1.tif.mortality.tab', 'MAX_12072018 Position 244-1.tif.mortality.tab', 'MAX_12072018 Position 246-1.tif.mortality.tab', 'MAX_12072018 Position 250-1.tif.mortality.tab', 'MAX_12072018 Position 252-1.tif.mortality.tab', 'MAX_12072018 Position 255-1.tif.mortality.tab']]
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_colomap_all_files_cluster0.png
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_mortality_orig_dataframe_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_relative_orig_timegrid_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_colomap_all_files_cluster1.png
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_mortality_orig_dataframe_cluster1.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.71634   sv2= 0.07561772   df= 12.44642   lambda= 194.615
# phi= 14.95454   sv2= 0.009973895   df= 6.472082   lambda= 1499.368
# phi= 15.38615   sv2= 0.004138284   df= 4.290436   lambda= 3718.003
# phi= 15.79811   sv2= 0.002735226   df= 3.612256   lambda= 5775.796
# phi= 16.0595   sv2= 0.00224974   df= 3.331341   lambda= 7138.382
# phi= 16.20078   sv2= 0.00205168   df= 3.206088   lambda= 7896.348
# phi= 16.27179   sv2= 0.001963836   df= 3.148515   lambda= 8285.718
# phi= 16.30651   sv2= 0.001923239   df= 3.12152   lambda= 8478.669
# phi= 16.3233   sv2= 0.001904101   df= 3.108714   lambda= 8572.708
# phi= 16.3314   sv2= 0.001894993   df= 3.102602   lambda= 8618.183
# phi= 16.33529   sv2= 0.001890638   df= 3.099676   lambda= 8640.092
# phi= 16.33716   sv2= 0.001888552   df= 3.098273   lambda= 8650.629
# phi= 16.33806   sv2= 0.001887551   df= 3.0976   lambda= 8655.693
# phi= 16.33849   sv2= 0.00188707   df= 3.097277   lambda= 8658.125
# phi= 16.3387   sv2= 0.00188684   df= 3.097122   lambda= 8659.293
# phi= 16.3388   sv2= 0.001886729   df= 3.097047   lambda= 8659.854
# Iterations: relative error in phi-hat = 1e-04
# phi= 79.86282   sv2= 0.08713339   df= 11.0806   lambda= 916.5581
# phi= 88.38549   sv2= 0.003200758   df= 4.299488   lambda= 27613.92
# No error in flxsrv_fit
# No error in flxsrv_fit
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_relative_timegrid_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_timeseries_dataframe_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/CR-TA_uxuR3-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 40.38735   sv2= 0.09710746   df= 13.82735   lambda= 415.9037
# phi= 40.82147   sv2= 0.00785589   df= 6.105548   lambda= 5196.288
# phi= 42.39108   sv2= 0.002457098   df= 3.717143   lambda= 17252.5
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  112.139514  109.244667  113.205505  0.000241}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-bfc24e719327> in <module>()
#       8 cutoff = -1
#       9 CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
# ---> 10 CR.run()
#
# /app/src/ms2/Check_Replication.pyc in run(self)
#      41             self.getStatsFromRefDf_timegrid(self.df_ref,self.timegrid_ref)
#      42             self.vsRef = True
# ---> 43         self.getDf_timegrid_timeseries(self.folderPath,showProgress = True)
#      44
#      45
#
# /app/src/ms2/Check_Replication.pyc in getDf_timegrid_timeseries(self, path_folder, showProgress)
#     132         self.out_name_s = out_name_s
#     133         CheckReplication.runDentrogramFromList(files_s,pdist_s,out_path_folder_s, out_name_s,self.cutoff_c)
# --> 134         self.runClusterFromList(files_s, pdist_s,df_s, tss_by_pos_s,profile_s,out_path_folder_s, out_name_s)
#     135
#     136     @staticmethod
#
# /app/src/ms2/Check_Replication.pyc in runClusterFromList(self, files_s, pdist_s, df_s, tss_by_pos_s, profile_s, path_folder_s, name_s)
#     422             out_folder = path_folder_s[idx]
#     423             name = name_s[idx]
# --> 424             self.runCluster(files,pdist,df, tss_by_pos,profile,out_folder,name)
#     425
#     426     def runCluster(self,files, pdist,df, tss_by_pos,profile,out_folder,name,showProgress=True):
#
# /app/src/ms2/Check_Replication.pyc in runCluster(self, files, pdist, df, tss_by_pos, profile, out_folder, name, showProgress)
#     477                     k+=1
#     478
# --> 479             superclusters = fcluster(complete(cpdist),cutoff,criterion='distance')
#     480             if nc == np.max(superclusters):
#     481                 clustersFixed = True
#
# /app/miniconda/envs/py27/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in complete(y)
#     285
#     286     """
# --> 287     return linkage(y, method='complete', metric='euclidean')
#     288
#     289
#
# /app/miniconda/envs/py27/lib/python2.7/site-packages/scipy/cluster/hierarchy.pyc in linkage(y, method, metric)
#     676         raise ValueError("The condensed distance matrix must contain only finite values.")
#     677
# --> 678     n = int(distance.num_obs_y(y))
#     679     method_code = _LINKAGE_METHODS[method]
#     680     if method == 'single':
#
# /app/miniconda/envs/py27/lib/python2.7/site-packages/scipy/spatial/distance.pyc in num_obs_y(Y)
#    1810     k = Y.shape[0]
#    1811     if k == 0:
# -> 1812         raise ValueError("The number of observations cannot be determined on "
#    1813                          "an empty distance matrix.")
#    1814     d = int(np.ceil(np.sqrt(k * 2)))
#
# ValueError: The number of observations cannot be determined on an empty distance matrix.
