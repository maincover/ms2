# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/app/src/ms2/dataset/MS 2 Github data part 9'
ref_df_path = '/app/src/ms2/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/TA_uxaC3-1_df_relative_timegrid.pickle'], ['/app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/TA_uxuR3-1_df_relative_timegrid.pickle'], ['/app/src/ms2/dataset/MS 2 Github data part 9/pgi3/TA_pgi3-1_df_relative_timegrid.pickle']]
# []
# [['/app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/TA_uxaC3-1_timeseries_dataframe.pickle'], ['/app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/TA_uxuR3-1_timeseries_dataframe.pickle'], ['/app/src/ms2/dataset/MS 2 Github data part 9/pgi3/TA_pgi3-1_timeseries_dataframe.pickle']]
# /app/src/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /app/src/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.32831027777777
# files will be written into :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3
# Iterations: relative error in phi-hat = 1e-04
# phi= 124.8655   sv2= 3.354186   df= 15.70199   lambda= 37.22676
# phi= 151.421   sv2= 1.587222   df= 12.2557   lambda= 95.39998
# phi= 185.1904   sv2= 0.796251   df= 10.26832   lambda= 232.5779
# phi= 230.8182   sv2= 0.3538217   df= 8.643204   lambda= 652.3575
# phi= 292.8552   sv2= 0.1125004   df= 7.017666   lambda= 2603.149
# phi= 358.1787   sv2= 0.02179694   df= 5.287213   lambda= 16432.52
# save file prefixed name is : TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe
# biName is :  TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe
# getGGMfit_dict--(1) /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_uxaC3-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# getKMNABSfits_dict-- /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_uxaC3-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 124.8655   sv2= 3.354186   df= 15.70199   lambda= 37.22676
# phi= 151.421   sv2= 1.587222   df= 12.2557   lambda= 95.39998
# phi= 185.1904   sv2= 0.796251   df= 10.26832   lambda= 232.5779
# phi= 230.8182   sv2= 0.3538217   df= 8.643204   lambda= 652.3575
# phi= 292.8552   sv2= 0.1125004   df= 7.017666   lambda= 2603.149
# phi= 358.1787   sv2= 0.02179694   df= 5.287213   lambda= 16432.52
# getKMNABSfits_dict-- /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_uxaC3-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_uxaC3-1_df_relative_timegrid.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MD-TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_uxaC3-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=24709.896462)
#                 est        L95%         U95%          se
# rate       0.084802    0.074786     0.096159    0.005438
# beta    1213.867646  635.557679  2318.396444  400.747246
# s          0.448495    0.359430     0.559629    0.050657
# lambda     0.003793    0.003422     0.004204    0.000199
#                 est      L95%       U95%       var
# lifespan  89.825317  88.81216  90.807487  0.000098
#
#
# /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MD-TA_uxaC3-1_df_relative_timegrid-vs-TA_uxaC3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_uxaC3-1_df_relative_timegrid.pickle
# working directory is :  /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# files will be written into :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3
# Iterations: relative error in phi-hat = 1e-04
# phi= 40.38735   sv2= 0.09710746   df= 13.82735   lambda= 415.9037
# phi= 40.82147   sv2= 0.00785589   df= 6.105548   lambda= 5196.288
# phi= 42.39108   sv2= 0.002457098   df= 3.717143   lambda= 17252.5
# save file prefixed name is : TA_uxuR3-1_df_relative_timegrid-vs-TA_uxuR3-1_timeseries_dataframe
# biName is :  TA_uxuR3-1_df_relative_timegrid-vs-TA_uxuR3-1_timeseries_dataframe
# getGGMfit_dict--(1) /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# No error in flxsrv_fit
# TA_uxuR3-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# getKMNABSfits_dict-- /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# TA_uxuR3-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 40.38735   sv2= 0.09710746   df= 13.82735   lambda= 415.9037
# phi= 40.82147   sv2= 0.00785589   df= 6.105548   lambda= 5196.288
# phi= 42.39108   sv2= 0.002457098   df= 3.717143   lambda= 17252.5
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_uxuR3-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_uxuR3-1_df_relative_timegrid.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MD-TA_uxuR3-1_df_relative_timegrid-vs-TA_uxuR3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_uxuR3-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=8985.022628)
#                  est          L95%           U95%            se
# rate        0.087564      0.067375       0.113804      0.011710
# beta    91065.571409  15978.286483  519012.993352  80861.631673
# s           1.962470      0.673904       5.714894      1.070239
# lambda      0.003010      0.002556       0.003544      0.000251
#                  est        L95%        U95%       var
# lifespan  112.139514  109.244667  113.205505  0.000241
#
#
# /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MD-TA_uxuR3-1_df_relative_timegrid-vs-TA_uxuR3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_uxuR3-1_df_relative_timegrid.pickle
# working directory is :  /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# files will be written into :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.2512   sv2= 0.161724   df= 13.79146   lambda= 168.5043
# phi= 28.38021   sv2= 0.01567236   df= 7.384467   lambda= 1810.844
# phi= 29.06149   sv2= 0.006423984   df= 4.540005   lambda= 4523.905
# phi= 29.53982   sv2= 0.005576318   df= 3.815292   lambda= 5297.371
# phi= 29.65387   sv2= 0.005506769   df= 3.705231   lambda= 5384.985
# phi= 29.66647   sv2= 0.005500238   df= 3.69402   lambda= 5393.67
# phi= 29.66772   sv2= 0.005499603   df= 3.692921   lambda= 5394.52
# phi= 29.66784   sv2= 0.005499541   df= 3.692814   lambda= 5394.603
# save file prefixed name is : TA_pgi3-1_df_relative_timegrid-vs-TA_pgi3-1_timeseries_dataframe
# biName is :  TA_pgi3-1_df_relative_timegrid-vs-TA_pgi3-1_timeseries_dataframe
# getGGMfit_dict--(1) /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# No error in flxsrv_fit
# TA_pgi3-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# getKMNABSfits_dict-- /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# TA_pgi3-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.2512   sv2= 0.161724   df= 13.79146   lambda= 168.5043
# phi= 28.38021   sv2= 0.01567236   df= 7.384467   lambda= 1810.844
# phi= 29.06149   sv2= 0.006423984   df= 4.540005   lambda= 4523.905
# phi= 29.53982   sv2= 0.005576318   df= 3.815292   lambda= 5297.371
# phi= 29.65387   sv2= 0.005506769   df= 3.705231   lambda= 5384.985
# phi= 29.66647   sv2= 0.005500238   df= 3.69402   lambda= 5393.67
# phi= 29.66772   sv2= 0.005499603   df= 3.692921   lambda= 5394.52
# phi= 29.66784   sv2= 0.005499541   df= 3.692814   lambda= 5394.603
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /app/src/ms2/demo/MS 2 Github data part 9/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pgi3-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_pgi3-1_df_relative_timegrid.pickle
# /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MD-TA_pgi3-1_df_relative_timegrid-vs-TA_pgi3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_pgi3-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=10597.832810)
#                  est          L95%          U95%            se
# rate    1.244342e-01  1.079848e-01  1.433895e-01  9.001802e-03
# beta    7.555701e+06  1.548812e+06  3.685961e+07  6.109491e+06
# s       1.707246e+00  9.518726e-01  3.062058e+00  5.088780e-01
# lambda  1.825826e-03  1.575250e-03  2.116260e-03  1.375153e-04
#                 est        L95%        U95%       var
# lifespan  117.77539  117.205652  119.206044  0.000189
#
#
# /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MD-TA_pgi3-1_df_relative_timegrid-vs-TA_pgi3-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pgi3-1_df_relative_timegrid.pickle
# working directory is :  /app/src/ms2/demo/MS 2 Github data part 9/run-MD
