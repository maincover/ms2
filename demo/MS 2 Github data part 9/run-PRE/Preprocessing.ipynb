# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/app/src/ms2/dataset/MS 2 Github data part 9'
prev_path = '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  834  Filtered files length (after MD5 check) :  47
# check line duplication(open file) :  50 / 834
# check line duplication(open file) :  100 / 834
# check line duplication(open file) :  150 / 834
# check line duplication(open file) :  200 / 834
# check line duplication(open file) :  250 / 834
# check line duplication(open file) :  300 / 834
# check line duplication(open file) :  350 / 834
# check line duplication(open file) :  400 / 834
# check line duplication(open file) :  450 / 834
# check line duplication(open file) :  500 / 834
# check line duplication(open file) :  550 / 834
# check line duplication(open file) :  600 / 834
# check line duplication(open file) :  650 / 834
# check line duplication(open file) :  700 / 834
# check line duplication(open file) :  750 / 834
# check line duplication(open file) :  800 / 834
# check line duplication:  0 / 834
# check line duplication:  50 / 834
# check line duplication:  100 / 834
# check line duplication:  150 / 834
# check line duplication:  200 / 834
# check line duplication:  250 / 834
# check line duplication:  300 / 834
# check line duplication:  350 / 834
# check line duplication:  400 / 834
# check line duplication:  450 / 834
# check line duplication:  500 / 834
# check line duplication:  550 / 834
# check line duplication:  600 / 834
# check line duplication:  650 / 834
# check line duplication:  700 / 834
# check line duplication:  750 / 834
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 105-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 106-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 107-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 110-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 178-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 179-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 180-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 182-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 183-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 209-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 211-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 215-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 224-1.tif.mortality.tab
# check line duplication:  800 / 834
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 226-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 227-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 228-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 230-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 231-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 232-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 236-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 245-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/pgi3/MAX_12072018 Position 251-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 140-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 148-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 155-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 156-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 157-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 171-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 175-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 176-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 177-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 181-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 185-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxaC3/MAX_12072018 Position 192-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 111-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 217-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 219-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 220-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 221-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 222-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 225-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 237-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 244-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 246-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 250-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 252-1.tif.mortality.tab
# exclude fn(itself) :  /app/src/ms2/dataset/MS 2 Github data part 9/uxuR3/MAX_12072018 Position 255-1.tif.mortality.tab
