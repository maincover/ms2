

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# MAX_05112017 Position 147-1.tif.mortality.tab 77 84
# MAX_05112017 Position 109-1.tif.mortality.tab 61 111
# MAX_05112017 Position 106-1.tif.mortality.tab 47 56
# MAX_05112017 Position 142-1.tif.mortality.tab 125 144
# MAX_05112017 Position 113-1.tif.mortality.tab 52 79
# MAX_05112017 Position 127-1.tif.mortality.tab 69 98
# MAX_05112017 Position 128-1.tif.mortality.tab 28 65
# MAX_05112017 Position 150-1.tif.mortality.tab 61 61
# MAX_05112017 Position 110-1.tif.mortality.tab 80 113
# MAX_05112017 Position 108-1.tif.mortality.tab 43 69
# MAX_05112017 Position 112-1.tif.mortality.tab 70 87
# MAX_05112017 Position 114-1.tif.mortality.tab 51 72
# MAX_05112017 Position 118-1.tif.mortality.tab 59 63
# MAX_05112017 Position 115-1.tif.mortality.tab 45 54
# MAX_05112017 Position 120-1.tif.mortality.tab 46 48
# MAX_05112017 Position 144-1.tif.mortality.tab 92 110
# MAX_05112017 Position 143-1.tif.mortality.tab 121 143
# MAX_05112017 Position 148-1.tif.mortality.tab 54 71
# MAX_05112017 Position 116-1.tif.mortality.tab 10 17
# MAX_05112017 Position 111-1.tif.mortality.tab 79 113
# MAX_05112017 Position 146-1.tif.mortality.tab 78 89
# MAX_05112017 Position 145-1.tif.mortality.tab 73 79
# MAX_05112017 Position 107-1.tif.mortality.tab 54 68
# 58
# MAX_05112017 Position 147-1.tif.mortality.tab 80 84
# MAX_05112017 Position 109-1.tif.mortality.tab 64 111
# MAX_05112017 Position 106-1.tif.mortality.tab 47 56
# MAX_05112017 Position 142-1.tif.mortality.tab 130 144
# MAX_05112017 Position 113-1.tif.mortality.tab 53 79
# MAX_05112017 Position 127-1.tif.mortality.tab 69 98
# MAX_05112017 Position 128-1.tif.mortality.tab 31 65
# MAX_05112017 Position 150-1.tif.mortality.tab 61 61
# MAX_05112017 Position 110-1.tif.mortality.tab 80 113
# MAX_05112017 Position 108-1.tif.mortality.tab 44 69
# MAX_05112017 Position 112-1.tif.mortality.tab 70 87
# MAX_05112017 Position 114-1.tif.mortality.tab 52 72
# MAX_05112017 Position 118-1.tif.mortality.tab 59 63
# MAX_05112017 Position 115-1.tif.mortality.tab 47 54
# MAX_05112017 Position 120-1.tif.mortality.tab 46 48
# MAX_05112017 Position 144-1.tif.mortality.tab 92 110
# MAX_05112017 Position 143-1.tif.mortality.tab 121 143
# MAX_05112017 Position 148-1.tif.mortality.tab 54 71
# MAX_05112017 Position 116-1.tif.mortality.tab 10 17
# MAX_05112017 Position 111-1.tif.mortality.tab 83 113
# MAX_05112017 Position 146-1.tif.mortality.tab 78 89
# MAX_05112017 Position 145-1.tif.mortality.tab 73 79
# MAX_05112017 Position 107-1.tif.mortality.tab 56 68
#
#             Step2: After the user have reviewed and set the alcohol time,
#             re-calculate cells to include. Then again use included data to
#             re-estimate illumination, estimate lifespan, and output data
#             in the form of pickles.

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
# Out:
# length of df is:  1500
# length of relative_time_grid is:  2683
