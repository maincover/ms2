# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/mg-wt/dataset/MS 2 Github data part 3'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  853  Filtered files length (after MD5 check) :  66
# check line duplication(open file) :  50 / 853
# check line duplication(open file) :  100 / 853
# check line duplication(open file) :  150 / 853
# check line duplication(open file) :  200 / 853
# check line duplication(open file) :  250 / 853
# check line duplication(open file) :  300 / 853
# check line duplication(open file) :  350 / 853
# check line duplication(open file) :  400 / 853
# check line duplication(open file) :  450 / 853
# check line duplication(open file) :  500 / 853
# check line duplication(open file) :  550 / 853
# check line duplication(open file) :  600 / 853
# check line duplication(open file) :  650 / 853
# check line duplication(open file) :  700 / 853
# check line duplication(open file) :  750 / 853
# check line duplication(open file) :  800 / 853
# check line duplication(open file) :  850 / 853
# check line duplication:  0 / 853
# check line duplication:  50 / 853
# check line duplication:  100 / 853
# check line duplication:  150 / 853
# check line duplication:  200 / 853
# check line duplication:  250 / 853
# check line duplication:  300 / 853
# check line duplication:  350 / 853
# check line duplication:  400 / 853
# check line duplication:  450 / 853
# check line duplication:  500 / 853
# check line duplication:  550 / 853
# check line duplication:  600 / 853
# check line duplication:  650 / 853
# check line duplication:  700 / 853
# check line duplication:  750 / 853
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 29-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 33-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 34-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 35-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 37-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 39-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 42-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 43-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 44-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 51-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 78-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MAX_07092014 Position 81-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 19-1.tif.mortality.tab
# check line duplication:  800 / 853
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 20-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 21-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 22-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 25-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 26-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 89-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 90-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 91-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MAX_07092014 Position 94-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 100-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 27-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 28-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 30-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 84-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 85-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 95-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 96-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MAX_07092014 Position 98-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 106-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 107-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 108-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 109-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 110-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 111-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 112-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 113-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 114-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 115-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 116-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 118-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 120-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 127-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 128-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 142-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 143-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 144-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 145-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 146-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 147-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 148-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MAX_05112017 Position 150-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 36-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 38-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 40-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 45-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 46-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 47-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 48-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 50-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 82-1.tif.mortality.tab
# check line duplication:  850 / 853
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 83-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 86-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MAX_07092014 Position 87-1.tif.mortality.tab
