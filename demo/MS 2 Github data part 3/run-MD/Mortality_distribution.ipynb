# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS 2 Github data part 3'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/TA_sgcQ-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/TA_yajQ-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/TA_ybiT-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/TA_nirC-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/TA_paaC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/TA_sgcQ-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/TA_yajQ-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/TA_ybiT-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/TA_nirC-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/TA_paaC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ
# Iterations: relative error in phi-hat = 1e-04
# phi= 15.73101   sv2= 0.06940222   df= 8.640059   lambda= 226.6643
# phi= 16.23589   sv2= 0.01694751   df= 4.5533   lambda= 958.0103
# phi= 17.07894   sv2= 0.008067136   df= 3.391496   lambda= 2117.101
# phi= 17.6188   sv2= 0.004111458   df= 2.855163   lambda= 4285.292
# phi= 18.04142   sv2= 0.002059076   df= 2.50252   lambda= 8761.902
# phi= 18.36225   sv2= 0.0009923654   df= 2.273397   lambda= 18503.51
# save file prefixed name is : TA_sgcQ-1_df_relative_timegrid-vs-TA_sgcQ-1_timeseries_dataframe
# biName is :  TA_sgcQ-1_df_relative_timegrid-vs-TA_sgcQ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# No error in flxsrv_fit
# TA_sgcQ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# TA_sgcQ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 15.73101   sv2= 0.06940222   df= 8.640059   lambda= 226.6643
# phi= 16.23589   sv2= 0.01694751   df= 4.5533   lambda= 958.0103
# phi= 17.07894   sv2= 0.008067136   df= 3.391496   lambda= 2117.101
# phi= 17.6188   sv2= 0.004111458   df= 2.855163   lambda= 4285.292
# phi= 18.04142   sv2= 0.002059076   df= 2.50252   lambda= 8761.902
# phi= 18.36225   sv2= 0.0009923654   df= 2.273397   lambda= 18503.51
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_sgcQ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_sgcQ-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MD-TA_sgcQ-1_df_relative_timegrid-vs-TA_sgcQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_sgcQ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=2390.302002)
#                  est          L95%          U95%            se
# rate    1.683341e-01  1.341412e-01  2.112428e-01  1.950112e-02
# beta    3.804786e+07  1.336636e+06  1.083047e+09  6.500652e+07
# s       4.380745e-01  2.596963e-01  7.389756e-01  1.168688e-01
# lambda  1.922535e-04  8.625120e-05  4.285323e-04  7.862442e-05
#                  est        L95%       U95%       var
# lifespan  111.202719  109.699054  111.83881  0.000651
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/MD-TA_sgcQ-1_df_relative_timegrid-vs-TA_sgcQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_sgcQ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ
# Iterations: relative error in phi-hat = 1e-04
# phi= 46.33963   sv2= 0.196256   df= 14.71631   lambda= 236.1183
# phi= 48.67878   sv2= 0.01243997   df= 7.330078   lambda= 3913.094
# phi= 48.63029   sv2= 0.005570282   df= 4.181069   lambda= 8730.31
# phi= 48.91914   sv2= 0.005835382   df= 3.625693   lambda= 8383.194
# phi= 48.89262   sv2= 0.005824268   df= 3.651104   lambda= 8394.637
# phi= 48.89348   sv2= 0.005824655   df= 3.650246   lambda= 8394.227
# save file prefixed name is : TA_yajQ-1_df_relative_timegrid-vs-TA_yajQ-1_timeseries_dataframe
# biName is :  TA_yajQ-1_df_relative_timegrid-vs-TA_yajQ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# No error in flxsrv_fit
# TA_yajQ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# TA_yajQ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 46.33963   sv2= 0.196256   df= 14.71631   lambda= 236.1183
# phi= 48.67878   sv2= 0.01243997   df= 7.330078   lambda= 3913.094
# phi= 48.63029   sv2= 0.005570282   df= 4.181069   lambda= 8730.31
# phi= 48.91914   sv2= 0.005835382   df= 3.625693   lambda= 8383.194
# phi= 48.89262   sv2= 0.005824268   df= 3.651104   lambda= 8394.637
# phi= 48.89348   sv2= 0.005824655   df= 3.650246   lambda= 8394.227
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yajQ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yajQ-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MD-TA_yajQ-1_df_relative_timegrid-vs-TA_yajQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yajQ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=12686.639334)
#                   est  L95%  U95%  se
# rate         0.000240   NaN   NaN NaN
# beta    964641.755682   NaN   NaN NaN
# s       804288.517286   NaN   NaN NaN
# lambda       0.015758   NaN   NaN NaN
#                 est       L95%      U95%       var
# lifespan  37.101131  30.069778  48.05511  0.000169
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/MD-TA_yajQ-1_df_relative_timegrid-vs-TA_yajQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yajQ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.431   sv2= 0.06735429   df= 9.482235   lambda= 214.2552
# phi= 14.32763   sv2= 0.01298765   df= 4.900597   lambda= 1103.174
# phi= 14.29105   sv2= 0.005263612   df= 3.473246   lambda= 2715.065
# phi= 14.37136   sv2= 0.002816501   df= 2.853441   lambda= 5102.557
# phi= 14.43605   sv2= 0.001744519   df= 2.520916   lambda= 8275.091
# phi= 14.48291   sv2= 0.001175633   df= 2.339999   lambda= 12319.24
# save file prefixed name is : TA_ybiT-1_df_relative_timegrid-vs-TA_ybiT-1_timeseries_dataframe
# biName is :  TA_ybiT-1_df_relative_timegrid-vs-TA_ybiT-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# No error in flxsrv_fit
# TA_ybiT-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# TA_ybiT-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.431   sv2= 0.06735429   df= 9.482235   lambda= 214.2552
# phi= 14.32763   sv2= 0.01298765   df= 4.900597   lambda= 1103.174
# phi= 14.29105   sv2= 0.005263612   df= 3.473246   lambda= 2715.065
# phi= 14.37136   sv2= 0.002816501   df= 2.853441   lambda= 5102.557
# phi= 14.43605   sv2= 0.001744519   df= 2.520916   lambda= 8275.091
# phi= 14.48291   sv2= 0.001175633   df= 2.339999   lambda= 12319.24
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybiT-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ybiT-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MD-TA_ybiT-1_df_relative_timegrid-vs-TA_ybiT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ybiT-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=3529.032566)
#                  est          L95%          U95%            se
# rate    1.614594e-01  1.321776e-01  1.972282e-01  1.648460e-02
# beta    6.060949e+07  3.516937e+06  1.044520e+09  8.803569e+07
# s       8.137724e-01  4.413090e-01  1.500593e+00  2.540741e-01
# lambda  2.527322e-04  1.371185e-04  4.658274e-04  7.884935e-05
#                  est        L95%        U95%      var
# lifespan  112.236417  111.304992  112.602734  0.00045
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/MD-TA_ybiT-1_df_relative_timegrid-vs-TA_ybiT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybiT-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.07421   sv2= 0.1197329   df= 10.93733   lambda= 84.13907
# phi= 10.52908   sv2= 0.0158626   df= 6.864414   lambda= 663.7673
# phi= 10.75299   sv2= 0.005381812   df= 4.492   lambda= 1998.025
# phi= 10.91016   sv2= 0.003207974   df= 3.630411   lambda= 3400.95
# phi= 11.0059   sv2= 0.002693778   df= 3.28068   lambda= 4085.673
# phi= 11.04521   sv2= 0.002553065   df= 3.167623   lambda= 4326.256
# phi= 11.05836   sv2= 0.002511039   df= 3.133072   lambda= 4403.9
# phi= 11.06255   sv2= 0.0024981   df= 3.122399   lambda= 4428.384
# phi= 11.06386   sv2= 0.002494078   df= 3.119079   lambda= 4436.052
# phi= 11.06427   sv2= 0.002492824   df= 3.118044   lambda= 4438.449
# phi= 11.0644   sv2= 0.002492433   df= 3.117721   lambda= 4439.197
# phi= 11.06444   sv2= 0.00249231   df= 3.11762   lambda= 4439.431
# save file prefixed name is : TA_nirC-1_df_relative_timegrid-vs-TA_nirC-1_timeseries_dataframe
# biName is :  TA_nirC-1_df_relative_timegrid-vs-TA_nirC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# No error in flxsrv_fit
# TA_nirC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# TA_nirC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.07421   sv2= 0.1197329   df= 10.93733   lambda= 84.13907
# phi= 10.52908   sv2= 0.0158626   df= 6.864414   lambda= 663.7673
# phi= 10.75299   sv2= 0.005381812   df= 4.492   lambda= 1998.025
# phi= 10.91016   sv2= 0.003207974   df= 3.630411   lambda= 3400.95
# phi= 11.0059   sv2= 0.002693778   df= 3.28068   lambda= 4085.673
# phi= 11.04521   sv2= 0.002553065   df= 3.167623   lambda= 4326.256
# phi= 11.05836   sv2= 0.002511039   df= 3.133072   lambda= 4403.9
# phi= 11.06255   sv2= 0.0024981   df= 3.122399   lambda= 4428.384
# phi= 11.06386   sv2= 0.002494078   df= 3.119079   lambda= 4436.052
# phi= 11.06427   sv2= 0.002492824   df= 3.118044   lambda= 4438.449
# phi= 11.0644   sv2= 0.002492433   df= 3.117721   lambda= 4439.197
# phi= 11.06444   sv2= 0.00249231   df= 3.11762   lambda= 4439.431
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_nirC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_nirC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MD-TA_nirC-1_df_relative_timegrid-vs-TA_nirC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_nirC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=4458.007633)
#                  est           L95%          U95%            se
# rate    1.383558e-01       0.108627  1.762214e-01  1.707685e-02
# beta    3.693520e+06  270614.510941  5.041152e+07  4.925361e+06
# s       9.453526e-01       0.407046  2.195552e+00  4.064275e-01
# lambda  6.439967e-04       0.000448  9.253473e-04  1.191007e-04
#                  est        L95%       U95%      var
# lifespan  109.272034  107.326011  111.24595  0.00038
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/MD-TA_nirC-1_df_relative_timegrid-vs-TA_nirC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_nirC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.19122   sv2= 0.05378631   df= 8.940367   lambda= 393.9891
# phi= 21.95072   sv2= 0.01059104   df= 4.169194   lambda= 2072.575
# phi= 23.14918   sv2= 0.003121297   df= 2.943347   lambda= 7416.528
# phi= 23.84847   sv2= 0.000868622   df= 2.379827   lambda= 27455.52
# save file prefixed name is : TA_paaC-1_df_relative_timegrid-vs-TA_paaC-1_timeseries_dataframe
# biName is :  TA_paaC-1_df_relative_timegrid-vs-TA_paaC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# No error in flxsrv_fit
# TA_paaC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# TA_paaC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.19122   sv2= 0.05378631   df= 8.940367   lambda= 393.9891
# phi= 21.95072   sv2= 0.01059104   df= 4.169194   lambda= 2072.575
# phi= 23.14918   sv2= 0.003121297   df= 2.943347   lambda= 7416.528
# phi= 23.84847   sv2= 0.000868622   df= 2.379827   lambda= 27455.52
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_paaC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_paaC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MD-TA_paaC-1_df_relative_timegrid-vs-TA_paaC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_paaC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=2427.520618)
#                  est           L95%          U95%            se
# rate    1.761793e-01       0.132225  2.347457e-01  2.579822e-02
# beta    2.761701e+07  432810.235175  1.762203e+09  5.855883e+07
# s       3.056166e-01       0.169808  5.500408e-01  9.163381e-02
# lambda  2.097832e-04       0.000102  4.330797e-04  7.758346e-05
#                  est        L95%        U95%       var
# lifespan  110.253968  107.254362  112.202948  0.000658
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/MD-TA_paaC-1_df_relative_timegrid-vs-TA_paaC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_paaC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS 2 Github data part 3/run-MD
