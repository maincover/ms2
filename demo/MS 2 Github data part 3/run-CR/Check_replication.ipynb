# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS 2 Github data part 3'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG-WT/CR-TA_MG-WT-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG-WT/CR-TA_MG-WT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/TA_sgcQ-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/TA_yajQ-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/TA_ybiT-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/TA_nirC-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/TA_paaC-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/TA_sgcQ-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/TA_yajQ-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/TA_ybiT-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/TA_nirC-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/TA_paaC-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/TA_sgcQ-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/TA_yajQ-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/TA_ybiT-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/TA_nirC-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/TA_paaC-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ', '/home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ', '/home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT', '/home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC', '/home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC']
#
# out_name_s  ['TA_sgcQ-1_', 'TA_yajQ-1_', 'TA_ybiT-1_', 'TA_nirC-1_', 'TA_paaC-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/TA_sgcQ-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/sgcQ/TA_sgcQ-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/TA_yajQ-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/TA_yajQ-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/TA_ybiT-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/TA_ybiT-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/TA_nirC-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/TA_nirC-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/TA_paaC-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/TA_paaC-1_analysis_metadata.pickle
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 27-1.tif.mortality.tab
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 28-1.tif.mortality.tab
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 30-1.tif.mortality.tab
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 84-1.tif.mortality.tab
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 85-1.tif.mortality.tab
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 95-1.tif.mortality.tab
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 96-1.tif.mortality.tab
# MAX_07092014 Position 100-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_07092014 Position 27-1.tif.mortality.tab ------ MAX_07092014 Position 28-1.tif.mortality.tab
# MAX_07092014 Position 27-1.tif.mortality.tab ------ MAX_07092014 Position 30-1.tif.mortality.tab
# MAX_07092014 Position 27-1.tif.mortality.tab ------ MAX_07092014 Position 84-1.tif.mortality.tab
# MAX_07092014 Position 27-1.tif.mortality.tab ------ MAX_07092014 Position 85-1.tif.mortality.tab
# MAX_07092014 Position 27-1.tif.mortality.tab ------ MAX_07092014 Position 95-1.tif.mortality.tab
# MAX_07092014 Position 27-1.tif.mortality.tab ------ MAX_07092014 Position 96-1.tif.mortality.tab
# MAX_07092014 Position 27-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_07092014 Position 28-1.tif.mortality.tab ------ MAX_07092014 Position 30-1.tif.mortality.tab
# MAX_07092014 Position 28-1.tif.mortality.tab ------ MAX_07092014 Position 84-1.tif.mortality.tab
# MAX_07092014 Position 28-1.tif.mortality.tab ------ MAX_07092014 Position 85-1.tif.mortality.tab
# MAX_07092014 Position 28-1.tif.mortality.tab ------ MAX_07092014 Position 95-1.tif.mortality.tab
# MAX_07092014 Position 28-1.tif.mortality.tab ------ MAX_07092014 Position 96-1.tif.mortality.tab
# MAX_07092014 Position 28-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_07092014 Position 30-1.tif.mortality.tab ------ MAX_07092014 Position 84-1.tif.mortality.tab
# MAX_07092014 Position 30-1.tif.mortality.tab ------ MAX_07092014 Position 85-1.tif.mortality.tab
# MAX_07092014 Position 30-1.tif.mortality.tab ------ MAX_07092014 Position 95-1.tif.mortality.tab
# MAX_07092014 Position 30-1.tif.mortality.tab ------ MAX_07092014 Position 96-1.tif.mortality.tab
# MAX_07092014 Position 30-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_07092014 Position 84-1.tif.mortality.tab ------ MAX_07092014 Position 85-1.tif.mortality.tab
# MAX_07092014 Position 84-1.tif.mortality.tab ------ MAX_07092014 Position 95-1.tif.mortality.tab
# MAX_07092014 Position 84-1.tif.mortality.tab ------ MAX_07092014 Position 96-1.tif.mortality.tab
# MAX_07092014 Position 84-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_07092014 Position 85-1.tif.mortality.tab ------ MAX_07092014 Position 95-1.tif.mortality.tab
# MAX_07092014 Position 85-1.tif.mortality.tab ------ MAX_07092014 Position 96-1.tif.mortality.tab
# MAX_07092014 Position 85-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_07092014 Position 95-1.tif.mortality.tab ------ MAX_07092014 Position 96-1.tif.mortality.tab
# MAX_07092014 Position 95-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_07092014 Position 96-1.tif.mortality.tab ------ MAX_07092014 Position 98-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 107-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 108-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 109-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 110-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 111-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 112-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 113-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 106-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 108-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 109-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 110-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 111-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 112-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 113-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 107-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 109-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 110-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 111-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 112-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 113-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 108-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 110-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 111-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 112-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 113-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 109-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 111-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 112-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 113-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 110-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 112-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 113-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 111-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 113-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 112-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 114-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 113-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 115-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 114-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 116-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 115-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 118-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 116-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 120-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 118-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 127-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 120-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 128-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 127-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 142-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 128-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 142-1.tif.mortality.tab ------ MAX_05112017 Position 143-1.tif.mortality.tab
# MAX_05112017 Position 142-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 142-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 142-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 142-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 142-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 142-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 143-1.tif.mortality.tab ------ MAX_05112017 Position 144-1.tif.mortality.tab
# MAX_05112017 Position 143-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 143-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 143-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 143-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 143-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 144-1.tif.mortality.tab ------ MAX_05112017 Position 145-1.tif.mortality.tab
# MAX_05112017 Position 144-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 144-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 144-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 144-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 145-1.tif.mortality.tab ------ MAX_05112017 Position 146-1.tif.mortality.tab
# MAX_05112017 Position 145-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 145-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 145-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 146-1.tif.mortality.tab ------ MAX_05112017 Position 147-1.tif.mortality.tab
# MAX_05112017 Position 146-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 146-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 147-1.tif.mortality.tab ------ MAX_05112017 Position 148-1.tif.mortality.tab
# MAX_05112017 Position 147-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_05112017 Position 148-1.tif.mortality.tab ------ MAX_05112017 Position 150-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 38-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 40-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 45-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 46-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 47-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 48-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 50-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 36-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 40-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 45-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 46-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 47-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 48-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 50-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 38-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 45-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 46-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 47-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 48-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 50-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 40-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 46-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 47-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 48-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 50-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 45-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 46-1.tif.mortality.tab ------ MAX_07092014 Position 47-1.tif.mortality.tab
# MAX_07092014 Position 46-1.tif.mortality.tab ------ MAX_07092014 Position 48-1.tif.mortality.tab
# MAX_07092014 Position 46-1.tif.mortality.tab ------ MAX_07092014 Position 50-1.tif.mortality.tab
# MAX_07092014 Position 46-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 46-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 46-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 46-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 47-1.tif.mortality.tab ------ MAX_07092014 Position 48-1.tif.mortality.tab
# MAX_07092014 Position 47-1.tif.mortality.tab ------ MAX_07092014 Position 50-1.tif.mortality.tab
# MAX_07092014 Position 47-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 47-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 47-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 47-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 48-1.tif.mortality.tab ------ MAX_07092014 Position 50-1.tif.mortality.tab
# MAX_07092014 Position 48-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 48-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 48-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 48-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 50-1.tif.mortality.tab ------ MAX_07092014 Position 82-1.tif.mortality.tab
# MAX_07092014 Position 50-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 50-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 50-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 82-1.tif.mortality.tab ------ MAX_07092014 Position 83-1.tif.mortality.tab
# MAX_07092014 Position 82-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 82-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 83-1.tif.mortality.tab ------ MAX_07092014 Position 86-1.tif.mortality.tab
# MAX_07092014 Position 83-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 86-1.tif.mortality.tab ------ MAX_07092014 Position 87-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 33-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 34-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 35-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 37-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 39-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 42-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 43-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 29-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 34-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 35-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 37-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 39-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 42-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 43-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 33-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 35-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 37-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 39-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 42-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 43-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 34-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 37-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 39-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 42-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 43-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 35-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 37-1.tif.mortality.tab ------ MAX_07092014 Position 39-1.tif.mortality.tab
# MAX_07092014 Position 37-1.tif.mortality.tab ------ MAX_07092014 Position 42-1.tif.mortality.tab
# MAX_07092014 Position 37-1.tif.mortality.tab ------ MAX_07092014 Position 43-1.tif.mortality.tab
# MAX_07092014 Position 37-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 37-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 37-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 37-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 39-1.tif.mortality.tab ------ MAX_07092014 Position 42-1.tif.mortality.tab
# MAX_07092014 Position 39-1.tif.mortality.tab ------ MAX_07092014 Position 43-1.tif.mortality.tab
# MAX_07092014 Position 39-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 39-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 39-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 39-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 42-1.tif.mortality.tab ------ MAX_07092014 Position 43-1.tif.mortality.tab
# MAX_07092014 Position 42-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 42-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 42-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 42-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 43-1.tif.mortality.tab ------ MAX_07092014 Position 44-1.tif.mortality.tab
# MAX_07092014 Position 43-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 43-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 43-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 44-1.tif.mortality.tab ------ MAX_07092014 Position 51-1.tif.mortality.tab
# MAX_07092014 Position 44-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 44-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 51-1.tif.mortality.tab ------ MAX_07092014 Position 78-1.tif.mortality.tab
# MAX_07092014 Position 51-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 78-1.tif.mortality.tab ------ MAX_07092014 Position 81-1.tif.mortality.tab
# MAX_07092014 Position 19-1.tif.mortality.tab ------ MAX_07092014 Position 20-1.tif.mortality.tab
# MAX_07092014 Position 19-1.tif.mortality.tab ------ MAX_07092014 Position 21-1.tif.mortality.tab
# MAX_07092014 Position 19-1.tif.mortality.tab ------ MAX_07092014 Position 22-1.tif.mortality.tab
# MAX_07092014 Position 19-1.tif.mortality.tab ------ MAX_07092014 Position 25-1.tif.mortality.tab
# MAX_07092014 Position 19-1.tif.mortality.tab ------ MAX_07092014 Position 26-1.tif.mortality.tab
# MAX_07092014 Position 19-1.tif.mortality.tab ------ MAX_07092014 Position 89-1.tif.mortality.tab
# MAX_07092014 Position 19-1.tif.mortality.tab ------ MAX_07092014 Position 90-1.tif.mortality.tab
# ...
# phi= 244.6335   sv2= 0.003526681   df= 3.042017   lambda= 69366.48
# Iterations: relative error in phi-hat = 1e-04
# phi= 56.28493   sv2= 0.2654548   df= 9.253369   lambda= 212.0321
# phi= 70.03441   sv2= 0.01967721   df= 5.0537   lambda= 3559.163
# phi= 82.18845   sv2= 0.004234186   df= 3.057993   lambda= 19410.68
# Iterations: relative error in phi-hat = 1e-04
# phi= 252.9562   sv2= 0.09322297   df= 8.689591   lambda= 2713.454
# phi= 541.6478   sv2= 0.01070859   df= 2.990095   lambda= 50580.67
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in solve.default(opt$hessian) :
#   system is computationally singular: reciprocal condition number = 1.65487e-20
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 14 warnings (use warnings() to see them)
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# Error in writeGGMtoFile
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_cluster1_tabs.txt
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_mortality_dataframe_cluster2.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/yajQ/CR-TA_yajQ-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.68797   sv2= 0.2112059   df= 13.28124   lambda= 239.9931
# phi= 51.86406   sv2= 0.01802206   df= 6.676953   lambda= 2877.809
# phi= 55.00777   sv2= 0.005269869   df= 4.083849   lambda= 10438.17
# Iterations: relative error in phi-hat = 1e-04
# phi= 56.28493   sv2= 0.2654548   df= 9.253369   lambda= 212.0321
# phi= 70.03441   sv2= 0.01967721   df= 5.0537   lambda= 3559.163
# phi= 82.18845   sv2= 0.004234186   df= 3.057993   lambda= 19410.68
# Iterations: relative error in phi-hat = 1e-04
# phi= 252.9562   sv2= 0.09322297   df= 8.689591   lambda= 2713.454
# phi= 541.6478   sv2= 0.01070859   df= 2.990095   lambda= 50580.67
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est      L95%       U95%       var
# lifespan  15.100216  12.09058  17.221709  0.000233, 1:                est       L95%        U95%       var
# lifespan  72.54064  67.658749  109.539301  0.001241, 2:                  est      L95%        U95%       var
# lifespan  105.624091  98.62805  112.632708  0.001669}
# [['MAX_07092014 Position 45-1.tif.mortality.tab', 'MAX_07092014 Position 46-1.tif.mortality.tab', 'MAX_07092014 Position 83-1.tif.mortality.tab', 'MAX_07092014 Position 86-1.tif.mortality.tab'], ['MAX_07092014 Position 36-1.tif.mortality.tab', 'MAX_07092014 Position 38-1.tif.mortality.tab', 'MAX_07092014 Position 40-1.tif.mortality.tab', 'MAX_07092014 Position 47-1.tif.mortality.tab', 'MAX_07092014 Position 48-1.tif.mortality.tab', 'MAX_07092014 Position 50-1.tif.mortality.tab', 'MAX_07092014 Position 82-1.tif.mortality.tab', 'MAX_07092014 Position 87-1.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.73214   sv2= 0.07496263   df= 8.555705   lambda= 196.5264
# phi= 14.74085   sv2= 0.01808581   df= 4.560176   lambda= 815.0505
# phi= 14.99011   sv2= 0.007203554   df= 3.380098   lambda= 2080.933
# phi= 15.19182   sv2= 0.003972695   df= 2.739905   lambda= 3824.058
# phi= 15.33617   sv2= 0.002626697   df= 2.436741   lambda= 5838.575
# phi= 15.44585   sv2= 0.001907802   df= 2.292374   lambda= 8096.148
# phi= 15.53037   sv2= 0.001462436   df= 2.212387   lambda= 10619.52
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.60598   sv2= 0.03259268   df= 8.223752   lambda= 1368.589
# phi= 43.14744   sv2= 0.001519639   df= 3.047365   lambda= 28393.23
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/ybiT/CR-TA_ybiT-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.431   sv2= 0.06735429   df= 9.482235   lambda= 214.2552
# phi= 14.32763   sv2= 0.01298765   df= 4.900597   lambda= 1103.174
# phi= 14.29105   sv2= 0.005263612   df= 3.473246   lambda= 2715.065
# phi= 14.37136   sv2= 0.002816501   df= 2.853441   lambda= 5102.557
# phi= 14.43605   sv2= 0.001744519   df= 2.520916   lambda= 8275.091
# phi= 14.48291   sv2= 0.001175633   df= 2.339999   lambda= 12319.24
# No error in flxsrv_fit
# {0:                  est        L95%        U95%      var
# lifespan  112.236417  111.304992  112.602734  0.00045}
# [['MAX_07092014 Position 37-1.tif.mortality.tab', 'MAX_07092014 Position 51-1.tif.mortality.tab', 'MAX_07092014 Position 81-1.tif.mortality.tab'], ['MAX_07092014 Position 42-1.tif.mortality.tab', 'MAX_07092014 Position 78-1.tif.mortality.tab'], ['MAX_07092014 Position 29-1.tif.mortality.tab', 'MAX_07092014 Position 33-1.tif.mortality.tab', 'MAX_07092014 Position 34-1.tif.mortality.tab', 'MAX_07092014 Position 35-1.tif.mortality.tab', 'MAX_07092014 Position 39-1.tif.mortality.tab', 'MAX_07092014 Position 43-1.tif.mortality.tab', 'MAX_07092014 Position 44-1.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 13.86855   sv2= 0.07769729   df= 9.491626   lambda= 178.4946
# phi= 14.46673   sv2= 0.01678311   df= 5.170591   lambda= 861.9811
# phi= 14.88516   sv2= 0.007804165   df= 3.815659   lambda= 1907.336
# phi= 15.11483   sv2= 0.005625945   df= 3.282946   lambda= 2686.631
# phi= 15.24725   sv2= 0.004972614   df= 3.069613   lambda= 3066.245
# phi= 15.31002   sv2= 0.004743938   df= 2.989247   lambda= 3227.28
# phi= 15.33661   sv2= 0.004657725   df= 2.958439   lambda= 3292.726
# phi= 15.34743   sv2= 0.004624212   df= 2.946409   lambda= 3318.929
# phi= 15.35176   sv2= 0.004611024   df= 2.941668   lambda= 3329.361
# phi= 15.35349   sv2= 0.004605809   df= 2.939793   lambda= 3333.505
# phi= 15.35417   sv2= 0.004603742   df= 2.939049   lambda= 3335.15
# phi= 15.35444   sv2= 0.004602923   df= 2.938754   lambda= 3335.802
# phi= 15.35455   sv2= 0.004602598   df= 2.938638   lambda= 3336.061
# Iterations: relative error in phi-hat = 1e-04
# phi= 2.713744   sv2= 0.03953855   df= 8.736069   lambda= 68.6354
# phi= 2.815411   sv2= 0.003765657   df= 5.758733   lambda= 747.6545
# phi= 2.940021   sv2= 0.0007735471   df= 3.56747   lambda= 3800.701
# phi= 3.194316   sv2= 0.0004737343   df= 2.659263   lambda= 6742.844
# phi= 3.323084   sv2= 0.0003553854   df= 2.434192   lambda= 9350.65
# phi= 3.394624   sv2= 0.0002901124   df= 2.33303   lambda= 11701.06
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/nirC/CR-TA_nirC-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.07421   sv2= 0.1197329   df= 10.93733   lambda= 84.13907
# phi= 10.52908   sv2= 0.0158626   df= 6.864414   lambda= 663.7673
# phi= 10.75299   sv2= 0.005381812   df= 4.492   lambda= 1998.025
# phi= 10.91016   sv2= 0.003207974   df= 3.630411   lambda= 3400.95
# phi= 11.0059   sv2= 0.002693778   df= 3.28068   lambda= 4085.673
# phi= 11.04521   sv2= 0.002553065   df= 3.167623   lambda= 4326.256
# phi= 11.05836   sv2= 0.002511039   df= 3.133072   lambda= 4403.9
# phi= 11.06255   sv2= 0.0024981   df= 3.122399   lambda= 4428.384
# phi= 11.06386   sv2= 0.002494078   df= 3.119079   lambda= 4436.052
# phi= 11.06427   sv2= 0.002492824   df= 3.118044   lambda= 4438.449
# phi= 11.0644   sv2= 0.002492433   df= 3.117721   lambda= 4439.197
# phi= 11.06444   sv2= 0.00249231   df= 3.11762   lambda= 4439.431
# No error in flxsrv_fit
# {0:                  est        L95%       U95%      var
# lifespan  109.272034  107.326011  111.24595  0.00038}
# [['MAX_07092014 Position 20-1.tif.mortality.tab', 'MAX_07092014 Position 91-1.tif.mortality.tab', 'MAX_07092014 Position 94-1.tif.mortality.tab'], ['MAX_07092014 Position 19-1.tif.mortality.tab', 'MAX_07092014 Position 22-1.tif.mortality.tab', 'MAX_07092014 Position 25-1.tif.mortality.tab', 'MAX_07092014 Position 26-1.tif.mortality.tab', 'MAX_07092014 Position 89-1.tif.mortality.tab', 'MAX_07092014 Position 90-1.tif.mortality.tab'], ['MAX_07092014 Position 21-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_colomap_all_files_cluster0.png
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.887976   sv2= 0.06056337   df= 8.137758   lambda= 64.19683
# phi= 3.981922   sv2= 0.02670535   df= 5.609873   lambda= 149.1058
# phi= 4.072376   sv2= 0.01743259   df= 4.738093   lambda= 233.6071
# phi= 4.137664   sv2= 0.01379413   df= 4.339756   lambda= 299.9583
# phi= 4.181615   sv2= 0.01200303   df= 4.133782   lambda= 348.3798
# phi= 4.211152   sv2= 0.01099221   df= 4.01482   lambda= 383.1032
# phi= 4.231295   sv2= 0.01037245   df= 3.940726   lambda= 407.9359
# phi= 4.245236   sv2= 0.009972028   df= 3.892297   lambda= 425.7144
# phi= 4.254997   sv2= 0.009704281   df= 3.859635   lambda= 438.4659
# phi= 4.261891   sv2= 0.009521059   df= 3.837143   lambda= 447.6278
# phi= 4.266791   sv2= 0.009393667   df= 3.821433   lambda= 454.2199
# phi= 4.270289   sv2= 0.009304107   df= 3.810351   lambda= 458.9682
# phi= 4.272795   sv2= 0.009240649   df= 3.80248   lambda= 462.3913
# phi= 4.274595   sv2= 0.009195436   df= 3.796862   lambda= 464.8605
# phi= 4.27589   sv2= 0.009163096   df= 3.792838   lambda= 466.6425
# phi= 4.276822   sv2= 0.009139897   df= 3.789949   lambda= 467.9289
# phi= 4.277494   sv2= 0.009123223   df= 3.787871   lambda= 468.8578
# phi= 4.277979   sv2= 0.00911122   df= 3.786375   lambda= 469.5287
# phi= 4.278329   sv2= 0.009102571   df= 3.785296   lambda= 470.0133
# phi= 4.278582   sv2= 0.009096333   df= 3.784518   lambda= 470.3633
# phi= 4.278764   sv2= 0.009091833   df= 3.783956   lambda= 470.6162
# phi= 4.278896   sv2= 0.009088585   df= 3.783551   lambda= 470.7989
# phi= 4.278991   sv2= 0.00908624   df= 3.783258   lambda= 470.9309
# phi= 4.27906   sv2= 0.009084546   df= 3.783047   lambda= 471.0263
# phi= 4.279109   sv2= 0.009083323   df= 3.782894   lambda= 471.0952
# phi= 4.279145   sv2= 0.009082439   df= 3.782784   lambda= 471.145
# phi= 4.279171   sv2= 0.009081801   df= 3.782704   lambda= 471.1809
# Iterations: relative error in phi-hat = 1e-04
# phi= 20.3461   sv2= 0.06163089   df= 6.162584   lambda= 330.1282
# phi= 21.50253   sv2= 0.01054307   df= 3.102732   lambda= 2039.494
# phi= 23.80589   sv2= 0.003408903   df= 2.447202   lambda= 6983.448
# phi= 25.02882   sv2= 0.001142781   df= 2.191616   lambda= 21901.67
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 3/paaC/CR-TA_paaC-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.07756   sv2= 0.06550163   df= 8.102176   lambda= 367.5872
# phi= 24.96279   sv2= 0.01408944   df= 3.841514   lambda= 1771.737
# phi= 26.3718   sv2= 0.00493843   df= 2.757557   lambda= 5340.118
# phi= 27.39916   sv2= 0.002015964   df= 2.367407   lambda= 13591.1
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  110.253968  107.228043  112.202948  0.000733}
