# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/TA_yagL-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/TA_yagL-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/TA_yagL-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL']
#
# out_name_s  ['TA_yagL-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/TA_yagL-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/TA_yagL-1_analysis_metadata.pickle
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 10-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 163-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 174-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 179-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 2-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 25-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 6-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 1-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 163-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 174-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 179-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 2-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 25-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 6-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 10-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 163-1.tif.mortality.tab ------ MAX_12072015 Position 174-1.tif.mortality.tab
# MAX_12072015 Position 163-1.tif.mortality.tab ------ MAX_12072015 Position 179-1.tif.mortality.tab
# MAX_12072015 Position 163-1.tif.mortality.tab ------ MAX_12072015 Position 2-1.tif.mortality.tab
# MAX_12072015 Position 163-1.tif.mortality.tab ------ MAX_12072015 Position 25-1.tif.mortality.tab
# MAX_12072015 Position 163-1.tif.mortality.tab ------ MAX_12072015 Position 6-1.tif.mortality.tab
# MAX_12072015 Position 163-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 163-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 174-1.tif.mortality.tab ------ MAX_12072015 Position 179-1.tif.mortality.tab
# MAX_12072015 Position 174-1.tif.mortality.tab ------ MAX_12072015 Position 2-1.tif.mortality.tab
# MAX_12072015 Position 174-1.tif.mortality.tab ------ MAX_12072015 Position 25-1.tif.mortality.tab
# MAX_12072015 Position 174-1.tif.mortality.tab ------ MAX_12072015 Position 6-1.tif.mortality.tab
# MAX_12072015 Position 174-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 174-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 179-1.tif.mortality.tab ------ MAX_12072015 Position 2-1.tif.mortality.tab
# MAX_12072015 Position 179-1.tif.mortality.tab ------ MAX_12072015 Position 25-1.tif.mortality.tab
# MAX_12072015 Position 179-1.tif.mortality.tab ------ MAX_12072015 Position 6-1.tif.mortality.tab
# MAX_12072015 Position 179-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 179-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 2-1.tif.mortality.tab ------ MAX_12072015 Position 25-1.tif.mortality.tab
# MAX_12072015 Position 2-1.tif.mortality.tab ------ MAX_12072015 Position 6-1.tif.mortality.tab
# MAX_12072015 Position 2-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 2-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 25-1.tif.mortality.tab ------ MAX_12072015 Position 6-1.tif.mortality.tab
# MAX_12072015 Position 25-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 25-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 6-1.tif.mortality.tab ------ MAX_12072015 Position 98-1.tif.mortality.tab
# MAX_12072015 Position 6-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# MAX_12072015 Position 98-1.tif.mortality.tab ------ MAX_12072015 Position 99-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_dentrogram-all-files.eps
# [['MAX_12072015 Position 163-1.tif.mortality.tab', 'MAX_12072015 Position 179-1.tif.mortality.tab'], ['MAX_12072015 Position 174-1.tif.mortality.tab', 'MAX_12072015 Position 2-1.tif.mortality.tab', 'MAX_12072015 Position 6-1.tif.mortality.tab', 'MAX_12072015 Position 98-1.tif.mortality.tab'], ['MAX_12072015 Position 1-1.tif.mortality.tab', 'MAX_12072015 Position 10-1.tif.mortality.tab', 'MAX_12072015 Position 25-1.tif.mortality.tab'], ['MAX_12072015 Position 99-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.56829   sv2= 0.1496387   df= 13.28237   lambda= 70.62539
# phi= 11.33968   sv2= 0.03648896   df= 8.610497   lambda= 310.7703
# phi= 12.01548   sv2= 0.01073204   df= 6.241838   lambda= 1119.59
# phi= 12.49159   sv2= 0.002552664   df= 4.783376   lambda= 4893.551
# phi= 12.80885   sv2= 0.0003931584   df= 3.594412   lambda= 32579.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.71882   sv2= 0.1087142   df= 10.31086   lambda= 135.39
# phi= 16.33352   sv2= 0.01424554   df= 5.922961   lambda= 1146.571
# phi= 17.34464   sv2= 0.004516222   df= 3.865871   lambda= 3840.52
# phi= 18.00722   sv2= 0.001903354   df= 3.044624   lambda= 9460.783
# phi= 18.46485   sv2= 0.0008650069   df= 2.566753   lambda= 21346.47
# Iterations: relative error in phi-hat = 1e-04
# phi= 5.955478   sv2= 0.09247914   df= 10.44543   lambda= 64.39806
# phi= 6.52452   sv2= 0.01279361   df= 6.917769   lambda= 509.9828
# phi= 6.816871   sv2= 0.0006633388   df= 4.486819   lambda= 10276.6
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_mortality_dataframe_cluster2.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagL/CR-TA_yagL-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.56829   sv2= 0.1496387   df= 13.28237   lambda= 70.62539
# phi= 11.33968   sv2= 0.03648896   df= 8.610497   lambda= 310.7703
# phi= 12.01548   sv2= 0.01073204   df= 6.241838   lambda= 1119.59
# phi= 12.49159   sv2= 0.002552664   df= 4.783376   lambda= 4893.551
# phi= 12.80885   sv2= 0.0003931584   df= 3.594412   lambda= 32579.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.455522   sv2= 0.08015401   df= 11.79209   lambda= 43.11103
# phi= 3.614218   sv2= 0.0226299   df= 8.513596   lambda= 159.7099
# phi= 3.737371   sv2= 0.006055181   df= 6.404824   lambda= 617.2188
# phi= 3.82431   sv2= 0.001696398   df= 4.823746   lambda= 2254.371
# phi= 3.8851   sv2= 0.0006339507   df= 3.724511   lambda= 6128.395
# phi= 3.928136   sv2= 0.0002501862   df= 3.084465   lambda= 15700.85
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.71882   sv2= 0.1087142   df= 10.31086   lambda= 135.39
# phi= 16.33352   sv2= 0.01424554   df= 5.922961   lambda= 1146.571
# phi= 17.34464   sv2= 0.004516222   df= 3.865871   lambda= 3840.52
# phi= 18.00722   sv2= 0.001903354   df= 3.044624   lambda= 9460.783
# phi= 18.46485   sv2= 0.0008650069   df= 2.566753   lambda= 21346.47
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  101.760912  100.276478  103.134359  0.000263, 1:                  est        L95%        U95%       var
# lifespan  115.837425  113.084237  119.096797  0.000326, 2:                 est        L95%        U95%       var
# lifespan  123.93938  122.368952  125.318349  0.000416}
