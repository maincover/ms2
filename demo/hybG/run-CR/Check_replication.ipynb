# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/TA_hybG-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/TA_hybG-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/TA_hybG-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG']
#
# out_name_s  ['TA_hybG-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/TA_hybG-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/TA_hybG-1_analysis_metadata.pickle
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 117-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 118-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 119-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 120-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 125-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 19-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 40-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 116-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 118-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 119-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 120-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 125-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 19-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 40-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 117-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 118-1.tif.mortality.tab ------ MAX_07042016 Position 119-1.tif.mortality.tab
# MAX_07042016 Position 118-1.tif.mortality.tab ------ MAX_07042016 Position 120-1.tif.mortality.tab
# MAX_07042016 Position 118-1.tif.mortality.tab ------ MAX_07042016 Position 125-1.tif.mortality.tab
# MAX_07042016 Position 118-1.tif.mortality.tab ------ MAX_07042016 Position 19-1.tif.mortality.tab
# MAX_07042016 Position 118-1.tif.mortality.tab ------ MAX_07042016 Position 40-1.tif.mortality.tab
# MAX_07042016 Position 118-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 118-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 119-1.tif.mortality.tab ------ MAX_07042016 Position 120-1.tif.mortality.tab
# MAX_07042016 Position 119-1.tif.mortality.tab ------ MAX_07042016 Position 125-1.tif.mortality.tab
# MAX_07042016 Position 119-1.tif.mortality.tab ------ MAX_07042016 Position 19-1.tif.mortality.tab
# MAX_07042016 Position 119-1.tif.mortality.tab ------ MAX_07042016 Position 40-1.tif.mortality.tab
# MAX_07042016 Position 119-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 119-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 120-1.tif.mortality.tab ------ MAX_07042016 Position 125-1.tif.mortality.tab
# MAX_07042016 Position 120-1.tif.mortality.tab ------ MAX_07042016 Position 19-1.tif.mortality.tab
# MAX_07042016 Position 120-1.tif.mortality.tab ------ MAX_07042016 Position 40-1.tif.mortality.tab
# MAX_07042016 Position 120-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 120-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 125-1.tif.mortality.tab ------ MAX_07042016 Position 19-1.tif.mortality.tab
# MAX_07042016 Position 125-1.tif.mortality.tab ------ MAX_07042016 Position 40-1.tif.mortality.tab
# MAX_07042016 Position 125-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 125-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 19-1.tif.mortality.tab ------ MAX_07042016 Position 40-1.tif.mortality.tab
# MAX_07042016 Position 19-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 19-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 40-1.tif.mortality.tab ------ MAX_07042016 Position 60-1.tif.mortality.tab
# MAX_07042016 Position 40-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# MAX_07042016 Position 60-1.tif.mortality.tab ------ MAX_07042016 Position 84-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_dentrogram-all-files.eps
# [['MAX_07042016 Position 118-1.tif.mortality.tab', 'MAX_07042016 Position 84-1.tif.mortality.tab'], ['MAX_07042016 Position 117-1.tif.mortality.tab', 'MAX_07042016 Position 119-1.tif.mortality.tab', 'MAX_07042016 Position 120-1.tif.mortality.tab', 'MAX_07042016 Position 125-1.tif.mortality.tab'], ['MAX_07042016 Position 116-1.tif.mortality.tab', 'MAX_07042016 Position 40-1.tif.mortality.tab'], ['MAX_07042016 Position 60-1.tif.mortality.tab'], ['MAX_07042016 Position 19-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.860179   sv2= 0.8377987   df= 10.52203   lambda= 10.57555
# phi= 8.914669   sv2= 0.7926626   df= 10.40635   lambda= 11.24649
# phi= 8.973295   sv2= 0.7454782   df= 10.28045   lambda= 12.03696
# phi= 9.036525   sv2= 0.6962122   df= 10.14297   lambda= 12.97956
# phi= 9.104914   sv2= 0.6448627   df= 9.99229   lambda= 14.11915
# phi= 9.179124   sv2= 0.5914731   df= 9.826477   lambda= 15.51909
# phi= 9.259968   sv2= 0.536151   df= 9.643207   lambda= 17.27119
# phi= 9.348456   sv2= 0.4790956   df= 9.439654   lambda= 19.51271
# phi= 9.445866   sv2= 0.4206394   df= 9.212355   lambda= 22.45597
# phi= 9.553805   sv2= 0.3613078   df= 8.95705   lambda= 26.44228
# phi= 9.674245   sv2= 0.3019088   df= 8.668529   lambda= 32.0436
# phi= 9.809395   sv2= 0.2436522   df= 8.340595   lambda= 40.25983
# phi= 9.961146   sv2= 0.1882839   df= 7.966416   lambda= 52.90493
# phi= 10.12955   sv2= 0.138146   df= 7.539996   lambda= 73.32495
# phi= 10.30991   sv2= 0.09594223   df= 7.060149   lambda= 107.4595
# phi= 10.48973   sv2= 0.06389016   df= 6.538569   lambda= 164.1837
# phi= 10.65139   sv2= 0.04237148   df= 6.009679   lambda= 251.381
# phi= 10.7841   sv2= 0.02938566   df= 5.528127   lambda= 366.9852
# phi= 10.88984   sv2= 0.02192381   df= 5.139431   lambda= 496.7126
# phi= 10.97364   sv2= 0.01762544   df= 4.852815   lambda= 622.6025
# phi= 11.0381   sv2= 0.01510406   df= 4.652016   lambda= 730.8032
# phi= 11.08526   sv2= 0.01360479   df= 4.515972   lambda= 814.8054
# phi= 11.11803   sv2= 0.01270745   df= 4.426474   lambda= 874.9228
# phi= 11.13981   sv2= 0.01216912   df= 4.369136   lambda= 915.4162
# phi= 11.15379   sv2= 0.01184603   df= 4.333181   lambda= 941.564
# phi= 11.16255   sv2= 0.01165213   df= 4.310987   lambda= 957.9837
# phi= 11.16795   sv2= 0.0115358   df= 4.297434   lambda= 968.1126
# phi= 11.17125   sv2= 0.01146601   df= 4.289214   lambda= 974.292
# phi= 11.17324   sv2= 0.01142416   df= 4.284252   lambda= 978.0362
# phi= 11.17444   sv2= 0.01139906   df= 4.281263   lambda= 980.2956
# phi= 11.17517   sv2= 0.011384   df= 4.279467   lambda= 981.6555
# phi= 11.1756   sv2= 0.01137497   df= 4.278388   lambda= 982.4729
# phi= 11.17587   sv2= 0.01136956   df= 4.277741   lambda= 982.9636
# phi= 11.17602   sv2= 0.01136632   df= 4.277352   lambda= 983.2582
# phi= 11.17612   sv2= 0.01136437   df= 4.277119   lambda= 983.4349
# phi= 11.17617   sv2= 0.0113632   df= 4.276979   lambda= 983.5409
# phi= 11.17621   sv2= 0.0113625   df= 4.276895   lambda= 983.6044
# Iterations: relative error in phi-hat = 1e-04
# phi= 105.5437   sv2= 0.1154072   df= 9.357959   lambda= 914.5335
# phi= 183.7102   sv2= 0.004220532   df= 3.810817   lambda= 43527.73
# Iterations: relative error in phi-hat = 1e-04
# phi= 2.489683   sv2= 0.1456589   df= 8.56837   lambda= 17.09256
# phi= 2.606802   sv2= 0.08099165   df= 7.727943   lambda= 32.18606
# phi= 2.728386   sv2= 0.04058234   df= 6.832842   lambda= 67.23086
# phi= 2.841036   sv2= 0.02044955   df= 5.917354   lambda= 138.929
# phi= 2.926344   sv2= 0.013669   df= 5.141539   lambda= 214.0862
# phi= 2.970731   sv2= 0.01238778   df= 4.735069   lambda= 239.8114
# phi= 2.982264   sv2= 0.01224286   df= 4.634953   lambda= 243.5921
# phi= 2.983863   sv2= 0.01222771   df= 4.621361   lambda= 244.0246
# phi= 2.984044   sv2= 0.01222607   df= 4.619823   lambda= 244.0723
# phi= 2.984064   sv2= 0.01222589   df= 4.619653   lambda= 244.0775
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hybG/CR-TA_hybG-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.34785   sv2= 0.4996372   df= 12.57694   lambda= 96.76591
# phi= 60.46956   sv2= 0.0475499   df= 7.76078   lambda= 1271.707
# phi= 56.12635   sv2= 0.008687679   df= 4.603422   lambda= 6460.454
# phi= 52.52971   sv2= 0.005671425   df= 3.410887   lambda= 9262.172
# phi= 52.62583   sv2= 0.00538206   df= 3.19214   lambda= 9778.01
# phi= 52.68957   sv2= 0.005336121   df= 3.160005   lambda= 9874.133
# phi= 52.70268   sv2= 0.005327702   df= 3.154223   lambda= 9892.198
# phi= 52.70518   sv2= 0.005326124   df= 3.153144   lambda= 9895.599
# phi= 52.70566   sv2= 0.005325827   df= 3.152941   lambda= 9896.239
# No error in flxsrv_fit
# {0:                  est       L95%      U95%       var
# lifespan  114.249435  113.19751  115.2505  0.000197}
