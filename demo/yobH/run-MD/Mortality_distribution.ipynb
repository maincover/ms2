# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yobH'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yobH/TA_yobH-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yobH/TA_yobH-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yobH
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.33449   sv2= 0.3444321   df= 15.8445   lambda= 108.3943
# phi= 41.13532   sv2= 0.02706107   df= 9.373733   lambda= 1520.092
# phi= 42.20856   sv2= 0.005259092   df= 5.339075   lambda= 8025.826
# phi= 43.29227   sv2= 0.002689623   df= 3.844437   lambda= 16096.04
# save file prefixed name is : TA_yobH-1_df_relative_timegrid-vs-TA_yobH-1_timeseries_dataframe
# biName is :  TA_yobH-1_df_relative_timegrid-vs-TA_yobH-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yobH/run-MD
# No error in flxsrv_fit
# TA_yobH-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yobH/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yobH/run-MD
# TA_yobH-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.33449   sv2= 0.3444321   df= 15.8445   lambda= 108.3943
# phi= 41.13532   sv2= 0.02706107   df= 9.373733   lambda= 1520.092
# phi= 42.20856   sv2= 0.005259092   df= 5.339075   lambda= 8025.826
# phi= 43.29227   sv2= 0.002689623   df= 3.844437   lambda= 16096.04
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yobH/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yobH-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yobH-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yobH/MD-TA_yobH-1_df_relative_timegrid-vs-TA_yobH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yobH-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=18502.607517)
#                  est       L95%          U95%            se
# rate    8.074069e-02   0.075494  8.635249e-02  2.768096e-03
# beta    9.820155e+06  50.751599  1.900146e+12  6.099132e+07
# s       1.358748e+03   0.006906  2.673277e+08  8.450506e+03
# lambda  1.795328e-03   0.001531  2.104828e-03  1.456863e-04
#                  est        L95%        U95%       var
# lifespan  101.681594  100.669441  102.681567  0.000108
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yobH/MD-TA_yobH-1_df_relative_timegrid-vs-TA_yobH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yobH-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yobH/run-MD
