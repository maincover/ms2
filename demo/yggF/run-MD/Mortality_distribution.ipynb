# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggF'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggF/TA_yggF-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggF/TA_yggF-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggF
# Iterations: relative error in phi-hat = 1e-04
# phi= 89.7129   sv2= 0.3449993   df= 16.54103   lambda= 260.0379
# phi= 94.6104   sv2= 0.02688604   df= 8.196836   lambda= 3518.941
# phi= 98.24152   sv2= 0.01042822   df= 4.775169   lambda= 9420.739
# phi= 100.9816   sv2= 0.007128903   df= 3.954624   lambda= 14165.09
# save file prefixed name is : TA_yggF-1_df_relative_timegrid-vs-TA_yggF-1_timeseries_dataframe
# biName is :  TA_yggF-1_df_relative_timegrid-vs-TA_yggF-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yggF/run-MD
# No error in flxsrv_fit
# TA_yggF-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yggF/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yggF/run-MD
# TA_yggF-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 89.7129   sv2= 0.3449993   df= 16.54103   lambda= 260.0379
# phi= 94.6104   sv2= 0.02688604   df= 8.196836   lambda= 3518.941
# phi= 98.24152   sv2= 0.01042822   df= 4.775169   lambda= 9420.739
# phi= 100.9816   sv2= 0.007128903   df= 3.954624   lambda= 14165.09
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yggF/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yggF-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yggF-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggF/MD-TA_yggF-1_df_relative_timegrid-vs-TA_yggF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yggF-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=31005.648854)
#                   est           L95%           U95%             se
# rate         0.122676       0.115203       0.130634       0.003934
# beta    423635.970501  223624.213440  802540.264946  138096.516939
# s            0.922818       0.786422       1.082869       0.075304
# lambda       0.000774       0.000667       0.000899       0.000059
#                  est        L95%        U95%       var
# lifespan  105.523599  104.524086  106.503724  0.000063
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggF/MD-TA_yggF-1_df_relative_timegrid-vs-TA_yggF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yggF-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yggF/run-MD
