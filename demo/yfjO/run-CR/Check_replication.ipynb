# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/TA_yfjO-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/TA_yfjO-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/TA_yfjO-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO']
#
# out_name_s  ['TA_yfjO-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/TA_yfjO-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/TA_yfjO-1_analysis_metadata.pickle
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 180-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 186-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 190-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 192-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 193-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 195-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 196-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 179-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 186-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 190-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 192-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 193-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 195-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 196-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 180-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 190-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 192-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 193-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 195-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 196-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 186-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 190-1.tif.mortality.tab ------ MAX_11102018 Position 192-1.tif.mortality.tab
# MAX_11102018 Position 190-1.tif.mortality.tab ------ MAX_11102018 Position 193-1.tif.mortality.tab
# MAX_11102018 Position 190-1.tif.mortality.tab ------ MAX_11102018 Position 195-1.tif.mortality.tab
# MAX_11102018 Position 190-1.tif.mortality.tab ------ MAX_11102018 Position 196-1.tif.mortality.tab
# MAX_11102018 Position 190-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 190-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 190-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 192-1.tif.mortality.tab ------ MAX_11102018 Position 193-1.tif.mortality.tab
# MAX_11102018 Position 192-1.tif.mortality.tab ------ MAX_11102018 Position 195-1.tif.mortality.tab
# MAX_11102018 Position 192-1.tif.mortality.tab ------ MAX_11102018 Position 196-1.tif.mortality.tab
# MAX_11102018 Position 192-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 192-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 192-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 193-1.tif.mortality.tab ------ MAX_11102018 Position 195-1.tif.mortality.tab
# MAX_11102018 Position 193-1.tif.mortality.tab ------ MAX_11102018 Position 196-1.tif.mortality.tab
# MAX_11102018 Position 193-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 193-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 193-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 195-1.tif.mortality.tab ------ MAX_11102018 Position 196-1.tif.mortality.tab
# MAX_11102018 Position 195-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 195-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 195-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 196-1.tif.mortality.tab ------ MAX_11102018 Position 197-1.tif.mortality.tab
# MAX_11102018 Position 196-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 196-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 197-1.tif.mortality.tab ------ MAX_11102018 Position 198-1.tif.mortality.tab
# MAX_11102018 Position 197-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# MAX_11102018 Position 198-1.tif.mortality.tab ------ MAX_11102018 Position 204-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_dentrogram-all-files.eps
# [['MAX_11102018 Position 192-1.tif.mortality.tab', 'MAX_11102018 Position 193-1.tif.mortality.tab', 'MAX_11102018 Position 195-1.tif.mortality.tab', 'MAX_11102018 Position 196-1.tif.mortality.tab', 'MAX_11102018 Position 197-1.tif.mortality.tab'], ['MAX_11102018 Position 179-1.tif.mortality.tab', 'MAX_11102018 Position 180-1.tif.mortality.tab', 'MAX_11102018 Position 186-1.tif.mortality.tab', 'MAX_11102018 Position 198-1.tif.mortality.tab'], ['MAX_11102018 Position 204-1.tif.mortality.tab'], ['MAX_11102018 Position 190-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 167.9426   sv2= 0.1955224   df= 10.71258   lambda= 858.9427
# phi= 181.5507   sv2= 0.004840454   df= 4.240023   lambda= 37506.95
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.45664   sv2= 0.1371213   df= 11.24863   lambda= 433.606
# phi= 65.52289   sv2= 0.007187053   df= 4.929685   lambda= 9116.794
# phi= 67.67369   sv2= 0.0005618866   df= 2.813274   lambda= 120440.1
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfjO/CR-TA_yfjO-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 76.32022   sv2= 0.2753142   df= 13.17338   lambda= 277.2113
# phi= 81.14751   sv2= 0.01602284   df= 6.385395   lambda= 5064.491
# phi= 84.26148   sv2= 0.001823769   df= 3.552793   lambda= 46201.83
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  129.159284  127.961339  130.298187  0.000144}
