# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/app/src/ms2/dataset/MS 2 Github data part 10/ydjK'
ref_df_path = '/app/src/ms2/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/app/src/ms2/dataset/MS 2 Github data part 10/ydjK/TA_ydjK-1_df_relative_timegrid.pickle']]
# []
# [['/app/src/ms2/dataset/MS 2 Github data part 10/ydjK/TA_ydjK-1_timeseries_dataframe.pickle']]
# /app/src/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /app/src/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.32831027777777
# files will be written into :  /app/src/ms2/dataset/MS 2 Github data part 10/ydjK
# Iterations: relative error in phi-hat = 1e-04
# phi= 123.0502   sv2= 0.3178329   df= 14.68213   lambda= 387.1537
# phi= 124.863   sv2= 0.02904349   df= 6.853909   lambda= 4299.173
# phi= 125.0227   sv2= 0.01333857   df= 4.038068   lambda= 9373.023
# phi= 126.6349   sv2= 0.009243719   df= 3.390453   lambda= 13699.56
# save file prefixed name is : TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe
# biName is :  TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe
# getGGMfit_dict--(1) /app/src/ms2/demo/ydjK/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ydjK-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /app/src/ms2/demo/ydjK/run-MD
# getKMNABSfits_dict-- /app/src/ms2/demo/ydjK/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ydjK-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 123.0502   sv2= 0.3178329   df= 14.68213   lambda= 387.1537
# phi= 124.863   sv2= 0.02904349   df= 6.853909   lambda= 4299.173
# phi= 125.0227   sv2= 0.01333857   df= 4.038068   lambda= 9373.023
# phi= 126.6349   sv2= 0.009243719   df= 3.390453   lambda= 13699.56
# getKMNABSfits_dict-- /app/src/ms2/demo/ydjK/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydjK-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ydjK-1_df_relative_timegrid.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/ydjK/MD-TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ydjK-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=41646.783656)
#                  est          L95%          U95%            se
# rate    1.835058e-01  1.734806e-01  1.941103e-01  5.260008e-03
# beta    1.204596e+07  5.595028e+06  2.593464e+07  4.713070e+06
# s       4.386276e-01  3.869660e-01  4.971864e-01  2.804452e-02
# lambda  1.038712e-04  7.540681e-05  1.430803e-04  1.697236e-05
#                 est       L95%       U95%       var
# lifespan  96.789231  95.701516  96.842693  0.000035
#
#
# /app/src/ms2/dataset/MS 2 Github data part 10/ydjK/MD-TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydjK-1_df_relative_timegrid.pickle
# working directory is :  /app/src/ms2/demo/ydjK/run-MD
