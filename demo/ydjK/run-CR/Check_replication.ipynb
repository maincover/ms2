# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/TA_ydjK-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/TA_ydjK-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/TA_ydjK-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK']
#
# out_name_s  ['TA_ydjK-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/TA_ydjK-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/TA_ydjK-1_analysis_metadata.pickle
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 27-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 39-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 42-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 70-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 71-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 74-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 76-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 1-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 39-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 42-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 70-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 71-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 74-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 76-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 27-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 42-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 70-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 71-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 74-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 76-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 39-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 42-1.tif.mortality.tab ------ MAX_10022015 Position 70-1.tif.mortality.tab
# MAX_10022015 Position 42-1.tif.mortality.tab ------ MAX_10022015 Position 71-1.tif.mortality.tab
# MAX_10022015 Position 42-1.tif.mortality.tab ------ MAX_10022015 Position 74-1.tif.mortality.tab
# MAX_10022015 Position 42-1.tif.mortality.tab ------ MAX_10022015 Position 76-1.tif.mortality.tab
# MAX_10022015 Position 42-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 42-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 42-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 70-1.tif.mortality.tab ------ MAX_10022015 Position 71-1.tif.mortality.tab
# MAX_10022015 Position 70-1.tif.mortality.tab ------ MAX_10022015 Position 74-1.tif.mortality.tab
# MAX_10022015 Position 70-1.tif.mortality.tab ------ MAX_10022015 Position 76-1.tif.mortality.tab
# MAX_10022015 Position 70-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 70-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 70-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 71-1.tif.mortality.tab ------ MAX_10022015 Position 74-1.tif.mortality.tab
# MAX_10022015 Position 71-1.tif.mortality.tab ------ MAX_10022015 Position 76-1.tif.mortality.tab
# MAX_10022015 Position 71-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 71-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 71-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 74-1.tif.mortality.tab ------ MAX_10022015 Position 76-1.tif.mortality.tab
# MAX_10022015 Position 74-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 74-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 74-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 76-1.tif.mortality.tab ------ MAX_10022015 Position 77-1.tif.mortality.tab
# MAX_10022015 Position 76-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 76-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 77-1.tif.mortality.tab ------ MAX_10022015 Position 90-1.tif.mortality.tab
# MAX_10022015 Position 77-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# MAX_10022015 Position 90-1.tif.mortality.tab ------ MAX_10022015 Position 96-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_dentrogram-all-files.eps
# [['MAX_10022015 Position 1-1.tif.mortality.tab', 'MAX_10022015 Position 90-1.tif.mortality.tab'], ['MAX_10022015 Position 39-1.tif.mortality.tab', 'MAX_10022015 Position 96-1.tif.mortality.tab'], ['MAX_10022015 Position 27-1.tif.mortality.tab'], ['MAX_10022015 Position 77-1.tif.mortality.tab'], ['MAX_10022015 Position 42-1.tif.mortality.tab'], ['MAX_10022015 Position 71-1.tif.mortality.tab', 'MAX_10022015 Position 74-1.tif.mortality.tab', 'MAX_10022015 Position 76-1.tif.mortality.tab'], ['MAX_10022015 Position 70-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 4.153295   sv2= 0.1187306   df= 15.68551   lambda= 34.98082
# phi= 4.283847   sv2= 0.02808002   df= 11.84102   lambda= 152.5586
# phi= 4.374932   sv2= 0.005569905   df= 8.485072   lambda= 785.4589
# phi= 4.437388   sv2= 0.001834358   df= 5.924978   lambda= 2419.041
# phi= 4.488818   sv2= 0.001074746   df= 4.680577   lambda= 4176.633
# phi= 4.519901   sv2= 0.0008222304   df= 4.192348   lambda= 5497.122
# phi= 4.53695   sv2= 0.000709089   df= 3.971564   lambda= 6398.28
# phi= 4.546638   sv2= 0.0006504529   df= 3.856198   lambda= 6989.958
# phi= 4.552334   sv2= 0.0006176418   df= 3.791079   lambda= 7370.508
# phi= 4.555757   sv2= 0.0005984724   df= 3.752771   lambda= 7612.308
# phi= 4.557842   sv2= 0.0005869868   df= 3.729707   lambda= 7764.813
# phi= 4.559124   sv2= 0.0005800001   df= 3.715632   lambda= 7860.558
# phi= 4.559916   sv2= 0.0005757107   df= 3.706973   lambda= 7920.499
# phi= 4.560407   sv2= 0.0005730624   df= 3.70162   lambda= 7957.959
# phi= 4.560712   sv2= 0.0005714216   df= 3.6983   lambda= 7981.343
# phi= 4.560901   sv2= 0.0005704028   df= 3.696238   lambda= 7995.931
# phi= 4.561019   sv2= 0.0005697693   df= 3.694956   lambda= 8005.028
# phi= 4.561093   sv2= 0.0005693752   df= 3.694157   lambda= 8010.698
# phi= 4.561138   sv2= 0.0005691298   df= 3.69366   lambda= 8014.233
# phi= 4.561167   sv2= 0.0005689769   df= 3.693351   lambda= 8016.436
# phi= 4.561185   sv2= 0.0005688817   df= 3.693158   lambda= 8017.808
# phi= 4.561196   sv2= 0.0005688224   df= 3.693038   lambda= 8018.664
# phi= 4.561203   sv2= 0.0005687855   df= 3.692963   lambda= 8019.197
# Iterations: relative error in phi-hat = 1e-04
# phi= 9.657176   sv2= 0.1084791   df= 14.90163   lambda= 89.02335
# phi= 9.71658   sv2= 0.006837231   df= 9.111053   lambda= 1421.128
# phi= 9.695326   sv2= 0.0007229052   df= 5.007204   lambda= 13411.62
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.94381   sv2= 0.06161897   df= 11.39279   lambda= 989.043
# phi= 62.86616   sv2= 0.004334508   df= 4.312152   lambda= 14503.64
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_mortality_dataframe_cluster0.pickle
# 7 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_mortality_dataframe_cluster1.pickle
# 7 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_mortality_dataframe_cluster2.pickle
# 7 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjK/CR-TA_ydjK-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 4.153295   sv2= 0.1187306   df= 15.68551   lambda= 34.98082
# phi= 4.283847   sv2= 0.02808002   df= 11.84102   lambda= 152.5586
# phi= 4.374932   sv2= 0.005569905   df= 8.485072   lambda= 785.4589
# phi= 4.437388   sv2= 0.001834358   df= 5.924978   lambda= 2419.041
# phi= 4.488818   sv2= 0.001074746   df= 4.680577   lambda= 4176.633
# phi= 4.519901   sv2= 0.0008222304   df= 4.192348   lambda= 5497.122
# phi= 4.53695   sv2= 0.000709089   df= 3.971564   lambda= 6398.28
# phi= 4.546638   sv2= 0.0006504529   df= 3.856198   lambda= 6989.958
# phi= 4.552334   sv2= 0.0006176418   df= 3.791079   lambda= 7370.508
# phi= 4.555757   sv2= 0.0005984724   df= 3.752771   lambda= 7612.308
# phi= 4.557842   sv2= 0.0005869868   df= 3.729707   lambda= 7764.813
# phi= 4.559124   sv2= 0.0005800001   df= 3.715632   lambda= 7860.558
# phi= 4.559916   sv2= 0.0005757107   df= 3.706973   lambda= 7920.499
# phi= 4.560407   sv2= 0.0005730624   df= 3.70162   lambda= 7957.959
# phi= 4.560712   sv2= 0.0005714216   df= 3.6983   lambda= 7981.343
# phi= 4.560901   sv2= 0.0005704028   df= 3.696238   lambda= 7995.931
# phi= 4.561019   sv2= 0.0005697693   df= 3.694956   lambda= 8005.028
# phi= 4.561093   sv2= 0.0005693752   df= 3.694157   lambda= 8010.698
# phi= 4.561138   sv2= 0.0005691298   df= 3.69366   lambda= 8014.233
# phi= 4.561167   sv2= 0.0005689769   df= 3.693351   lambda= 8016.436
# phi= 4.561185   sv2= 0.0005688817   df= 3.693158   lambda= 8017.808
# phi= 4.561196   sv2= 0.0005688224   df= 3.693038   lambda= 8018.664
# phi= 4.561203   sv2= 0.0005687855   df= 3.692963   lambda= 8019.197
# Iterations: relative error in phi-hat = 1e-04
# phi= 9.657176   sv2= 0.1084791   df= 14.90163   lambda= 89.02335
# phi= 9.71658   sv2= 0.006837231   df= 9.111053   lambda= 1421.128
# phi= 9.695326   sv2= 0.0007229052   df= 5.007204   lambda= 13411.62
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.94381   sv2= 0.06161897   df= 11.39279   lambda= 989.043
# phi= 62.86616   sv2= 0.004334508   df= 4.312152   lambda= 14503.64
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  73.540665  73.540665  75.540701  0.000154, 1:                 est       L95%       U95%       var
# lifespan  86.804977  82.803679  87.201171  0.000193, 2:                 est       L95%        U95%       var
# lifespan  96.080981  93.061106  100.081722  0.000634}
