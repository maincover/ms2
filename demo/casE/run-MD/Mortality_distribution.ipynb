# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/casE'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/casE/TA_casE-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/casE/TA_casE-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/casE
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.25872   sv2= 0.08577907   df= 15.08744   lambda= 457.6725
# phi= 39.10418   sv2= 0.01744309   df= 6.498674   lambda= 2241.815
# phi= 38.71127   sv2= 0.01136278   df= 4.756511   lambda= 3406.848
# phi= 38.77227   sv2= 0.009692391   df= 4.400986   lambda= 4000.279
# phi= 38.82793   sv2= 0.009083751   df= 4.273373   lambda= 4274.437
# phi= 38.85695   sv2= 0.008839344   df= 4.22202   lambda= 4395.908
# phi= 38.87034   sv2= 0.008737319   df= 4.20054   lambda= 4448.772
# phi= 38.87626   sv2= 0.008694035   df= 4.191418   lambda= 4471.602
# phi= 38.87884   sv2= 0.008675545   df= 4.187519   lambda= 4481.429
# phi= 38.87995   sv2= 0.008667624   df= 4.185848   lambda= 4485.652
# phi= 38.88043   sv2= 0.008664226   df= 4.185131   lambda= 4487.467
# phi= 38.88063   sv2= 0.008662767   df= 4.184824   lambda= 4488.246
# phi= 38.88072   sv2= 0.008662141   df= 4.184692   lambda= 4488.581
# save file prefixed name is : TA_casE-1_df_relative_timegrid-vs-TA_casE-1_timeseries_dataframe
# biName is :  TA_casE-1_df_relative_timegrid-vs-TA_casE-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/casE/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_casE-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/casE/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/casE/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_casE-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.25872   sv2= 0.08577907   df= 15.08744   lambda= 457.6725
# phi= 39.10418   sv2= 0.01744309   df= 6.498674   lambda= 2241.815
# phi= 38.71127   sv2= 0.01136278   df= 4.756511   lambda= 3406.848
# phi= 38.77227   sv2= 0.009692391   df= 4.400986   lambda= 4000.279
# phi= 38.82793   sv2= 0.009083751   df= 4.273373   lambda= 4274.437
# phi= 38.85695   sv2= 0.008839344   df= 4.22202   lambda= 4395.908
# phi= 38.87034   sv2= 0.008737319   df= 4.20054   lambda= 4448.772
# phi= 38.87626   sv2= 0.008694035   df= 4.191418   lambda= 4471.602
# phi= 38.87884   sv2= 0.008675545   df= 4.187519   lambda= 4481.429
# phi= 38.87995   sv2= 0.008667624   df= 4.185848   lambda= 4485.652
# phi= 38.88043   sv2= 0.008664226   df= 4.185131   lambda= 4487.467
# phi= 38.88063   sv2= 0.008662767   df= 4.184824   lambda= 4488.246
# phi= 38.88072   sv2= 0.008662141   df= 4.184692   lambda= 4488.581
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/casE/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_casE-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_casE-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/casE/MD-TA_casE-1_df_relative_timegrid-vs-TA_casE-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_casE-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=13158.938220)
#                  est          L95%          U95%            se
# rate    1.865635e-01  1.391233e-01  2.501806e-01  2.792900e-02
# beta    1.279162e+11  1.254346e+08  1.304469e+14  4.521102e+11
# s       2.525306e-01  1.535959e-01  4.151914e-01  6.406241e-02
# lambda  6.486287e-03  6.034117e-03  6.972340e-03  2.391387e-04
#                  est        L95%        U95%       var
# lifespan  115.257458  100.446699  121.754852  0.000172
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/casE/MD-TA_casE-1_df_relative_timegrid-vs-TA_casE-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_casE-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/casE/run-MD
