# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/TA_ldcC-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/TA_ldcC-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/TA_ldcC-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC']
#
# out_name_s  ['TA_ldcC-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/TA_ldcC-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/TA_ldcC-1_analysis_metadata.pickle
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 72-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 73-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 76-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 77-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 84-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 89-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 95-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 69-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 73-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 76-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 77-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 84-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 89-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 95-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 72-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 73-1.tif.mortality.tab ------ MAX_05072014 Position 76-1.tif.mortality.tab
# MAX_05072014 Position 73-1.tif.mortality.tab ------ MAX_05072014 Position 77-1.tif.mortality.tab
# MAX_05072014 Position 73-1.tif.mortality.tab ------ MAX_05072014 Position 84-1.tif.mortality.tab
# MAX_05072014 Position 73-1.tif.mortality.tab ------ MAX_05072014 Position 89-1.tif.mortality.tab
# MAX_05072014 Position 73-1.tif.mortality.tab ------ MAX_05072014 Position 95-1.tif.mortality.tab
# MAX_05072014 Position 73-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 73-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 76-1.tif.mortality.tab ------ MAX_05072014 Position 77-1.tif.mortality.tab
# MAX_05072014 Position 76-1.tif.mortality.tab ------ MAX_05072014 Position 84-1.tif.mortality.tab
# MAX_05072014 Position 76-1.tif.mortality.tab ------ MAX_05072014 Position 89-1.tif.mortality.tab
# MAX_05072014 Position 76-1.tif.mortality.tab ------ MAX_05072014 Position 95-1.tif.mortality.tab
# MAX_05072014 Position 76-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 76-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 77-1.tif.mortality.tab ------ MAX_05072014 Position 84-1.tif.mortality.tab
# MAX_05072014 Position 77-1.tif.mortality.tab ------ MAX_05072014 Position 89-1.tif.mortality.tab
# MAX_05072014 Position 77-1.tif.mortality.tab ------ MAX_05072014 Position 95-1.tif.mortality.tab
# MAX_05072014 Position 77-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 77-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 84-1.tif.mortality.tab ------ MAX_05072014 Position 89-1.tif.mortality.tab
# MAX_05072014 Position 84-1.tif.mortality.tab ------ MAX_05072014 Position 95-1.tif.mortality.tab
# MAX_05072014 Position 84-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 84-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 89-1.tif.mortality.tab ------ MAX_05072014 Position 95-1.tif.mortality.tab
# MAX_05072014 Position 89-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 89-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 95-1.tif.mortality.tab ------ MAX_05072014 Position 98-1.tif.mortality.tab
# MAX_05072014 Position 95-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# MAX_05072014 Position 98-1.tif.mortality.tab ------ MAX_05072014 Position 99-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_dentrogram-all-files.eps
# [['MAX_05072014 Position 69-1.tif.mortality.tab', 'MAX_05072014 Position 73-1.tif.mortality.tab', 'MAX_05072014 Position 76-1.tif.mortality.tab', 'MAX_05072014 Position 98-1.tif.mortality.tab'], ['MAX_05072014 Position 95-1.tif.mortality.tab', 'MAX_05072014 Position 99-1.tif.mortality.tab'], ['MAX_05072014 Position 72-1.tif.mortality.tab', 'MAX_05072014 Position 77-1.tif.mortality.tab', 'MAX_05072014 Position 84-1.tif.mortality.tab', 'MAX_05072014 Position 89-1.tif.mortality.tab']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.26055   sv2= 0.1721569   df= 14.48324   lambda= 216.4336
# phi= 39.38132   sv2= 0.005716976   df= 7.310132   lambda= 6888.487
# phi= 40.2035   sv2= 0.0002101047   df= 3.56861   lambda= 191349.8
# Iterations: relative error in phi-hat = 1e-04
# phi= 17.73426   sv2= 0.07106619   df= 11.41424   lambda= 249.5457
# phi= 18.11276   sv2= 0.008460242   df= 5.427395   lambda= 2140.927
# phi= 18.40557   sv2= 0.003571613   df= 3.560394   lambda= 5153.294
# phi= 18.53477   sv2= 0.002620079   df= 3.061453   lambda= 7074.127
# phi= 18.60252   sv2= 0.002303872   df= 2.909688   lambda= 8074.462
# phi= 18.63552   sv2= 0.002172871   df= 2.850304   lambda= 8576.45
# phi= 18.65154   sv2= 0.002113343   df= 2.82398   lambda= 8825.608
# phi= 18.65935   sv2= 0.002085135   df= 2.811646   lambda= 8948.751
# phi= 18.66318   sv2= 0.002071501   df= 2.805715   lambda= 9009.499
# phi= 18.66507   sv2= 0.002064847   df= 2.802829   lambda= 9039.441
# phi= 18.66599   sv2= 0.002061585   df= 2.801415   lambda= 9054.193
# phi= 18.66645   sv2= 0.002059982   df= 2.800721   lambda= 9061.459
# phi= 18.66667   sv2= 0.002059194   df= 2.80038   lambda= 9065.038
# phi= 18.66678   sv2= 0.002058806   df= 2.800212   lambda= 9066.801
# phi= 18.66684   sv2= 0.002058615   df= 2.800129   lambda= 9067.669
# Iterations: relative error in phi-hat = 1e-04
# phi= 11.97302   sv2= 0.0654866   df= 10.46446   lambda= 182.8316
# phi= 11.51361   sv2= 0.004685742   df= 5.491784   lambda= 2457.158
# phi= 11.01432   sv2= 0.002181611   df= 3.287164   lambda= 5048.707
# phi= 10.93181   sv2= 0.001771144   df= 2.915462   lambda= 6172.175
# phi= 10.92154   sv2= 0.001637148   df= 2.824966   lambda= 6671.075
# phi= 10.91916   sv2= 0.001583722   df= 2.791406   lambda= 6894.622
# phi= 10.91842   sv2= 0.00156086   df= 2.777417   lambda= 6995.134
# phi= 10.91815   sv2= 0.001550787   df= 2.771319   lambda= 7040.392
# phi= 10.91804   sv2= 0.001546293   df= 2.768611   lambda= 7060.782
# phi= 10.91799   sv2= 0.001544276   df= 2.767399   lambda= 7069.972
# phi= 10.91797   sv2= 0.001543369   df= 2.766854   lambda= 7074.114
# phi= 10.91796   sv2= 0.00154296   df= 2.766608   lambda= 7075.981
# phi= 10.91795   sv2= 0.001542776   df= 2.766498   lambda= 7076.823
# phi= 10.91795   sv2= 0.001542693   df= 2.766448   lambda= 7077.202
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/CR-TA_ldcC-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.57318   sv2= 0.1086084   df= 14.36943   lambda= 235.4622
# phi= 26.26482   sv2= 0.003053372   df= 7.074652   lambda= 8601.907
# phi= 26.79039   sv2= 0.0007034085   df= 3.374442   lambda= 38086.53
# Iterations: relative error in phi-hat = 1e-04
# phi= 11.97302   sv2= 0.0654866   df= 10.46446   lambda= 182.8316
# phi= 11.51361   sv2= 0.004685742   df= 5.491784   lambda= 2457.158
# phi= 11.01432   sv2= 0.002181611   df= 3.287164   lambda= 5048.707
# phi= 10.93181   sv2= 0.001771144   df= 2.915462   lambda= 6172.175
# phi= 10.92154   sv2= 0.001637148   df= 2.824966   lambda= 6671.075
# phi= 10.91916   sv2= 0.001583722   df= 2.791406   lambda= 6894.622
# phi= 10.91842   sv2= 0.00156086   df= 2.777417   lambda= 6995.134
# phi= 10.91815   sv2= 0.001550787   df= 2.771319   lambda= 7040.392
# phi= 10.91804   sv2= 0.001546293   df= 2.768611   lambda= 7060.782
# phi= 10.91799   sv2= 0.001544276   df= 2.767399   lambda= 7069.972
# phi= 10.91797   sv2= 0.001543369   df= 2.766854   lambda= 7074.114
# phi= 10.91796   sv2= 0.00154296   df= 2.766608   lambda= 7075.981
# phi= 10.91795   sv2= 0.001542776   df= 2.766498   lambda= 7076.823
# phi= 10.91795   sv2= 0.001542693   df= 2.766448   lambda= 7077.202
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%     var
# lifespan  103.289731  101.335539  104.446751  0.0002, 1:                  est        L95%        U95%       var
# lifespan  111.502161  110.502344  114.540038  0.000641}
