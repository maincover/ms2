# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/TA_ldcC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/TA_ldcC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.42116   sv2= 0.1334491   df= 16.19804   lambda= 168.0128
# phi= 22.99263   sv2= 0.006620089   df= 8.628663   lambda= 3473.16
# phi= 23.2962   sv2= 0.0006426015   df= 4.481229   lambda= 36252.96
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_ldcC-1_df_relative_timegrid-vs-TA_ldcC-1_timeseries_dataframe
# biName is :  TA_ldcC-1_df_relative_timegrid-vs-TA_ldcC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ldcC/run-MD
# No error in flxsrv_fit
# TA_ldcC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ldcC/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ldcC/run-MD
# TA_ldcC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.42116   sv2= 0.1334491   df= 16.19804   lambda= 168.0128
# phi= 22.99263   sv2= 0.006620089   df= 8.628663   lambda= 3473.16
# phi= 23.2962   sv2= 0.0006426015   df= 4.481229   lambda= 36252.96
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ldcC/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ldcC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ldcC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/MD-TA_ldcC-1_df_relative_timegrid-vs-TA_ldcC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ldcC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=19094.688141)
#                  est          L95%          U95%         se
# rate    4.278720e-02  3.933909e-02      0.046538   0.001834
# beta    3.434627e+02  2.560306e+02    460.751983  51.482057
# s       2.833291e+00  1.767927e+00      4.540651   0.681783
# lambda  2.875671e-07  5.320169e-18  15543.644622   0.000004
#                  est        L95%        U95%      var
# lifespan  105.400903  104.261662  107.298882  0.00012
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ldcC/MD-TA_ldcC-1_df_relative_timegrid-vs-TA_ldcC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ldcC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ldcC/run-MD
