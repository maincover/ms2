# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagZ'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagZ/TA_nagZ-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagZ/TA_nagZ-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagZ
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.16449   sv2= 0.1515814   df= 18.3507   lambda= 317.7467
# phi= 48.7045   sv2= 0.01361245   df= 8.593704   lambda= 3577.938
# phi= 49.13449   sv2= 0.002274648   df= 5.10026   lambda= 21600.92
# save file prefixed name is : TA_nagZ-1_df_relative_timegrid-vs-TA_nagZ-1_timeseries_dataframe
# biName is :  TA_nagZ-1_df_relative_timegrid-vs-TA_nagZ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/nagZ/run-MD
# No error in flxsrv_fit
# TA_nagZ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/nagZ/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/nagZ/run-MD
# TA_nagZ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.16449   sv2= 0.1515814   df= 18.3507   lambda= 317.7467
# phi= 48.7045   sv2= 0.01361245   df= 8.593704   lambda= 3577.938
# phi= 49.13449   sv2= 0.002274648   df= 5.10026   lambda= 21600.92
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/nagZ/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_nagZ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_nagZ-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagZ/MD-TA_nagZ-1_df_relative_timegrid-vs-TA_nagZ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_nagZ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=40164.259635)
#                  est          L95%        U95%         se
# rate    4.341326e-02  4.081570e-02    0.046176   0.001367
# beta    2.429170e+02  1.935783e+02  304.830995  28.138946
# s       1.982967e+00  1.399300e+00    2.810090   0.352714
# lambda  4.239299e-07  1.704661e-14   10.542656   0.000004
#                  est        L95%        U95%      var
# lifespan  108.612921  107.428242  109.766926  0.00005
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagZ/MD-TA_nagZ-1_df_relative_timegrid-vs-TA_nagZ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_nagZ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/nagZ/run-MD
