# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/lsrC'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/lsrC/TA_lsrC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/lsrC/TA_lsrC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/lsrC
# Iterations: relative error in phi-hat = 1e-04
# phi= 117.4226   sv2= 0.6455592   df= 18.03523   lambda= 181.8929
# phi= 127.7206   sv2= 0.03632028   df= 9.539594   lambda= 3516.511
# phi= 133.546   sv2= 0.002118501   df= 5.03047   lambda= 63037.94
# save file prefixed name is : TA_lsrC-1_df_relative_timegrid-vs-TA_lsrC-1_timeseries_dataframe
# biName is :  TA_lsrC-1_df_relative_timegrid-vs-TA_lsrC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/lsrC/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_lsrC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/lsrC/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/lsrC/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_lsrC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 117.4226   sv2= 0.6455592   df= 18.03523   lambda= 181.8929
# phi= 127.7206   sv2= 0.03632028   df= 9.539594   lambda= 3516.511
# phi= 133.546   sv2= 0.002118501   df= 5.03047   lambda= 63037.94
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/lsrC/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_lsrC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_lsrC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/lsrC/MD-TA_lsrC-1_df_relative_timegrid-vs-TA_lsrC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_lsrC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=32124.014601)
#                  est          L95%          U95%           se
# rate    3.826584e-02  3.630161e-02      0.040336     0.001029
# beta    2.685543e+03  1.714568e+02  42063.906237  3769.841810
# s       4.042643e+01  2.261657e+00    722.610301    59.473043
# lambda  1.981223e-07  1.677990e-18  23392.539531     0.000003
#                 est       L95%        U95%       var
# lifespan  99.949127  97.601724  102.627177  0.000073
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/lsrC/MD-TA_lsrC-1_df_relative_timegrid-vs-TA_lsrC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_lsrC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/lsrC/run-MD
