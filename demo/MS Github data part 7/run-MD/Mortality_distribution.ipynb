# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS Github data part 7'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/TA_ynaA-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/caiT/TA_caiT-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/TA_yhbS-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/flu/TA_flu-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/syd/TA_syd-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/TA_ynaA-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/caiT/TA_caiT-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/TA_yhbS-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/flu/TA_flu-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/syd/TA_syd-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA
# Iterations: relative error in phi-hat = 1e-04
# phi= 69.02614   sv2= 0.2582263   df= 15.29764   lambda= 267.3087
# phi= 71.37918   sv2= 0.03176587   df= 7.470483   lambda= 2247.04
# phi= 72.10505   sv2= 0.01162749   df= 4.756159   lambda= 6201.256
# phi= 73.27245   sv2= 0.006890862   df= 3.880542   lambda= 10633.28
# save file prefixed name is : TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe
# biName is :  TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ynaA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ynaA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 69.02614   sv2= 0.2582263   df= 15.29764   lambda= 267.3087
# phi= 71.37918   sv2= 0.03176587   df= 7.470483   lambda= 2247.04
# phi= 72.10505   sv2= 0.01162749   df= 4.756159   lambda= 6201.256
# phi= 73.27245   sv2= 0.006890862   df= 3.880542   lambda= 10633.28
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ynaA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MD-TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ynaA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=17226.786501)
#                   est          L95%           U95%             se
# rate         0.113135      0.102477       0.124901       0.005711
# beta    233239.392465  84620.105955  642880.478392  120655.225032
# s            1.089947      0.890146       1.334595       0.112611
# lambda       0.000990      0.000796       0.001232       0.000110
#                  est        L95%        U95%       var
# lifespan  106.586276  105.810601  107.927317  0.000123
#
#
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MD-TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT
# Iterations: relative error in phi-hat = 1e-04
# phi= 43.48355   sv2= 0.4475924   df= 15.34439   lambda= 97.1499
# phi= 46.36412   sv2= 0.08349762   df= 9.355214   lambda= 555.2747
# phi= 49.5702   sv2= 0.02478897   df= 6.399984   lambda= 1999.688
# phi= 52.30985   sv2= 0.01032574   df= 4.893855   lambda= 5065.966
# phi= 53.5625   sv2= 0.00559689   df= 4.055886   lambda= 9570.047
# phi= 54.10449   sv2= 0.003450667   df= 3.575342   lambda= 15679.43
# save file prefixed name is : TA_caiT-1_df_relative_timegrid-vs-TA_caiT-1_timeseries_dataframe
# biName is :  TA_caiT-1_df_relative_timegrid-vs-TA_caiT-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# No error in flxsrv_fit
# TA_caiT-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# TA_caiT-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 43.48355   sv2= 0.4475924   df= 15.34439   lambda= 97.1499
# phi= 46.36412   sv2= 0.08349762   df= 9.355214   lambda= 555.2747
# phi= 49.5702   sv2= 0.02478897   df= 6.399984   lambda= 1999.688
# phi= 52.30985   sv2= 0.01032574   df= 4.893855   lambda= 5065.966
# phi= 53.5625   sv2= 0.00559689   df= 4.055886   lambda= 9570.047
# phi= 54.10449   sv2= 0.003450667   df= 3.575342   lambda= 15679.43
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_caiT-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_caiT-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MD-TA_caiT-1_df_relative_timegrid-vs-TA_caiT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_caiT-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=17538.806657)
#                   est          L95%           U95%             se
# rate         0.111736      0.098063       0.127314       0.007441
# beta    219680.746566  60484.127130  797889.176911  144565.406631
# s            0.838615      0.648744       1.084056       0.109841
# lambda       0.000923      0.000746       0.001142       0.000100
#                  est        L95%        U95%       var
# lifespan  109.170423  109.003733  110.342814  0.000125
#
#
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MD-TA_caiT-1_df_relative_timegrid-vs-TA_caiT-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_caiT-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS
# Iterations: relative error in phi-hat = 1e-04
# phi= 127.9318   sv2= 0.2483759   df= 14.98453   lambda= 515.0732
# phi= 142.7003   sv2= 0.01775344   df= 6.315592   lambda= 8037.894
# phi= 137.3016   sv2= 0.007627284   df= 3.651218   lambda= 18001.37
# save file prefixed name is : TA_yhbS-1_df_relative_timegrid-vs-TA_yhbS-1_timeseries_dataframe
# biName is :  TA_yhbS-1_df_relative_timegrid-vs-TA_yhbS-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# No error in flxsrv_fit
# TA_yhbS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# TA_yhbS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 127.9318   sv2= 0.2483759   df= 14.98453   lambda= 515.0732
# phi= 142.7003   sv2= 0.01775344   df= 6.315592   lambda= 8037.894
# phi= 137.3016   sv2= 0.007627284   df= 3.651218   lambda= 18001.37
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhbS-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yhbS-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MD-TA_yhbS-1_df_relative_timegrid-vs-TA_yhbS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yhbS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=17025.472782)
#                  est          L95%          U95%            se
# rate    1.472179e-01  1.330339e-01  1.629142e-01  7.609633e-03
# beta    1.243770e+07  2.992722e+06  5.169085e+07  9.040017e+06
# s       7.501490e-01  6.136770e-01  9.169702e-01  7.685461e-02
# lambda  1.061689e-03  9.015724e-04  1.250241e-03  8.855270e-05
#                  est       L95%        U95%       var
# lifespan  111.020084  111.00263  112.231099  0.000122
#
#
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MD-TA_yhbS-1_df_relative_timegrid-vs-TA_yhbS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhbS-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu
# Iterations: relative error in phi-hat = 1e-04
# phi= 82.85762   sv2= 0.679907   df= 13.74289   lambda= 121.8661
# phi= 91.34743   sv2= 0.0902799   df= 8.122955   lambda= 1011.825
# phi= 97.89636   sv2= 0.01713131   df= 5.044996   lambda= 5714.471
# phi= 102.7579   sv2= 0.005527728   df= 3.504473   lambda= 18589.53
# save file prefixed name is : TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe
# biName is :  TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# No error in flxsrv_fit
# TA_flu-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# TA_flu-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 82.85762   sv2= 0.679907   df= 13.74289   lambda= 121.8661
# phi= 91.34743   sv2= 0.0902799   df= 8.122955   lambda= 1011.825
# phi= 97.89636   sv2= 0.01713131   df= 5.044996   lambda= 5714.471
# phi= 102.7579   sv2= 0.005527728   df= 3.504473   lambda= 18589.53
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_flu-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_flu-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MD-TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_flu-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=14571.170319)
#                  est          L95%           U95%            se
# rate        0.103468      0.095635       0.111941      0.004155
# beta    64476.172592  33743.993171  123197.536551  21300.335714
# s           1.417081      1.138793       1.763374      0.158073
# lambda      0.000356      0.000239       0.000528      0.000072
#                  est       L95%        U95%       var
# lifespan  101.350116  101.28915  102.573529  0.000139
#
#
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MD-TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_flu-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd
# Iterations: relative error in phi-hat = 1e-04
# phi= 56.45723   sv2= 0.3542611   df= 13.68752   lambda= 159.3661
# phi= 62.25197   sv2= 0.1223021   df= 7.439309   lambda= 509.0018
# phi= 65.2935   sv2= 0.07210631   df= 5.792316   lambda= 905.5171
# phi= 67.3576   sv2= 0.05362706   df= 5.159628   lambda= 1256.037
# phi= 68.77634   sv2= 0.04465683   df= 4.841752   lambda= 1540.108
# phi= 69.74721   sv2= 0.03962989   df= 4.656392   lambda= 1759.965
# phi= 70.41563   sv2= 0.03657341   df= 4.539796   lambda= 1925.323
# phi= 70.87914   sv2= 0.03461939   df= 4.463277   lambda= 2047.383
# phi= 71.20247   sv2= 0.03332896   df= 4.411753   lambda= 2136.354
# phi= 71.42901   sv2= 0.0324581   df= 4.376486   lambda= 2200.653
# phi= 71.58825   sv2= 0.03186167   df= 4.352086   lambda= 2246.845
# phi= 71.70044   sv2= 0.03144902   df= 4.33508   lambda= 2279.894
# phi= 71.77961   sv2= 0.0311615   df= 4.32317   lambda= 2303.471
# phi= 71.83554   sv2= 0.03096017   df= 4.314799   lambda= 2320.256
# phi= 71.87509   sv2= 0.03081871   df= 4.308901   lambda= 2332.19
# phi= 71.90307   sv2= 0.03071907   df= 4.30474   lambda= 2340.666
# phi= 71.92288   sv2= 0.03064876   df= 4.301799   lambda= 2346.681
# phi= 71.9369   sv2= 0.0305991   df= 4.29972   lambda= 2350.948
# phi= 71.94683   sv2= 0.03056398   df= 4.298249   lambda= 2353.974
# phi= 71.95386   sv2= 0.03053914   df= 4.297208   lambda= 2356.119
# phi= 71.95884   sv2= 0.03052156   df= 4.296471   lambda= 2357.64
# phi= 71.96237   sv2= 0.03050911   df= 4.295949   lambda= 2358.718
# phi= 71.96487   sv2= 0.0305003   df= 4.295579   lambda= 2359.481
# phi= 71.96664   sv2= 0.03049405   df= 4.295318   lambda= 2360.022
# phi= 71.9679   sv2= 0.03048963   df= 4.295132   lambda= 2360.406
# phi= 71.96879   sv2= 0.0304865   df= 4.295001   lambda= 2360.678
# phi= 71.96942   sv2= 0.03048428   df= 4.294908   lambda= 2360.87
# save file prefixed name is : TA_syd-1_df_relative_timegrid-vs-TA_syd-1_timeseries_dataframe
# biName is :  TA_syd-1_df_relative_timegrid-vs-TA_syd-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_syd-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_syd-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 56.45723   sv2= 0.3542611   df= 13.68752   lambda= 159.3661
# phi= 62.25197   sv2= 0.1223021   df= 7.439309   lambda= 509.0018
# phi= 65.2935   sv2= 0.07210631   df= 5.792316   lambda= 905.5171
# phi= 67.3576   sv2= 0.05362706   df= 5.159628   lambda= 1256.037
# phi= 68.77634   sv2= 0.04465683   df= 4.841752   lambda= 1540.108
# phi= 69.74721   sv2= 0.03962989   df= 4.656392   lambda= 1759.965
# phi= 70.41563   sv2= 0.03657341   df= 4.539796   lambda= 1925.323
# phi= 70.87914   sv2= 0.03461939   df= 4.463277   lambda= 2047.383
# phi= 71.20247   sv2= 0.03332896   df= 4.411753   lambda= 2136.354
# phi= 71.42901   sv2= 0.0324581   df= 4.376486   lambda= 2200.653
# phi= 71.58825   sv2= 0.03186167   df= 4.352086   lambda= 2246.845
# phi= 71.70044   sv2= 0.03144902   df= 4.33508   lambda= 2279.894
# phi= 71.77961   sv2= 0.0311615   df= 4.32317   lambda= 2303.471
# phi= 71.83554   sv2= 0.03096017   df= 4.314799   lambda= 2320.256
# phi= 71.87509   sv2= 0.03081871   df= 4.308901   lambda= 2332.19
# phi= 71.90307   sv2= 0.03071907   df= 4.30474   lambda= 2340.666
# phi= 71.92288   sv2= 0.03064876   df= 4.301799   lambda= 2346.681
# phi= 71.9369   sv2= 0.0305991   df= 4.29972   lambda= 2350.948
# phi= 71.94683   sv2= 0.03056398   df= 4.298249   lambda= 2353.974
# phi= 71.95386   sv2= 0.03053914   df= 4.297208   lambda= 2356.119
# phi= 71.95884   sv2= 0.03052156   df= 4.296471   lambda= 2357.64
# phi= 71.96237   sv2= 0.03050911   df= 4.295949   lambda= 2358.718
# phi= 71.96487   sv2= 0.0305003   df= 4.295579   lambda= 2359.481
# phi= 71.96664   sv2= 0.03049405   df= 4.295318   lambda= 2360.022
# phi= 71.9679   sv2= 0.03048963   df= 4.295132   lambda= 2360.406
# phi= 71.96879   sv2= 0.0304865   df= 4.295001   lambda= 2360.678
# phi= 71.96942   sv2= 0.03048428   df= 4.294908   lambda= 2360.87
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_syd-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_syd-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MD-TA_syd-1_df_relative_timegrid-vs-TA_syd-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_syd-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=12747.111853)
#                  est          L95%          U95%            se
# rate    4.422524e-01  3.911670e-01  5.000093e-01  2.769680e-02
# beta    5.808261e+19  2.553385e+17  1.321222e+22  1.608275e+20
# s       4.095656e-01  3.442483e-01  4.872762e-01  3.630447e-02
# lambda  1.664909e-03  1.460357e-03  1.898113e-03  1.113551e-04
#                  est       L95%        U95%      var
# lifespan  104.605511  104.56236  105.549476  0.00015
#
#
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MD-TA_syd-1_df_relative_timegrid-vs-TA_syd-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_syd-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS Github data part 7/run-MD
