# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/mg-wt/dataset/MS Github data part 7'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  825  Filtered files length (after MD5 check) :  38
# check line duplication(open file) :  50 / 825
# check line duplication(open file) :  100 / 825
# check line duplication(open file) :  150 / 825
# check line duplication(open file) :  200 / 825
# check line duplication(open file) :  250 / 825
# check line duplication(open file) :  300 / 825
# check line duplication(open file) :  350 / 825
# check line duplication(open file) :  400 / 825
# check line duplication(open file) :  450 / 825
# check line duplication(open file) :  500 / 825
# check line duplication(open file) :  550 / 825
# check line duplication(open file) :  600 / 825
# check line duplication(open file) :  650 / 825
# check line duplication(open file) :  700 / 825
# check line duplication(open file) :  750 / 825
# check line duplication(open file) :  800 / 825
# check line duplication:  0 / 825
# check line duplication:  50 / 825
# check line duplication:  100 / 825
# check line duplication:  150 / 825
# check line duplication:  200 / 825
# check line duplication:  250 / 825
# check line duplication:  300 / 825
# check line duplication:  350 / 825
# check line duplication:  400 / 825
# check line duplication:  450 / 825
# check line duplication:  500 / 825
# check line duplication:  550 / 825
# check line duplication:  600 / 825
# check line duplication:  650 / 825
# check line duplication:  700 / 825
# check line duplication:  750 / 825
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 100-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 107-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 110-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 111-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 91-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 92-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 95-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/MAX_08062016 Position 99-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MAX_08062016 Position 104-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MAX_08062016 Position 105-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MAX_08062016 Position 106-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MAX_08062016 Position 112-1.tif.mortality.tab
# check line duplication:  800 / 825
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MAX_08062016 Position 4-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MAX_08062016 Position 93-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/MAX_08062016 Position 98-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MAX_08062016 Position 10-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MAX_08062016 Position 123-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MAX_08062016 Position 15-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MAX_08062016 Position 20-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MAX_08062016 Position 28-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MAX_08062016 Position 6-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/MAX_08062016 Position 9-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 144-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 17-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 19-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 21-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 22-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 27-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 29-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/MAX_08062016 Position 97-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MAX_08062016 Position 103-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MAX_08062016 Position 26-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MAX_08062016 Position 30-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MAX_08062016 Position 7-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MAX_08062016 Position 8-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MAX_08062016 Position 94-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/MAX_08062016 Position 96-1.tif.mortality.tab
