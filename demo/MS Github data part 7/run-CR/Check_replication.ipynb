# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS Github data part 7'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/TA_ynaA-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/caiT/TA_caiT-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/TA_yhbS-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/flu/TA_flu-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/syd/TA_syd-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/TA_ynaA-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/caiT/TA_caiT-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/TA_yhbS-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/flu/TA_flu-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/syd/TA_syd-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/TA_ynaA-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/caiT/TA_caiT-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/TA_yhbS-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/flu/TA_flu-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS Github data part 7/syd/TA_syd-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS Github data part 7/ynaA', '/home/xsong/mg-wt/dataset/MS Github data part 7/caiT', '/home/xsong/mg-wt/dataset/MS Github data part 7/yhbS', '/home/xsong/mg-wt/dataset/MS Github data part 7/flu', '/home/xsong/mg-wt/dataset/MS Github data part 7/syd']
#
# out_name_s  ['TA_ynaA-1_', 'TA_caiT-1_', 'TA_yhbS-1_', 'TA_flu-1_', 'TA_syd-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/TA_ynaA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/TA_ynaA-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/TA_caiT-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/TA_caiT-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/TA_yhbS-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/TA_yhbS-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/TA_flu-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/TA_flu-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/TA_syd-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/TA_syd-1_analysis_metadata.pickle
# MAX_08062016 Position 103-1.tif.mortality.tab ------ MAX_08062016 Position 26-1.tif.mortality.tab
# MAX_08062016 Position 103-1.tif.mortality.tab ------ MAX_08062016 Position 30-1.tif.mortality.tab
# MAX_08062016 Position 103-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 103-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 103-1.tif.mortality.tab ------ MAX_08062016 Position 94-1.tif.mortality.tab
# MAX_08062016 Position 103-1.tif.mortality.tab ------ MAX_08062016 Position 96-1.tif.mortality.tab
# MAX_08062016 Position 26-1.tif.mortality.tab ------ MAX_08062016 Position 30-1.tif.mortality.tab
# MAX_08062016 Position 26-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 26-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 26-1.tif.mortality.tab ------ MAX_08062016 Position 94-1.tif.mortality.tab
# MAX_08062016 Position 26-1.tif.mortality.tab ------ MAX_08062016 Position 96-1.tif.mortality.tab
# MAX_08062016 Position 30-1.tif.mortality.tab ------ MAX_08062016 Position 7-1.tif.mortality.tab
# MAX_08062016 Position 30-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 30-1.tif.mortality.tab ------ MAX_08062016 Position 94-1.tif.mortality.tab
# MAX_08062016 Position 30-1.tif.mortality.tab ------ MAX_08062016 Position 96-1.tif.mortality.tab
# MAX_08062016 Position 7-1.tif.mortality.tab ------ MAX_08062016 Position 8-1.tif.mortality.tab
# MAX_08062016 Position 7-1.tif.mortality.tab ------ MAX_08062016 Position 94-1.tif.mortality.tab
# MAX_08062016 Position 7-1.tif.mortality.tab ------ MAX_08062016 Position 96-1.tif.mortality.tab
# MAX_08062016 Position 8-1.tif.mortality.tab ------ MAX_08062016 Position 94-1.tif.mortality.tab
# MAX_08062016 Position 8-1.tif.mortality.tab ------ MAX_08062016 Position 96-1.tif.mortality.tab
# MAX_08062016 Position 94-1.tif.mortality.tab ------ MAX_08062016 Position 96-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 107-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 110-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 111-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 2-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 91-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 92-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 95-1.tif.mortality.tab
# MAX_08062016 Position 100-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 107-1.tif.mortality.tab ------ MAX_08062016 Position 110-1.tif.mortality.tab
# MAX_08062016 Position 107-1.tif.mortality.tab ------ MAX_08062016 Position 111-1.tif.mortality.tab
# MAX_08062016 Position 107-1.tif.mortality.tab ------ MAX_08062016 Position 2-1.tif.mortality.tab
# MAX_08062016 Position 107-1.tif.mortality.tab ------ MAX_08062016 Position 91-1.tif.mortality.tab
# MAX_08062016 Position 107-1.tif.mortality.tab ------ MAX_08062016 Position 92-1.tif.mortality.tab
# MAX_08062016 Position 107-1.tif.mortality.tab ------ MAX_08062016 Position 95-1.tif.mortality.tab
# MAX_08062016 Position 107-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 110-1.tif.mortality.tab ------ MAX_08062016 Position 111-1.tif.mortality.tab
# MAX_08062016 Position 110-1.tif.mortality.tab ------ MAX_08062016 Position 2-1.tif.mortality.tab
# MAX_08062016 Position 110-1.tif.mortality.tab ------ MAX_08062016 Position 91-1.tif.mortality.tab
# MAX_08062016 Position 110-1.tif.mortality.tab ------ MAX_08062016 Position 92-1.tif.mortality.tab
# MAX_08062016 Position 110-1.tif.mortality.tab ------ MAX_08062016 Position 95-1.tif.mortality.tab
# MAX_08062016 Position 110-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 111-1.tif.mortality.tab ------ MAX_08062016 Position 2-1.tif.mortality.tab
# MAX_08062016 Position 111-1.tif.mortality.tab ------ MAX_08062016 Position 91-1.tif.mortality.tab
# MAX_08062016 Position 111-1.tif.mortality.tab ------ MAX_08062016 Position 92-1.tif.mortality.tab
# MAX_08062016 Position 111-1.tif.mortality.tab ------ MAX_08062016 Position 95-1.tif.mortality.tab
# MAX_08062016 Position 111-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 91-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 92-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 95-1.tif.mortality.tab
# MAX_08062016 Position 2-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 91-1.tif.mortality.tab ------ MAX_08062016 Position 92-1.tif.mortality.tab
# MAX_08062016 Position 91-1.tif.mortality.tab ------ MAX_08062016 Position 95-1.tif.mortality.tab
# MAX_08062016 Position 91-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 92-1.tif.mortality.tab ------ MAX_08062016 Position 95-1.tif.mortality.tab
# MAX_08062016 Position 92-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 95-1.tif.mortality.tab ------ MAX_08062016 Position 99-1.tif.mortality.tab
# MAX_08062016 Position 144-1.tif.mortality.tab ------ MAX_08062016 Position 17-1.tif.mortality.tab
# MAX_08062016 Position 144-1.tif.mortality.tab ------ MAX_08062016 Position 19-1.tif.mortality.tab
# MAX_08062016 Position 144-1.tif.mortality.tab ------ MAX_08062016 Position 21-1.tif.mortality.tab
# MAX_08062016 Position 144-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 144-1.tif.mortality.tab ------ MAX_08062016 Position 27-1.tif.mortality.tab
# MAX_08062016 Position 144-1.tif.mortality.tab ------ MAX_08062016 Position 29-1.tif.mortality.tab
# MAX_08062016 Position 144-1.tif.mortality.tab ------ MAX_08062016 Position 97-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 19-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 21-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 27-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 29-1.tif.mortality.tab
# MAX_08062016 Position 17-1.tif.mortality.tab ------ MAX_08062016 Position 97-1.tif.mortality.tab
# MAX_08062016 Position 19-1.tif.mortality.tab ------ MAX_08062016 Position 21-1.tif.mortality.tab
# MAX_08062016 Position 19-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 19-1.tif.mortality.tab ------ MAX_08062016 Position 27-1.tif.mortality.tab
# MAX_08062016 Position 19-1.tif.mortality.tab ------ MAX_08062016 Position 29-1.tif.mortality.tab
# MAX_08062016 Position 19-1.tif.mortality.tab ------ MAX_08062016 Position 97-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 22-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 27-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 29-1.tif.mortality.tab
# MAX_08062016 Position 21-1.tif.mortality.tab ------ MAX_08062016 Position 97-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 27-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 29-1.tif.mortality.tab
# MAX_08062016 Position 22-1.tif.mortality.tab ------ MAX_08062016 Position 97-1.tif.mortality.tab
# MAX_08062016 Position 27-1.tif.mortality.tab ------ MAX_08062016 Position 29-1.tif.mortality.tab
# MAX_08062016 Position 27-1.tif.mortality.tab ------ MAX_08062016 Position 97-1.tif.mortality.tab
# MAX_08062016 Position 29-1.tif.mortality.tab ------ MAX_08062016 Position 97-1.tif.mortality.tab
# MAX_08062016 Position 104-1.tif.mortality.tab ------ MAX_08062016 Position 105-1.tif.mortality.tab
# MAX_08062016 Position 104-1.tif.mortality.tab ------ MAX_08062016 Position 106-1.tif.mortality.tab
# MAX_08062016 Position 104-1.tif.mortality.tab ------ MAX_08062016 Position 112-1.tif.mortality.tab
# MAX_08062016 Position 104-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 104-1.tif.mortality.tab ------ MAX_08062016 Position 93-1.tif.mortality.tab
# MAX_08062016 Position 104-1.tif.mortality.tab ------ MAX_08062016 Position 98-1.tif.mortality.tab
# MAX_08062016 Position 105-1.tif.mortality.tab ------ MAX_08062016 Position 106-1.tif.mortality.tab
# MAX_08062016 Position 105-1.tif.mortality.tab ------ MAX_08062016 Position 112-1.tif.mortality.tab
# MAX_08062016 Position 105-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 105-1.tif.mortality.tab ------ MAX_08062016 Position 93-1.tif.mortality.tab
# MAX_08062016 Position 105-1.tif.mortality.tab ------ MAX_08062016 Position 98-1.tif.mortality.tab
# MAX_08062016 Position 106-1.tif.mortality.tab ------ MAX_08062016 Position 112-1.tif.mortality.tab
# MAX_08062016 Position 106-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 106-1.tif.mortality.tab ------ MAX_08062016 Position 93-1.tif.mortality.tab
# MAX_08062016 Position 106-1.tif.mortality.tab ------ MAX_08062016 Position 98-1.tif.mortality.tab
# MAX_08062016 Position 112-1.tif.mortality.tab ------ MAX_08062016 Position 4-1.tif.mortality.tab
# MAX_08062016 Position 112-1.tif.mortality.tab ------ MAX_08062016 Position 93-1.tif.mortality.tab
# MAX_08062016 Position 112-1.tif.mortality.tab ------ MAX_08062016 Position 98-1.tif.mortality.tab
# MAX_08062016 Position 4-1.tif.mortality.tab ------ MAX_08062016 Position 93-1.tif.mortality.tab
# MAX_08062016 Position 4-1.tif.mortality.tab ------ MAX_08062016 Position 98-1.tif.mortality.tab
# MAX_08062016 Position 93-1.tif.mortality.tab ------ MAX_08062016 Position 98-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 123-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 15-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 20-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 28-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 10-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 123-1.tif.mortality.tab ------ MAX_08062016 Position 15-1.tif.mortality.tab
# MAX_08062016 Position 123-1.tif.mortality.tab ------ MAX_08062016 Position 20-1.tif.mortality.tab
# MAX_08062016 Position 123-1.tif.mortality.tab ------ MAX_08062016 Position 28-1.tif.mortality.tab
# MAX_08062016 Position 123-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 123-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 15-1.tif.mortality.tab ------ MAX_08062016 Position 20-1.tif.mortality.tab
# MAX_08062016 Position 15-1.tif.mortality.tab ------ MAX_08062016 Position 28-1.tif.mortality.tab
# MAX_08062016 Position 15-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 15-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 28-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 20-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 28-1.tif.mortality.tab ------ MAX_08062016 Position 6-1.tif.mortality.tab
# MAX_08062016 Position 28-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# MAX_08062016 Position 6-1.tif.mortality.tab ------ MAX_08062016 Position 9-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA
# save eps to :  /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_dentrogram-all-files.eps
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT
# save eps to :  /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_dentrogram-all-files.eps
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS
# save eps to :  /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_dentrogram-all-files.eps
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu
# save eps to :  /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_dentrogram-all-files.eps
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd
# save eps to :  /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_dentrogram-all-files.eps
# [['MAX_08062016 Position 103-1.tif.mortality.tab', 'MAX_08062016 Position 30-1.tif.mortality.tab'], ['MAX_08062016 Position 26-1.tif.mortality.tab'], ['MAX_08062016 Position 7-1.tif.mortality.tab'], ['MAX_08062016 Position 94-1.tif.mortality.tab'], ['MAX_08062016 Position 96-1.tif.mortality.tab'], ['MAX_08062016 Position 8-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.081776   sv2= 0.2158361   df= 10.53909   lambda= 14.27832
# phi= 3.168001   sv2= 0.1769967   df= 9.769386   lambda= 17.89865
# phi= 3.229467   sv2= 0.1554866   df= 9.309021   lambda= 20.77006
# phi= 3.272832   sv2= 0.1425756   df= 9.017513   lambda= 22.95506
# phi= 3.303277   sv2= 0.1344293   df= 8.82662   lambda= 24.57261
# phi= 3.324595   sv2= 0.1291207   df= 8.698974   lambda= 25.74795
# phi= 3.339498   sv2= 0.1255868   df= 8.612459   lambda= 26.59115
# phi= 3.349906   sv2= 0.1232001   df= 8.553298   lambda= 27.19077
# phi= 3.357171   sv2= 0.1215724   df= 8.512597   lambda= 27.61457
# phi= 3.362239   sv2= 0.1204549   df= 8.484483   lambda= 27.91285
# phi= 3.365774   sv2= 0.119684   df= 8.465009   lambda= 28.12217
# phi= 3.368239   sv2= 0.1191505   df= 8.451493   lambda= 28.26876
# phi= 3.369957   sv2= 0.1187806   df= 8.442101   lambda= 28.37128
# phi= 3.371155   sv2= 0.1185236   df= 8.435567   lambda= 28.4429
# phi= 3.371991   sv2= 0.118345   df= 8.43102   lambda= 28.4929
# phi= 3.372573   sv2= 0.1182206   df= 8.427853   lambda= 28.52779
# phi= 3.372979   sv2= 0.1181341   df= 8.425648   lambda= 28.55213
# phi= 3.373262   sv2= 0.1180738   df= 8.424111   lambda= 28.56911
# phi= 3.373459   sv2= 0.1180318   df= 8.42304   lambda= 28.58094
# phi= 3.373597   sv2= 0.1180025   df= 8.422294   lambda= 28.5892
# phi= 3.373693   sv2= 0.1179821   df= 8.421774   lambda= 28.59495
# phi= 3.373759   sv2= 0.1179679   df= 8.421412   lambda= 28.59896
# phi= 3.373806   sv2= 0.117958   df= 8.421159   lambda= 28.60176
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_mortality_dataframe_cluster0.pickle
# 6 --c-- 0
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/ynaA/CR-TA_ynaA-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.081776   sv2= 0.2158361   df= 10.53909   lambda= 14.27832
# phi= 3.168001   sv2= 0.1769967   df= 9.769386   lambda= 17.89865
# phi= 3.229467   sv2= 0.1554866   df= 9.309021   lambda= 20.77006
# phi= 3.272832   sv2= 0.1425756   df= 9.017513   lambda= 22.95506
# phi= 3.303277   sv2= 0.1344293   df= 8.82662   lambda= 24.57261
# phi= 3.324595   sv2= 0.1291207   df= 8.698974   lambda= 25.74795
# phi= 3.339498   sv2= 0.1255868   df= 8.612459   lambda= 26.59115
# phi= 3.349906   sv2= 0.1232001   df= 8.553298   lambda= 27.19077
# phi= 3.357171   sv2= 0.1215724   df= 8.512597   lambda= 27.61457
# phi= 3.362239   sv2= 0.1204549   df= 8.484483   lambda= 27.91285
# phi= 3.365774   sv2= 0.119684   df= 8.465009   lambda= 28.12217
# phi= 3.368239   sv2= 0.1191505   df= 8.451493   lambda= 28.26876
# phi= 3.369957   sv2= 0.1187806   df= 8.442101   lambda= 28.37128
# phi= 3.371155   sv2= 0.1185236   df= 8.435567   lambda= 28.4429
# phi= 3.371991   sv2= 0.118345   df= 8.43102   lambda= 28.4929
# phi= 3.372573   sv2= 0.1182206   df= 8.427853   lambda= 28.52779
# phi= 3.372979   sv2= 0.1181341   df= 8.425648   lambda= 28.55213
# phi= 3.373262   sv2= 0.1180738   df= 8.424111   lambda= 28.56911
# phi= 3.373459   sv2= 0.1180318   df= 8.42304   lambda= 28.58094
# phi= 3.373597   sv2= 0.1180025   df= 8.422294   lambda= 28.5892
# phi= 3.373693   sv2= 0.1179821   df= 8.421774   lambda= 28.59495
# phi= 3.373759   sv2= 0.1179679   df= 8.421412   lambda= 28.59896
# phi= 3.373806   sv2= 0.117958   df= 8.421159   lambda= 28.60176
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  106.010258  105.364113  106.647242  0.000471}
# 4 [2 1 3 1]
# [['MAX_08062016 Position 111-1.tif.mortality.tab', 'MAX_08062016 Position 91-1.tif.mortality.tab', 'MAX_08062016 Position 95-1.tif.mortality.tab'], ['MAX_08062016 Position 107-1.tif.mortality.tab', 'MAX_08062016 Position 110-1.tif.mortality.tab'], ['MAX_08062016 Position 100-1.tif.mortality.tab', 'MAX_08062016 Position 2-1.tif.mortality.tab', 'MAX_08062016 Position 92-1.tif.mortality.tab', 'MAX_08062016 Position 99-1.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.40914   sv2= 0.205687   df= 13.20268   lambda= 123.5331
# phi= 26.30022   sv2= 0.0257478   df= 7.573332   lambda= 1021.455
# phi= 27.01314   sv2= 0.01182279   df= 4.860466   lambda= 2284.836
# phi= 27.68048   sv2= 0.008833668   df= 4.150773   lambda= 3133.521
# phi= 28.02618   sv2= 0.007526878   df= 3.906166   lambda= 3723.481
# phi= 28.22971   sv2= 0.006809143   df= 3.779129   lambda= 4145.853
# phi= 28.36009   sv2= 0.00636765   df= 3.702127   lambda= 4453.776
# phi= 28.44807   sv2= 0.006077467   df= 3.651649   lambda= 4680.909
# phi= 28.50948   sv2= 0.005878511   df= 3.616998   lambda= 4849.78
# phi= 28.55335   sv2= 0.005738181   df= 3.592501   lambda= 4976.028
# phi= 28.5852   sv2= 0.005637235   df= 3.574838   lambda= 5070.784
# phi= 28.60859   sv2= 0.005563595   df= 3.561925   lambda= 5142.105
# phi= 28.62591   sv2= 0.005509327   df= 3.552393   lambda= 5195.899
# phi= 28.63881   sv2= 0.005469037   df= 3.545306   lambda= 5236.537
# phi= 28.64847   sv2= 0.00543896   df= 3.54001   lambda= 5267.27
# phi= 28.65573   sv2= 0.005416415   df= 3.536037   lambda= 5290.534
# phi= 28.66119   sv2= 0.005399465   df= 3.533047   lambda= 5308.154
# phi= 28.66531   sv2= 0.005386691   df= 3.530793   lambda= 5321.507
# phi= 28.66843   sv2= 0.005377049   df= 3.529091   lambda= 5331.629
# phi= 28.67078   sv2= 0.00536976   df= 3.527804   lambda= 5339.305
# phi= 28.67257   sv2= 0.005364246   df= 3.52683   lambda= 5345.126
# phi= 28.67392   sv2= 0.00536007   df= 3.526093   lambda= 5349.542
# phi= 28.67494   sv2= 0.005356907   df= 3.525534   lambda= 5352.892
# phi= 28.67572   sv2= 0.005354509   df= 3.52511   lambda= 5355.434
# phi= 28.67631   sv2= 0.005352692   df= 3.524789   lambda= 5357.362
# phi= 28.67675   sv2= 0.005351313   df= 3.524545   lambda= 5358.826
# phi= 28.67709   sv2= 0.005350268   df= 3.524361   lambda= 5359.936
# phi= 28.67735   sv2= 0.005349474   df= 3.524221   lambda= 5360.779
# phi= 28.67754   sv2= 0.005348873   df= 3.524114   lambda= 5361.418
# phi= 28.67769   sv2= 0.005348416   df= 3.524033   lambda= 5361.904
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.183   sv2= 0.3768521   df= 12.76685   lambda= 125.203
# phi= 55.00165   sv2= 0.05884276   df= 7.381583   lambda= 934.7224
# phi= 67.2357   sv2= 0.01057333   df= 4.860497   lambda= 6358.99
# phi= 76.40064   sv2= 0.001136486   df= 3.339252   lambda= 67225.34
# Iterations: relative error in phi-hat = 1e-04
# phi= 53.5831   sv2= 0.1514339   df= 9.562966   lambda= 353.8383
# phi= 69.0457   sv2= 0.02200727   df= 4.61538   lambda= 3137.404
# phi= 77.44447   sv2= 0.002858238   df= 3.045305   lambda= 27095.18
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/caiT/CR-TA_caiT-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.04667   sv2= 0.4243775   df= 14.89964   lambda= 70.80175
# phi= 31.02463   sv2= 0.08457178   df= 9.716895   lambda= 366.8438
# phi= 31.46869   sv2= 0.03029234   df= 6.781154   lambda= 1038.833
# phi= 31.91309   sv2= 0.01693241   df= 5.44297   lambda= 1884.733
# phi= 32.21238   sv2= 0.01219013   df= 4.817223   lambda= 2642.496
# phi= 32.38543   sv2= 0.01012147   df= 4.50054   lambda= 3199.676
# phi= 32.48698   sv2= 0.009081294   df= 4.332161   lambda= 3577.351
# phi= 32.54829   sv2= 0.008508086   df= 4.237336   lambda= 3825.572
# phi= 32.58608   sv2= 0.008173723   df= 4.181459   lambda= 3986.688
# phi= 32.60971   sv2= 0.007971689   df= 4.14751   lambda= 4090.69
# phi= 32.62461   sv2= 0.007846896   df= 4.126473   lambda= 4157.645
# phi= 32.63407   sv2= 0.007768738   df= 4.113273   lambda= 4200.691
# phi= 32.64009   sv2= 0.007719357   df= 4.104922   lambda= 4228.344
# phi= 32.64394   sv2= 0.007687982   df= 4.099612   lambda= 4246.101
# phi= 32.64641   sv2= 0.007667977   df= 4.096225   lambda= 4257.5
# phi= 32.64799   sv2= 0.007655192   df= 4.094059   lambda= 4264.816
# phi= 32.649   sv2= 0.007647009   df= 4.092673   lambda= 4269.512
# phi= 32.64965   sv2= 0.007641767   df= 4.091785   lambda= 4272.525
# phi= 32.65006   sv2= 0.007638407   df= 4.091216   lambda= 4274.459
# phi= 32.65033   sv2= 0.007636253   df= 4.090851   lambda= 4275.7
# phi= 32.6505   sv2= 0.007634871   df= 4.090617   lambda= 4276.497
# phi= 32.65061   sv2= 0.007633984   df= 4.090466   lambda= 4277.008
# phi= 32.65068   sv2= 0.007633416   df= 4.09037   lambda= 4277.335
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# {0:                  est        L95%        U95%       var
# lifespan  109.170423  109.030612  110.351508  0.000143}
# [['MAX_08062016 Position 17-1.tif.mortality.tab', 'MAX_08062016 Position 19-1.tif.mortality.tab', 'MAX_08062016 Position 22-1.tif.mortality.tab'], ['MAX_08062016 Position 97-1.tif.mortality.tab'], ['MAX_08062016 Position 144-1.tif.mortality.tab'], ['MAX_08062016 Position 27-1.tif.mortality.tab'], ['MAX_08062016 Position 29-1.tif.mortality.tab'], ['MAX_08062016 Position 21-1.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 195.9546   sv2= 0.259677   df= 11.81543   lambda= 754.6091
# phi= 247.5611   sv2= 0.006833993   df= 4.77938   lambda= 36224.96
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_mortality_dataframe_cluster0.pickle
# 6 --c-- 0
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/yhbS/CR-TA_yhbS-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 195.9546   sv2= 0.259677   df= 11.81543   lambda= 754.6091
# phi= 247.5611   sv2= 0.006833993   df= 4.77938   lambda= 36224.96
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  116.792901  113.472833  116.810339  0.000403}
# 5 [1 2 3 1 4]
# [['MAX_08062016 Position 104-1.tif.mortality.tab', 'MAX_08062016 Position 106-1.tif.mortality.tab', 'MAX_08062016 Position 93-1.tif.mortality.tab', 'MAX_08062016 Position 98-1.tif.mortality.tab'], ['MAX_08062016 Position 112-1.tif.mortality.tab'], ['MAX_08062016 Position 4-1.tif.mortality.tab'], ['MAX_08062016 Position 105-1.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 68.52366   sv2= 0.534054   df= 13.40433   lambda= 128.3085
# phi= 79.65623   sv2= 0.05544936   df= 7.733122   lambda= 1436.558
# phi= 84.91501   sv2= 0.005988641   df= 4.636158   lambda= 14179.35
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 2
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/flu/CR-TA_flu-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 88.46662   sv2= 0.3027099   df= 11.8036   lambda= 292.2489
# phi= 101.021   sv2= 0.02340208   df= 5.790004   lambda= 4316.752
# phi= 109.6091   sv2= 0.003165645   df= 3.330026   lambda= 34624.56
# No error in flxsrv_fit
# {0:                  est       L95%        U95%       var
# lifespan  101.341464  101.24552  103.807755  0.000339}
# [['MAX_08062016 Position 28-1.tif.mortality.tab'], ['MAX_08062016 Position 6-1.tif.mortality.tab'], ['MAX_08062016 Position 123-1.tif.mortality.tab', 'MAX_08062016 Position 20-1.tif.mortality.tab'], ['MAX_08062016 Position 10-1.tif.mortality.tab'], ['MAX_08062016 Position 15-1.tif.mortality.tab'], ['MAX_08062016 Position 9-1.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 13.60815   sv2= 0.1593514   df= 9.92688   lambda= 85.39714
# phi= 15.20418   sv2= 0.06886325   df= 6.298057   lambda= 220.788
# phi= 16.42621   sv2= 0.05293702   df= 5.188097   lambda= 310.2972
# phi= 16.99772   sv2= 0.04761222   df= 4.857035   lambda= 357.0034
# phi= 17.25854   sv2= 0.04538039   df= 4.729181   lambda= 380.3083
# phi= 17.38134   sv2= 0.04436422   df= 4.672985   lambda= 391.7874
# phi= 17.44023   sv2= 0.04388424   df= 4.646858   lambda= 397.4145
# phi= 17.46874   sv2= 0.0436536   df= 4.634395   lambda= 400.1671
# phi= 17.48259   sv2= 0.04354185   df= 4.628377   lambda= 401.5124
# phi= 17.48935   sv2= 0.04348749   df= 4.625455   lambda= 402.1696
# phi= 17.49264   sv2= 0.04346099   df= 4.624031   lambda= 402.4906
# phi= 17.49425   sv2= 0.04344807   df= 4.623337   lambda= 402.6473
# phi= 17.49503   sv2= 0.04344176   df= 4.622999   lambda= 402.7239
# phi= 17.49542   sv2= 0.04343868   df= 4.622833   lambda= 402.7612
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_mortality_dataframe_cluster0.pickle
# 6 --c-- 2
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 7/syd/CR-TA_syd-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 13.60815   sv2= 0.1593514   df= 9.92688   lambda= 85.39714
# phi= 15.20418   sv2= 0.06886325   df= 6.298057   lambda= 220.788
# phi= 16.42621   sv2= 0.05293702   df= 5.188097   lambda= 310.2972
# phi= 16.99772   sv2= 0.04761222   df= 4.857035   lambda= 357.0034
# phi= 17.25854   sv2= 0.04538039   df= 4.729181   lambda= 380.3083
# phi= 17.38134   sv2= 0.04436422   df= 4.672985   lambda= 391.7874
# phi= 17.44023   sv2= 0.04388424   df= 4.646858   lambda= 397.4145
# phi= 17.46874   sv2= 0.0436536   df= 4.634395   lambda= 400.1671
# phi= 17.48259   sv2= 0.04354185   df= 4.628377   lambda= 401.5124
# phi= 17.48935   sv2= 0.04348749   df= 4.625455   lambda= 402.1696
# phi= 17.49264   sv2= 0.04346099   df= 4.624031   lambda= 402.4906
# phi= 17.49425   sv2= 0.04344807   df= 4.623337   lambda= 402.6473
# phi= 17.49503   sv2= 0.04344176   df= 4.622999   lambda= 402.7239
# phi= 17.49542   sv2= 0.04343868   df= 4.622833   lambda= 402.7612
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  104.264841  101.705571  105.549476  0.000526}
