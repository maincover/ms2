# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/TA_dcuA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/TA_dcuA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/TA_dcuA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA']
#
# out_name_s  ['TA_dcuA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/TA_dcuA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/TA_dcuA-1_analysis_metadata.pickle
# MAX_18102018 Position 41-1.tif.mortality.tab ------ MAX_18102018 Position 44-1.tif.mortality.tab
# MAX_18102018 Position 41-1.tif.mortality.tab ------ MAX_18102018 Position 56-1.tif.mortality.tab
# MAX_18102018 Position 41-1.tif.mortality.tab ------ MAX_18102018 Position 57-1.tif.mortality.tab
# MAX_18102018 Position 41-1.tif.mortality.tab ------ MAX_18102018 Position 58-1.tif.mortality.tab
# MAX_18102018 Position 41-1.tif.mortality.tab ------ MAX_18102018 Position 61-1.tif.mortality.tab
# MAX_18102018 Position 41-1.tif.mortality.tab ------ MAX_18102018 Position 67-1.tif.mortality.tab
# MAX_18102018 Position 44-1.tif.mortality.tab ------ MAX_18102018 Position 56-1.tif.mortality.tab
# MAX_18102018 Position 44-1.tif.mortality.tab ------ MAX_18102018 Position 57-1.tif.mortality.tab
# MAX_18102018 Position 44-1.tif.mortality.tab ------ MAX_18102018 Position 58-1.tif.mortality.tab
# MAX_18102018 Position 44-1.tif.mortality.tab ------ MAX_18102018 Position 61-1.tif.mortality.tab
# MAX_18102018 Position 44-1.tif.mortality.tab ------ MAX_18102018 Position 67-1.tif.mortality.tab
# MAX_18102018 Position 56-1.tif.mortality.tab ------ MAX_18102018 Position 57-1.tif.mortality.tab
# MAX_18102018 Position 56-1.tif.mortality.tab ------ MAX_18102018 Position 58-1.tif.mortality.tab
# MAX_18102018 Position 56-1.tif.mortality.tab ------ MAX_18102018 Position 61-1.tif.mortality.tab
# MAX_18102018 Position 56-1.tif.mortality.tab ------ MAX_18102018 Position 67-1.tif.mortality.tab
# MAX_18102018 Position 57-1.tif.mortality.tab ------ MAX_18102018 Position 58-1.tif.mortality.tab
# MAX_18102018 Position 57-1.tif.mortality.tab ------ MAX_18102018 Position 61-1.tif.mortality.tab
# MAX_18102018 Position 57-1.tif.mortality.tab ------ MAX_18102018 Position 67-1.tif.mortality.tab
# MAX_18102018 Position 58-1.tif.mortality.tab ------ MAX_18102018 Position 61-1.tif.mortality.tab
# MAX_18102018 Position 58-1.tif.mortality.tab ------ MAX_18102018 Position 67-1.tif.mortality.tab
# MAX_18102018 Position 61-1.tif.mortality.tab ------ MAX_18102018 Position 67-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_dentrogram-all-files.eps
# [['MAX_18102018 Position 44-1.tif.mortality.tab', 'MAX_18102018 Position 56-1.tif.mortality.tab'], ['MAX_18102018 Position 41-1.tif.mortality.tab', 'MAX_18102018 Position 58-1.tif.mortality.tab', 'MAX_18102018 Position 61-1.tif.mortality.tab'], ['MAX_18102018 Position 57-1.tif.mortality.tab'], ['MAX_18102018 Position 67-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 64.11596   sv2= 0.248747   df= 14.27073   lambda= 257.7557
# phi= 68.31583   sv2= 0.01538608   df= 6.982991   lambda= 4440.105
# phi= 73.9993   sv2= 0.002941328   df= 3.944582   lambda= 25158.47
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.77275   sv2= 0.2034933   df= 13.14605   lambda= 239.6774
# phi= 51.8538   sv2= 0.01748336   df= 6.582299   lambda= 2965.894
# phi= 55.92234   sv2= 0.002362685   df= 3.977174   lambda= 23668.98
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcuA/CR-TA_dcuA-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 64.11596   sv2= 0.248747   df= 14.27073   lambda= 257.7557
# phi= 68.31583   sv2= 0.01538608   df= 6.982991   lambda= 4440.105
# phi= 73.9993   sv2= 0.002941328   df= 3.944582   lambda= 25158.47
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.77275   sv2= 0.2034933   df= 13.14605   lambda= 239.6774
# phi= 51.8538   sv2= 0.01748336   df= 6.582299   lambda= 2965.894
# phi= 55.92234   sv2= 0.002362685   df= 3.977174   lambda= 23668.98
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  109.916962  107.429014  113.598846  0.000247, 1:                  est       L95%        U95%       var
# lifespan  102.492421  93.857627  107.365875  0.000389}
