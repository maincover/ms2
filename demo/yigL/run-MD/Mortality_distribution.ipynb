# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigL'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigL/TA_yigL-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigL/TA_yigL-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigL
# Iterations: relative error in phi-hat = 1e-04
# phi= 19.39171   sv2= 0.2619818   df= 17.10851   lambda= 74.01931
# phi= 19.96506   sv2= 0.04313725   df= 11.0721   lambda= 462.8264
# phi= 20.5454   sv2= 0.01063646   df= 7.361644   lambda= 1931.602
# phi= 20.99018   sv2= 0.004533942   df= 5.404317   lambda= 4629.566
# phi= 21.26879   sv2= 0.002658419   df= 4.499082   lambda= 8000.541
# phi= 21.44676   sv2= 0.001866972   df= 4.024212   lambda= 11487.46
# save file prefixed name is : TA_yigL-1_df_relative_timegrid-vs-TA_yigL-1_timeseries_dataframe
# biName is :  TA_yigL-1_df_relative_timegrid-vs-TA_yigL-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yigL/run-MD
# No error in flxsrv_fit
# TA_yigL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yigL/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yigL/run-MD
# TA_yigL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 19.39171   sv2= 0.2619818   df= 17.10851   lambda= 74.01931
# phi= 19.96506   sv2= 0.04313725   df= 11.0721   lambda= 462.8264
# phi= 20.5454   sv2= 0.01063646   df= 7.361644   lambda= 1931.602
# phi= 20.99018   sv2= 0.004533942   df= 5.404317   lambda= 4629.566
# phi= 21.26879   sv2= 0.002658419   df= 4.499082   lambda= 8000.541
# phi= 21.44676   sv2= 0.001866972   df= 4.024212   lambda= 11487.46
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yigL/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yigL-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yigL-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigL/MD-TA_yigL-1_df_relative_timegrid-vs-TA_yigL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yigL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=25341.910381)
#                 est        L95%         U95%          se
# rate       0.074649    0.066226     0.084143    0.004560
# beta    1754.514147  992.805865  3100.626216  509.724476
# s          1.004383    0.765611     1.317623    0.139107
# lambda     0.000621    0.000433     0.000892    0.000114
#                 est       L95%       U95%       var
# lifespan  97.028364  95.937126  97.590393  0.000088
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigL/MD-TA_yigL-1_df_relative_timegrid-vs-TA_yigL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yigL-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yigL/run-MD
