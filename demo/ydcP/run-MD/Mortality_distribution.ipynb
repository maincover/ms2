# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydcP'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydcP/TA_ydcP-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydcP/TA_ydcP-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydcP
# Iterations: relative error in phi-hat = 1e-04
# phi= 35.74289   sv2= 0.4581736   df= 16.2094   lambda= 78.01168
# phi= 38.05827   sv2= 0.07826698   df= 10.32735   lambda= 486.2621
# phi= 39.53437   sv2= 0.02491275   df= 6.911197   lambda= 1586.913
# phi= 40.90193   sv2= 0.01078963   df= 5.384053   lambda= 3790.855
# phi= 42.11138   sv2= 0.004713676   df= 4.513617   lambda= 8933.872
# phi= 43.11134   sv2= 0.001856705   df= 3.823149   lambda= 23219.28
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_ydcP-1_df_relative_timegrid-vs-TA_ydcP-1_timeseries_dataframe
# biName is :  TA_ydcP-1_df_relative_timegrid-vs-TA_ydcP-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ydcP/run-MD
# No error in flxsrv_fit
# TA_ydcP-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ydcP/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ydcP/run-MD
# TA_ydcP-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 35.74289   sv2= 0.4581736   df= 16.2094   lambda= 78.01168
# phi= 38.05827   sv2= 0.07826698   df= 10.32735   lambda= 486.2621
# phi= 39.53437   sv2= 0.02491275   df= 6.911197   lambda= 1586.913
# phi= 40.90193   sv2= 0.01078963   df= 5.384053   lambda= 3790.855
# phi= 42.11138   sv2= 0.004713676   df= 4.513617   lambda= 8933.872
# phi= 43.11134   sv2= 0.001856705   df= 3.823149   lambda= 23219.28
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ydcP/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydcP-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ydcP-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydcP/MD-TA_ydcP-1_df_relative_timegrid-vs-TA_ydcP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ydcP-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=22113.922678)
#                est          L95%        U95%         se
# rate      0.045592  4.231313e-02    0.049125   0.001736
# beta    322.788779  2.507469e+02  415.529013  41.593460
# s         1.862783  1.279807e+00    2.711317   0.356751
# lambda    0.000002  1.386066e-10    0.023457   0.000009
#                  est        L95%        U95%       var
# lifespan  111.185354  109.971938  112.430517  0.000094
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydcP/MD-TA_ydcP-1_df_relative_timegrid-vs-TA_ydcP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydcP-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ydcP/run-MD
