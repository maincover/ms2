# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alsB'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alsB/TA_alsB-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alsB/TA_alsB-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alsB
# Iterations: relative error in phi-hat = 1e-04
# phi= 53.93867   sv2= 0.3317551   df= 19.02523   lambda= 162.5858
# phi= 58.65529   sv2= 0.02434689   df= 10.30009   lambda= 2409.15
# phi= 62.24322   sv2= 0.002902204   df= 5.720259   lambda= 21446.88
# save file prefixed name is : TA_alsB-1_df_relative_timegrid-vs-TA_alsB-1_timeseries_dataframe
# biName is :  TA_alsB-1_df_relative_timegrid-vs-TA_alsB-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/alsB/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_alsB-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/alsB/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/alsB/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_alsB-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 53.93867   sv2= 0.3317551   df= 19.02523   lambda= 162.5858
# phi= 58.65529   sv2= 0.02434689   df= 10.30009   lambda= 2409.15
# phi= 62.24322   sv2= 0.002902204   df= 5.720259   lambda= 21446.88
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/alsB/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_alsB-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_alsB-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alsB/MD-TA_alsB-1_df_relative_timegrid-vs-TA_alsB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_alsB-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=36350.889072)
#                est          L95%        U95%         se
# rate      0.034599  3.205884e-02    0.037341   0.001346
# beta    103.320201  7.556006e+01  141.279195  16.494905
# s         3.685278  2.339109e+00    5.806175   0.854729
# lambda    0.000002  8.745617e-11    0.050187   0.000011
#                 est       L95%       U95%       var
# lifespan  87.793587  86.380193  88.972472  0.000066
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alsB/MD-TA_alsB-1_df_relative_timegrid-vs-TA_alsB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_alsB-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/alsB/run-MD
