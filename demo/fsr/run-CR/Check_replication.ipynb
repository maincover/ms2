# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/TA_fsr-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/TA_fsr-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/TA_fsr-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr']
#
# out_name_s  ['TA_fsr-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/TA_fsr-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/TA_fsr-1_analysis_metadata.pickle
# MAX_12072015 Position 100-1.tif.mortality.tab ------ MAX_12072015 Position 178-1.tif.mortality.tab
# MAX_12072015 Position 100-1.tif.mortality.tab ------ MAX_12072015 Position 181-1.tif.mortality.tab
# MAX_12072015 Position 100-1.tif.mortality.tab ------ MAX_12072015 Position 182-1.tif.mortality.tab
# MAX_12072015 Position 100-1.tif.mortality.tab ------ MAX_12072015 Position 183-1.tif.mortality.tab
# MAX_12072015 Position 100-1.tif.mortality.tab ------ MAX_12072015 Position 186-1.tif.mortality.tab
# MAX_12072015 Position 100-1.tif.mortality.tab ------ MAX_12072015 Position 91-1.tif.mortality.tab
# MAX_12072015 Position 100-1.tif.mortality.tab ------ MAX_12072015 Position 97-1.tif.mortality.tab
# MAX_12072015 Position 178-1.tif.mortality.tab ------ MAX_12072015 Position 181-1.tif.mortality.tab
# MAX_12072015 Position 178-1.tif.mortality.tab ------ MAX_12072015 Position 182-1.tif.mortality.tab
# MAX_12072015 Position 178-1.tif.mortality.tab ------ MAX_12072015 Position 183-1.tif.mortality.tab
# MAX_12072015 Position 178-1.tif.mortality.tab ------ MAX_12072015 Position 186-1.tif.mortality.tab
# MAX_12072015 Position 178-1.tif.mortality.tab ------ MAX_12072015 Position 91-1.tif.mortality.tab
# MAX_12072015 Position 178-1.tif.mortality.tab ------ MAX_12072015 Position 97-1.tif.mortality.tab
# MAX_12072015 Position 181-1.tif.mortality.tab ------ MAX_12072015 Position 182-1.tif.mortality.tab
# MAX_12072015 Position 181-1.tif.mortality.tab ------ MAX_12072015 Position 183-1.tif.mortality.tab
# MAX_12072015 Position 181-1.tif.mortality.tab ------ MAX_12072015 Position 186-1.tif.mortality.tab
# MAX_12072015 Position 181-1.tif.mortality.tab ------ MAX_12072015 Position 91-1.tif.mortality.tab
# MAX_12072015 Position 181-1.tif.mortality.tab ------ MAX_12072015 Position 97-1.tif.mortality.tab
# MAX_12072015 Position 182-1.tif.mortality.tab ------ MAX_12072015 Position 183-1.tif.mortality.tab
# MAX_12072015 Position 182-1.tif.mortality.tab ------ MAX_12072015 Position 186-1.tif.mortality.tab
# MAX_12072015 Position 182-1.tif.mortality.tab ------ MAX_12072015 Position 91-1.tif.mortality.tab
# MAX_12072015 Position 182-1.tif.mortality.tab ------ MAX_12072015 Position 97-1.tif.mortality.tab
# MAX_12072015 Position 183-1.tif.mortality.tab ------ MAX_12072015 Position 186-1.tif.mortality.tab
# MAX_12072015 Position 183-1.tif.mortality.tab ------ MAX_12072015 Position 91-1.tif.mortality.tab
# MAX_12072015 Position 183-1.tif.mortality.tab ------ MAX_12072015 Position 97-1.tif.mortality.tab
# MAX_12072015 Position 186-1.tif.mortality.tab ------ MAX_12072015 Position 91-1.tif.mortality.tab
# MAX_12072015 Position 186-1.tif.mortality.tab ------ MAX_12072015 Position 97-1.tif.mortality.tab
# MAX_12072015 Position 91-1.tif.mortality.tab ------ MAX_12072015 Position 97-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_dentrogram-all-files.eps
# [['MAX_12072015 Position 181-1.tif.mortality.tab', 'MAX_12072015 Position 182-1.tif.mortality.tab', 'MAX_12072015 Position 186-1.tif.mortality.tab'], ['MAX_12072015 Position 100-1.tif.mortality.tab', 'MAX_12072015 Position 91-1.tif.mortality.tab', 'MAX_12072015 Position 97-1.tif.mortality.tab'], ['MAX_12072015 Position 183-1.tif.mortality.tab'], ['MAX_12072015 Position 178-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 344.889   sv2= 0.1325364   df= 13.66108   lambda= 2602.22
# phi= 366.5754   sv2= 0.00563605   df= 4.020149   lambda= 65041.2
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.28266   sv2= 0.08881093   df= 11.72019   lambda= 239.6401
# phi= 22.17276   sv2= 0.01287377   df= 5.938747   lambda= 1722.32
# phi= 22.81352   sv2= 0.004978367   df= 4.026322   lambda= 4582.53
# phi= 23.33102   sv2= 0.002496088   df= 3.358885   lambda= 9347.033
# phi= 23.7772   sv2= 0.001349663   df= 2.950453   lambda= 17617.14
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fsr/CR-TA_fsr-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 290.9468   sv2= 0.1519913   df= 14.5982   lambda= 1914.234
# phi= 303.6468   sv2= 0.006042856   df= 4.575778   lambda= 50248.9
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.28266   sv2= 0.08881093   df= 11.72019   lambda= 239.6401
# phi= 22.17276   sv2= 0.01287377   df= 5.938747   lambda= 1722.32
# phi= 22.81352   sv2= 0.004978367   df= 4.026322   lambda= 4582.53
# phi= 23.33102   sv2= 0.002496088   df= 3.358885   lambda= 9347.033
# phi= 23.7772   sv2= 0.001349663   df= 2.950453   lambda= 17617.14
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  107.948402  106.579192  109.319619  0.000074, 1:                  est        L95%        U95%       var
# lifespan  114.246539  112.828996  116.957965  0.000332}
