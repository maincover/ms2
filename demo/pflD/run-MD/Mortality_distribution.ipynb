# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/TA_pflD-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/TA_pflD-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD
# Iterations: relative error in phi-hat = 1e-04
# phi= 86.03976   sv2= 0.1811399   df= 21.35128   lambda= 474.9906
# phi= 88.15832   sv2= 0.01078766   df= 9.345103   lambda= 8172.144
# phi= 89.35954   sv2= 0.003155395   df= 5.047475   lambda= 28319.61
# save file prefixed name is : TA_pflD-1_df_relative_timegrid-vs-TA_pflD-1_timeseries_dataframe
# biName is :  TA_pflD-1_df_relative_timegrid-vs-TA_pflD-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/pflD/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_pflD-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/pflD/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/pflD/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_pflD-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 86.03976   sv2= 0.1811399   df= 21.35128   lambda= 474.9906
# phi= 88.15832   sv2= 0.01078766   df= 9.345103   lambda= 8172.144
# phi= 89.35954   sv2= 0.003155395   df= 5.047475   lambda= 28319.61
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/pflD/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pflD-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_pflD-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/MD-TA_pflD-1_df_relative_timegrid-vs-TA_pflD-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_pflD-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=82201.652084)
#                  est          L95%        U95%        se
# rate    6.680279e-02  6.396392e-02    0.069768  0.001480
# beta    1.381502e+02  1.239569e+02  153.968643  7.641233
# s       8.280697e-01  7.450916e-01    0.920289  0.044611
# lambda  4.435323e-07  4.768978e-11    0.004125  0.000002
#                 est       L95%       U95%       var
# lifespan  78.394184  77.400109  79.378405  0.000026
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/MD-TA_pflD-1_df_relative_timegrid-vs-TA_pflD-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pflD-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/pflD/run-MD
