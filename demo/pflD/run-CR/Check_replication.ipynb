# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/TA_pflD-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/TA_pflD-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/TA_pflD-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD']
#
# out_name_s  ['TA_pflD-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/TA_pflD-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/TA_pflD-1_analysis_metadata.pickle
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 127-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 128-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 129-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 130-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 131-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 133-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 134-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 125-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 128-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 129-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 130-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 131-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 133-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 134-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 127-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 128-1.tif.mortality.tab ------ MAX_17022015 Position 129-1.tif.mortality.tab
# MAX_17022015 Position 128-1.tif.mortality.tab ------ MAX_17022015 Position 130-1.tif.mortality.tab
# MAX_17022015 Position 128-1.tif.mortality.tab ------ MAX_17022015 Position 131-1.tif.mortality.tab
# MAX_17022015 Position 128-1.tif.mortality.tab ------ MAX_17022015 Position 133-1.tif.mortality.tab
# MAX_17022015 Position 128-1.tif.mortality.tab ------ MAX_17022015 Position 134-1.tif.mortality.tab
# MAX_17022015 Position 128-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 128-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 129-1.tif.mortality.tab ------ MAX_17022015 Position 130-1.tif.mortality.tab
# MAX_17022015 Position 129-1.tif.mortality.tab ------ MAX_17022015 Position 131-1.tif.mortality.tab
# MAX_17022015 Position 129-1.tif.mortality.tab ------ MAX_17022015 Position 133-1.tif.mortality.tab
# MAX_17022015 Position 129-1.tif.mortality.tab ------ MAX_17022015 Position 134-1.tif.mortality.tab
# MAX_17022015 Position 129-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 129-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 130-1.tif.mortality.tab ------ MAX_17022015 Position 131-1.tif.mortality.tab
# MAX_17022015 Position 130-1.tif.mortality.tab ------ MAX_17022015 Position 133-1.tif.mortality.tab
# MAX_17022015 Position 130-1.tif.mortality.tab ------ MAX_17022015 Position 134-1.tif.mortality.tab
# MAX_17022015 Position 130-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 130-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 131-1.tif.mortality.tab ------ MAX_17022015 Position 133-1.tif.mortality.tab
# MAX_17022015 Position 131-1.tif.mortality.tab ------ MAX_17022015 Position 134-1.tif.mortality.tab
# MAX_17022015 Position 131-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 131-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 133-1.tif.mortality.tab ------ MAX_17022015 Position 134-1.tif.mortality.tab
# MAX_17022015 Position 133-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 133-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 134-1.tif.mortality.tab ------ MAX_17022015 Position 135-1.tif.mortality.tab
# MAX_17022015 Position 134-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# MAX_17022015 Position 135-1.tif.mortality.tab ------ MAX_17022015 Position 137-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_dentrogram-all-files.eps
# 5 [1 2 4 3 3]
# [['MAX_17022015 Position 131-1.tif.mortality.tab', 'MAX_17022015 Position 133-1.tif.mortality.tab'], ['MAX_17022015 Position 129-1.tif.mortality.tab', 'MAX_17022015 Position 134-1.tif.mortality.tab'], ['MAX_17022015 Position 127-1.tif.mortality.tab', 'MAX_17022015 Position 128-1.tif.mortality.tab', 'MAX_17022015 Position 137-1.tif.mortality.tab'], ['MAX_17022015 Position 125-1.tif.mortality.tab', 'MAX_17022015 Position 130-1.tif.mortality.tab', 'MAX_17022015 Position 135-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 154.5734   sv2= 0.2771311   df= 17.43231   lambda= 557.763
# phi= 162.7697   sv2= 0.00792545   df= 7.094302   lambda= 20537.6
# Iterations: relative error in phi-hat = 1e-04
# phi= 57.42124   sv2= 0.1277316   df= 16.38622   lambda= 449.5462
# phi= 58.56305   sv2= 0.01043889   df= 6.989514   lambda= 5610.085
# phi= 60.09577   sv2= 0.003285704   df= 4.173039   lambda= 18290.07
# Iterations: relative error in phi-hat = 1e-04
# phi= 180.9768   sv2= 0.3546057   df= 15.9741   lambda= 510.3605
# phi= 197.3707   sv2= 0.008327631   df= 6.711868   lambda= 23700.7
# Iterations: relative error in phi-hat = 1e-04
# phi= 71.89298   sv2= 0.1924989   df= 15.42346   lambda= 373.4722
# phi= 78.61149   sv2= 0.00648287   df= 6.825055   lambda= 12126.03
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflD/CR-TA_pflD-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.45933   sv2= 0.1553615   df= 19.48349   lambda= 550.0676
# phi= 88.01831   sv2= 0.008288882   df= 8.02221   lambda= 10618.84
# Iterations: relative error in phi-hat = 1e-04
# phi= 166.9585   sv2= 0.2946374   df= 17.88448   lambda= 566.6575
# phi= 179.1132   sv2= 0.008966212   df= 7.376648   lambda= 19976.46
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  80.400441  79.385304  82.365487  0.000044, 1:                est       L95%       U95%       var
# lifespan  75.42921  74.429902  76.406836  0.000065}
