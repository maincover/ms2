# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/ms2/dataset/MS 2 Github data part 8'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  875  Filtered files length (after MD5 check) :  88
# check line duplication(open file) :  50 / 875
# check line duplication(open file) :  100 / 875
# check line duplication(open file) :  150 / 875
# check line duplication(open file) :  200 / 875
# check line duplication(open file) :  250 / 875
# check line duplication(open file) :  300 / 875
# check line duplication(open file) :  350 / 875
# check line duplication(open file) :  400 / 875
# check line duplication(open file) :  450 / 875
# check line duplication(open file) :  500 / 875
# check line duplication(open file) :  550 / 875
# check line duplication(open file) :  600 / 875
# check line duplication(open file) :  650 / 875
# check line duplication(open file) :  700 / 875
# check line duplication(open file) :  750 / 875
# check line duplication(open file) :  800 / 875
# check line duplication(open file) :  850 / 875
# check line duplication:  0 / 875
# check line duplication:  50 / 875
# check line duplication:  100 / 875
# check line duplication:  150 / 875
# check line duplication:  200 / 875
# check line duplication:  250 / 875
# check line duplication:  300 / 875
# check line duplication:  350 / 875
# check line duplication:  400 / 875
# check line duplication:  450 / 875
# check line duplication:  500 / 875
# check line duplication:  550 / 875
# check line duplication:  600 / 875
# check line duplication:  650 / 875
# check line duplication:  700 / 875
# check line duplication:  750 / 875
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 112-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 113-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 114-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 115-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 116-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 118-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 65-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 66-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 67-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/aqpZ2/MAX_08042016 Position 68-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 122-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 126-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 128-1.tif.mortality.tab
# check line duplication:  800 / 875
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 16-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 18-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 19-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 24-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ascG2/MAX_08042016 Position 26-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/hslR2/MAX_08042016 Position 105-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/hslR2/MAX_08042016 Position 42-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/hslR2/MAX_08042016 Position 78-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/hslR2/MAX_08042016 Position 80-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/hslR2/MAX_08042016 Position 81-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/hslR2/MAX_08042016 Position 94-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 106-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 109-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 111-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 117-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 119-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 120-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 123-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 124-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/ompL2/MAX_08042016 Position 77-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 102-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 30-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 32-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 33-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 34-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 35-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 36-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 37-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 39-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 40-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 44-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 45-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 54-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 61-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 63-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 70-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/pgi2/MAX_08042016 Position 71-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 100-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 110-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 62-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 72-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 73-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 76-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 84-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 88-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 90-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 96-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaB2/MAX_08042016 Position 99-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaC2/MAX_08042016 Position 79-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaC2/MAX_08042016 Position 83-1.tif.mortality.tab
# check line duplication:  850 / 875
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaC2/MAX_08042016 Position 86-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaC2/MAX_08042016 Position 92-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaC2/MAX_08042016 Position 93-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaC2/MAX_08042016 Position 97-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxaC2/MAX_08042016 Position 98-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxuR2/MAX_08042016 Position 69-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxuR2/MAX_08042016 Position 74-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxuR2/MAX_08042016 Position 85-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxuR2/MAX_08042016 Position 89-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxuR2/MAX_08042016 Position 91-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/uxuR2/MAX_08042016 Position 95-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 101-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 104-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 107-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 125-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 127-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 28-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 31-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 38-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 41-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 43-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 46-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 53-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 64-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/ms2/dataset/MS 2 Github data part 8/yfiD2/MAX_08042016 Position 82-1.tif.mortality.tab
