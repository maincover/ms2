# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/TA_tdcE-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/TA_tdcE-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/TA_tdcE-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE']
#
# out_name_s  ['TA_tdcE-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/TA_tdcE-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/TA_tdcE-1_analysis_metadata.pickle
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 133-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 134-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 135-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 138-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 139-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 201-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 203-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 124-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 134-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 135-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 138-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 139-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 201-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 203-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 133-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 135-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 138-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 139-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 201-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 203-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 134-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 138-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 139-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 201-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 203-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 135-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 139-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 201-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 203-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 138-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 201-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 203-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 139-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 201-1.tif.mortality.tab ------ MAX_11102018 Position 203-1.tif.mortality.tab
# MAX_11102018 Position 201-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 201-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 201-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 201-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 201-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 201-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 203-1.tif.mortality.tab ------ MAX_11102018 Position 205-1.tif.mortality.tab
# MAX_11102018 Position 203-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 203-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 203-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 203-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 203-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 205-1.tif.mortality.tab ------ MAX_11102018 Position 216-1.tif.mortality.tab
# MAX_11102018 Position 205-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 205-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 205-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 205-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 216-1.tif.mortality.tab ------ MAX_11102018 Position 217-1.tif.mortality.tab
# MAX_11102018 Position 216-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 216-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 216-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 217-1.tif.mortality.tab ------ MAX_11102018 Position 218-1.tif.mortality.tab
# MAX_11102018 Position 217-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 217-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 218-1.tif.mortality.tab ------ MAX_11102018 Position 219-1.tif.mortality.tab
# MAX_11102018 Position 218-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# MAX_11102018 Position 219-1.tif.mortality.tab ------ MAX_11102018 Position 220-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_dentrogram-all-files.eps
# [['MAX_11102018 Position 133-1.tif.mortality.tab', 'MAX_11102018 Position 135-1.tif.mortality.tab', 'MAX_11102018 Position 138-1.tif.mortality.tab'], ['MAX_11102018 Position 124-1.tif.mortality.tab', 'MAX_11102018 Position 134-1.tif.mortality.tab', 'MAX_11102018 Position 139-1.tif.mortality.tab'], ['MAX_11102018 Position 203-1.tif.mortality.tab', 'MAX_11102018 Position 216-1.tif.mortality.tab'], ['MAX_11102018 Position 201-1.tif.mortality.tab', 'MAX_11102018 Position 205-1.tif.mortality.tab', 'MAX_11102018 Position 218-1.tif.mortality.tab', 'MAX_11102018 Position 219-1.tif.mortality.tab', 'MAX_11102018 Position 220-1.tif.mortality.tab'], ['MAX_11102018 Position 217-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 119.973   sv2= 0.2860041   df= 11.95372   lambda= 419.48
# phi= 132.2313   sv2= 0.008870435   df= 5.442604   lambda= 14906.97
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.09854   sv2= 0.1536546   df= 11.21273   lambda= 306.5222
# phi= 47.67295   sv2= 0.01160488   df= 5.426052   lambda= 4108.007
# phi= 47.86162   sv2= 0.0007823416   df= 3.278507   lambda= 61177.39
# Iterations: relative error in phi-hat = 1e-04
# phi= 57.69308   sv2= 0.0384902   df= 9.510996   lambda= 1498.903
# phi= 57.59522   sv2= 0.004984549   df= 3.214175   lambda= 11554.75
# Iterations: relative error in phi-hat = 1e-04
# phi= 97.89414   sv2= 0.1182495   df= 10.25445   lambda= 827.8606
# phi= 110.536   sv2= 0.008270479   df= 4.1189   lambda= 13365.13
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/tdcE/CR-TA_tdcE-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 121.5515   sv2= 0.2840071   df= 13.37517   lambda= 427.9875
# phi= 138.0919   sv2= 0.009333465   df= 5.979175   lambda= 14795.35
# Iterations: relative error in phi-hat = 1e-04
# phi= 119.6569   sv2= 0.09720851   df= 11.82441   lambda= 1230.93
# phi= 123.4581   sv2= 0.008096611   df= 4.240925   lambda= 15248.12
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  123.453179  121.048578  125.879635  0.000181, 1:                  est        L95%        U95%       var
# lifespan  112.811892  111.574543  114.029566  0.000274}
