# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/TA_yjgB-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/TA_yjgB-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB
# Iterations: relative error in phi-hat = 1e-04
# phi= 20.48099   sv2= 0.2617949   df= 14.02639   lambda= 78.23296
# phi= 21.33797   sv2= 0.0616875   df= 8.929196   lambda= 345.9042
# phi= 21.66227   sv2= 0.02885105   df= 6.530841   lambda= 750.8314
# phi= 21.79052   sv2= 0.01980446   df= 5.596234   lambda= 1100.283
# phi= 21.88253   sv2= 0.01626393   df= 5.196875   lambda= 1345.464
# phi= 21.94327   sv2= 0.01465351   df= 5.000783   lambda= 1497.476
# phi= 21.97951   sv2= 0.01387083   df= 4.900143   lambda= 1584.585
# phi= 21.9998   sv2= 0.01347853   df= 4.847981   lambda= 1632.212
# phi= 22.01076   sv2= 0.01327891   df= 4.820932   lambda= 1657.572
# phi= 22.01655   sv2= 0.01317658   df= 4.806922   lambda= 1670.885
# phi= 22.01957   sv2= 0.01312392   df= 4.799672   lambda= 1677.82
# phi= 22.02115   sv2= 0.01309677   df= 4.795924   lambda= 1681.419
# phi= 22.02197   sv2= 0.01308275   df= 4.793986   lambda= 1683.282
# phi= 22.02239   sv2= 0.01307552   df= 4.792985   lambda= 1684.246
# phi= 22.02261   sv2= 0.01307178   df= 4.792467   lambda= 1684.744
# phi= 22.02272   sv2= 0.01306985   df= 4.7922   lambda= 1685.002
# phi= 22.02278   sv2= 0.01306885   df= 4.792062   lambda= 1685.135
# save file prefixed name is : TA_yjgB-1_df_relative_timegrid-vs-TA_yjgB-1_timeseries_dataframe
# biName is :  TA_yjgB-1_df_relative_timegrid-vs-TA_yjgB-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yjgB/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yjgB-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yjgB/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjgB/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yjgB-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 20.48099   sv2= 0.2617949   df= 14.02639   lambda= 78.23296
# phi= 21.33797   sv2= 0.0616875   df= 8.929196   lambda= 345.9042
# phi= 21.66227   sv2= 0.02885105   df= 6.530841   lambda= 750.8314
# phi= 21.79052   sv2= 0.01980446   df= 5.596234   lambda= 1100.283
# phi= 21.88253   sv2= 0.01626393   df= 5.196875   lambda= 1345.464
# phi= 21.94327   sv2= 0.01465351   df= 5.000783   lambda= 1497.476
# phi= 21.97951   sv2= 0.01387083   df= 4.900143   lambda= 1584.585
# phi= 21.9998   sv2= 0.01347853   df= 4.847981   lambda= 1632.212
# phi= 22.01076   sv2= 0.01327891   df= 4.820932   lambda= 1657.572
# phi= 22.01655   sv2= 0.01317658   df= 4.806922   lambda= 1670.885
# phi= 22.01957   sv2= 0.01312392   df= 4.799672   lambda= 1677.82
# phi= 22.02115   sv2= 0.01309677   df= 4.795924   lambda= 1681.419
# phi= 22.02197   sv2= 0.01308275   df= 4.793986   lambda= 1683.282
# phi= 22.02239   sv2= 0.01307552   df= 4.792985   lambda= 1684.246
# phi= 22.02261   sv2= 0.01307178   df= 4.792467   lambda= 1684.744
# phi= 22.02272   sv2= 0.01306985   df= 4.7922   lambda= 1685.002
# phi= 22.02278   sv2= 0.01306885   df= 4.792062   lambda= 1685.135
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjgB/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjgB-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yjgB-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/MD-TA_yjgB-1_df_relative_timegrid-vs-TA_yjgB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yjgB-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=13330.533245)
#                  est          L95%          U95%            se
# rate    1.148990e-01  1.006815e-01  1.311242e-01  7.743622e-03
# beta    5.560442e+06  1.373703e+06  2.250742e+07  3.966619e+06
# s       1.219929e+00  6.605227e-01  2.253105e+00  3.818676e-01
# lambda  2.077913e-03  1.854738e-03  2.327942e-03  1.204580e-04
#                  est        L95%        U95%       var
# lifespan  129.175174  128.648531  129.823677  0.000139
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/MD-TA_yjgB-1_df_relative_timegrid-vs-TA_yjgB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjgB-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yjgB/run-MD
