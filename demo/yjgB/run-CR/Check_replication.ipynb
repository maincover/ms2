# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/TA_yjgB-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/TA_yjgB-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/TA_yjgB-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB']
#
# out_name_s  ['TA_yjgB-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/TA_yjgB-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/TA_yjgB-1_analysis_metadata.pickle
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 141-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 142-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 143-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 144-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 145-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 42-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 51-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 140-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 142-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 143-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 144-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 145-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 42-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 51-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 141-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 143-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 144-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 145-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 42-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 51-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 142-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 144-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 145-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 42-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 51-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 143-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 145-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 42-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 51-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 144-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 42-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 51-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 145-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 42-1.tif.mortality.tab ------ MAX_28062016 Position 51-1.tif.mortality.tab
# MAX_28062016 Position 42-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 42-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 42-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 42-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 42-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 42-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 51-1.tif.mortality.tab ------ MAX_28062016 Position 56-1.tif.mortality.tab
# MAX_28062016 Position 51-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 51-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 51-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 51-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 51-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 56-1.tif.mortality.tab ------ MAX_28062016 Position 58-1.tif.mortality.tab
# MAX_28062016 Position 56-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 56-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 56-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 56-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 58-1.tif.mortality.tab ------ MAX_28062016 Position 62-1.tif.mortality.tab
# MAX_28062016 Position 58-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 58-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 58-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 62-1.tif.mortality.tab ------ MAX_28062016 Position 63-1.tif.mortality.tab
# MAX_28062016 Position 62-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 62-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 63-1.tif.mortality.tab ------ MAX_28062016 Position 64-1.tif.mortality.tab
# MAX_28062016 Position 63-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# MAX_28062016 Position 64-1.tif.mortality.tab ------ MAX_28062016 Position 95-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_dentrogram-all-files.eps
# 6 [1 2 3 3 4 5]
# [['MAX_28062016 Position 140-1.tif.mortality.tab', 'MAX_28062016 Position 141-1.tif.mortality.tab', 'MAX_28062016 Position 142-1.tif.mortality.tab', 'MAX_28062016 Position 143-1.tif.mortality.tab', 'MAX_28062016 Position 144-1.tif.mortality.tab', 'MAX_28062016 Position 145-1.tif.mortality.tab'], ['MAX_28062016 Position 51-1.tif.mortality.tab'], ['MAX_28062016 Position 42-1.tif.mortality.tab', 'MAX_28062016 Position 56-1.tif.mortality.tab', 'MAX_28062016 Position 58-1.tif.mortality.tab', 'MAX_28062016 Position 63-1.tif.mortality.tab', 'MAX_28062016 Position 64-1.tif.mortality.tab'], ['MAX_28062016 Position 62-1.tif.mortality.tab'], ['MAX_28062016 Position 95-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.36688   sv2= 0.1750574   df= 9.27734   lambda= 339.128
# phi= 63.97115   sv2= 0.03201265   df= 4.714848   lambda= 1998.308
# phi= 71.99753   sv2= 0.01391684   df= 3.47797   lambda= 5173.41
# phi= 77.15753   sv2= 0.01147639   df= 3.001396   lambda= 6723.155
# phi= 79.32741   sv2= 0.01077451   df= 2.881719   lambda= 7362.507
# phi= 80.21787   sv2= 0.01051383   df= 2.840763   lambda= 7629.745
# phi= 80.58994   sv2= 0.01040913   df= 2.824751   lambda= 7742.239
# phi= 80.74655   sv2= 0.01036576   df= 2.818187   lambda= 7789.736
# phi= 80.81268   sv2= 0.01034758   df= 2.815446   lambda= 7809.817
# phi= 80.84063   sv2= 0.01033991   df= 2.814292   lambda= 7818.31
# phi= 80.85246   sv2= 0.01033667   df= 2.813806   lambda= 7821.904
# phi= 80.85746   sv2= 0.0103353   df= 2.8136   lambda= 7823.425
# phi= 80.85958   sv2= 0.01033472   df= 2.813513   lambda= 7824.068
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.03365   sv2= 0.3003657   df= 11.89094   lambda= 146.6001
# phi= 51.37209   sv2= 0.04198262   df= 6.676145   lambda= 1223.651
# phi= 55.07226   sv2= 0.01715433   df= 4.448138   lambda= 3210.4
# phi= 58.46299   sv2= 0.01136346   df= 3.746404   lambda= 5144.824
# phi= 61.16272   sv2= 0.009370349   df= 3.453924   lambda= 6527.262
# phi= 62.8751   sv2= 0.008527407   df= 3.318104   lambda= 7373.297
# phi= 63.85617   sv2= 0.00813   df= 3.251446   lambda= 7854.387
# phi= 64.39466   sv2= 0.007931801   df= 3.21762   lambda= 8118.542
# phi= 64.68482   sv2= 0.007830051   df= 3.200115   lambda= 8261.099
# phi= 64.83986   sv2= 0.007777025   df= 3.190957   lambda= 8337.36
# phi= 64.92236   sv2= 0.007749174   df= 3.186138   lambda= 8377.972
# phi= 64.96617   sv2= 0.007734485   df= 3.183593   lambda= 8399.548
# phi= 64.98942   sv2= 0.00772672   df= 3.182248   lambda= 8410.996
# phi= 65.00174   sv2= 0.007722612   df= 3.181536   lambda= 8417.067
# phi= 65.00827   sv2= 0.007720436   df= 3.181158   lambda= 8420.285
# phi= 65.01173   sv2= 0.007719284   df= 3.180959   lambda= 8421.99
# phi= 65.01356   sv2= 0.007718673   df= 3.180853   lambda= 8422.894
# phi= 65.01454   sv2= 0.00771835   df= 3.180797   lambda= 8423.372
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.58159   sv2= 0.188059   df= 9.569717   lambda= 242.3792
# phi= 49.75472   sv2= 0.02899434   df= 5.084288   lambda= 1716.015
# phi= 56.61749   sv2= 0.0143796   df= 3.564192   lambda= 3937.348
# phi= 60.57416   sv2= 0.01291678   df= 3.091369   lambda= 4689.57
# phi= 61.73091   sv2= 0.01255705   df= 3.00004   lambda= 4916.036
# phi= 62.07597   sv2= 0.01245173   df= 2.975718   lambda= 4985.328
# phi= 62.1814   sv2= 0.01241977   df= 2.968523   lambda= 5006.648
# phi= 62.21383   sv2= 0.01240995   df= 2.966331   lambda= 5013.22
# phi= 62.22382   sv2= 0.01240693   df= 2.965657   lambda= 5015.247
# phi= 62.22691   sv2= 0.012406   df= 2.96545   lambda= 5015.872
# phi= 62.22786   sv2= 0.01240571   df= 2.965386   lambda= 5016.065
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.68019   sv2= 0.3354488   df= 12.53227   lambda= 142.1385
# phi= 53.69585   sv2= 0.04095379   df= 7.053621   lambda= 1311.133
# phi= 56.05725   sv2= 0.01338206   df= 4.563097   lambda= 4188.985
# phi= 57.60824   sv2= 0.008298204   df= 3.696318   lambda= 6942.254
# phi= 58.98136   sv2= 0.007101325   df= 3.386578   lambda= 8305.684
# phi= 59.64951   sv2= 0.006746635   df= 3.285473   lambda= 8841.371
# phi= 59.90918   sv2= 0.006628043   df= 3.251244   lambda= 9038.744
# phi= 60.00442   sv2= 0.00658663   df= 3.239275   lambda= 9110.034
# phi= 60.03876   sv2= 0.006571947   df= 3.235031   lambda= 9135.611
# phi= 60.05107   sv2= 0.006566714   df= 3.233518   lambda= 9144.767
# phi= 60.05548   sv2= 0.006564846   df= 3.232978   lambda= 9148.041
# phi= 60.05705   sv2= 0.006564178   df= 3.232785   lambda= 9149.211
# phi= 60.05761   sv2= 0.006563939   df= 3.232716   lambda= 9149.63
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  135.055614  133.870708  136.941341  0.000353, 1:                  est        L95%        U95%       var
# lifespan  116.219325  110.311776  117.339789  0.000351}
