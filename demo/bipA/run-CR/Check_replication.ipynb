# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/TA_bipA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/TA_bipA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/TA_bipA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA']
#
# out_name_s  ['TA_bipA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/TA_bipA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/TA_bipA-1_analysis_metadata.pickle
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 26-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 29-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 45-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 72-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 74-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 75-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 77-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 14-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 29-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 45-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 72-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 74-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 75-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 77-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 26-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 45-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 72-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 74-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 75-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 77-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 29-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 72-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 74-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 75-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 77-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 45-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 72-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 74-1.tif.mortality.tab
# MAX_28072014 mRFP Position 72-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 75-1.tif.mortality.tab
# MAX_28072014 mRFP Position 72-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 77-1.tif.mortality.tab
# MAX_28072014 mRFP Position 72-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 72-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 72-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 72-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 74-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 75-1.tif.mortality.tab
# MAX_28072014 mRFP Position 74-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 77-1.tif.mortality.tab
# MAX_28072014 mRFP Position 74-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 74-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 74-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 74-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 75-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 77-1.tif.mortality.tab
# MAX_28072014 mRFP Position 75-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 75-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 75-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 75-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 77-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 78-1.tif.mortality.tab
# MAX_28072014 mRFP Position 77-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 77-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 77-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 78-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 83-1.tif.mortality.tab
# MAX_28072014 mRFP Position 78-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 78-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 83-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 87-1.tif.mortality.tab
# MAX_28072014 mRFP Position 83-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# MAX_28072014 mRFP Position 87-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 89-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_dentrogram-all-files.eps
# 6 [1 2 3 3 4 5]
# [['MAX_28072014 mRFP Position 26-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 77-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 78-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 45-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 29-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 75-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 83-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 14-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 72-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 74-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 87-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 89-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 186.1611   sv2= 0.2638882   df= 15.35023   lambda= 705.4545
# phi= 193.2381   sv2= 0.004546793   df= 6.009354   lambda= 42499.86
# Iterations: relative error in phi-hat = 1e-04
# phi= 36.88355   sv2= 0.09694063   df= 13.45972   lambda= 380.4756
# phi= 38.24839   sv2= 0.005483178   df= 6.044076   lambda= 6975.588
# phi= 39.56986   sv2= 0.001539626   df= 3.367746   lambda= 25700.95
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.63062   sv2= 0.06912432   df= 9.37772   lambda= 211.6566
# phi= 15.06838   sv2= 0.006635583   df= 4.884277   lambda= 2270.845
# phi= 15.71323   sv2= 0.0007753307   df= 3.075032   lambda= 20266.49
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_mortality_dataframe_cluster2.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/CR-TA_bipA-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 116.4721   sv2= 0.2022393   df= 16.22643   lambda= 575.9122
# phi= 118.8939   sv2= 0.004567862   df= 6.629994   lambda= 26028.36
# Iterations: relative error in phi-hat = 1e-04
# phi= 69.81736   sv2= 0.1221842   df= 13.2946   lambda= 571.4108
# phi= 72.09675   sv2= 0.005011469   df= 5.462085   lambda= 14386.35
# Iterations: relative error in phi-hat = 1e-04
# phi= 12.31209   sv2= 0.0577996   df= 10.4265   lambda= 213.0135
# phi= 12.57027   sv2= 0.004773433   df= 5.363922   lambda= 2633.381
# phi= 12.92663   sv2= 0.0003135386   df= 3.243976   lambda= 41228.19
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  83.579136  82.398179  84.883945  0.000105, 1:                 est       L95%       U95%       var
# lifespan  96.996661  96.996661  97.999698  0.000224, 2:                  est        L95%       U95%     var
# lifespan  107.416593  105.967684  110.98929  0.0006}
