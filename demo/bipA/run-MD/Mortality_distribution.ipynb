# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/TA_bipA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/TA_bipA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA
# Iterations: relative error in phi-hat = 1e-04
# phi= 53.11247   sv2= 0.3302663   df= 17.60371   lambda= 160.8171
# phi= 55.44942   sv2= 0.02073586   df= 9.618715   lambda= 2674.083
# phi= 56.54579   sv2= 0.002423353   df= 5.219261   lambda= 23333.7
# save file prefixed name is : TA_bipA-1_df_relative_timegrid-vs-TA_bipA-1_timeseries_dataframe
# biName is :  TA_bipA-1_df_relative_timegrid-vs-TA_bipA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/bipA/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_bipA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/bipA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/bipA/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_bipA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 53.11247   sv2= 0.3302663   df= 17.60371   lambda= 160.8171
# phi= 55.44942   sv2= 0.02073586   df= 9.618715   lambda= 2674.083
# phi= 56.54579   sv2= 0.002423353   df= 5.219261   lambda= 23333.7
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/bipA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_bipA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_bipA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/MD-TA_bipA-1_df_relative_timegrid-vs-TA_bipA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_bipA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=34749.002773)
#                  est          L95%        U95%         se
# rate    6.080061e-02  5.681250e-02    0.065069   0.002105
# beta    2.843932e+02  2.407745e+02  335.913909  24.158940
# s       1.074905e+00  8.633696e-01    1.338268   0.120185
# lambda  7.809285e-07  2.288116e-11    0.026653   0.000004
#                est       L95%       U95%       var
# lifespan  89.89533  88.940587  91.398219  0.000058
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bipA/MD-TA_bipA-1_df_relative_timegrid-vs-TA_bipA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_bipA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/bipA/run-MD
