# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MG WT 0.2% Glucose'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/TA_MG WT 0.2% Glucose-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/TA_MG WT 0.2% Glucose-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.41887   sv2= 0.1619901   df= 21.28254   lambda= 206.3019
# phi= 33.88097   sv2= 0.02743517   df= 11.2059   lambda= 1234.946
# phi= 34.15453   sv2= 0.009702661   df= 7.534768   lambda= 3520.12
# phi= 34.38778   sv2= 0.004633735   df= 6.026795   lambda= 7421.178
# phi= 34.55958   sv2= 0.002711879   df= 5.167146   lambda= 12743.78
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_MG WT 0.2% Glucose-1_df_relative_timegrid-vs-TA_MG WT 0.2% Glucose-1_timeseries_dataframe
# biName is :  TA_MG WT 0.2% Glucose-1_df_relative_timegrid-vs-TA_MG WT 0.2% Glucose-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MG WT 0.2% Glucose/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_MG WT 0.2% Glucose-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MG WT 0.2% Glucose/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG WT 0.2% Glucose/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_MG WT 0.2% Glucose-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.41887   sv2= 0.1619901   df= 21.28254   lambda= 206.3019
# phi= 33.88097   sv2= 0.02743517   df= 11.2059   lambda= 1234.946
# phi= 34.15453   sv2= 0.009702661   df= 7.534768   lambda= 3520.12
# phi= 34.38778   sv2= 0.004633735   df= 6.026795   lambda= 7421.178
# phi= 34.55958   sv2= 0.002711879   df= 5.167146   lambda= 12743.78
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG WT 0.2% Glucose/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG WT 0.2% Glucose-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_MG WT 0.2% Glucose-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/MD-TA_MG WT 0.2% Glucose-1_df_relative_timegrid-vs-TA_MG WT 0.2% Glucose-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_MG WT 0.2% Glucose-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=78977.797910)
#               est          L95%       U95%        se
# rate     0.043807  4.143748e-02   0.046312  0.001243
# beta    58.178170  5.263134e+01  64.309580  2.974218
# s        0.712317  6.138854e-01   0.826532  0.054048
# lambda   0.000001  9.940250e-10   0.001050  0.000004
#                  est        L95%        U95%       var
# lifespan  106.232614  104.869913  107.337394  0.000025
#
#
# /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/MD-TA_MG WT 0.2% Glucose-1_df_relative_timegrid-vs-TA_MG WT 0.2% Glucose-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG WT 0.2% Glucose-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MG WT 0.2% Glucose/run-MD
