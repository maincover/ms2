# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicH'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicH/TA_yicH-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicH/TA_yicH-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicH
# Iterations: relative error in phi-hat = 1e-04
# phi= 82.68114   sv2= 0.1858303   df= 15.19589   lambda= 444.9282
# phi= 89.58409   sv2= 0.009505373   df= 6.590905   lambda= 9424.574
# phi= 92.37811   sv2= 0.001358387   df= 3.569689   lambda= 68005.72
# save file prefixed name is : TA_yicH-1_df_relative_timegrid-vs-TA_yicH-1_timeseries_dataframe
# biName is :  TA_yicH-1_df_relative_timegrid-vs-TA_yicH-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yicH/run-MD
# No error in flxsrv_fit
# TA_yicH-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yicH/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yicH/run-MD
# TA_yicH-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 82.68114   sv2= 0.1858303   df= 15.19589   lambda= 444.9282
# phi= 89.58409   sv2= 0.009505373   df= 6.590905   lambda= 9424.574
# phi= 92.37811   sv2= 0.001358387   df= 3.569689   lambda= 68005.72
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yicH/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yicH-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yicH-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicH/MD-TA_yicH-1_df_relative_timegrid-vs-TA_yicH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yicH-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=16246.662125)
#                  est         L95%          U95%           se
# rate        0.075890     0.063275      0.091021     0.007039
# beta    11600.006710  3897.700578  34522.958596  6454.805585
# s           1.478255     0.891151      2.452151     0.381716
# lambda      0.001232     0.000934      0.001625     0.000174
#                  est        L95%        U95%      var
# lifespan  112.813412  110.819523  113.288028  0.00013
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicH/MD-TA_yicH-1_df_relative_timegrid-vs-TA_yicH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yicH-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yicH/run-MD
