# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/TA_rsd-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/TA_rsd-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/TA_rsd-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd']
#
# out_name_s  ['TA_rsd-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/TA_rsd-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/TA_rsd-1_analysis_metadata.pickle
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 144-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 162-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 17-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 18-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 19-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 20-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 24-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 141-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 162-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 17-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 18-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 19-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 20-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 24-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 144-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 17-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 18-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 19-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 20-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 24-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 162-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 18-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 19-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 20-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 24-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 17-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 18-1.tif.mortality.tab ------ MAX_12072015 Position 19-1.tif.mortality.tab
# MAX_12072015 Position 18-1.tif.mortality.tab ------ MAX_12072015 Position 20-1.tif.mortality.tab
# MAX_12072015 Position 18-1.tif.mortality.tab ------ MAX_12072015 Position 24-1.tif.mortality.tab
# MAX_12072015 Position 18-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 18-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 18-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 18-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 19-1.tif.mortality.tab ------ MAX_12072015 Position 20-1.tif.mortality.tab
# MAX_12072015 Position 19-1.tif.mortality.tab ------ MAX_12072015 Position 24-1.tif.mortality.tab
# MAX_12072015 Position 19-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 19-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 19-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 19-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 20-1.tif.mortality.tab ------ MAX_12072015 Position 24-1.tif.mortality.tab
# MAX_12072015 Position 20-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 20-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 20-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 20-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 24-1.tif.mortality.tab ------ MAX_12072015 Position 32-1.tif.mortality.tab
# MAX_12072015 Position 24-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 24-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 24-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 32-1.tif.mortality.tab ------ MAX_12072015 Position 56-1.tif.mortality.tab
# MAX_12072015 Position 32-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 32-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 56-1.tif.mortality.tab ------ MAX_12072015 Position 59-1.tif.mortality.tab
# MAX_12072015 Position 56-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# MAX_12072015 Position 59-1.tif.mortality.tab ------ MAX_12072015 Position 83-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_dentrogram-all-files.eps
# [['MAX_12072015 Position 59-1.tif.mortality.tab', 'MAX_12072015 Position 83-1.tif.mortality.tab'], ['MAX_12072015 Position 141-1.tif.mortality.tab', 'MAX_12072015 Position 144-1.tif.mortality.tab', 'MAX_12072015 Position 17-1.tif.mortality.tab', 'MAX_12072015 Position 18-1.tif.mortality.tab', 'MAX_12072015 Position 19-1.tif.mortality.tab', 'MAX_12072015 Position 20-1.tif.mortality.tab', 'MAX_12072015 Position 32-1.tif.mortality.tab'], ['MAX_12072015 Position 24-1.tif.mortality.tab'], ['MAX_12072015 Position 56-1.tif.mortality.tab'], ['MAX_12072015 Position 162-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.86976   sv2= 0.149704   df= 11.47046   lambda= 172.8061
# phi= 27.9341   sv2= 0.03210546   df= 6.26053   lambda= 870.0734
# phi= 29.75216   sv2= 0.006439583   df= 4.505372   lambda= 4620.2
# phi= 30.61374   sv2= 0.001120259   df= 3.263937   lambda= 27327.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 9.154982   sv2= 0.2050026   df= 11.84376   lambda= 44.65788
# phi= 9.888134   sv2= 0.04027556   df= 8.650438   lambda= 245.512
# phi= 10.35479   sv2= 0.006457209   df= 5.974852   lambda= 1603.602
# phi= 10.67587   sv2= 0.001291009   df= 4.00269   lambda= 8269.402
# phi= 10.76228   sv2= 0.0005422702   df= 2.949833   lambda= 19846.72
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rsd/CR-TA_rsd-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.8449   sv2= 0.1000036   df= 12.76341   lambda= 348.4366
# phi= 34.88309   sv2= 0.009225526   df= 5.933367   lambda= 3781.149
# phi= 34.62657   sv2= 0.001546293   df= 3.707397   lambda= 22393.27
# Iterations: relative error in phi-hat = 1e-04
# phi= 9.154982   sv2= 0.2050026   df= 11.84376   lambda= 44.65788
# phi= 9.888134   sv2= 0.04027556   df= 8.650438   lambda= 245.512
# phi= 10.35479   sv2= 0.006457209   df= 5.974852   lambda= 1603.602
# phi= 10.67587   sv2= 0.001291009   df= 4.00269   lambda= 8269.402
# phi= 10.76228   sv2= 0.0005422702   df= 2.949833   lambda= 19846.72
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est       L95%        U95%       var
# lifespan  132.977118  130.76293  134.898362  0.000197, 1:                 est        L95%        U95%       var
# lifespan  124.30103  122.758442  125.680454  0.000252}
