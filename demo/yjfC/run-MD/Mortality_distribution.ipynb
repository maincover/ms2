# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfC'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfC/TA_yjfC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfC/TA_yjfC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfC
# Iterations: relative error in phi-hat = 1e-04
# phi= 245.6947   sv2= 0.314548   df= 17.37184   lambda= 781.1039
# phi= 256.2889   sv2= 0.02125123   df= 6.85411   lambda= 12059.95
# save file prefixed name is : TA_yjfC-1_df_relative_timegrid-vs-TA_yjfC-1_timeseries_dataframe
# biName is :  TA_yjfC-1_df_relative_timegrid-vs-TA_yjfC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yjfC/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yjfC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yjfC/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjfC/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yjfC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 245.6947   sv2= 0.314548   df= 17.37184   lambda= 781.1039
# phi= 256.2889   sv2= 0.02125123   df= 6.85411   lambda= 12059.95
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjfC/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjfC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yjfC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfC/MD-TA_yjfC-1_df_relative_timegrid-vs-TA_yjfC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yjfC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=51920.351953)
#                  est          L95%         U95%            se
# rate    8.277508e-02  7.803102e-02     0.087808  2.492613e-03
# beta    2.241295e+03  1.679771e+03  2990.528748  3.297926e+02
# s       5.345181e-01  4.692846e-01     0.608819  3.549597e-02
# lambda  8.617968e-08  3.999910e-16    18.567761  8.437084e-07
#                  est        L95%        U95%       var
# lifespan  105.921255  104.557676  105.935008  0.000038
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfC/MD-TA_yjfC-1_df_relative_timegrid-vs-TA_yjfC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjfC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yjfC/run-MD
