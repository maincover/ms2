# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/TA_yeeW-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/TA_yeeW-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/TA_yeeW-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW']
#
# out_name_s  ['TA_yeeW-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/TA_yeeW-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/TA_yeeW-1_analysis_metadata.pickle
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 57-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 61-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 62-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 63-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 66-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 67-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 84-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 56-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 61-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 62-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 63-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 66-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 67-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 84-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 57-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 61-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 62-1.tif.mortality.tab
# MAX_28072014 mRFP Position 61-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 63-1.tif.mortality.tab
# MAX_28072014 mRFP Position 61-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 66-1.tif.mortality.tab
# MAX_28072014 mRFP Position 61-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 67-1.tif.mortality.tab
# MAX_28072014 mRFP Position 61-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 84-1.tif.mortality.tab
# MAX_28072014 mRFP Position 61-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 61-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 62-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 63-1.tif.mortality.tab
# MAX_28072014 mRFP Position 62-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 66-1.tif.mortality.tab
# MAX_28072014 mRFP Position 62-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 67-1.tif.mortality.tab
# MAX_28072014 mRFP Position 62-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 84-1.tif.mortality.tab
# MAX_28072014 mRFP Position 62-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 62-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 63-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 66-1.tif.mortality.tab
# MAX_28072014 mRFP Position 63-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 67-1.tif.mortality.tab
# MAX_28072014 mRFP Position 63-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 84-1.tif.mortality.tab
# MAX_28072014 mRFP Position 63-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 63-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 66-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 67-1.tif.mortality.tab
# MAX_28072014 mRFP Position 66-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 84-1.tif.mortality.tab
# MAX_28072014 mRFP Position 66-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 66-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 67-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 84-1.tif.mortality.tab
# MAX_28072014 mRFP Position 67-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 67-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 84-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 85-1.tif.mortality.tab
# MAX_28072014 mRFP Position 84-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# MAX_28072014 mRFP Position 85-1.tif.mortality.tab ------ MAX_28072014 mRFP Position 88-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_dentrogram-all-files.eps
# [['MAX_28072014 mRFP Position 56-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 62-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 57-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 63-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 66-1.tif.mortality.tab'], ['MAX_28072014 mRFP Position 61-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 67-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 84-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 85-1.tif.mortality.tab', 'MAX_28072014 mRFP Position 88-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.624135   sv2= 0.06059036   df= 14.35964   lambda= 142.3351
# phi= 8.808148   sv2= 0.01146195   df= 7.93206   lambda= 768.4683
# phi= 9.056852   sv2= 0.004865495   df= 5.470927   lambda= 1861.445
# phi= 9.30588   sv2= 0.00341512   df= 4.525676   lambda= 2724.906
# phi= 9.426745   sv2= 0.002912784   df= 4.181784   lambda= 3236.335
# phi= 9.479255   sv2= 0.002706692   df= 4.038262   lambda= 3502.155
# phi= 9.502351   sv2= 0.002616489   df= 3.974749   lambda= 3631.718
# phi= 9.51271   sv2= 0.002575909   df= 3.946008   lambda= 3692.953
# phi= 9.517416   sv2= 0.002557429   df= 3.932882   lambda= 3721.478
# phi= 9.519567   sv2= 0.002548966   df= 3.926863   lambda= 3734.678
# phi= 9.520554   sv2= 0.002545081   df= 3.924098   lambda= 3740.767
# phi= 9.521008   sv2= 0.002543295   df= 3.922827   lambda= 3743.571
# phi= 9.521216   sv2= 0.002542474   df= 3.922242   lambda= 3744.862
# phi= 9.521312   sv2= 0.002542097   df= 3.921973   lambda= 3745.456
# phi= 9.521356   sv2= 0.002541923   df= 3.92185   lambda= 3745.73
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.74865   sv2= 0.1794105   df= 13.08315   lambda= 137.9442
# phi= 25.33629   sv2= 0.03345869   df= 7.359377   lambda= 757.241
# phi= 26.10919   sv2= 0.006831451   df= 5.106946   lambda= 3821.91
# phi= 26.74254   sv2= 0.001280759   df= 3.656729   lambda= 20880.22
# Iterations: relative error in phi-hat = 1e-04
# phi= 62.15119   sv2= 0.1343501   df= 12.58463   lambda= 462.6064
# phi= 65.3113   sv2= 0.006032973   df= 5.379021   lambda= 10825.72
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/CR-TA_yeeW-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.65472   sv2= 0.09432964   df= 15.92061   lambda= 314.3733
# phi= 29.78823   sv2= 0.009522566   df= 7.375381   lambda= 3128.173
# phi= 30.26009   sv2= 0.002979627   df= 4.484335   lambda= 10155.66
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.74865   sv2= 0.1794105   df= 13.08315   lambda= 137.9442
# phi= 25.33629   sv2= 0.03345869   df= 7.359377   lambda= 757.241
# phi= 26.10919   sv2= 0.006831451   df= 5.106946   lambda= 3821.91
# phi= 26.74254   sv2= 0.001280759   df= 3.656729   lambda= 20880.22
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  89.341863  88.338881  91.338868  0.000107, 1:                  est        L95%        U95%       var
# lifespan  102.687727  100.519393  103.520522  0.000193}
