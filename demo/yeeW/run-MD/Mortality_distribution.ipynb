# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/TA_yeeW-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/TA_yeeW-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.7224   sv2= 0.1034252   df= 17.81864   lambda= 461.4194
# phi= 45.57451   sv2= 0.01204873   df= 7.686088   lambda= 3782.517
# phi= 45.32873   sv2= 0.00206918   df= 4.871635   lambda= 21906.62
# save file prefixed name is : TA_yeeW-1_df_relative_timegrid-vs-TA_yeeW-1_timeseries_dataframe
# biName is :  TA_yeeW-1_df_relative_timegrid-vs-TA_yeeW-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yeeW/run-MD
# No error in flxsrv_fit
# TA_yeeW-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yeeW/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yeeW/run-MD
# TA_yeeW-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.7224   sv2= 0.1034252   df= 17.81864   lambda= 461.4194
# phi= 45.57451   sv2= 0.01204873   df= 7.686088   lambda= 3782.517
# phi= 45.32873   sv2= 0.00206918   df= 4.871635   lambda= 21906.62
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yeeW/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yeeW-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yeeW-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/MD-TA_yeeW-1_df_relative_timegrid-vs-TA_yeeW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yeeW-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=35108.113965)
#                  est          L95%        U95%         se
# rate    5.947571e-02  5.601498e-02    0.063150   0.001819
# beta    5.475401e+02  4.557974e+02  657.748661  51.231490
# s       1.751287e+00  1.304059e+00    2.351894   0.263475
# lambda  4.598601e-07  3.021443e-14    6.999020   0.000004
#                 est       L95%       U95%       var
# lifespan  91.586713  91.329472  96.414382  0.000056
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yeeW/MD-TA_yeeW-1_df_relative_timegrid-vs-TA_yeeW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yeeW-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yeeW/run-MD
