# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glpX'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glpX/TA_glpX-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glpX/TA_glpX-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glpX
# Iterations: relative error in phi-hat = 1e-04
# phi= 195.4616   sv2= 0.2815165   df= 15.04559   lambda= 694.3166
# phi= 197.2898   sv2= 0.06096496   df= 6.064233   lambda= 3236.117
# phi= 202.3608   sv2= 0.03825453   df= 4.377602   lambda= 5289.853
# phi= 206.6716   sv2= 0.03033466   df= 3.940155   lambda= 6813.053
# phi= 209.6271   sv2= 0.02640468   df= 3.731529   lambda= 7939.011
# phi= 211.6592   sv2= 0.02412383   df= 3.611823   lambda= 8773.864
# phi= 213.079   sv2= 0.02268139   df= 3.536441   lambda= 9394.441
# phi= 214.0863   sv2= 0.02172036   df= 3.486298   lambda= 9856.481
# phi= 214.8098   sv2= 0.02105808   df= 3.45176   lambda= 10200.82
# save file prefixed name is : TA_glpX-1_df_relative_timegrid-vs-TA_glpX-1_timeseries_dataframe
# biName is :  TA_glpX-1_df_relative_timegrid-vs-TA_glpX-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/glpX/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_glpX-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/glpX/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/glpX/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_glpX-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 195.4616   sv2= 0.2815165   df= 15.04559   lambda= 694.3166
# phi= 197.2898   sv2= 0.06096496   df= 6.064233   lambda= 3236.117
# phi= 202.3608   sv2= 0.03825453   df= 4.377602   lambda= 5289.853
# phi= 206.6716   sv2= 0.03033466   df= 3.940155   lambda= 6813.053
# phi= 209.6271   sv2= 0.02640468   df= 3.731529   lambda= 7939.011
# phi= 211.6592   sv2= 0.02412383   df= 3.611823   lambda= 8773.864
# phi= 213.079   sv2= 0.02268139   df= 3.536441   lambda= 9394.441
# phi= 214.0863   sv2= 0.02172036   df= 3.486298   lambda= 9856.481
# phi= 214.8098   sv2= 0.02105808   df= 3.45176   lambda= 10200.82
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/glpX/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_glpX-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_glpX-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glpX/MD-TA_glpX-1_df_relative_timegrid-vs-TA_glpX-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_glpX-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=30360.529484)
#                  est          L95%          U95%            se
# rate    2.109404e-01  1.939182e-01  2.294567e-01  9.055428e-03
# beta    1.773774e+08  4.024455e+07  7.817889e+08  1.342396e+08
# s       6.876733e-01  6.048398e-01  7.818510e-01  4.503300e-02
# lambda  6.710885e-04  5.373745e-04  8.380744e-04  7.608292e-05
#                 est       L95%       U95%       var
# lifespan  91.191647  91.184138  92.163248  0.000063
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glpX/MD-TA_glpX-1_df_relative_timegrid-vs-TA_glpX-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_glpX-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/glpX/run-MD
