# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/mprA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/mprA/TA_mprA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/mprA/TA_mprA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/mprA
# Iterations: relative error in phi-hat = 1e-04
# phi= 109.9208   sv2= 0.5167801   df= 17.37403   lambda= 212.7032
# phi= 124.9977   sv2= 0.08848404   df= 8.9644   lambda= 1412.658
# phi= 139.0928   sv2= 0.02080688   df= 6.05304   lambda= 6684.942
# phi= 148.6027   sv2= 0.00556045   df= 4.467498   lambda= 26724.95
# save file prefixed name is : TA_mprA-1_df_relative_timegrid-vs-TA_mprA-1_timeseries_dataframe
# biName is :  TA_mprA-1_df_relative_timegrid-vs-TA_mprA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/mprA/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_mprA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/mprA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/mprA/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_mprA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 109.9208   sv2= 0.5167801   df= 17.37403   lambda= 212.7032
# phi= 124.9977   sv2= 0.08848404   df= 8.9644   lambda= 1412.658
# phi= 139.0928   sv2= 0.02080688   df= 6.05304   lambda= 6684.942
# phi= 148.6027   sv2= 0.00556045   df= 4.467498   lambda= 26724.95
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/mprA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_mprA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_mprA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/mprA/MD-TA_mprA-1_df_relative_timegrid-vs-TA_mprA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_mprA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=27363.023707)
#                  est          L95%           U95%            se
# rate        0.103383      0.090366       0.118275      0.007098
# beta    87284.292474  26595.472189  286460.328980  52925.070152
# s           0.657775      0.473383       0.913993      0.110401
# lambda      0.004663      0.004348       0.005001      0.000166
#                  est        L95%        U95%       var
# lifespan  102.020242  101.753637  103.757301  0.000078
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/mprA/MD-TA_mprA-1_df_relative_timegrid-vs-TA_mprA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_mprA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/mprA/run-MD
