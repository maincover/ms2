# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG-WT/CR-TA_MG-WT-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG-WT/CR-TA_MG-WT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/TA_ynaA 2-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/TA_ynaA 2-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/TA_ynaA 2-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2']
#
# out_name_s  ['TA_ynaA 2-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/TA_ynaA 2-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/TA_ynaA 2-1_analysis_metadata.pickle
# MAX_09032016 Position 12-1.tif.mortality.tab ------ MAX_09032016 Position 13-1.tif.mortality.tab
# MAX_09032016 Position 12-1.tif.mortality.tab ------ MAX_09032016 Position 3-1.tif.mortality.tab
# MAX_09032016 Position 12-1.tif.mortality.tab ------ MAX_09032016 Position 48-1.tif.mortality.tab
# MAX_09032016 Position 12-1.tif.mortality.tab ------ MAX_09032016 Position 49-1.tif.mortality.tab
# MAX_09032016 Position 12-1.tif.mortality.tab ------ MAX_09032016 Position 54-1.tif.mortality.tab
# MAX_09032016 Position 12-1.tif.mortality.tab ------ MAX_09032016 Position 6-1.tif.mortality.tab
# MAX_09032016 Position 13-1.tif.mortality.tab ------ MAX_09032016 Position 3-1.tif.mortality.tab
# MAX_09032016 Position 13-1.tif.mortality.tab ------ MAX_09032016 Position 48-1.tif.mortality.tab
# MAX_09032016 Position 13-1.tif.mortality.tab ------ MAX_09032016 Position 49-1.tif.mortality.tab
# MAX_09032016 Position 13-1.tif.mortality.tab ------ MAX_09032016 Position 54-1.tif.mortality.tab
# MAX_09032016 Position 13-1.tif.mortality.tab ------ MAX_09032016 Position 6-1.tif.mortality.tab
# MAX_09032016 Position 3-1.tif.mortality.tab ------ MAX_09032016 Position 48-1.tif.mortality.tab
# MAX_09032016 Position 3-1.tif.mortality.tab ------ MAX_09032016 Position 49-1.tif.mortality.tab
# MAX_09032016 Position 3-1.tif.mortality.tab ------ MAX_09032016 Position 54-1.tif.mortality.tab
# MAX_09032016 Position 3-1.tif.mortality.tab ------ MAX_09032016 Position 6-1.tif.mortality.tab
# MAX_09032016 Position 48-1.tif.mortality.tab ------ MAX_09032016 Position 49-1.tif.mortality.tab
# MAX_09032016 Position 48-1.tif.mortality.tab ------ MAX_09032016 Position 54-1.tif.mortality.tab
# MAX_09032016 Position 48-1.tif.mortality.tab ------ MAX_09032016 Position 6-1.tif.mortality.tab
# MAX_09032016 Position 49-1.tif.mortality.tab ------ MAX_09032016 Position 54-1.tif.mortality.tab
# MAX_09032016 Position 49-1.tif.mortality.tab ------ MAX_09032016 Position 6-1.tif.mortality.tab
# MAX_09032016 Position 54-1.tif.mortality.tab ------ MAX_09032016 Position 6-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2
# save eps to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_dentrogram-all-files.eps
# [['MAX_09032016 Position 12-1.tif.mortality.tab', 'MAX_09032016 Position 3-1.tif.mortality.tab', 'MAX_09032016 Position 48-1.tif.mortality.tab'], ['MAX_09032016 Position 6-1.tif.mortality.tab'], ['MAX_09032016 Position 49-1.tif.mortality.tab', 'MAX_09032016 Position 54-1.tif.mortality.tab'], ['MAX_09032016 Position 13-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.436367   sv2= 0.1090444   df= 10.69856   lambda= 68.19575
# phi= 7.669651   sv2= 0.02435928   df= 7.104794   lambda= 314.8555
# phi= 7.744743   sv2= 0.01108461   df= 5.21232   lambda= 698.6935
# phi= 7.816658   sv2= 0.01004012   df= 4.486537   lambda= 778.5423
# phi= 7.830443   sv2= 0.01004591   df= 4.399463   lambda= 779.4657
# phi= 7.830601   sv2= 0.0100461   df= 4.398523   lambda= 779.4668
# Iterations: relative error in phi-hat = 1e-04
# phi= 17.81096   sv2= 0.2482318   df= 10.83433   lambda= 71.75134
# phi= 21.0959   sv2= 0.03896928   df= 7.123984   lambda= 541.347
# phi= 23.11242   sv2= 0.003491207   df= 4.699673   lambda= 6620.181
# phi= 23.79566   sv2= 0.001041247   df= 2.985568   lambda= 22853.05
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/CR-TA_ynaA 2-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 12.02375   sv2= 0.1287905   df= 11.06296   lambda= 93.35901
# phi= 12.53154   sv2= 0.02201612   df= 6.858603   lambda= 569.1982
# phi= 12.78554   sv2= 0.01154278   df= 4.786426   lambda= 1107.666
# phi= 12.98872   sv2= 0.01166621   df= 4.243108   lambda= 1113.363
# phi= 12.99082   sv2= 0.01167026   df= 4.239288   lambda= 1113.156
# phi= 12.99074   sv2= 0.01167012   df= 4.239427   lambda= 1113.163
# Iterations: relative error in phi-hat = 1e-04
# phi= 17.81096   sv2= 0.2482318   df= 10.83433   lambda= 71.75134
# phi= 21.0959   sv2= 0.03896928   df= 7.123984   lambda= 541.347
# phi= 23.11242   sv2= 0.003491207   df= 4.699673   lambda= 6620.181
# phi= 23.79566   sv2= 0.001041247   df= 2.985568   lambda= 22853.05
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est       L95%        U95%       var
# lifespan  100.747332  96.098896  102.770864  0.000476, 1:                 est       L95%       U95%       var
# lifespan  68.700834  61.656439  76.031668  0.000843}
