# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/TA_ynaA 2-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/TA_ynaA 2-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2
# Iterations: relative error in phi-hat = 1e-04
# phi= 23.98701   sv2= 0.2325861   df= 13.71415   lambda= 103.1317
# phi= 25.8305   sv2= 0.0218706   df= 8.201163   lambda= 1181.061
# phi= 26.86562   sv2= 0.004664069   df= 4.949863   lambda= 5760.126
# phi= 27.02847   sv2= 0.005188894   df= 3.688786   lambda= 5208.907
# phi= 27.01423   sv2= 0.005145902   df= 3.75473   lambda= 5249.659
# phi= 27.01522   sv2= 0.005149405   df= 3.749561   lambda= 5246.281
# phi= 27.01514   sv2= 0.005149116   df= 3.749988   lambda= 5246.558
# save file prefixed name is : TA_ynaA 2-1_df_relative_timegrid-vs-TA_ynaA 2-1_timeseries_dataframe
# biName is :  TA_ynaA 2-1_df_relative_timegrid-vs-TA_ynaA 2-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ynaA 2/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ynaA 2-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ynaA 2/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ynaA 2/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ynaA 2-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 23.98701   sv2= 0.2325861   df= 13.71415   lambda= 103.1317
# phi= 25.8305   sv2= 0.0218706   df= 8.201163   lambda= 1181.061
# phi= 26.86562   sv2= 0.004664069   df= 4.949863   lambda= 5760.126
# phi= 27.02847   sv2= 0.005188894   df= 3.688786   lambda= 5208.907
# phi= 27.01423   sv2= 0.005145902   df= 3.75473   lambda= 5249.659
# phi= 27.01522   sv2= 0.005149405   df= 3.749561   lambda= 5246.281
# phi= 27.01514   sv2= 0.005149116   df= 3.749988   lambda= 5246.558
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ynaA 2/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA 2-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ynaA 2-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/MD-TA_ynaA 2-1_df_relative_timegrid-vs-TA_ynaA 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ynaA 2-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=8388.496739)
#                  est          L95%          U95%            se
# rate    2.008019e-01  1.480616e-01  2.723285e-01  3.121609e-02
# beta    3.288602e+09  8.232798e+06  1.313636e+12  1.005071e+10
# s       4.666961e-01  2.394957e-01  9.094330e-01  1.588565e-01
# lambda  8.681592e-03  7.942001e-03  9.490056e-03  3.943979e-04
#                 est       L95%       U95%       var
# lifespan  87.769928  76.031668  92.816641  0.000254
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ynaA 2/MD-TA_ynaA 2-1_df_relative_timegrid-vs-TA_ynaA 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA 2-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ynaA 2/run-MD
