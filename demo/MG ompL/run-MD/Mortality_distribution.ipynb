# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MG strains tab/MG ompL'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_df_relative_timegrid.pickle']]
# [('/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_df_relative_timegrid.pickle'), ('/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_df_relative_timegrid.pickle'), ('/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_df_relative_timegrid.pickle')]
# [['/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_timeseries_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_timeseries_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# --------PAIR-------
# df1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_df_relative_timegrid.pickle
# df2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_df_relative_timegrid.pickle
# ts1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_timeseries_dataframe.pickle
# ts2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_timeseries_dataframe.pickle
# files will be written into :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.64139   sv2= 0.02191583   df= 7.412366   lambda= 1261.252
# phi= 28.91878   sv2= 0.001812293   df= 2.957939   lambda= 15957.01
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.47931   sv2= 0.01315337   df= 6.357509   lambda= 2849.408
# phi= 42.0877   sv2= 0.001009005   df= 2.359147   lambda= 41712.09
# save file prefixed name is : TA_MG ompL-1-vs-MG ompL-2
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-TA_MG ompL-1-vs-MG ompL-2_Mortality_summary_binning poster.png
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MG ompL/run-MD
# No error in flxsrv_fit
# MG ompL-2_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_MG ompL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MG ompL/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG ompL/run-MD
# MG ompL-2_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.47931   sv2= 0.01315337   df= 6.357509   lambda= 2849.408
# phi= 42.0877   sv2= 0.001009005   df= 2.359147   lambda= 41712.09
# TA_MG ompL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.64139   sv2= 0.02191583   df= 7.412366   lambda= 1261.252
# phi= 28.91878   sv2= 0.001812293   df= 2.957939   lambda= 15957.01
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG ompL/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG ompL-1_df_relative_timegrid.pickle
# 2 MG ompL-2_df_relative_timegrid.pickle
# MG ompL-2_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_MG ompL-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-TA_MG ompL-1-vs-MG ompL-2-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG ompL-2_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=258.869210)
#                  est          L95%          U95%            se
# rate    4.039112e-01  4.389579e-02  3.716627e+00  4.573713e-01
# beta    1.519358e+18  9.008038e-21  2.562655e+56  6.823360e+19
# s       3.270442e+01  6.418386e-07  1.666429e+09  2.961212e+02
# lambda  3.262987e-02  2.237844e-02  4.757743e-02  6.278541e-03
#                 est      L95%       U95%       var
# lifespan  14.071537  7.093769  23.085744  0.007927
#
#
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_MG ompL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=459.872393)
#                  est          L95%          U95%            se
# rate    1.330022e-01  4.054272e-02  4.363196e-01  8.061774e-02
# beta    5.047553e+07  1.792044e-06  1.421717e+21  7.975577e+08
# s       7.116258e+01  1.236599e-10  4.095193e+13  9.831674e+02
# lambda  2.784499e-02  2.054108e-02  3.774598e-02  4.322106e-03
#                 est      L95%       U95%      var
# lifespan  20.078293  9.073564  33.064725  0.00476
#
#
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-TA_MG ompL-1-vs-MG ompL-2-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG ompL-1_df_relative_timegrid.pickle
# 2 MG ompL-2_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MG ompL/run-MD
# --------PAIR-------
# df1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_df_relative_timegrid.pickle
# df2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_df_relative_timegrid.pickle
# ts1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/TA_MG ompL-1_timeseries_dataframe.pickle
# ts2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_timeseries_dataframe.pickle
# files will be written into :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.64139   sv2= 0.02191583   df= 7.412366   lambda= 1261.252
# phi= 28.91878   sv2= 0.001812293   df= 2.957939   lambda= 15957.01
# Iterations: relative error in phi-hat = 1e-04
# phi= 1.048848   sv2= 0.03713853   df= 5.966458   lambda= 28.2415
# phi= 1.176683   sv2= 0.0125314   df= 5.031296   lambda= 93.8987
# phi= 1.264292   sv2= 0.003901051   df= 4.124288   lambda= 324.0901
# phi= 1.316587   sv2= 0.00116269   df= 3.33934   lambda= 1132.362
# phi= 1.32903   sv2= 0.000414581   df= 2.699933   lambda= 3205.719
# phi= 1.329714   sv2= 0.0001864315   df= 2.328975   lambda= 7132.455
# phi= 1.331089   sv2= 9.477947e-05   df= 2.16436   lambda= 14044.06
# save file prefixed name is : TA_-vs-
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-TA_-vs_Mortality_summary_binning poster.png
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MG ompL/run-MD
# No error in flxsrv_fit
# TA_MG ompL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG ompL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MG ompL/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG ompL/run-MD
# TA_MG ompL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.64139   sv2= 0.02191583   df= 7.412366   lambda= 1261.252
# phi= 28.91878   sv2= 0.001812293   df= 2.957939   lambda= 15957.01
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# MG ompL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 1.048848   sv2= 0.03713853   df= 5.966458   lambda= 28.2415
# phi= 1.176683   sv2= 0.0125314   df= 5.031296   lambda= 93.8987
# phi= 1.264292   sv2= 0.003901051   df= 4.124288   lambda= 324.0901
# phi= 1.316587   sv2= 0.00116269   df= 3.33934   lambda= 1132.362
# phi= 1.32903   sv2= 0.000414581   df= 2.699933   lambda= 3205.719
# phi= 1.329714   sv2= 0.0001864315   df= 2.328975   lambda= 7132.455
# phi= 1.331089   sv2= 9.477947e-05   df= 2.16436   lambda= 14044.06
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG ompL/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG ompL-1_df_relative_timegrid.pickle
# 2 MG ompL-1_df_relative_timegrid.pickle
# MG ompL-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_MG ompL-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-TA_-vs-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG ompL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=215.626188)
#                  est  L95%  U95%  se
# rate    1.929915e-01   NaN   NaN NaN
# beta    4.952321e+13   NaN   NaN NaN
# s       1.226499e+02   NaN   NaN NaN
# lambda  2.169810e-02   NaN   NaN NaN
#                 est      L95%       U95%       var
# lifespan  33.064725  6.076478  59.077629  0.010616
#
#
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_MG ompL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=459.872393)
#                  est          L95%          U95%            se
# rate    1.330022e-01  4.054272e-02  4.363196e-01  8.061774e-02
# beta    5.047553e+07  1.792044e-06  1.421717e+21  7.975577e+08
# s       7.116258e+01  1.236599e-10  4.095193e+13  9.831674e+02
# lambda  2.784499e-02  2.054108e-02  3.774598e-02  4.322106e-03
#                 est      L95%       U95%      var
# lifespan  20.078293  9.073564  33.064725  0.00476
#
#
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-TA_-vs-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG ompL-1_df_relative_timegrid.pickle
# 2 MG ompL-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MG ompL/run-MD
# --------PAIR-------
# df1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_df_relative_timegrid.pickle
# df2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_df_relative_timegrid.pickle
# ts1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-2_timeseries_dataframe.pickle
# ts2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MG ompL-1_timeseries_dataframe.pickle
# files will be written into :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.47931   sv2= 0.01315337   df= 6.357509   lambda= 2849.408
# phi= 42.0877   sv2= 0.001009005   df= 2.359147   lambda= 41712.09
# Iterations: relative error in phi-hat = 1e-04
# phi= 1.048848   sv2= 0.03713853   df= 5.966458   lambda= 28.2415
# phi= 1.176683   sv2= 0.0125314   df= 5.031296   lambda= 93.8987
# phi= 1.264292   sv2= 0.003901051   df= 4.124288   lambda= 324.0901
# phi= 1.316587   sv2= 0.00116269   df= 3.33934   lambda= 1132.362
# phi= 1.32903   sv2= 0.000414581   df= 2.699933   lambda= 3205.719
# phi= 1.329714   sv2= 0.0001864315   df= 2.328975   lambda= 7132.455
# phi= 1.331089   sv2= 9.477947e-05   df= 2.16436   lambda= 14044.06
# save file prefixed name is : MG ompL-2-vs-MG ompL-1
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-MG ompL-2-vs-MG ompL-1_Mortality_summary_binning poster.png
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MG ompL/run-MD
# No error in flxsrv_fit
# MG ompL-2_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG ompL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MG ompL/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG ompL/run-MD
# MG ompL-2_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.47931   sv2= 0.01315337   df= 6.357509   lambda= 2849.408
# phi= 42.0877   sv2= 0.001009005   df= 2.359147   lambda= 41712.09
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# MG ompL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 1.048848   sv2= 0.03713853   df= 5.966458   lambda= 28.2415
# phi= 1.176683   sv2= 0.0125314   df= 5.031296   lambda= 93.8987
# phi= 1.264292   sv2= 0.003901051   df= 4.124288   lambda= 324.0901
# phi= 1.316587   sv2= 0.00116269   df= 3.33934   lambda= 1132.362
# phi= 1.32903   sv2= 0.000414581   df= 2.699933   lambda= 3205.719
# phi= 1.329714   sv2= 0.0001864315   df= 2.328975   lambda= 7132.455
# phi= 1.331089   sv2= 9.477947e-05   df= 2.16436   lambda= 14044.06
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG ompL/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 MG ompL-2_df_relative_timegrid.pickle
# 2 MG ompL-1_df_relative_timegrid.pickle
# MG ompL-1_df_relative_timegrid.pickle
# MG ompL-2_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-MG ompL-2-vs-MG ompL-1-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG ompL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=215.626188)
#                  est  L95%  U95%  se
# rate    1.929915e-01   NaN   NaN NaN
# beta    4.952321e+13   NaN   NaN NaN
# s       1.226499e+02   NaN   NaN NaN
# lambda  2.169810e-02   NaN   NaN NaN
#                 est      L95%       U95%       var
# lifespan  33.064725  6.076478  59.077629  0.010616
#
#
# MG ompL-2_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=258.869210)
#                  est          L95%          U95%            se
# rate    4.039112e-01  4.389579e-02  3.716627e+00  4.573713e-01
# beta    1.519358e+18  9.008038e-21  2.562655e+56  6.823360e+19
# s       3.270442e+01  6.418386e-07  1.666429e+09  2.961212e+02
# lambda  3.262987e-02  2.237844e-02  4.757743e-02  6.278541e-03
#                 est      L95%       U95%       var
# lifespan  14.071537  7.093769  23.085744  0.007927
#
#
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/MD-MG ompL-2-vs-MG ompL-1-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 MG ompL-2_df_relative_timegrid.pickle
# 2 MG ompL-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MG ompL/run-MD
