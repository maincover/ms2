# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/TA_treC-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/TA_treC-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/TA_treC-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC']
#
# out_name_s  ['TA_treC-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/TA_treC-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/TA_treC-1_analysis_metadata.pickle
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 11-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 12-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 13-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 14-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 17-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 18-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 19-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 10-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 12-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 13-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 14-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 17-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 18-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 19-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 11-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 12-1.tif.mortality.tab ------ MAX_08062014 Position 13-1.tif.mortality.tab
# MAX_08062014 Position 12-1.tif.mortality.tab ------ MAX_08062014 Position 14-1.tif.mortality.tab
# MAX_08062014 Position 12-1.tif.mortality.tab ------ MAX_08062014 Position 17-1.tif.mortality.tab
# MAX_08062014 Position 12-1.tif.mortality.tab ------ MAX_08062014 Position 18-1.tif.mortality.tab
# MAX_08062014 Position 12-1.tif.mortality.tab ------ MAX_08062014 Position 19-1.tif.mortality.tab
# MAX_08062014 Position 12-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 12-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 13-1.tif.mortality.tab ------ MAX_08062014 Position 14-1.tif.mortality.tab
# MAX_08062014 Position 13-1.tif.mortality.tab ------ MAX_08062014 Position 17-1.tif.mortality.tab
# MAX_08062014 Position 13-1.tif.mortality.tab ------ MAX_08062014 Position 18-1.tif.mortality.tab
# MAX_08062014 Position 13-1.tif.mortality.tab ------ MAX_08062014 Position 19-1.tif.mortality.tab
# MAX_08062014 Position 13-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 13-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 14-1.tif.mortality.tab ------ MAX_08062014 Position 17-1.tif.mortality.tab
# MAX_08062014 Position 14-1.tif.mortality.tab ------ MAX_08062014 Position 18-1.tif.mortality.tab
# MAX_08062014 Position 14-1.tif.mortality.tab ------ MAX_08062014 Position 19-1.tif.mortality.tab
# MAX_08062014 Position 14-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 14-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 17-1.tif.mortality.tab ------ MAX_08062014 Position 18-1.tif.mortality.tab
# MAX_08062014 Position 17-1.tif.mortality.tab ------ MAX_08062014 Position 19-1.tif.mortality.tab
# MAX_08062014 Position 17-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 17-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 18-1.tif.mortality.tab ------ MAX_08062014 Position 19-1.tif.mortality.tab
# MAX_08062014 Position 18-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 18-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 19-1.tif.mortality.tab ------ MAX_08062014 Position 54-1.tif.mortality.tab
# MAX_08062014 Position 19-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# MAX_08062014 Position 54-1.tif.mortality.tab ------ MAX_08062014 Position 62-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_dentrogram-all-files.eps
# [['MAX_08062014 Position 10-1.tif.mortality.tab', 'MAX_08062014 Position 12-1.tif.mortality.tab', 'MAX_08062014 Position 14-1.tif.mortality.tab', 'MAX_08062014 Position 18-1.tif.mortality.tab', 'MAX_08062014 Position 54-1.tif.mortality.tab'], ['MAX_08062014 Position 11-1.tif.mortality.tab', 'MAX_08062014 Position 17-1.tif.mortality.tab', 'MAX_08062014 Position 19-1.tif.mortality.tab', 'MAX_08062014 Position 62-1.tif.mortality.tab'], ['MAX_08062014 Position 13-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 17.06158   sv2= 0.07239157   df= 13.27501   lambda= 235.6846
# phi= 17.43833   sv2= 0.01684544   df= 6.815619   lambda= 1035.196
# phi= 17.8422   sv2= 0.008181997   df= 5.053308   lambda= 2180.666
# phi= 18.09747   sv2= 0.005740957   df= 4.372956   lambda= 3152.344
# phi= 18.22916   sv2= 0.004890387   df= 4.078987   lambda= 3727.55
# phi= 18.28996   sv2= 0.004565889   df= 3.953906   lambda= 4005.783
# phi= 18.3163   sv2= 0.004436851   df= 3.901784   lambda= 4128.22
# phi= 18.32736   sv2= 0.004384593   df= 3.880267   lambda= 4179.946
# phi= 18.33194   sv2= 0.004363265   df= 3.871416   lambda= 4201.428
# phi= 18.33383   sv2= 0.004354532   df= 3.86778   lambda= 4210.287
# phi= 18.33461   sv2= 0.004350952   df= 3.866288   lambda= 4213.93
# phi= 18.33493   sv2= 0.004349483   df= 3.865675   lambda= 4215.427
# phi= 18.33506   sv2= 0.00434888   df= 3.865424   lambda= 4216.041
# phi= 18.33511   sv2= 0.004348633   df= 3.865321   lambda= 4216.293
# Iterations: relative error in phi-hat = 1e-04
# phi= 6.92849   sv2= 0.08448287   df= 12.94578   lambda= 82.01059
# phi= 7.14769   sv2= 0.02071071   df= 8.305793   lambda= 345.1206
# phi= 7.27897   sv2= 0.01031691   df= 6.162606   lambda= 705.5379
# phi= 7.348264   sv2= 0.007278831   df= 5.33376   lambda= 1009.539
# phi= 7.383836   sv2= 0.006108384   df= 4.967712   lambda= 1208.804
# phi= 7.401483   sv2= 0.005608302   df= 4.795031   lambda= 1319.737
# phi= 7.409958   sv2= 0.005385601   df= 4.713505   lambda= 1375.883
# phi= 7.413942   sv2= 0.005284664   df= 4.675413   lambda= 1402.916
# phi= 7.415793   sv2= 0.005238557   df= 4.657752   lambda= 1415.618
# phi= 7.416649   sv2= 0.005217422   df= 4.6496   lambda= 1421.516
# phi= 7.417043   sv2= 0.005207719   df= 4.645845   lambda= 1424.24
# phi= 7.417225   sv2= 0.005203261   df= 4.644117   lambda= 1425.496
# phi= 7.417308   sv2= 0.005201211   df= 4.643322   lambda= 1426.073
# phi= 7.417347   sv2= 0.005200269   df= 4.642957   lambda= 1426.339
# phi= 7.417364   sv2= 0.005199836   df= 4.642789   lambda= 1426.461
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/CR-TA_treC-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 20.32221   sv2= 0.0745906   df= 15.07056   lambda= 272.4501
# phi= 20.52842   sv2= 0.01761877   df= 7.531834   lambda= 1165.145
# phi= 20.80391   sv2= 0.009247495   df= 5.58969   lambda= 2249.681
# phi= 20.98408   sv2= 0.006715491   df= 4.904609   lambda= 3124.728
# phi= 21.08172   sv2= 0.005742333   df= 4.600384   lambda= 3671.282
# phi= 21.13045   sv2= 0.005334156   df= 4.459648   lambda= 3961.348
# phi= 21.15353   sv2= 0.005156705   df= 4.395133   lambda= 4102.14
# phi= 21.16414   sv2= 0.005078349   df= 4.365899   lambda= 4167.524
# phi= 21.16895   sv2= 0.005043509   df= 4.352744   lambda= 4197.266
# phi= 21.17111   sv2= 0.005027971   df= 4.346845   lambda= 4210.667
# phi= 21.17208   sv2= 0.005021032   df= 4.344204   lambda= 4216.679
# phi= 21.17251   sv2= 0.00501793   df= 4.343023   lambda= 4219.372
# phi= 21.17271   sv2= 0.005016544   df= 4.342494   lambda= 4220.577
# phi= 21.1728   sv2= 0.005015924   df= 4.342258   lambda= 4221.116
# phi= 21.17283   sv2= 0.005015647   df= 4.342152   lambda= 4221.356
# No error in flxsrv_fit
# {0:                est       L95%       U95%       var
# lifespan  90.00198  88.090211  91.088797  0.000094}
