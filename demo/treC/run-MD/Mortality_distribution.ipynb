# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/TA_treC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/TA_treC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC
# Iterations: relative error in phi-hat = 1e-04
# phi= 20.18593   sv2= 0.07512669   df= 15.53006   lambda= 268.6919
# phi= 20.36294   sv2= 0.01692226   df= 7.787453   lambda= 1203.323
# phi= 20.60239   sv2= 0.009123191   df= 5.717308   lambda= 2258.244
# phi= 20.75276   sv2= 0.006869558   df= 5.042273   lambda= 3020.975
# phi= 20.8299   sv2= 0.006024905   df= 4.762548   lambda= 3457.3
# phi= 20.86668   sv2= 0.005676468   df= 4.63928   lambda= 3675.998
# phi= 20.88356   sv2= 0.005526979   df= 4.584536   lambda= 3778.476
# phi= 20.89114   sv2= 0.005461756   df= 4.560255   lambda= 3824.987
# phi= 20.89453   sv2= 0.005433088   df= 4.549503   lambda= 3845.792
# phi= 20.89603   sv2= 0.005420448   df= 4.544746   lambda= 3855.037
# phi= 20.89669   sv2= 0.005414866   df= 4.542642   lambda= 3859.134
# phi= 20.89698   sv2= 0.0054124   df= 4.541712   lambda= 3860.946
# phi= 20.89711   sv2= 0.005411309   df= 4.541301   lambda= 3861.748
# phi= 20.89717   sv2= 0.005410828   df= 4.541119   lambda= 3862.103
# save file prefixed name is : TA_treC-1_df_relative_timegrid-vs-TA_treC-1_timeseries_dataframe
# biName is :  TA_treC-1_df_relative_timegrid-vs-TA_treC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/treC/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_treC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/treC/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/treC/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_treC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 20.18593   sv2= 0.07512669   df= 15.53006   lambda= 268.6919
# phi= 20.36294   sv2= 0.01692226   df= 7.787453   lambda= 1203.323
# phi= 20.60239   sv2= 0.009123191   df= 5.717308   lambda= 2258.244
# phi= 20.75276   sv2= 0.006869558   df= 5.042273   lambda= 3020.975
# phi= 20.8299   sv2= 0.006024905   df= 4.762548   lambda= 3457.3
# phi= 20.86668   sv2= 0.005676468   df= 4.63928   lambda= 3675.998
# phi= 20.88356   sv2= 0.005526979   df= 4.584536   lambda= 3778.476
# phi= 20.89114   sv2= 0.005461756   df= 4.560255   lambda= 3824.987
# phi= 20.89453   sv2= 0.005433088   df= 4.549503   lambda= 3845.792
# phi= 20.89603   sv2= 0.005420448   df= 4.544746   lambda= 3855.037
# phi= 20.89669   sv2= 0.005414866   df= 4.542642   lambda= 3859.134
# phi= 20.89698   sv2= 0.0054124   df= 4.541712   lambda= 3860.946
# phi= 20.89711   sv2= 0.005411309   df= 4.541301   lambda= 3861.748
# phi= 20.89717   sv2= 0.005410828   df= 4.541119   lambda= 3862.103
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/treC/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_treC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_treC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/MD-TA_treC-1_df_relative_timegrid-vs-TA_treC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_treC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=23794.827620)
#                est       L95%        U95%         se
# rate      0.066369   0.059055    0.074590   0.003954
# beta    105.981047  71.742459  156.559763  21.098052
# s         0.471007   0.381889    0.580922   0.050404
# lambda    0.000145   0.000018    0.001160   0.000154
#                 est       L95%       U95%       var
# lifespan  89.001888  87.658537  90.039679  0.000081
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/treC/MD-TA_treC-1_df_relative_timegrid-vs-TA_treC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_treC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/treC/run-MD
