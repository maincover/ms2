# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MG strains tab/MG yagS'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_mortality_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_mortality_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_analysis_metadata.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_analysis_metadata.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_timeseries_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_timeseries_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MG strains tab/MG yagS']
#
# out_name_s  ['MG yagS-1_']
# /home/xsong/mg-wt/Check_Replication.py:835: PerformanceWarning: indexing past lexsort depth may impact performance.
#   profile.loc[row].fillna(method = "ffill",inplace=True)
# /home/xsong/mg-wt/Check_Replication.py:836: PerformanceWarning: indexing past lexsort depth may impact performance.
#   profile.loc[row].fillna(method = "bfill",inplace=True)
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_analysis_metadata.pickle
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 12.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 13.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 14.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 15.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 16.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 17.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 18.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 11.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 13.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 14.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 15.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 16.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 17.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 18.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 12.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 13.tif.mortality.tab ------ MAX_MAX_12052015 Position 14.tif.mortality.tab
# MAX_MAX_12052015 Position 13.tif.mortality.tab ------ MAX_MAX_12052015 Position 15.tif.mortality.tab
# MAX_MAX_12052015 Position 13.tif.mortality.tab ------ MAX_MAX_12052015 Position 16.tif.mortality.tab
# MAX_MAX_12052015 Position 13.tif.mortality.tab ------ MAX_MAX_12052015 Position 17.tif.mortality.tab
# MAX_MAX_12052015 Position 13.tif.mortality.tab ------ MAX_MAX_12052015 Position 18.tif.mortality.tab
# MAX_MAX_12052015 Position 13.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 13.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 14.tif.mortality.tab ------ MAX_MAX_12052015 Position 15.tif.mortality.tab
# MAX_MAX_12052015 Position 14.tif.mortality.tab ------ MAX_MAX_12052015 Position 16.tif.mortality.tab
# MAX_MAX_12052015 Position 14.tif.mortality.tab ------ MAX_MAX_12052015 Position 17.tif.mortality.tab
# MAX_MAX_12052015 Position 14.tif.mortality.tab ------ MAX_MAX_12052015 Position 18.tif.mortality.tab
# MAX_MAX_12052015 Position 14.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 14.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 15.tif.mortality.tab ------ MAX_MAX_12052015 Position 16.tif.mortality.tab
# MAX_MAX_12052015 Position 15.tif.mortality.tab ------ MAX_MAX_12052015 Position 17.tif.mortality.tab
# MAX_MAX_12052015 Position 15.tif.mortality.tab ------ MAX_MAX_12052015 Position 18.tif.mortality.tab
# MAX_MAX_12052015 Position 15.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 15.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 16.tif.mortality.tab ------ MAX_MAX_12052015 Position 17.tif.mortality.tab
# MAX_MAX_12052015 Position 16.tif.mortality.tab ------ MAX_MAX_12052015 Position 18.tif.mortality.tab
# MAX_MAX_12052015 Position 16.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 16.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 17.tif.mortality.tab ------ MAX_MAX_12052015 Position 18.tif.mortality.tab
# MAX_MAX_12052015 Position 17.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 17.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 18.tif.mortality.tab ------ MAX_MAX_12052015 Position 19.tif.mortality.tab
# MAX_MAX_12052015 Position 18.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# MAX_MAX_12052015 Position 19.tif.mortality.tab ------ MAX_MAX_12052015 Position 20.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS
# save eps to :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_dentrogram-all-files.eps
# [['MAX_MAX_12052015 Position 11.tif.mortality.tab'], ['MAX_MAX_12052015 Position 13.tif.mortality.tab'], ['MAX_MAX_12052015 Position 16.tif.mortality.tab', 'MAX_MAX_12052015 Position 17.tif.mortality.tab', 'MAX_MAX_12052015 Position 18.tif.mortality.tab', 'MAX_MAX_12052015 Position 19.tif.mortality.tab'], ['MAX_MAX_12052015 Position 14.tif.mortality.tab', 'MAX_MAX_12052015 Position 20.tif.mortality.tab'], ['MAX_MAX_12052015 Position 12.tif.mortality.tab'], ['MAX_MAX_12052015 Position 15.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2824: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if self.run_code(code, result):
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.4723   sv2= 0.1489242   df= 13.74173   lambda= 345.6275
# phi= 54.87081   sv2= 0.0122685   df= 6.255458   lambda= 4472.493
# phi= 57.67326   sv2= 0.004571663   df= 3.663441   lambda= 12615.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.54861   sv2= 0.07632853   df= 12.5884   lambda= 360.9215
# phi= 28.02433   sv2= 0.006185554   df= 5.840149   lambda= 4530.61
# phi= 26.55361   sv2= 0.002447988   df= 3.455853   lambda= 10847.11
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2878: PerformanceWarning: indexing past lexsort depth may impact performance.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 2
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/CR-MG yagS-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 2402.33   sv2= 0.1791007   df= 14.78993   lambda= 13413.29
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  104.721007  103.714712  104.743256  0.000107}
