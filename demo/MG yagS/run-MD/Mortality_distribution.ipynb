# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MG strains tab/MG yagS'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_df_relative_timegrid.pickle']]
# [('/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_df_relative_timegrid.pickle'), ('/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_df_relative_timegrid.pickle'), ('/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_df_relative_timegrid.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_df_relative_timegrid.pickle')]
# [['/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_timeseries_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_timeseries_dataframe.pickle', '/home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# --------PAIR-------
# df1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_df_relative_timegrid.pickle
# df2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_df_relative_timegrid.pickle
# ts1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_timeseries_dataframe.pickle
# ts2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_timeseries_dataframe.pickle
# files will be written into :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.70679   sv2= 0.08085669   df= 14.7284   lambda= 1035.249
# phi= 87.00378   sv2= 0.002624063   df= 5.377454   lambda= 33156.13
# Iterations: relative error in phi-hat = 1e-04
# phi= 43.93703   sv2= 0.24042   df= 13.90841   lambda= 182.7511
# phi= 48.74681   sv2= 0.03200798   df= 7.327665   lambda= 1522.958
# phi= 54.44041   sv2= 0.007715759   df= 4.707771   lambda= 7055.742
# phi= 57.49713   sv2= 0.002055637   df= 3.492857   lambda= 27970.47
# save file prefixed name is : MG yagS-2-vs-TA_MG yagS-1
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-MG yagS-2-vs-TA_MG yagS-1_Mortality_summary_binning poster.png
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MG yagS/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG yagS-2_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_MG yagS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MG yagS/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG yagS/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# MG yagS-2_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.70679   sv2= 0.08085669   df= 14.7284   lambda= 1035.249
# phi= 87.00378   sv2= 0.002624063   df= 5.377454   lambda= 33156.13
# TA_MG yagS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 43.93703   sv2= 0.24042   df= 13.90841   lambda= 182.7511
# phi= 48.74681   sv2= 0.03200798   df= 7.327665   lambda= 1522.958
# phi= 54.44041   sv2= 0.007715759   df= 4.707771   lambda= 7055.742
# phi= 57.49713   sv2= 0.002055637   df= 3.492857   lambda= 27970.47
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG yagS/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 MG yagS-2_df_relative_timegrid.pickle
# 2 TA_MG yagS-1_df_relative_timegrid.pickle
# MG yagS-2_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_MG yagS-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-MG yagS-2-vs-TA_MG yagS-1-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG yagS-2_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=12489.136131)
#                  est          L95%          U95%            se
# rate    9.476079e-02  8.810973e-02  1.019139e-01      0.003518
# beta    3.941356e+04  2.356830e+04  6.591176e+04  10340.358786
# s       1.599693e+00  1.249345e+00  2.048287e+00      0.201755
# lambda  1.188072e-07  8.962825e-24  1.574856e+09      0.000002
#                  est        L95%        U95%       var
# lifespan  104.691126  103.684898  105.709841  0.000162
#
#
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_MG yagS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=20355.832040)
#                  est  L95%  U95%  se
# rate    6.910595e-02   NaN   NaN NaN
# beta    5.117326e+06   NaN   NaN NaN
# s       2.697468e+03   NaN   NaN NaN
# lambda  7.966730e-08   NaN   NaN NaN
#                  est        L95%        U95%       var
# lifespan  102.726383  102.689666  103.692261  0.000084
#
#
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-MG yagS-2-vs-TA_MG yagS-1-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 MG yagS-2_df_relative_timegrid.pickle
# 2 TA_MG yagS-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MG yagS/run-MD
# --------PAIR-------
# df1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_df_relative_timegrid.pickle
# df2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_df_relative_timegrid.pickle
# ts1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-2_timeseries_dataframe.pickle
# ts2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_timeseries_dataframe.pickle
# files will be written into :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.70679   sv2= 0.08085669   df= 14.7284   lambda= 1035.249
# phi= 87.00378   sv2= 0.002624063   df= 5.377454   lambda= 33156.13
# Iterations: relative error in phi-hat = 1e-04
# phi= 102.9487   sv2= 0.08074528   df= 14.78532   lambda= 1274.981
# phi= 125.7592   sv2= 0.002466166   df= 5.180924   lambda= 50993.81
# save file prefixed name is : MG yagS-2-vs-MG yagS-1
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-MG yagS-2-vs-MG yagS-1_Mortality_summary_binning poster.png
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MG yagS/run-MD
# No error in flxsrv_fit
# MG yagS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG yagS-2_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MG yagS/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG yagS/run-MD
# MG yagS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 102.9487   sv2= 0.08074528   df= 14.78532   lambda= 1274.981
# phi= 125.7592   sv2= 0.002466166   df= 5.180924   lambda= 50993.81
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# MG yagS-2_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.70679   sv2= 0.08085669   df= 14.7284   lambda= 1035.249
# phi= 87.00378   sv2= 0.002624063   df= 5.377454   lambda= 33156.13
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG yagS/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 MG yagS-2_df_relative_timegrid.pickle
# 2 MG yagS-1_df_relative_timegrid.pickle
# MG yagS-1_df_relative_timegrid.pickle
# MG yagS-2_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-MG yagS-2-vs-MG yagS-1-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG yagS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=14320.788003)
#                  est          L95%         U95%          se
# rate    7.595214e-02  7.046867e-02     0.081862    0.002904
# beta    4.919512e+03  3.405710e+03  7106.184626  923.068204
# s       1.556184e+00  1.185864e+00     2.042148    0.215778
# lambda  1.349687e-07  2.997512e-18  6077.221556    0.000002
#                  est        L95%        U95%       var
# lifespan  104.690633  103.677146  105.678991  0.000146
#
#
# MG yagS-2_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=12489.136131)
#                  est          L95%          U95%            se
# rate    9.476079e-02  8.810973e-02  1.019139e-01      0.003518
# beta    3.941356e+04  2.356830e+04  6.591176e+04  10340.358786
# s       1.599693e+00  1.249345e+00  2.048287e+00      0.201755
# lambda  1.188072e-07  8.962825e-24  1.574856e+09      0.000002
#                  est        L95%        U95%       var
# lifespan  104.691126  103.684898  105.709841  0.000162
#
#
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-MG yagS-2-vs-MG yagS-1-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 MG yagS-2_df_relative_timegrid.pickle
# 2 MG yagS-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MG yagS/run-MD
# --------PAIR-------
# df1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_df_relative_timegrid.pickle
# df2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_df_relative_timegrid.pickle
# ts1 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/TA_MG yagS-1_timeseries_dataframe.pickle
# ts2 path : /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MG yagS-1_timeseries_dataframe.pickle
# files will be written into :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS
# Iterations: relative error in phi-hat = 1e-04
# phi= 43.93703   sv2= 0.24042   df= 13.90841   lambda= 182.7511
# phi= 48.74681   sv2= 0.03200798   df= 7.327665   lambda= 1522.958
# phi= 54.44041   sv2= 0.007715759   df= 4.707771   lambda= 7055.742
# phi= 57.49713   sv2= 0.002055637   df= 3.492857   lambda= 27970.47
# Iterations: relative error in phi-hat = 1e-04
# phi= 102.9487   sv2= 0.08074528   df= 14.78532   lambda= 1274.981
# phi= 125.7592   sv2= 0.002466166   df= 5.180924   lambda= 50993.81
# save file prefixed name is : TA_-vs-
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-TA_-vs_Mortality_summary_binning poster.png
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MG yagS/run-MD
# No error in flxsrv_fit
# MG yagS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_MG yagS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MG yagS/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG yagS/run-MD
# MG yagS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 102.9487   sv2= 0.08074528   df= 14.78532   lambda= 1274.981
# phi= 125.7592   sv2= 0.002466166   df= 5.180924   lambda= 50993.81
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_MG yagS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 43.93703   sv2= 0.24042   df= 13.90841   lambda= 182.7511
# phi= 48.74681   sv2= 0.03200798   df= 7.327665   lambda= 1522.958
# phi= 54.44041   sv2= 0.007715759   df= 4.707771   lambda= 7055.742
# phi= 57.49713   sv2= 0.002055637   df= 3.492857   lambda= 27970.47
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MG yagS/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG yagS-1_df_relative_timegrid.pickle
# 2 MG yagS-1_df_relative_timegrid.pickle
# MG yagS-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_MG yagS-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-TA_-vs-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG yagS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=14320.788003)
#                  est          L95%         U95%          se
# rate    7.595214e-02  7.046867e-02     0.081862    0.002904
# beta    4.919512e+03  3.405710e+03  7106.184626  923.068204
# s       1.556184e+00  1.185864e+00     2.042148    0.215778
# lambda  1.349687e-07  2.997512e-18  6077.221556    0.000002
#                  est        L95%        U95%       var
# lifespan  104.690633  103.677146  105.678991  0.000146
#
#
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_MG yagS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=20355.832040)
#                  est  L95%  U95%  se
# rate    6.910595e-02   NaN   NaN NaN
# beta    5.117326e+06   NaN   NaN NaN
# s       2.697468e+03   NaN   NaN NaN
# lambda  7.966730e-08   NaN   NaN NaN
#                  est        L95%        U95%       var
# lifespan  102.726383  102.689666  103.692261  0.000084
#
#
# /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MD-TA_-vs-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_MG yagS-1_df_relative_timegrid.pickle
# 2 MG yagS-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MG yagS/run-MD
