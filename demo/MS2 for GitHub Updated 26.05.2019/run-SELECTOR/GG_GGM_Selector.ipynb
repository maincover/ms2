# %% [markdown]
# # GG_GGM_SELECTOR Write the result to table

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Selector_GG_GGM import GG_GGM_Selector
data_folder = '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019'
out_folder = '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE'
gg_ggm_selector = GG_GGM_Selector(data_folder,out_folder)
gg_ggm_selector.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_relative_timegrid_cluster0.pickle', 'CR-TA_ptsH-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_mortality_dataframe_cluster0.pickle', 'CR-TA_cbpM-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pflC/CR-TA_pflC-1_relative_timegrid_cluster0.pickle', 'CR-TA_pflC-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_mortality_dataframe_cluster0.pickle', 'CR-TA_agaV-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafV/CR-TA_yafV-1_mortality_dataframe_cluster0.pickle', 'CR-TA_yafV-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_mortality_dataframe_cluster0.pickle', 'CR-TA_yhdX-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA/CR-TA_crcA-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA/CR-TA_crcA-1_mortality_dataframe_cluster0.pickle', 'CR-TA_crcA-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafX/CR-TA_yafX-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yafX/CR-TA_yafX-1_mortality_dataframe_cluster0.pickle', 'CR-TA_yafX-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_mortality_dataframe_cluster0.pickle', 'CR-TA_norW-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_relative_timegrid_cluster0.pickle', 'CR-TA_paoB-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_relative_timegrid_cluster0.pickle', 'CR-TA_yjeL-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_relative_timegrid_cluster0.pickle', 'CR-TA_ytfL-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybgD/CR-TA_ybgD-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybgD/CR-TA_ybgD-1_mortality_dataframe_cluster0.pickle', 'CR-TA_ybgD-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_relative_timegrid_cluster0.pickle', 'CR-TA_yicM-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjgB/CR-TA_yjgB-1_relative_timegrid_cluster0.pickle', 'CR-TA_yjgB-1_'], ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_relative_timegrid_cluster0.pickle', ' ...
# CR-TA_ptsH-1_
# ../../../cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# ../../../cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ptsH-1_.txt
# No error in flxsrv_fit
# 8058.2252417
# 3
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.00446251019633 0.984615384615
# No error in flxsrv_fit
# CR-TA_cbpM-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_cbpM-1_.txt
# No error in flxsrv_fit
# 17884.1376293
# 3
# 1 ['2015-01-24 00:00:00']
# No error in flxsrv_fit
# 0.10168561409 1.0
# No error in flxsrv_fit
# CR-TA_pflC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_pflC-1_.txt
# No error in flxsrv_fit
# 14987.5103521
# 9
# 1 ['2014-01-16 00:00:00']
# No error in flxsrv_fit
# 0.062379393617 1.0
# No error in flxsrv_fit
# CR-TA_agaV-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_agaV-1_.txt
# No error in flxsrv_fit
# 22991.0353442
# 10
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.00636086222648 0.989583333333
# No error in flxsrv_fit
# CR-TA_yafV-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yafV-1_.txt
# No error in flxsrv_fit
# 6518.61065924
# 7
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.000291721051826 0.997187060478
# No error in flxsrv_fit
# CR-TA_yhdX-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yhdX-1_.txt
# No error in flxsrv_fit
# 17207.642403
# 13
# 1 ['2016-06-28 00:00:00']
# No error in flxsrv_fit
# 0.00236865956542 0.99462004035
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_crcA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_crcA-1_.txt
# No error in flxsrv_fit
# 24622.0496587
# 15
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.24572746012 1.0
# No error in flxsrv_fit
# CR-TA_yafX-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yafX-1_.txt
# No error in flxsrv_fit
# 12354.3357331
# 7
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.00803744043357 0.986198243413
# No error in flxsrv_fit
# CR-TA_norW-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_norW-1_.txt
# No error in flxsrv_fit
# 29505.0462375
# 20
# 1 ['2014-11-30 00:00:00']
# No error in flxsrv_fit
# 0.0406563042877 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_paoB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_paoB-1_.txt
# No error in flxsrv_fit
# 5750.46056853
# 7
# 1 ['2016-06-28 00:00:00']
# No error in flxsrv_fit
# 0.00144660891529 0.990789473684
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yjeL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yjeL-1_.txt
# No error in flxsrv_fit
# 7469.16804142
# 7
# 1 ['2016-06-28 00:00:00']
# No error in flxsrv_fit
# 0.0449475584639 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ytfL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ytfL-1_.txt
# No error in flxsrv_fit
# 5168.73735651
# 6
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.677821857323 1.0
# No error in flxsrv_fit
# finalKM >=0.25, theoretical stats not meaningful
# CR-TA_ybgD-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ybgD-1_.txt
# No error in flxsrv_fit
# 6837.65268612
# 2
# 1 ['2016-04-07 00:00:00']
# No error in flxsrv_fit
# 0.663490729846 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yicM-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yicM-1_.txt
# No error in flxsrv_fit
# 4011.93740936
# 6
# 1 ['2016-07-07 00:00:00']
# No error in flxsrv_fit
# 0.0619008936154 1.0
# No error in flxsrv_fit
# Error in ggParameterStats
# CR-TA_yjgB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yjgB-1_.txt
# No error in flxsrv_fit
# 4251.25650312
# 7
# 1 ['2016-06-28 00:00:00']
# No error in flxsrv_fit
# 0.170494839121 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yphG-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yphG-1_.txt
# No error in flxsrv_fit
# 14492.3751577
# 11
# 1 ['2014-11-07 00:00:00']
# No error in flxsrv_fit
# 0.203569690757 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yihV-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yihV-1_.txt
# No error in flxsrv_fit
# 3848.41503206
# 7
# 1 ['2016-07-07 00:00:00']
# No error in flxsrv_fit
# 0.112697169629 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_pflD-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_pflD-1_.txt
# No error in flxsrv_fit
# 48726.8485978
# 6
# 1 ['2015-02-17 00:00:00']
# No error in flxsrv_fit
# 0.250323559648 1.0
# No error in flxsrv_fit
# CR-TA_gnsA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_gnsA-1_.txt
# No error in flxsrv_fit
# 15954.5595687
# 2
# 1 ['2015-11-17 00:00:00']
# No error in flxsrv_fit
# 0.411679123464 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_fsr-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_fsr-1_.txt
# No error in flxsrv_fit
# 24824.6866009
# 4
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# >= 0.8 1.0
# No error in flxsrv_fit
# CR-TA_yihS-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yihS-1_.txt
# No error in flxsrv_fit
# 9067.61591388
# 4
# 1 ['2016-06-01 00:00:00']
# No error in flxsrv_fit
# 0.00278805389309 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_agaR-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_agaR-1_.txt
# No error in flxsrv_fit
# 60572.0378421
# 8
# 1 ['2014-09-28 00:00:00']
# No error in flxsrv_fit
# 0.295560704074 1.0
# No error in flxsrv_fit
# CR-TA_agaA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_agaA-1_.txt
# No error in flxsrv_fit
# 9215.11144565
# 2
# 1 ['2015-02-17 00:00:00']
# No error in flxsrv_fit
# 0.314375059623 1.0
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in (function (x, B, newdata = NULL, X = NULL, transform = FALSE,  :
#   Covariance matrix not available from non-converged model
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 50 or more warnings (use warnings() to see the first 50)
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_ydjQ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ydjQ-1_.txt
# No error in flxsrv_fit
# 21078.5361363
# 9
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# 0.0598768584383 1.0
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 41 warnings (use warnings() to see them)
#   warnings.warn(x, RRuntimeWarning)
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_ybbP-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ybbP-1_.txt
# No error in flxsrv_fit
# 4544.624419
# 9
# 1 ['2016-07-07 00:00:00']
# No error in flxsrv_fit
# 0.198291537047 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_treC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_treC-1_.txt
# No error in flxsrv_fit
# 16570.8855943
# 7
# 1 ['2014-06-08 00:00:00']
# No error in flxsrv_fit
# 0.69512862649 1.0
# No error in flxsrv_fit
# CR-TA_yhbW-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yhbW-1_.txt
# No error in flxsrv_fit
# 6463.74468421
# 10
# 1 ['2014-06-02 00:00:00']
# No error in flxsrv_fit
# 0.32444231559 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_fruR-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_fruR-1_.txt
# No error in flxsrv_fit
# 12893.7376418
# 6
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 1.90528278119e-07 0.96
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ssuA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ssuA-1_.txt
# No error in flxsrv_fit
# 11211.6248724
# 7
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.102213747701 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_glpX-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_glpX-1_.txt
# No error in flxsrv_fit
# 6609.91291711
# 2
# 1 ['2016-06-01 00:00:00']
# No error in flxsrv_fit
# 0.0902862050319 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_eptA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_eptA-1_.txt
# No error in flxsrv_fit
# 9191.67444275
# 8
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.00367064220694 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_sspA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_sspA-1_.txt
# No error in flxsrv_fit
# 21763.118059
# 10
# 1 ['2014-08-06 00:00:00']
# No error in flxsrv_fit
# 0.75186465901 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_phnH-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_phnH-1_.txt
# No error in flxsrv_fit
# 4548.95237143
# 4
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.159454320743 1.0
# No error in flxsrv_fit
# finalKM >=0.25, theoretical stats not meaningful
# CR-TA_fabR-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_fabR-1_.txt
# No error in flxsrv_fit
# 8176.81196075
# 8
# 1 ['2016-03-09 00:00:00']
# No error in flxsrv_fit
# 2.16508850062e-37 0.574088440652
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_hybG-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_hybG-1_.txt
# No error in flxsrv_fit
# 9495.03579113
# 8
# 1 ['2016-04-07 00:00:00']
# No error in flxsrv_fit
# 0.000167505860879 0.958199356913
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_osmY-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_osmY-1_.txt
# No error in flxsrv_fit
# 32346.3354657
# 6
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.736382562397 1.0
# No error in flxsrv_fit
# CR-TA_yecP-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yecP-1_.txt
# No error in flxsrv_fit
# 5525.5931881
# 3
# 1 ['2016-06-01 00:00:00']
# No error in flxsrv_fit
# 0.183353875478 1.0
# No error in flxsrv_fit
# CR-TA_casE-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_casE-1_.txt
# No error in flxsrv_fit
# 11614.8365406
# 18
# 1 ['2018-09-25 00:00:00']
# No error in flxsrv_fit
# 0.0 0.441663729292
# No error in flxsrv_fit
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_fixC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_fixC-1_.txt
# No error in flxsrv_fit
# 8169.35579762
# 9
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.13951199472 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_dnaT-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_dnaT-1_.txt
# No error in flxsrv_fit
# 4378.74770441
# 4
# 1 ['2015-08-02 00:00:00']
# No error in flxsrv_fit
# 0.24751235744 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_fruB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_fruB-1_.txt
# No error in flxsrv_fit
# 13808.0979526
# 5
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 1.1180017151e-05 0.945188794153
# No error in flxsrv_fit
# Error in ggParameterStats
# CR-TA_gltL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_gltL-1_.txt
# No error in flxsrv_fit
# 5446.64750096
# 4
# 1 ['2014-07-05 00:00:00']
# No error in flxsrv_fit
# 0.0889514496419 1.0
# No error in flxsrv_fit
# CR-TA_yigL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yigL-1_.txt
# No error in flxsrv_fit
# 13978.5364257
# 13
# 1 ['2014-11-14 00:00:00']
# No error in flxsrv_fit
# 0.00678284169504 0.995430809399
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_glf-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_glf-1_.txt
# No error in flxsrv_fit
# 8250.48528962
# 4
# 1 ['2014-07-05 00:00:00']
# No error in flxsrv_fit
# 0.223108146103 1.0
# No error in flxsrv_fit
# CR-TA_nagK-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_nagK-1_.txt
# No error in flxsrv_fit
# 18954.5658016
# 7
# 1 ['2015-02-27 00:00:00']
# No error in flxsrv_fit
# 0.66971237846 1.0
# No error in flxsrv_fit
# CR-TA_yjfL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yjfL-1_.txt
# No error in flxsrv_fit
# 26916.9264767
# 4
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# 0.659370842935 1.0
# No error in flxsrv_fit
# CR-TA_cynX-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_cynX-1_.txt
# No error in flxsrv_fit
# 28327.0952111
# 4
# 1 ['2014-11-30 00:00:00']
# No error in flxsrv_fit
# 0.226027756241 1.0
# No error in flxsrv_fit
# CR-TA_ydcP-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ydcP-1_.txt
# No error in flxsrv_fit
# 16283.4788555
# 13
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 3.14451665505e-05 0.965465465465
# No error in flxsrv_fit
# CR-TA_bipA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_bipA-1_.txt
# No error in flxsrv_fit
# 12475.2848865
# 4
# 1 ['2014-07-28 00:00:00']
# No error in flxsrv_fit
# 0.0446182536051 1.0
# No error in flxsrv_fit
# CR-TA_hycA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_hycA-1_.txt
# No error in flxsrv_fit
# 26347.8402854
# 5
# 1 ['2014-09-28 00:00:00']
# No error in flxsrv_fit
# 0.00244762016142 0.994082840237
# No error in flxsrv_fit
# CR-TA_rarD-1_
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in optim(method = "BFGS", par = c(4.60517018598809, -2.30258509299405,  :
#   non-finite finite-difference value [3]
#
#   warnings.warn(x, RRuntimeWarning)
# error in ggfit
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_rarD-1_.txt
# No error in flxsrv_fit
# 7219.32535345
# 7
# 1 ['2016-03-09 00:00:00']
# No error in flxsrv_fit
# 2.59589082351e-29 0.584775086505
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Warning messages:
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 1:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In (function (x, beta, s, rate = 1, log.p = FALSE)  :
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Non-positive shape or rate
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 2:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In (function (q, beta, s, rate = 1, lower.tail = TRUE, log.p = FALSE)  :
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 3:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 4:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 5:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 6:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 7:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 8:
#   warnings.warn(x, RRuntimeWarning)
# "ERROR in step ggmStats(df)"
# finalKM >=0.25, theoretical stats not meaningful
# CR-TA_xdhC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_xdhC-1_.txt
# No error in flxsrv_fit
# 14427.9117844
# 2
# 1 ['2015-02-17 00:00:00']
# No error in flxsrv_fit
# >= 0.8 1.0
# No error in flxsrv_fit
# CR-TA_ykfF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ykfF-1_.txt
# No error in flxsrv_fit
# 14276.2151064
# 5
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.0392580243775 1.0
# No error in flxsrv_fit
# CR-TA_ulaD-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ulaD-1_.txt
# No error in flxsrv_fit
# 5701.62700019
# 4
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.065277323753 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yjhG-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yjhG-1_.txt
# No error in flxsrv_fit
# 14561.64668
# 26
# 1 ['2015-06-21 00:00:00']
# No error in flxsrv_fit
# 0.000550323025697 0.973333333333
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_eutQ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_eutQ-1_.txt
# No error in flxsrv_fit
# 8826.42688292
# 5
# 1 ['2014-07-05 00:00:00']
# No error in flxsrv_fit
# 0.0630208339089 1.0
# No error in flxsrv_fit
# CR-TA_ydjK-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ydjK-1_.txt
# No error in flxsrv_fit
# 14218.4784962
# 2
# 1 ['2015-02-10 00:00:00']
# No error in flxsrv_fit
# >= 0.8 1.0
# No error in flxsrv_fit
# CR-TA_gspM-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_gspM-1_.txt
# No error in flxsrv_fit
# 10964.8340793
# 5
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 0.000101710746148 0.943089430894
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yjfF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yjfF-1_.txt
# No error in flxsrv_fit
# 6163.03621841
# 3
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.00444839862293 0.959183673469
# No error in flxsrv_fit
# Error in ggParameterStats
# CR-TA_yfjO-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yfjO-1_.txt
# No error in flxsrv_fit
# 12785.7003774
# 10
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.0262805097555 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yjfJ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yjfJ-1_.txt
# No error in flxsrv_fit
# 23331.8824225
# 2
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# 0.339983688072 1.0
# No error in flxsrv_fit
# CR-TA_ygfO-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ygfO-1_.txt
# No error in flxsrv_fit
# 12800.336981
# 6
# 1 ['2014-07-05 00:00:00']
# No error in flxsrv_fit
# 0.475971537657 1.0
# No error in flxsrv_fit
# CR-TA_yagH-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yagH-1_.txt
# No error in flxsrv_fit
# 2595.29640929
# 3
# 1 ['2014-01-16 00:00:00']
# No error in flxsrv_fit
# 0.00869119884033 0.996503496503
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_zapE-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_zapE-1_.txt
# No error in flxsrv_fit
# 27332.730775
# 6
# 1 ['2014-07-28 00:00:00']
# No error in flxsrv_fit
# 0.0355792572082 1.0
# No error in flxsrv_fit
# CR-TA_yicH-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yicH-1_.txt
# No error in flxsrv_fit
# 6911.86102353
# 6
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.296308313563 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_gltD-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_gltD-1_.txt
# No error in flxsrv_fit
# 9187.82308814
# 8
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.0133878011618 0.997461928934
# No error in flxsrv_fit
# "ERROR in step ggmStats(df)"
# CR-TA_ybdK-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ybdK-1_.txt
# No error in flxsrv_fit
# 10333.2254618
# 7
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.167215769188 1.0
# No error in flxsrv_fit
# CR-TA_appA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_appA-1_.txt
# No error in flxsrv_fit
# 30648.0128989
# 4
# 1 ['2015-02-17 00:00:00']
# No error in flxsrv_fit
# >= 0.8 1.0
# No error in flxsrv_fit
# CR-TA_yigZ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yigZ-1_.txt
# No error in flxsrv_fit
# 15883.8795685
# 6
# 1 ['2016-10-10 00:00:00']
# No error in flxsrv_fit
# 5.34350082346e-06 0.95756718529
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yagQ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yagQ-1_.txt
# No error in flxsrv_fit
# 14115.9504677
# 9
# 1 ['2014-01-16 00:00:00']
# No error in flxsrv_fit
# 0.214524017419 1.0
# No error in flxsrv_fit
# CR-TA_ldcC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ldcC-1_.txt
# No error in flxsrv_fit
# 11431.5385693
# 7
# 1 ['2014-07-05 00:00:00']
# No error in flxsrv_fit
# 0.456248656862 1.0
# No error in flxsrv_fit
# CR-TA_nsrR-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_nsrR-1_.txt
# No error in flxsrv_fit
# 5091.09476442
# 4
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.0462569649134 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yncI-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yncI-1_.txt
# No error in flxsrv_fit
# 27404.2720451
# 9
# 1 ['2014-06-08 00:00:00']
# No error in flxsrv_fit
# 0.255491558465 1.0
# No error in flxsrv_fit
# CR-TA_bglF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_bglF-1_.txt
# No error in flxsrv_fit
# 13256.9612745
# 2
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# >= 0.8 1.0
# No error in flxsrv_fit
# "ERROR in step ggmStats(df)"
# CR-TA_ycaL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ycaL-1_.txt
# No error in flxsrv_fit
# 7655.96635229
# 6
# 1 ['2018-10-26 00:00:00']
# No error in flxsrv_fit
# 0.0441007232254 1.0
# No error in flxsrv_fit
# CR-TA_yggF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yggF-1_.txt
# No error in flxsrv_fit
# 11198.4259373
# 4
# 1 ['2016-04-07 00:00:00']
# No error in flxsrv_fit
# 0.299116335468 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yobH-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yobH-1_.txt
# No error in flxsrv_fit
# 14440.3161465
# 13
# 1 ['2015-03-06 00:00:00']
# No error in flxsrv_fit
# 0.000954779042118 0.987675070028
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_alr-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_alr-1_.txt
# No error in flxsrv_fit
# 25024.6624001
# 42
# 1 ['2018-07-12 00:00:00']
# No error in flxsrv_fit
# 2.64672148271e-05 0.67215506461
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_caiB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_caiB-1_.txt
# No error in flxsrv_fit
# 9475.4429876
# 7
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.000177889682246 0.991803278689
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ydgT-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ydgT-1_.txt
# No error in flxsrv_fit
# 9003.46380676
# 2
# 1 ['2016-04-07 00:00:00']
# No error in flxsrv_fit
# 0.175209932005 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_dcp-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_dcp-1_.txt
# No error in flxsrv_fit
# 20474.7208829
# 4
# 1 ['2014-09-28 00:00:00']
# No error in flxsrv_fit
# 0.295156260922 1.0
# No error in flxsrv_fit
# CR-TA_dcuA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_dcuA-1_.txt
# No error in flxsrv_fit
# 9454.30203252
# 2
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.336681379307 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yhbP-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yhbP-1_.txt
# No error in flxsrv_fit
# 7788.92079513
# 10
# 1 ['2014-06-02 00:00:00']
# No error in flxsrv_fit
# 0.353918285754 1.0
# No error in flxsrv_fit
# CR-TA_lsrC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_lsrC-1_.txt
# No error in flxsrv_fit
# 13009.1201063
# 5
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.0120082947211 1.0
# No error in flxsrv_fit
# CR-TA_fkpA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_fkpA-1_.txt
# No error in flxsrv_fit
# 22854.6282484
# 3
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 0.0044852221117 0.989648033126
# No error in flxsrv_fit
# CR-TA_yiaW-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yiaW-1_.txt
# No error in flxsrv_fit
# 3968.89505925
# 5
# 1 ['2016-07-07 00:00:00']
# No error in flxsrv_fit
# 0.0624916995879 1.0
# No error in flxsrv_fit
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_xdhB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_xdhB-1_.txt
# No error in flxsrv_fit
# 8626.98160828
# 9
# 1 ['2014-06-02 00:00:00']
# No error in flxsrv_fit
# >= 0.8 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_cstA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_cstA-1_.txt
# No error in flxsrv_fit
# 28172.2570266
# 8
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 0.00668317877267 0.998447204969
# No error in flxsrv_fit
# CR-TA_ynaA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ynaA-1_.txt
# No error in flxsrv_fit
# 5352.1554558
# 17
# 1 ['2018-09-25 00:00:00']
# No error in flxsrv_fit
# 4.65957751572e-13 0.709932726553
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_appB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_appB-1_.txt
# No error in flxsrv_fit
# 6472.33855433
# 7
# 1 ['2014-06-02 00:00:00']
# No error in flxsrv_fit
# 0.519257927402 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_gspF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_gspF-1_.txt
# No error in flxsrv_fit
# 6959.64102199
# 4
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 0.0941916096081 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_recF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_recF-1_.txt
# No error in flxsrv_fit
# 8636.3755266
# 5
# 1 ['2014-07-05 00:00:00']
# No error in flxsrv_fit
# 0.0735328982574 1.0
# No error in flxsrv_fit
# CR-TA_ycaD-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ycaD-1_.txt
# No error in flxsrv_fit
# 21561.5761254
# 5
# 1 ['2014-07-28 00:00:00']
# No error in flxsrv_fit
# 0.337278879612 1.0
# No error in flxsrv_fit
# CR-TA_yehA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yehA-1_.txt
# No error in flxsrv_fit
# 6266.50227433
# 10
# 1 ['2015-03-06 00:00:00']
# No error in flxsrv_fit
# 0.0390715626842 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yggE-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yggE-1_.txt
# No error in flxsrv_fit
# 17781.5915319
# 9
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.0924065861678 1.0
# No error in flxsrv_fit
# CR-TA_yfbM-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yfbM-1_.txt
# No error in flxsrv_fit
# 10041.9216704
# 13
# 1 ['2016-06-28 00:00:00']
# No error in flxsrv_fit
# 0.0498843571144 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_citT-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_citT-1_.txt
# No error in flxsrv_fit
# 10753.4616607
# 7
# 1 ['2014-11-30 00:00:00']
# No error in flxsrv_fit
# 0.16264058788 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_tyrB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_tyrB-1_.txt
# No error in flxsrv_fit
# 8608.79795366
# 7
# 1 ['2014-11-07 00:00:00']
# No error in flxsrv_fit
# 0.747344267932 1.0
# No error in flxsrv_fit
# "ERROR in step ggmStats(df)"
# CR-TA_yoaF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yoaF-1_.txt
# No error in flxsrv_fit
# 9103.16742963
# 3
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# 0.0665522510565 1.0
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 46 warnings (use warnings() to see them)
#   warnings.warn(x, RRuntimeWarning)
# "ERROR in step ggmStats(df)"
# CR-TA_yeeW-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yeeW-1_.txt
# No error in flxsrv_fit
# 19100.8078616
# 4
# 1 ['2014-07-28 00:00:00']
# No error in flxsrv_fit
# 0.185301808355 1.0
# No error in flxsrv_fit
# CR-TA_yjfC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yjfC-1_.txt
# No error in flxsrv_fit
# 27783.8101956
# 5
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# 0.266002503972 1.0
# No error in flxsrv_fit
# CR-TA_ygjP-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ygjP-1_.txt
# No error in flxsrv_fit
# 8563.28610377
# 18
# 1 ['2018-09-25 00:00:00']
# No error in flxsrv_fit
# 7.31643327255e-10 0.76714801444
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_atoS-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_atoS-1_.txt
# No error in flxsrv_fit
# 9789.66913654
# 17
# 1 ['2018-09-25 00:00:00']
# No error in flxsrv_fit
# 2.18029616533e-09 0.756725595696
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yqjE-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yqjE-1_.txt
# No error in flxsrv_fit
# 15346.6905267
# 10
# 1 ['2016-04-07 00:00:00']
# No error in flxsrv_fit
# 8.6304103536e-07 0.934075342466
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yidH-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yidH-1_.txt
# No error in flxsrv_fit
# 8287.32349861
# 11
# 1 ['2016-07-07 00:00:00']
# No error in flxsrv_fit
# 0.000164955911803 0.989814814815
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_pfkA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_pfkA-1_.txt
# No error in flxsrv_fit
# 17688.0637459
# 9
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.650411766882 1.0
# No error in flxsrv_fit
# CR-TA_rsd-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_rsd-1_.txt
# No error in flxsrv_fit
# 6956.91775597
# 2
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# 0.64956395856 1.0
# No error in flxsrv_fit
# CR-TA_nagZ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_nagZ-1_.txt
# No error in flxsrv_fit
# 28108.8141846
# 15
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.0780649039481 1.0
# No error in flxsrv_fit
# CR-TA_yiaG-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yiaG-1_.txt
# No error in flxsrv_fit
# 6852.22838239
# 6
# 1 ['2018-11-01 00:00:00']
# No error in flxsrv_fit
# 0.648332850854 1.0
# No error in flxsrv_fit
# CR-TA_ygcQ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ygcQ-1_.txt
# No error in flxsrv_fit
# 5801.21058005
# 11
# 1 ['2018-09-25 00:00:00']
# No error in flxsrv_fit
# 6.42020950239e-19 0.506729081334
# No error in flxsrv_fit
# CR-TA_mprA-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_mprA-1_.txt
# No error in flxsrv_fit
# 12536.6570865
# 4
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 3.31541820762e-07 0.842105263158
# No error in flxsrv_fit
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_yagL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_yagL-1_.txt
# No error in flxsrv_fit
# 6105.2263479
# 3
# 1 ['2015-07-12 00:00:00']
# No error in flxsrv_fit
# >= 0.8 1.0
# No error in flxsrv_fit
# CR-TA_tdcE-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_tdcE-1_.txt
# No error in flxsrv_fit
# 11004.8301873
# 7
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.00346936047571 0.993215739484
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ykfI-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ykfI-1_.txt
# No error in flxsrv_fit
# 8754.28293428
# 8
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.358284666527 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_alsB-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_alsB-1_.txt
# No error in flxsrv_fit
# 12044.6674569
# 2
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.158909826893 1.0
# No error in flxsrv_fit
# Error in ggParameterStats
# CR-TA_gspL-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_gspL-1_.txt
# No error in flxsrv_fit
# 8123.18886263
# 5
# 1 ['2018-09-10 00:00:00']
# No error in flxsrv_fit
# 0.000895817592328 0.969465648855
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_idnD-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_idnD-1_.txt
# No error in flxsrv_fit
# 7229.81015781
# 3
# 1 ['2015-01-24 00:00:00']
# No error in flxsrv_fit
# 0.566858519696 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ybaJ-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ybaJ-1_.txt
# No error in flxsrv_fit
# 3216.53647326
# 2
# 1 ['2016-04-07 00:00:00']
# No error in flxsrv_fit
# 0.0220817925936 1.0
# No error in flxsrv_fit
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_napC-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_napC-1_.txt
# No error in flxsrv_fit
# 8936.44052554
# 7
# 1 ['2018-10-18 00:00:00']
# No error in flxsrv_fit
# 0.0599946418657 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ytfF-1_
# ----------- /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/GG_GGM_TABLE/CR-TA_ytfF-1_.txt
# No error in flxsrv_fit
# 10385.413772
# 10
# 1 ['2018-10-11 00:00:00']
# No error in flxsrv_fit
# 0.0830532663707 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
