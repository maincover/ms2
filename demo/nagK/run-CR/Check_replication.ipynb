# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/TA_nagK-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/TA_nagK-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/TA_nagK-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK']
#
# out_name_s  ['TA_nagK-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/TA_nagK-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/TA_nagK-1_analysis_metadata.pickle
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 25-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 26-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 27-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 28-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 30-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 31-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 33-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 21-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 26-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 27-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 28-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 30-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 31-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 33-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 25-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 27-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 28-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 30-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 31-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 33-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 26-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 28-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 30-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 31-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 33-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 27-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 30-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 31-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 33-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 28-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 31-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 33-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 30-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 33-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 31-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 34-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 33-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 35-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 34-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 44-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 35-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 45-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 44-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 46-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 45-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 46-1.tif.mortality.tab ------ MAX_27022015 Position 70-1.tif.mortality.tab
# MAX_27022015 Position 46-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 46-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 46-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 46-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 46-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 46-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 70-1.tif.mortality.tab ------ MAX_27022015 Position 71-1.tif.mortality.tab
# MAX_27022015 Position 70-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 70-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 70-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 70-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 70-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 71-1.tif.mortality.tab ------ MAX_27022015 Position 72-1.tif.mortality.tab
# MAX_27022015 Position 71-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 71-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 71-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 71-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 72-1.tif.mortality.tab ------ MAX_27022015 Position 77-1.tif.mortality.tab
# MAX_27022015 Position 72-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 72-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 72-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 77-1.tif.mortality.tab ------ MAX_27022015 Position 79-1.tif.mortality.tab
# MAX_27022015 Position 77-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 77-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 79-1.tif.mortality.tab ------ MAX_27022015 Position 83-1.tif.mortality.tab
# MAX_27022015 Position 79-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# MAX_27022015 Position 83-1.tif.mortality.tab ------ MAX_27022015 Position 98-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_dentrogram-all-files.eps
# [['MAX_27022015 Position 21-1.tif.mortality.tab', 'MAX_27022015 Position 27-1.tif.mortality.tab', 'MAX_27022015 Position 28-1.tif.mortality.tab', 'MAX_27022015 Position 33-1.tif.mortality.tab'], ['MAX_27022015 Position 25-1.tif.mortality.tab', 'MAX_27022015 Position 30-1.tif.mortality.tab', 'MAX_27022015 Position 34-1.tif.mortality.tab', 'MAX_27022015 Position 35-1.tif.mortality.tab', 'MAX_27022015 Position 45-1.tif.mortality.tab', 'MAX_27022015 Position 46-1.tif.mortality.tab'], ['MAX_27022015 Position 70-1.tif.mortality.tab', 'MAX_27022015 Position 71-1.tif.mortality.tab', 'MAX_27022015 Position 83-1.tif.mortality.tab', 'MAX_27022015 Position 98-1.tif.mortality.tab'], ['MAX_27022015 Position 26-1.tif.mortality.tab', 'MAX_27022015 Position 31-1.tif.mortality.tab', 'MAX_27022015 Position 72-1.tif.mortality.tab', 'MAX_27022015 Position 77-1.tif.mortality.tab', 'MAX_27022015 Position 79-1.tif.mortality.tab'], ['MAX_27022015 Position 44-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 143.4038   sv2= 0.05907065   df= 14.08107   lambda= 2427.665
# phi= 149.0753   sv2= 0.001851031   df= 4.207481   lambda= 80536.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 19.42293   sv2= 0.06289332   df= 13.42559   lambda= 308.8234
# phi= 19.74725   sv2= 0.004093796   df= 6.223532   lambda= 4823.702
# phi= 20.06206   sv2= 0.003550047   df= 3.562729   lambda= 5651.209
# phi= 20.11367   sv2= 0.003524961   df= 3.463905   lambda= 5706.07
# phi= 20.11707   sv2= 0.003522842   df= 3.458028   lambda= 5710.467
# phi= 20.11735   sv2= 0.00352267   df= 3.45756   lambda= 5710.823
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.75313   sv2= 0.04512178   df= 12.37813   lambda= 415.6115
# phi= 20.11496   sv2= 0.001354601   df= 5.485462   lambda= 14849.36
# Iterations: relative error in phi-hat = 1e-04
# phi= 63.65726   sv2= 0.03971314   df= 9.172454   lambda= 1602.927
# phi= 56.83314   sv2= 0.003505292   df= 3.267165   lambda= 16213.52
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nagK/CR-TA_nagK-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 49.20096   sv2= 0.07829069   df= 16.05363   lambda= 628.4395
# phi= 50.39654   sv2= 0.001444431   df= 6.382067   lambda= 34890.23
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.73127   sv2= 0.05202718   df= 13.42585   lambda= 283.1457
# phi= 14.92042   sv2= 0.005449396   df= 6.300493   lambda= 2737.995
# phi= 15.04521   sv2= 0.004858087   df= 3.870466   lambda= 3096.941
# phi= 15.05942   sv2= 0.004867944   df= 3.779375   lambda= 3093.59
# phi= 15.05929   sv2= 0.004867903   df= 3.78016   lambda= 3093.589
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  80.219431  79.184377  81.926039  0.000126, 1:                 est       L95%       U95%       var
# lifespan  76.365557  75.259678  76.365557  0.000201}
