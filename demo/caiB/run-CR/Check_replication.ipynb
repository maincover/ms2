# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/TA_caiB-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/TA_caiB-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/TA_caiB-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB']
#
# out_name_s  ['TA_caiB-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/TA_caiB-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/TA_caiB-1_analysis_metadata.pickle
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 110-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 111-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 125-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 3-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 4-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 42-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 43-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 109-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 111-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 125-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 3-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 4-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 42-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 43-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 110-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 125-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 3-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 4-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 42-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 43-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 111-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 3-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 4-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 42-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 43-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 125-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 4-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 42-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 43-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 3-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 42-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 43-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 4-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 42-1.tif.mortality.tab ------ MAX_11102018 Position 43-1.tif.mortality.tab
# MAX_11102018 Position 42-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 42-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 42-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 42-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 42-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 42-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 43-1.tif.mortality.tab ------ MAX_11102018 Position 5-1.tif.mortality.tab
# MAX_11102018 Position 43-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 43-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 43-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 43-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 43-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 5-1.tif.mortality.tab ------ MAX_11102018 Position 6-1.tif.mortality.tab
# MAX_11102018 Position 5-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 5-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 5-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 5-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 6-1.tif.mortality.tab ------ MAX_11102018 Position 62-1.tif.mortality.tab
# MAX_11102018 Position 6-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 6-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 6-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 62-1.tif.mortality.tab ------ MAX_11102018 Position 63-1.tif.mortality.tab
# MAX_11102018 Position 62-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 62-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 63-1.tif.mortality.tab ------ MAX_11102018 Position 66-1.tif.mortality.tab
# MAX_11102018 Position 63-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# MAX_11102018 Position 66-1.tif.mortality.tab ------ MAX_11102018 Position 7-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_dentrogram-all-files.eps
# [['MAX_11102018 Position 110-1.tif.mortality.tab', 'MAX_11102018 Position 125-1.tif.mortality.tab'], ['MAX_11102018 Position 5-1.tif.mortality.tab', 'MAX_11102018 Position 6-1.tif.mortality.tab', 'MAX_11102018 Position 7-1.tif.mortality.tab'], ['MAX_11102018 Position 3-1.tif.mortality.tab', 'MAX_11102018 Position 4-1.tif.mortality.tab', 'MAX_11102018 Position 62-1.tif.mortality.tab', 'MAX_11102018 Position 66-1.tif.mortality.tab'], ['MAX_11102018 Position 109-1.tif.mortality.tab', 'MAX_11102018 Position 111-1.tif.mortality.tab', 'MAX_11102018 Position 42-1.tif.mortality.tab', 'MAX_11102018 Position 43-1.tif.mortality.tab'], ['MAX_11102018 Position 63-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 133.7971   sv2= 0.2779603   df= 11.48221   lambda= 481.3534
# phi= 147.5487   sv2= 0.003495492   df= 4.895725   lambda= 42211.14
# Iterations: relative error in phi-hat = 1e-04
# phi= 295.7143   sv2= 0.1515559   df= 10.04716   lambda= 1951.189
# phi= 304.9062   sv2= 0.001008172   df= 3.303082   lambda= 302434.8
# Iterations: relative error in phi-hat = 1e-04
# phi= 160.4435   sv2= 0.08702676   df= 9.938162   lambda= 1843.611
# phi= 180.0363   sv2= 0.006019477   df= 3.51484   lambda= 29908.96
# Iterations: relative error in phi-hat = 1e-04
# phi= 26.55735   sv2= 0.04187922   df= 9.406309   lambda= 634.1416
# phi= 28.84275   sv2= 0.002534664   df= 3.972229   lambda= 11379.32
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_mortality_dataframe_cluster2.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/caiB/CR-TA_caiB-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 112.7185   sv2= 0.3280449   df= 12.56585   lambda= 343.607
# phi= 124.1538   sv2= 0.00808018   df= 5.81448   lambda= 15365.22
# Iterations: relative error in phi-hat = 1e-04
# phi= 160.4435   sv2= 0.08702676   df= 9.938162   lambda= 1843.611
# phi= 180.0363   sv2= 0.006019477   df= 3.51484   lambda= 29908.96
# Iterations: relative error in phi-hat = 1e-04
# phi= 26.55735   sv2= 0.04187922   df= 9.406309   lambda= 634.1416
# phi= 28.84275   sv2= 0.002534664   df= 3.972229   lambda= 11379.32
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%     var
# lifespan  114.033378  111.630074  115.234406  0.0002, 1:                  est        L95%       U95%       var
# lifespan  121.169674  119.960703  122.07409  0.000618, 2:                  est        L95%        U95%       var
# lifespan  102.327307  101.111506  107.225076  0.000925}
