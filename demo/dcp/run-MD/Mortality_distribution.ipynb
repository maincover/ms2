# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/TA_dcp-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/TA_dcp-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp
# Iterations: relative error in phi-hat = 1e-04
# phi= 75.98882   sv2= 0.2377931   df= 16.79529   lambda= 319.5586
# phi= 78.73248   sv2= 0.008255779   df= 7.836296   lambda= 9536.65
# phi= 79.48104   sv2= 0.0008276928   df= 3.878268   lambda= 96027.22
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_dcp-1_df_relative_timegrid-vs-TA_dcp-1_timeseries_dataframe
# biName is :  TA_dcp-1_df_relative_timegrid-vs-TA_dcp-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/dcp/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_dcp-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/dcp/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/dcp/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_dcp-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 75.98882   sv2= 0.2377931   df= 16.79529   lambda= 319.5586
# phi= 78.73248   sv2= 0.008255779   df= 7.836296   lambda= 9536.65
# phi= 79.48104   sv2= 0.0008276928   df= 3.878268   lambda= 96027.22
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/dcp/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_dcp-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_dcp-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/MD-TA_dcp-1_df_relative_timegrid-vs-TA_dcp-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_dcp-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=30424.720665)
#                  est          L95%         U95%            se
# rate    6.148341e-02  5.794217e-02     0.065241  1.860911e-03
# beta    3.233933e+03  2.110264e+03  4955.928918  7.043596e+02
# s       3.899957e+00  2.078555e+00     7.317425  1.252174e+00
# lambda  8.519180e-08  1.216523e-16    59.658897  8.852723e-07
#                  est       L95%        U95%       var
# lifespan  104.829341  103.82964  106.763148  0.000063
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/MD-TA_dcp-1_df_relative_timegrid-vs-TA_dcp-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_dcp-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/dcp/run-MD
