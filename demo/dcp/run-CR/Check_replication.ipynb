# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/TA_dcp-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/TA_dcp-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/TA_dcp-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp']
#
# out_name_s  ['TA_dcp-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/TA_dcp-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/TA_dcp-1_analysis_metadata.pickle
# MAX_28092014 Position 100-1.tif.mortality.tab ------ MAX_28092014 Position 101-1.tif.mortality.tab
# MAX_28092014 Position 100-1.tif.mortality.tab ------ MAX_28092014 Position 90-1.tif.mortality.tab
# MAX_28092014 Position 100-1.tif.mortality.tab ------ MAX_28092014 Position 93-1.tif.mortality.tab
# MAX_28092014 Position 100-1.tif.mortality.tab ------ MAX_28092014 Position 95-1.tif.mortality.tab
# MAX_28092014 Position 100-1.tif.mortality.tab ------ MAX_28092014 Position 96-1.tif.mortality.tab
# MAX_28092014 Position 100-1.tif.mortality.tab ------ MAX_28092014 Position 99-1.tif.mortality.tab
# MAX_28092014 Position 101-1.tif.mortality.tab ------ MAX_28092014 Position 90-1.tif.mortality.tab
# MAX_28092014 Position 101-1.tif.mortality.tab ------ MAX_28092014 Position 93-1.tif.mortality.tab
# MAX_28092014 Position 101-1.tif.mortality.tab ------ MAX_28092014 Position 95-1.tif.mortality.tab
# MAX_28092014 Position 101-1.tif.mortality.tab ------ MAX_28092014 Position 96-1.tif.mortality.tab
# MAX_28092014 Position 101-1.tif.mortality.tab ------ MAX_28092014 Position 99-1.tif.mortality.tab
# MAX_28092014 Position 90-1.tif.mortality.tab ------ MAX_28092014 Position 93-1.tif.mortality.tab
# MAX_28092014 Position 90-1.tif.mortality.tab ------ MAX_28092014 Position 95-1.tif.mortality.tab
# MAX_28092014 Position 90-1.tif.mortality.tab ------ MAX_28092014 Position 96-1.tif.mortality.tab
# MAX_28092014 Position 90-1.tif.mortality.tab ------ MAX_28092014 Position 99-1.tif.mortality.tab
# MAX_28092014 Position 93-1.tif.mortality.tab ------ MAX_28092014 Position 95-1.tif.mortality.tab
# MAX_28092014 Position 93-1.tif.mortality.tab ------ MAX_28092014 Position 96-1.tif.mortality.tab
# MAX_28092014 Position 93-1.tif.mortality.tab ------ MAX_28092014 Position 99-1.tif.mortality.tab
# MAX_28092014 Position 95-1.tif.mortality.tab ------ MAX_28092014 Position 96-1.tif.mortality.tab
# MAX_28092014 Position 95-1.tif.mortality.tab ------ MAX_28092014 Position 99-1.tif.mortality.tab
# MAX_28092014 Position 96-1.tif.mortality.tab ------ MAX_28092014 Position 99-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_dentrogram-all-files.eps
# [['MAX_28092014 Position 93-1.tif.mortality.tab', 'MAX_28092014 Position 96-1.tif.mortality.tab', 'MAX_28092014 Position 99-1.tif.mortality.tab'], ['MAX_28092014 Position 90-1.tif.mortality.tab', 'MAX_28092014 Position 95-1.tif.mortality.tab'], ['MAX_28092014 Position 100-1.tif.mortality.tab', 'MAX_28092014 Position 101-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 201.1226   sv2= 0.1437869   df= 13.80115   lambda= 1398.755
# phi= 216.7095   sv2= 0.001615975   df= 4.658994   lambda= 134104.5
# Iterations: relative error in phi-hat = 1e-04
# phi= 41.9406   sv2= 0.1113665   df= 12.9426   lambda= 376.5996
# phi= 42.74602   sv2= 0.005136101   df= 5.851153   lambda= 8322.66
# phi= 42.55979   sv2= 0.0003760182   df= 3.208239   lambda= 113185.4
# Iterations: relative error in phi-hat = 1e-04
# phi= 69.78269   sv2= 0.06620039   df= 13.81772   lambda= 1054.113
# phi= 72.64207   sv2= 0.002370239   df= 5.053116   lambda= 30647.57
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/dcp/CR-TA_dcp-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 82.98622   sv2= 0.1449469   df= 15.74257   lambda= 572.5284
# phi= 85.43504   sv2= 0.00326176   df= 6.415401   lambda= 26192.93
# Iterations: relative error in phi-hat = 1e-04
# phi= 41.9406   sv2= 0.1113665   df= 12.9426   lambda= 376.5996
# phi= 42.74602   sv2= 0.005136101   df= 5.851153   lambda= 8322.66
# phi= 42.55979   sv2= 0.0003760182   df= 3.208239   lambda= 113185.4
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  101.837632  100.844198  103.763317  0.000095, 1:                  est        L95%        U95%       var
# lifespan  108.785442  107.785453  108.829452  0.000186}
