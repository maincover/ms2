# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygcQ'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygcQ/TA_ygcQ-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygcQ/TA_ygcQ-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygcQ
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.93186   sv2= 0.129346   df= 12.83686   lambda= 293.2588
# phi= 39.2821   sv2= 0.02798467   df= 6.206371   lambda= 1403.701
# phi= 41.65326   sv2= 0.01756043   df= 4.607171   lambda= 2371.995
# phi= 43.26068   sv2= 0.01405995   df= 4.192186   lambda= 3076.873
# phi= 44.23496   sv2= 0.01236666   df= 4.003094   lambda= 3576.954
# phi= 44.84873   sv2= 0.01141592   df= 3.898234   lambda= 3928.615
# phi= 45.24755   sv2= 0.01083848   df= 3.834562   lambda= 4174.714
# phi= 45.51215   sv2= 0.01047126   df= 3.793958   lambda= 4346.389
# phi= 45.69014   sv2= 0.01023093   df= 3.767303   lambda= 4465.881
# phi= 45.81097   sv2= 0.01007073   df= 3.749488   lambda= 4548.921
# phi= 45.89352   sv2= 0.009962634   df= 3.737443   lambda= 4606.565
# phi= 45.95015   sv2= 0.009889093   df= 3.729236   lambda= 4646.548
# phi= 45.98911   sv2= 0.009838785   df= 3.723616   lambda= 4674.267
# phi= 46.01597   sv2= 0.009804241   df= 3.719754   lambda= 4693.476
# phi= 46.03451   sv2= 0.00978046   df= 3.717093   lambda= 4706.784
# phi= 46.04732   sv2= 0.009764059   df= 3.715258   lambda= 4716.002
# phi= 46.05617   sv2= 0.009752734   df= 3.71399   lambda= 4722.386
# phi= 46.0623   sv2= 0.009744907   df= 3.713114   lambda= 4726.807
# phi= 46.06654   sv2= 0.009739495   df= 3.712508   lambda= 4729.869
# phi= 46.06947   sv2= 0.009735752   df= 3.712089   lambda= 4731.989
# phi= 46.0715   sv2= 0.009733161   df= 3.711799   lambda= 4733.457
# phi= 46.07291   sv2= 0.009731368   df= 3.711598   lambda= 4734.474
# phi= 46.07388   sv2= 0.009730127   df= 3.711459   lambda= 4735.178
# phi= 46.07455   sv2= 0.009729268   df= 3.711363   lambda= 4735.665
# phi= 46.07502   sv2= 0.009728673   df= 3.711296   lambda= 4736.002
# save file prefixed name is : TA_ygcQ-1_df_relative_timegrid-vs-TA_ygcQ-1_timeseries_dataframe
# biName is :  TA_ygcQ-1_df_relative_timegrid-vs-TA_ygcQ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ygcQ/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ygcQ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ygcQ/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ygcQ/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ygcQ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 37.93186   sv2= 0.129346   df= 12.83686   lambda= 293.2588
# phi= 39.2821   sv2= 0.02798467   df= 6.206371   lambda= 1403.701
# phi= 41.65326   sv2= 0.01756043   df= 4.607171   lambda= 2371.995
# phi= 43.26068   sv2= 0.01405995   df= 4.192186   lambda= 3076.873
# phi= 44.23496   sv2= 0.01236666   df= 4.003094   lambda= 3576.954
# phi= 44.84873   sv2= 0.01141592   df= 3.898234   lambda= 3928.615
# phi= 45.24755   sv2= 0.01083848   df= 3.834562   lambda= 4174.714
# phi= 45.51215   sv2= 0.01047126   df= 3.793958   lambda= 4346.389
# phi= 45.69014   sv2= 0.01023093   df= 3.767303   lambda= 4465.881
# phi= 45.81097   sv2= 0.01007073   df= 3.749488   lambda= 4548.921
# phi= 45.89352   sv2= 0.009962634   df= 3.737443   lambda= 4606.565
# phi= 45.95015   sv2= 0.009889093   df= 3.729236   lambda= 4646.548
# phi= 45.98911   sv2= 0.009838785   df= 3.723616   lambda= 4674.267
# phi= 46.01597   sv2= 0.009804241   df= 3.719754   lambda= 4693.476
# phi= 46.03451   sv2= 0.00978046   df= 3.717093   lambda= 4706.784
# phi= 46.04732   sv2= 0.009764059   df= 3.715258   lambda= 4716.002
# phi= 46.05617   sv2= 0.009752734   df= 3.71399   lambda= 4722.386
# phi= 46.0623   sv2= 0.009744907   df= 3.713114   lambda= 4726.807
# phi= 46.06654   sv2= 0.009739495   df= 3.712508   lambda= 4729.869
# phi= 46.06947   sv2= 0.009735752   df= 3.712089   lambda= 4731.989
# phi= 46.0715   sv2= 0.009733161   df= 3.711799   lambda= 4733.457
# phi= 46.07291   sv2= 0.009731368   df= 3.711598   lambda= 4734.474
# phi= 46.07388   sv2= 0.009730127   df= 3.711459   lambda= 4735.178
# phi= 46.07455   sv2= 0.009729268   df= 3.711363   lambda= 4735.665
# phi= 46.07502   sv2= 0.009728673   df= 3.711296   lambda= 4736.002
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ygcQ/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ygcQ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ygcQ-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygcQ/MD-TA_ygcQ-1_df_relative_timegrid-vs-TA_ygcQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ygcQ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7553.457424)
#                  est          L95%          U95%            se
# rate    2.527309e-01  1.483071e-01  4.306799e-01  6.873374e-02
# beta    1.426600e+15  2.393888e+07  8.501602e+22  1.303111e+16
# s       1.835426e-01  8.288622e-02  4.064355e-01  7.444647e-02
# lambda  9.134998e-03  8.383953e-03  9.953322e-03  3.998660e-04
#                 est       L95%       U95%       var
# lifespan  48.382214  44.749584  57.514348  0.000298
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygcQ/MD-TA_ygcQ-1_df_relative_timegrid-vs-TA_ygcQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ygcQ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ygcQ/run-MD
