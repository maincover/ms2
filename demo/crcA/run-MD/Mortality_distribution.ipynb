# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA/TA_crcA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA/TA_crcA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA
# Iterations: relative error in phi-hat = 1e-04
# phi= 40.15516   sv2= 0.1130308   df= 17.52823   lambda= 355.2584
# phi= 41.58028   sv2= 0.005151728   df= 7.911579   lambda= 8071.134
# phi= 42.06731   sv2= 0.001003163   df= 4.105119   lambda= 41934.68
# save file prefixed name is : TA_crcA-1_df_relative_timegrid-vs-TA_crcA-1_timeseries_dataframe
# biName is :  TA_crcA-1_df_relative_timegrid-vs-TA_crcA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/crcA/run-MD
# No error in flxsrv_fit
# TA_crcA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/crcA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/crcA/run-MD
# TA_crcA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 40.15516   sv2= 0.1130308   df= 17.52823   lambda= 355.2584
# phi= 41.58028   sv2= 0.005151728   df= 7.911579   lambda= 8071.134
# phi= 42.06731   sv2= 0.001003163   df= 4.105119   lambda= 41934.68
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/crcA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_crcA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_crcA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA/MD-TA_crcA-1_df_relative_timegrid-vs-TA_crcA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_crcA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=24622.049659)
#                  est          L95%       U95%        se
# rate    5.212130e-02  4.742906e-02   0.057278  0.002509
# beta    5.748181e+01  4.849776e+01  68.130118  4.984318
# s       9.417798e-01  7.546102e-01   1.175374  0.106466
# lambda  8.290994e-07  8.595572e-15  79.972076  0.000008
#                 est      L95%       U95%       var
# lifespan  79.251995  77.57643  80.508809  0.000093
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/crcA/MD-TA_crcA-1_df_relative_timegrid-vs-TA_crcA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_crcA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/crcA/run-MD
