# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/mg-wt/dataset/MG strains tab'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  864  Filtered files length (after MD5 check) :  77
# check line duplication(open file) :  50 / 864
# check line duplication(open file) :  100 / 864
# check line duplication(open file) :  150 / 864
# check line duplication(open file) :  200 / 864
# check line duplication(open file) :  250 / 864
# check line duplication(open file) :  300 / 864
# check line duplication(open file) :  350 / 864
# check line duplication(open file) :  400 / 864
# check line duplication(open file) :  450 / 864
# check line duplication(open file) :  500 / 864
# check line duplication(open file) :  550 / 864
# check line duplication(open file) :  600 / 864
# check line duplication(open file) :  650 / 864
# check line duplication(open file) :  700 / 864
# check line duplication(open file) :  750 / 864
# check line duplication(open file) :  800 / 864
# check line duplication(open file) :  850 / 864
# check line duplication:  0 / 864
# check line duplication:  50 / 864
# check line duplication:  100 / 864
# check line duplication:  150 / 864
# check line duplication:  200 / 864
# check line duplication:  250 / 864
# check line duplication:  300 / 864
# check line duplication:  350 / 864
# check line duplication:  400 / 864
# check line duplication:  450 / 864
# check line duplication:  500 / 864
# check line duplication:  550 / 864
# check line duplication:  600 / 864
# check line duplication:  650 / 864
# check line duplication:  700 / 864
# check line duplication:  750 / 864
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/02062014 mRFP Position 51 mask.tif.mortality.tab
# check line duplication:  800 / 864
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/02062014 mRFP Position 53 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/02062014 mRFP Position 55 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/02062014 mRFP Position 56 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/02062014 mRFP Position 57 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/02062014 mRFP Position 58 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG aqpZ/MAX_Result of MAX_09032016 Position 19.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG aqpZ/MAX_Result of MAX_09032016 Position 2.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG aqpZ/MAX_Result of MAX_09032016 Position 3.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG aqpZ/MAX_Result of MAX_09032016 position 43-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ascG/02062014 mRFP Position 59 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ascG/02062014 mRFP Position 60 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ascG/02062014 mRFP Position 61 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ascG/02062014 mRFP Position 62 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ascG/02062014 mRFP Position 63 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ascG/02062014 mRFP Position 64 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG caiT/06052014 mRFP Position 11 stabilized.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG caiT/06052014 mRFP Position 12 stabilized.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG caiT/06052014 mRFP Position 13 stabilized.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG caiT/06052014 mRFP Position 14 stabilized.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG caiT/06052014 mRFP Position 15.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/06052014 mRFP Position 16.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/06052014 mRFP Position 17.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/06052014 mRFP Position 18.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/06052014 mRFP Position 19.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG ompL/06052014 mRFP Position 20.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 81 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 82 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 83 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 84 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 85 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 87 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 89 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 90 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 91 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG pgi/MAX_04082014 Position 92 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_24012015 Position 1-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_24012015 Position 14-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_24012015 Position 15-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_MAX_06082014 Position 45 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_MAX_06082014 Position 46 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_MAX_06082014 Position 51 mask.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_MAX_16052015 Position 44.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_MAX_16052015 Position 48.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_MAX_16052015 Position 49.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG uxaB/MAX_MAX_24012015 Position 15.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 11.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 12.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 13.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 14.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 15.tif.mortality.tab
# check line duplication:  850 / 864
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 16.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 17.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 18.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 19.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yagS/MAX_MAX_12052015 Position 20.tif.mortality.tab
# /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012014 Position 85.tif.mortality.tab	/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/moaE/MAX_MAX_10012014 Position 85.tif.mortality.tab	1.0
#
# /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012014 Position 85.tif.mortality.tab /home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/moaE/MAX_MAX_10012014 Position 85.tif.mortality.tab 1.0
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012014 Position 85.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 110.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 111.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 113.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 125.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 127.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 128.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 86.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MG strains tab/MG yfiD/MAX_MAX_10012015 Position 87.tif.mortality.tab
