# %% [markdown]
# # TAB Analyzer Process (only file filter listed .tab files (existed also in pth) )
# TabPostAnalyzer.py is should be in the grand parent folder
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from TabPostAnalyzer import TabPostAnalyzer
pth='/home/xsong/mg-wt/dataset/MG strains tab/MG WT'
fFn='/home/xsong/mg-wt/dataset/MG strains tab/report/finalFiles.txt'
partial=1
pA = TabPostAnalyzer(pth,filterFile=fFn, group=partial)
# Out:
# part,  1
# ['/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MG strains tab/MG WT/MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab']
# Total cell number :  3406
# filtered file/all file:  12 / 12

# %%
step0PlotOriginalFiles = True
step1TvReg = False
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
#             Step 0: Before we process any data, preview the PI profiles in
#             each tab files. No need for any parameters, could always run directly.
#             self.checkTimeJump() could be used to check time indeces of each files,
#             but is only triggered if self.debug is True.
#
#             Use self.viewCellTraces(fileName,start,end,pn=5) to check cell traces

# %%
step0PlotOriginalFiles = False
step1TvReg = True
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# autoDefineAlcohol is True, the alcohol index will be selected as: 142
# Alcohol time index is :  142
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (142, 141.62532239898991, 140.66752074074074, -0.35437885201743857)
# [ 1 ]  (143, 142.60751909090908, 141.62532239898991, -0.29029937501534536)
# [ 2 ]  (141, 140.66752074074074, 139.84782793209877, -0.097010884351336243)
# [ 3 ]  (140, 139.84782793209877, 138.68766819444443, 0.083081056360615926)
# [ 4 ]  (139, 138.68766819444443, 137.5378816388889, 0.070150956643582618)
# [ 5 ]  (55, 56.928004671717169, 55.984960631313129, -0.063148572922202009)
# [ 6 ]  (138, 137.5378816388889, 136.53813425000001, 0.062302176577258526)
# [ 7 ]  (58, 59.292502121212124, 58.447375198412701, 0.054420628523045675)
# [ 8 ]  (137, 136.53813425000001, 135.53794641666667, 0.051253465931690369)
# [ 9 ]  (57, 58.447375198412701, 57.817342604166669, 0.050830968191790865)
#
#             Step1: Use TVReg to calculate illumination levels, which are used
#             to estimate alcohol Time and then which cell to included in the end.
#             This step requires a set of data visualisation and report, so that
#             the user can verify the automatically chosen alcohol time is correct,
#             and the correct cells are included.
#
#             The first visualisations are the PI profiles for each file and
#             their illumination levels. The second visualisation is all illuminations
#             plotted into the same figure. The third visualisation is the combined
#             PI profile and illumination.
#
#             We also report the number of included or excluded cells in each file.
#
#             The user SHOULD make sure alcohol time is correct, or manually set
#             it according to suggestions.

# %%
pA.denoisePlotAll(asp=0.01,onlyPlot=True)
aIndex=120
pA.defineAlcoholTime(more=20,aIndex=aIndex)
# Out:
# Alcohol time index is :  120
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (142, 141.62532239898991, 140.66752074074074, -0.35437885201743857)
# [ 1 ]  (143, 142.60751909090908, 141.62532239898991, -0.29029937501534536)
# [ 2 ]  (141, 140.66752074074074, 139.84782793209877, -0.097010884351336243)
# [ 3 ]  (140, 139.84782793209877, 138.68766819444443, 0.083081056360615926)
# [ 4 ]  (139, 138.68766819444443, 137.5378816388889, 0.070150956643582618)
# [ 5 ]  (55, 56.928004671717169, 55.984960631313129, -0.063148572922202009)
# [ 6 ]  (138, 137.5378816388889, 136.53813425000001, 0.062302176577258526)
# [ 7 ]  (58, 59.292502121212124, 58.447375198412701, 0.054420628523045675)
# [ 8 ]  (137, 136.53813425000001, 135.53794641666667, 0.051253465931690369)
# [ 9 ]  (57, 58.447375198412701, 57.817342604166669, 0.050830968191790865)
# [ 10 ]  (144, 144.02228192129627, 142.60751909090908, -0.046419346463691426)
# [ 11 ]  (86, 86.455473585858584, 85.523788737373735, -0.043922669874197726)
# [ 12 ]  (3, 3.2820239583333404, 2.2817351157407444, -0.043273569463021251)
# [ 13 ]  (0, 0.2798181712962986, 148.9326642777778, 0.041342238487806014)
# [ 14 ]  (136, 135.53794641666667, 134.55794909090909, 0.040112788467576176)
# [ 15 ]  (2, 2.2817351157407444, 1.2797175925926041, -0.039341016288622632)
# [ 16 ]  (112, 111.73874293209877, 110.8549269212963, 0.037238014833305196)
# [ 17 ]  (84, 84.704371141975315, 83.821941435185181, 0.036696641044892744)
# [ 18 ]  (76, 77.487795856481483, 76.655126805555554, -0.03634623444699104)
# [ 19 ]  (146, 146.19435807291666, 145.02446125, 0.035467361257810394)

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab 447 447
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab 312 327
# MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab 421 439
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab 287 307
# MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab 470 493
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab 339 344
# MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab 70 73
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab 521 537
# MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab 262 273
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab 52 52
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab 52 53
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab 59 61
# 45
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab 447 447
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab 319 327
# MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab 429 439
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab 287 307
# MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab 481 493
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab 341 344
# MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab 71 73
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab 531 537
# MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab 263 273
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab 52 52
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab 52 53
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab 59 61
#
#             Step2: After the user have reviewed and set the alcohol time,
#             re-calculate cells to include. Then again use included data to
#             re-estimate illumination, estimate lifespan, and output data
#             in the form of pickles.

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
# Out:
# length of df is:  3332
# length of relative_time_grid is:  1738
