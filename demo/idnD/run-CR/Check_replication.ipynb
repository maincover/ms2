# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/TA_idnD-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/TA_idnD-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/TA_idnD-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD']
#
# out_name_s  ['TA_idnD-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/TA_idnD-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/TA_idnD-1_analysis_metadata.pickle
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 106-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 107-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 110-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 12-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 126-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 13-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 14-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 1-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 107-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 110-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 12-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 126-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 13-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 14-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 106-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 110-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 12-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 126-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 13-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 14-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 107-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 110-1.tif.mortality.tab ------ MAX_24012015 Position 12-1.tif.mortality.tab
# MAX_24012015 Position 110-1.tif.mortality.tab ------ MAX_24012015 Position 126-1.tif.mortality.tab
# MAX_24012015 Position 110-1.tif.mortality.tab ------ MAX_24012015 Position 13-1.tif.mortality.tab
# MAX_24012015 Position 110-1.tif.mortality.tab ------ MAX_24012015 Position 14-1.tif.mortality.tab
# MAX_24012015 Position 110-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 110-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 110-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 12-1.tif.mortality.tab ------ MAX_24012015 Position 126-1.tif.mortality.tab
# MAX_24012015 Position 12-1.tif.mortality.tab ------ MAX_24012015 Position 13-1.tif.mortality.tab
# MAX_24012015 Position 12-1.tif.mortality.tab ------ MAX_24012015 Position 14-1.tif.mortality.tab
# MAX_24012015 Position 12-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 12-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 12-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 126-1.tif.mortality.tab ------ MAX_24012015 Position 13-1.tif.mortality.tab
# MAX_24012015 Position 126-1.tif.mortality.tab ------ MAX_24012015 Position 14-1.tif.mortality.tab
# MAX_24012015 Position 126-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 126-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 126-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 13-1.tif.mortality.tab ------ MAX_24012015 Position 14-1.tif.mortality.tab
# MAX_24012015 Position 13-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 13-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 13-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 14-1.tif.mortality.tab ------ MAX_24012015 Position 15-1.tif.mortality.tab
# MAX_24012015 Position 14-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 14-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 15-1.tif.mortality.tab ------ MAX_24012015 Position 29-1.tif.mortality.tab
# MAX_24012015 Position 15-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# MAX_24012015 Position 29-1.tif.mortality.tab ------ MAX_24012015 Position 30-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_dentrogram-all-files.eps
# [['MAX_24012015 Position 1-1.tif.mortality.tab', 'MAX_24012015 Position 29-1.tif.mortality.tab', 'MAX_24012015 Position 30-1.tif.mortality.tab'], ['MAX_24012015 Position 12-1.tif.mortality.tab'], ['MAX_24012015 Position 14-1.tif.mortality.tab', 'MAX_24012015 Position 15-1.tif.mortality.tab'], ['MAX_24012015 Position 126-1.tif.mortality.tab', 'MAX_24012015 Position 13-1.tif.mortality.tab'], ['MAX_24012015 Position 106-1.tif.mortality.tab'], ['MAX_24012015 Position 110-1.tif.mortality.tab'], ['MAX_24012015 Position 107-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.99156   sv2= 0.09234299   df= 13.02606   lambda= 660.4894
# phi= 68.57434   sv2= 0.004557706   df= 5.162037   lambda= 15045.8
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.617665   sv2= 0.1214504   df= 11.88436   lambda= 29.78719
# phi= 3.692155   sv2= 0.04482412   df= 9.32164   lambda= 82.36981
# phi= 3.735488   sv2= 0.02083205   df= 7.403993   lambda= 179.3145
# phi= 3.762527   sv2= 0.01359465   df= 6.210758   lambda= 276.7653
# phi= 3.783677   sv2= 0.01102476   df= 5.634535   lambda= 343.1983
# phi= 3.797383   sv2= 0.009928244   df= 5.370243   lambda= 382.4828
# phi= 3.805234   sv2= 0.009408239   df= 5.242175   lambda= 404.4577
# phi= 3.809536   sv2= 0.009147983   df= 5.177456   lambda= 416.4346
# phi= 3.811852   sv2= 0.009014091   df= 5.143995   lambda= 422.877
# phi= 3.813089   sv2= 0.008944219   df= 5.126486   lambda= 426.3188
# phi= 3.813747   sv2= 0.008907483   df= 5.117268   lambda= 428.151
# phi= 3.814097   sv2= 0.008888093   df= 5.112399   lambda= 429.1244
# phi= 3.814283   sv2= 0.008877836   df= 5.109822   lambda= 429.641
# phi= 3.814381   sv2= 0.008872406   df= 5.108458   lambda= 429.9151
# phi= 3.814433   sv2= 0.008869528   df= 5.107735   lambda= 430.0605
# phi= 3.814461   sv2= 0.008868003   df= 5.107351   lambda= 430.1375
# phi= 3.814476   sv2= 0.008867195   df= 5.107148   lambda= 430.1784
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.81706   sv2= 0.09233985   df= 11.12252   lambda= 929.3611
# phi= 91.98717   sv2= 0.004017757   df= 4.218483   lambda= 22895.16
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_mortality_dataframe_cluster0.pickle
# 6 --c-- 4
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_mortality_dataframe_cluster1.pickle
# 6 --c-- 3
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_mortality_dataframe_cluster2.pickle
# 6 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/idnD/CR-TA_idnD-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 55.26038   sv2= 0.13794   df= 12.80919   lambda= 400.6118
# phi= 58.03249   sv2= 0.009108253   df= 5.689285   lambda= 6371.419
# phi= 63.36691   sv2= 0.001623834   df= 3.205915   lambda= 39023.03
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.99156   sv2= 0.09234299   df= 13.02606   lambda= 660.4894
# phi= 68.57434   sv2= 0.004557706   df= 5.162037   lambda= 15045.8
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.81706   sv2= 0.09233985   df= 11.12252   lambda= 929.3611
# phi= 91.98717   sv2= 0.004017757   df= 4.218483   lambda= 22895.16
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  82.841543  81.834084  83.840968  0.000292, 1:                 est       L95%       U95%       var
# lifespan  82.757732  80.951749  83.952465  0.000375, 2:                 est       L95%       U95%       var
# lifespan  85.847859  84.855013  89.848188  0.000503}
