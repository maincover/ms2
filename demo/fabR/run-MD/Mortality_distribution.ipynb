# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/TA_fabR-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/TA_fabR-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.5507   sv2= 0.3032204   df= 13.28487   lambda= 199.692
# phi= 69.18108   sv2= 0.03954874   df= 6.947594   lambda= 1749.261
# phi= 76.86023   sv2= 0.01446123   df= 4.555787   lambda= 5314.918
# phi= 79.73198   sv2= 0.0152576   df= 3.77304   lambda= 5225.722
# phi= 79.68052   sv2= 0.01524096   df= 3.783361   lambda= 5228.05
# phi= 79.68187   sv2= 0.0152414   df= 3.783089   lambda= 5227.987
# save file prefixed name is : TA_fabR-1_df_relative_timegrid-vs-TA_fabR-1_timeseries_dataframe
# biName is :  TA_fabR-1_df_relative_timegrid-vs-TA_fabR-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/fabR/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_fabR-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/fabR/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fabR/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_fabR-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.5507   sv2= 0.3032204   df= 13.28487   lambda= 199.692
# phi= 69.18108   sv2= 0.03954874   df= 6.947594   lambda= 1749.261
# phi= 76.86023   sv2= 0.01446123   df= 4.555787   lambda= 5314.918
# phi= 79.73198   sv2= 0.0152576   df= 3.77304   lambda= 5225.722
# phi= 79.68052   sv2= 0.01524096   df= 3.783361   lambda= 5228.05
# phi= 79.68187   sv2= 0.0152414   df= 3.783089   lambda= 5227.987
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fabR/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fabR-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_fabR-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/MD-TA_fabR-1_df_relative_timegrid-vs-TA_fabR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_fabR-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=11796.333478)
#                  est          L95%          U95%            se
# rate    4.518303e-01  2.475936e-01  8.245393e-01  1.386679e-01
# beta    3.840511e+21  7.103813e+08  2.076283e+34  5.744918e+22
# s       2.268213e-01  1.011881e-01  5.084380e-01  9.341284e-02
# lambda  8.498895e-03  7.874250e-03  9.173091e-03  3.310216e-04
#                 est       L95%        U95%       var
# lifespan  96.896382  91.934234  100.756274  0.000169
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/MD-TA_fabR-1_df_relative_timegrid-vs-TA_fabR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fabR-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/fabR/run-MD
