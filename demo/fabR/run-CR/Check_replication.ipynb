# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/TA_fabR-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/TA_fabR-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/TA_fabR-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR']
#
# out_name_s  ['TA_fabR-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/TA_fabR-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/TA_fabR-1_analysis_metadata.pickle
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 11-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 14-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 15-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 22-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 23-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 25-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 26-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 10-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 14-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 15-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 22-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 23-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 25-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 26-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 11-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 15-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 22-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 23-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 25-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 26-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 14-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 22-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 23-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 25-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 26-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 15-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 22-1.tif.mortality.tab ------ MAX_09032016 Position 23-1.tif.mortality.tab
# MAX_09032016 Position 22-1.tif.mortality.tab ------ MAX_09032016 Position 25-1.tif.mortality.tab
# MAX_09032016 Position 22-1.tif.mortality.tab ------ MAX_09032016 Position 26-1.tif.mortality.tab
# MAX_09032016 Position 22-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 22-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 22-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 22-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 23-1.tif.mortality.tab ------ MAX_09032016 Position 25-1.tif.mortality.tab
# MAX_09032016 Position 23-1.tif.mortality.tab ------ MAX_09032016 Position 26-1.tif.mortality.tab
# MAX_09032016 Position 23-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 23-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 23-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 23-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 25-1.tif.mortality.tab ------ MAX_09032016 Position 26-1.tif.mortality.tab
# MAX_09032016 Position 25-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 25-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 25-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 25-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 26-1.tif.mortality.tab ------ MAX_09032016 Position 27-1.tif.mortality.tab
# MAX_09032016 Position 26-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 26-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 26-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 27-1.tif.mortality.tab ------ MAX_09032016 Position 28-1.tif.mortality.tab
# MAX_09032016 Position 27-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 27-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 28-1.tif.mortality.tab ------ MAX_09032016 Position 4-1.tif.mortality.tab
# MAX_09032016 Position 28-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# MAX_09032016 Position 4-1.tif.mortality.tab ------ MAX_09032016 Position 5-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_dentrogram-all-files.eps
# [['MAX_09032016 Position 15-1.tif.mortality.tab', 'MAX_09032016 Position 27-1.tif.mortality.tab'], ['MAX_09032016 Position 10-1.tif.mortality.tab', 'MAX_09032016 Position 11-1.tif.mortality.tab', 'MAX_09032016 Position 14-1.tif.mortality.tab', 'MAX_09032016 Position 23-1.tif.mortality.tab', 'MAX_09032016 Position 25-1.tif.mortality.tab', 'MAX_09032016 Position 4-1.tif.mortality.tab'], ['MAX_09032016 Position 28-1.tif.mortality.tab', 'MAX_09032016 Position 5-1.tif.mortality.tab'], ['MAX_09032016 Position 22-1.tif.mortality.tab'], ['MAX_09032016 Position 26-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 35.20723   sv2= 0.2986941   df= 11.29381   lambda= 117.8705
# phi= 39.12063   sv2= 0.02913293   df= 6.637877   lambda= 1342.832
# phi= 41.99127   sv2= 0.01635225   df= 4.180528   lambda= 2567.92
# phi= 42.85474   sv2= 0.01679364   df= 3.758827   lambda= 2551.843
# phi= 42.84497   sv2= 0.01679138   df= 3.762579   lambda= 2551.604
# phi= 42.84482   sv2= 0.01679135   df= 3.762635   lambda= 2551.601
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.33729   sv2= 0.2124885   df= 8.694609   lambda= 241.6004
# phi= 71.11576   sv2= 0.02939029   df= 4.873312   lambda= 2419.703
# phi= 87.17295   sv2= 0.01797639   df= 3.357306   lambda= 4849.301
# phi= 93.8965   sv2= 0.0164295   df= 3.051865   lambda= 5715.118
# phi= 96.11762   sv2= 0.01585155   df= 2.985672   lambda= 6063.609
# phi= 96.99795   sv2= 0.01562401   df= 2.962228   lambda= 6208.263
# phi= 97.36129   sv2= 0.01553066   df= 2.952945   lambda= 6268.975
# phi= 97.51343   sv2= 0.01549168   df= 2.949121   lambda= 6294.568
# phi= 97.5775   sv2= 0.01547529   df= 2.947522   lambda= 6305.376
# phi= 97.60455   sv2= 0.01546837   df= 2.946849   lambda= 6309.944
# phi= 97.61598   sv2= 0.01546545   df= 2.946565   lambda= 6311.875
# phi= 97.62081   sv2= 0.01546421   df= 2.946445   lambda= 6312.692
# phi= 97.62285   sv2= 0.01546369   df= 2.946394   lambda= 6313.037
# Iterations: relative error in phi-hat = 1e-04
# phi= 17.24483   sv2= 0.263662   df= 8.230557   lambda= 65.40506
# phi= 21.36005   sv2= 0.06161872   df= 5.708901   lambda= 346.6487
# phi= 24.86465   sv2= 0.01853984   df= 4.212788   lambda= 1341.147
# phi= 27.09905   sv2= 0.01242491   df= 3.379403   lambda= 2181.027
# phi= 27.91743   sv2= 0.01145457   df= 3.144663   lambda= 2437.231
# phi= 28.12593   sv2= 0.0112094   df= 3.094603   lambda= 2509.138
# phi= 28.18235   sv2= 0.01114274   df= 3.081686   lambda= 2529.213
# phi= 28.19796   sv2= 0.01112428   df= 3.078159   lambda= 2534.813
# phi= 28.2023   sv2= 0.01111914   df= 3.077181   lambda= 2536.375
# phi= 28.20351   sv2= 0.01111771   df= 3.076909   lambda= 2536.811
# phi= 28.20385   sv2= 0.01111731   df= 3.076833   lambda= 2536.932
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fabR/CR-TA_fabR-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 46.06344   sv2= 0.2885977   df= 12.06586   lambda= 159.6112
# phi= 53.29287   sv2= 0.03886057   df= 6.675601   lambda= 1371.387
# phi= 58.7537   sv2= 0.01635556   df= 4.434067   lambda= 3592.276
# phi= 60.24826   sv2= 0.01672436   df= 3.777047   lambda= 3602.425
# phi= 60.25353   sv2= 0.01672563   df= 3.775354   lambda= 3602.468
# Iterations: relative error in phi-hat = 1e-04
# phi= 17.24483   sv2= 0.263662   df= 8.230557   lambda= 65.40506
# phi= 21.36005   sv2= 0.06161872   df= 5.708901   lambda= 346.6487
# phi= 24.86465   sv2= 0.01853984   df= 4.212788   lambda= 1341.147
# phi= 27.09905   sv2= 0.01242491   df= 3.379403   lambda= 2181.027
# phi= 27.91743   sv2= 0.01145457   df= 3.144663   lambda= 2437.231
# phi= 28.12593   sv2= 0.0112094   df= 3.094603   lambda= 2509.138
# phi= 28.18235   sv2= 0.01114274   df= 3.081686   lambda= 2529.213
# phi= 28.19796   sv2= 0.01112428   df= 3.078159   lambda= 2534.813
# phi= 28.2023   sv2= 0.01111914   df= 3.077181   lambda= 2536.375
# phi= 28.20351   sv2= 0.01111771   df= 3.076909   lambda= 2536.811
# phi= 28.20385   sv2= 0.01111731   df= 3.076833   lambda= 2536.932
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  108.795396  106.748686  109.826199  0.000231, 1:                est      L95%       U95%       var
# lifespan  9.006556  7.006367  11.007168  0.001292}
