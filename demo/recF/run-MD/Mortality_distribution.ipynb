# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/TA_recF-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/TA_recF-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.96596   sv2= 0.1444552   df= 17.42914   lambda= 276.6668
# phi= 40.44982   sv2= 0.004764688   df= 8.313077   lambda= 8489.501
# phi= 41.00023   sv2= 0.001437119   df= 4.022788   lambda= 28529.46
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_recF-1_df_relative_timegrid-vs-TA_recF-1_timeseries_dataframe
# biName is :  TA_recF-1_df_relative_timegrid-vs-TA_recF-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/recF/run-MD
# No error in flxsrv_fit
# TA_recF-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/recF/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/recF/run-MD
# TA_recF-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.96596   sv2= 0.1444552   df= 17.42914   lambda= 276.6668
# phi= 40.44982   sv2= 0.004764688   df= 8.313077   lambda= 8489.501
# phi= 41.00023   sv2= 0.001437119   df= 4.022788   lambda= 28529.46
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/recF/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_recF-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_recF-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/MD-TA_recF-1_df_relative_timegrid-vs-TA_recF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_recF-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=25798.086182)
#                est          L95%        U95%         se
# rate      0.048320  4.430058e-02    0.052705   0.002141
# beta    116.860665  9.796543e+01  139.400345  10.515724
# s         1.156079  9.143148e-01    1.461771   0.138387
# lambda    0.000008  1.263987e-07    0.000533   0.000017
#                 est       L95%       U95%       var
# lifespan  92.643841  91.217888  93.867128  0.000092
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/MD-TA_recF-1_df_relative_timegrid-vs-TA_recF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_recF-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/recF/run-MD
