# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/TA_recF-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/TA_recF-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/TA_recF-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF']
#
# out_name_s  ['TA_recF-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/TA_recF-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/TA_recF-1_analysis_metadata.pickle
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 2-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 22-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 24-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 25-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 26-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 39-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 63-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 1-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 22-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 24-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 25-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 26-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 39-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 63-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 2-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 22-1.tif.mortality.tab ------ MAX_05072014 Position 24-1.tif.mortality.tab
# MAX_05072014 Position 22-1.tif.mortality.tab ------ MAX_05072014 Position 25-1.tif.mortality.tab
# MAX_05072014 Position 22-1.tif.mortality.tab ------ MAX_05072014 Position 26-1.tif.mortality.tab
# MAX_05072014 Position 22-1.tif.mortality.tab ------ MAX_05072014 Position 39-1.tif.mortality.tab
# MAX_05072014 Position 22-1.tif.mortality.tab ------ MAX_05072014 Position 63-1.tif.mortality.tab
# MAX_05072014 Position 22-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 22-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 24-1.tif.mortality.tab ------ MAX_05072014 Position 25-1.tif.mortality.tab
# MAX_05072014 Position 24-1.tif.mortality.tab ------ MAX_05072014 Position 26-1.tif.mortality.tab
# MAX_05072014 Position 24-1.tif.mortality.tab ------ MAX_05072014 Position 39-1.tif.mortality.tab
# MAX_05072014 Position 24-1.tif.mortality.tab ------ MAX_05072014 Position 63-1.tif.mortality.tab
# MAX_05072014 Position 24-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 24-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 25-1.tif.mortality.tab ------ MAX_05072014 Position 26-1.tif.mortality.tab
# MAX_05072014 Position 25-1.tif.mortality.tab ------ MAX_05072014 Position 39-1.tif.mortality.tab
# MAX_05072014 Position 25-1.tif.mortality.tab ------ MAX_05072014 Position 63-1.tif.mortality.tab
# MAX_05072014 Position 25-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 25-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 26-1.tif.mortality.tab ------ MAX_05072014 Position 39-1.tif.mortality.tab
# MAX_05072014 Position 26-1.tif.mortality.tab ------ MAX_05072014 Position 63-1.tif.mortality.tab
# MAX_05072014 Position 26-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 26-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 39-1.tif.mortality.tab ------ MAX_05072014 Position 63-1.tif.mortality.tab
# MAX_05072014 Position 39-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 39-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 63-1.tif.mortality.tab ------ MAX_05072014 Position 67-1.tif.mortality.tab
# MAX_05072014 Position 63-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# MAX_05072014 Position 67-1.tif.mortality.tab ------ MAX_05072014 Position 78-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_dentrogram-all-files.eps
# [['MAX_05072014 Position 24-1.tif.mortality.tab', 'MAX_05072014 Position 25-1.tif.mortality.tab', 'MAX_05072014 Position 67-1.tif.mortality.tab'], ['MAX_05072014 Position 22-1.tif.mortality.tab', 'MAX_05072014 Position 26-1.tif.mortality.tab'], ['MAX_05072014 Position 63-1.tif.mortality.tab', 'MAX_05072014 Position 78-1.tif.mortality.tab'], ['MAX_05072014 Position 1-1.tif.mortality.tab'], ['MAX_05072014 Position 39-1.tif.mortality.tab'], ['MAX_05072014 Position 2-1.tif.mortality.tab']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 113.6942   sv2= 0.07538476   df= 11.69981   lambda= 1508.186
# phi= 118.6824   sv2= 0.005702869   df= 3.948615   lambda= 20810.99
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.7652   sv2= 0.0660485   df= 11.47798   lambda= 511.2183
# phi= 34.494   sv2= 0.001743859   df= 4.959294   lambda= 19780.27
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.485587   sv2= 0.1022719   df= 11.07798   lambda= 82.97089
# phi= 9.231799   sv2= 0.01842625   df= 6.90357   lambda= 501.0135
# phi= 9.514157   sv2= 0.01090819   df= 4.737228   lambda= 872.2029
# phi= 9.698188   sv2= 0.009131288   df= 4.243173   lambda= 1062.083
# phi= 9.785837   sv2= 0.008486131   df= 4.083207   lambda= 1153.156
# phi= 9.826251   sv2= 0.008216706   df= 4.018697   lambda= 1195.887
# phi= 9.844855   sv2= 0.008097786   df= 3.990594   lambda= 1215.746
# phi= 9.853425   sv2= 0.008044025   df= 3.977958   lambda= 1224.937
# phi= 9.857374   sv2= 0.008019458   df= 3.972198   lambda= 1229.182
# phi= 9.859195   sv2= 0.008008177   df= 3.969556   lambda= 1231.141
# phi= 9.860034   sv2= 0.008002985   df= 3.968341   lambda= 1232.045
# phi= 9.860421   sv2= 0.008000593   df= 3.967781   lambda= 1232.461
# phi= 9.8606   sv2= 0.007999491   df= 3.967523   lambda= 1232.653
# phi= 9.860682   sv2= 0.007998982   df= 3.967404   lambda= 1232.742
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/recF/CR-TA_recF-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 80.23758   sv2= 0.07621786   df= 13.32167   lambda= 1052.74
# phi= 83.51005   sv2= 0.004264989   df= 4.808983   lambda= 19580.37
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.497972   sv2= 0.2969384   df= 12.69978   lambda= 28.61863
# phi= 9.119011   sv2= 0.1182052   df= 9.938429   lambda= 77.14559
# phi= 9.628681   sv2= 0.04843197   df= 7.880128   lambda= 198.8084
# phi= 10.01896   sv2= 0.02111001   df= 6.367985   lambda= 474.607
# phi= 10.27395   sv2= 0.01133408   df= 5.261262   lambda= 906.465
# phi= 10.41989   sv2= 0.008027703   df= 4.582127   lambda= 1297.991
# phi= 10.49797   sv2= 0.006741234   df= 4.252965   lambda= 1557.278
# phi= 10.53828   sv2= 0.006161933   df= 4.098179   lambda= 1710.223
# phi= 10.55918   sv2= 0.005878452   df= 4.021633   lambda= 1796.252
# phi= 10.57016   sv2= 0.005733555   df= 3.982349   lambda= 1843.561
# phi= 10.57598   sv2= 0.005657781   df= 3.961765   lambda= 1869.28
# phi= 10.57908   sv2= 0.005617672   df= 3.950859   lambda= 1883.178
# phi= 10.58073   sv2= 0.005596305   df= 3.945046   lambda= 1890.664
# phi= 10.58162   sv2= 0.005584883   df= 3.941938   lambda= 1894.69
# phi= 10.5821   sv2= 0.005578766   df= 3.940273   lambda= 1896.852
# phi= 10.58235   sv2= 0.005575487   df= 3.93938   lambda= 1898.014
# phi= 10.58249   sv2= 0.005573728   df= 3.938901   lambda= 1898.637
# phi= 10.58256   sv2= 0.005572785   df= 3.938644   lambda= 1898.972
# phi= 10.5826   sv2= 0.005572278   df= 3.938506   lambda= 1899.152
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  103.858411  100.839372  106.857897  0.000265, 1:                 est       L95%       U95%       var
# lifespan  88.221626  88.221626  91.217888  0.000317}
