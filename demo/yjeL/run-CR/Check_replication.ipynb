# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/TA_yjeL-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/TA_yjeL-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/TA_yjeL-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL']
#
# out_name_s  ['TA_yjeL-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/TA_yjeL-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/TA_yjeL-1_analysis_metadata.pickle
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 104-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 110-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 113-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 114-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 115-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 117-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 146-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 101-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 110-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 113-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 114-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 115-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 117-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 146-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 104-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 113-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 114-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 115-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 117-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 146-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 110-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 114-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 115-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 117-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 146-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 113-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 115-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 117-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 146-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 114-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 117-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 146-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 115-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 117-1.tif.mortality.tab ------ MAX_28062016 Position 146-1.tif.mortality.tab
# MAX_28062016 Position 117-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 117-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 117-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 117-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 117-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 117-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 146-1.tif.mortality.tab ------ MAX_28062016 Position 155-1.tif.mortality.tab
# MAX_28062016 Position 146-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 146-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 146-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 146-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 146-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 155-1.tif.mortality.tab ------ MAX_28062016 Position 53-1.tif.mortality.tab
# MAX_28062016 Position 155-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 155-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 155-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 155-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 53-1.tif.mortality.tab ------ MAX_28062016 Position 59-1.tif.mortality.tab
# MAX_28062016 Position 53-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 53-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 53-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 59-1.tif.mortality.tab ------ MAX_28062016 Position 60-1.tif.mortality.tab
# MAX_28062016 Position 59-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 59-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 60-1.tif.mortality.tab ------ MAX_28062016 Position 96-1.tif.mortality.tab
# MAX_28062016 Position 60-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# MAX_28062016 Position 96-1.tif.mortality.tab ------ MAX_28062016 Position 97-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_dentrogram-all-files.eps
# [['MAX_28062016 Position 146-1.tif.mortality.tab', 'MAX_28062016 Position 155-1.tif.mortality.tab'], ['MAX_28062016 Position 101-1.tif.mortality.tab', 'MAX_28062016 Position 104-1.tif.mortality.tab', 'MAX_28062016 Position 117-1.tif.mortality.tab'], ['MAX_28062016 Position 114-1.tif.mortality.tab', 'MAX_28062016 Position 115-1.tif.mortality.tab', 'MAX_28062016 Position 96-1.tif.mortality.tab'], ['MAX_28062016 Position 110-1.tif.mortality.tab', 'MAX_28062016 Position 113-1.tif.mortality.tab', 'MAX_28062016 Position 97-1.tif.mortality.tab'], ['MAX_28062016 Position 53-1.tif.mortality.tab', 'MAX_28062016 Position 59-1.tif.mortality.tab', 'MAX_28062016 Position 60-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 159.7624   sv2= 0.1202004   df= 11.10375   lambda= 1329.134
# phi= 199.9692   sv2= 0.02073244   df= 4.169871   lambda= 9645.233
# phi= 276.9787   sv2= 0.005494498   df= 2.904514   lambda= 50410.18
# Iterations: relative error in phi-hat = 1e-04
# phi= 38.09304   sv2= 0.1086917   df= 9.793237   lambda= 350.4687
# phi= 49.06267   sv2= 0.02916815   df= 4.819111   lambda= 1682.063
# phi= 80.99663   sv2= 0.01443049   df= 3.65084   lambda= 5612.881
# phi= 194.8647   sv2= 0.005470708   df= 2.878655   lambda= 35619.64
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.55113   sv2= 0.09938917   df= 9.869237   lambda= 428.1265
# phi= 45.76528   sv2= 0.01225231   df= 4.601818   lambda= 3735.235
# phi= 49.27614   sv2= 0.007343157   df= 3.161226   lambda= 6710.484
# phi= 52.14747   sv2= 0.00627743   df= 2.86132   lambda= 8307.136
# phi= 53.67111   sv2= 0.005847281   df= 2.757798   lambda= 9178.814
# phi= 54.48726   sv2= 0.005638948   df= 2.710727   lambda= 9662.664
# phi= 54.93423   sv2= 0.005530132   df= 2.686878   lambda= 9933.62
# phi= 55.18247   sv2= 0.005471156   df= 2.674156   lambda= 10086.07
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/CR-TA_yjeL-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 117.9604   sv2= 0.1525212   df= 13.03653   lambda= 773.4035
# phi= 122.1794   sv2= 0.02127236   df= 5.230617   lambda= 5743.577
# phi= 135.5524   sv2= 0.009752166   df= 3.630394   lambda= 13899.73
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.55113   sv2= 0.09938917   df= 9.869237   lambda= 428.1265
# phi= 45.76528   sv2= 0.01225231   df= 4.601818   lambda= 3735.235
# phi= 49.27614   sv2= 0.007343157   df= 3.161226   lambda= 6710.484
# phi= 52.14747   sv2= 0.00627743   df= 2.86132   lambda= 8307.136
# phi= 53.67111   sv2= 0.005847281   df= 2.757798   lambda= 9178.814
# phi= 54.48726   sv2= 0.005638948   df= 2.710727   lambda= 9662.664
# phi= 54.93423   sv2= 0.005530132   df= 2.686878   lambda= 9933.62
# phi= 55.18247   sv2= 0.005471156   df= 2.674156   lambda= 10086.07
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  120.050207  117.680122  121.094437  0.000192, 1:                  est        L95%       U95%      var
# lifespan  106.963303  103.513719  112.97494  0.00095}
