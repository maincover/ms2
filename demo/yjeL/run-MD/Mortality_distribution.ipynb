# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/TA_yjeL-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/TA_yjeL-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL
# Iterations: relative error in phi-hat = 1e-04
# phi= 71.1202   sv2= 0.1594555   df= 13.85897   lambda= 446.0192
# phi= 71.5474   sv2= 0.02318641   df= 6.178013   lambda= 3085.747
# phi= 75.34704   sv2= 0.01340464   df= 4.26744   lambda= 5620.968
# phi= 77.70583   sv2= 0.01046292   df= 3.840141   lambda= 7426.78
# phi= 79.01503   sv2= 0.009140768   df= 3.658412   lambda= 8644.243
# phi= 79.78324   sv2= 0.008456197   df= 3.562815   lambda= 9434.885
# phi= 80.24377   sv2= 0.008076165   df= 3.508641   lambda= 9935.875
# phi= 80.52218   sv2= 0.007857026   df= 3.476912   lambda= 10248.43
# save file prefixed name is : TA_yjeL-1_df_relative_timegrid-vs-TA_yjeL-1_timeseries_dataframe
# biName is :  TA_yjeL-1_df_relative_timegrid-vs-TA_yjeL-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yjeL/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yjeL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yjeL/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjeL/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yjeL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 71.1202   sv2= 0.1594555   df= 13.85897   lambda= 446.0192
# phi= 71.5474   sv2= 0.02318641   df= 6.178013   lambda= 3085.747
# phi= 75.34704   sv2= 0.01340464   df= 4.26744   lambda= 5620.968
# phi= 77.70583   sv2= 0.01046292   df= 3.840141   lambda= 7426.78
# phi= 79.01503   sv2= 0.009140768   df= 3.658412   lambda= 8644.243
# phi= 79.78324   sv2= 0.008456197   df= 3.562815   lambda= 9434.885
# phi= 80.24377   sv2= 0.008076165   df= 3.508641   lambda= 9935.875
# phi= 80.52218   sv2= 0.007857026   df= 3.476912   lambda= 10248.43
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjeL/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjeL-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yjeL-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/MD-TA_yjeL-1_df_relative_timegrid-vs-TA_yjeL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yjeL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=13575.647565)
#                  est          L95%          U95%            se
# rate    1.341982e-01  1.210430e-01  1.487830e-01  7.064127e-03
# beta    6.536162e+06  1.649938e+06  2.589274e+07  4.590780e+06
# s       6.576657e-01  5.288343e-01  8.178822e-01  7.315711e-02
# lambda  1.067771e-03  8.997821e-04  1.267123e-03  9.325506e-05
#                  est        L95%        U95%      var
# lifespan  119.914003  117.680122  121.094437  0.00015
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjeL/MD-TA_yjeL-1_df_relative_timegrid-vs-TA_yjeL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjeL-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yjeL/run-MD
