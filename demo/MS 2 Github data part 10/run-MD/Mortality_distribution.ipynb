# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/Desktop/gitProjects/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10'
ref_df_path = '/home/xsong/Desktop/gitProjects/ms2/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/TA_ybaJ-1_df_relative_timegrid.pickle'], ['/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/TA_ydjK-1_df_relative_timegrid.pickle'], ['/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/TA_yiaW-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/TA_ybaJ-1_timeseries_dataframe.pickle'], ['/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/TA_ydjK-1_timeseries_dataframe.pickle'], ['/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/TA_yiaW-1_timeseries_dataframe.pickle']]
# /home/xsong/Desktop/gitProjects/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/Desktop/gitProjects/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.32831027777777
# files will be written into :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ
# Iterations: relative error in phi-hat = 1e-04
# phi= 73.04774   sv2= 0.1491318   df= 14.41475   lambda= 489.82
# phi= 75.51433   sv2= 0.02508496   df= 6.270682   lambda= 3010.343
# phi= 76.08054   sv2= 0.01084031   df= 4.324383   lambda= 7018.296
# phi= 76.29244   sv2= 0.00629403   df= 3.647206   lambda= 12121.4
# save file prefixed name is : TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe
# biName is :  TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ybaJ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# getKMNABSfits_dict-- /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ybaJ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 73.04774   sv2= 0.1491318   df= 14.41475   lambda= 489.82
# phi= 75.51433   sv2= 0.02508496   df= 6.270682   lambda= 3010.343
# phi= 76.08054   sv2= 0.01084031   df= 4.324383   lambda= 7018.296
# phi= 76.29244   sv2= 0.00629403   df= 3.647206   lambda= 12121.4
# getKMNABSfits_dict-- /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybaJ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ybaJ-1_df_relative_timegrid.pickle
# /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MD-TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ybaJ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=23340.315641)
#                  est          L95%          U95%            se
# rate    1.839834e-01  1.694132e-01  1.998066e-01  7.744759e-03
# beta    1.133069e+07  3.683054e+06  3.485819e+07  6.496612e+06
# s       4.336602e-01  3.605527e-01  5.215912e-01  4.084954e-02
# lambda  3.919579e-04  3.194846e-04  4.808714e-04  4.088545e-05
#                 est       L95%       U95%       var
# lifespan  94.686548  94.531875  95.699957  0.000064
#
#
# /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MD-TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybaJ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# files will be written into :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK
# Iterations: relative error in phi-hat = 1e-04
# phi= 123.0445   sv2= 0.3177221   df= 14.68216   lambda= 387.2707
# phi= 124.8568   sv2= 0.02901507   df= 6.853446   lambda= 4303.17
# phi= 125.019   sv2= 0.01331838   df= 4.037175   lambda= 9386.957
# phi= 126.6334   sv2= 0.009224324   df= 3.38933   lambda= 13728.21
# save file prefixed name is : TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe
# biName is :  TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ydjK-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# getKMNABSfits_dict-- /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ydjK-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 123.0445   sv2= 0.3177221   df= 14.68216   lambda= 387.2707
# phi= 124.8568   sv2= 0.02901507   df= 6.853446   lambda= 4303.17
# phi= 125.019   sv2= 0.01331838   df= 4.037175   lambda= 9386.957
# phi= 126.6334   sv2= 0.009224324   df= 3.38933   lambda= 13728.21
# getKMNABSfits_dict-- /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydjK-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ydjK-1_df_relative_timegrid.pickle
# /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MD-TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ydjK-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=41644.594521)
#                  est          L95%          U95%            se
# rate    1.834581e-01  1.734403e-01  1.940546e-01  5.256090e-03
# beta    1.201476e+07  5.584075e+06  2.585110e+07  4.696982e+06
# s       4.391516e-01  3.874143e-01  4.977983e-01  2.808609e-02
# lambda  1.038221e-04  7.536440e-05  1.430255e-04  1.696907e-05
#                 est       L95%       U95%       var
# lifespan  96.789231  95.701516  96.842693  0.000035
#
#
# /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MD-TA_ydjK-1_df_relative_timegrid-vs-TA_ydjK-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydjK-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# files will be written into :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW
# Iterations: relative error in phi-hat = 1e-04
# phi= 102.6691   sv2= 0.2095491   df= 13.70069   lambda= 489.9525
# phi= 106.1307   sv2= 0.03243738   df= 6.024923   lambda= 3271.865
# phi= 108.9413   sv2= 0.01554432   df= 4.053959   lambda= 7008.429
# phi= 111.0164   sv2= 0.009515756   df= 3.434051   lambda= 11666.58
# save file prefixed name is : TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe
# biName is :  TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# No error in flxsrv_fit
# TA_yiaW-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# getKMNABSfits_dict-- /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# TA_yiaW-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 102.6691   sv2= 0.2095491   df= 13.70069   lambda= 489.9525
# phi= 106.1307   sv2= 0.03243738   df= 6.024923   lambda= 3271.865
# phi= 108.9413   sv2= 0.01554432   df= 4.053959   lambda= 7008.429
# phi= 111.0164   sv2= 0.009515756   df= 3.434051   lambda= 11666.58
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yiaW-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yiaW-1_df_relative_timegrid.pickle
# /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MD-TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yiaW-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=26352.015644)
#                  est          L95%          U95%            se
# rate    2.146012e-01  1.992402e-01  2.311465e-01  8.132031e-03
# beta    2.072260e+08  6.055599e+07  7.091389e+08  1.300728e+08
# s       3.704109e-01  3.158956e-01  4.343343e-01  3.008725e-02
# lambda  2.107987e-04  1.655382e-04  2.684339e-04  2.599552e-05
#                 est       L95%       U95%       var
# lifespan  96.839738  96.814279  96.871593  0.000054
#
#
# /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MD-TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yiaW-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/Desktop/gitProjects/ms2/demo/MS 2 Github data part 10/run-MD
