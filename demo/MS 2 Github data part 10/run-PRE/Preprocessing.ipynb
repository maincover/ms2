# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/Desktop/gitProjects/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10'
prev_path = '/home/xsong/Desktop/gitProjects/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  848  Filtered files length (after MD5 check) :  61
# check line duplication(open file) :  50 / 848
# check line duplication(open file) :  100 / 848
# check line duplication(open file) :  150 / 848
# check line duplication(open file) :  200 / 848
# check line duplication(open file) :  250 / 848
# check line duplication(open file) :  300 / 848
# check line duplication(open file) :  350 / 848
# check line duplication(open file) :  400 / 848
# check line duplication(open file) :  450 / 848
# check line duplication(open file) :  500 / 848
# check line duplication(open file) :  550 / 848
# check line duplication(open file) :  600 / 848
# check line duplication(open file) :  650 / 848
# check line duplication(open file) :  700 / 848
# check line duplication(open file) :  750 / 848
# check line duplication(open file) :  800 / 848
# check line duplication:  0 / 848
# check line duplication:  50 / 848
# check line duplication:  100 / 848
# check line duplication:  150 / 848
# check line duplication:  200 / 848
# check line duplication:  250 / 848
# check line duplication:  300 / 848
# check line duplication:  350 / 848
# check line duplication:  400 / 848
# check line duplication:  450 / 848
# check line duplication:  500 / 848
# check line duplication:  550 / 848
# check line duplication:  600 / 848
# check line duplication:  650 / 848
# check line duplication:  700 / 848
# check line duplication:  750 / 848
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 164-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 165-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 166-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 170-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 171-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 172-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 173-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 176-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 177-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 178-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 179-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 180-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 181-1.tif.mortality.tab
# check line duplication:  800 / 848
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 182-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 183-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 184-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 185-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 186-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 187-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 188-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 214-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ybaJ/MAX_18112018 Position 215-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 189-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 190-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 191-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 192-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 193-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 194-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 195-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 198-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 199-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 200-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 201-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 202-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 203-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 204-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 207-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 208-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 209-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 210-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 211-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 212-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/ydjK/MAX_18112018 Position 213-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 216-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 217-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 218-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 219-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 220-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 221-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 222-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 223-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 224-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 225-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 226-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 228-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 229-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 230-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 231-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 233-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 234-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/Desktop/gitProjects/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 235-1.tif.mortality.tab
