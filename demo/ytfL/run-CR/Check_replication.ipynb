# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/TA_ytfL-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/TA_ytfL-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/TA_ytfL-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL']
#
# out_name_s  ['TA_ytfL-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/TA_ytfL-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/TA_ytfL-1_analysis_metadata.pickle
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 149-1.tif.mortality.tab
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 150-1.tif.mortality.tab
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 151-1.tif.mortality.tab
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 152-1.tif.mortality.tab
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 28-1.tif.mortality.tab
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 33-1.tif.mortality.tab
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 34-1.tif.mortality.tab
# MAX_01112018 Position 137-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# MAX_01112018 Position 149-1.tif.mortality.tab ------ MAX_01112018 Position 150-1.tif.mortality.tab
# MAX_01112018 Position 149-1.tif.mortality.tab ------ MAX_01112018 Position 151-1.tif.mortality.tab
# MAX_01112018 Position 149-1.tif.mortality.tab ------ MAX_01112018 Position 152-1.tif.mortality.tab
# MAX_01112018 Position 149-1.tif.mortality.tab ------ MAX_01112018 Position 28-1.tif.mortality.tab
# MAX_01112018 Position 149-1.tif.mortality.tab ------ MAX_01112018 Position 33-1.tif.mortality.tab
# MAX_01112018 Position 149-1.tif.mortality.tab ------ MAX_01112018 Position 34-1.tif.mortality.tab
# MAX_01112018 Position 149-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# MAX_01112018 Position 150-1.tif.mortality.tab ------ MAX_01112018 Position 151-1.tif.mortality.tab
# MAX_01112018 Position 150-1.tif.mortality.tab ------ MAX_01112018 Position 152-1.tif.mortality.tab
# MAX_01112018 Position 150-1.tif.mortality.tab ------ MAX_01112018 Position 28-1.tif.mortality.tab
# MAX_01112018 Position 150-1.tif.mortality.tab ------ MAX_01112018 Position 33-1.tif.mortality.tab
# MAX_01112018 Position 150-1.tif.mortality.tab ------ MAX_01112018 Position 34-1.tif.mortality.tab
# MAX_01112018 Position 150-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# MAX_01112018 Position 151-1.tif.mortality.tab ------ MAX_01112018 Position 152-1.tif.mortality.tab
# MAX_01112018 Position 151-1.tif.mortality.tab ------ MAX_01112018 Position 28-1.tif.mortality.tab
# MAX_01112018 Position 151-1.tif.mortality.tab ------ MAX_01112018 Position 33-1.tif.mortality.tab
# MAX_01112018 Position 151-1.tif.mortality.tab ------ MAX_01112018 Position 34-1.tif.mortality.tab
# MAX_01112018 Position 151-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# MAX_01112018 Position 152-1.tif.mortality.tab ------ MAX_01112018 Position 28-1.tif.mortality.tab
# MAX_01112018 Position 152-1.tif.mortality.tab ------ MAX_01112018 Position 33-1.tif.mortality.tab
# MAX_01112018 Position 152-1.tif.mortality.tab ------ MAX_01112018 Position 34-1.tif.mortality.tab
# MAX_01112018 Position 152-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# MAX_01112018 Position 28-1.tif.mortality.tab ------ MAX_01112018 Position 33-1.tif.mortality.tab
# MAX_01112018 Position 28-1.tif.mortality.tab ------ MAX_01112018 Position 34-1.tif.mortality.tab
# MAX_01112018 Position 28-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# MAX_01112018 Position 33-1.tif.mortality.tab ------ MAX_01112018 Position 34-1.tif.mortality.tab
# MAX_01112018 Position 33-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# MAX_01112018 Position 34-1.tif.mortality.tab ------ MAX_01112018 Position 40-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_dentrogram-all-files.eps
# 3 [2 1 1]
# [['MAX_01112018 Position 137-1.tif.mortality.tab', 'MAX_01112018 Position 149-1.tif.mortality.tab', 'MAX_01112018 Position 152-1.tif.mortality.tab', 'MAX_01112018 Position 28-1.tif.mortality.tab', 'MAX_01112018 Position 34-1.tif.mortality.tab'], ['MAX_01112018 Position 150-1.tif.mortality.tab', 'MAX_01112018 Position 151-1.tif.mortality.tab', 'MAX_01112018 Position 33-1.tif.mortality.tab', 'MAX_01112018 Position 40-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 32.77125   sv2= 0.07589114   df= 11.37594   lambda= 431.8192
# phi= 34.30588   sv2= 0.004524033   df= 5.032086   lambda= 7583.03
# phi= 36.58259   sv2= 0.001507611   df= 2.950975   lambda= 24265.28
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.97784   sv2= 0.1073352   df= 10.31119   lambda= 400.4078
# phi= 44.80356   sv2= 0.003751603   df= 4.758695   lambda= 11942.51
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfL/CR-TA_ytfL-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.36969   sv2= 0.08307243   df= 12.33465   lambda= 473.92
# phi= 40.75228   sv2= 0.003870475   df= 5.326564   lambda= 10529.01
# No error in flxsrv_fit
# {0:                  est        L95%        U95%      var
# lifespan  130.114249  127.633831  135.050832  0.00026}
