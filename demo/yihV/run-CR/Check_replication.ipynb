# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/TA_yihV-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/TA_yihV-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/TA_yihV-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV']
#
# out_name_s  ['TA_yihV-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/TA_yihV-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/TA_yihV-1_analysis_metadata.pickle
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 107-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 109-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 114-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 115-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 138-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 143-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 144-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 101-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 109-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 114-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 115-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 138-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 143-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 144-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 107-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 114-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 115-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 138-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 143-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 144-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 109-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 114-1.tif.mortality.tab ------ MAX_07072016 Position 115-1.tif.mortality.tab
# MAX_07072016 Position 114-1.tif.mortality.tab ------ MAX_07072016 Position 138-1.tif.mortality.tab
# MAX_07072016 Position 114-1.tif.mortality.tab ------ MAX_07072016 Position 143-1.tif.mortality.tab
# MAX_07072016 Position 114-1.tif.mortality.tab ------ MAX_07072016 Position 144-1.tif.mortality.tab
# MAX_07072016 Position 114-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 114-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 114-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 115-1.tif.mortality.tab ------ MAX_07072016 Position 138-1.tif.mortality.tab
# MAX_07072016 Position 115-1.tif.mortality.tab ------ MAX_07072016 Position 143-1.tif.mortality.tab
# MAX_07072016 Position 115-1.tif.mortality.tab ------ MAX_07072016 Position 144-1.tif.mortality.tab
# MAX_07072016 Position 115-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 115-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 115-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 138-1.tif.mortality.tab ------ MAX_07072016 Position 143-1.tif.mortality.tab
# MAX_07072016 Position 138-1.tif.mortality.tab ------ MAX_07072016 Position 144-1.tif.mortality.tab
# MAX_07072016 Position 138-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 138-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 138-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 143-1.tif.mortality.tab ------ MAX_07072016 Position 144-1.tif.mortality.tab
# MAX_07072016 Position 143-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 143-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 143-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 144-1.tif.mortality.tab ------ MAX_07072016 Position 145-1.tif.mortality.tab
# MAX_07072016 Position 144-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 144-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 145-1.tif.mortality.tab ------ MAX_07072016 Position 146-1.tif.mortality.tab
# MAX_07072016 Position 145-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# MAX_07072016 Position 146-1.tif.mortality.tab ------ MAX_07072016 Position 150-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_dentrogram-all-files.eps
# [['MAX_07072016 Position 114-1.tif.mortality.tab', 'MAX_07072016 Position 115-1.tif.mortality.tab'], ['MAX_07072016 Position 109-1.tif.mortality.tab', 'MAX_07072016 Position 144-1.tif.mortality.tab', 'MAX_07072016 Position 145-1.tif.mortality.tab'], ['MAX_07072016 Position 107-1.tif.mortality.tab', 'MAX_07072016 Position 143-1.tif.mortality.tab', 'MAX_07072016 Position 146-1.tif.mortality.tab', 'MAX_07072016 Position 150-1.tif.mortality.tab'], ['MAX_07072016 Position 101-1.tif.mortality.tab'], ['MAX_07072016 Position 138-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 17.52327   sv2= 0.2761983   df= 9.2594   lambda= 63.4445
# phi= 20.24761   sv2= 0.07305688   df= 6.303641   lambda= 277.1485
# phi= 23.0112   sv2= 0.02490622   df= 4.746832   lambda= 923.914
# phi= 25.40295   sv2= 0.01041573   df= 3.840254   lambda= 2438.904
# phi= 27.25803   sv2= 0.004393871   df= 3.267782   lambda= 6203.649
# phi= 28.48733   sv2= 0.001690988   df= 2.801936   lambda= 16846.56
# Iterations: relative error in phi-hat = 1e-04
# phi= 19.53402   sv2= 0.1035066   df= 8.869184   lambda= 188.7224
# phi= 24.87508   sv2= 0.01744404   df= 4.87959   lambda= 1425.993
# phi= 29.39818   sv2= 0.003446569   df= 3.382883   lambda= 8529.695
# phi= 31.04708   sv2= 0.0006407089   df= 2.496645   lambda= 48457.4
# Iterations: relative error in phi-hat = 1e-04
# phi= 296.3325   sv2= 0.5641978   df= 7.20437   lambda= 525.228
# phi= 451.5391   sv2= 0.02958367   df= 3.420158   lambda= 15263.12
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/CR-TA_yihV-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.53266   sv2= 0.2048465   df= 10.83545   lambda= 149.0515
# phi= 32.83667   sv2= 0.04180079   df= 6.08746   lambda= 785.5515
# phi= 35.85575   sv2= 0.01268225   df= 4.406724   lambda= 2827.239
# phi= 38.63743   sv2= 0.004599967   df= 3.509849   lambda= 8399.503
# phi= 40.50521   sv2= 0.001596895   df= 2.908379   lambda= 25364.98
# Iterations: relative error in phi-hat = 1e-04
# phi= 296.3325   sv2= 0.5641978   df= 7.20437   lambda= 525.228
# phi= 451.5391   sv2= 0.02958367   df= 3.420158   lambda= 15263.12
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  112.264664  110.800178  115.609474  0.000434, 1:                  est       L95%        U95%       var
# lifespan  104.814158  99.988508  106.013613  0.000927}
