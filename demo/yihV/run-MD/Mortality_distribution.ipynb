# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/TA_yihV-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/TA_yihV-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.29646   sv2= 0.1717765   df= 12.52823   lambda= 246.2297
# phi= 44.20751   sv2= 0.03618388   df= 6.323535   lambda= 1221.746
# phi= 45.13679   sv2= 0.01232764   df= 4.595226   lambda= 3661.43
# phi= 46.47798   sv2= 0.005546121   df= 3.751938   lambda= 8380.269
# phi= 47.84045   sv2= 0.002610072   df= 3.239224   lambda= 18329.17
# save file prefixed name is : TA_yihV-1_df_relative_timegrid-vs-TA_yihV-1_timeseries_dataframe
# biName is :  TA_yihV-1_df_relative_timegrid-vs-TA_yihV-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yihV/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yihV-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yihV/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yihV/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yihV-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.29646   sv2= 0.1717765   df= 12.52823   lambda= 246.2297
# phi= 44.20751   sv2= 0.03618388   df= 6.323535   lambda= 1221.746
# phi= 45.13679   sv2= 0.01232764   df= 4.595226   lambda= 3661.43
# phi= 46.47798   sv2= 0.005546121   df= 3.751938   lambda= 8380.269
# phi= 47.84045   sv2= 0.002610072   df= 3.239224   lambda= 18329.17
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yihV/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yihV-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yihV-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/MD-TA_yihV-1_df_relative_timegrid-vs-TA_yihV-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yihV-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7830.503811)
#                  est          L95%          U95%            se
# rate    2.327269e-01  1.871112e-01  2.894633e-01  2.590474e-02
# beta    1.139929e+09  1.683796e+07  7.717309e+10  2.451523e+09
# s       1.267198e-01  9.451016e-02  1.699067e-01  1.896120e-02
# lambda  8.431721e-04  6.693005e-04  1.062212e-03  9.934896e-05
#                 est        L95%        U95%       var
# lifespan  111.08255  108.664771  112.272278  0.000217
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihV/MD-TA_yihV-1_df_relative_timegrid-vs-TA_yihV-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yihV-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yihV/run-MD
