# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/TA_ybbP-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/TA_ybbP-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP
# Iterations: relative error in phi-hat = 1e-04
# phi= 26.1512   sv2= 0.1486363   df= 11.71964   lambda= 175.9409
# phi= 28.69787   sv2= 0.03143211   df= 6.334548   lambda= 913.0115
# phi= 29.69614   sv2= 0.01409711   df= 4.555675   lambda= 2106.541
# phi= 30.14615   sv2= 0.008217683   df= 3.883447   lambda= 3668.449
# phi= 30.43819   sv2= 0.005279873   df= 3.499735   lambda= 5764.948
# phi= 30.6857   sv2= 0.003499765   df= 3.216427   lambda= 8767.931
# phi= 30.91685   sv2= 0.002315779   df= 2.975854   lambda= 13350.52
# save file prefixed name is : TA_ybbP-1_df_relative_timegrid-vs-TA_ybbP-1_timeseries_dataframe
# biName is :  TA_ybbP-1_df_relative_timegrid-vs-TA_ybbP-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ybbP/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ybbP-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ybbP/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ybbP/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ybbP-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 26.1512   sv2= 0.1486363   df= 11.71964   lambda= 175.9409
# phi= 28.69787   sv2= 0.03143211   df= 6.334548   lambda= 913.0115
# phi= 29.69614   sv2= 0.01409711   df= 4.555675   lambda= 2106.541
# phi= 30.14615   sv2= 0.008217683   df= 3.883447   lambda= 3668.449
# phi= 30.43819   sv2= 0.005279873   df= 3.499735   lambda= 5764.948
# phi= 30.6857   sv2= 0.003499765   df= 3.216427   lambda= 8767.931
# phi= 30.91685   sv2= 0.002315779   df= 2.975854   lambda= 13350.52
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ybbP/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybbP-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ybbP-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/MD-TA_ybbP-1_df_relative_timegrid-vs-TA_ybbP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ybbP-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=6722.821662)
#                  est          L95%          U95%            se
# rate    1.686756e-01  1.427372e-01  1.993276e-01  1.436974e-02
# beta    1.408305e+07  1.255096e+06  1.580215e+08  1.737247e+07
# s       2.861903e-01  2.129580e-01  3.846059e-01  4.315742e-02
# lambda  7.469275e-04  5.736654e-04  9.725194e-04  1.005786e-04
#                  est        L95%        U95%       var
# lifespan  109.727248  107.321191  110.846048  0.000251
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/MD-TA_ybbP-1_df_relative_timegrid-vs-TA_ybbP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybbP-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ybbP/run-MD
