# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/TA_ybbP-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/TA_ybbP-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/TA_ybbP-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP']
#
# out_name_s  ['TA_ybbP-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/TA_ybbP-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/TA_ybbP-1_analysis_metadata.pickle
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 112-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 118-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 123-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 124-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 127-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 134-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 135-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 111-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 118-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 123-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 124-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 127-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 134-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 135-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 112-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 123-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 124-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 127-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 134-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 135-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 118-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 123-1.tif.mortality.tab ------ MAX_07072016 Position 124-1.tif.mortality.tab
# MAX_07072016 Position 123-1.tif.mortality.tab ------ MAX_07072016 Position 127-1.tif.mortality.tab
# MAX_07072016 Position 123-1.tif.mortality.tab ------ MAX_07072016 Position 134-1.tif.mortality.tab
# MAX_07072016 Position 123-1.tif.mortality.tab ------ MAX_07072016 Position 135-1.tif.mortality.tab
# MAX_07072016 Position 123-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 123-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 123-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 124-1.tif.mortality.tab ------ MAX_07072016 Position 127-1.tif.mortality.tab
# MAX_07072016 Position 124-1.tif.mortality.tab ------ MAX_07072016 Position 134-1.tif.mortality.tab
# MAX_07072016 Position 124-1.tif.mortality.tab ------ MAX_07072016 Position 135-1.tif.mortality.tab
# MAX_07072016 Position 124-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 124-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 124-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 127-1.tif.mortality.tab ------ MAX_07072016 Position 134-1.tif.mortality.tab
# MAX_07072016 Position 127-1.tif.mortality.tab ------ MAX_07072016 Position 135-1.tif.mortality.tab
# MAX_07072016 Position 127-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 127-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 127-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 134-1.tif.mortality.tab ------ MAX_07072016 Position 135-1.tif.mortality.tab
# MAX_07072016 Position 134-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 134-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 134-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 135-1.tif.mortality.tab ------ MAX_07072016 Position 140-1.tif.mortality.tab
# MAX_07072016 Position 135-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 135-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 140-1.tif.mortality.tab ------ MAX_07072016 Position 147-1.tif.mortality.tab
# MAX_07072016 Position 140-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# MAX_07072016 Position 147-1.tif.mortality.tab ------ MAX_07072016 Position 148-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_dentrogram-all-files.eps
# [['MAX_07072016 Position 111-1.tif.mortality.tab', 'MAX_07072016 Position 127-1.tif.mortality.tab'], ['MAX_07072016 Position 112-1.tif.mortality.tab', 'MAX_07072016 Position 123-1.tif.mortality.tab'], ['MAX_07072016 Position 118-1.tif.mortality.tab', 'MAX_07072016 Position 124-1.tif.mortality.tab', 'MAX_07072016 Position 134-1.tif.mortality.tab', 'MAX_07072016 Position 135-1.tif.mortality.tab', 'MAX_07072016 Position 140-1.tif.mortality.tab', 'MAX_07072016 Position 147-1.tif.mortality.tab', 'MAX_07072016 Position 148-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 32.03074   sv2= 0.1191064   df= 10.02088   lambda= 268.9254
# phi= 30.79055   sv2= 0.02687218   df= 5.035707   lambda= 1145.815
# phi= 30.55312   sv2= 0.01275269   df= 3.809404   lambda= 2395.817
# phi= 30.95372   sv2= 0.007067088   df= 3.308498   lambda= 4379.982
# phi= 31.39099   sv2= 0.003947743   df= 2.948277   lambda= 7951.629
# phi= 31.7829   sv2= 0.002111052   df= 2.648541   lambda= 15055.48
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.71379   sv2= 0.1343458   df= 9.46211   lambda= 161.626
# phi= 26.4377   sv2= 0.02203884   df= 5.328376   lambda= 1199.596
# phi= 27.74295   sv2= 0.004435405   df= 3.622327   lambda= 6254.887
# phi= 28.36996   sv2= 0.0008553806   df= 2.703253   lambda= 33166.47
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ybbP/CR-TA_ybbP-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.1748   sv2= 0.09771835   df= 10.52821   lambda= 247.3926
# phi= 23.85429   sv2= 0.02545812   df= 5.355808   lambda= 937.0011
# phi= 23.83348   sv2= 0.01413535   df= 4.142401   lambda= 1686.091
# phi= 24.06152   sv2= 0.009611259   df= 3.71367   lambda= 2503.473
# phi= 24.29109   sv2= 0.007030739   df= 3.450417   lambda= 3454.983
# phi= 24.50386   sv2= 0.005292457   df= 3.248359   lambda= 4629.959
# phi= 24.70263   sv2= 0.004012888   df= 3.074365   lambda= 6155.824
# phi= 24.89044   sv2= 0.00302701   df= 2.914869   lambda= 8222.781
# phi= 25.06809   sv2= 0.002254302   df= 2.764518   lambda= 11120.11
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.71379   sv2= 0.1343458   df= 9.46211   lambda= 161.626
# phi= 26.4377   sv2= 0.02203884   df= 5.328376   lambda= 1199.596
# phi= 27.74295   sv2= 0.004435405   df= 3.622327   lambda= 6254.887
# phi= 28.36996   sv2= 0.0008553806   df= 2.703253   lambda= 33166.47
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est       L95%        U95%       var
# lifespan  112.142539  109.90998  112.317529  0.000353, 1:                  est       L95%        U95%       var
# lifespan  103.606484  99.995642  106.020722  0.000891}
