# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygjP'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygjP/TA_ygjP-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygjP/TA_ygjP-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygjP
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.17287   sv2= 0.128982   df= 13.12744   lambda= 195.1657
# phi= 26.15963   sv2= 0.0256441   df= 6.878308   lambda= 1020.103
# phi= 27.65836   sv2= 0.01071745   df= 4.954121   lambda= 2580.685
# phi= 28.82166   sv2= 0.007223998   df= 4.173405   lambda= 3989.71
# phi= 29.39549   sv2= 0.006454487   df= 3.861543   lambda= 4554.272
# phi= 29.57517   sv2= 0.006297881   df= 3.772955   lambda= 4696.05
# phi= 29.61738   sv2= 0.006265544   df= 3.752828   lambda= 4727.025
# phi= 29.62647   sv2= 0.006258785   df= 3.74853   lambda= 4733.581
# phi= 29.62838   sv2= 0.006257367   df= 3.747625   lambda= 4734.96
# phi= 29.62879   sv2= 0.00625707   df= 3.747435   lambda= 4735.25
# save file prefixed name is : TA_ygjP-1_df_relative_timegrid-vs-TA_ygjP-1_timeseries_dataframe
# biName is :  TA_ygjP-1_df_relative_timegrid-vs-TA_ygjP-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ygjP/run-MD
# No error in flxsrv_fit
# TA_ygjP-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ygjP/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ygjP/run-MD
# TA_ygjP-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.17287   sv2= 0.128982   df= 13.12744   lambda= 195.1657
# phi= 26.15963   sv2= 0.0256441   df= 6.878308   lambda= 1020.103
# phi= 27.65836   sv2= 0.01071745   df= 4.954121   lambda= 2580.685
# phi= 28.82166   sv2= 0.007223998   df= 4.173405   lambda= 3989.71
# phi= 29.39549   sv2= 0.006454487   df= 3.861543   lambda= 4554.272
# phi= 29.57517   sv2= 0.006297881   df= 3.772955   lambda= 4696.05
# phi= 29.61738   sv2= 0.006265544   df= 3.752828   lambda= 4727.025
# phi= 29.62647   sv2= 0.006258785   df= 3.74853   lambda= 4733.581
# phi= 29.62838   sv2= 0.006257367   df= 3.747625   lambda= 4734.96
# phi= 29.62879   sv2= 0.00625707   df= 3.747435   lambda= 4735.25
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ygjP/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ygjP-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ygjP-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygjP/MD-TA_ygjP-1_df_relative_timegrid-vs-TA_ygjP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ygjP-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=8219.920781)
#                  est          L95%          U95%            se
# rate    1.703737e-01  1.328067e-01  2.185673e-01  2.165348e-02
# beta    6.264193e+09  3.379250e+07  1.161208e+12  1.669108e+10
# s       2.818627e-01  1.871377e-01  4.245355e-01  5.890112e-02
# lambda  3.307689e-03  2.944760e-03  3.715347e-03  1.961401e-04
#                  est        L95%        U95%       var
# lifespan  134.921062  133.137162  138.341297  0.000254
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygjP/MD-TA_ygjP-1_df_relative_timegrid-vs-TA_ygjP-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ygjP-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ygjP/run-MD
