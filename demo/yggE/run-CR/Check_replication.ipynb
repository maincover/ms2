# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/TA_yggE-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/TA_yggE-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/TA_yggE-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE']
#
# out_name_s  ['TA_yggE-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/TA_yggE-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/TA_yggE-1_analysis_metadata.pickle
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 110-1.tif.mortality.tab
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 51-1.tif.mortality.tab
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 52-1.tif.mortality.tab
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 57-1.tif.mortality.tab
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 58-1.tif.mortality.tab
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 80-1.tif.mortality.tab
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 90-1.tif.mortality.tab
# MAX_01112018 Position 108-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# MAX_01112018 Position 110-1.tif.mortality.tab ------ MAX_01112018 Position 51-1.tif.mortality.tab
# MAX_01112018 Position 110-1.tif.mortality.tab ------ MAX_01112018 Position 52-1.tif.mortality.tab
# MAX_01112018 Position 110-1.tif.mortality.tab ------ MAX_01112018 Position 57-1.tif.mortality.tab
# MAX_01112018 Position 110-1.tif.mortality.tab ------ MAX_01112018 Position 58-1.tif.mortality.tab
# MAX_01112018 Position 110-1.tif.mortality.tab ------ MAX_01112018 Position 80-1.tif.mortality.tab
# MAX_01112018 Position 110-1.tif.mortality.tab ------ MAX_01112018 Position 90-1.tif.mortality.tab
# MAX_01112018 Position 110-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# MAX_01112018 Position 51-1.tif.mortality.tab ------ MAX_01112018 Position 52-1.tif.mortality.tab
# MAX_01112018 Position 51-1.tif.mortality.tab ------ MAX_01112018 Position 57-1.tif.mortality.tab
# MAX_01112018 Position 51-1.tif.mortality.tab ------ MAX_01112018 Position 58-1.tif.mortality.tab
# MAX_01112018 Position 51-1.tif.mortality.tab ------ MAX_01112018 Position 80-1.tif.mortality.tab
# MAX_01112018 Position 51-1.tif.mortality.tab ------ MAX_01112018 Position 90-1.tif.mortality.tab
# MAX_01112018 Position 51-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# MAX_01112018 Position 52-1.tif.mortality.tab ------ MAX_01112018 Position 57-1.tif.mortality.tab
# MAX_01112018 Position 52-1.tif.mortality.tab ------ MAX_01112018 Position 58-1.tif.mortality.tab
# MAX_01112018 Position 52-1.tif.mortality.tab ------ MAX_01112018 Position 80-1.tif.mortality.tab
# MAX_01112018 Position 52-1.tif.mortality.tab ------ MAX_01112018 Position 90-1.tif.mortality.tab
# MAX_01112018 Position 52-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# MAX_01112018 Position 57-1.tif.mortality.tab ------ MAX_01112018 Position 58-1.tif.mortality.tab
# MAX_01112018 Position 57-1.tif.mortality.tab ------ MAX_01112018 Position 80-1.tif.mortality.tab
# MAX_01112018 Position 57-1.tif.mortality.tab ------ MAX_01112018 Position 90-1.tif.mortality.tab
# MAX_01112018 Position 57-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# MAX_01112018 Position 58-1.tif.mortality.tab ------ MAX_01112018 Position 80-1.tif.mortality.tab
# MAX_01112018 Position 58-1.tif.mortality.tab ------ MAX_01112018 Position 90-1.tif.mortality.tab
# MAX_01112018 Position 58-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# MAX_01112018 Position 80-1.tif.mortality.tab ------ MAX_01112018 Position 90-1.tif.mortality.tab
# MAX_01112018 Position 80-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# MAX_01112018 Position 90-1.tif.mortality.tab ------ MAX_01112018 Position 93-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_dentrogram-all-files.eps
# [['MAX_01112018 Position 51-1.tif.mortality.tab', 'MAX_01112018 Position 93-1.tif.mortality.tab'], ['MAX_01112018 Position 108-1.tif.mortality.tab', 'MAX_01112018 Position 110-1.tif.mortality.tab', 'MAX_01112018 Position 52-1.tif.mortality.tab', 'MAX_01112018 Position 57-1.tif.mortality.tab', 'MAX_01112018 Position 58-1.tif.mortality.tab', 'MAX_01112018 Position 80-1.tif.mortality.tab', 'MAX_01112018 Position 90-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 93.23582   sv2= 0.1196866   df= 15.55336   lambda= 778.9997
# phi= 98.48701   sv2= 0.006135658   df= 5.953998   lambda= 16051.58
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.375726   sv2= 0.09603806   df= 9.311396   lambda= 87.21258
# phi= 8.098641   sv2= 0.01252321   df= 5.900795   lambda= 646.6904
# phi= 7.997033   sv2= 0.001806145   df= 3.944245   lambda= 4427.68
# phi= 8.188004   sv2= 0.000671716   df= 2.81331   lambda= 12189.68
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yggE/CR-TA_yggE-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 75.42139   sv2= 0.1361226   df= 15.85575   lambda= 554.0696
# phi= 78.67288   sv2= 0.008765605   df= 6.535047   lambda= 8975.18
# phi= 82.34667   sv2= 0.0009059611   df= 3.707651   lambda= 90894.27
# No error in flxsrv_fit
# {0:                 est       L95%        U95%      var
# lifespan  98.728471  97.222681  101.146788  0.00012}
