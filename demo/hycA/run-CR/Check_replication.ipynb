# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/TA_hycA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/TA_hycA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/TA_hycA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA']
#
# out_name_s  ['TA_hycA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/TA_hycA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/TA_hycA-1_analysis_metadata.pickle
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 103-1.tif.mortality.tab
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 104-1.tif.mortality.tab
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 105-1.tif.mortality.tab
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 18-1.tif.mortality.tab
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 40-1.tif.mortality.tab
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 84-1.tif.mortality.tab
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 85-1.tif.mortality.tab
# MAX_28092014 Position 102-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# MAX_28092014 Position 103-1.tif.mortality.tab ------ MAX_28092014 Position 104-1.tif.mortality.tab
# MAX_28092014 Position 103-1.tif.mortality.tab ------ MAX_28092014 Position 105-1.tif.mortality.tab
# MAX_28092014 Position 103-1.tif.mortality.tab ------ MAX_28092014 Position 18-1.tif.mortality.tab
# MAX_28092014 Position 103-1.tif.mortality.tab ------ MAX_28092014 Position 40-1.tif.mortality.tab
# MAX_28092014 Position 103-1.tif.mortality.tab ------ MAX_28092014 Position 84-1.tif.mortality.tab
# MAX_28092014 Position 103-1.tif.mortality.tab ------ MAX_28092014 Position 85-1.tif.mortality.tab
# MAX_28092014 Position 103-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# MAX_28092014 Position 104-1.tif.mortality.tab ------ MAX_28092014 Position 105-1.tif.mortality.tab
# MAX_28092014 Position 104-1.tif.mortality.tab ------ MAX_28092014 Position 18-1.tif.mortality.tab
# MAX_28092014 Position 104-1.tif.mortality.tab ------ MAX_28092014 Position 40-1.tif.mortality.tab
# MAX_28092014 Position 104-1.tif.mortality.tab ------ MAX_28092014 Position 84-1.tif.mortality.tab
# MAX_28092014 Position 104-1.tif.mortality.tab ------ MAX_28092014 Position 85-1.tif.mortality.tab
# MAX_28092014 Position 104-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# MAX_28092014 Position 105-1.tif.mortality.tab ------ MAX_28092014 Position 18-1.tif.mortality.tab
# MAX_28092014 Position 105-1.tif.mortality.tab ------ MAX_28092014 Position 40-1.tif.mortality.tab
# MAX_28092014 Position 105-1.tif.mortality.tab ------ MAX_28092014 Position 84-1.tif.mortality.tab
# MAX_28092014 Position 105-1.tif.mortality.tab ------ MAX_28092014 Position 85-1.tif.mortality.tab
# MAX_28092014 Position 105-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# MAX_28092014 Position 18-1.tif.mortality.tab ------ MAX_28092014 Position 40-1.tif.mortality.tab
# MAX_28092014 Position 18-1.tif.mortality.tab ------ MAX_28092014 Position 84-1.tif.mortality.tab
# MAX_28092014 Position 18-1.tif.mortality.tab ------ MAX_28092014 Position 85-1.tif.mortality.tab
# MAX_28092014 Position 18-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# MAX_28092014 Position 40-1.tif.mortality.tab ------ MAX_28092014 Position 84-1.tif.mortality.tab
# MAX_28092014 Position 40-1.tif.mortality.tab ------ MAX_28092014 Position 85-1.tif.mortality.tab
# MAX_28092014 Position 40-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# MAX_28092014 Position 84-1.tif.mortality.tab ------ MAX_28092014 Position 85-1.tif.mortality.tab
# MAX_28092014 Position 84-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# MAX_28092014 Position 85-1.tif.mortality.tab ------ MAX_28092014 Position 86-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_dentrogram-all-files.eps
# [['MAX_28092014 Position 84-1.tif.mortality.tab', 'MAX_28092014 Position 85-1.tif.mortality.tab'], ['MAX_28092014 Position 102-1.tif.mortality.tab', 'MAX_28092014 Position 105-1.tif.mortality.tab'], ['MAX_28092014 Position 103-1.tif.mortality.tab', 'MAX_28092014 Position 104-1.tif.mortality.tab', 'MAX_28092014 Position 18-1.tif.mortality.tab', 'MAX_28092014 Position 40-1.tif.mortality.tab', 'MAX_28092014 Position 86-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 67.49134   sv2= 0.1248896   df= 15.86169   lambda= 540.4079
# phi= 69.30392   sv2= 0.005039726   df= 6.471538   lambda= 13751.52
# Iterations: relative error in phi-hat = 1e-04
# phi= 101.2705   sv2= 0.1246019   df= 13.63605   lambda= 812.7521
# phi= 115.9921   sv2= 0.002401512   df= 5.212803   lambda= 48299.6
# Iterations: relative error in phi-hat = 1e-04
# phi= 121.6845   sv2= 0.0414377   df= 14.07758   lambda= 2936.566
# phi= 123.4288   sv2= 0.002615887   df= 4.152067   lambda= 47184.29
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_mortality_dataframe_cluster2.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/CR-TA_hycA-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 67.49134   sv2= 0.1248896   df= 15.86169   lambda= 540.4079
# phi= 69.30392   sv2= 0.005039726   df= 6.471538   lambda= 13751.52
# Iterations: relative error in phi-hat = 1e-04
# phi= 101.2705   sv2= 0.1246019   df= 13.63605   lambda= 812.7521
# phi= 115.9921   sv2= 0.002401512   df= 5.212803   lambda= 48299.6
# Iterations: relative error in phi-hat = 1e-04
# phi= 121.6845   sv2= 0.0414377   df= 14.07758   lambda= 2936.566
# phi= 123.4288   sv2= 0.002615887   df= 4.152067   lambda= 47184.29
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%        U95%       var
# lifespan  99.387133  98.924504  100.924958  0.000073, 1:                  est       L95%        U95%       var
# lifespan  101.379924  99.401201  102.402913  0.000184, 2:                 est      L95%       U95%      var
# lifespan  85.255034  82.25581  87.254132  0.00022}
