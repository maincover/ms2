# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/TA_hycA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/TA_hycA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA
# Iterations: relative error in phi-hat = 1e-04
# phi= 84.85233   sv2= 0.1250773   df= 17.83929   lambda= 678.3993
# phi= 87.40183   sv2= 0.005333336   df= 7.089869   lambda= 16387.84
# save file prefixed name is : TA_hycA-1_df_relative_timegrid-vs-TA_hycA-1_timeseries_dataframe
# biName is :  TA_hycA-1_df_relative_timegrid-vs-TA_hycA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/hycA/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_hycA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/hycA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/hycA/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_hycA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 84.85233   sv2= 0.1250773   df= 17.83929   lambda= 678.3993
# phi= 87.40183   sv2= 0.005333336   df= 7.089869   lambda= 16387.84
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/hycA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_hycA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_hycA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/MD-TA_hycA-1_df_relative_timegrid-vs-TA_hycA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_hycA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=46494.155848)
#                  est          L95%          U95%            se
# rate    5.311600e-02  5.050724e-02      0.055859  1.364818e-03
# beta    2.832996e+03  9.016778e+02   8901.035511  1.654779e+03
# s       1.077225e+01  2.909772e+00     39.879903  7.193902e+00
# lambda  3.958626e-08  1.895734e-20  82663.062202  5.729471e-07
#                 est       L95%       U95%       var
# lifespan  98.255099  97.394819  99.255017  0.000042
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/hycA/MD-TA_hycA-1_df_relative_timegrid-vs-TA_hycA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_hycA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/hycA/run-MD
