# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS'
ref_df_path = '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/TA_80 MG yagS-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/TA_80 MG yagS-1_timeseries_dataframe.pickle']]
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS
# Iterations: relative error in phi-hat = 1e-04
# phi= 196.6054   sv2= 0.4166153   df= 20.13024   lambda= 471.9111
# phi= 208.4545   sv2= 0.03603388   df= 8.845687   lambda= 5784.96
# phi= 216.6622   sv2= 0.007508567   df= 5.187376   lambda= 28855.33
# save file prefixed name is : TA_80 MG yagS-1_df_relative_timegrid-vs-TA_80 MG yagS-1_timeseries_dataframe
# biName is :  TA_80 MG yagS-1_df_relative_timegrid-vs-TA_80 MG yagS-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/coliSurvivalAnalysis/xsong/main/demo/80 MG yagS/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_80 MG yagS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/coliSurvivalAnalysis/xsong/main/demo/80 MG yagS/run-MD
# getKMNABSfits_dict-- /home/xsong/coliSurvivalAnalysis/xsong/main/demo/80 MG yagS/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_80 MG yagS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 196.6054   sv2= 0.4166153   df= 20.13024   lambda= 471.9111
# phi= 208.4545   sv2= 0.03603388   df= 8.845687   lambda= 5784.96
# phi= 216.6622   sv2= 0.007508567   df= 5.187376   lambda= 28855.33
# getKMNABSfits_dict-- /home/xsong/coliSurvivalAnalysis/xsong/main/demo/80 MG yagS/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_80 MG yagS-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_80 MG yagS-1_df_relative_timegrid.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/MD-TA_80 MG yagS-1_df_relative_timegrid-vs-TA_80 MG yagS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_80 MG yagS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=69720.771761)
#                  est          L95%          U95%            se
# rate    4.842383e-02  4.638181e-02  5.055575e-02  1.064472e-03
# beta    8.892803e+03  3.597420e+00  2.198296e+07  3.544836e+04
# s       1.265835e+02  4.536300e-02  3.532260e+05  5.124119e+02
# lambda  6.345208e-08  9.985644e-18  4.031955e+02  7.307614e-07
#                 est       L95%       U95%       var
# lifespan  81.385876  81.372271  81.402645  0.000032
#
#
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/MD-TA_80 MG yagS-1_df_relative_timegrid-vs-TA_80 MG yagS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_80 MG yagS-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/coliSurvivalAnalysis/xsong/main/demo/80 MG yagS/run-MD
