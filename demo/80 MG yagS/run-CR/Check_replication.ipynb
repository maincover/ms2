# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS'
path_ref_folder ='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/abgR_output/abgR mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/abgR_output/abgR relative_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 797.0653   sv2= 0.02651864   df= 19.77049   lambda= 30056.79
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/TA_80 MG yagS-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/TA_80 MG yagS-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/TA_80 MG yagS-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS']
#
# out_name_s  ['TA_80 MG yagS-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/TA_80 MG yagS-1_mortality_dataframe.pickle
# path meta  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/TA_80 MG yagS-1_analysis_metadata.pickle
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 71_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 72_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 73_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 74_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 75_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 78_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 79_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 70_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 72_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 73_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 74_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 75_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 78_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 79_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 71_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 73_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 74_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 75_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 78_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 79_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 72_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 74_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 75_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 78_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 79_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 73_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 75_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 78_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 79_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 74_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 78_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 79_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 75_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 79_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 78_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 80_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 79_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 80_MAX.tif.mortality.tab ------ MAX_30102017 Position 81_MAX.tif.mortality.tab
# MAX_30102017 Position 80_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 80_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 80_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 80_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 80_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 80_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 81_MAX.tif.mortality.tab ------ MAX_30102017 Position 82_MAX.tif.mortality.tab
# MAX_30102017 Position 81_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 81_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 81_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 81_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 81_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 82_MAX.tif.mortality.tab ------ MAX_30102017 Position 83_MAX.tif.mortality.tab
# MAX_30102017 Position 82_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 82_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 82_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 82_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 83_MAX.tif.mortality.tab ------ MAX_30102017 Position 84_MAX.tif.mortality.tab
# MAX_30102017 Position 83_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 83_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 83_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 84_MAX.tif.mortality.tab ------ MAX_30102017 Position 86_MAX.tif.mortality.tab
# MAX_30102017 Position 84_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 84_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 86_MAX.tif.mortality.tab ------ MAX_30102017 Position 87_MAX.tif.mortality.tab
# MAX_30102017 Position 86_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# MAX_30102017 Position 87_MAX.tif.mortality.tab ------ MAX_30102017 Position 90_MAX.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS
# save eps to :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_dentrogram-all-files.eps
# 7 [5 4 4 1 1 2 3]
# [['MAX_30102017 Position 73_MAX.tif.mortality.tab', 'MAX_30102017 Position 75_MAX.tif.mortality.tab', 'MAX_30102017 Position 79_MAX.tif.mortality.tab', 'MAX_30102017 Position 80_MAX.tif.mortality.tab'], ['MAX_30102017 Position 70_MAX.tif.mortality.tab', 'MAX_30102017 Position 72_MAX.tif.mortality.tab', 'MAX_30102017 Position 74_MAX.tif.mortality.tab'], ['MAX_30102017 Position 71_MAX.tif.mortality.tab'], ['MAX_30102017 Position 78_MAX.tif.mortality.tab', 'MAX_30102017 Position 81_MAX.tif.mortality.tab', 'MAX_30102017 Position 82_MAX.tif.mortality.tab', 'MAX_30102017 Position 90_MAX.tif.mortality.tab'], ['MAX_30102017 Position 83_MAX.tif.mortality.tab', 'MAX_30102017 Position 84_MAX.tif.mortality.tab', 'MAX_30102017 Position 86_MAX.tif.mortality.tab', 'MAX_30102017 Position 87_MAX.tif.mortality.tab']]
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_colomap_all_files_cluster0.png
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_colomap_all_files_cluster1.png
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_colomap_all_files_cluster2.png
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_colomap_all_files_cluster3.png
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 452.5325   sv2= 0.3000248   df= 16.51799   lambda= 1508.317
# phi= 574.698   sv2= 0.006696639   df= 5.531671   lambda= 85818.88
# Iterations: relative error in phi-hat = 1e-04
# phi= 467.0081   sv2= 0.3713941   df= 16.3721   lambda= 1257.446
# phi= 507.0312   sv2= 0.009234733   df= 5.670975   lambda= 54904.8
# Iterations: relative error in phi-hat = 1e-04
# phi= 413.4747   sv2= 0.2349677   df= 14.8674   lambda= 1759.709
# phi= 454.1383   sv2= 0.006932711   df= 4.764638   lambda= 65506.59
# Iterations: relative error in phi-hat = 1e-04
# phi= 394.4553   sv2= 0.1450584   df= 15.72109   lambda= 2719.286
# phi= 390.874   sv2= 0.008054293   df= 4.688893   lambda= 48529.89
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 3
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_relative_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_cluster0_tabs.txt
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_mortality_dataframe_cluster1.pickle
# 5 --c-- 1
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_relative_timegrid_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_cluster1_tabs.txt
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_mortality_dataframe_cluster2.pickle
# 5 --c-- 0
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_relative_timegrid_cluster2.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/ana_19032013_MG_WT/80 MG yagS/CR-TA_80 MG yagS-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 386.4773   sv2= 0.3796763   df= 18.16546   lambda= 1017.913
# phi= 416.3198   sv2= 0.016987   df= 6.581616   lambda= 24508.14
# Iterations: relative error in phi-hat = 1e-04
# phi= 645.712   sv2= 0.2311215   df= 15.41083   lambda= 2793.821
# phi= 799.189   sv2= 0.004078355   df= 4.600548   lambda= 195958.7
# Iterations: relative error in phi-hat = 1e-04
# phi= 413.4747   sv2= 0.2349677   df= 14.8674   lambda= 1759.709
# phi= 454.1383   sv2= 0.006932711   df= 4.764638   lambda= 65506.59
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%      var
# lifespan  81.368902  81.357806  81.372271  0.00007, 1:                 est       L95%       U95%       var
# lifespan  81.395692  78.406234  81.428288  0.000158, 2:                 est       L95%       U95%       var
# lifespan  82.413288  81.402645  83.406452  0.000165}
