
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-7761c1ddf041> in <module>()
#       2 step1TvReg = True
#       3 step2Output = False
# ----> 4 pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
#
# /home/xsong/Desktop/coliSurvivalAnalysis/xsong/main/TabPostAnalyzer.py in process(self, doPIcolormap, doReview, doOutput)
#     647
#     648         if doReview:
# --> 649             self.denoise();
#     650             self.tightPlot();
#     651             if self.debug:
#
# /home/xsong/Desktop/coliSurvivalAnalysis/xsong/main/TabPostAnalyzer.py in denoise(self)
#     264             fn_ts[fn_ts<1]=np.nan
#     265             L=np.concatenate(([1],np.exp(np.cumsum(np.nanmean(np.diff(np.log(fn_ts),axis=0), axis=1)))))
# --> 266             logLprime = TVRegDiff(np.log(L), *self.TVRegDiff_para, plotflag=0, diagflag=0)
#     267             logLscale = np.sum(np.cumsum(logLprime[1:-1])*(np.log(L[1:])-np.log(L[0])))/np.sum(np.cumsum(logLprime[1:-1])*np.cumsum(logLprime[1:-1]))
#     268             filtered_L = L[0]*np.concatenate(([1],np.exp(np.cumsum(logLprime[1:-1])*logLscale)))
#
# /home/xsong/Desktop/coliSurvivalAnalysis/xsong/main/tvregdiff.py in TVRegDiff(data, itern, alph, u0, scale, ep, dx, plotflag, diagflag)
#     217                     print "WARNING - illegal input or breakdown"
#     218             else:
# --> 219                 [s, info_i] = sparse.linalg.cg( linop, g, None, tol, maxit, None, P )
#     220             # Update solution.
#     221             u = u - s;
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/scipy/sparse/linalg/isolve/iterative.pyc in cg(A, b, x0, tol, maxiter, M, callback, atol)
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/scipy/_lib/_threadsafety.pyc in caller(func, *a, **kw)
#      44         def caller(func, *a, **kw):
#      45             with self:
# ---> 46                 return func(*a, **kw)
#      47         return scipy._lib.decorator.decorate(func, caller)
#      48
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/scipy/sparse/linalg/isolve/iterative.pyc in cg(A, b, x0, tol, maxiter, M, callback, atol)
#     298            revcom(b, x, work, iter_, resid, info, ndx1, ndx2, ijob)
#     299         if callback is not None and iter_ > olditer:
# --> 300             callback(x)
#     301         slice1 = slice(ndx1-1, ndx1-1+n)
#     302         slice2 = slice(ndx2-1, ndx2-1+n)
#
# TypeError: 'dia_matrix' object is not callable

# %%
# Out:
#   File "<ipython-input-5-5fa611a2f8cf>", line 17
#     -0.20913201  0.03491691 -0.20054549  0.04378266 -0.19321255  0.05132671
#                           ^
# SyntaxError: invalid syntax

# %%
pA.denoisePlotAll(asp=0.01,onlyPlot=True)
aIndex=120
pA.defineAlcoholTime(more=20,aIndex=aIndex)

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
