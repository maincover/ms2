# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/TA_ykfI-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/TA_ykfI-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.93086   sv2= 0.3455102   df= 13.19359   lambda= 150.302
# phi= 55.47753   sv2= 0.03453898   df= 7.358275   lambda= 1606.229
# phi= 57.21649   sv2= 0.006332066   df= 4.505617   lambda= 9035.991
# phi= 58.09967   sv2= 0.001682988   df= 3.215545   lambda= 34521.74
# save file prefixed name is : TA_ykfI-1_df_relative_timegrid-vs-TA_ykfI-1_timeseries_dataframe
# biName is :  TA_ykfI-1_df_relative_timegrid-vs-TA_ykfI-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ykfI/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ykfI-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ykfI/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ykfI/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ykfI-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.93086   sv2= 0.3455102   df= 13.19359   lambda= 150.302
# phi= 55.47753   sv2= 0.03453898   df= 7.358275   lambda= 1606.229
# phi= 57.21649   sv2= 0.006332066   df= 4.505617   lambda= 9035.991
# phi= 58.09967   sv2= 0.001682988   df= 3.215545   lambda= 34521.74
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ykfI/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ykfI-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ykfI-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/MD-TA_ykfI-1_df_relative_timegrid-vs-TA_ykfI-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ykfI-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=13542.646721)
#                  est          L95%           U95%            se
# rate        0.084222      0.074939       0.094655      0.005018
# beta    56320.066529  22127.091983  143351.412658  26845.859715
# s           0.739083      0.540161       1.011262      0.118234
# lambda      0.000409      0.000301       0.000556      0.000064
#                  est        L95%       U95%       var
# lifespan  133.083161  131.810723  135.07395  0.000132
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/MD-TA_ykfI-1_df_relative_timegrid-vs-TA_ykfI-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ykfI-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ykfI/run-MD
