# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/TA_ykfI-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/TA_ykfI-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/TA_ykfI-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI']
#
# out_name_s  ['TA_ykfI-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/TA_ykfI-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/TA_ykfI-1_analysis_metadata.pickle
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 175-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 177-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 249-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 250-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 251-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 252-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 259-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 174-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 177-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 249-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 250-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 251-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 252-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 259-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 175-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 249-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 250-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 251-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 252-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 259-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 177-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 250-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 251-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 252-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 259-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 249-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 250-1.tif.mortality.tab ------ MAX_11102018 Position 251-1.tif.mortality.tab
# MAX_11102018 Position 250-1.tif.mortality.tab ------ MAX_11102018 Position 252-1.tif.mortality.tab
# MAX_11102018 Position 250-1.tif.mortality.tab ------ MAX_11102018 Position 259-1.tif.mortality.tab
# MAX_11102018 Position 250-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 250-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 250-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 250-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 251-1.tif.mortality.tab ------ MAX_11102018 Position 252-1.tif.mortality.tab
# MAX_11102018 Position 251-1.tif.mortality.tab ------ MAX_11102018 Position 259-1.tif.mortality.tab
# MAX_11102018 Position 251-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 251-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 251-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 251-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 252-1.tif.mortality.tab ------ MAX_11102018 Position 259-1.tif.mortality.tab
# MAX_11102018 Position 252-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 252-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 252-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 252-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 259-1.tif.mortality.tab ------ MAX_11102018 Position 264-1.tif.mortality.tab
# MAX_11102018 Position 259-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 259-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 259-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 264-1.tif.mortality.tab ------ MAX_11102018 Position 266-1.tif.mortality.tab
# MAX_11102018 Position 264-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 264-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 266-1.tif.mortality.tab ------ MAX_11102018 Position 267-1.tif.mortality.tab
# MAX_11102018 Position 266-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# MAX_11102018 Position 267-1.tif.mortality.tab ------ MAX_11102018 Position 270-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_dentrogram-all-files.eps
# [['MAX_11102018 Position 174-1.tif.mortality.tab', 'MAX_11102018 Position 175-1.tif.mortality.tab', 'MAX_11102018 Position 177-1.tif.mortality.tab', 'MAX_11102018 Position 267-1.tif.mortality.tab'], ['MAX_11102018 Position 250-1.tif.mortality.tab', 'MAX_11102018 Position 252-1.tif.mortality.tab', 'MAX_11102018 Position 264-1.tif.mortality.tab', 'MAX_11102018 Position 270-1.tif.mortality.tab'], ['MAX_11102018 Position 249-1.tif.mortality.tab', 'MAX_11102018 Position 251-1.tif.mortality.tab', 'MAX_11102018 Position 259-1.tif.mortality.tab', 'MAX_11102018 Position 266-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 197.3248   sv2= 0.2369606   df= 10.66857   lambda= 832.7326
# phi= 238.1626   sv2= 0.006739088   df= 4.287388   lambda= 35340.48
# Iterations: relative error in phi-hat = 1e-04
# phi= 32.36823   sv2= 0.06083958   df= 10.40887   lambda= 532.0258
# phi= 33.84761   sv2= 0.00529512   df= 4.330765   lambda= 6392.226
# phi= 34.75338   sv2= 0.0005964145   df= 2.680199   lambda= 58270.51
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.64544   sv2= 0.09965229   df= 11.16691   lambda= 508.2215
# phi= 51.80238   sv2= 0.001860969   df= 4.876944   lambda= 27836.25
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ykfI/CR-TA_ykfI-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 58.49168   sv2= 0.1145088   df= 12.1499   lambda= 510.805
# phi= 59.66427   sv2= 0.003873189   df= 5.129177   lambda= 15404.43
# Iterations: relative error in phi-hat = 1e-04
# phi= 197.3248   sv2= 0.2369606   df= 10.66857   lambda= 832.7326
# phi= 238.1626   sv2= 0.006739088   df= 4.287388   lambda= 35340.48
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                est        L95%        U95%       var
# lifespan  130.6104  129.413294  130.648084  0.000213, 1:                  est        L95%        U95%      var
# lifespan  138.714815  138.707301  141.142968  0.00035}
