# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/TA_ptsH-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/TA_ptsH-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH
# Iterations: relative error in phi-hat = 1e-04
# phi= 141.3429   sv2= 0.1340369   df= 17.54019   lambda= 1054.507
# phi= 145.3394   sv2= 0.006927863   df= 6.315983   lambda= 20978.96
# save file prefixed name is : TA_ptsH-1_df_relative_timegrid-vs-TA_ptsH-1_timeseries_dataframe
# biName is :  TA_ptsH-1_df_relative_timegrid-vs-TA_ptsH-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ptsH/run-MD
# No error in flxsrv_fit
# TA_ptsH-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ptsH/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ptsH/run-MD
# TA_ptsH-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 141.3429   sv2= 0.1340369   df= 17.54019   lambda= 1054.507
# phi= 145.3394   sv2= 0.006927863   df= 6.315983   lambda= 20978.96
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ptsH/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ptsH-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ptsH-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/MD-TA_ptsH-1_df_relative_timegrid-vs-TA_ptsH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ptsH-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=28593.585903)
#                est          L95%        U95%         se
# rate      0.078603  7.217229e-02    0.085607   0.003423
# beta    126.967191  9.825493e+01  164.069809  16.607309
# s         0.448326  3.878859e-01    0.518184   0.033124
# lambda    0.000005  3.643175e-08    0.000558   0.000011
#                 est       L95%       U95%       var
# lifespan  77.735659  76.505862  79.795723  0.000079
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/MD-TA_ptsH-1_df_relative_timegrid-vs-TA_ptsH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ptsH-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ptsH/run-MD
