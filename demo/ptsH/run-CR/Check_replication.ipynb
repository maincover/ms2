# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/TA_ptsH-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/TA_ptsH-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/TA_ptsH-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH']
#
# out_name_s  ['TA_ptsH-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/TA_ptsH-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/TA_ptsH-1_analysis_metadata.pickle
# MAX_18102018 Position 20-1.tif.mortality.tab ------ MAX_18102018 Position 203-1.tif.mortality.tab
# MAX_18102018 Position 20-1.tif.mortality.tab ------ MAX_18102018 Position 208-1.tif.mortality.tab
# MAX_18102018 Position 20-1.tif.mortality.tab ------ MAX_18102018 Position 209-1.tif.mortality.tab
# MAX_18102018 Position 20-1.tif.mortality.tab ------ MAX_18102018 Position 210-1.tif.mortality.tab
# MAX_18102018 Position 20-1.tif.mortality.tab ------ MAX_18102018 Position 211-1.tif.mortality.tab
# MAX_18102018 Position 20-1.tif.mortality.tab ------ MAX_18102018 Position 22-1.tif.mortality.tab
# MAX_18102018 Position 20-1.tif.mortality.tab ------ MAX_18102018 Position 27-1.tif.mortality.tab
# MAX_18102018 Position 203-1.tif.mortality.tab ------ MAX_18102018 Position 208-1.tif.mortality.tab
# MAX_18102018 Position 203-1.tif.mortality.tab ------ MAX_18102018 Position 209-1.tif.mortality.tab
# MAX_18102018 Position 203-1.tif.mortality.tab ------ MAX_18102018 Position 210-1.tif.mortality.tab
# MAX_18102018 Position 203-1.tif.mortality.tab ------ MAX_18102018 Position 211-1.tif.mortality.tab
# MAX_18102018 Position 203-1.tif.mortality.tab ------ MAX_18102018 Position 22-1.tif.mortality.tab
# MAX_18102018 Position 203-1.tif.mortality.tab ------ MAX_18102018 Position 27-1.tif.mortality.tab
# MAX_18102018 Position 208-1.tif.mortality.tab ------ MAX_18102018 Position 209-1.tif.mortality.tab
# MAX_18102018 Position 208-1.tif.mortality.tab ------ MAX_18102018 Position 210-1.tif.mortality.tab
# MAX_18102018 Position 208-1.tif.mortality.tab ------ MAX_18102018 Position 211-1.tif.mortality.tab
# MAX_18102018 Position 208-1.tif.mortality.tab ------ MAX_18102018 Position 22-1.tif.mortality.tab
# MAX_18102018 Position 208-1.tif.mortality.tab ------ MAX_18102018 Position 27-1.tif.mortality.tab
# MAX_18102018 Position 209-1.tif.mortality.tab ------ MAX_18102018 Position 210-1.tif.mortality.tab
# MAX_18102018 Position 209-1.tif.mortality.tab ------ MAX_18102018 Position 211-1.tif.mortality.tab
# MAX_18102018 Position 209-1.tif.mortality.tab ------ MAX_18102018 Position 22-1.tif.mortality.tab
# MAX_18102018 Position 209-1.tif.mortality.tab ------ MAX_18102018 Position 27-1.tif.mortality.tab
# MAX_18102018 Position 210-1.tif.mortality.tab ------ MAX_18102018 Position 211-1.tif.mortality.tab
# MAX_18102018 Position 210-1.tif.mortality.tab ------ MAX_18102018 Position 22-1.tif.mortality.tab
# MAX_18102018 Position 210-1.tif.mortality.tab ------ MAX_18102018 Position 27-1.tif.mortality.tab
# MAX_18102018 Position 211-1.tif.mortality.tab ------ MAX_18102018 Position 22-1.tif.mortality.tab
# MAX_18102018 Position 211-1.tif.mortality.tab ------ MAX_18102018 Position 27-1.tif.mortality.tab
# MAX_18102018 Position 22-1.tif.mortality.tab ------ MAX_18102018 Position 27-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_dentrogram-all-files.eps
# [['MAX_18102018 Position 20-1.tif.mortality.tab', 'MAX_18102018 Position 22-1.tif.mortality.tab'], ['MAX_18102018 Position 209-1.tif.mortality.tab', 'MAX_18102018 Position 210-1.tif.mortality.tab'], ['MAX_18102018 Position 211-1.tif.mortality.tab'], ['MAX_18102018 Position 203-1.tif.mortality.tab'], ['MAX_18102018 Position 208-1.tif.mortality.tab'], ['MAX_18102018 Position 27-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 264.7471   sv2= 0.1245499   df= 13.42648   lambda= 2125.631
# phi= 294.3107   sv2= 0.002505663   df= 4.312693   lambda= 117458.2
# Iterations: relative error in phi-hat = 1e-04
# phi= 462.7107   sv2= 0.1363732   df= 12.55601   lambda= 3392.974
# phi= 543.2353   sv2= 0.00587151   df= 3.752502   lambda= 92520.55
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_mortality_dataframe_cluster1.pickle
# 5 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ptsH/CR-TA_ptsH-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 373.079   sv2= 0.13235   df= 13.59744   lambda= 2818.881
# phi= 401.5231   sv2= 0.007457605   df= 4.127996   lambda= 53840.76
# Iterations: relative error in phi-hat = 1e-04
# phi= 264.7471   sv2= 0.1245499   df= 13.42648   lambda= 2125.631
# phi= 294.3107   sv2= 0.002505663   df= 4.312693   lambda= 117458.2
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                est       L95%       U95%       var
# lifespan  77.33125  76.085933  82.264025  0.000297, 1:                 est       L95%       U95%       var
# lifespan  76.505862  75.256211  78.967605  0.000331}
