# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/TA_appA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/TA_appA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/TA_appA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA']
#
# out_name_s  ['TA_appA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/TA_appA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/TA_appA-1_analysis_metadata.pickle
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 122-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 123-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 126-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 138-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 139-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 39-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 45-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 121-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 123-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 126-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 138-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 139-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 39-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 45-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 122-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 126-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 138-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 139-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 39-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 45-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 123-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 126-1.tif.mortality.tab ------ MAX_17022015 Position 138-1.tif.mortality.tab
# MAX_17022015 Position 126-1.tif.mortality.tab ------ MAX_17022015 Position 139-1.tif.mortality.tab
# MAX_17022015 Position 126-1.tif.mortality.tab ------ MAX_17022015 Position 39-1.tif.mortality.tab
# MAX_17022015 Position 126-1.tif.mortality.tab ------ MAX_17022015 Position 45-1.tif.mortality.tab
# MAX_17022015 Position 126-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 126-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 126-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 138-1.tif.mortality.tab ------ MAX_17022015 Position 139-1.tif.mortality.tab
# MAX_17022015 Position 138-1.tif.mortality.tab ------ MAX_17022015 Position 39-1.tif.mortality.tab
# MAX_17022015 Position 138-1.tif.mortality.tab ------ MAX_17022015 Position 45-1.tif.mortality.tab
# MAX_17022015 Position 138-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 138-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 138-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 139-1.tif.mortality.tab ------ MAX_17022015 Position 39-1.tif.mortality.tab
# MAX_17022015 Position 139-1.tif.mortality.tab ------ MAX_17022015 Position 45-1.tif.mortality.tab
# MAX_17022015 Position 139-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 139-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 139-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 39-1.tif.mortality.tab ------ MAX_17022015 Position 45-1.tif.mortality.tab
# MAX_17022015 Position 39-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 39-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 39-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 45-1.tif.mortality.tab ------ MAX_17022015 Position 51-1.tif.mortality.tab
# MAX_17022015 Position 45-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 45-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 51-1.tif.mortality.tab ------ MAX_17022015 Position 67-1.tif.mortality.tab
# MAX_17022015 Position 51-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# MAX_17022015 Position 67-1.tif.mortality.tab ------ MAX_17022015 Position 96-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_dentrogram-all-files.eps
# [['MAX_17022015 Position 45-1.tif.mortality.tab', 'MAX_17022015 Position 96-1.tif.mortality.tab'], ['MAX_17022015 Position 39-1.tif.mortality.tab'], ['MAX_17022015 Position 51-1.tif.mortality.tab'], ['MAX_17022015 Position 123-1.tif.mortality.tab'], ['MAX_17022015 Position 138-1.tif.mortality.tab'], ['MAX_17022015 Position 121-1.tif.mortality.tab', 'MAX_17022015 Position 122-1.tif.mortality.tab', 'MAX_17022015 Position 139-1.tif.mortality.tab', 'MAX_17022015 Position 67-1.tif.mortality.tab'], ['MAX_17022015 Position 126-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 82.70062   sv2= 0.303815   df= 17.63894   lambda= 272.2072
# phi= 83.9125   sv2= 0.01519451   df= 8.440817   lambda= 5522.555
# phi= 84.68385   sv2= 0.001122176   df= 4.474452   lambda= 75463.96
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.59694   sv2= 0.1883332   df= 14.70083   lambda= 130.6033
# phi= 26.32766   sv2= 0.04060676   df= 8.30931   lambda= 648.3565
# phi= 27.73068   sv2= 0.01027971   df= 5.841286   lambda= 2697.613
# phi= 28.55561   sv2= 0.003275226   df= 4.303705   lambda= 8718.668
# phi= 29.02912   sv2= 0.001451647   df= 3.390847   lambda= 19997.37
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_mortality_dataframe_cluster0.pickle
# 7 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_mortality_dataframe_cluster1.pickle
# 7 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/CR-TA_appA-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 82.70062   sv2= 0.303815   df= 17.63894   lambda= 272.2072
# phi= 83.9125   sv2= 0.01519451   df= 8.440817   lambda= 5522.555
# phi= 84.68385   sv2= 0.001122176   df= 4.474452   lambda= 75463.96
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.59694   sv2= 0.1883332   df= 14.70083   lambda= 130.6033
# phi= 26.32766   sv2= 0.04060676   df= 8.30931   lambda= 648.3565
# phi= 27.73068   sv2= 0.01027971   df= 5.841286   lambda= 2697.613
# phi= 28.55561   sv2= 0.003275226   df= 4.303705   lambda= 8718.668
# phi= 29.02912   sv2= 0.001451647   df= 3.390847   lambda= 19997.37
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  89.063941  88.066789  90.066547  0.000066, 1:                 est       L95%       U95%       var
# lifespan  83.411828  82.767292  84.412473  0.000112}
