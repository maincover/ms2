# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/TA_appA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/TA_appA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.00685   sv2= 0.3512881   df= 21.03619   lambda= 128.1195
# phi= 45.97725   sv2= 0.04685755   df= 12.3906   lambda= 981.2133
# phi= 46.29848   sv2= 0.009671159   df= 7.836411   lambda= 4787.273
# phi= 46.57668   sv2= 0.003585487   df= 5.579068   lambda= 12990.34
# save file prefixed name is : TA_appA-1_df_relative_timegrid-vs-TA_appA-1_timeseries_dataframe
# biName is :  TA_appA-1_df_relative_timegrid-vs-TA_appA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/appA/run-MD
# No error in flxsrv_fit
# TA_appA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/appA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/appA/run-MD
# TA_appA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.00685   sv2= 0.3512881   df= 21.03619   lambda= 128.1195
# phi= 45.97725   sv2= 0.04685755   df= 12.3906   lambda= 981.2133
# phi= 46.29848   sv2= 0.009671159   df= 7.836411   lambda= 4787.273
# phi= 46.57668   sv2= 0.003585487   df= 5.579068   lambda= 12990.34
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/appA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_appA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_appA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/MD-TA_appA-1_df_relative_timegrid-vs-TA_appA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_appA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=80934.365840)
#                  est          L95%        U95%         se
# rate    5.864749e-02  5.644064e-02    0.060941   0.001148
# beta    2.222652e+02  1.999191e+02  247.109096  12.015993
# s       1.288045e+00  1.127609e+00    1.471308   0.087422
# lambda  6.196842e-07  2.829066e-12    0.135737   0.000004
#                 est       L95%       U95%       var
# lifespan  86.058905  85.062267  86.766836  0.000025
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appA/MD-TA_appA-1_df_relative_timegrid-vs-TA_appA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_appA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/appA/run-MD
