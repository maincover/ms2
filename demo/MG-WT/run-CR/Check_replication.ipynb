# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT'
path_ref_folder ='/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT/WT mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT/WT relative_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 235.5627   sv2= 0.1234959   df= 18.03344   lambda= 1907.454
# phi= 236.4887   sv2= 0.001903347   df= 5.639079   lambda= 124248.8
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/TA_MG-WT-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/TA_MG-WT-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/TA_MG-WT-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT']
#
# out_name_s  ['TA_MG-WT-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/TA_MG-WT-1_mortality_dataframe.pickle
# path meta  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/TA_MG-WT-1_analysis_metadata.pickle
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab ------ MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT
# save eps to :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_dentrogram-all-files.eps
# [['MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab'], ['MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab'], ['MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab', 'MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab'], ['MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab']]
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_colomap_all_files_cluster0.png
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_colomap_all_files_cluster1.png
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_colomap_all_files_cluster2.png
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.77787   sv2= 0.1024031   df= 13.32642   lambda= 583.7508
# phi= 63.9358   sv2= 0.009044967   df= 5.425023   lambda= 7068.66
# phi= 63.20495   sv2= 0.005387274   df= 3.312843   lambda= 11732.27
# Iterations: relative error in phi-hat = 1e-04
# phi= 41.83465   sv2= 0.04407538   df= 14.0738   lambda= 949.1613
# phi= 43.00599   sv2= 0.001638319   df= 5.135055   lambda= 26250.07
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.219799   sv2= 0.07476289   df= 12.86255   lambda= 43.06681
# phi= 3.372639   sv2= 0.01959846   df= 9.279664   lambda= 172.0869
# phi= 3.46834   sv2= 0.006653336   df= 6.861005   lambda= 521.2934
# phi= 3.511199   sv2= 0.003867234   df= 5.434789   lambda= 907.9354
# phi= 3.521068   sv2= 0.003457981   df= 4.85389   lambda= 1018.244
# phi= 3.522385   sv2= 0.003409315   df= 4.743566   lambda= 1033.165
# phi= 3.522539   sv2= 0.0034037   df= 4.729796   lambda= 1034.915
# phi= 3.522557   sv2= 0.003403054   df= 4.728197   lambda= 1035.116
# phi= 3.522559   sv2= 0.00340298   df= 4.728013   lambda= 1035.139
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_relative_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_cluster0_tabs.txt
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_relative_timegrid_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/CR-TA_MG-WT-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# Iterations: relative error in phi-hat = 1e-04
# phi= 59.77787   sv2= 0.1024031   df= 13.32642   lambda= 583.7508
# phi= 63.9358   sv2= 0.009044967   df= 5.425023   lambda= 7068.66
# phi= 63.20495   sv2= 0.005387274   df= 3.312843   lambda= 11732.27
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143, 1:                est       L95%       U95%       var
# lifespan  59.17727  58.044402  61.023736  0.000245}
