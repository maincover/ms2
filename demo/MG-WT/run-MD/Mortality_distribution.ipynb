# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT'
ref_df_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT/WT-1_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/TA_MG-WT-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/TA_MG-WT-1_timeseries_dataframe.pickle']]
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# WT-1_df_relative_timegrid
# load reference pickle,  WT-1_df_relative_timegrid 112.602349444
# files will be written into :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.25017   sv2= 0.08382169   df= 17.74319   lambda= 325.0969
# phi= 27.91736   sv2= 0.005741726   df= 8.196747   lambda= 4862.189
# phi= 28.14909   sv2= 0.002283877   df= 4.570329   lambda= 12325.13
# save file prefixed name is : TA_MG-WT-1_df_relative_timegrid-vs-TA_MG-WT-1_timeseries_dataframe
# biName is :  TA_MG-WT-1_df_relative_timegrid-vs-TA_MG-WT-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG-WT/run-MD
# No error in flxsrv_fit
# WT-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_MG-WT-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG-WT/run-MD
# getKMNABSfits_dict-- /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG-WT/run-MD
# WT-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.715   sv2= 0.42506   df= 17.31378   lambda= 119.3126
# phi= 55.04413   sv2= 0.04353927   df= 10.05507   lambda= 1264.241
# phi= 57.89357   sv2= 0.003954065   df= 5.965454   lambda= 14641.53
# TA_MG-WT-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.25017   sv2= 0.08382169   df= 17.74319   lambda= 325.0969
# phi= 27.91736   sv2= 0.005741726   df= 8.196747   lambda= 4862.189
# phi= 28.14909   sv2= 0.002283877   df= 4.570329   lambda= 12325.13
# getKMNABSfits_dict-- /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG-WT/run-MD
# 0 WT-1_df_relative_timegrid.pickle
# 1 TA_MG-WT-1_df_relative_timegrid.pickle
# TA_MG-WT-1_df_relative_timegrid.pickle
# WT-1_df_relative_timegrid.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MD-TA_MG-WT-1_df_relative_timegrid-vs-TA_MG-WT-1_timeseries_dataframe-vs-WT-1_df_relative_timegrid_GG_GGM_parameters.txt
# TA_MG-WT-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=29950.904362)
#                est       L95%        U95%         se
# rate      0.076514   0.067241    0.087064   0.005043
# beta    112.405356  72.329573  174.686005  25.284703
# s         0.839274   0.674681    1.044019   0.093476
# lambda    0.000503   0.000126    0.001999   0.000354
#                est       L95%       U95%       var
# lifespan  64.17728  63.177142  65.173502  0.000076
#
#
# WT-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=27003.675001)
#                est        L95%        U95%         se
# rate      0.070890    0.062119    0.080899   0.004777
# beta    208.286774  144.098661  301.067198  39.152006
# s         1.321167    0.957716    1.822546   0.216864
# lambda    0.000213    0.000017    0.002687   0.000275
#                 est      L95%       U95%       var
# lifespan  69.946437  68.94717  70.947297  0.000077
#
#
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MD-TA_MG-WT-1_df_relative_timegrid-vs-TA_MG-WT-1_timeseries_dataframe-vs-WT-1_df_relative_timegrid_GG_GGM_parameters.txt
# 0 WT-1_df_relative_timegrid.pickle
# 1 TA_MG-WT-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG-WT/run-MD
