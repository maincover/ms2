# %% [markdown]
# # TAB Analyzer Process (only file filter listed .tab files (existed also in pth) )
# TabPostAnalyzer.py is should be in the grand parent folder
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from TabPostAnalyzer import TabPostAnalyzer
pth='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT'
fFn='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/report/finalFiles.txt'
partial=1
pA = TabPostAnalyzer(pth,filterFile=fFn, group=partial)
# Out:
# part,  1
# ['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab', '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG-WT/MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab']
# Total cell number :  3406
# filtered file/all file:  12 / 12

# %%
step0PlotOriginalFiles = True
step1TvReg = False
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
#             Step 0: Before we process any data, preview the PI profiles in
#             each tab files. No need for any parameters, could always run directly.
#             self.checkTimeJump() could be used to check time indeces of each files,
#             but is only triggered if self.debug is True.
#
#             Use self.viewCellTraces(fileName,start,end,pn=5) to check cell traces

# %%
step0PlotOriginalFiles = False
step1TvReg = True
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# autoDefineAlcohol is True, the alcohol index will be selected as: 142
# Alcohol time index is :  142
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (142, 141.62532239898991, 140.51355154320987, -0.33390290556344349)
# [ 1 ]  (143, 142.60751909090908, 141.62532239898991, -0.27923990557603345)
# [ 2 ]  (141, 140.51355154320987, 139.51511033950618, -0.080357248736844245)
# [ 3 ]  (0, 0.11438916666666898, 148.83081682870369, 0.070342692533492679)
# [ 4 ]  (140, 139.51511033950618, 138.66788532407406, 0.066581657428177857)
# [ 5 ]  (139, 138.66788532407406, 137.837852, 0.063965468119192223)
# [ 6 ]  (138, 137.837852, 137.12558562499999, 0.059321754671061128)
# [ 7 ]  (137, 137.12558562499999, 136.5001801851852, 0.058870644219101188)
# [ 8 ]  (136, 136.5001801851852, 135.53794641666667, 0.053096762584559719)
# [ 9 ]  (62, 58.92858681818182, 57.927963131313128, 0.051769549925600261)
#
#             Step1: Use TVReg to calculate illumination levels, which are used
#             to estimate alcohol Time and then which cell to included in the end.
#             This step requires a set of data visualisation and report, so that
#             the user can verify the automatically chosen alcohol time is correct,
#             and the correct cells are included.
#
#             The first visualisations are the PI profiles for each file and
#             their illumination levels. The second visualisation is all illuminations
#             plotted into the same figure. The third visualisation is the combined
#             PI profile and illumination.
#
#             We also report the number of included or excluded cells in each file.
#
#             The user SHOULD make sure alcohol time is correct, or manually set
#             it according to suggestions.

# %%
pA.denoisePlotAll(asp=0.01,onlyPlot=True)
aIndex=140
pA.defineAlcoholTime(more=20,aIndex=aIndex)
# Out:
# Alcohol time index is :  140
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (142, 141.62532239898991, 140.51355154320987, -0.33390290556344349)
# [ 1 ]  (143, 142.60751909090908, 141.62532239898991, -0.27923990557603345)
# [ 2 ]  (141, 140.51355154320987, 139.51511033950618, -0.080357248736844245)
# [ 3 ]  (0, 0.11438916666666898, 148.83081682870369, 0.070342692533492679)
# [ 4 ]  (140, 139.51511033950618, 138.66788532407406, 0.066581657428177857)
# [ 5 ]  (139, 138.66788532407406, 137.837852, 0.063965468119192223)
# [ 6 ]  (138, 137.837852, 137.12558562499999, 0.059321754671061128)
# [ 7 ]  (137, 137.12558562499999, 136.5001801851852, 0.058870644219101188)
# [ 8 ]  (136, 136.5001801851852, 135.53794641666667, 0.053096762584559719)
# [ 9 ]  (62, 58.92858681818182, 57.927963131313128, 0.051769549925600261)
# [ 10 ]  (60, 56.928004671717169, 55.949197245370371, -0.04392743658848499)
# [ 11 ]  (4, 3.1162671875000001, 2.2817351157407444, -0.042855148192445285)
# [ 12 ]  (144, 144.02228192129627, 142.60751909090908, -0.042755719484029134)
# [ 13 ]  (87, 84.82162252314815, 83.692006444444445, 0.038274211389853104)
# [ 14 ]  (135, 135.53794641666667, 134.68956927083332, 0.037289801566030796)
# [ 15 ]  (15, 13.81692243055555, 12.949381412037042, -0.037237391230144953)
# [ 16 ]  (112, 111.52213564814815, 110.52181372685186, 0.035105943427531268)
# [ 17 ]  (3, 2.2817351157407444, 1.5477125555555489, -0.034252956232386951)
# [ 18 ]  (127, 127.85522115740741, 126.85582307870371, 0.033715083488522653)
# [ 19 ]  (146, 146.19435807291666, 145.02446125, 0.033484514715178534)

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab 447 447
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab 314 327
# MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab 421 439
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab 269 307
# MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab 470 493
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab 337 344
# MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab 70 73
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab 521 537
# MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab 262 273
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab 52 52
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab 52 53
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab 59 61
# 45
# MAX_MAX_10022015 Position 28 v2-1.tif.mortality.tab 447 447
# MAX_MAX_10022015 Position 47 v2 ok-1.tif.mortality.tab 321 327
# MAX_MAX_10022015 Position 94 v2-1.tif.mortality.tab 429 439
# MAX_MAX_10022015 Position 30 v2-1.tif.mortality.tab 269 307
# MAX_MAX_10022015 Position 93 v2-1.tif.mortality.tab 483 493
# MAX_MAX_10022015 Position 29 v2-1.tif.mortality.tab 339 344
# MAX_MAX_10022015 Position 9 v2-1.tif.mortality.tab 71 73
# MAX_MAX_10022015 Position 83 v2-1.tif.mortality.tab 531 537
# MAX_MAX_10022015 Position 95 v2-1.tif.mortality.tab 263 273
# MAX_MAX_10022015 Position 4 v2-1.tif.mortality.tab 52 52
# MAX_MAX_10022015 Position 6 v2-1.tif.mortality.tab 52 53
# MAX_MAX_10022015 Position 3 v2-1.tif.mortality.tab 59 61
#
#             Step2: After the user have reviewed and set the alcohol time,
#             re-calculate cells to include. Then again use included data to
#             re-estimate illumination, estimate lifespan, and output data
#             in the form of pickles.

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
# Out:
# length of df is:  3316
# length of relative_time_grid is:  1738
