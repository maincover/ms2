# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/TA_yphG-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/TA_yphG-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.39382   sv2= 0.2436116   df= 14.52449   lambda= 124.7634
# phi= 32.58908   sv2= 0.03366545   df= 8.417955   lambda= 968.0274
# phi= 33.77205   sv2= 0.005026271   df= 5.395424   lambda= 6719.105
# phi= 34.04695   sv2= 0.001253008   df= 3.60801   lambda= 27172.18
# save file prefixed name is : TA_yphG-1_df_relative_timegrid-vs-TA_yphG-1_timeseries_dataframe
# biName is :  TA_yphG-1_df_relative_timegrid-vs-TA_yphG-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yphG/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yphG-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yphG/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yphG/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yphG-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.39382   sv2= 0.2436116   df= 14.52449   lambda= 124.7634
# phi= 32.58908   sv2= 0.03366545   df= 8.417955   lambda= 968.0274
# phi= 33.77205   sv2= 0.005026271   df= 5.395424   lambda= 6719.105
# phi= 34.04695   sv2= 0.001253008   df= 3.60801   lambda= 27172.18
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yphG/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yphG-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yphG-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/MD-TA_yphG-1_df_relative_timegrid-vs-TA_yphG-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yphG-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=18689.685405)
#                 est         L95%         U95%           se
# rate       0.073914     0.065715     0.083137     0.004434
# beta    4785.160323  2765.411200  8280.055897  1338.722491
# s          0.939036     0.643597     1.370093     0.180998
# lambda     0.000184     0.000102     0.000334     0.000056
#                  est        L95%        U95%       var
# lifespan  114.512265  113.387327  116.686859  0.000098
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/MD-TA_yphG-1_df_relative_timegrid-vs-TA_yphG-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yphG-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yphG/run-MD
