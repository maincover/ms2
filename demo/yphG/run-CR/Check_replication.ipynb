# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/TA_yphG-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/TA_yphG-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/TA_yphG-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG']
#
# out_name_s  ['TA_yphG-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/TA_yphG-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/TA_yphG-1_analysis_metadata.pickle
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 47-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 61-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 83-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 84-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 85-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 86-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 88-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 33-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 61-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 83-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 84-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 85-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 86-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 88-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 47-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 83-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 84-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 85-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 86-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 88-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 61-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 84-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 85-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 86-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 88-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 83-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 85-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 86-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 88-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 84-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 86-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 88-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 85-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 86-1.tif.mortality.tab ------ MAX_07112014 Position 88-1.tif.mortality.tab
# MAX_07112014 Position 86-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 86-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 86-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 86-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 86-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 86-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 88-1.tif.mortality.tab ------ MAX_07112014 Position 89-1.tif.mortality.tab
# MAX_07112014 Position 88-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 88-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 88-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 88-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 88-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 89-1.tif.mortality.tab ------ MAX_07112014 Position 90-1.tif.mortality.tab
# MAX_07112014 Position 89-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 89-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 89-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 89-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 90-1.tif.mortality.tab ------ MAX_07112014 Position 94-1.tif.mortality.tab
# MAX_07112014 Position 90-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 90-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 90-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 94-1.tif.mortality.tab ------ MAX_07112014 Position 97-1.tif.mortality.tab
# MAX_07112014 Position 94-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 94-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 97-1.tif.mortality.tab ------ MAX_07112014 Position 98-1.tif.mortality.tab
# MAX_07112014 Position 97-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# MAX_07112014 Position 98-1.tif.mortality.tab ------ MAX_07112014 Position 99-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_dentrogram-all-files.eps
# [['MAX_07112014 Position 61-1.tif.mortality.tab', 'MAX_07112014 Position 83-1.tif.mortality.tab', 'MAX_07112014 Position 84-1.tif.mortality.tab', 'MAX_07112014 Position 85-1.tif.mortality.tab', 'MAX_07112014 Position 88-1.tif.mortality.tab', 'MAX_07112014 Position 90-1.tif.mortality.tab', 'MAX_07112014 Position 94-1.tif.mortality.tab', 'MAX_07112014 Position 98-1.tif.mortality.tab'], ['MAX_07112014 Position 86-1.tif.mortality.tab'], ['MAX_07112014 Position 47-1.tif.mortality.tab', 'MAX_07112014 Position 97-1.tif.mortality.tab'], ['MAX_07112014 Position 33-1.tif.mortality.tab', 'MAX_07112014 Position 89-1.tif.mortality.tab', 'MAX_07112014 Position 99-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 35.68351   sv2= 0.2261448   df= 13.02477   lambda= 157.7905
# phi= 38.88835   sv2= 0.0259169   df= 7.164911   lambda= 1500.501
# phi= 40.30685   sv2= 0.006830056   df= 4.413297   lambda= 5901.393
# phi= 40.67871   sv2= 0.003145815   df= 3.330105   lambda= 12931.06
# Iterations: relative error in phi-hat = 1e-04
# phi= 6.841104   sv2= 0.1347373   df= 8.096341   lambda= 50.77366
# phi= 7.155256   sv2= 0.02888815   df= 5.943244   lambda= 247.6883
# phi= 7.414268   sv2= 0.005256664   df= 4.367106   lambda= 1410.451
# phi= 7.822991   sv2= 0.0008557749   df= 3.028069   lambda= 9141.412
# phi= 8.467677   sv2= 0.0001561335   df= 2.239408   lambda= 54233.56
# Iterations: relative error in phi-hat = 1e-04
# phi= 13.41215   sv2= 0.1084093   df= 8.388806   lambda= 123.7177
# phi= 14.83872   sv2= 0.03635208   df= 5.105158   lambda= 408.1945
# phi= 15.59507   sv2= 0.01947594   df= 4.053856   lambda= 800.7353
# phi= 16.00491   sv2= 0.01245042   df= 3.558855   lambda= 1285.492
# phi= 16.2945   sv2= 0.008572731   df= 3.227605   lambda= 1900.737
# phi= 16.52075   sv2= 0.006120501   df= 2.966531   lambda= 2699.248
# phi= 16.7047   sv2= 0.00445765   df= 2.753823   lambda= 3747.424
# phi= 16.85641   sv2= 0.003283288   df= 2.582723   lambda= 5134.004
# phi= 16.98159   sv2= 0.002432292   df= 2.447427   lambda= 6981.72
# phi= 17.0841   sv2= 0.001805823   df= 2.341599   lambda= 9460.562
# phi= 17.16707   sv2= 0.001340729   df= 2.259381   lambda= 12804.28
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yphG/CR-TA_yphG-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.59872   sv2= 0.2231762   df= 13.47867   lambda= 150.5479
# phi= 36.03163   sv2= 0.02501959   df= 7.494505   lambda= 1440.137
# phi= 37.13837   sv2= 0.006159916   df= 4.608243   lambda= 6029.038
# phi= 37.50437   sv2= 0.002694528   df= 3.418484   lambda= 13918.72
# Iterations: relative error in phi-hat = 1e-04
# phi= 6.841104   sv2= 0.1347373   df= 8.096341   lambda= 50.77366
# phi= 7.155256   sv2= 0.02888815   df= 5.943244   lambda= 247.6883
# phi= 7.414268   sv2= 0.005256664   df= 4.367106   lambda= 1410.451
# phi= 7.822991   sv2= 0.0008557749   df= 3.028069   lambda= 9141.412
# phi= 8.467677   sv2= 0.0001561335   df= 2.239408   lambda= 54233.56
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  113.333034  113.143077  114.444371  0.000125, 1:                  est        L95%        U95%      var
# lifespan  125.430973  124.289947  128.852259  0.00072}
