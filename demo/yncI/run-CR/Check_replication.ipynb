# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/TA_yncI-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/TA_yncI-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/TA_yncI-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI']
#
# out_name_s  ['TA_yncI-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/TA_yncI-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/TA_yncI-1_analysis_metadata.pickle
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 16-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 20-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 21-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 22-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 23-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 24-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 25-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 15-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 20-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 21-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 22-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 23-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 24-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 25-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 16-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 21-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 22-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 23-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 24-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 25-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 20-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 21-1.tif.mortality.tab ------ MAX_08062014 Position 22-1.tif.mortality.tab
# MAX_08062014 Position 21-1.tif.mortality.tab ------ MAX_08062014 Position 23-1.tif.mortality.tab
# MAX_08062014 Position 21-1.tif.mortality.tab ------ MAX_08062014 Position 24-1.tif.mortality.tab
# MAX_08062014 Position 21-1.tif.mortality.tab ------ MAX_08062014 Position 25-1.tif.mortality.tab
# MAX_08062014 Position 21-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 21-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 21-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 22-1.tif.mortality.tab ------ MAX_08062014 Position 23-1.tif.mortality.tab
# MAX_08062014 Position 22-1.tif.mortality.tab ------ MAX_08062014 Position 24-1.tif.mortality.tab
# MAX_08062014 Position 22-1.tif.mortality.tab ------ MAX_08062014 Position 25-1.tif.mortality.tab
# MAX_08062014 Position 22-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 22-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 22-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 23-1.tif.mortality.tab ------ MAX_08062014 Position 24-1.tif.mortality.tab
# MAX_08062014 Position 23-1.tif.mortality.tab ------ MAX_08062014 Position 25-1.tif.mortality.tab
# MAX_08062014 Position 23-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 23-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 23-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 24-1.tif.mortality.tab ------ MAX_08062014 Position 25-1.tif.mortality.tab
# MAX_08062014 Position 24-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 24-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 24-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 25-1.tif.mortality.tab ------ MAX_08062014 Position 36-1.tif.mortality.tab
# MAX_08062014 Position 25-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 25-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 36-1.tif.mortality.tab ------ MAX_08062014 Position 37-1.tif.mortality.tab
# MAX_08062014 Position 36-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# MAX_08062014 Position 37-1.tif.mortality.tab ------ MAX_08062014 Position 38-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_dentrogram-all-files.eps
# [['MAX_08062014 Position 24-1.tif.mortality.tab', 'MAX_08062014 Position 25-1.tif.mortality.tab'], ['MAX_08062014 Position 15-1.tif.mortality.tab', 'MAX_08062014 Position 38-1.tif.mortality.tab'], ['MAX_08062014 Position 16-1.tif.mortality.tab', 'MAX_08062014 Position 20-1.tif.mortality.tab', 'MAX_08062014 Position 21-1.tif.mortality.tab', 'MAX_08062014 Position 22-1.tif.mortality.tab', 'MAX_08062014 Position 23-1.tif.mortality.tab', 'MAX_08062014 Position 36-1.tif.mortality.tab', 'MAX_08062014 Position 37-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.88338   sv2= 0.02302236   df= 16.19074   lambda= 820.219
# phi= 18.98126   sv2= 0.001639177   df= 6.014796   lambda= 11579.75
# Iterations: relative error in phi-hat = 1e-04
# phi= 2.870386   sv2= 0.02944345   df= 13.98655   lambda= 97.48809
# phi= 2.94268   sv2= 0.004648757   df= 8.336596   lambda= 633.0037
# phi= 2.994106   sv2= 0.002380258   df= 5.542982   lambda= 1257.891
# phi= 3.02369   sv2= 0.002087537   df= 4.804657   lambda= 1448.449
# phi= 3.031621   sv2= 0.002017574   df= 4.668184   lambda= 1502.607
# phi= 3.033812   sv2= 0.00199844   df= 4.633458   lambda= 1518.09
# phi= 3.034433   sv2= 0.001993026   df= 4.623817   lambda= 1522.526
# phi= 3.034611   sv2= 0.001991479   df= 4.621078   lambda= 1523.798
# phi= 3.034662   sv2= 0.001991036   df= 4.620294   lambda= 1524.162
# phi= 3.034676   sv2= 0.001990909   df= 4.62007   lambda= 1524.267
# Iterations: relative error in phi-hat = 1e-04
# phi= 15.66352   sv2= 0.04748582   df= 9.6452   lambda= 329.8567
# phi= 16.19846   sv2= 0.001538034   df= 4.60503   lambda= 10531.92
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yncI/CR-TA_yncI-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.00742   sv2= 0.03295748   df= 17.56058   lambda= 637.4098
# phi= 21.09826   sv2= 0.001919309   df= 6.906274   lambda= 10992.63
# Iterations: relative error in phi-hat = 1e-04
# phi= 15.66352   sv2= 0.04748582   df= 9.6452   lambda= 329.8567
# phi= 16.19846   sv2= 0.001538034   df= 4.60503   lambda= 10531.92
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  84.268016  83.001665  85.280273  0.000071, 1:                 est       L95%       U95%       var
# lifespan  92.117286  88.129391  94.130308  0.000918}
