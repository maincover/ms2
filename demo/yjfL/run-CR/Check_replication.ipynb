# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/TA_yjfL-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/TA_yjfL-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/TA_yjfL-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL']
#
# out_name_s  ['TA_yjfL-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/TA_yjfL-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/TA_yjfL-1_analysis_metadata.pickle
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 192-1.tif.mortality.tab
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 198-1.tif.mortality.tab
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 199-1.tif.mortality.tab
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 200-1.tif.mortality.tab
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 4-1.tif.mortality.tab
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 5-1.tif.mortality.tab
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 8-1.tif.mortality.tab
# MAX_12072015 Position 191-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# MAX_12072015 Position 192-1.tif.mortality.tab ------ MAX_12072015 Position 198-1.tif.mortality.tab
# MAX_12072015 Position 192-1.tif.mortality.tab ------ MAX_12072015 Position 199-1.tif.mortality.tab
# MAX_12072015 Position 192-1.tif.mortality.tab ------ MAX_12072015 Position 200-1.tif.mortality.tab
# MAX_12072015 Position 192-1.tif.mortality.tab ------ MAX_12072015 Position 4-1.tif.mortality.tab
# MAX_12072015 Position 192-1.tif.mortality.tab ------ MAX_12072015 Position 5-1.tif.mortality.tab
# MAX_12072015 Position 192-1.tif.mortality.tab ------ MAX_12072015 Position 8-1.tif.mortality.tab
# MAX_12072015 Position 192-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# MAX_12072015 Position 198-1.tif.mortality.tab ------ MAX_12072015 Position 199-1.tif.mortality.tab
# MAX_12072015 Position 198-1.tif.mortality.tab ------ MAX_12072015 Position 200-1.tif.mortality.tab
# MAX_12072015 Position 198-1.tif.mortality.tab ------ MAX_12072015 Position 4-1.tif.mortality.tab
# MAX_12072015 Position 198-1.tif.mortality.tab ------ MAX_12072015 Position 5-1.tif.mortality.tab
# MAX_12072015 Position 198-1.tif.mortality.tab ------ MAX_12072015 Position 8-1.tif.mortality.tab
# MAX_12072015 Position 198-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# MAX_12072015 Position 199-1.tif.mortality.tab ------ MAX_12072015 Position 200-1.tif.mortality.tab
# MAX_12072015 Position 199-1.tif.mortality.tab ------ MAX_12072015 Position 4-1.tif.mortality.tab
# MAX_12072015 Position 199-1.tif.mortality.tab ------ MAX_12072015 Position 5-1.tif.mortality.tab
# MAX_12072015 Position 199-1.tif.mortality.tab ------ MAX_12072015 Position 8-1.tif.mortality.tab
# MAX_12072015 Position 199-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# MAX_12072015 Position 200-1.tif.mortality.tab ------ MAX_12072015 Position 4-1.tif.mortality.tab
# MAX_12072015 Position 200-1.tif.mortality.tab ------ MAX_12072015 Position 5-1.tif.mortality.tab
# MAX_12072015 Position 200-1.tif.mortality.tab ------ MAX_12072015 Position 8-1.tif.mortality.tab
# MAX_12072015 Position 200-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# MAX_12072015 Position 4-1.tif.mortality.tab ------ MAX_12072015 Position 5-1.tif.mortality.tab
# MAX_12072015 Position 4-1.tif.mortality.tab ------ MAX_12072015 Position 8-1.tif.mortality.tab
# MAX_12072015 Position 4-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# MAX_12072015 Position 5-1.tif.mortality.tab ------ MAX_12072015 Position 8-1.tif.mortality.tab
# MAX_12072015 Position 5-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# MAX_12072015 Position 8-1.tif.mortality.tab ------ MAX_12072015 Position 9-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_dentrogram-all-files.eps
# [['MAX_12072015 Position 191-1.tif.mortality.tab', 'MAX_12072015 Position 200-1.tif.mortality.tab', 'MAX_12072015 Position 5-1.tif.mortality.tab'], ['MAX_12072015 Position 192-1.tif.mortality.tab'], ['MAX_12072015 Position 198-1.tif.mortality.tab', 'MAX_12072015 Position 199-1.tif.mortality.tab'], ['MAX_12072015 Position 4-1.tif.mortality.tab', 'MAX_12072015 Position 8-1.tif.mortality.tab', 'MAX_12072015 Position 9-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 52.44932   sv2= 0.1175223   df= 14.1145   lambda= 446.2925
# phi= 52.19419   sv2= 0.009052848   df= 6.105073   lambda= 5765.499
# phi= 52.82233   sv2= 0.003086961   df= 3.609159   lambda= 17111.44
# Iterations: relative error in phi-hat = 1e-04
# phi= 469.5838   sv2= 0.1327845   df= 12.34576   lambda= 3536.435
# phi= 514.3542   sv2= 0.004757464   df= 3.548   lambda= 108115.2
# Iterations: relative error in phi-hat = 1e-04
# phi= 95.42209   sv2= 0.0815075   df= 6.871232   lambda= 1170.715
# phi= 128.3469   sv2= 0.01239483   df= 2.948834   lambda= 10354.88
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_mortality_dataframe_cluster2.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfL/CR-TA_yjfL-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 216.5617   sv2= 0.1853948   df= 15.24045   lambda= 1168.111
# phi= 227.4973   sv2= 0.007076273   df= 5.364517   lambda= 32149.31
# Iterations: relative error in phi-hat = 1e-04
# phi= 469.5838   sv2= 0.1327845   df= 12.34576   lambda= 3536.435
# phi= 514.3542   sv2= 0.004757464   df= 3.548   lambda= 108115.2
# Iterations: relative error in phi-hat = 1e-04
# phi= 95.42209   sv2= 0.0815075   df= 6.871232   lambda= 1170.715
# phi= 128.3469   sv2= 0.01239483   df= 2.948834   lambda= 10354.88
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  107.282709  105.907708  108.658396  0.000072, 1:                  est        L95%        U95%       var
# lifespan  112.830989  111.452913  114.212416  0.000138, 2:                est        L95%        U95%       var
# lifespan  126.6691  125.291342  128.049188  0.002312}
