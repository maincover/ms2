# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/TA_yfbM-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/TA_yfbM-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.75016   sv2= 0.1724562   df= 13.47248   lambda= 282.6815
# phi= 52.87   sv2= 0.03092754   df= 6.528205   lambda= 1709.48
# phi= 57.03694   sv2= 0.0178727   df= 4.577634   lambda= 3191.289
# phi= 59.59746   sv2= 0.01331155   df= 4.083514   lambda= 4477.125
# phi= 61.28147   sv2= 0.01090609   df= 3.84288   lambda= 5619.016
# phi= 62.51167   sv2= 0.009385691   df= 3.690028   lambda= 6660.316
# phi= 63.47492   sv2= 0.008318504   df= 3.579544   lambda= 7630.57
# phi= 64.26626   sv2= 0.007516348   df= 3.493339   lambda= 8550.197
# phi= 64.93947   sv2= 0.006883676   df= 3.422594   lambda= 9433.836
# phi= 65.52754   sv2= 0.006366618   df= 3.362419   lambda= 10292.36
# save file prefixed name is : TA_yfbM-1_df_relative_timegrid-vs-TA_yfbM-1_timeseries_dataframe
# biName is :  TA_yfbM-1_df_relative_timegrid-vs-TA_yfbM-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yfbM/run-MD
# No error in flxsrv_fit
# TA_yfbM-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yfbM/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yfbM/run-MD
# TA_yfbM-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.75016   sv2= 0.1724562   df= 13.47248   lambda= 282.6815
# phi= 52.87   sv2= 0.03092754   df= 6.528205   lambda= 1709.48
# phi= 57.03694   sv2= 0.0178727   df= 4.577634   lambda= 3191.289
# phi= 59.59746   sv2= 0.01331155   df= 4.083514   lambda= 4477.125
# phi= 61.28147   sv2= 0.01090609   df= 3.84288   lambda= 5619.016
# phi= 62.51167   sv2= 0.009385691   df= 3.690028   lambda= 6660.316
# phi= 63.47492   sv2= 0.008318504   df= 3.579544   lambda= 7630.57
# phi= 64.26626   sv2= 0.007516348   df= 3.493339   lambda= 8550.197
# phi= 64.93947   sv2= 0.006883676   df= 3.422594   lambda= 9433.836
# phi= 65.52754   sv2= 0.006366618   df= 3.362419   lambda= 10292.36
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yfbM/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yfbM-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yfbM-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/MD-TA_yfbM-1_df_relative_timegrid-vs-TA_yfbM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yfbM-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=10041.921670)
#                  est          L95%          U95%            se
# rate    2.277568e-01  1.842460e-01  2.815428e-01  2.463610e-02
# beta    3.100469e+10  2.355702e+08  4.080698e+12  7.719495e+10
# s       2.753411e-01  2.077475e-01  3.649272e-01  3.957219e-02
# lambda  1.547320e-03  1.303879e-03  1.836213e-03  1.351410e-04
#                  est        L95%        U95%       var
# lifespan  112.452565  112.110027  113.588144  0.000207
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/MD-TA_yfbM-1_df_relative_timegrid-vs-TA_yfbM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yfbM-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yfbM/run-MD
