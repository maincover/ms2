# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/TA_yfbM-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/TA_yfbM-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/TA_yfbM-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM']
#
# out_name_s  ['TA_yfbM-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/TA_yfbM-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/TA_yfbM-1_analysis_metadata.pickle
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 106-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 107-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 108-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 109-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 116-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 118-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 147-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 10-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 107-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 108-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 109-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 116-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 118-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 147-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 106-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 108-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 109-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 116-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 118-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 147-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 107-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 109-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 116-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 118-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 147-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 108-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 116-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 118-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 147-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 109-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 116-1.tif.mortality.tab ------ MAX_28062016 Position 118-1.tif.mortality.tab
# MAX_28062016 Position 116-1.tif.mortality.tab ------ MAX_28062016 Position 147-1.tif.mortality.tab
# MAX_28062016 Position 116-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 116-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 116-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 116-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 116-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 118-1.tif.mortality.tab ------ MAX_28062016 Position 147-1.tif.mortality.tab
# MAX_28062016 Position 118-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 118-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 118-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 118-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 118-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 147-1.tif.mortality.tab ------ MAX_28062016 Position 148-1.tif.mortality.tab
# MAX_28062016 Position 147-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 147-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 147-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 147-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 148-1.tif.mortality.tab ------ MAX_28062016 Position 150-1.tif.mortality.tab
# MAX_28062016 Position 148-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 148-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 148-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 150-1.tif.mortality.tab ------ MAX_28062016 Position 151-1.tif.mortality.tab
# MAX_28062016 Position 150-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 150-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 151-1.tif.mortality.tab ------ MAX_28062016 Position 152-1.tif.mortality.tab
# MAX_28062016 Position 151-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# MAX_28062016 Position 152-1.tif.mortality.tab ------ MAX_28062016 Position 154-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_dentrogram-all-files.eps
# [['MAX_28062016 Position 10-1.tif.mortality.tab', 'MAX_28062016 Position 106-1.tif.mortality.tab', 'MAX_28062016 Position 107-1.tif.mortality.tab', 'MAX_28062016 Position 108-1.tif.mortality.tab', 'MAX_28062016 Position 109-1.tif.mortality.tab', 'MAX_28062016 Position 116-1.tif.mortality.tab', 'MAX_28062016 Position 118-1.tif.mortality.tab', 'MAX_28062016 Position 148-1.tif.mortality.tab', 'MAX_28062016 Position 150-1.tif.mortality.tab', 'MAX_28062016 Position 151-1.tif.mortality.tab', 'MAX_28062016 Position 152-1.tif.mortality.tab', 'MAX_28062016 Position 154-1.tif.mortality.tab'], ['MAX_28062016 Position 147-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.20657   sv2= 0.1749537   df= 13.4062   lambda= 269.8232
# phi= 51.14519   sv2= 0.03120687   df= 6.564826   lambda= 1638.908
# phi= 55.02688   sv2= 0.01799857   df= 4.59761   lambda= 3057.292
# phi= 57.43768   sv2= 0.01347894   df= 4.101364   lambda= 4261.29
# phi= 59.0157   sv2= 0.01111814   df= 3.86397   lambda= 5308.055
# phi= 60.1627   sv2= 0.009636143   df= 3.715154   lambda= 6243.443
# phi= 61.05615   sv2= 0.008601635   df= 3.608833   lambda= 7098.203
# phi= 61.78627   sv2= 0.007827631   df= 3.526765   lambda= 7893.354
# phi= 62.40417   sv2= 0.007219513   df= 3.460088   lambda= 8643.82
# phi= 62.94124   sv2= 0.006724064   df= 3.4039   lambda= 9360.595
# phi= 63.41793   sv2= 0.006308953   df= 3.355238   lambda= 10052.05
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yfbM/CR-TA_yfbM-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.75016   sv2= 0.1724562   df= 13.47248   lambda= 282.6815
# phi= 52.87   sv2= 0.03092754   df= 6.528205   lambda= 1709.48
# phi= 57.03694   sv2= 0.0178727   df= 4.577634   lambda= 3191.289
# phi= 59.59746   sv2= 0.01331155   df= 4.083514   lambda= 4477.125
# phi= 61.28147   sv2= 0.01090609   df= 3.84288   lambda= 5619.016
# phi= 62.51167   sv2= 0.009385691   df= 3.690028   lambda= 6660.316
# phi= 63.47492   sv2= 0.008318504   df= 3.579544   lambda= 7630.57
# phi= 64.26626   sv2= 0.007516348   df= 3.493339   lambda= 8550.197
# phi= 64.93947   sv2= 0.006883676   df= 3.422594   lambda= 9433.836
# phi= 65.52754   sv2= 0.006366618   df= 3.362419   lambda= 10292.36
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  112.452565  112.110027  113.588144  0.000207}
