# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/napC'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/napC/TA_napC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/napC/TA_napC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/napC
# Iterations: relative error in phi-hat = 1e-04
# phi= 64.00204   sv2= 0.4460936   df= 15.59628   lambda= 143.4722
# phi= 68.11043   sv2= 0.06309778   df= 8.743939   lambda= 1079.443
# phi= 72.20074   sv2= 0.01376555   df= 5.735295   lambda= 5245.032
# phi= 74.93851   sv2= 0.00422081   df= 4.208381   lambda= 17754.53
# save file prefixed name is : TA_napC-1_df_relative_timegrid-vs-TA_napC-1_timeseries_dataframe
# biName is :  TA_napC-1_df_relative_timegrid-vs-TA_napC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/napC/run-MD
# No error in flxsrv_fit
# TA_napC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/napC/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/napC/run-MD
# TA_napC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 64.00204   sv2= 0.4460936   df= 15.59628   lambda= 143.4722
# phi= 68.11043   sv2= 0.06309778   df= 8.743939   lambda= 1079.443
# phi= 72.20074   sv2= 0.01376555   df= 5.735295   lambda= 5245.032
# phi= 74.93851   sv2= 0.00422081   df= 4.208381   lambda= 17754.53
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/napC/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_napC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_napC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/napC/MD-TA_napC-1_df_relative_timegrid-vs-TA_napC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_napC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=17040.443838)
#                  est          L95%          U95%            se
# rate    1.384620e-01  1.169709e-01  1.639017e-01  1.191578e-02
# beta    2.725724e+07  2.048542e+06  3.626760e+08  3.599399e+07
# s       5.437661e-01  4.031406e-01  7.334453e-01  8.301847e-02
# lambda  3.052449e-03  2.774151e-03  3.358665e-03  1.488864e-04
#                 est       L95%        U95%       var
# lifespan  123.68903  122.69004  123.837593  0.000128
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/napC/MD-TA_napC-1_df_relative_timegrid-vs-TA_napC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_napC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/napC/run-MD
