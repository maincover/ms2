# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/TA_yiaW-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/TA_yiaW-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW
# Iterations: relative error in phi-hat = 1e-04
# phi= 28.47552   sv2= 0.1228642   df= 12.77273   lambda= 231.7642
# phi= 30.67652   sv2= 0.01602023   df= 6.406587   lambda= 1914.862
# phi= 32.30474   sv2= 0.005726354   df= 4.190162   lambda= 5641.416
# phi= 33.36305   sv2= 0.00280831   df= 3.420402   lambda= 11880.12
# save file prefixed name is : TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe
# biName is :  TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yiaW/run-MD
# No error in flxsrv_fit
# TA_yiaW-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yiaW/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yiaW/run-MD
# TA_yiaW-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 28.47552   sv2= 0.1228642   df= 12.77273   lambda= 231.7642
# phi= 30.67652   sv2= 0.01602023   df= 6.406587   lambda= 1914.862
# phi= 32.30474   sv2= 0.005726354   df= 4.190162   lambda= 5641.416
# phi= 33.36305   sv2= 0.00280831   df= 3.420402   lambda= 11880.12
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yiaW/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yiaW-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yiaW-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/MD-TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yiaW-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7681.272435)
#                   est          L95%          U95%             se
# rate         0.142134      0.113671  1.777242e-01       0.016205
# beta    325337.234428  28949.674909  3.656149e+06  401583.628929
# s            0.283429      0.196781  4.082314e-01       0.052764
# lambda       0.000891      0.000679  1.168638e-03       0.000123
#                  est        L95%        U95%       var
# lifespan  103.867786  103.600955  104.805085  0.000235
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/MD-TA_yiaW-1_df_relative_timegrid-vs-TA_yiaW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yiaW-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yiaW/run-MD
