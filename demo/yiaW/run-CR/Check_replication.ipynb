# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/TA_yiaW-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/TA_yiaW-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/TA_yiaW-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW']
#
# out_name_s  ['TA_yiaW-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/TA_yiaW-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/TA_yiaW-1_analysis_metadata.pickle
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 104-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 105-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 110-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 128-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 55-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 56-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 80-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 103-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 105-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 110-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 128-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 55-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 56-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 80-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 104-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 110-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 128-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 55-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 56-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 80-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 105-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 128-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 55-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 56-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 80-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 110-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 128-1.tif.mortality.tab ------ MAX_07072016 Position 55-1.tif.mortality.tab
# MAX_07072016 Position 128-1.tif.mortality.tab ------ MAX_07072016 Position 56-1.tif.mortality.tab
# MAX_07072016 Position 128-1.tif.mortality.tab ------ MAX_07072016 Position 80-1.tif.mortality.tab
# MAX_07072016 Position 128-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 128-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 128-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 128-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 55-1.tif.mortality.tab ------ MAX_07072016 Position 56-1.tif.mortality.tab
# MAX_07072016 Position 55-1.tif.mortality.tab ------ MAX_07072016 Position 80-1.tif.mortality.tab
# MAX_07072016 Position 55-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 55-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 55-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 55-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 56-1.tif.mortality.tab ------ MAX_07072016 Position 80-1.tif.mortality.tab
# MAX_07072016 Position 56-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 56-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 56-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 56-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 80-1.tif.mortality.tab ------ MAX_07072016 Position 89-1.tif.mortality.tab
# MAX_07072016 Position 80-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 80-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 80-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 89-1.tif.mortality.tab ------ MAX_07072016 Position 90-1.tif.mortality.tab
# MAX_07072016 Position 89-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 89-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 90-1.tif.mortality.tab ------ MAX_07072016 Position 91-1.tif.mortality.tab
# MAX_07072016 Position 90-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# MAX_07072016 Position 91-1.tif.mortality.tab ------ MAX_07072016 Position 92-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_dentrogram-all-files.eps
# [['MAX_07072016 Position 55-1.tif.mortality.tab', 'MAX_07072016 Position 56-1.tif.mortality.tab'], ['MAX_07072016 Position 110-1.tif.mortality.tab', 'MAX_07072016 Position 128-1.tif.mortality.tab', 'MAX_07072016 Position 89-1.tif.mortality.tab', 'MAX_07072016 Position 90-1.tif.mortality.tab'], ['MAX_07072016 Position 104-1.tif.mortality.tab', 'MAX_07072016 Position 105-1.tif.mortality.tab', 'MAX_07072016 Position 80-1.tif.mortality.tab', 'MAX_07072016 Position 91-1.tif.mortality.tab', 'MAX_07072016 Position 92-1.tif.mortality.tab'], ['MAX_07072016 Position 103-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 56.26246   sv2= 0.09110648   df= 10.72529   lambda= 617.5462
# phi= 53.47709   sv2= 0.01067303   df= 4.586069   lambda= 5010.489
# phi= 62.63943   sv2= 0.002791357   df= 3.145383   lambda= 22440.49
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.21634   sv2= 0.06411331   df= 9.70577   lambda= 346.5168
# phi= 25.50537   sv2= 0.00522549   df= 4.711343   lambda= 4880.952
# phi= 28.69388   sv2= 0.0008355297   df= 2.904362   lambda= 34342.14
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yiaW/CR-TA_yiaW-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 56.26246   sv2= 0.09110648   df= 10.72529   lambda= 617.5462
# phi= 53.47709   sv2= 0.01067303   df= 4.586069   lambda= 5010.489
# phi= 62.63943   sv2= 0.002791357   df= 3.145383   lambda= 22440.49
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.21634   sv2= 0.06411331   df= 9.70577   lambda= 346.5168
# phi= 25.50537   sv2= 0.00522549   df= 4.711343   lambda= 4880.952
# phi= 28.69388   sv2= 0.0008355297   df= 2.904362   lambda= 34342.14
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%       U95%       var
# lifespan  107.595638  105.179835  108.80204  0.000437, 1:                 est       L95%        U95%       var
# lifespan  96.928924  92.983866  100.537443  0.001001}
