# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/app/src/ms2/dataset/MS 2 Github data part 10/yiaW'
path_ref_folder ='/app/src/ms2/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /app/src/ms2/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /app/src/ms2/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /app/src/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /app/src/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/TA_yiaW-1_mortality_dataframe.pickle']]
# meta_paths:  [['/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/TA_yiaW-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/TA_yiaW-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/app/src/ms2/dataset/MS 2 Github data part 10/yiaW']
#
# out_name_s  ['TA_yiaW-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/TA_yiaW-1_mortality_dataframe.pickle
# path meta  /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/TA_yiaW-1_analysis_metadata.pickle
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 217-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 218-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 219-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 220-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 221-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 222-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 223-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 216-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 218-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 219-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 220-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 221-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 222-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 223-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 217-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 219-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 220-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 221-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 222-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 223-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 218-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 220-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 221-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 222-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 223-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 219-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 221-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 222-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 223-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 220-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 222-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 223-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 221-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 223-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 222-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 224-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 223-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 225-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 224-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 226-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 225-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 226-1.tif.mortality.tab ------ MAX_18112018 Position 228-1.tif.mortality.tab
# MAX_18112018 Position 226-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 226-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 226-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 226-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 226-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 226-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 228-1.tif.mortality.tab ------ MAX_18112018 Position 229-1.tif.mortality.tab
# MAX_18112018 Position 228-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 228-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 228-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 228-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 228-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 229-1.tif.mortality.tab ------ MAX_18112018 Position 230-1.tif.mortality.tab
# MAX_18112018 Position 229-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 229-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 229-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 229-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 230-1.tif.mortality.tab ------ MAX_18112018 Position 231-1.tif.mortality.tab
# MAX_18112018 Position 230-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 230-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 230-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 231-1.tif.mortality.tab ------ MAX_18112018 Position 233-1.tif.mortality.tab
# MAX_18112018 Position 231-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 231-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 233-1.tif.mortality.tab ------ MAX_18112018 Position 234-1.tif.mortality.tab
# MAX_18112018 Position 233-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# MAX_18112018 Position 234-1.tif.mortality.tab ------ MAX_18112018 Position 235-1.tif.mortality.tab
# dendrogram will be saved to :  /app/src/ms2/dataset/MS 2 Github data part 10/yiaW
# save eps to :  /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_dentrogram-all-files.eps
# [['MAX_18112018 Position 220-1.tif.mortality.tab', 'MAX_18112018 Position 221-1.tif.mortality.tab', 'MAX_18112018 Position 224-1.tif.mortality.tab', 'MAX_18112018 Position 225-1.tif.mortality.tab'], ['MAX_18112018 Position 217-1.tif.mortality.tab', 'MAX_18112018 Position 218-1.tif.mortality.tab', 'MAX_18112018 Position 222-1.tif.mortality.tab', 'MAX_18112018 Position 223-1.tif.mortality.tab', 'MAX_18112018 Position 226-1.tif.mortality.tab', 'MAX_18112018 Position 230-1.tif.mortality.tab', 'MAX_18112018 Position 231-1.tif.mortality.tab'], ['MAX_18112018 Position 216-1.tif.mortality.tab', 'MAX_18112018 Position 234-1.tif.mortality.tab', 'MAX_18112018 Position 235-1.tif.mortality.tab'], ['MAX_18112018 Position 228-1.tif.mortality.tab', 'MAX_18112018 Position 229-1.tif.mortality.tab', 'MAX_18112018 Position 233-1.tif.mortality.tab'], ['MAX_18112018 Position 219-1.tif.mortality.tab']]
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_colomap_all_files_cluster0.png
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_mortality_orig_dataframe_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_relative_orig_timegrid_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_colomap_all_files_cluster1.png
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_mortality_orig_dataframe_cluster1.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_relative_orig_timegrid_cluster1.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_colomap_all_files_cluster2.png
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_mortality_orig_dataframe_cluster2.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_relative_orig_timegrid_cluster2.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_colomap_all_files_cluster3.png
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_mortality_orig_dataframe_cluster3.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 92.61954   sv2= 0.1552218   df= 11.30216   lambda= 596.6916
# phi= 99.06069   sv2= 0.01985721   df= 4.726685   lambda= 4988.652
# phi= 105.6385   sv2= 0.00524873   df= 3.04823   lambda= 20126.48
# Iterations: relative error in phi-hat = 1e-04
# phi= 495.1322   sv2= 0.1935128   df= 9.804217   lambda= 2558.653
# phi= 569.8891   sv2= 0.01040115   df= 3.037742   lambda= 54790.95
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.00414   sv2= 0.186138   df= 10.24903   lambda= 445.9278
# phi= 91.86471   sv2= 0.007671793   df= 4.678617   lambda= 11974.35
# Iterations: relative error in phi-hat = 1e-04
# phi= 122.0807   sv2= 0.09467389   df= 9.477607   lambda= 1289.487
# phi= 115.4628   sv2= 0.0231449   df= 3.523628   lambda= 4988.694
# phi= 121.5429   sv2= 0.008144031   df= 2.653401   lambda= 14924.17
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_relative_timegrid_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_timeseries_dataframe_cluster0.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_cluster0_tabs.txt
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_relative_timegrid_cluster1.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_timeseries_dataframe_cluster1.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/yiaW/CR-TA_yiaW-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 144.0645   sv2= 0.1471709   df= 12.55449   lambda= 978.8925
# phi= 144.0919   sv2= 0.0230975   df= 4.730515   lambda= 6238.42
# phi= 146.5318   sv2= 0.007943458   df= 3.204781   lambda= 18446.85
# Iterations: relative error in phi-hat = 1e-04
# phi= 277.9072   sv2= 0.1342151   df= 11.55101   lambda= 2070.611
# phi= 341.3797   sv2= 0.009789682   df= 3.802769   lambda= 34871.38
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  95.629375  94.474283  96.804259  0.000101, 1:                 est       L95%       U95%       var
# lifespan  96.884331  96.880036  98.040654  0.000123}
