# %% [markdown]
# # TAB Analyzer Process (only file filter listed .tab files (existed also in pth) )
# TabPostAnalyzer.py is should be in the grand parent folder
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from TabPostAnalyzer import TabPostAnalyzer
pth='/app/src/ms2/dataset/MS 2 Github data part 10/yiaW'
fFn='/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/report/finalFiles.txt'
partial=1
pA = TabPostAnalyzer(pth,filterFile=fFn, group=partial)
# Out:
# part,  1
# ['/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 216-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 217-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 218-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 219-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 220-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 221-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 222-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 223-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 224-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 225-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 226-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 228-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 229-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 230-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 231-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 233-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 234-1.tif.mortality.tab', '/app/src/ms2/dataset/MS 2 Github data part 10/yiaW/MAX_18112018 Position 235-1.tif.mortality.tab']
# Total cell number :  5708
# filtered file/all file:  18 / 18

# %%
step0PlotOriginalFiles = True
step1TvReg = False
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
#             Step 0: Before we process any data, preview the PI profiles in
#             each tab files. No need for any parameters, could always run directly.
#             self.checkTimeJump() could be used to check time indeces of each files,
#             but is only triggered if self.debug is True.
#
#             Use self.viewCellTraces(fileName,start,end,pn=5) to check cell traces

# %%
step0PlotOriginalFiles = False
step1TvReg = True
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# autoDefineAlcohol is True, the alcohol index will be selected as: 105
# Alcohol time index is :  91
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (89, 103.93408100308642, 102.7435270261438, -0.06078699187291747)
# [ 1 ]  (84, 98.01823901851853, 96.840038595679, 0.04699126698366721)
# [ 2 ]  (77, 89.81292630718954, 88.64357375, 0.04585691230927652)
# [ 3 ]  (86, 100.37718246732025, 99.1832143627451, -0.04440705264396147)
# [ 4 ]  (87, 101.57113096296297, 100.37718246732025, 0.039094550261047634)
# [ 5 ]  (82, 95.65593777777778, 94.4763097376543, -0.03090681783453455)
# [ 6 ]  (90, 105.11223420370371, 103.93408100308642, -0.028146815932482534)
# [ 7 ]  (67, 78.07855240740741, 76.91702922839507, -0.027242264754330368)
# [ 8 ]  (78, 90.98532938271606, 89.81292630718954, 0.020917356827530348)
# [ 9 ]  (69, 80.4404061111111, 79.26314531045752, 0.017794924646149294)
#
#             Step1: Use TVReg to calculate illumination levels, which are used
#             to estimate alcohol Time and then which cell to included in the end.
#             This step requires a set of data visualisation and report, so that
#             the user can verify the automatically chosen alcohol time is correct,
#             and the correct cells are included.
#
#             The first visualisations are the PI profiles for each file and
#             their illumination levels. The second visualisation is all illuminations
#             plotted into the same figure. The third visualisation is the combined
#             PI profile and illumination.
#
#             We also report the number of included or excluded cells in each file.
#
#             The user SHOULD make sure alcohol time is correct, or manually set
#             it according to suggestions.

# %%
pA.denoisePlotAll(asp=0.01,onlyPlot=True)
aIndex=120
pA.defineAlcoholTime(more=20,aIndex=aIndex)
# Out:
# Alcohol time index is :  91
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (89, 103.93408100308642, 102.7435270261438, -0.06078699187291747)
# [ 1 ]  (84, 98.01823901851853, 96.840038595679, 0.04699126698366721)
# [ 2 ]  (77, 89.81292630718954, 88.64357375, 0.04585691230927652)
# [ 3 ]  (86, 100.37718246732025, 99.1832143627451, -0.04440705264396147)
# [ 4 ]  (87, 101.57113096296297, 100.37718246732025, 0.039094550261047634)
# [ 5 ]  (82, 95.65593777777778, 94.4763097376543, -0.03090681783453455)
# [ 6 ]  (90, 105.11223420370371, 103.93408100308642, -0.028146815932482534)
# [ 7 ]  (67, 78.07855240740741, 76.91702922839507, -0.027242264754330368)
# [ 8 ]  (78, 90.98532938271606, 89.81292630718954, 0.020917356827530348)
# [ 9 ]  (69, 80.4404061111111, 79.26314531045752, 0.017794924646149294)
# [ 10 ]  (70, 81.632026748366, 80.4404061111111, 0.01668546892729617)
# [ 11 ]  (71, 82.80644996732025, 81.632026748366, 0.01631908470355311)
# [ 12 ]  (65, 75.74563081790123, 74.56470553921568, 0.013863897149866697)
# [ 13 ]  (81, 94.4763097376543, 93.31446228395062, -0.012950596391758976)
# [ 14 ]  (68, 79.26314531045752, 78.07855240740741, 0.01186057527276329)
# [ 15 ]  (66, 76.91702922839507, 75.74563081790123, -0.011686645715661918)
# [ 16 ]  (83, 96.840038595679, 95.65593777777778, -0.011389594624152762)
# [ 17 ]  (51, 59.31312068627451, 58.13739180555555, -0.011329185909382217)
# [ 18 ]  (62, 72.21323787037036, 71.02854608024691, -0.011123748942371368)
# [ 19 ]  (56, 65.18547097222222, 64.00772415123457, -0.010488450954083073)

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# MAX_18112018 Position 220-1.tif.mortality.tab 325 347
# MAX_18112018 Position 217-1.tif.mortality.tab 339 376
# MAX_18112018 Position 216-1.tif.mortality.tab 323 342
# MAX_18112018 Position 228-1.tif.mortality.tab 298 339
# MAX_18112018 Position 221-1.tif.mortality.tab 98 108
# MAX_18112018 Position 223-1.tif.mortality.tab 238 260
# MAX_18112018 Position 233-1.tif.mortality.tab 521 602
# MAX_18112018 Position 222-1.tif.mortality.tab 275 340
# MAX_18112018 Position 231-1.tif.mortality.tab 89 104
# MAX_18112018 Position 225-1.tif.mortality.tab 110 144
# MAX_18112018 Position 229-1.tif.mortality.tab 465 566
# MAX_18112018 Position 234-1.tif.mortality.tab 482 578
# MAX_18112018 Position 224-1.tif.mortality.tab 211 218
# MAX_18112018 Position 218-1.tif.mortality.tab 422 477
# MAX_18112018 Position 226-1.tif.mortality.tab 72 87
# MAX_18112018 Position 230-1.tif.mortality.tab 67 70
# MAX_18112018 Position 235-1.tif.mortality.tab 174 196
# MAX_18112018 Position 219-1.tif.mortality.tab 520 554
# 442
# MAX_18112018 Position 220-1.tif.mortality.tab 347 347
# MAX_18112018 Position 217-1.tif.mortality.tab 366 376
# MAX_18112018 Position 216-1.tif.mortality.tab 336 342
# MAX_18112018 Position 228-1.tif.mortality.tab 309 339
# MAX_18112018 Position 221-1.tif.mortality.tab 107 108
# MAX_18112018 Position 223-1.tif.mortality.tab 259 260
# MAX_18112018 Position 233-1.tif.mortality.tab 576 602
# MAX_18112018 Position 222-1.tif.mortality.tab 331 340
# MAX_18112018 Position 231-1.tif.mortality.tab 100 104
# MAX_18112018 Position 225-1.tif.mortality.tab 135 144
# MAX_18112018 Position 229-1.tif.mortality.tab 520 566
# MAX_18112018 Position 234-1.tif.mortality.tab 501 578
# MAX_18112018 Position 224-1.tif.mortality.tab 214 218
# MAX_18112018 Position 218-1.tif.mortality.tab 453 477
# MAX_18112018 Position 226-1.tif.mortality.tab 84 87
# MAX_18112018 Position 230-1.tif.mortality.tab 69 70
# MAX_18112018 Position 235-1.tif.mortality.tab 183 196
# MAX_18112018 Position 219-1.tif.mortality.tab 549 554
#
#             Step2: After the user have reviewed and set the alcohol time,
#             re-calculate cells to include. Then again use included data to
#             re-estimate illumination, estimate lifespan, and output data
#             in the form of pickles.

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
# Out:
# length of df is:  5439
# length of relative_time_grid is:  1583
