# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/TA_gnsA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/TA_gnsA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA
# Iterations: relative error in phi-hat = 1e-04
# phi= 185.6488   sv2= 0.3555187   df= 19.3506   lambda= 522.1915
# phi= 189.1319   sv2= 0.04495032   df= 8.744714   lambda= 4207.576
# phi= 187.2248   sv2= 0.0226088   df= 5.691447   lambda= 8281.059
# phi= 188.6815   sv2= 0.01460714   df= 4.97626   lambda= 12917.07
# save file prefixed name is : TA_gnsA-1_df_relative_timegrid-vs-TA_gnsA-1_timeseries_dataframe
# biName is :  TA_gnsA-1_df_relative_timegrid-vs-TA_gnsA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/gnsA/run-MD
# No error in flxsrv_fit
# TA_gnsA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/gnsA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gnsA/run-MD
# TA_gnsA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 185.6488   sv2= 0.3555187   df= 19.3506   lambda= 522.1915
# phi= 189.1319   sv2= 0.04495032   df= 8.744714   lambda= 4207.576
# phi= 187.2248   sv2= 0.0226088   df= 5.691447   lambda= 8281.059
# phi= 188.6815   sv2= 0.01460714   df= 4.97626   lambda= 12917.07
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gnsA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gnsA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_gnsA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/MD-TA_gnsA-1_df_relative_timegrid-vs-TA_gnsA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_gnsA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=79619.593405)
#                  est           L95%          U95%             se
# rate    1.176914e-01       0.110775  1.250400e-01       0.003637
# beta    1.577297e+06  837593.850271  2.970252e+06  509358.984880
# s       1.060860e+00       0.896755  1.254996e+00       0.090961
# lambda  1.019223e-03       0.000946  1.097562e-03       0.000039
#                  est        L95%        U95%       var
# lifespan  117.818083  117.778944  117.825767  0.000027
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/MD-TA_gnsA-1_df_relative_timegrid-vs-TA_gnsA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gnsA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/gnsA/run-MD
