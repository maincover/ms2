# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/TA_gnsA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/TA_gnsA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/TA_gnsA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA']
#
# out_name_s  ['TA_gnsA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/TA_gnsA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/TA_gnsA-1_analysis_metadata.pickle
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 29-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 33-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 34-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 35-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 36-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 37-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 38-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 28-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 33-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 34-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 35-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 36-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 37-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 38-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 29-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 33-1.tif.mortality.tab ------ MAX_17112015 Position 34-1.tif.mortality.tab
# MAX_17112015 Position 33-1.tif.mortality.tab ------ MAX_17112015 Position 35-1.tif.mortality.tab
# MAX_17112015 Position 33-1.tif.mortality.tab ------ MAX_17112015 Position 36-1.tif.mortality.tab
# MAX_17112015 Position 33-1.tif.mortality.tab ------ MAX_17112015 Position 37-1.tif.mortality.tab
# MAX_17112015 Position 33-1.tif.mortality.tab ------ MAX_17112015 Position 38-1.tif.mortality.tab
# MAX_17112015 Position 33-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 33-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 34-1.tif.mortality.tab ------ MAX_17112015 Position 35-1.tif.mortality.tab
# MAX_17112015 Position 34-1.tif.mortality.tab ------ MAX_17112015 Position 36-1.tif.mortality.tab
# MAX_17112015 Position 34-1.tif.mortality.tab ------ MAX_17112015 Position 37-1.tif.mortality.tab
# MAX_17112015 Position 34-1.tif.mortality.tab ------ MAX_17112015 Position 38-1.tif.mortality.tab
# MAX_17112015 Position 34-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 34-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 35-1.tif.mortality.tab ------ MAX_17112015 Position 36-1.tif.mortality.tab
# MAX_17112015 Position 35-1.tif.mortality.tab ------ MAX_17112015 Position 37-1.tif.mortality.tab
# MAX_17112015 Position 35-1.tif.mortality.tab ------ MAX_17112015 Position 38-1.tif.mortality.tab
# MAX_17112015 Position 35-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 35-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 36-1.tif.mortality.tab ------ MAX_17112015 Position 37-1.tif.mortality.tab
# MAX_17112015 Position 36-1.tif.mortality.tab ------ MAX_17112015 Position 38-1.tif.mortality.tab
# MAX_17112015 Position 36-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 36-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 37-1.tif.mortality.tab ------ MAX_17112015 Position 38-1.tif.mortality.tab
# MAX_17112015 Position 37-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 37-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 38-1.tif.mortality.tab ------ MAX_17112015 Position 43-1.tif.mortality.tab
# MAX_17112015 Position 38-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# MAX_17112015 Position 43-1.tif.mortality.tab ------ MAX_17112015 Position 45-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_dentrogram-all-files.eps
# [['MAX_17112015 Position 35-1.tif.mortality.tab', 'MAX_17112015 Position 45-1.tif.mortality.tab'], ['MAX_17112015 Position 34-1.tif.mortality.tab'], ['MAX_17112015 Position 33-1.tif.mortality.tab'], ['MAX_17112015 Position 29-1.tif.mortality.tab'], ['MAX_17112015 Position 38-1.tif.mortality.tab'], ['MAX_17112015 Position 43-1.tif.mortality.tab'], ['MAX_17112015 Position 28-1.tif.mortality.tab'], ['MAX_17112015 Position 37-1.tif.mortality.tab'], ['MAX_17112015 Position 36-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 67.50121   sv2= 0.1314198   df= 13.84226   lambda= 513.6304
# phi= 70.908   sv2= 0.02213883   df= 6.066631   lambda= 3202.879
# phi= 75.64728   sv2= 0.01173366   df= 4.184986   lambda= 6447.035
# phi= 78.19794   sv2= 0.007892145   df= 3.64396   lambda= 9908.325
# phi= 80.0277   sv2= 0.005777038   df= 3.338003   lambda= 13852.72
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_mortality_dataframe_cluster0.pickle
# 9 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gnsA/CR-TA_gnsA-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 67.50121   sv2= 0.1314198   df= 13.84226   lambda= 513.6304
# phi= 70.908   sv2= 0.02213883   df= 6.066631   lambda= 3202.879
# phi= 75.64728   sv2= 0.01173366   df= 4.184986   lambda= 6447.035
# phi= 78.19794   sv2= 0.007892145   df= 3.64396   lambda= 9908.325
# phi= 80.0277   sv2= 0.005777038   df= 3.338003   lambda= 13852.72
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  114.825556  113.826028  115.826185  0.000128}
