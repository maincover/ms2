# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/TA_gltL-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/TA_gltL-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/TA_gltL-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL']
#
# out_name_s  ['TA_gltL-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/TA_gltL-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/TA_gltL-1_analysis_metadata.pickle
# MAX_05072014 Position 32-1.tif.mortality.tab ------ MAX_05072014 Position 35-1.tif.mortality.tab
# MAX_05072014 Position 32-1.tif.mortality.tab ------ MAX_05072014 Position 41-1.tif.mortality.tab
# MAX_05072014 Position 32-1.tif.mortality.tab ------ MAX_05072014 Position 46-1.tif.mortality.tab
# MAX_05072014 Position 32-1.tif.mortality.tab ------ MAX_05072014 Position 66-1.tif.mortality.tab
# MAX_05072014 Position 32-1.tif.mortality.tab ------ MAX_05072014 Position 68-1.tif.mortality.tab
# MAX_05072014 Position 35-1.tif.mortality.tab ------ MAX_05072014 Position 41-1.tif.mortality.tab
# MAX_05072014 Position 35-1.tif.mortality.tab ------ MAX_05072014 Position 46-1.tif.mortality.tab
# MAX_05072014 Position 35-1.tif.mortality.tab ------ MAX_05072014 Position 66-1.tif.mortality.tab
# MAX_05072014 Position 35-1.tif.mortality.tab ------ MAX_05072014 Position 68-1.tif.mortality.tab
# MAX_05072014 Position 41-1.tif.mortality.tab ------ MAX_05072014 Position 46-1.tif.mortality.tab
# MAX_05072014 Position 41-1.tif.mortality.tab ------ MAX_05072014 Position 66-1.tif.mortality.tab
# MAX_05072014 Position 41-1.tif.mortality.tab ------ MAX_05072014 Position 68-1.tif.mortality.tab
# MAX_05072014 Position 46-1.tif.mortality.tab ------ MAX_05072014 Position 66-1.tif.mortality.tab
# MAX_05072014 Position 46-1.tif.mortality.tab ------ MAX_05072014 Position 68-1.tif.mortality.tab
# MAX_05072014 Position 66-1.tif.mortality.tab ------ MAX_05072014 Position 68-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_dentrogram-all-files.eps
# [['MAX_05072014 Position 35-1.tif.mortality.tab', 'MAX_05072014 Position 68-1.tif.mortality.tab'], ['MAX_05072014 Position 32-1.tif.mortality.tab', 'MAX_05072014 Position 66-1.tif.mortality.tab'], ['MAX_05072014 Position 46-1.tif.mortality.tab'], ['MAX_05072014 Position 41-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 2.000387   sv2= 0.1247202   df= 11.12366   lambda= 16.03899
# phi= 2.074447   sv2= 0.08541604   df= 10.04887   lambda= 24.28638
# phi= 2.138735   sv2= 0.06142223   df= 9.189791   lambda= 34.82021
# phi= 2.193521   sv2= 0.04644998   df= 8.503605   lambda= 47.22329
# phi= 2.239118   sv2= 0.03693547   df= 7.964129   lambda= 60.62244
# phi= 2.276092   sv2= 0.03077969   df= 7.548464   lambda= 73.94785
# phi= 2.305328   sv2= 0.0267239   df= 7.234264   lambda= 86.26464
# phi= 2.327949   sv2= 0.02400355   df= 7.000373   lambda= 96.98356
# phi= 2.345155   sv2= 0.0221484   df= 6.828105   lambda= 105.8837
# phi= 2.358077   sv2= 0.02086481   df= 6.702044   lambda= 113.0169
# phi= 2.367693   sv2= 0.01996595   df= 6.610119   lambda= 118.5866
# phi= 2.374804   sv2= 0.0193304   df= 6.543199   lambda= 122.8533
# phi= 2.380039   sv2= 0.01887767   df= 6.494513   lambda= 126.077
# phi= 2.383881   sv2= 0.01855331   df= 6.459099   lambda= 128.4881
# phi= 2.386694   sv2= 0.01831994   df= 6.433336   lambda= 130.2785
# phi= 2.388751   sv2= 0.01815148   df= 6.414591   lambda= 131.6009
# phi= 2.390253   sv2= 0.0180296   df= 6.40095   lambda= 132.5738
# phi= 2.391349   sv2= 0.01794126   df= 6.391021   lambda= 133.2877
# phi= 2.392149   sv2= 0.01787714   df= 6.383793   lambda= 133.8104
# phi= 2.392731   sv2= 0.01783057   df= 6.378531   lambda= 134.1926
# phi= 2.393156   sv2= 0.01779672   df= 6.3747   lambda= 134.4718
# phi= 2.393466   sv2= 0.0177721   df= 6.371911   lambda= 134.6755
# phi= 2.393691   sv2= 0.01775418   df= 6.369879   lambda= 134.8241
# phi= 2.393856   sv2= 0.01774115   df= 6.3684   lambda= 134.9324
# phi= 2.393975   sv2= 0.01773166   df= 6.367323   lambda= 135.0113
# phi= 2.394062   sv2= 0.01772475   df= 6.366539   lambda= 135.0689
# phi= 2.394126   sv2= 0.01771972   df= 6.365967   lambda= 135.1108
# phi= 2.394172   sv2= 0.01771606   df= 6.365551   lambda= 135.1413
# phi= 2.394206   sv2= 0.0177134   df= 6.365248   lambda= 135.1636
# phi= 2.39423   sv2= 0.01771145   df= 6.365028   lambda= 135.1798
# phi= 2.394248   sv2= 0.01771004   df= 6.364867   lambda= 135.1916
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.157694   sv2= 0.1529084   df= 11.2376   lambda= 20.65089
# phi= 3.290326   sv2= 0.08800798   df= 9.583336   lambda= 37.38668
# phi= 3.40204   sv2= 0.05335481   df= 8.41166   lambda= 63.76257
# phi= 3.489422   sv2= 0.03415174   df= 7.484874   lambda= 102.174
# phi= 3.547553   sv2= 0.02401704   df= 6.758893   lambda= 147.7098
# phi= 3.579412   sv2= 0.01904587   df= 6.247755   lambda= 187.9364
# phi= 3.594625   sv2= 0.01673277   df= 5.938795   lambda= 214.8255
# phi= 3.601536   sv2= 0.01568211   df= 5.775393   lambda= 229.659
# phi= 3.604653   sv2= 0.01520867   df= 5.695909   lambda= 237.013
# phi= 3.606056   sv2= 0.01499581   df= 5.658866   lambda= 240.471
# phi= 3.606688   sv2= 0.01490015   df= 5.641945   lambda= 242.0572
# phi= 3.606972   sv2= 0.01485717   df= 5.634285   lambda= 242.7766
# phi= 3.6071   sv2= 0.01483785   df= 5.630832   lambda= 243.1012
# phi= 3.607157   sv2= 0.01482918   df= 5.629279   lambda= 243.2473
# phi= 3.607183   sv2= 0.01482528   df= 5.62858   lambda= 243.313
# phi= 3.607195   sv2= 0.01482353   df= 5.628266   lambda= 243.3425
# phi= 3.6072   sv2= 0.01482274   df= 5.628125   lambda= 243.3558
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/CR-TA_gltL-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.42969   sv2= 0.1491653   df= 13.02543   lambda= 183.8879
# phi= 29.60709   sv2= 0.02091092   df= 6.870768   lambda= 1415.868
# phi= 30.75829   sv2= 0.006904038   df= 4.51836   lambda= 4455.116
# phi= 31.15089   sv2= 0.003938855   df= 3.645148   lambda= 7908.616
# phi= 31.4115   sv2= 0.002954015   df= 3.297799   lambda= 10633.49
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  108.174628  105.868101  112.155343  0.000412}
