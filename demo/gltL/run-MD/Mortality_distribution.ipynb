# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/TA_gltL-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/TA_gltL-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.79458   sv2= 0.1067548   df= 13.72287   lambda= 288.4609
# phi= 31.93525   sv2= 0.01012665   df= 6.266182   lambda= 3153.586
# phi= 32.40657   sv2= 0.004900409   df= 3.853023   lambda= 6613.033
# phi= 32.59668   sv2= 0.004226898   df= 3.376501   lambda= 7711.725
# phi= 32.65134   sv2= 0.004078898   df= 3.289487   lambda= 8004.942
# phi= 32.66568   sv2= 0.004041951   df= 3.268929   lambda= 8081.662
# phi= 32.66942   sv2= 0.004032439   df= 3.263709   lambda= 8101.654
# phi= 32.67039   sv2= 0.00402997   df= 3.262359   lambda= 8106.858
# phi= 32.67065   sv2= 0.004029328   df= 3.262008   lambda= 8108.213
# phi= 32.67071   sv2= 0.004029161   df= 3.261917   lambda= 8108.566
# save file prefixed name is : TA_gltL-1_df_relative_timegrid-vs-TA_gltL-1_timeseries_dataframe
# biName is :  TA_gltL-1_df_relative_timegrid-vs-TA_gltL-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/gltL/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_gltL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/gltL/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gltL/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_gltL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.79458   sv2= 0.1067548   df= 13.72287   lambda= 288.4609
# phi= 31.93525   sv2= 0.01012665   df= 6.266182   lambda= 3153.586
# phi= 32.40657   sv2= 0.004900409   df= 3.853023   lambda= 6613.033
# phi= 32.59668   sv2= 0.004226898   df= 3.376501   lambda= 7711.725
# phi= 32.65134   sv2= 0.004078898   df= 3.289487   lambda= 8004.942
# phi= 32.66568   sv2= 0.004041951   df= 3.268929   lambda= 8081.662
# phi= 32.66942   sv2= 0.004032439   df= 3.263709   lambda= 8101.654
# phi= 32.67039   sv2= 0.00402997   df= 3.262359   lambda= 8106.858
# phi= 32.67065   sv2= 0.004029328   df= 3.262008   lambda= 8108.213
# phi= 32.67071   sv2= 0.004029161   df= 3.261917   lambda= 8108.566
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gltL/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gltL-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_gltL-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/MD-TA_gltL-1_df_relative_timegrid-vs-TA_gltL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_gltL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=12513.874671)
#                  est          L95%         U95%          se
# rate    7.635658e-02  6.926124e-02     0.084179    0.003800
# beta    2.358480e+03  1.466065e+03  3794.120513  572.104813
# s       8.760721e-01  6.909806e-01     1.110744    0.106086
# lambda  2.705451e-07  7.440940e-16    98.367461    0.000003
#                  est        L95%        U95%       var
# lifespan  103.155667  102.174099  105.155569  0.000178
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltL/MD-TA_gltL-1_df_relative_timegrid-vs-TA_gltL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gltL-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/gltL/run-MD
