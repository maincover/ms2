# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/TA_yihS-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/TA_yihS-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS
# Iterations: relative error in phi-hat = 1e-04
# phi= 133.8952   sv2= 0.2739373   df= 15.61627   lambda= 488.7806
# phi= 142.4122   sv2= 0.06362672   df= 6.687364   lambda= 2238.245
# phi= 149.8613   sv2= 0.03143693   df= 4.926746   lambda= 4767.046
# phi= 156.4025   sv2= 0.01954708   df= 4.267417   lambda= 8001.323
# phi= 162.0284   sv2= 0.01338561   df= 3.874368   lambda= 12104.67
# save file prefixed name is : TA_yihS-1_df_relative_timegrid-vs-TA_yihS-1_timeseries_dataframe
# biName is :  TA_yihS-1_df_relative_timegrid-vs-TA_yihS-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yihS/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yihS-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yihS/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yihS/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yihS-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 133.8952   sv2= 0.2739373   df= 15.61627   lambda= 488.7806
# phi= 142.4122   sv2= 0.06362672   df= 6.687364   lambda= 2238.245
# phi= 149.8613   sv2= 0.03143693   df= 4.926746   lambda= 4767.046
# phi= 156.4025   sv2= 0.01954708   df= 4.267417   lambda= 8001.323
# phi= 162.0284   sv2= 0.01338561   df= 3.874368   lambda= 12104.67
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yihS/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yihS-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yihS-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/MD-TA_yihS-1_df_relative_timegrid-vs-TA_yihS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yihS-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=19273.905699)
#                  est          L95%          U95%            se
# rate    3.288650e-01  2.883954e-01  3.750136e-01  2.203352e-02
# beta    5.877932e+12  1.395505e+11  2.475813e+14  1.121786e+13
# s       4.085852e-01  3.430405e-01  4.866534e-01  3.645059e-02
# lambda  2.789004e-03  2.522141e-03  3.084104e-03  1.431192e-04
#                 est       L95%       U95%       var
# lifespan  91.111283  91.075301  92.123163  0.000106
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/MD-TA_yihS-1_df_relative_timegrid-vs-TA_yihS-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yihS-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yihS/run-MD
