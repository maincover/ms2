# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/TA_yihS-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/TA_yihS-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/TA_yihS-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS']
#
# out_name_s  ['TA_yihS-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/TA_yihS-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/TA_yihS-1_analysis_metadata.pickle
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 71-1.tif.mortality.tab
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 72-1.tif.mortality.tab
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 73-1.tif.mortality.tab
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 75-1.tif.mortality.tab
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 76-1.tif.mortality.tab
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 77-1.tif.mortality.tab
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 81-1.tif.mortality.tab
# MAX_01062016 Position 70-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# MAX_01062016 Position 71-1.tif.mortality.tab ------ MAX_01062016 Position 72-1.tif.mortality.tab
# MAX_01062016 Position 71-1.tif.mortality.tab ------ MAX_01062016 Position 73-1.tif.mortality.tab
# MAX_01062016 Position 71-1.tif.mortality.tab ------ MAX_01062016 Position 75-1.tif.mortality.tab
# MAX_01062016 Position 71-1.tif.mortality.tab ------ MAX_01062016 Position 76-1.tif.mortality.tab
# MAX_01062016 Position 71-1.tif.mortality.tab ------ MAX_01062016 Position 77-1.tif.mortality.tab
# MAX_01062016 Position 71-1.tif.mortality.tab ------ MAX_01062016 Position 81-1.tif.mortality.tab
# MAX_01062016 Position 71-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# MAX_01062016 Position 72-1.tif.mortality.tab ------ MAX_01062016 Position 73-1.tif.mortality.tab
# MAX_01062016 Position 72-1.tif.mortality.tab ------ MAX_01062016 Position 75-1.tif.mortality.tab
# MAX_01062016 Position 72-1.tif.mortality.tab ------ MAX_01062016 Position 76-1.tif.mortality.tab
# MAX_01062016 Position 72-1.tif.mortality.tab ------ MAX_01062016 Position 77-1.tif.mortality.tab
# MAX_01062016 Position 72-1.tif.mortality.tab ------ MAX_01062016 Position 81-1.tif.mortality.tab
# MAX_01062016 Position 72-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# MAX_01062016 Position 73-1.tif.mortality.tab ------ MAX_01062016 Position 75-1.tif.mortality.tab
# MAX_01062016 Position 73-1.tif.mortality.tab ------ MAX_01062016 Position 76-1.tif.mortality.tab
# MAX_01062016 Position 73-1.tif.mortality.tab ------ MAX_01062016 Position 77-1.tif.mortality.tab
# MAX_01062016 Position 73-1.tif.mortality.tab ------ MAX_01062016 Position 81-1.tif.mortality.tab
# MAX_01062016 Position 73-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# MAX_01062016 Position 75-1.tif.mortality.tab ------ MAX_01062016 Position 76-1.tif.mortality.tab
# MAX_01062016 Position 75-1.tif.mortality.tab ------ MAX_01062016 Position 77-1.tif.mortality.tab
# MAX_01062016 Position 75-1.tif.mortality.tab ------ MAX_01062016 Position 81-1.tif.mortality.tab
# MAX_01062016 Position 75-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# MAX_01062016 Position 76-1.tif.mortality.tab ------ MAX_01062016 Position 77-1.tif.mortality.tab
# MAX_01062016 Position 76-1.tif.mortality.tab ------ MAX_01062016 Position 81-1.tif.mortality.tab
# MAX_01062016 Position 76-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# MAX_01062016 Position 77-1.tif.mortality.tab ------ MAX_01062016 Position 81-1.tif.mortality.tab
# MAX_01062016 Position 77-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# MAX_01062016 Position 81-1.tif.mortality.tab ------ MAX_01062016 Position 82-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_dentrogram-all-files.eps
# [['MAX_01062016 Position 72-1.tif.mortality.tab', 'MAX_01062016 Position 76-1.tif.mortality.tab', 'MAX_01062016 Position 77-1.tif.mortality.tab'], ['MAX_01062016 Position 70-1.tif.mortality.tab'], ['MAX_01062016 Position 71-1.tif.mortality.tab'], ['MAX_01062016 Position 75-1.tif.mortality.tab', 'MAX_01062016 Position 82-1.tif.mortality.tab'], ['MAX_01062016 Position 81-1.tif.mortality.tab'], ['MAX_01062016 Position 73-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.61366   sv2= 0.1594327   df= 12.3266   lambda= 91.66036
# phi= 15.28793   sv2= 0.05342537   df= 7.571076   lambda= 286.1548
# phi= 15.62518   sv2= 0.02969957   df= 5.960848   lambda= 526.108
# phi= 15.8161   sv2= 0.02091811   df= 5.266621   lambda= 756.0962
# phi= 15.93311   sv2= 0.01685527   df= 4.898993   lambda= 945.2894
# phi= 16.00864   sv2= 0.01472263   df= 4.6878   lambda= 1087.349
# phi= 16.05809   sv2= 0.01351174   df= 4.56087   lambda= 1188.455
# phi= 16.09052   sv2= 0.01278894   df= 4.482344   lambda= 1258.159
# phi= 16.11177   sv2= 0.0123434   df= 4.432828   lambda= 1305.294
# phi= 16.12568   sv2= 0.01206301   df= 4.401209   lambda= 1336.788
# phi= 16.13479   sv2= 0.01188416   df= 4.38085   lambda= 1357.672
# phi= 16.14075   sv2= 0.01176908   df= 4.36767   lambda= 1371.454
# phi= 16.14464   sv2= 0.0116946   df= 4.359107   lambda= 1380.521
# phi= 16.1472   sv2= 0.01164623   df= 4.353531   lambda= 1386.474
# phi= 16.14886   sv2= 0.01161473   df= 4.349894   lambda= 1390.377
# phi= 16.14996   sv2= 0.01159419   df= 4.347519   lambda= 1392.935
# phi= 16.15067   sv2= 0.01158078   df= 4.345968   lambda= 1394.609
# phi= 16.15114   sv2= 0.01157202   df= 4.344954   lambda= 1395.705
# phi= 16.15144   sv2= 0.0115663   df= 4.344292   lambda= 1396.423
# phi= 16.15164   sv2= 0.01156256   df= 4.343858   lambda= 1396.892
# phi= 16.15177   sv2= 0.01156011   df= 4.343575   lambda= 1397.199
# phi= 16.15186   sv2= 0.01155851   df= 4.343389   lambda= 1397.4
# phi= 16.15191   sv2= 0.01155746   df= 4.343268   lambda= 1397.531
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.42361   sv2= 0.2632961   df= 9.443054   lambda= 130.741
# phi= 44.39735   sv2= 0.07354419   df= 5.384902   lambda= 603.6826
# phi= 53.98912   sv2= 0.01854138   df= 4.002566   lambda= 2911.817
# phi= 61.96448   sv2= 0.00347121   df= 3.024111   lambda= 17850.97
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_mortality_dataframe_cluster1.pickle
# 5 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yihS/CR-TA_yihS-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 139.799   sv2= 0.2012307   df= 13.37768   lambda= 694.7201
# phi= 151.4202   sv2= 0.02821863   df= 5.388206   lambda= 5365.967
# phi= 170.8081   sv2= 0.007628524   df= 3.64282   lambda= 22390.72
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.42361   sv2= 0.2632961   df= 9.443054   lambda= 130.741
# phi= 44.39735   sv2= 0.07354419   df= 5.384902   lambda= 603.6826
# phi= 53.98912   sv2= 0.01854138   df= 4.002566   lambda= 2911.817
# phi= 61.96448   sv2= 0.00347121   df= 3.024111   lambda= 17850.97
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  90.120911  89.072809  91.068041  0.000228, 1:                est       L95%       U95%       var
# lifespan  93.10387  91.104053  94.102881  0.000919}
