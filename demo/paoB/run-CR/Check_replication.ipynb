# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/TA_paoB-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/TA_paoB-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/TA_paoB-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB']
#
# out_name_s  ['TA_paoB-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/TA_paoB-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/TA_paoB-1_analysis_metadata.pickle
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 103-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 105-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 11-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 111-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 17-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 20-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 21-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 102-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 105-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 11-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 111-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 17-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 20-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 21-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 103-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 11-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 111-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 17-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 20-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 21-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 105-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 11-1.tif.mortality.tab ------ MAX_28062016 Position 111-1.tif.mortality.tab
# MAX_28062016 Position 11-1.tif.mortality.tab ------ MAX_28062016 Position 17-1.tif.mortality.tab
# MAX_28062016 Position 11-1.tif.mortality.tab ------ MAX_28062016 Position 20-1.tif.mortality.tab
# MAX_28062016 Position 11-1.tif.mortality.tab ------ MAX_28062016 Position 21-1.tif.mortality.tab
# MAX_28062016 Position 11-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 11-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 11-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 111-1.tif.mortality.tab ------ MAX_28062016 Position 17-1.tif.mortality.tab
# MAX_28062016 Position 111-1.tif.mortality.tab ------ MAX_28062016 Position 20-1.tif.mortality.tab
# MAX_28062016 Position 111-1.tif.mortality.tab ------ MAX_28062016 Position 21-1.tif.mortality.tab
# MAX_28062016 Position 111-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 111-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 111-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 17-1.tif.mortality.tab ------ MAX_28062016 Position 20-1.tif.mortality.tab
# MAX_28062016 Position 17-1.tif.mortality.tab ------ MAX_28062016 Position 21-1.tif.mortality.tab
# MAX_28062016 Position 17-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 17-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 17-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 20-1.tif.mortality.tab ------ MAX_28062016 Position 21-1.tif.mortality.tab
# MAX_28062016 Position 20-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 20-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 20-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 21-1.tif.mortality.tab ------ MAX_28062016 Position 44-1.tif.mortality.tab
# MAX_28062016 Position 21-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 21-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 44-1.tif.mortality.tab ------ MAX_28062016 Position 48-1.tif.mortality.tab
# MAX_28062016 Position 44-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# MAX_28062016 Position 48-1.tif.mortality.tab ------ MAX_28062016 Position 9-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_dentrogram-all-files.eps
# [['MAX_28062016 Position 20-1.tif.mortality.tab', 'MAX_28062016 Position 44-1.tif.mortality.tab', 'MAX_28062016 Position 9-1.tif.mortality.tab'], ['MAX_28062016 Position 103-1.tif.mortality.tab', 'MAX_28062016 Position 11-1.tif.mortality.tab', 'MAX_28062016 Position 17-1.tif.mortality.tab', 'MAX_28062016 Position 21-1.tif.mortality.tab'], ['MAX_28062016 Position 102-1.tif.mortality.tab', 'MAX_28062016 Position 111-1.tif.mortality.tab', 'MAX_28062016 Position 48-1.tif.mortality.tab'], ['MAX_28062016 Position 105-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 13.67493   sv2= 0.0971379   df= 10.77809   lambda= 140.7785
# phi= 14.5038   sv2= 0.01097839   df= 6.086096   lambda= 1321.123
# phi= 14.70859   sv2= 0.003960899   df= 3.874419   lambda= 3713.447
# phi= 14.81652   sv2= 0.002251027   df= 3.187474   lambda= 6582.116
# phi= 14.94232   sv2= 0.001593126   df= 2.864552   lambda= 9379.25
# phi= 15.0496   sv2= 0.001273318   df= 2.687459   lambda= 11819.2
# Iterations: relative error in phi-hat = 1e-04
# phi= 12.07228   sv2= 0.1506632   df= 9.527923   lambda= 80.12758
# phi= 13.15167   sv2= 0.02999447   df= 6.163142   lambda= 438.4698
# phi= 13.40845   sv2= 0.0168171   df= 4.416228   lambda= 797.3104
# phi= 13.55157   sv2= 0.01290418   df= 3.943222   lambda= 1050.169
# phi= 13.67115   sv2= 0.01100577   df= 3.737632   lambda= 1242.18
# phi= 13.76426   sv2= 0.00986701   df= 3.61494   lambda= 1394.978
# phi= 13.83781   sv2= 0.009101301   df= 3.53126   lambda= 1520.421
# phi= 13.89723   sv2= 0.008548238   df= 3.469752   lambda= 1625.742
# phi= 13.94622   sv2= 0.008128671   df= 3.422296   lambda= 1715.682
# phi= 13.98731   sv2= 0.007798795   df= 3.38441   lambda= 1793.522
# phi= 14.02229   sv2= 0.007532293   df= 3.353384   lambda= 1861.623
# phi= 14.05241   sv2= 0.007312349   df= 3.327468   lambda= 1921.737
# phi= 14.07863   sv2= 0.007127687   df= 3.305477   lambda= 1975.204
# phi= 14.10165   sv2= 0.006970445   df= 3.286574   lambda= 2023.063
# phi= 14.12201   sv2= 0.006834965   df= 3.27015   lambda= 2066.143
# phi= 14.14014   sv2= 0.006717065   df= 3.255749   lambda= 2105.108
# phi= 14.15638   sv2= 0.006613584   df= 3.243023   lambda= 2140.501
# phi= 14.171   sv2= 0.006522084   df= 3.231701   lambda= 2172.771
# phi= 14.18421   sv2= 0.006440655   df= 3.22157   lambda= 2202.293
# phi= 14.1962   sv2= 0.006367776   df= 3.212457   lambda= 2229.382
# phi= 14.20713   sv2= 0.006302221   df= 3.204222   lambda= 2254.306
# phi= 14.21712   sv2= 0.006242988   df= 3.19675   lambda= 2277.294
# phi= 14.22628   sv2= 0.006189255   df= 3.189945   lambda= 2298.545
# phi= 14.2347   sv2= 0.006140333   df= 3.183728   lambda= 2318.229
# phi= 14.24245   sv2= 0.006095648   df= 3.178031   lambda= 2336.495
# phi= 14.24962   sv2= 0.006054711   df= 3.172796   lambda= 2353.476
# phi= 14.25624   sv2= 0.006017108   df= 3.167974   lambda= 2369.285
# phi= 14.26239   sv2= 0.005982482   df= 3.163522   lambda= 2384.025
# phi= 14.26809   sv2= 0.005950526   df= 3.159403   lambda= 2397.787
# phi= 14.2734   sv2= 0.005920973   df= 3.155586   lambda= 2410.652
# phi= 14.27835   sv2= 0.005893591   df= 3.152042   lambda= 2422.691
# phi= 14.28296   sv2= 0.005868176   df= 3.148746   lambda= 2433.969
# phi= 14.28727   sv2= 0.005844548   df= 3.145676   lambda= 2444.546
# phi= 14.2913   sv2= 0.00582255   df= 3.142813   lambda= 2454.474
# phi= 14.29507   sv2= 0.00580204   df= 3.14014   lambda= 2463.8
# phi= 14.2986   sv2= 0.005782893   df= 3.137641   lambda= 2472.568
# phi= 14.30191   sv2= 0.005764998   df= 3.135301   lambda= 2480.819
# phi= 14.30502   sv2= 0.005748252   df= 3.133109   lambda= 2488.587
# phi= 14.30795   sv2= 0.005732568   df= 3.131054   lambda= 2495.906
# phi= 14.3107   sv2= 0.005717862   df= 3.129124   lambda= 2502.806
# phi= 14.31328   sv2= 0.005704062   df= 3.127312   lambda= 2509.314
# phi= 14.31572   sv2= 0.0056911   df= 3.125608   lambda= 2515.457
# phi= 14.31801   sv2= 0.005678917   df= 3.124004   lambda= 2521.258
# phi= 14.32018   sv2= 0.005667456   df= 3.122494   lambda= 2526.738
# phi= 14.32222   sv2= 0.005656667   df= 3.121072   lambda= 2531.918
# phi= 14.32415   sv2= 0.005646505   df= 3.119731   lambda= 2536.816
# phi= 14.32596   sv2= 0.005636926   df= 3.118466   lambda= 2541.45
# phi= 14.32768   sv2= 0.005627893   df= 3.117273   lambda= 2545.834
# phi= 14.32931   sv2= 0.005619369   df= 3.116146   lambda= 2549.985
# phi= 14.33084   sv2= 0.005611321   df= 3.115081   lambda= 2553.916
# phi= 14.3323   sv2= 0.00560372   df= 3.114074   lambda= 2557.64
# phi= 14.33367   sv2= 0.005596537   df= 3.113123   lambda= 2561.168
# phi= 14.33497   sv2= 0.005589747   df= 3.112223   lambda= 2564.512
# phi= 14.33621   sv2= 0.005583324   df= 3.111371   lambda= 2567.683
# phi= 14.33737   sv2= 0.005577247   df= 3.110565   lambda= 2570.69
# phi= 14.33848   sv2= 0.005571496   df= 3.109801   lambda= 2573.542
# phi= 14.33953   sv2= 0.00556605   df= 3.109078   lambda= 2576.249
# phi= 14.34052   sv2= 0.005560893   df= 3.108393   lambda= 2578.817
# phi= 14.34147   sv2= 0.005556006   df= 3.107744   lambda= 2581.255
# phi= 14.34236   sv2= 0.005551376   df= 3.107128   lambda= 2583.569
# phi= 14.34321   sv2= 0.005546986   df= 3.106544   lambda= 2585.767
# phi= 14.34402   sv2= 0.005542823   df= 3.10599   lambda= 2587.854
# phi= 14.34478   sv2= 0.005538876   df= 3.105465   lambda= 2589.836
# phi= 14.34551   sv2= 0.00553513   df= 3.104966   lambda= 2591.72
# phi= 14.34619   sv2= 0.005531577   df= 3.104493   lambda= 2593.509
# phi= 14.34685   sv2= 0.005528204   df= 3.104044   lambda= 2595.21
# phi= 14.34747   sv2= 0.005525003   df= 3.103617   lambda= 2596.826
# phi= 14.34806   sv2= 0.005521963   df= 3.103212   lambda= 2598.363
# phi= 14.34862   sv2= 0.005519076   df= 3.102827   lambda= 2599.823
# phi= 14.34916   sv2= 0.005516335   df= 3.102462   lambda= 2601.212
# phi= 14.34966   sv2= 0.00551373   df= 3.102114   lambda= 2602.532
# phi= 14.35014   sv2= 0.005511256   df= 3.101784   lambda= 2603.788
# phi= 14.3506   sv2= 0.005508905   df= 3.101471   lambda= 2604.983
# phi= 14.35104   sv2= 0.005506671   df= 3.101172   lambda= 2606.119
# phi= 14.35145   sv2= 0.005504547   df= 3.100889   lambda= 2607.199
# phi= 14.35185   sv2= 0.005502528   df= 3.10062   lambda= 2608.227
# phi= 14.35222   sv2= 0.005500609   df= 3.100363   lambda= 2609.206
# phi= 14.35258   sv2= 0.005498784   df= 3.10012   lambda= 2610.136
# phi= 14.35291   sv2= 0.005497049   df= 3.099888   lambda= 2611.022
# phi= 14.35324   sv2= 0.005495399   df= 3.099667   lambda= 2611.865
# phi= 14.35354   sv2= 0.005493829   df= 3.099458   lambda= 2612.667
# phi= 14.35384   sv2= 0.005492336   df= 3.099258   lambda= 2613.43
# phi= 14.35411   sv2= 0.005490916   df= 3.099069   lambda= 2614.156
# phi= 14.35438   sv2= 0.005489565   df= 3.098888   lambda= 2614.848
# phi= 14.35463   sv2= 0.005488279   df= 3.098716   lambda= 2615.506
# phi= 14.35487   sv2= 0.005487056   df= 3.098553   lambda= 2616.133
# phi= 14.3551   sv2= 0.005485892   df= 3.098397   lambda= 2616.73
# phi= 14.35531   sv2= 0.005484784   df= 3.098249   lambda= 2617.298
# phi= 14.35552   sv2= 0.00548373   df= 3.098108   lambda= 2617.838
# phi= 14.35572   sv2= 0.005482727   df= 3.097974   lambda= 2618.353
# phi= 14.3559   sv2= 0.005481772   df= 3.097846   lambda= 2618.843
# phi= 14.35608   sv2= 0.005480863   df= 3.097725   lambda= 2619.31
# phi= 14.35625   sv2= 0.005479998   df= 3.097609   lambda= 2619.755
# phi= 14.35641   sv2= 0.005479174   df= 3.097499   lambda= 2620.178
# phi= 14.35657   sv2= 0.00547839   df= 3.097394   lambda= 2620.581
# phi= 14.35671   sv2= 0.005477643   df= 3.097294   lambda= 2620.965
# phi= 14.35685   sv2= 0.005476932   df= 3.097199   lambda= 2621.331
# phi= 14.35698   sv2= 0.005476255   df= 3.097109   lambda= 2621.679
# phi= 14.35711   sv2= 0.005475611   df= 3.097022   lambda= 2622.011
# phi= 14.35723   sv2= 0.005474997   df= 3.09694   lambda= 2622.327
# phi= 14.35734   sv2= 0.005474413   df= 3.096862   lambda= 2622.627
# phi= 14.35745   sv2= 0.005473856   df= 3.096788   lambda= 2622.914
# phi= 14.35756   sv2= 0.005473326   df= 3.096717   lambda= 2623.187
# phi= 14.35766   sv2= 0.005472822   df= 3.096649   lambda= 2623.447
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.752549   sv2= 0.1211336   df= 10.37425   lambda= 63.99998
# phi= 8.126582   sv2= 0.02180976   df= 6.949254   lambda= 372.6122
# phi= 8.482872   sv2= 0.003780341   df= 4.837022   lambda= 2243.944
# phi= 8.710069   sv2= 0.0005529416   df= 3.421327   lambda= 15752.24
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/paoB/CR-TA_paoB-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.22713   sv2= 0.1856119   df= 11.89488   lambda= 119.7506
# phi= 25.62535   sv2= 0.02276764   df= 6.93933   lambda= 1125.516
# phi= 26.22219   sv2= 0.007432764   df= 4.375045   lambda= 3527.919
# phi= 26.25678   sv2= 0.004218518   df= 3.50756   lambda= 6224.171
# phi= 26.50749   sv2= 0.002848779   df= 3.141271   lambda= 9304.861
# phi= 26.79108   sv2= 0.002099184   df= 2.90614   lambda= 12762.62
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.752549   sv2= 0.1211336   df= 10.37425   lambda= 63.99998
# phi= 8.126582   sv2= 0.02180976   df= 6.949254   lambda= 372.6122
# phi= 8.482872   sv2= 0.003780341   df= 4.837022   lambda= 2243.944
# phi= 8.710069   sv2= 0.0005529416   df= 3.421327   lambda= 15752.24
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%      var
# lifespan  102.611889  100.809524  103.793777  0.00037, 1:                 est       L95%       U95%       var
# lifespan  96.077475  93.710248  97.258359  0.000874}
