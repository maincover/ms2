# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruR'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruR/TA_fruR-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruR/TA_fruR-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruR
# Iterations: relative error in phi-hat = 1e-04
# phi= 112.7432   sv2= 0.3904458   df= 18.71413   lambda= 288.7552
# phi= 126.6803   sv2= 0.07680289   df= 9.04939   lambda= 1649.421
# phi= 143.8464   sv2= 0.02247485   df= 6.261737   lambda= 6400.327
# phi= 156.1926   sv2= 0.005081006   df= 4.753759   lambda= 30740.48
# save file prefixed name is : TA_fruR-1_df_relative_timegrid-vs-TA_fruR-1_timeseries_dataframe
# biName is :  TA_fruR-1_df_relative_timegrid-vs-TA_fruR-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/fruR/run-MD
# No error in flxsrv_fit
# TA_fruR-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/fruR/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fruR/run-MD
# TA_fruR-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 112.7432   sv2= 0.3904458   df= 18.71413   lambda= 288.7552
# phi= 126.6803   sv2= 0.07680289   df= 9.04939   lambda= 1649.421
# phi= 143.8464   sv2= 0.02247485   df= 6.261737   lambda= 6400.327
# phi= 156.1926   sv2= 0.005081006   df= 4.753759   lambda= 30740.48
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fruR/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fruR-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_fruR-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruR/MD-TA_fruR-1_df_relative_timegrid-vs-TA_fruR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_fruR-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=35255.387171)
#                  est        L95%           U95%            se
# rate        0.053307    0.049973       0.056864      0.001757
# beta    21525.906018  504.122062  919151.659208  41231.587790
# s         104.559865    2.145592    5095.454789    207.328119
# lambda      0.001953    0.001597       0.002389      0.000201
#                 est       L95%       U95%       var
# lifespan  91.865349  91.647782  92.656553  0.000063
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fruR/MD-TA_fruR-1_df_relative_timegrid-vs-TA_fruR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fruR-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/fruR/run-MD
