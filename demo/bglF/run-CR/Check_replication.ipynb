# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/TA_bglF-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/TA_bglF-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/TA_bglF-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF']
#
# out_name_s  ['TA_bglF-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/TA_bglF-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/TA_bglF-1_analysis_metadata.pickle
# MAX_12072015 Position 187-1.tif.mortality.tab ------ MAX_12072015 Position 188-1.tif.mortality.tab
# MAX_12072015 Position 187-1.tif.mortality.tab ------ MAX_12072015 Position 189-1.tif.mortality.tab
# MAX_12072015 Position 187-1.tif.mortality.tab ------ MAX_12072015 Position 190-1.tif.mortality.tab
# MAX_12072015 Position 187-1.tif.mortality.tab ------ MAX_12072015 Position 23-1.tif.mortality.tab
# MAX_12072015 Position 187-1.tif.mortality.tab ------ MAX_12072015 Position 33-1.tif.mortality.tab
# MAX_12072015 Position 187-1.tif.mortality.tab ------ MAX_12072015 Position 34-1.tif.mortality.tab
# MAX_12072015 Position 187-1.tif.mortality.tab ------ MAX_12072015 Position 37-1.tif.mortality.tab
# MAX_12072015 Position 188-1.tif.mortality.tab ------ MAX_12072015 Position 189-1.tif.mortality.tab
# MAX_12072015 Position 188-1.tif.mortality.tab ------ MAX_12072015 Position 190-1.tif.mortality.tab
# MAX_12072015 Position 188-1.tif.mortality.tab ------ MAX_12072015 Position 23-1.tif.mortality.tab
# MAX_12072015 Position 188-1.tif.mortality.tab ------ MAX_12072015 Position 33-1.tif.mortality.tab
# MAX_12072015 Position 188-1.tif.mortality.tab ------ MAX_12072015 Position 34-1.tif.mortality.tab
# MAX_12072015 Position 188-1.tif.mortality.tab ------ MAX_12072015 Position 37-1.tif.mortality.tab
# MAX_12072015 Position 189-1.tif.mortality.tab ------ MAX_12072015 Position 190-1.tif.mortality.tab
# MAX_12072015 Position 189-1.tif.mortality.tab ------ MAX_12072015 Position 23-1.tif.mortality.tab
# MAX_12072015 Position 189-1.tif.mortality.tab ------ MAX_12072015 Position 33-1.tif.mortality.tab
# MAX_12072015 Position 189-1.tif.mortality.tab ------ MAX_12072015 Position 34-1.tif.mortality.tab
# MAX_12072015 Position 189-1.tif.mortality.tab ------ MAX_12072015 Position 37-1.tif.mortality.tab
# MAX_12072015 Position 190-1.tif.mortality.tab ------ MAX_12072015 Position 23-1.tif.mortality.tab
# MAX_12072015 Position 190-1.tif.mortality.tab ------ MAX_12072015 Position 33-1.tif.mortality.tab
# MAX_12072015 Position 190-1.tif.mortality.tab ------ MAX_12072015 Position 34-1.tif.mortality.tab
# MAX_12072015 Position 190-1.tif.mortality.tab ------ MAX_12072015 Position 37-1.tif.mortality.tab
# MAX_12072015 Position 23-1.tif.mortality.tab ------ MAX_12072015 Position 33-1.tif.mortality.tab
# MAX_12072015 Position 23-1.tif.mortality.tab ------ MAX_12072015 Position 34-1.tif.mortality.tab
# MAX_12072015 Position 23-1.tif.mortality.tab ------ MAX_12072015 Position 37-1.tif.mortality.tab
# MAX_12072015 Position 33-1.tif.mortality.tab ------ MAX_12072015 Position 34-1.tif.mortality.tab
# MAX_12072015 Position 33-1.tif.mortality.tab ------ MAX_12072015 Position 37-1.tif.mortality.tab
# MAX_12072015 Position 34-1.tif.mortality.tab ------ MAX_12072015 Position 37-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_dentrogram-all-files.eps
# [['MAX_12072015 Position 187-1.tif.mortality.tab', 'MAX_12072015 Position 34-1.tif.mortality.tab'], ['MAX_12072015 Position 190-1.tif.mortality.tab'], ['MAX_12072015 Position 23-1.tif.mortality.tab', 'MAX_12072015 Position 33-1.tif.mortality.tab', 'MAX_12072015 Position 37-1.tif.mortality.tab'], ['MAX_12072015 Position 188-1.tif.mortality.tab', 'MAX_12072015 Position 189-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 465.3226   sv2= 0.1405289   df= 12.31988   lambda= 3311.223
# phi= 497.6012   sv2= 0.006507964   df= 3.532512   lambda= 76460.35
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.979006   sv2= 0.1445891   df= 12.36573   lambda= 27.51939
# phi= 4.090464   sv2= 0.0823722   df= 9.897338   lambda= 49.65831
# phi= 4.165282   sv2= 0.0578166   df= 8.68941   lambda= 72.04301
# phi= 4.220848   sv2= 0.04511412   df= 8.00783   lambda= 93.55936
# phi= 4.264267   sv2= 0.03740705   df= 7.563134   lambda= 113.9963
# phi= 4.299244   sv2= 0.03225911   df= 7.244463   lambda= 133.2722
# phi= 4.327964   sv2= 0.02860644   df= 7.002678   lambda= 151.2933
# phi= 4.351805   sv2= 0.02591129   df= 6.812783   lambda= 167.9502
# phi= 4.371697   sv2= 0.02387064   df= 6.660572   lambda= 183.1412
# phi= 4.388309   sv2= 0.02229877   df= 6.537172   lambda= 196.796
# phi= 4.402158   sv2= 0.02107399   df= 6.436576   lambda= 208.8905
# phi= 4.413665   sv2= 0.02011231   df= 6.354416   lambda= 219.4509
# phi= 4.423185   sv2= 0.01935331   df= 6.287339   lambda= 228.5493
# phi= 4.431026   sv2= 0.0187522   df= 6.232667   lambda= 236.2936
# phi= 4.437455   sv2= 0.01827506   df= 6.188206   lambda= 242.8148
# phi= 4.442704   sv2= 0.01789572   df= 6.15214   lambda= 248.2551
# phi= 4.446974   sv2= 0.01759383   df= 6.122954   lambda= 252.7577
# phi= 4.450436   sv2= 0.0173534   df= 6.09939   lambda= 256.4591
# phi= 4.453234   sv2= 0.01716182   df= 6.080403   lambda= 259.4849
# phi= 4.455491   sv2= 0.01700913   df= 6.065131   lambda= 261.947
# phi= 4.457307   sv2= 0.0168874   df= 6.052866   lambda= 263.9428
# phi= 4.458767   sv2= 0.01679034   df= 6.043027   lambda= 265.5555
# phi= 4.459938   sv2= 0.01671293   df= 6.035144   lambda= 266.8555
# phi= 4.460876   sv2= 0.0166512   df= 6.028832   lambda= 267.9011
# phi= 4.461628   sv2= 0.01660197   df= 6.023783   lambda= 268.7409
# phi= 4.462229   sv2= 0.0165627   df= 6.019745   lambda= 269.4144
# phi= 4.46271   sv2= 0.01653138   df= 6.016519   lambda= 269.9539
# phi= 4.463094   sv2= 0.01650639   df= 6.013941   lambda= 270.3858
# phi= 4.463401   sv2= 0.01648646   df= 6.011882   lambda= 270.7313
# phi= 4.463646   sv2= 0.01647056   df= 6.010238   lambda= 271.0075
# phi= 4.463842   sv2= 0.01645788   df= 6.008925   lambda= 271.2282
# phi= 4.463998   sv2= 0.01644777   df= 6.007877   lambda= 271.4045
# phi= 4.464123   sv2= 0.0164397   df= 6.007041   lambda= 271.5453
# phi= 4.464223   sv2= 0.01643326   df= 6.006374   lambda= 271.6577
# phi= 4.464302   sv2= 0.01642813   df= 6.005841   lambda= 271.7475
# phi= 4.464366   sv2= 0.01642403   df= 6.005417   lambda= 271.8191
# phi= 4.464416   sv2= 0.01642076   df= 6.005078   lambda= 271.8763
# phi= 4.464457   sv2= 0.01641816   df= 6.004807   lambda= 271.9219
# phi= 4.464489   sv2= 0.01641608   df= 6.004591   lambda= 271.9583
# phi= 4.464515   sv2= 0.01641442   df= 6.004419   lambda= 271.9874
# phi= 4.464535   sv2= 0.0164131   df= 6.004282   lambda= 272.0105
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.87546   sv2= 0.1114967   df= 9.162864   lambda= 267.9493
# phi= 33.1583   sv2= 0.01077693   df= 4.510656   lambda= 3076.786
# phi= 38.95793   sv2= 0.001867574   df= 2.774419   lambda= 20860.18
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 3
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_mortality_dataframe_cluster2.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/bglF/CR-TA_bglF-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 465.3226   sv2= 0.1405289   df= 12.31988   lambda= 3311.223
# phi= 497.6012   sv2= 0.006507964   df= 3.532512   lambda= 76460.35
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.979006   sv2= 0.1445891   df= 12.36573   lambda= 27.51939
# phi= 4.090464   sv2= 0.0823722   df= 9.897338   lambda= 49.65831
# phi= 4.165282   sv2= 0.0578166   df= 8.68941   lambda= 72.04301
# phi= 4.220848   sv2= 0.04511412   df= 8.00783   lambda= 93.55936
# phi= 4.264267   sv2= 0.03740705   df= 7.563134   lambda= 113.9963
# phi= 4.299244   sv2= 0.03225911   df= 7.244463   lambda= 133.2722
# phi= 4.327964   sv2= 0.02860644   df= 7.002678   lambda= 151.2933
# phi= 4.351805   sv2= 0.02591129   df= 6.812783   lambda= 167.9502
# phi= 4.371697   sv2= 0.02387064   df= 6.660572   lambda= 183.1412
# phi= 4.388309   sv2= 0.02229877   df= 6.537172   lambda= 196.796
# phi= 4.402158   sv2= 0.02107399   df= 6.436576   lambda= 208.8905
# phi= 4.413665   sv2= 0.02011231   df= 6.354416   lambda= 219.4509
# phi= 4.423185   sv2= 0.01935331   df= 6.287339   lambda= 228.5493
# phi= 4.431026   sv2= 0.0187522   df= 6.232667   lambda= 236.2936
# phi= 4.437455   sv2= 0.01827506   df= 6.188206   lambda= 242.8148
# phi= 4.442704   sv2= 0.01789572   df= 6.15214   lambda= 248.2551
# phi= 4.446974   sv2= 0.01759383   df= 6.122954   lambda= 252.7577
# phi= 4.450436   sv2= 0.0173534   df= 6.09939   lambda= 256.4591
# phi= 4.453234   sv2= 0.01716182   df= 6.080403   lambda= 259.4849
# phi= 4.455491   sv2= 0.01700913   df= 6.065131   lambda= 261.947
# phi= 4.457307   sv2= 0.0168874   df= 6.052866   lambda= 263.9428
# phi= 4.458767   sv2= 0.01679034   df= 6.043027   lambda= 265.5555
# phi= 4.459938   sv2= 0.01671293   df= 6.035144   lambda= 266.8555
# phi= 4.460876   sv2= 0.0166512   df= 6.028832   lambda= 267.9011
# phi= 4.461628   sv2= 0.01660197   df= 6.023783   lambda= 268.7409
# phi= 4.462229   sv2= 0.0165627   df= 6.019745   lambda= 269.4144
# phi= 4.46271   sv2= 0.01653138   df= 6.016519   lambda= 269.9539
# phi= 4.463094   sv2= 0.01650639   df= 6.013941   lambda= 270.3858
# phi= 4.463401   sv2= 0.01648646   df= 6.011882   lambda= 270.7313
# phi= 4.463646   sv2= 0.01647056   df= 6.010238   lambda= 271.0075
# phi= 4.463842   sv2= 0.01645788   df= 6.008925   lambda= 271.2282
# phi= 4.463998   sv2= 0.01644777   df= 6.007877   lambda= 271.4045
# phi= 4.464123   sv2= 0.0164397   df= 6.007041   lambda= 271.5453
# phi= 4.464223   sv2= 0.01643326   df= 6.006374   lambda= 271.6577
# phi= 4.464302   sv2= 0.01642813   df= 6.005841   lambda= 271.7475
# phi= 4.464366   sv2= 0.01642403   df= 6.005417   lambda= 271.8191
# phi= 4.464416   sv2= 0.01642076   df= 6.005078   lambda= 271.8763
# phi= 4.464457   sv2= 0.01641816   df= 6.004807   lambda= 271.9219
# phi= 4.464489   sv2= 0.01641608   df= 6.004591   lambda= 271.9583
# phi= 4.464515   sv2= 0.01641442   df= 6.004419   lambda= 271.9874
# phi= 4.464535   sv2= 0.0164131   df= 6.004282   lambda= 272.0105
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.87546   sv2= 0.1114967   df= 9.162864   lambda= 267.9493
# phi= 33.1583   sv2= 0.01077693   df= 4.510656   lambda= 3076.786
# phi= 38.95793   sv2= 0.001867574   df= 2.774419   lambda= 20860.18
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  113.974861  112.593162  116.722294  0.000127, 1:                  est        L95%        U95%       var
# lifespan  106.028013  105.704167  107.402488  0.000208, 2:                est      L95%        U95%       var
# lifespan  122.5661  122.5661  129.364136  0.000544}
