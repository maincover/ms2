# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/TA_gltD-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/TA_gltD-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD
# Iterations: relative error in phi-hat = 1e-04
# phi= 23.99769   sv2= 0.2673787   df= 13.51853   lambda= 89.7517
# phi= 26.22572   sv2= 0.04728004   df= 8.396594   lambda= 554.6889
# phi= 27.45618   sv2= 0.01494761   df= 5.706665   lambda= 1836.827
# phi= 28.36017   sv2= 0.005324345   df= 4.481597   lambda= 5326.508
# phi= 29.14631   sv2= 0.001755131   df= 3.648912   lambda= 16606.34
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_gltD-1_df_relative_timegrid-vs-TA_gltD-1_timeseries_dataframe
# biName is :  TA_gltD-1_df_relative_timegrid-vs-TA_gltD-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/gltD/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_gltD-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/gltD/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gltD/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_gltD-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 23.99769   sv2= 0.2673787   df= 13.51853   lambda= 89.7517
# phi= 26.22572   sv2= 0.04728004   df= 8.396594   lambda= 554.6889
# phi= 27.45618   sv2= 0.01494761   df= 5.706665   lambda= 1836.827
# phi= 28.36017   sv2= 0.005324345   df= 4.481597   lambda= 5326.508
# phi= 29.14631   sv2= 0.001755131   df= 3.648912   lambda= 16606.34
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gltD/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gltD-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_gltD-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/MD-TA_gltD-1_df_relative_timegrid-vs-TA_gltD-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_gltD-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=10488.365537)
#                est        L95%         U95%          se
# rate      0.056354    0.047409     0.066986    0.004969
# beta    943.400714  488.875582  1820.514138  316.421983
# s         1.198962    0.709823     2.025165    0.320664
# lambda    0.000260    0.000080     0.000848    0.000157
#                  est        L95%        U95%       var
# lifespan  116.060106  114.793273  118.340798  0.000185
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/MD-TA_gltD-1_df_relative_timegrid-vs-TA_gltD-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gltD-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/gltD/run-MD
