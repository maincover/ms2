# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/TA_gltD-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/TA_gltD-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/TA_gltD-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD']
#
# out_name_s  ['TA_gltD-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/TA_gltD-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/TA_gltD-1_analysis_metadata.pickle
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 27-1.tif.mortality.tab
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 29-1.tif.mortality.tab
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 39-1.tif.mortality.tab
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 44-1.tif.mortality.tab
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 47-1.tif.mortality.tab
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 5-1.tif.mortality.tab
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 50-1.tif.mortality.tab
# MAX_01112018 Position 16-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# MAX_01112018 Position 27-1.tif.mortality.tab ------ MAX_01112018 Position 29-1.tif.mortality.tab
# MAX_01112018 Position 27-1.tif.mortality.tab ------ MAX_01112018 Position 39-1.tif.mortality.tab
# MAX_01112018 Position 27-1.tif.mortality.tab ------ MAX_01112018 Position 44-1.tif.mortality.tab
# MAX_01112018 Position 27-1.tif.mortality.tab ------ MAX_01112018 Position 47-1.tif.mortality.tab
# MAX_01112018 Position 27-1.tif.mortality.tab ------ MAX_01112018 Position 5-1.tif.mortality.tab
# MAX_01112018 Position 27-1.tif.mortality.tab ------ MAX_01112018 Position 50-1.tif.mortality.tab
# MAX_01112018 Position 27-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# MAX_01112018 Position 29-1.tif.mortality.tab ------ MAX_01112018 Position 39-1.tif.mortality.tab
# MAX_01112018 Position 29-1.tif.mortality.tab ------ MAX_01112018 Position 44-1.tif.mortality.tab
# MAX_01112018 Position 29-1.tif.mortality.tab ------ MAX_01112018 Position 47-1.tif.mortality.tab
# MAX_01112018 Position 29-1.tif.mortality.tab ------ MAX_01112018 Position 5-1.tif.mortality.tab
# MAX_01112018 Position 29-1.tif.mortality.tab ------ MAX_01112018 Position 50-1.tif.mortality.tab
# MAX_01112018 Position 29-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# MAX_01112018 Position 39-1.tif.mortality.tab ------ MAX_01112018 Position 44-1.tif.mortality.tab
# MAX_01112018 Position 39-1.tif.mortality.tab ------ MAX_01112018 Position 47-1.tif.mortality.tab
# MAX_01112018 Position 39-1.tif.mortality.tab ------ MAX_01112018 Position 5-1.tif.mortality.tab
# MAX_01112018 Position 39-1.tif.mortality.tab ------ MAX_01112018 Position 50-1.tif.mortality.tab
# MAX_01112018 Position 39-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# MAX_01112018 Position 44-1.tif.mortality.tab ------ MAX_01112018 Position 47-1.tif.mortality.tab
# MAX_01112018 Position 44-1.tif.mortality.tab ------ MAX_01112018 Position 5-1.tif.mortality.tab
# MAX_01112018 Position 44-1.tif.mortality.tab ------ MAX_01112018 Position 50-1.tif.mortality.tab
# MAX_01112018 Position 44-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# MAX_01112018 Position 47-1.tif.mortality.tab ------ MAX_01112018 Position 5-1.tif.mortality.tab
# MAX_01112018 Position 47-1.tif.mortality.tab ------ MAX_01112018 Position 50-1.tif.mortality.tab
# MAX_01112018 Position 47-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# MAX_01112018 Position 5-1.tif.mortality.tab ------ MAX_01112018 Position 50-1.tif.mortality.tab
# MAX_01112018 Position 5-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# MAX_01112018 Position 50-1.tif.mortality.tab ------ MAX_01112018 Position 60-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_dentrogram-all-files.eps
# [['MAX_01112018 Position 27-1.tif.mortality.tab', 'MAX_01112018 Position 39-1.tif.mortality.tab', 'MAX_01112018 Position 44-1.tif.mortality.tab', 'MAX_01112018 Position 5-1.tif.mortality.tab', 'MAX_01112018 Position 50-1.tif.mortality.tab'], ['MAX_01112018 Position 16-1.tif.mortality.tab', 'MAX_01112018 Position 29-1.tif.mortality.tab', 'MAX_01112018 Position 47-1.tif.mortality.tab'], ['MAX_01112018 Position 60-1.tif.mortality.tab']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 28.46679   sv2= 0.1682351   df= 12.23974   lambda= 169.2084
# phi= 30.53375   sv2= 0.02578437   df= 6.620543   lambda= 1184.196
# phi= 32.74415   sv2= 0.004833086   df= 4.444731   lambda= 6774.999
# phi= 34.31229   sv2= 0.0007300536   df= 3.200881   lambda= 46999.69
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.36409   sv2= 0.1520657   df= 9.903697   lambda= 94.45975
# phi= 15.55359   sv2= 0.02148771   df= 6.245149   lambda= 723.8363
# phi= 15.74658   sv2= 0.004624434   df= 4.182299   lambda= 3405.083
# phi= 15.74653   sv2= 0.001228351   df= 3.130977   lambda= 12819.25
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gltD/CR-TA_gltD-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.03843   sv2= 0.2183699   df= 13.25268   lambda= 114.6606
# phi= 27.32632   sv2= 0.03172855   df= 7.796896   lambda= 861.2534
# phi= 28.60348   sv2= 0.007044764   df= 5.109601   lambda= 4060.247
# phi= 29.48446   sv2= 0.001525322   df= 3.767955   lambda= 19329.99
# No error in flxsrv_fit
# {0:                  est        L95%        U95%      var
# lifespan  116.072549  114.745297  118.399039  0.00021}
