# %% [markdown]
# # GG_GGM_SELECTOR Write the result to table

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Selector_GG_GGM import GG_GGM_Selector
data_folder = '/home/xsong/mg-wt/dataset/MS 2 Github data part 2'
out_folder = '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE'
gg_ggm_selector = GG_GGM_Selector(data_folder,out_folder)
gg_ggm_selector.run()
# Out:
# create output folder :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/ssuE/CR-TA_ssuE-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/ssuE/CR-TA_ssuE-1_relative_timegrid_cluster0.pickle', 'CR-TA_ssuE-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/mtlD/CR-TA_mtlD-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/mtlD/CR-TA_mtlD-1_relative_timegrid_cluster0.pickle', 'CR-TA_mtlD-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/uxuR/CR-TA_uxuR-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/uxuR/CR-TA_uxuR-1_mortality_dataframe_cluster0.pickle', 'CR-TA_uxuR-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/CR-TA_hslR-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/CR-TA_hslR-1_relative_timegrid_cluster0.pickle', 'CR-TA_hslR-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/uxaA/CR-TA_uxaA-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/uxaA/CR-TA_uxaA-1_relative_timegrid_cluster0.pickle', 'CR-TA_uxaA-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/ycfX/CR-TA_ycfX-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/ycfX/CR-TA_ycfX-1_mortality_dataframe_cluster0.pickle', 'CR-TA_ycfX-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/CR-TA_lysC-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/CR-TA_lysC-1_mortality_dataframe_cluster0.pickle', 'CR-TA_lysC-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/ybdG/CR-TA_ybdG-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/ybdG/CR-TA_ybdG-1_relative_timegrid_cluster0.pickle', 'CR-TA_ybdG-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/melA/CR-TA_melA-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/melA/CR-TA_melA-1_relative_timegrid_cluster0.pickle', 'CR-TA_melA-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/mhpB/CR-TA_mhpB-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/mhpB/CR-TA_mhpB-1_relative_timegrid_cluster0.pickle', 'CR-TA_mhpB-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/CR-TA_caiC-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/CR-TA_caiC-1_mortality_dataframe_cluster0.pickle', 'CR-TA_caiC-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/norV/CR-TA_norV-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/norV/CR-TA_norV-1_mortality_dataframe_cluster0.pickle', 'CR-TA_norV-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/uxaC/CR-TA_uxaC-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/uxaC/CR-TA_uxaC-1_mortality_dataframe_cluster0.pickle', 'CR-TA_uxaC-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/rph/CR-TA_rph-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/rph/CR-TA_rph-1_mortality_dataframe_cluster0.pickle', 'CR-TA_rph-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/CR-TA_flgD-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/CR-TA_flgD-1_mortality_dataframe_cluster0.pickle', 'CR-TA_flgD-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/CR-TA_gltK-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/CR-TA_gltK-1_mortality_dataframe_cluster0.pickle', 'CR-TA_gltK-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/CR-TA_intG-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/CR-TA_intG-1_relative_timegrid_cluster0.pickle', 'CR-TA_intG-1_']]
# CR-TA_ssuE-1_
# ../../../cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# ../../../cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_ssuE-1_.txt
# No error in flxsrv_fit
# 7513.4835262
# 5
# 1 ['2014-12-06 00:00:00']
# No error in flxsrv_fit
# 8.52154260379e-05 0.952517985612
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_mtlD-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_mtlD-1_.txt
# No error in flxsrv_fit
# 2760.42990235
# 5
# 1 ['2014-10-07 00:00:00']
# No error in flxsrv_fit
# 0.607358908082 1.0
# No error in flxsrv_fit
# CR-TA_uxuR-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_uxuR-1_.txt
# No error in flxsrv_fit
# 16545.6174554
# 14
# 1 ['2014-09-07 00:00:00']
# No error in flxsrv_fit
# 0.0627626511414 1.0
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in (function (x, B, newdata = NULL, X = NULL, transform = FALSE,  :
#   Covariance matrix not available from non-converged model
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 50 or more warnings (use warnings() to see the first 50)
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_hslR-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_hslR-1_.txt
# No error in flxsrv_fit
# 5138.38577687
# 5
# 1 ['2015-03-13 00:00:00']
# No error in flxsrv_fit
# 0.0634338533854 1.0
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 25 warnings (use warnings() to see them)
#   warnings.warn(x, RRuntimeWarning)
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_uxaA-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_uxaA-1_.txt
# No error in flxsrv_fit
# 4201.53824629
# 2
# 1 ['2014-12-06 00:00:00']
# No error in flxsrv_fit
# 0.0248510795876 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ycfX-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_ycfX-1_.txt
# No error in flxsrv_fit
# 9185.0146293
# 9
# 1 ['2014-01-16 00:00:00']
# No error in flxsrv_fit
# 0.193608091157 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_lysC-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_lysC-1_.txt
# No error in flxsrv_fit
# 2791.45345397
# 6
# 1 ['2018-02-18 00:00:00']
# No error in flxsrv_fit
# 0.174008854572 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ybdG-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_ybdG-1_.txt
# No error in flxsrv_fit
# 6843.28021482
# 8
# 1 ['2015-09-06 00:00:00']
# No error in flxsrv_fit
# 0.0500481256321 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_melA-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_melA-1_.txt
# No error in flxsrv_fit
# 5846.00311009
# 3
# 1 ['2015-03-13 00:00:00']
# No error in flxsrv_fit
# 2.14167431741e-08 0.986301369863
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_mhpB-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_mhpB-1_.txt
# No error in flxsrv_fit
# 7995.89438802
# 8
# 1 ['2015-02-03 00:00:00']
# No error in flxsrv_fit
# 0.0130692990786 0.998632010944
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_caiC-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_caiC-1_.txt
# No error in flxsrv_fit
# 12338.9095502
# 14
# 1 ['2015-03-13 00:00:00']
# No error in flxsrv_fit
# 0.0943371264362 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_norV-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_norV-1_.txt
# No error in flxsrv_fit
# 9696.35888705
# 7
# 1 ['2015-02-03 00:00:00']
# No error in flxsrv_fit
# 0.018037325358 0.998459167951
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_uxaC-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_uxaC-1_.txt
# No error in flxsrv_fit
# 3169.67407505
# 3
# 1 ['2014-01-16 00:00:00']
# No error in flxsrv_fit
# 0.0050712775519 0.99537037037
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_rph-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_rph-1_.txt
# No error in flxsrv_fit
# 11084.7511416
# 19
# 1 ['2015-09-06 00:00:00']
# No error in flxsrv_fit
# 0.00453915251358 0.992961876833
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_flgD-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_flgD-1_.txt
# No error in flxsrv_fit
# 3419.35860402
# 5
# 1 ['2014-12-06 00:00:00']
# No error in flxsrv_fit
# 0.000755874639448 0.989795918367
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_gltK-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_gltK-1_.txt
# No error in flxsrv_fit
# 2748.39847087
# 2
# 1 ['2015-03-13 00:00:00']
# No error in flxsrv_fit
# 0.744660499237 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_intG-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 2/GG_GGM_TABLE/CR-TA_intG-1_.txt
# No error in flxsrv_fit
# 5508.39875444
# 9
# 1 ['2015-09-06 00:00:00']
# No error in flxsrv_fit
# 0.206492050281 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
