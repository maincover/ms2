# [ 11 ]  (115, 116.30570261904761, 115.29946036324787, 0.027934555696802078)
# [ 12 ]  (130, 131.30685581196582, 130.30473499999999, -0.026997954038085969)
# [ 13 ]  (114, 115.29946036324787, 114.30453408730159, -0.025630207192143095)
# [ 14 ]  (104, 105.30034305555554, 104.30246395833333, 0.025261906487613818)
# [ 15 ]  (124, 125.3153830324074, 124.3054509126984, 0.025181459865703026)
# [ 16 ]  (77, 78.303830773809523, 77.307418867521363, -0.02492531591854507)
# [ 17 ]  (78, 79.309802670940172, 78.303830773809523, -0.024582601905244247)
# [ 18 ]  (69, 70.10364930555555, 69.10465103174603, -0.024243011753304594)
# [ 19 ]  (122, 123.30542900793651, 122.30693818376068, -0.022043245559511572)

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# MAX_MAX_07092014 Position 21.tif.mortality.tab 88 175
# MAX_MAX_07092014 Position 19.tif.mortality.tab 117 190
# MAX_MAX_07092014 Position 22.tif.mortality.tab 136 221
# MAX_MAX_07092014 Position 8.tif.mortality.tab 423 583
# MAX_MAX_07092014 Position 1.tif.mortality.tab 39 70
# MAX_MAX_07092014 Position 10.tif.mortality.tab 40 82
# MAX_MAX_07092014 Position 20.tif.mortality.tab 169 281
# MAX_MAX_07092014 Position 4.tif.mortality.tab 32 44
# MAX_MAX_07092014 Position 9.tif.mortality.tab 194 343
# MAX_MAX_07092014 Position 7.tif.mortality.tab 315 432
# MAX_MAX_07092014 Position 6.tif.mortality.tab 183 288
# MAX_MAX_07092014 Position 11.tif.mortality.tab 75 156
# MAX_MAX_07092014 Position 24.tif.mortality.tab 32 51
# MAX_MAX_07092014 Position 16.tif.mortality.tab 311 451
# 945
# MAX_MAX_07092014 Position 21.tif.mortality.tab 144 175
# MAX_MAX_07092014 Position 19.tif.mortality.tab 173 190
# MAX_MAX_07092014 Position 22.tif.mortality.tab 183 221
# MAX_MAX_07092014 Position 8.tif.mortality.tab 554 583
# MAX_MAX_07092014 Position 1.tif.mortality.tab 59 70
# MAX_MAX_07092014 Position 10.tif.mortality.tab 61 82
# MAX_MAX_07092014 Position 20.tif.mortality.tab 236 281
# MAX_MAX_07092014 Position 4.tif.mortality.tab 38 44
# MAX_MAX_07092014 Position 9.tif.mortality.tab 293 343
# MAX_MAX_07092014 Position 7.tif.mortality.tab 387 432
# MAX_MAX_07092014 Position 6.tif.mortality.tab 255 288
# MAX_MAX_07092014 Position 11.tif.mortality.tab 136 156
# MAX_MAX_07092014 Position 24.tif.mortality.tab 39 51
# MAX_MAX_07092014 Position 16.tif.mortality.tab 402 451
#
#             Step2: After the user have reviewed and set the alcohol time,
#             re-calculate cells to include. Then again use included data to
#             re-estimate illumination, estimate lifespan, and output data
#             in the form of pickles.

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
# Out:
# length of df is:  2960
# length of relative_time_grid is:  1922
