# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/mg-wt/dataset/MS 2 Github data part 2'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  1032  Filtered files length (after MD5 check) :  245
# check line duplication(open file) :  50 / 1032
# check line duplication(open file) :  100 / 1032
# check line duplication(open file) :  150 / 1032
# check line duplication(open file) :  200 / 1032
# check line duplication(open file) :  250 / 1032
# check line duplication(open file) :  300 / 1032
# check line duplication(open file) :  350 / 1032
# check line duplication(open file) :  400 / 1032
# check line duplication(open file) :  450 / 1032
# check line duplication(open file) :  500 / 1032
# check line duplication(open file) :  550 / 1032
# check line duplication(open file) :  600 / 1032
# check line duplication(open file) :  650 / 1032
# check line duplication(open file) :  700 / 1032
# check line duplication(open file) :  750 / 1032
# check line duplication(open file) :  800 / 1032
# check line duplication(open file) :  850 / 1032
# check line duplication(open file) :  900 / 1032
# check line duplication(open file) :  950 / 1032
# check line duplication(open file) :  1000 / 1032
# check line duplication:  0 / 1032
# check line duplication:  50 / 1032
# check line duplication:  100 / 1032
# check line duplication:  150 / 1032
# check line duplication:  200 / 1032
# check line duplication:  250 / 1032
# check line duplication:  300 / 1032
# check line duplication:  350 / 1032
# check line duplication:  400 / 1032
# check line duplication:  450 / 1032
# check line duplication:  500 / 1032
# check line duplication:  550 / 1032
# check line duplication:  600 / 1032
# check line duplication:  650 / 1032
# check line duplication:  700 / 1032
# check line duplication:  750 / 1032
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 103-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 104-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 109-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 23-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 25-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 29-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 30-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 50-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 55-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 70-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 81-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 82-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 83-1.tif.mortality.tab
# check line duplication:  800 / 1032
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 84-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 85-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 86-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 87-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 88-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 89-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 92-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/caiC/MAX_13032015 Position 99-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 116-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 117-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 132-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 134-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 24-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 26-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 28-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 31-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 32-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 38-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 41-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 42-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 45-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 61-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 62-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/flgD/MAX_06122014 Position 72-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 1-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 105-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 113-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 116-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 117-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 118-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 47-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 49-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 51-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/gltK/MAX_13032015 Position 52-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 106-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 107-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 108-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 111-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 56-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 57-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 66-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 78-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 90-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/hslR/MAX_13032015 Position 95-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 105-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 107-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 108-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 109-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 112-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 118-1.tif.mortality.tab
# check line duplication:  850 / 1032
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 119-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 120-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 121-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 122-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 124-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 142-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 143-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 44-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 82-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 83-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/intG/MAX_06092015 Position 97-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 10-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 100-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 101-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 102-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 12-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 15-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 16-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 37-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 38-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 8-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 9-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/lysC/MAX_18022018 Position 99-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/melA/MAX_13032015 Position 102-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/melA/MAX_13032015 Position 112-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/melA/MAX_13032015 Position 114-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/melA/MAX_13032015 Position 115-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2/melA/MAX_13032015 Position 119-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 2