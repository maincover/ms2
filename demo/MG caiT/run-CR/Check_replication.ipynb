# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT'
path_ref_folder ='/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT/WT mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT/WT relative_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 235.5627   sv2= 0.1234959   df= 18.03344   lambda= 1907.454
# phi= 236.4887   sv2= 0.001903347   df= 5.639079   lambda= 124248.8
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/TA_MG caiT-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/TA_MG caiT-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/TA_MG caiT-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT']
#
# out_name_s  ['TA_MG caiT-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/TA_MG caiT-1_mortality_dataframe.pickle
# path meta  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/TA_MG caiT-1_analysis_metadata.pickle
# 06052014 mRFP Position 11 stabilized.mortality.tab ------ 06052014 mRFP Position 12 stabilized.tif.mortality.tab
# 06052014 mRFP Position 11 stabilized.mortality.tab ------ 06052014 mRFP Position 13 stabilized.tif.mortality.tab
# 06052014 mRFP Position 11 stabilized.mortality.tab ------ 06052014 mRFP Position 14 stabilized.mortality.tab
# 06052014 mRFP Position 11 stabilized.mortality.tab ------ 06052014 mRFP Position 15.mortality.tab
# 06052014 mRFP Position 12 stabilized.tif.mortality.tab ------ 06052014 mRFP Position 13 stabilized.tif.mortality.tab
# 06052014 mRFP Position 12 stabilized.tif.mortality.tab ------ 06052014 mRFP Position 14 stabilized.mortality.tab
# 06052014 mRFP Position 12 stabilized.tif.mortality.tab ------ 06052014 mRFP Position 15.mortality.tab
# 06052014 mRFP Position 13 stabilized.tif.mortality.tab ------ 06052014 mRFP Position 14 stabilized.mortality.tab
# 06052014 mRFP Position 13 stabilized.tif.mortality.tab ------ 06052014 mRFP Position 15.mortality.tab
# 06052014 mRFP Position 14 stabilized.mortality.tab ------ 06052014 mRFP Position 15.mortality.tab
# dendrogram will be saved to :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT
# save eps to :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/CR-TA_MG caiT-1_dentrogram-all-files.eps
# [['06052014 mRFP Position 12 stabilized.tif.mortality.tab', '06052014 mRFP Position 14 stabilized.mortality.tab'], ['06052014 mRFP Position 11 stabilized.mortality.tab', '06052014 mRFP Position 13 stabilized.tif.mortality.tab', '06052014 mRFP Position 15.mortality.tab']]
# plotStatsRefvsClusters2 : NO ERROR
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/CR-TA_MG caiT-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/CR-TA_MG caiT-1_relative_timegrid_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/CR-TA_MG caiT-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/MG caiT/CR-TA_MG caiT-1_cluster0_tabs.txt
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# Iterations: relative error in phi-hat = 1e-04
# phi= 27.62571   sv2= 0.03736494   df= 9.659443   lambda= 739.3485
# phi= 33.05513   sv2= 0.001535358   df= 3.909193   lambda= 21529.27
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  66.099561  57.079415  73.090536  0.001484}
