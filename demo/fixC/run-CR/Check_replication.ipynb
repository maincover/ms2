# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/TA_fixC-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/TA_fixC-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/TA_fixC-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC']
#
# out_name_s  ['TA_fixC-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/TA_fixC-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/TA_fixC-1_analysis_metadata.pickle
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 113-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 116-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 117-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 118-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 119-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 12-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 120-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 112-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 116-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 117-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 118-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 119-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 12-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 120-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 113-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 117-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 118-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 119-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 12-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 120-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 116-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 118-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 119-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 12-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 120-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 117-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 119-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 12-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 120-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 118-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 12-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 120-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 119-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 12-1.tif.mortality.tab ------ MAX_11102018 Position 120-1.tif.mortality.tab
# MAX_11102018 Position 12-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 12-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 12-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 12-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 12-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 12-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 120-1.tif.mortality.tab ------ MAX_11102018 Position 15-1.tif.mortality.tab
# MAX_11102018 Position 120-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 120-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 120-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 120-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 120-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 15-1.tif.mortality.tab ------ MAX_11102018 Position 25-1.tif.mortality.tab
# MAX_11102018 Position 15-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 15-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 15-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 15-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 25-1.tif.mortality.tab ------ MAX_11102018 Position 28-1.tif.mortality.tab
# MAX_11102018 Position 25-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 25-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 25-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 28-1.tif.mortality.tab ------ MAX_11102018 Position 32-1.tif.mortality.tab
# MAX_11102018 Position 28-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 28-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 32-1.tif.mortality.tab ------ MAX_11102018 Position 8-1.tif.mortality.tab
# MAX_11102018 Position 32-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# MAX_11102018 Position 8-1.tif.mortality.tab ------ MAX_11102018 Position 9-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_dentrogram-all-files.eps
# 5 [3 4 2 1 1]
# [['MAX_11102018 Position 113-1.tif.mortality.tab', 'MAX_11102018 Position 117-1.tif.mortality.tab', 'MAX_11102018 Position 119-1.tif.mortality.tab', 'MAX_11102018 Position 12-1.tif.mortality.tab', 'MAX_11102018 Position 120-1.tif.mortality.tab', 'MAX_11102018 Position 8-1.tif.mortality.tab'], ['MAX_11102018 Position 112-1.tif.mortality.tab', 'MAX_11102018 Position 116-1.tif.mortality.tab', 'MAX_11102018 Position 118-1.tif.mortality.tab'], ['MAX_11102018 Position 15-1.tif.mortality.tab', 'MAX_11102018 Position 25-1.tif.mortality.tab', 'MAX_11102018 Position 28-1.tif.mortality.tab', 'MAX_11102018 Position 9-1.tif.mortality.tab'], ['MAX_11102018 Position 32-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 116.3282   sv2= 0.08580272   df= 11.75838   lambda= 1355.764
# phi= 121.2837   sv2= 0.006804456   df= 4.209379   lambda= 17824.15
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.49815   sv2= 0.2013898   df= 9.710692   lambda= 196.1279
# phi= 44.64905   sv2= 0.03725751   df= 5.096499   lambda= 1198.391
# phi= 50.94975   sv2= 0.0101694   df= 3.555956   lambda= 5010.107
# phi= 55.24569   sv2= 0.002446618   df= 2.728292   lambda= 22580.43
# Iterations: relative error in phi-hat = 1e-04
# phi= 135.1633   sv2= 0.05855963   df= 9.37399   lambda= 2308.13
# phi= 155.9189   sv2= 0.006826127   df= 3.256911   lambda= 22841.49
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/CR-TA_fixC-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 150.7063   sv2= 0.1192624   df= 12.59051   lambda= 1263.654
# phi= 154.7592   sv2= 0.009026946   df= 4.539022   lambda= 17144.14
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.49815   sv2= 0.2013898   df= 9.710692   lambda= 196.1279
# phi= 44.64905   sv2= 0.03725751   df= 5.096499   lambda= 1198.391
# phi= 50.94975   sv2= 0.0101694   df= 3.555956   lambda= 5010.107
# phi= 55.24569   sv2= 0.002446618   df= 2.728292   lambda= 22580.43
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  119.981953  119.955817  121.187253  0.000235, 1:                  est        L95%        U95%       var
# lifespan  110.468929  110.425753  111.619237  0.000654}
