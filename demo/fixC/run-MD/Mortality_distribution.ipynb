# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/TA_fixC-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/TA_fixC-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.49575   sv2= 0.2312548   df= 13.64815   lambda= 369.7037
# phi= 91.03142   sv2= 0.02769164   df= 6.198588   lambda= 3287.324
# phi= 90.91254   sv2= 0.009160998   df= 4.010489   lambda= 9923.869
# phi= 92.6946   sv2= 0.004187858   df= 3.251519   lambda= 22134.13
# save file prefixed name is : TA_fixC-1_df_relative_timegrid-vs-TA_fixC-1_timeseries_dataframe
# biName is :  TA_fixC-1_df_relative_timegrid-vs-TA_fixC-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/fixC/run-MD
# No error in flxsrv_fit
# TA_fixC-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/fixC/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fixC/run-MD
# TA_fixC-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.49575   sv2= 0.2312548   df= 13.64815   lambda= 369.7037
# phi= 91.03142   sv2= 0.02769164   df= 6.198588   lambda= 3287.324
# phi= 90.91254   sv2= 0.009160998   df= 4.010489   lambda= 9923.869
# phi= 92.6946   sv2= 0.004187858   df= 3.251519   lambda= 22134.13
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/fixC/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fixC-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_fixC-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/MD-TA_fixC-1_df_relative_timegrid-vs-TA_fixC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_fixC-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=12518.130820)
#                  est          L95%          U95%            se
# rate    1.761214e-01  1.505171e-01  2.060811e-01  1.411662e-02
# beta    2.951677e+08  1.814000e+07  4.802863e+09  4.200831e+08
# s       4.127973e-01  3.206157e-01  5.314825e-01  5.322521e-02
# lambda  9.972380e-04  8.283973e-04  1.200491e-03  9.438150e-05
#                  est       L95%        U95%       var
# lifespan  116.519902  115.71509  118.122585  0.000156
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/fixC/MD-TA_fixC-1_df_relative_timegrid-vs-TA_fixC-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_fixC-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/fixC/run-MD
