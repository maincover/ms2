# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/TA_glf-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/TA_glf-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/TA_glf-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf']
#
# out_name_s  ['TA_glf-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/TA_glf-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/TA_glf-1_analysis_metadata.pickle
# MAX_05072014 Position 3-1.tif.mortality.tab ------ MAX_05072014 Position 51-1.tif.mortality.tab
# MAX_05072014 Position 3-1.tif.mortality.tab ------ MAX_05072014 Position 56-1.tif.mortality.tab
# MAX_05072014 Position 3-1.tif.mortality.tab ------ MAX_05072014 Position 80-1.tif.mortality.tab
# MAX_05072014 Position 3-1.tif.mortality.tab ------ MAX_05072014 Position 92-1.tif.mortality.tab
# MAX_05072014 Position 3-1.tif.mortality.tab ------ MAX_05072014 Position 94-1.tif.mortality.tab
# MAX_05072014 Position 3-1.tif.mortality.tab ------ MAX_05072014 Position 96-1.tif.mortality.tab
# MAX_05072014 Position 51-1.tif.mortality.tab ------ MAX_05072014 Position 56-1.tif.mortality.tab
# MAX_05072014 Position 51-1.tif.mortality.tab ------ MAX_05072014 Position 80-1.tif.mortality.tab
# MAX_05072014 Position 51-1.tif.mortality.tab ------ MAX_05072014 Position 92-1.tif.mortality.tab
# MAX_05072014 Position 51-1.tif.mortality.tab ------ MAX_05072014 Position 94-1.tif.mortality.tab
# MAX_05072014 Position 51-1.tif.mortality.tab ------ MAX_05072014 Position 96-1.tif.mortality.tab
# MAX_05072014 Position 56-1.tif.mortality.tab ------ MAX_05072014 Position 80-1.tif.mortality.tab
# MAX_05072014 Position 56-1.tif.mortality.tab ------ MAX_05072014 Position 92-1.tif.mortality.tab
# MAX_05072014 Position 56-1.tif.mortality.tab ------ MAX_05072014 Position 94-1.tif.mortality.tab
# MAX_05072014 Position 56-1.tif.mortality.tab ------ MAX_05072014 Position 96-1.tif.mortality.tab
# MAX_05072014 Position 80-1.tif.mortality.tab ------ MAX_05072014 Position 92-1.tif.mortality.tab
# MAX_05072014 Position 80-1.tif.mortality.tab ------ MAX_05072014 Position 94-1.tif.mortality.tab
# MAX_05072014 Position 80-1.tif.mortality.tab ------ MAX_05072014 Position 96-1.tif.mortality.tab
# MAX_05072014 Position 92-1.tif.mortality.tab ------ MAX_05072014 Position 94-1.tif.mortality.tab
# MAX_05072014 Position 92-1.tif.mortality.tab ------ MAX_05072014 Position 96-1.tif.mortality.tab
# MAX_05072014 Position 94-1.tif.mortality.tab ------ MAX_05072014 Position 96-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_dentrogram-all-files.eps
# [['MAX_05072014 Position 51-1.tif.mortality.tab', 'MAX_05072014 Position 56-1.tif.mortality.tab'], ['MAX_05072014 Position 80-1.tif.mortality.tab', 'MAX_05072014 Position 92-1.tif.mortality.tab'], ['MAX_05072014 Position 94-1.tif.mortality.tab'], ['MAX_05072014 Position 96-1.tif.mortality.tab'], ['MAX_05072014 Position 3-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 24.37883   sv2= 0.104541   df= 11.10596   lambda= 233.1986
# phi= 28.28547   sv2= 0.01076658   df= 5.529162   lambda= 2627.155
# phi= 30.65624   sv2= 0.004430536   df= 3.465535   lambda= 6919.308
# phi= 30.74522   sv2= 0.002882428   df= 2.954086   lambda= 10666.43
# Iterations: relative error in phi-hat = 1e-04
# phi= 14.98143   sv2= 0.08060919   df= 10.52314   lambda= 185.8526
# phi= 15.43626   sv2= 0.005150162   df= 5.62391   lambda= 2997.238
# phi= 15.52835   sv2= 0.001925631   df= 3.247643   lambda= 8064.03
# phi= 15.65707   sv2= 0.001347374   df= 2.770178   lambda= 11620.44
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/CR-TA_glf-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 11.54515   sv2= 0.1042949   df= 12.62086   lambda= 110.6971
# phi= 12.17995   sv2= 0.01154859   df= 7.37223   lambda= 1054.67
# phi= 12.72318   sv2= 0.005057268   df= 4.540102   lambda= 2515.821
# phi= 12.93944   sv2= 0.003940001   df= 3.833705   lambda= 3284.121
# phi= 12.99859   sv2= 0.003611582   df= 3.650069   lambda= 3599.14
# phi= 13.01747   sv2= 0.003501624   df= 3.590136   lambda= 3717.553
# phi= 13.02395   sv2= 0.003463161   df= 3.56933   lambda= 3760.711
# phi= 13.02623   sv2= 0.003449497   df= 3.561958   lambda= 3776.27
# phi= 13.02705   sv2= 0.003444616   df= 3.559328   lambda= 3781.857
# phi= 13.02734   sv2= 0.00344287   df= 3.558386   lambda= 3783.86
# phi= 13.02744   sv2= 0.003442244   df= 3.558049   lambda= 3784.578
# phi= 13.02748   sv2= 0.00344202   df= 3.557928   lambda= 3784.835
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  115.554065  112.507449  118.546865  0.000249}
