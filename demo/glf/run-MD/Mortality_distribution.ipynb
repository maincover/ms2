# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/TA_glf-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/TA_glf-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.58978   sv2= 0.1517007   df= 15.33347   lambda= 122.5425
# phi= 19.40595   sv2= 0.01480597   df= 8.841793   lambda= 1310.683
# phi= 20.06185   sv2= 0.002613951   df= 5.317818   lambda= 7674.912
# phi= 20.41047   sv2= 0.001271172   df= 3.744299   lambda= 16056.43
# save file prefixed name is : TA_glf-1_df_relative_timegrid-vs-TA_glf-1_timeseries_dataframe
# biName is :  TA_glf-1_df_relative_timegrid-vs-TA_glf-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/glf/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_glf-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/glf/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/glf/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_glf-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.58978   sv2= 0.1517007   df= 15.33347   lambda= 122.5425
# phi= 19.40595   sv2= 0.01480597   df= 8.841793   lambda= 1310.683
# phi= 20.06185   sv2= 0.002613951   df= 5.317818   lambda= 7674.912
# phi= 20.41047   sv2= 0.001271172   df= 3.744299   lambda= 16056.43
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/glf/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_glf-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_glf-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/MD-TA_glf-1_df_relative_timegrid-vs-TA_glf-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_glf-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15928.489464)
#                  est          L95%        U95%         se
# rate    4.793327e-02  4.325766e-02    0.053114   0.002510
# beta    2.512664e+02  1.966449e+02  321.059973  31.423505
# s       1.147879e+00  8.186666e-01    1.609477   0.197951
# lambda  3.219782e-07  8.194107e-15   12.651770   0.000003
#                  est        L95%        U95%       var
# lifespan  111.554192  108.507784  113.555924  0.000136
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/glf/MD-TA_glf-1_df_relative_timegrid-vs-TA_glf-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_glf-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/glf/run-MD
