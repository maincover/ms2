# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/TA_agaA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/TA_agaA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA
# Iterations: relative error in phi-hat = 1e-04
# phi= 23.50593   sv2= 0.4006446   df= 15.23546   lambda= 58.67027
# phi= 24.73837   sv2= 0.1671287   df= 10.39875   lambda= 148.0199
# phi= 25.71483   sv2= 0.09152556   df= 8.53629   lambda= 280.9579
# phi= 26.47087   sv2= 0.05480986   df= 7.463129   lambda= 482.9581
# phi= 27.03786   sv2= 0.03392519   df= 6.670252   lambda= 796.9847
# phi= 27.44781   sv2= 0.02130045   df= 6.017924   lambda= 1288.602
# phi= 27.74088   sv2= 0.01354307   df= 5.457291   lambda= 2048.345
# phi= 27.95439   sv2= 0.00884908   df= 4.97145   lambda= 3159.017
# phi= 28.10829   sv2= 0.006155458   df= 4.562282   lambda= 4566.401
# phi= 28.20803   sv2= 0.004748396   df= 4.246   lambda= 5940.539
# phi= 28.26192   sv2= 0.004092237   df= 4.036847   lambda= 6906.228
# phi= 28.28658   sv2= 0.003813496   df= 3.923014   lambda= 7417.493
# phi= 28.29683   sv2= 0.003701356   df= 3.870491   lambda= 7644.99
# phi= 28.3009   sv2= 0.003657368   df= 3.84855   lambda= 7738.052
# phi= 28.3025   sv2= 0.003640294   df= 3.839807   lambda= 7774.784
# phi= 28.30311   sv2= 0.003633694   df= 3.836392   lambda= 7789.075
# phi= 28.30335   sv2= 0.003631146   df= 3.835069   lambda= 7794.604
# phi= 28.30344   sv2= 0.003630164   df= 3.834558   lambda= 7796.739
# phi= 28.30348   sv2= 0.003629785   df= 3.834361   lambda= 7797.562
# phi= 28.30349   sv2= 0.003629639   df= 3.834285   lambda= 7797.88
# save file prefixed name is : TA_agaA-1_df_relative_timegrid-vs-TA_agaA-1_timeseries_dataframe
# biName is :  TA_agaA-1_df_relative_timegrid-vs-TA_agaA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/agaA/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_agaA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/agaA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/agaA/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_agaA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 23.50593   sv2= 0.4006446   df= 15.23546   lambda= 58.67027
# phi= 24.73837   sv2= 0.1671287   df= 10.39875   lambda= 148.0199
# phi= 25.71483   sv2= 0.09152556   df= 8.53629   lambda= 280.9579
# phi= 26.47087   sv2= 0.05480986   df= 7.463129   lambda= 482.9581
# phi= 27.03786   sv2= 0.03392519   df= 6.670252   lambda= 796.9847
# phi= 27.44781   sv2= 0.02130045   df= 6.017924   lambda= 1288.602
# phi= 27.74088   sv2= 0.01354307   df= 5.457291   lambda= 2048.345
# phi= 27.95439   sv2= 0.00884908   df= 4.97145   lambda= 3159.017
# phi= 28.10829   sv2= 0.006155458   df= 4.562282   lambda= 4566.401
# phi= 28.20803   sv2= 0.004748396   df= 4.246   lambda= 5940.539
# phi= 28.26192   sv2= 0.004092237   df= 4.036847   lambda= 6906.228
# phi= 28.28658   sv2= 0.003813496   df= 3.923014   lambda= 7417.493
# phi= 28.29683   sv2= 0.003701356   df= 3.870491   lambda= 7644.99
# phi= 28.3009   sv2= 0.003657368   df= 3.84855   lambda= 7738.052
# phi= 28.3025   sv2= 0.003640294   df= 3.839807   lambda= 7774.784
# phi= 28.30311   sv2= 0.003633694   df= 3.836392   lambda= 7789.075
# phi= 28.30335   sv2= 0.003631146   df= 3.835069   lambda= 7794.604
# phi= 28.30344   sv2= 0.003630164   df= 3.834558   lambda= 7796.739
# phi= 28.30348   sv2= 0.003629785   df= 3.834361   lambda= 7797.562
# phi= 28.30349   sv2= 0.003629639   df= 3.834285   lambda= 7797.88
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/agaA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_agaA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_agaA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MD-TA_agaA-1_df_relative_timegrid-vs-TA_agaA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_agaA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=16675.608136)
#                  est          L95%          U95%            se
# rate    8.062315e-02  7.418350e-02  8.762180e-02  3.424245e-03
# beta    2.903882e+07  9.028309e-30  9.340098e+43  1.245452e+09
# s       2.758758e+03  7.747374e-34  9.823645e+39  1.184642e+05
# lambda  2.372641e-03  2.077882e-03  2.709214e-03  1.605857e-04
#                  est        L95%        U95%       var
# lifespan  106.066739  106.045991  107.009937  0.000116
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MD-TA_agaA-1_df_relative_timegrid-vs-TA_agaA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_agaA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/agaA/run-MD
