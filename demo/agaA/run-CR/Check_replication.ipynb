# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/TA_agaA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/TA_agaA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/TA_agaA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA']
#
# out_name_s  ['TA_agaA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/TA_agaA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/TA_agaA-1_analysis_metadata.pickle
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 107-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 108-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 109-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 110-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 111-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 113-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 114-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 106-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 108-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 109-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 110-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 111-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 113-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 114-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 107-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 108-1.tif.mortality.tab ------ MAX_17022015 Position 109-1.tif.mortality.tab
# MAX_17022015 Position 108-1.tif.mortality.tab ------ MAX_17022015 Position 110-1.tif.mortality.tab
# MAX_17022015 Position 108-1.tif.mortality.tab ------ MAX_17022015 Position 111-1.tif.mortality.tab
# MAX_17022015 Position 108-1.tif.mortality.tab ------ MAX_17022015 Position 113-1.tif.mortality.tab
# MAX_17022015 Position 108-1.tif.mortality.tab ------ MAX_17022015 Position 114-1.tif.mortality.tab
# MAX_17022015 Position 108-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 108-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 109-1.tif.mortality.tab ------ MAX_17022015 Position 110-1.tif.mortality.tab
# MAX_17022015 Position 109-1.tif.mortality.tab ------ MAX_17022015 Position 111-1.tif.mortality.tab
# MAX_17022015 Position 109-1.tif.mortality.tab ------ MAX_17022015 Position 113-1.tif.mortality.tab
# MAX_17022015 Position 109-1.tif.mortality.tab ------ MAX_17022015 Position 114-1.tif.mortality.tab
# MAX_17022015 Position 109-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 109-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 110-1.tif.mortality.tab ------ MAX_17022015 Position 111-1.tif.mortality.tab
# MAX_17022015 Position 110-1.tif.mortality.tab ------ MAX_17022015 Position 113-1.tif.mortality.tab
# MAX_17022015 Position 110-1.tif.mortality.tab ------ MAX_17022015 Position 114-1.tif.mortality.tab
# MAX_17022015 Position 110-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 110-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 111-1.tif.mortality.tab ------ MAX_17022015 Position 113-1.tif.mortality.tab
# MAX_17022015 Position 111-1.tif.mortality.tab ------ MAX_17022015 Position 114-1.tif.mortality.tab
# MAX_17022015 Position 111-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 111-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 113-1.tif.mortality.tab ------ MAX_17022015 Position 114-1.tif.mortality.tab
# MAX_17022015 Position 113-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 113-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 114-1.tif.mortality.tab ------ MAX_17022015 Position 117-1.tif.mortality.tab
# MAX_17022015 Position 114-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# MAX_17022015 Position 117-1.tif.mortality.tab ------ MAX_17022015 Position 50-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_dentrogram-all-files.eps
# [['MAX_17022015 Position 106-1.tif.mortality.tab', 'MAX_17022015 Position 107-1.tif.mortality.tab', 'MAX_17022015 Position 108-1.tif.mortality.tab', 'MAX_17022015 Position 109-1.tif.mortality.tab', 'MAX_17022015 Position 110-1.tif.mortality.tab', 'MAX_17022015 Position 111-1.tif.mortality.tab', 'MAX_17022015 Position 113-1.tif.mortality.tab', 'MAX_17022015 Position 114-1.tif.mortality.tab'], ['MAX_17022015 Position 117-1.tif.mortality.tab', 'MAX_17022015 Position 50-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.052184   sv2= 0.3976413   df= 13.57666   lambda= 20.24987
# phi= 8.390766   sv2= 0.2848219   df= 11.66559   lambda= 29.45969
# phi= 8.621309   sv2= 0.2330362   df= 10.76544   lambda= 36.99557
# phi= 8.780698   sv2= 0.204214   df= 10.25526   lambda= 42.99753
# phi= 8.893266   sv2= 0.1864255   df= 9.933047   lambda= 47.70413
# phi= 8.974027   sv2= 0.1747538   df= 9.716958   lambda= 51.35239
# phi= 9.032606   sv2= 0.1667926   df= 9.566821   lambda= 54.15471
# phi= 9.075419   sv2= 0.1612205   df= 9.460176   lambda= 56.29197
# phi= 9.106879   sv2= 0.1572509   df= 9.383322   lambda= 57.91303
# phi= 9.130085   sv2= 0.1543877   df= 9.327395   lambda= 59.13737
# phi= 9.147251   sv2= 0.1523041   df= 9.286423   lambda= 60.0591
# phi= 9.159974   sv2= 0.1507782   df= 9.256263   lambda= 60.75132
# phi= 9.169419   sv2= 0.1496554   df= 9.233986   lambda= 61.27021
# phi= 9.176438   sv2= 0.1488265   df= 9.217492   lambda= 61.65864
# phi= 9.181658   sv2= 0.1482129   df= 9.205258   lambda= 61.9491
# phi= 9.185543   sv2= 0.147758   df= 9.196172   lambda= 62.16614
# phi= 9.188435   sv2= 0.1474201   df= 9.189416   lambda= 62.32822
# phi= 9.190589   sv2= 0.147169   df= 9.18439   lambda= 62.4492
# phi= 9.192194   sv2= 0.1469823   df= 9.18065   lambda= 62.53948
# phi= 9.193389   sv2= 0.1468432   df= 9.177864   lambda= 62.60683
# phi= 9.19428   sv2= 0.1467397   df= 9.175789   lambda= 62.65706
# phi= 9.194944   sv2= 0.1466626   df= 9.174243   lambda= 62.69453
# phi= 9.195439   sv2= 0.1466052   df= 9.173091   lambda= 62.72246
# phi= 9.195808   sv2= 0.1465624   df= 9.172233   lambda= 62.7433
# phi= 9.196083   sv2= 0.1465305   df= 9.171593   lambda= 62.75883
# phi= 9.196288   sv2= 0.1465067   df= 9.171116   lambda= 62.77041
# phi= 9.196441   sv2= 0.146489   df= 9.170761   lambda= 62.77904
# phi= 9.196555   sv2= 0.1464758   df= 9.170496   lambda= 62.78548
# phi= 9.19664   sv2= 0.146466   df= 9.170298   lambda= 62.79028
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.56397   sv2= 0.4781616   df= 11.59233   lambda= 99.47259
# phi= 54.55606   sv2= 0.06312036   df= 7.063069   lambda= 864.3179
# phi= 58.59043   sv2= 0.00722039   df= 4.466229   lambda= 8114.579
# phi= 59.91541   sv2= 0.0007333016   df= 2.868902   lambda= 81706.37
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/CR-TA_agaA-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.052184   sv2= 0.3976413   df= 13.57666   lambda= 20.24987
# phi= 8.390766   sv2= 0.2848219   df= 11.66559   lambda= 29.45969
# phi= 8.621309   sv2= 0.2330362   df= 10.76544   lambda= 36.99557
# phi= 8.780698   sv2= 0.204214   df= 10.25526   lambda= 42.99753
# phi= 8.893266   sv2= 0.1864255   df= 9.933047   lambda= 47.70413
# phi= 8.974027   sv2= 0.1747538   df= 9.716958   lambda= 51.35239
# phi= 9.032606   sv2= 0.1667926   df= 9.566821   lambda= 54.15471
# phi= 9.075419   sv2= 0.1612205   df= 9.460176   lambda= 56.29197
# phi= 9.106879   sv2= 0.1572509   df= 9.383322   lambda= 57.91303
# phi= 9.130085   sv2= 0.1543877   df= 9.327395   lambda= 59.13737
# phi= 9.147251   sv2= 0.1523041   df= 9.286423   lambda= 60.0591
# phi= 9.159974   sv2= 0.1507782   df= 9.256263   lambda= 60.75132
# phi= 9.169419   sv2= 0.1496554   df= 9.233986   lambda= 61.27021
# phi= 9.176438   sv2= 0.1488265   df= 9.217492   lambda= 61.65864
# phi= 9.181658   sv2= 0.1482129   df= 9.205258   lambda= 61.9491
# phi= 9.185543   sv2= 0.147758   df= 9.196172   lambda= 62.16614
# phi= 9.188435   sv2= 0.1474201   df= 9.189416   lambda= 62.32822
# phi= 9.190589   sv2= 0.147169   df= 9.18439   lambda= 62.4492
# phi= 9.192194   sv2= 0.1469823   df= 9.18065   lambda= 62.53948
# phi= 9.193389   sv2= 0.1468432   df= 9.177864   lambda= 62.60683
# phi= 9.19428   sv2= 0.1467397   df= 9.175789   lambda= 62.65706
# phi= 9.194944   sv2= 0.1466626   df= 9.174243   lambda= 62.69453
# phi= 9.195439   sv2= 0.1466052   df= 9.173091   lambda= 62.72246
# phi= 9.195808   sv2= 0.1465624   df= 9.172233   lambda= 62.7433
# phi= 9.196083   sv2= 0.1465305   df= 9.171593   lambda= 62.75883
# phi= 9.196288   sv2= 0.1465067   df= 9.171116   lambda= 62.77041
# phi= 9.196441   sv2= 0.146489   df= 9.170761   lambda= 62.77904
# phi= 9.196555   sv2= 0.1464758   df= 9.170496   lambda= 62.78548
# phi= 9.19664   sv2= 0.146466   df= 9.170298   lambda= 62.79028
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.56397   sv2= 0.4781616   df= 11.59233   lambda= 99.47259
# phi= 54.55606   sv2= 0.06312036   df= 7.063069   lambda= 864.3179
# phi= 58.59043   sv2= 0.00722039   df= 4.466229   lambda= 8114.579
# phi= 59.91541   sv2= 0.0007333016   df= 2.868902   lambda= 81706.37
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est       L95%        U95%       var
# lifespan  104.064268  97.837728  106.066739  0.000218, 1:                  est        L95%        U95%       var
# lifespan  107.977075  107.023917  108.961887  0.000252}
