# %% [markdown]
# # TAB Analyzer Process (only file filter listed .tab files (existed also in pth) )
# TabPostAnalyzer.py is should be in the grand parent folder
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from TabPostAnalyzer import TabPostAnalyzer
pth='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA'
fFn='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/report/finalFiles.txt'
partial=1
pA = TabPostAnalyzer(pth,filterFile=fFn, group=partial)
# Out:
# part,  1
# ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 50-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 106-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 107-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 108-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 109-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 110-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 111-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 113-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 114-1.tif.mortality.tab', '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaA/MAX_17022015 Position 117-1.tif.mortality.tab']
# Total cell number :  2768
# filtered file/all file:  10 / 10

# %%
step0PlotOriginalFiles = True
step1TvReg = False
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
#             Step 0: Before we process any data, preview the PI profiles in
#             each tab files. No need for any parameters, could always run directly.
#             self.checkTimeJump() could be used to check time indeces of each files,
#             but is only triggered if self.debug is True.
#
#             Use self.viewCellTraces(fileName,start,end,pn=5) to check cell traces

# %%
step0PlotOriginalFiles = False
step1TvReg = True
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# autoDefineAlcohol is True, the alcohol index will be selected as: 123
# Alcohol time index is :  123
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (114, 114.94434925000002, 113.9462273611111, 0.10748278140821818)
# [ 1 ]  (115, 115.94519805555555, 114.94434925000002, 0.070962442969465883)
# [ 2 ]  (113, 113.9462273611111, 112.94349955555556, 0.060423750709406233)
# [ 3 ]  (119, 121.28387212121213, 118.98635475308642, -0.05441497934396277)
# [ 4 ]  (104, 104.97812894444445, 103.97720972222223, 0.047762702141929021)
# [ 5 ]  (118, 118.98635475308642, 117.98801012345677, -0.045527665492799144)
# [ 6 ]  (121, 123.43334243827161, 122.3899359722222, -0.043816651345600262)
# [ 7 ]  (97, 97.75056008333334, 96.750200694444445, -0.032424542319259765)
# [ 8 ]  (120, 122.3899359722222, 121.28387212121213, -0.029658191384616481)
# [ 9 ]  (103, 103.97720972222223, 102.97932361111111, 0.027653569417871636)
#
#             Step1: Use TVReg to calculate illumination levels, which are used
#             to estimate alcohol Time and then which cell to included in the end.
#             This step requires a set of data visualisation and report, so that
#             the user can verify the automatically chosen alcohol time is correct,
#             and the correct cells are included.
#
#             The first visualisations are the PI profiles for each file and
#             their illumination levels. The second visualisation is all illuminations
#             plotted into the same figure. The third visualisation is the combined
#             PI profile and illumination.
#
#             We also report the number of included or excluded cells in each file.
#
#             The user SHOULD make sure alcohol time is correct, or manually set
#             it according to suggestions.

# %%
pA.denoisePlotAll(asp=0.01,onlyPlot=True)
aIndex=120
pA.defineAlcoholTime(more=20,aIndex=aIndex)
# Out:
# Alcohol time index is :  120
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (114, 114.94434925000002, 113.9462273611111, 0.10748278140821818)
# [ 1 ]  (115, 115.94519805555555, 114.94434925000002, 0.070962442969465883)
# [ 2 ]  (113, 113.9462273611111, 112.94349955555556, 0.060423750709406233)
# [ 3 ]  (119, 121.28387212121213, 118.98635475308642, -0.05441497934396277)
# [ 4 ]  (104, 104.97812894444445, 103.97720972222223, 0.047762702141929021)
# [ 5 ]  (118, 118.98635475308642, 117.98801012345677, -0.045527665492799144)
# [ 6 ]  (121, 123.43334243827161, 122.3899359722222, -0.043816651345600262)
# [ 7 ]  (97, 97.75056008333334, 96.750200694444445, -0.032424542319259765)
# [ 8 ]  (120, 122.3899359722222, 121.28387212121213, -0.029658191384616481)
# [ 9 ]  (103, 103.97720972222223, 102.97932361111111, 0.027653569417871636)
# [ 10 ]  (117, 117.98801012345677, 116.9446906111111, -0.02509990823749968)
# [ 11 ]  (122, 124.43364003086421, 123.43334243827161, -0.025068713481075575)
# [ 12 ]  (98, 98.976332000000014, 97.75056008333334, -0.024711091336387912)
# [ 13 ]  (45, 45.383860222222225, 44.382963388888889, 0.021658218866416015)
# [ 14 ]  (44, 44.382963388888889, 43.384311055555557, 0.018752572081962474)
# [ 15 ]  (37, 37.381080861111116, 36.38082691666667, -0.017706241698388855)
# [ 16 ]  (109, 109.94520597222223, 108.94457283333332, 0.017317946183610985)
# [ 17 ]  (47, 47.381875388888886, 46.380541333333333, -0.017008566520383541)
# [ 18 ]  (4, 4.3811510833333287, 3.3830772499999995, -0.017007530114447326)
# [ 19 ]  (48, 48.383803111111106, 47.381875388888886, -0.016941498210870338)

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# MAX_17022015 Position 111-1.tif.mortality.tab 119 167
# MAX_17022015 Position 113-1.tif.mortality.tab 121 207
# MAX_17022015 Position 50-1.tif.mortality.tab 975 1007
# MAX_17022015 Position 108-1.tif.mortality.tab 127 167
# MAX_17022015 Position 114-1.tif.mortality.tab 116 269
# MAX_17022015 Position 109-1.tif.mortality.tab 146 182
# MAX_17022015 Position 107-1.tif.mortality.tab 110 140
# MAX_17022015 Position 117-1.tif.mortality.tab 169 301
# MAX_17022015 Position 110-1.tif.mortality.tab 136 176
# MAX_17022015 Position 106-1.tif.mortality.tab 115 152
# 100
# MAX_17022015 Position 111-1.tif.mortality.tab 119 167
# MAX_17022015 Position 113-1.tif.mortality.tab 129 207
# MAX_17022015 Position 50-1.tif.mortality.tab 999 1007
# MAX_17022015 Position 108-1.tif.mortality.tab 129 167
# MAX_17022015 Position 114-1.tif.mortality.tab 116 269
# MAX_17022015 Position 109-1.tif.mortality.tab 151 182
# MAX_17022015 Position 107-1.tif.mortality.tab 116 140
# MAX_17022015 Position 117-1.tif.mortality.tab 173 301
# MAX_17022015 Position 110-1.tif.mortality.tab 147 176
# MAX_17022015 Position 106-1.tif.mortality.tab 120 152
#
#             Step2: After the user have reviewed and set the alcohol time,
#             re-calculate cells to include. Then again use included data to
#             re-estimate illumination, estimate lifespan, and output data
#             in the form of pickles.

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
# Out:
# length of df is:  2199
# length of relative_time_grid is:  1234
