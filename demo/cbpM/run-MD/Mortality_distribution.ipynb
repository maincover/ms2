# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/TA_cbpM-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/TA_cbpM-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.14541   sv2= 0.3853699   df= 19.17818   lambda= 220.9446
# phi= 86.81068   sv2= 0.02351505   df= 9.973099   lambda= 3691.707
# phi= 90.28959   sv2= 0.008494227   df= 5.479857   lambda= 10629.52
# save file prefixed name is : TA_cbpM-1_df_relative_timegrid-vs-TA_cbpM-1_timeseries_dataframe
# biName is :  TA_cbpM-1_df_relative_timegrid-vs-TA_cbpM-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/cbpM/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_cbpM-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/cbpM/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/cbpM/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_cbpM-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 85.14541   sv2= 0.3853699   df= 19.17818   lambda= 220.9446
# phi= 86.81068   sv2= 0.02351505   df= 9.973099   lambda= 3691.707
# phi= 90.28959   sv2= 0.008494227   df= 5.479857   lambda= 10629.52
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/cbpM/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_cbpM-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_cbpM-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/MD-TA_cbpM-1_df_relative_timegrid-vs-TA_cbpM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_cbpM-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=54466.475894)
#                  est          L95%          U95%           se
# rate        0.088786      0.084195      0.093628     0.002405
# beta    33631.935131  25881.682406  43702.995923  4494.760626
# s           2.842170      2.043344      3.953290     0.478509
# lambda      0.001424      0.001300      0.001561     0.000066
#                 est       L95%       U95%       var
# lifespan  99.467833  98.757823  99.503108  0.000038
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/MD-TA_cbpM-1_df_relative_timegrid-vs-TA_cbpM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_cbpM-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/cbpM/run-MD
