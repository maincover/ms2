# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/TA_cbpM-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/TA_cbpM-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/TA_cbpM-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM']
#
# out_name_s  ['TA_cbpM-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/TA_cbpM-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/TA_cbpM-1_analysis_metadata.pickle
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 111-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 116-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 117-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 122-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 123-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 132-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 133-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 105-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 116-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 117-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 122-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 123-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 132-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 133-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 111-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 117-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 122-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 123-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 132-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 133-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 116-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 122-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 123-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 132-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 133-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 117-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 122-1.tif.mortality.tab ------ MAX_24012015 Position 123-1.tif.mortality.tab
# MAX_24012015 Position 122-1.tif.mortality.tab ------ MAX_24012015 Position 132-1.tif.mortality.tab
# MAX_24012015 Position 122-1.tif.mortality.tab ------ MAX_24012015 Position 133-1.tif.mortality.tab
# MAX_24012015 Position 122-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 122-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 122-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 122-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 123-1.tif.mortality.tab ------ MAX_24012015 Position 132-1.tif.mortality.tab
# MAX_24012015 Position 123-1.tif.mortality.tab ------ MAX_24012015 Position 133-1.tif.mortality.tab
# MAX_24012015 Position 123-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 123-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 123-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 123-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 132-1.tif.mortality.tab ------ MAX_24012015 Position 133-1.tif.mortality.tab
# MAX_24012015 Position 132-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 132-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 132-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 132-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 133-1.tif.mortality.tab ------ MAX_24012015 Position 139-1.tif.mortality.tab
# MAX_24012015 Position 133-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 133-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 133-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 139-1.tif.mortality.tab ------ MAX_24012015 Position 140-1.tif.mortality.tab
# MAX_24012015 Position 139-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 139-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 140-1.tif.mortality.tab ------ MAX_24012015 Position 141-1.tif.mortality.tab
# MAX_24012015 Position 140-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# MAX_24012015 Position 141-1.tif.mortality.tab ------ MAX_24012015 Position 9-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_dentrogram-all-files.eps
# [['MAX_24012015 Position 132-1.tif.mortality.tab', 'MAX_24012015 Position 139-1.tif.mortality.tab', 'MAX_24012015 Position 140-1.tif.mortality.tab'], ['MAX_24012015 Position 133-1.tif.mortality.tab', 'MAX_24012015 Position 9-1.tif.mortality.tab'], ['MAX_24012015 Position 122-1.tif.mortality.tab'], ['MAX_24012015 Position 141-1.tif.mortality.tab'], ['MAX_24012015 Position 111-1.tif.mortality.tab'], ['MAX_24012015 Position 123-1.tif.mortality.tab'], ['MAX_24012015 Position 116-1.tif.mortality.tab'], ['MAX_24012015 Position 117-1.tif.mortality.tab'], ['MAX_24012015 Position 105-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 146.2671   sv2= 0.2127406   df= 15.09671   lambda= 687.5373
# phi= 151.7586   sv2= 0.008450568   df= 6.089582   lambda= 17958.39
# Iterations: relative error in phi-hat = 1e-04
# phi= 2.018969   sv2= 0.09348285   df= 12.27455   lambda= 21.59722
# phi= 2.109136   sv2= 0.05249517   df= 10.35416   lambda= 40.17772
# phi= 2.187937   sv2= 0.0314416   df= 9.029249   lambda= 69.58732
# phi= 2.254727   sv2= 0.01962687   df= 8.005722   lambda= 114.8796
# phi= 2.30638   sv2= 0.01293262   df= 7.179983   lambda= 178.3382
# phi= 2.341163   sv2= 0.009217369   df= 6.531768   lambda= 253.9947
# phi= 2.362142   sv2= 0.007147546   df= 6.057136   lambda= 330.4829
# phi= 2.374655   sv2= 0.005942131   df= 5.728459   lambda= 399.6303
# phi= 2.382595   sv2= 0.005194844   df= 5.503426   lambda= 458.6461
# phi= 2.388   sv2= 0.004703007   df= 5.346346   lambda= 507.7602
# phi= 2.39188   sv2= 0.004362808   df= 5.233494   lambda= 548.2432
# phi= 2.39477   sv2= 0.004118076   df= 5.150133   lambda= 581.5264
# phi= 2.396981   sv2= 0.00393655   df= 5.087081   lambda= 608.9039
# phi= 2.398704   sv2= 0.003798649   df= 5.038459   lambda= 631.4624
# phi= 2.400067   sv2= 0.003691901   df= 5.000376   lambda= 650.0897
# phi= 2.401157   sv2= 0.003608028   df= 4.970171   lambda= 665.5039
# phi= 2.402036   sv2= 0.003541339   df= 4.945972   lambda= 678.2848
# phi= 2.402751   sv2= 0.003487802   df= 4.926425   lambda= 688.9013
# phi= 2.403335   sv2= 0.003444488   df= 4.91053   lambda= 697.7337
# phi= 2.403815   sv2= 0.003409222   df= 4.897534   lambda= 705.0917
# phi= 2.40421   sv2= 0.003380361   df= 4.886862   lambda= 711.2287
# phi= 2.404536   sv2= 0.003356639   df= 4.878065   lambda= 716.3523
# phi= 2.404807   sv2= 0.003337073   df= 4.870793   lambda= 720.6335
# phi= 2.405032   sv2= 0.003320889   df= 4.864765   lambda= 724.2132
# phi= 2.405219   sv2= 0.003307469   df= 4.859758   lambda= 727.2083
# phi= 2.405374   sv2= 0.003296318   df= 4.855593   lambda= 729.7154
# phi= 2.405504   sv2= 0.003287039   df= 4.852122   lambda= 731.815
# phi= 2.405613   sv2= 0.003279305   df= 4.849227   lambda= 733.5739
# phi= 2.405703   sv2= 0.003272853   df= 4.84681   lambda= 735.0478
# phi= 2.405779   sv2= 0.003267464   df= 4.844789   lambda= 736.2833
# phi= 2.405843   sv2= 0.00326296   df= 4.8431   lambda= 737.3191
# phi= 2.405896   sv2= 0.003259192   df= 4.841686   lambda= 738.1877
# phi= 2.40594   sv2= 0.00325604   df= 4.840502   lambda= 738.9161
# phi= 2.405978   sv2= 0.0032534   df= 4.839511   lambda= 739.5271
# phi= 2.406009   sv2= 0.003251189   df= 4.83868   lambda= 740.0397
# phi= 2.406035   sv2= 0.003249336   df= 4.837984   lambda= 740.4696
# phi= 2.406057   sv2= 0.003247784   df= 4.837401   lambda= 740.8304
# phi= 2.406075   sv2= 0.003246482   df= 4.836911   lambda= 741.1331
# phi= 2.406091   sv2= 0.003245391   df= 4.836501   lambda= 741.3871
# phi= 2.406104   sv2= 0.003244475   df= 4.836157   lambda= 741.6002
# phi= 2.406115   sv2= 0.003243708   df= 4.835868   lambda= 741.7791
# phi= 2.406124   sv2= 0.003243064   df= 4.835626   lambda= 741.9291
# phi= 2.406131   sv2= 0.003242524   df= 4.835423   lambda= 742.0551
# phi= 2.406138   sv2= 0.003242071   df= 4.835253   lambda= 742.1608
# phi= 2.406143   sv2= 0.00324169   df= 4.83511   lambda= 742.2495
# phi= 2.406148   sv2= 0.003241371   df= 4.83499   lambda= 742.324
# phi= 2.406151   sv2= 0.003241104   df= 4.834889   lambda= 742.3865
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_mortality_dataframe_cluster0.pickle
# 8 --c-- 4
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_mortality_dataframe_cluster1.pickle
# 8 --c-- 5
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cbpM/CR-TA_cbpM-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 146.2671   sv2= 0.2127406   df= 15.09671   lambda= 687.5373
# phi= 151.7586   sv2= 0.008450568   df= 6.089582   lambda= 17958.39
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.47311   sv2= 0.1397845   df= 13.01326   lambda= 132.1542
# phi= 19.90284   sv2= 0.01550889   df= 7.404981   lambda= 1283.318
# phi= 19.82977   sv2= 0.005184952   df= 4.642977   lambda= 3824.485
# phi= 19.7027   sv2= 0.002689598   df= 3.759782   lambda= 7325.517
# phi= 19.66595   sv2= 0.001633749   df= 3.327564   lambda= 12037.31
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  96.615628  94.662302  97.609272  0.000113, 1:                 est      L95%       U95%       var
# lifespan  95.758294  93.75766  97.757721  0.000284}
