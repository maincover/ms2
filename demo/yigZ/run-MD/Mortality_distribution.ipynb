# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/TA_yigZ-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/TA_yigZ-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.92034   sv2= 1.148005   df= 17.29936   lambda= 53.06627
# phi= 65.74714   sv2= 0.3433575   df= 12.33348   lambda= 191.4831
# phi= 70.15514   sv2= 0.09698126   df= 9.350054   lambda= 723.3886
# phi= 73.53698   sv2= 0.02145287   df= 7.022893   lambda= 3427.84
# phi= 74.83852   sv2= 0.00654394   df= 5.090521   lambda= 11436.31
# save file prefixed name is : TA_yigZ-1_df_relative_timegrid-vs-TA_yigZ-1_timeseries_dataframe
# biName is :  TA_yigZ-1_df_relative_timegrid-vs-TA_yigZ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yigZ/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yigZ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yigZ/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yigZ/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yigZ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 60.92034   sv2= 1.148005   df= 17.29936   lambda= 53.06627
# phi= 65.74714   sv2= 0.3433575   df= 12.33348   lambda= 191.4831
# phi= 70.15514   sv2= 0.09698126   df= 9.350054   lambda= 723.3886
# phi= 73.53698   sv2= 0.02145287   df= 7.022893   lambda= 3427.84
# phi= 74.83852   sv2= 0.00654394   df= 5.090521   lambda= 11436.31
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yigZ/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yigZ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yigZ-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/MD-TA_yigZ-1_df_relative_timegrid-vs-TA_yigZ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yigZ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=35575.341790)
#                   est           L95%          U95%             se
# rate         0.097096       0.090909  1.037037e-01       0.003262
# beta    652136.868247  382292.085525  1.112454e+06  177700.421254
# s            2.660512       1.885169  3.754743e+00       0.467636
# lambda       0.001531       0.001392  1.683311e-03       0.000074
#                  est        L95%        U95%      var
# lifespan  121.666024  121.563386  122.694564  0.00006
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/MD-TA_yigZ-1_df_relative_timegrid-vs-TA_yigZ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yigZ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yigZ/run-MD
