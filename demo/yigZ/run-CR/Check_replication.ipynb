# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/TA_yigZ-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/TA_yigZ-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/TA_yigZ-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ']
#
# out_name_s  ['TA_yigZ-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/TA_yigZ-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/TA_yigZ-1_analysis_metadata.pickle
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 122-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 123-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 124-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 129-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 131-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 132-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 134-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 121-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 123-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 124-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 129-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 131-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 132-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 134-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 122-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 124-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 129-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 131-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 132-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 134-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 123-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 129-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 131-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 132-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 134-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 124-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 131-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 132-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 134-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 129-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 132-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 134-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 131-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 134-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 132-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 135-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 134-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 136-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 135-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 137-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 136-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 138-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 137-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 142-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 138-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 143-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 142-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 146-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 143-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 147-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 146-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 148-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 147-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 148-1.tif.mortality.tab ------ MAX_10102016 Position 149-1.tif.mortality.tab
# MAX_10102016 Position 148-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 148-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 148-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 148-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 148-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 148-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 149-1.tif.mortality.tab ------ MAX_10102016 Position 150-1.tif.mortality.tab
# MAX_10102016 Position 149-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 149-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 149-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 149-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 149-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 150-1.tif.mortality.tab ------ MAX_10102016 Position 52-1.tif.mortality.tab
# MAX_10102016 Position 150-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 150-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 150-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 150-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 52-1.tif.mortality.tab ------ MAX_10102016 Position 56-1.tif.mortality.tab
# MAX_10102016 Position 52-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 52-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 52-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 56-1.tif.mortality.tab ------ MAX_10102016 Position 57-1.tif.mortality.tab
# MAX_10102016 Position 56-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 56-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 57-1.tif.mortality.tab ------ MAX_10102016 Position 59-1.tif.mortality.tab
# MAX_10102016 Position 57-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# MAX_10102016 Position 59-1.tif.mortality.tab ------ MAX_10102016 Position 60-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_dentrogram-all-files.eps
# [['MAX_10102016 Position 121-1.tif.mortality.tab', 'MAX_10102016 Position 122-1.tif.mortality.tab', 'MAX_10102016 Position 123-1.tif.mortality.tab', 'MAX_10102016 Position 129-1.tif.mortality.tab', 'MAX_10102016 Position 131-1.tif.mortality.tab', 'MAX_10102016 Position 132-1.tif.mortality.tab', 'MAX_10102016 Position 134-1.tif.mortality.tab', 'MAX_10102016 Position 60-1.tif.mortality.tab'], ['MAX_10102016 Position 52-1.tif.mortality.tab', 'MAX_10102016 Position 56-1.tif.mortality.tab', 'MAX_10102016 Position 57-1.tif.mortality.tab'], ['MAX_10102016 Position 146-1.tif.mortality.tab', 'MAX_10102016 Position 149-1.tif.mortality.tab', 'MAX_10102016 Position 150-1.tif.mortality.tab'], ['MAX_10102016 Position 138-1.tif.mortality.tab'], ['MAX_10102016 Position 124-1.tif.mortality.tab', 'MAX_10102016 Position 135-1.tif.mortality.tab', 'MAX_10102016 Position 136-1.tif.mortality.tab', 'MAX_10102016 Position 59-1.tif.mortality.tab'], ['MAX_10102016 Position 142-1.tif.mortality.tab', 'MAX_10102016 Position 143-1.tif.mortality.tab', 'MAX_10102016 Position 147-1.tif.mortality.tab', 'MAX_10102016 Position 148-1.tif.mortality.tab'], ['MAX_10102016 Position 137-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_orig_timegrid_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_colomap_all_files_cluster4.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_orig_dataframe_cluster4.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_orig_timegrid_cluster4.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 178.0912   sv2= 0.7048957   df= 13.59352   lambda= 252.649
# phi= 220.8672   sv2= 0.0431536   df= 6.860836   lambda= 5118.163
# phi= 243.419   sv2= 0.007492155   df= 3.759761   lambda= 32489.84
# Iterations: relative error in phi-hat = 1e-04
# phi= 38.87663   sv2= 0.2174463   df= 11.21146   lambda= 178.7873
# phi= 41.62608   sv2= 0.02551528   df= 6.065195   lambda= 1631.417
# phi= 43.72078   sv2= 0.009107861   df= 3.984   lambda= 4800.334
# phi= 44.96184   sv2= 0.006689905   df= 3.303221   lambda= 6720.848
# phi= 45.41727   sv2= 0.006097146   df= 3.115551   lambda= 7448.939
# phi= 45.57146   sv2= 0.005919041   df= 3.059798   lambda= 7699.128
# phi= 45.62293   sv2= 0.005861822   df= 3.04204   lambda= 7783.062
# phi= 45.64004   sv2= 0.005843031   df= 3.036226   lambda= 7811.021
# phi= 45.64573   sv2= 0.005836815   df= 3.034306   lambda= 7820.314
# phi= 45.64761   sv2= 0.005834754   df= 3.033669   lambda= 7823.4
# phi= 45.64824   sv2= 0.00583407   df= 3.033458   lambda= 7824.424
# phi= 45.64845   sv2= 0.005833843   df= 3.033387   lambda= 7824.764
# Iterations: relative error in phi-hat = 1e-04
# phi= 182.2716   sv2= 0.7273069   df= 11.36201   lambda= 250.6117
# phi= 224.916   sv2= 0.01817532   df= 5.811012   lambda= 12374.8
# Iterations: relative error in phi-hat = 1e-04
# phi= 157.1735   sv2= 0.2521402   df= 12.05761   lambda= 623.3576
# phi= 183.42   sv2= 0.009025659   df= 5.068574   lambda= 20322.06
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.02874   sv2= 0.1711537   df= 8.743119   lambda= 485.1121
# phi= 95.80288   sv2= 0.008202775   df= 4.146368   lambda= 11679.33
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in solve.default(opt$hessian) :
#   Lapack routine dgesv: system is exactly singular: U[7,7] = 0
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 50 or more warnings (use warnings() to see the first 50)
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# Error in writeGGMtoFile
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_dataframe_cluster1.pickle
# 5 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_mortality_dataframe_cluster2.pickle
# 5 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yigZ/CR-TA_yigZ-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 91.12863   sv2= 1.374125   df= 15.88571   lambda= 66.31756
# phi= 105.8599   sv2= 0.2589111   df= 10.75761   lambda= 408.8658
# phi= 119.1508   sv2= 0.03384226   df= 7.270398   lambda= 3520.771
# phi= 124.8958   sv2= 0.005856582   df= 4.650657   lambda= 21325.72
# Iterations: relative error in phi-hat = 1e-04
# phi= 38.87663   sv2= 0.2174463   df= 11.21146   lambda= 178.7873
# phi= 41.62608   sv2= 0.02551528   df= 6.065195   lambda= 1631.417
# phi= 43.72078   sv2= 0.009107861   df= 3.984   lambda= 4800.334
# phi= 44.96184   sv2= 0.006689905   df= 3.303221   lambda= 6720.848
# phi= 45.41727   sv2= 0.006097146   df= 3.115551   lambda= 7448.939
# phi= 45.57146   sv2= 0.005919041   df= 3.059798   lambda= 7699.128
# phi= 45.62293   sv2= 0.005861822   df= 3.04204   lambda= 7783.062
# phi= 45.64004   sv2= 0.005843031   df= 3.036226   lambda= 7811.021
# phi= 45.64573   sv2= 0.005836815   df= 3.034306   lambda= 7820.314
# phi= 45.64761   sv2= 0.005834754   df= 3.033669   lambda= 7823.4
# phi= 45.64824   sv2= 0.00583407   df= 3.033458   lambda= 7824.424
# phi= 45.64845   sv2= 0.005833843   df= 3.033387   lambda= 7824.764
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.02874   sv2= 0.1711537   df= 8.743119   lambda= 485.1121
# phi= 95.80288   sv2= 0.008202775   df= 4.146368   lambda= 11679.33
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  120.459808  119.421232  121.490349  0.000092, 1:                  est        L95%        U95%       var
# lifespan  128.308572  127.209695  129.417395  0.000344, 2:                 est       L95%       U95%       var
# lifespan  50.926647  20.370261  93.467323  0.001365}
