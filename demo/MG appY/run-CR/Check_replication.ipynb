# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MG strains tab/MG appY'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MG strains tab/MG appY/TA_MG appY-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MG strains tab/MG appY/TA_MG appY-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MG strains tab/MG appY/TA_MG appY-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MG strains tab/MG appY']
#
# out_name_s  ['TA_MG appY-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/TA_MG appY-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/TA_MG appY-1_analysis_metadata.pickle
# 02062014 mRFP Position 51 mask.tif.mortality.tab ------ 02062014 mRFP Position 53 mask.tif.mortality.tab
# 02062014 mRFP Position 51 mask.tif.mortality.tab ------ 02062014 mRFP Position 55 mask.tif.mortality.tab
# 02062014 mRFP Position 51 mask.tif.mortality.tab ------ 02062014 mRFP Position 56 mask.tif.mortality.tab
# 02062014 mRFP Position 51 mask.tif.mortality.tab ------ 02062014 mRFP Position 57 mask.tif.mortality.tab
# 02062014 mRFP Position 51 mask.tif.mortality.tab ------ 02062014 mRFP Position 58 mask.tif.mortality.tab
# 02062014 mRFP Position 53 mask.tif.mortality.tab ------ 02062014 mRFP Position 55 mask.tif.mortality.tab
# 02062014 mRFP Position 53 mask.tif.mortality.tab ------ 02062014 mRFP Position 56 mask.tif.mortality.tab
# 02062014 mRFP Position 53 mask.tif.mortality.tab ------ 02062014 mRFP Position 57 mask.tif.mortality.tab
# 02062014 mRFP Position 53 mask.tif.mortality.tab ------ 02062014 mRFP Position 58 mask.tif.mortality.tab
# 02062014 mRFP Position 55 mask.tif.mortality.tab ------ 02062014 mRFP Position 56 mask.tif.mortality.tab
# 02062014 mRFP Position 55 mask.tif.mortality.tab ------ 02062014 mRFP Position 57 mask.tif.mortality.tab
# 02062014 mRFP Position 55 mask.tif.mortality.tab ------ 02062014 mRFP Position 58 mask.tif.mortality.tab
# 02062014 mRFP Position 56 mask.tif.mortality.tab ------ 02062014 mRFP Position 57 mask.tif.mortality.tab
# 02062014 mRFP Position 56 mask.tif.mortality.tab ------ 02062014 mRFP Position 58 mask.tif.mortality.tab
# 02062014 mRFP Position 57 mask.tif.mortality.tab ------ 02062014 mRFP Position 58 mask.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY
# save eps to :  /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_dentrogram-all-files.eps
# [['02062014 mRFP Position 51 mask.tif.mortality.tab', '02062014 mRFP Position 53 mask.tif.mortality.tab'], ['02062014 mRFP Position 57 mask.tif.mortality.tab'], ['02062014 mRFP Position 55 mask.tif.mortality.tab', '02062014 mRFP Position 56 mask.tif.mortality.tab'], ['02062014 mRFP Position 58 mask.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.98058   sv2= 0.03341705   df= 11.87724   lambda= 1016.864
# phi= 35.70472   sv2= 0.004347846   df= 4.403042   lambda= 8212.049
# phi= 38.38406   sv2= 0.00142186   df= 2.964254   lambda= 26995.67
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.32096   sv2= 0.0483418   df= 10.89014   lambda= 875.4528
# phi= 43.38343   sv2= 0.003915351   df= 4.257426   lambda= 11080.34
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MG strains tab/MG appY/CR-TA_MG appY-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.98058   sv2= 0.03341705   df= 11.87724   lambda= 1016.864
# phi= 35.70472   sv2= 0.004347846   df= 4.403042   lambda= 8212.049
# phi= 38.38406   sv2= 0.00142186   df= 2.964254   lambda= 26995.67
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.32096   sv2= 0.0483418   df= 10.89014   lambda= 875.4528
# phi= 43.38343   sv2= 0.003915351   df= 4.257426   lambda= 11080.34
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%      var
# lifespan  76.002131  73.003692  77.026867  0.00054, 1:                 est       L95%       U95%       var
# lifespan  80.065438  79.052345  83.065718  0.000682}
