# %% [markdown]
# # TAB Analyzer Process (only file filter listed .tab files (existed also in pth) )
# TabPostAnalyzer.py is should be in the grand parent folder
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from TabPostAnalyzer import TabPostAnalyzer
pth='/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB'
fFn='/app/src/ms2/dataset/MS Github data part 9/report/finalFiles.txt'
partial=1
pA = TabPostAnalyzer(pth,filterFile=fFn, group=partial)
# Out:
# part,  1
# ['/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 1 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 2 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 3 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 6 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 7 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 13 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 22 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 25 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 27 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 28 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 29 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 30 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 31 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 32 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 33 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 34 mask.tif.mortality.tab', '/app/src/coliSurvivalAnalysis/xsong/Microfluidics Database/yjeB/MAX_26062014 mRFP Position 35 mask.tif.mortality.tab']
# Total cell number :  2442
# filtered file/all file:  17 / 17

# %%
step0PlotOriginalFiles = True
step1TvReg = False
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
#             Step 0: Before we process any data, preview the PI profiles in
#             each tab files. No need for any parameters, could always run directly.
#             self.checkTimeJump() could be used to check time indeces of each files,
#             but is only triggered if self.debug is True.
#
#             Use self.viewCellTraces(fileName,start,end,pn=5) to check cell traces

# %%
step0PlotOriginalFiles = False
step1TvReg = True
step2Output = False
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# autoDefineAlcohol is True, the alcohol index will be selected as: 138
# Alcohol time index is :  106
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (103, 136.92360290849672, 135.71659776143792, -0.37315648317125133)
# [ 1 ]  (104, 138.1105372222222, 136.92360290849672, -0.2485844327287993)
# [ 2 ]  (102, 135.71659776143792, 134.51138147058825, -0.1611230346379483)
# [ 3 ]  (105, 138.54166805555556, 138.1105372222222, -0.0848945370868835)
# [ 4 ]  (96, 128.48264098039215, 127.27705740196079, -0.04146706572908625)
# [ 5 ]  (87, 117.6229071875, 116.42460150326798, -0.03804595853816727)
# [ 6 ]  (31, 37.6256187745098, 36.417306094771234, -0.03742052588739682)
# [ 7 ]  (65, 78.66744290849672, 77.46105924836601, -0.03395085446969248)
# [ 8 ]  (67, 81.08207019607843, 79.86577515625001, 0.03277283400721501)
# [ 9 ]  (48, 58.14653905228758, 56.93662578431372, -0.03200321622274274)
#
#             Step1: Use TVReg to calculate illumination levels, which are used
#             to estimate alcohol Time and then which cell to included in the end.
#             This step requires a set of data visualisation and report, so that
#             the user can verify the automatically chosen alcohol time is correct,
#             and the correct cells are included.
#
#             The first visualisations are the PI profiles for each file and
#             their illumination levels. The second visualisation is all illuminations
#             plotted into the same figure. The third visualisation is the combined
#             PI profile and illumination.
#
#             We also report the number of included or excluded cells in each file.
#
#             The user SHOULD make sure alcohol time is correct, or manually set
#             it according to suggestions.

# %%
pA.denoisePlotAll(asp=0.01,onlyPlot=True)
aIndex=120
pA.defineAlcoholTime(more=20,aIndex=aIndex)
# Out:
# Alcohol time index is :  106
# Other possible candidates are printed, also seen in the plot 2 cells above
# [ 0 ]  (103, 136.92360290849672, 135.71659776143792, -0.37315648317125133)
# [ 1 ]  (104, 138.1105372222222, 136.92360290849672, -0.2485844327287993)
# [ 2 ]  (102, 135.71659776143792, 134.51138147058825, -0.1611230346379483)
# [ 3 ]  (105, 138.54166805555556, 138.1105372222222, -0.0848945370868835)
# [ 4 ]  (96, 128.48264098039215, 127.27705740196079, -0.04146706572908625)
# [ 5 ]  (87, 117.6229071875, 116.42460150326798, -0.03804595853816727)
# [ 6 ]  (31, 37.6256187745098, 36.417306094771234, -0.03742052588739682)
# [ 7 ]  (65, 78.66744290849672, 77.46105924836601, -0.03395085446969248)
# [ 8 ]  (67, 81.08207019607843, 79.86577515625001, 0.03277283400721501)
# [ 9 ]  (48, 58.14653905228758, 56.93662578431372, -0.03200321622274274)
# [ 10 ]  (88, 118.83618066993463, 117.6229071875, -0.030988017323257667)
# [ 11 ]  (95, 127.27705740196079, 126.07155586601307, -0.030361679180568233)
# [ 12 ]  (63, 76.25235810457517, 75.04336594771242, 0.029487794736929553)
# [ 13 ]  (90, 121.24737050653594, 120.04166694444444, 0.029228619284982875)
# [ 14 ]  (45, 54.52385901960784, 53.31717825163399, -0.02797961917466066)
# [ 15 ]  (98, 130.89532892156862, 129.68887274509802, 0.024704028630137126)
# [ 16 ]  (32, 38.832840718954245, 37.6256187745098, -0.02254048643781488)
# [ 17 ]  (54, 65.3863179248366, 64.17808200980392, 0.02219318535489212)
# [ 18 ]  (40, 48.490424934640515, 47.29587255208333, -0.021564965358897438)
# [ 19 ]  (72, 87.11698119281046, 85.90929258169935, 0.020241807791329704)

# %%
step0PlotOriginalFiles = False
step1TvReg = False
step2Output = True
pA.process(step0PlotOriginalFiles, step1TvReg, step2Output)
# Out:
# MAX_26062014 mRFP Position 35 mask.tif.mortality.tab 124 257
# MAX_26062014 mRFP Position 30 mask.tif.mortality.tab 43 113
# MAX_26062014 mRFP Position 13 mask.tif.mortality.tab 14 32
# MAX_26062014 mRFP Position 7 mask.tif.mortality.tab 30 44
# MAX_26062014 mRFP Position 32 mask.tif.mortality.tab 90 133
# MAX_26062014 mRFP Position 33 mask.tif.mortality.tab 133 255
# MAX_26062014 mRFP Position 27 mask.tif.mortality.tab 112 182
# MAX_26062014 mRFP Position 29 mask.tif.mortality.tab 86 200
# MAX_26062014 mRFP Position 1 mask.tif.mortality.tab 9 17
# MAX_26062014 mRFP Position 28 mask.tif.mortality.tab 183 300
# MAX_26062014 mRFP Position 6 mask.tif.mortality.tab 22 56
# MAX_26062014 mRFP Position 34 mask.tif.mortality.tab 105 248
# MAX_26062014 mRFP Position 2 mask.tif.mortality.tab 27 53
# MAX_26062014 mRFP Position 22 mask.tif.mortality.tab 38 64
# MAX_26062014 mRFP Position 3 mask.tif.mortality.tab 123 246
# MAX_26062014 mRFP Position 25 mask.tif.mortality.tab 57 93
# MAX_26062014 mRFP Position 31 mask.tif.mortality.tab 75 149
# 750
# MAX_26062014 mRFP Position 35 mask.tif.mortality.tab 207 257
# MAX_26062014 mRFP Position 30 mask.tif.mortality.tab 84 113
# MAX_26062014 mRFP Position 13 mask.tif.mortality.tab 22 32
# MAX_26062014 mRFP Position 7 mask.tif.mortality.tab 40 44
# MAX_26062014 mRFP Position 32 mask.tif.mortality.tab 116 133
# MAX_26062014 mRFP Position 33 mask.tif.mortality.tab 214 255
# MAX_26062014 mRFP Position 27 mask.tif.mortality.tab 155 182
# MAX_26062014 mRFP Position 29 mask.tif.mortality.tab 159 200
# MAX_26062014 mRFP Position 1 mask.tif.mortality.tab 17 17
# MAX_26062014 mRFP Position 28 mask.tif.mortality.tab 250 300
# MAX_26062014 mRFP Position 6 mask.tif.mortality.tab 44 56
# MAX_26062014 mRFP Position 34 mask.tif.mortality.tab 197 248
# MAX_26062014 mRFP Position 2 mask.tif.mortality.tab 46 53
# MAX_26062014 mRFP Position 22 mask.tif.mortality.tab 52 64
# MAX_26062014 mRFP Position 3 mask.tif.mortality.tab 190 246
# MAX_26062014 mRFP Position 25 mask.tif.mortality.tab 79 93
# MAX_26062014 mRFP Position 31 mask.tif.mortality.tab 141 149
#
#             Step2: After the user have reviewed and set the alcohol time,
#             re-calculate cells to include. Then again use included data to
#             re-estimate illumination, estimate lifespan, and output data
#             in the form of pickles.

# %%
pA.plotAllFiles(0.03)

# %%
import pickle
f0 = open(os.path.join(pA.path,pA.subfolderName, 'TA_'+pA.saveName+'_df_relative_timegrid.pickle'), 'rb')
df_ts = pickle.load(f0)
df_ts.checkLength()
# Out:
# length of df is:  2013
# length of relative_time_grid is:  1805
