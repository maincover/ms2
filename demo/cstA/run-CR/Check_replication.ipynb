# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/TA_cstA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/TA_cstA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/TA_cstA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA']
#
# out_name_s  ['TA_cstA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/TA_cstA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/TA_cstA-1_analysis_metadata.pickle
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 138-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 166-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 182-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 19-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 20-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 25-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 26-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 101-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 166-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 182-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 19-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 20-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 25-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 26-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 138-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 182-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 19-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 20-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 25-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 26-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 166-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 19-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 20-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 25-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 26-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 182-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 19-1.tif.mortality.tab ------ MAX_10092018 Position 20-1.tif.mortality.tab
# MAX_10092018 Position 19-1.tif.mortality.tab ------ MAX_10092018 Position 25-1.tif.mortality.tab
# MAX_10092018 Position 19-1.tif.mortality.tab ------ MAX_10092018 Position 26-1.tif.mortality.tab
# MAX_10092018 Position 19-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 19-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 19-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 19-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 20-1.tif.mortality.tab ------ MAX_10092018 Position 25-1.tif.mortality.tab
# MAX_10092018 Position 20-1.tif.mortality.tab ------ MAX_10092018 Position 26-1.tif.mortality.tab
# MAX_10092018 Position 20-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 20-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 20-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 20-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 25-1.tif.mortality.tab ------ MAX_10092018 Position 26-1.tif.mortality.tab
# MAX_10092018 Position 25-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 25-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 25-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 25-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 26-1.tif.mortality.tab ------ MAX_10092018 Position 43-1.tif.mortality.tab
# MAX_10092018 Position 26-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 26-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 26-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 43-1.tif.mortality.tab ------ MAX_10092018 Position 44-1.tif.mortality.tab
# MAX_10092018 Position 43-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 43-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 44-1.tif.mortality.tab ------ MAX_10092018 Position 45-1.tif.mortality.tab
# MAX_10092018 Position 44-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# MAX_10092018 Position 45-1.tif.mortality.tab ------ MAX_10092018 Position 5-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_dentrogram-all-files.eps
# 6 [1 1 2 3 4 5]
# [['MAX_10092018 Position 101-1.tif.mortality.tab', 'MAX_10092018 Position 19-1.tif.mortality.tab', 'MAX_10092018 Position 26-1.tif.mortality.tab', 'MAX_10092018 Position 45-1.tif.mortality.tab', 'MAX_10092018 Position 5-1.tif.mortality.tab'], ['MAX_10092018 Position 20-1.tif.mortality.tab'], ['MAX_10092018 Position 138-1.tif.mortality.tab', 'MAX_10092018 Position 25-1.tif.mortality.tab', 'MAX_10092018 Position 43-1.tif.mortality.tab', 'MAX_10092018 Position 44-1.tif.mortality.tab'], ['MAX_10092018 Position 182-1.tif.mortality.tab'], ['MAX_10092018 Position 166-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 34.92617   sv2= 0.4134559   df= 16.34383   lambda= 84.47375
# phi= 38.53976   sv2= 0.08605564   df= 10.26325   lambda= 447.8471
# phi= 42.3522   sv2= 0.02117616   df= 7.138564   lambda= 1999.994
# phi= 44.53647   sv2= 0.005144941   df= 5.216439   lambda= 8656.363
# phi= 44.96393   sv2= 0.001177609   df= 3.900267   lambda= 38182.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 62.55225   sv2= 0.3561738   df= 15.17372   lambda= 175.6228
# phi= 63.46224   sv2= 0.02792686   df= 8.066639   lambda= 2272.444
# phi= 64.80192   sv2= 0.002125808   df= 4.707764   lambda= 30483.43
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_mortality_dataframe_cluster1.pickle
# 5 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/CR-TA_cstA-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.80133   sv2= 0.3833924   df= 16.81822   lambda= 119.4633
# phi= 48.93761   sv2= 0.06147882   df= 9.785763   lambda= 796.0076
# phi= 52.7225   sv2= 0.01330405   df= 6.487847   lambda= 3962.892
# phi= 54.78116   sv2= 0.00288277   df= 4.661195   lambda= 19002.96
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.05833   sv2= 0.3900995   df= 14.5416   lambda= 25.784
# phi= 10.37553   sv2= 0.1907989   df= 11.82212   lambda= 54.37939
# phi= 10.6511   sv2= 0.09673431   df= 10.02067   lambda= 110.1067
# phi= 10.90829   sv2= 0.04555217   df= 8.572579   lambda= 239.468
# phi= 11.15241   sv2= 0.01832857   df= 7.233489   lambda= 608.471
# phi= 11.38253   sv2= 0.006078665   df= 5.92931   lambda= 1872.537
# phi= 11.59795   sv2= 0.001757913   df= 4.711079   lambda= 6597.569
# phi= 11.76771   sv2= 0.0004844448   df= 3.691828   lambda= 24291.12
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  79.695682  77.622109  83.532807  0.000114, 1:                 est       L95%       U95%       var
# lifespan  76.096049  75.095559  77.082546  0.000192}
