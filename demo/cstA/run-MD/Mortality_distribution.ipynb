# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/TA_cstA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/TA_cstA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA
# Iterations: relative error in phi-hat = 1e-04
# phi= 55.6189   sv2= 0.6917468   df= 19.65669   lambda= 80.40355
# phi= 58.20349   sv2= 0.1909393   df= 12.74535   lambda= 304.8272
# phi= 60.46502   sv2= 0.06194034   df= 9.508268   lambda= 976.1815
# phi= 62.79421   sv2= 0.02198217   df= 7.385504   lambda= 2856.597
# phi= 64.92733   sv2= 0.007228516   df= 5.882904   lambda= 8982.111
# phi= 66.48791   sv2= 0.001788123   df= 4.653786   lambda= 37183.07
# save file prefixed name is : TA_cstA-1_df_relative_timegrid-vs-TA_cstA-1_timeseries_dataframe
# biName is :  TA_cstA-1_df_relative_timegrid-vs-TA_cstA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/cstA/run-MD
# No error in flxsrv_fit
# TA_cstA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/cstA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/cstA/run-MD
# TA_cstA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 55.6189   sv2= 0.6917468   df= 19.65669   lambda= 80.40355
# phi= 58.20349   sv2= 0.1909393   df= 12.74535   lambda= 304.8272
# phi= 60.46502   sv2= 0.06194034   df= 9.508268   lambda= 976.1815
# phi= 62.79421   sv2= 0.02198217   df= 7.385504   lambda= 2856.597
# phi= 64.92733   sv2= 0.007228516   df= 5.882904   lambda= 8982.111
# phi= 66.48791   sv2= 0.001788123   df= 4.653786   lambda= 37183.07
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/cstA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_cstA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_cstA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/MD-TA_cstA-1_df_relative_timegrid-vs-TA_cstA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_cstA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=48041.111695)
#                  est          L95%          U95%             se
# rate        0.040907  3.979871e-02  4.204589e-02       0.000573
# beta    44304.874605  2.791424e-01  7.031974e+09  270691.557669
# s        1330.276268  8.267522e-03  2.140466e+08    8136.935224
# lambda      0.000001  1.052198e-14  1.883510e+02       0.000013
#               est       L95%       U95%       var
# lifespan  76.5954  75.596784  77.688968  0.000047
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/cstA/MD-TA_cstA-1_df_relative_timegrid-vs-TA_cstA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_cstA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/cstA/run-MD
