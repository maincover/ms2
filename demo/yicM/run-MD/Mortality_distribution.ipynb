# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/TA_yicM-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/TA_yicM-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.01924   sv2= 0.1744191   df= 12.43746   lambda= 120.5099
# phi= 22.16447   sv2= 0.01940512   df= 7.209142   lambda= 1142.197
# phi= 22.55569   sv2= 0.002995423   df= 4.5356   lambda= 7530.051
# phi= 22.79259   sv2= 0.0006597861   df= 3.182824   lambda= 34545.42
# save file prefixed name is : TA_yicM-1_df_relative_timegrid-vs-TA_yicM-1_timeseries_dataframe
# biName is :  TA_yicM-1_df_relative_timegrid-vs-TA_yicM-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yicM/run-MD
# No error in flxsrv_fit
# TA_yicM-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yicM/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yicM/run-MD
# TA_yicM-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 21.01924   sv2= 0.1744191   df= 12.43746   lambda= 120.5099
# phi= 22.16447   sv2= 0.01940512   df= 7.209142   lambda= 1142.197
# phi= 22.55569   sv2= 0.002995423   df= 4.5356   lambda= 7530.051
# phi= 22.79259   sv2= 0.0006597861   df= 3.182824   lambda= 34545.42
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yicM/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yicM-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yicM-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/MD-TA_yicM-1_df_relative_timegrid-vs-TA_yicM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yicM-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7130.579093)
#                 est        L95%         U95%           se
# rate       0.069432    0.053986     0.089298     0.008914
# beta    2724.786562  900.247798  8247.131319  1539.637411
# s          0.921523    0.425305     1.996692     0.363547
# lambda     0.000277    0.000090     0.000847     0.000158
#                  est        L95%        U95%       var
# lifespan  113.296773  112.141918  115.676814  0.000235
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/MD-TA_yicM-1_df_relative_timegrid-vs-TA_yicM-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yicM-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yicM/run-MD
