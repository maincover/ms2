# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/TA_yicM-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/TA_yicM-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/TA_yicM-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM']
#
# out_name_s  ['TA_yicM-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/TA_yicM-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/TA_yicM-1_analysis_metadata.pickle
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 102-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 106-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 108-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 113-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 116-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 93-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 94-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 100-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 106-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 108-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 113-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 116-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 93-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 94-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 102-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 108-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 113-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 116-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 93-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 94-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 106-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 113-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 116-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 93-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 94-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 108-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 113-1.tif.mortality.tab ------ MAX_07072016 Position 116-1.tif.mortality.tab
# MAX_07072016 Position 113-1.tif.mortality.tab ------ MAX_07072016 Position 93-1.tif.mortality.tab
# MAX_07072016 Position 113-1.tif.mortality.tab ------ MAX_07072016 Position 94-1.tif.mortality.tab
# MAX_07072016 Position 113-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 113-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 113-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 113-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 116-1.tif.mortality.tab ------ MAX_07072016 Position 93-1.tif.mortality.tab
# MAX_07072016 Position 116-1.tif.mortality.tab ------ MAX_07072016 Position 94-1.tif.mortality.tab
# MAX_07072016 Position 116-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 116-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 116-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 116-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 93-1.tif.mortality.tab ------ MAX_07072016 Position 94-1.tif.mortality.tab
# MAX_07072016 Position 93-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 93-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 93-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 93-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 94-1.tif.mortality.tab ------ MAX_07072016 Position 95-1.tif.mortality.tab
# MAX_07072016 Position 94-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 94-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 94-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 95-1.tif.mortality.tab ------ MAX_07072016 Position 96-1.tif.mortality.tab
# MAX_07072016 Position 95-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 95-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 96-1.tif.mortality.tab ------ MAX_07072016 Position 97-1.tif.mortality.tab
# MAX_07072016 Position 96-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# MAX_07072016 Position 97-1.tif.mortality.tab ------ MAX_07072016 Position 98-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_dentrogram-all-files.eps
# [['MAX_07072016 Position 102-1.tif.mortality.tab', 'MAX_07072016 Position 93-1.tif.mortality.tab', 'MAX_07072016 Position 94-1.tif.mortality.tab', 'MAX_07072016 Position 95-1.tif.mortality.tab', 'MAX_07072016 Position 96-1.tif.mortality.tab', 'MAX_07072016 Position 97-1.tif.mortality.tab', 'MAX_07072016 Position 98-1.tif.mortality.tab'], ['MAX_07072016 Position 100-1.tif.mortality.tab', 'MAX_07072016 Position 113-1.tif.mortality.tab'], ['MAX_07072016 Position 106-1.tif.mortality.tab', 'MAX_07072016 Position 108-1.tif.mortality.tab', 'MAX_07072016 Position 116-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.71543   sv2= 0.1040858   df= 10.13067   lambda= 410.3865
# phi= 45.60524   sv2= 0.008294698   df= 4.666214   lambda= 5498.12
# phi= 47.37874   sv2= 0.0008798775   df= 2.899981   lambda= 53846.98
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.1557   sv2= 0.08143976   df= 10.0676   lambda= 272.0502
# phi= 24.05796   sv2= 0.002393214   df= 4.960728   lambda= 10052.57
# Iterations: relative error in phi-hat = 1e-04
# phi= 12.8157   sv2= 0.1160357   df= 9.090976   lambda= 110.4461
# phi= 16.21564   sv2= 0.01525714   df= 5.480259   lambda= 1062.823
# phi= 18.08202   sv2= 0.001727415   df= 3.563423   lambda= 10467.68
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_mortality_dataframe_cluster2.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yicM/CR-TA_yicM-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.71543   sv2= 0.1040858   df= 10.13067   lambda= 410.3865
# phi= 45.60524   sv2= 0.008294698   df= 4.666214   lambda= 5498.12
# phi= 47.37874   sv2= 0.0008798775   df= 2.899981   lambda= 53846.98
# Iterations: relative error in phi-hat = 1e-04
# phi= 22.1557   sv2= 0.08143976   df= 10.0676   lambda= 272.0502
# phi= 24.05796   sv2= 0.002393214   df= 4.960728   lambda= 10052.57
# Iterations: relative error in phi-hat = 1e-04
# phi= 12.8157   sv2= 0.1160357   df= 9.090976   lambda= 110.4461
# phi= 16.21564   sv2= 0.01525714   df= 5.480259   lambda= 1062.823
# phi= 18.08202   sv2= 0.001727415   df= 3.563423   lambda= 10467.68
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  123.229003  123.167987  126.805786  0.000524, 1:                  est        L95%        U95%       var
# lifespan  106.135069  106.074008  112.103807  0.000756, 2:                 est       L95%      U95%       var
# lifespan  93.938082  90.318704  98.88258  0.001517}
