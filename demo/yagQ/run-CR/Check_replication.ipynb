# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/TA_yagQ-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/TA_yagQ-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/TA_yagQ-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ']
#
# out_name_s  ['TA_yagQ-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/TA_yagQ-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/TA_yagQ-1_analysis_metadata.pickle
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 40-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 41-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 42-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 43-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 44-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 45-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 46-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 39-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 41-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 42-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 43-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 44-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 45-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 46-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 40-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 41-1.tif.mortality.tab ------ MAX_16012014 Position 42-1.tif.mortality.tab
# MAX_16012014 Position 41-1.tif.mortality.tab ------ MAX_16012014 Position 43-1.tif.mortality.tab
# MAX_16012014 Position 41-1.tif.mortality.tab ------ MAX_16012014 Position 44-1.tif.mortality.tab
# MAX_16012014 Position 41-1.tif.mortality.tab ------ MAX_16012014 Position 45-1.tif.mortality.tab
# MAX_16012014 Position 41-1.tif.mortality.tab ------ MAX_16012014 Position 46-1.tif.mortality.tab
# MAX_16012014 Position 41-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 41-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 42-1.tif.mortality.tab ------ MAX_16012014 Position 43-1.tif.mortality.tab
# MAX_16012014 Position 42-1.tif.mortality.tab ------ MAX_16012014 Position 44-1.tif.mortality.tab
# MAX_16012014 Position 42-1.tif.mortality.tab ------ MAX_16012014 Position 45-1.tif.mortality.tab
# MAX_16012014 Position 42-1.tif.mortality.tab ------ MAX_16012014 Position 46-1.tif.mortality.tab
# MAX_16012014 Position 42-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 42-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 43-1.tif.mortality.tab ------ MAX_16012014 Position 44-1.tif.mortality.tab
# MAX_16012014 Position 43-1.tif.mortality.tab ------ MAX_16012014 Position 45-1.tif.mortality.tab
# MAX_16012014 Position 43-1.tif.mortality.tab ------ MAX_16012014 Position 46-1.tif.mortality.tab
# MAX_16012014 Position 43-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 43-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 44-1.tif.mortality.tab ------ MAX_16012014 Position 45-1.tif.mortality.tab
# MAX_16012014 Position 44-1.tif.mortality.tab ------ MAX_16012014 Position 46-1.tif.mortality.tab
# MAX_16012014 Position 44-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 44-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 45-1.tif.mortality.tab ------ MAX_16012014 Position 46-1.tif.mortality.tab
# MAX_16012014 Position 45-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 45-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 46-1.tif.mortality.tab ------ MAX_16012014 Position 48-1.tif.mortality.tab
# MAX_16012014 Position 46-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# MAX_16012014 Position 48-1.tif.mortality.tab ------ MAX_16012014 Position 49-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_dentrogram-all-files.eps
# [['MAX_16012014 Position 39-1.tif.mortality.tab', 'MAX_16012014 Position 41-1.tif.mortality.tab', 'MAX_16012014 Position 46-1.tif.mortality.tab', 'MAX_16012014 Position 48-1.tif.mortality.tab'], ['MAX_16012014 Position 40-1.tif.mortality.tab', 'MAX_16012014 Position 42-1.tif.mortality.tab', 'MAX_16012014 Position 43-1.tif.mortality.tab', 'MAX_16012014 Position 44-1.tif.mortality.tab', 'MAX_16012014 Position 49-1.tif.mortality.tab'], ['MAX_16012014 Position 45-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.41458   sv2= 0.07431961   df= 12.67988   lambda= 651.4374
# phi= 50.48294   sv2= 0.006810428   df= 4.937378   lambda= 7412.594
# phi= 53.53317   sv2= 0.004161756   df= 3.074034   lambda= 12863.12
# Iterations: relative error in phi-hat = 1e-04
# phi= 31.5208   sv2= 0.07738315   df= 12.77556   lambda= 407.3342
# phi= 33.04799   sv2= 0.004287239   df= 5.646895   lambda= 7708.456
# phi= 34.24637   sv2= 0.002645519   df= 3.21832   lambda= 12945.05
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/CR-TA_yagQ-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 31.58051   sv2= 0.1024917   df= 14.26558   lambda= 308.1275
# phi= 32.60618   sv2= 0.006345367   df= 6.559009   lambda= 5138.58
# phi= 33.08487   sv2= 0.004381509   df= 3.624811   lambda= 7551.021
# phi= 33.29308   sv2= 0.00426741   df= 3.382777   lambda= 7801.706
# phi= 33.31448   sv2= 0.004251894   df= 3.363564   lambda= 7835.21
# phi= 33.31734   sv2= 0.004249786   df= 3.361058   lambda= 7839.768
# phi= 33.31773   sv2= 0.004249499   df= 3.360718   lambda= 7840.39
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  78.284338  77.248368  80.256215  0.000148}
