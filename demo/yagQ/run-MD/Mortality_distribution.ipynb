# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/TA_yagQ-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/TA_yagQ-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.76182   sv2= 0.1131858   df= 14.4807   lambda= 262.9465
# phi= 30.88149   sv2= 0.007530544   df= 6.913273   lambda= 4100.831
# phi= 31.35554   sv2= 0.004464064   df= 3.831207   lambda= 7023.988
# phi= 31.57571   sv2= 0.004392419   df= 3.468039   lambda= 7188.684
# phi= 31.58802   sv2= 0.004384382   df= 3.453752   lambda= 7204.669
# phi= 31.58921   sv2= 0.004383586   df= 3.452388   lambda= 7206.248
# phi= 31.58933   sv2= 0.004383508   df= 3.452254   lambda= 7206.404
# save file prefixed name is : TA_yagQ-1_df_relative_timegrid-vs-TA_yagQ-1_timeseries_dataframe
# biName is :  TA_yagQ-1_df_relative_timegrid-vs-TA_yagQ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yagQ/run-MD
# No error in flxsrv_fit
# TA_yagQ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yagQ/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yagQ/run-MD
# TA_yagQ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 29.76182   sv2= 0.1131858   df= 14.4807   lambda= 262.9465
# phi= 30.88149   sv2= 0.007530544   df= 6.913273   lambda= 4100.831
# phi= 31.35554   sv2= 0.004464064   df= 3.831207   lambda= 7023.988
# phi= 31.57571   sv2= 0.004392419   df= 3.468039   lambda= 7188.684
# phi= 31.58802   sv2= 0.004384382   df= 3.453752   lambda= 7204.669
# phi= 31.58921   sv2= 0.004383586   df= 3.452388   lambda= 7206.248
# phi= 31.58933   sv2= 0.004383508   df= 3.452254   lambda= 7206.404
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yagQ/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yagQ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yagQ-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/MD-TA_yagQ-1_df_relative_timegrid-vs-TA_yagQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yagQ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15403.049345)
#                 est         L95%         U95%           se
# rate       0.109877     0.099722     0.121066     0.005436
# beta    3699.878279  2094.256219  6536.496897  1074.308578
# s          0.699175     0.574657     0.850674     0.069964
# lambda     0.000050     0.000007     0.000365     0.000050
#                 est       L95%       U95%       var
# lifespan  79.279893  78.256493  80.289754  0.000135
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yagQ/MD-TA_yagQ-1_df_relative_timegrid-vs-TA_yagQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yagQ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yagQ/run-MD
