# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/TA_appB-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/TA_appB-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.770004   sv2= 0.02244219   df= 13.68948   lambda= 390.7821
# phi= 8.935034   sv2= 0.005902599   df= 6.009033   lambda= 1513.746
# phi= 9.100817   sv2= 0.004226397   df= 4.517937   lambda= 2153.328
# phi= 9.169667   sv2= 0.003672341   df= 4.206392   lambda= 2496.954
# phi= 9.202402   sv2= 0.003426398   df= 4.083441   lambda= 2685.737
# phi= 9.219306   sv2= 0.003303494   df= 4.024558   lambda= 2790.774
# phi= 9.228403   sv2= 0.003238475   df= 3.99399   lambda= 2849.614
# phi= 9.233406   sv2= 0.003203044   df= 3.977488   lambda= 2882.698
# phi= 9.236191   sv2= 0.003183426   df= 3.968395   lambda= 2901.337
# phi= 9.23775   sv2= 0.003172467   df= 3.963329   lambda= 2911.851
# phi= 9.238628   sv2= 0.003166315   df= 3.960489   lambda= 2917.785
# phi= 9.239122   sv2= 0.003162853   df= 3.958892   lambda= 2921.136
# phi= 9.2394   sv2= 0.003160901   df= 3.957992   lambda= 2923.028
# phi= 9.239558   sv2= 0.003159799   df= 3.957485   lambda= 2924.096
# phi= 9.239646   sv2= 0.003159178   df= 3.957198   lambda= 2924.7
# phi= 9.239697   sv2= 0.003158826   df= 3.957036   lambda= 2925.041
# phi= 9.239725   sv2= 0.003158628   df= 3.956945   lambda= 2925.234
# save file prefixed name is : TA_appB-1_df_relative_timegrid-vs-TA_appB-1_timeseries_dataframe
# biName is :  TA_appB-1_df_relative_timegrid-vs-TA_appB-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/appB/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_appB-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/appB/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/appB/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_appB-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.770004   sv2= 0.02244219   df= 13.68948   lambda= 390.7821
# phi= 8.935034   sv2= 0.005902599   df= 6.009033   lambda= 1513.746
# phi= 9.100817   sv2= 0.004226397   df= 4.517937   lambda= 2153.328
# phi= 9.169667   sv2= 0.003672341   df= 4.206392   lambda= 2496.954
# phi= 9.202402   sv2= 0.003426398   df= 4.083441   lambda= 2685.737
# phi= 9.219306   sv2= 0.003303494   df= 4.024558   lambda= 2790.774
# phi= 9.228403   sv2= 0.003238475   df= 3.99399   lambda= 2849.614
# phi= 9.233406   sv2= 0.003203044   df= 3.977488   lambda= 2882.698
# phi= 9.236191   sv2= 0.003183426   df= 3.968395   lambda= 2901.337
# phi= 9.23775   sv2= 0.003172467   df= 3.963329   lambda= 2911.851
# phi= 9.238628   sv2= 0.003166315   df= 3.960489   lambda= 2917.785
# phi= 9.239122   sv2= 0.003162853   df= 3.958892   lambda= 2921.136
# phi= 9.2394   sv2= 0.003160901   df= 3.957992   lambda= 2923.028
# phi= 9.239558   sv2= 0.003159799   df= 3.957485   lambda= 2924.096
# phi= 9.239646   sv2= 0.003159178   df= 3.957198   lambda= 2924.7
# phi= 9.239697   sv2= 0.003158826   df= 3.957036   lambda= 2925.041
# phi= 9.239725   sv2= 0.003158628   df= 3.956945   lambda= 2925.234
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/appB/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_appB-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_appB-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/MD-TA_appB-1_df_relative_timegrid-vs-TA_appB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_appB-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=9305.901544)
#                 est         L95%          U95%           se
# rate       0.109543     0.090539      0.132536     0.010649
# beta    8354.096661  2270.368733  30739.910222  5553.060631
# s          0.872869     0.597018      1.276177     0.169161
# lambda     0.001356     0.000952      0.001931     0.000245
#                 est       L95%       U95%       var
# lifespan  82.001336  80.228208  82.227982  0.000223
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/MD-TA_appB-1_df_relative_timegrid-vs-TA_appB-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_appB-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/appB/run-MD
