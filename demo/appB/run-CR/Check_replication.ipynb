# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/TA_appB-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/TA_appB-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/TA_appB-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB']
#
# out_name_s  ['TA_appB-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/TA_appB-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/TA_appB-1_analysis_metadata.pickle
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 33-1.tif.mortality.tab
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 34-1.tif.mortality.tab
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 35-1.tif.mortality.tab
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 43-1.tif.mortality.tab
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 44-1.tif.mortality.tab
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 47-1.tif.mortality.tab
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 48-1.tif.mortality.tab
# MAX_02062014 Position 31-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# MAX_02062014 Position 33-1.tif.mortality.tab ------ MAX_02062014 Position 34-1.tif.mortality.tab
# MAX_02062014 Position 33-1.tif.mortality.tab ------ MAX_02062014 Position 35-1.tif.mortality.tab
# MAX_02062014 Position 33-1.tif.mortality.tab ------ MAX_02062014 Position 43-1.tif.mortality.tab
# MAX_02062014 Position 33-1.tif.mortality.tab ------ MAX_02062014 Position 44-1.tif.mortality.tab
# MAX_02062014 Position 33-1.tif.mortality.tab ------ MAX_02062014 Position 47-1.tif.mortality.tab
# MAX_02062014 Position 33-1.tif.mortality.tab ------ MAX_02062014 Position 48-1.tif.mortality.tab
# MAX_02062014 Position 33-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# MAX_02062014 Position 34-1.tif.mortality.tab ------ MAX_02062014 Position 35-1.tif.mortality.tab
# MAX_02062014 Position 34-1.tif.mortality.tab ------ MAX_02062014 Position 43-1.tif.mortality.tab
# MAX_02062014 Position 34-1.tif.mortality.tab ------ MAX_02062014 Position 44-1.tif.mortality.tab
# MAX_02062014 Position 34-1.tif.mortality.tab ------ MAX_02062014 Position 47-1.tif.mortality.tab
# MAX_02062014 Position 34-1.tif.mortality.tab ------ MAX_02062014 Position 48-1.tif.mortality.tab
# MAX_02062014 Position 34-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# MAX_02062014 Position 35-1.tif.mortality.tab ------ MAX_02062014 Position 43-1.tif.mortality.tab
# MAX_02062014 Position 35-1.tif.mortality.tab ------ MAX_02062014 Position 44-1.tif.mortality.tab
# MAX_02062014 Position 35-1.tif.mortality.tab ------ MAX_02062014 Position 47-1.tif.mortality.tab
# MAX_02062014 Position 35-1.tif.mortality.tab ------ MAX_02062014 Position 48-1.tif.mortality.tab
# MAX_02062014 Position 35-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# MAX_02062014 Position 43-1.tif.mortality.tab ------ MAX_02062014 Position 44-1.tif.mortality.tab
# MAX_02062014 Position 43-1.tif.mortality.tab ------ MAX_02062014 Position 47-1.tif.mortality.tab
# MAX_02062014 Position 43-1.tif.mortality.tab ------ MAX_02062014 Position 48-1.tif.mortality.tab
# MAX_02062014 Position 43-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# MAX_02062014 Position 44-1.tif.mortality.tab ------ MAX_02062014 Position 47-1.tif.mortality.tab
# MAX_02062014 Position 44-1.tif.mortality.tab ------ MAX_02062014 Position 48-1.tif.mortality.tab
# MAX_02062014 Position 44-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# MAX_02062014 Position 47-1.tif.mortality.tab ------ MAX_02062014 Position 48-1.tif.mortality.tab
# MAX_02062014 Position 47-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# MAX_02062014 Position 48-1.tif.mortality.tab ------ MAX_02062014 Position 49-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_dentrogram-all-files.eps
# 3 [2 1 1]
# [['MAX_02062014 Position 33-1.tif.mortality.tab', 'MAX_02062014 Position 34-1.tif.mortality.tab', 'MAX_02062014 Position 35-1.tif.mortality.tab', 'MAX_02062014 Position 43-1.tif.mortality.tab', 'MAX_02062014 Position 44-1.tif.mortality.tab', 'MAX_02062014 Position 47-1.tif.mortality.tab', 'MAX_02062014 Position 48-1.tif.mortality.tab'], ['MAX_02062014 Position 31-1.tif.mortality.tab', 'MAX_02062014 Position 49-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 11.71761   sv2= 0.02316742   df= 12.67294   lambda= 505.7797
# phi= 11.99766   sv2= 0.007614222   df= 5.298986   lambda= 1575.691
# phi= 12.29735   sv2= 0.005299066   df= 4.199842   lambda= 2320.664
# phi= 12.45127   sv2= 0.004354291   df= 3.890931   lambda= 2859.541
# phi= 12.54374   sv2= 0.003844275   df= 3.736148   lambda= 3262.966
# phi= 12.6047   sv2= 0.003529615   df= 3.642382   lambda= 3571.127
# phi= 12.6472   sv2= 0.003319902   df= 3.580033   lambda= 3809.511
# phi= 12.67793   sv2= 0.003173075   df= 3.536256   lambda= 3995.472
# phi= 12.7007   sv2= 0.003066777   df= 3.504428   lambda= 4141.386
# phi= 12.71789   sv2= 0.002987977   df= 3.480731   lambda= 4256.355
# phi= 12.73103   sv2= 0.002928544   df= 3.462787   lambda= 4347.221
# phi= 12.74117   sv2= 0.002883138   df= 3.449031   lambda= 4419.201
# phi= 12.74905   sv2= 0.002848111   df= 3.438389   lambda= 4476.319
# phi= 12.75522   sv2= 0.002820889   df= 3.430098   lambda= 4521.704
# phi= 12.76007   sv2= 0.002799609   df= 3.423605   lambda= 4557.803
# phi= 12.76389   sv2= 0.002782902   df= 3.418499   lambda= 4586.539
# phi= 12.76691   sv2= 0.002769737   df= 3.414471   lambda= 4609.428
# phi= 12.7693   sv2= 0.002759337   df= 3.411285   lambda= 4627.669
# phi= 12.77119   sv2= 0.002751101   df= 3.40876   lambda= 4642.211
# phi= 12.7727   sv2= 0.00274457   df= 3.406756   lambda= 4653.807
# phi= 12.7739   sv2= 0.002739382   df= 3.405164   lambda= 4663.058
# phi= 12.77485   sv2= 0.002735258   df= 3.403897   lambda= 4670.438
# phi= 12.77561   sv2= 0.002731975   df= 3.402889   lambda= 4676.327
# phi= 12.77621   sv2= 0.002729362   df= 3.402086   lambda= 4681.026
# phi= 12.7767   sv2= 0.00272728   df= 3.401446   lambda= 4684.777
# phi= 12.77708   sv2= 0.00272562   df= 3.400936   lambda= 4687.77
# phi= 12.77739   sv2= 0.002724297   df= 3.400529   lambda= 4690.16
# phi= 12.77763   sv2= 0.002723241   df= 3.400205   lambda= 4692.068
# phi= 12.77783   sv2= 0.002722399   df= 3.399946   lambda= 4693.59
# phi= 12.77798   sv2= 0.002721728   df= 3.399739   lambda= 4694.806
# phi= 12.77811   sv2= 0.002721192   df= 3.399574   lambda= 4695.776
# phi= 12.77821   sv2= 0.002720764   df= 3.399443   lambda= 4696.551
# phi= 12.77829   sv2= 0.002720422   df= 3.399338   lambda= 4697.17
# phi= 12.77835   sv2= 0.00272015   df= 3.399254   lambda= 4697.664
# phi= 12.7784   sv2= 0.002719932   df= 3.399187   lambda= 4698.058
# Iterations: relative error in phi-hat = 1e-04
# phi= 1.226836   sv2= 0.01854396   df= 10.44473   lambda= 66.15826
# phi= 1.252521   sv2= 0.003290251   df= 6.837782   lambda= 380.6766
# phi= 1.262591   sv2= 0.001737712   df= 4.708115   lambda= 726.5825
# phi= 1.268564   sv2= 0.001336954   df= 4.126264   lambda= 948.8458
# phi= 1.272116   sv2= 0.001157117   df= 3.911556   lambda= 1099.384
# phi= 1.274358   sv2= 0.001057321   df= 3.798993   lambda= 1205.271
# phi= 1.275851   sv2= 0.0009955634   df= 3.730763   lambda= 1281.537
# phi= 1.276884   sv2= 0.0009547974   df= 3.6861   lambda= 1337.335
# phi= 1.277618   sv2= 0.0009267495   df= 3.655478   lambda= 1378.601
# phi= 1.278149   sv2= 0.0009069049   df= 3.633842   lambda= 1409.352
# phi= 1.278538   sv2= 0.0008925876   df= 3.618239   lambda= 1432.395
# phi= 1.278826   sv2= 0.0008821131   df= 3.606825   lambda= 1449.73
# phi= 1.27904   sv2= 0.000874372   df= 3.598388   lambda= 1462.81
# phi= 1.279201   sv2= 0.0008686082   df= 3.592105   lambda= 1472.702
# phi= 1.279322   sv2= 0.000864293   df= 3.587401   lambda= 1480.195
# phi= 1.279414   sv2= 0.0008610489   df= 3.583863   lambda= 1485.878
# phi= 1.279483   sv2= 0.0008586025   df= 3.581195   lambda= 1490.192
# phi= 1.279535   sv2= 0.0008567534   df= 3.579178   lambda= 1493.469
# phi= 1.279575   sv2= 0.0008553533   df= 3.577651   lambda= 1495.96
# phi= 1.279605   sv2= 0.0008542917   df= 3.576493   lambda= 1497.854
# phi= 1.279628   sv2= 0.000853486   df= 3.575614   lambda= 1499.295
# phi= 1.279645   sv2= 0.0008528741   df= 3.574947   lambda= 1500.391
# phi= 1.279658   sv2= 0.000852409   df= 3.574439   lambda= 1501.225
# phi= 1.279668   sv2= 0.0008520554   df= 3.574053   lambda= 1501.86
# phi= 1.279676   sv2= 0.0008517865   df= 3.57376   lambda= 1502.343
# phi= 1.279682   sv2= 0.0008515819   df= 3.573537   lambda= 1502.711
# phi= 1.279686   sv2= 0.0008514262   df= 3.573367   lambda= 1502.991
# phi= 1.279689   sv2= 0.0008513078   df= 3.573238   lambda= 1503.204
# phi= 1.279692   sv2= 0.0008512176   df= 3.573139   lambda= 1503.366
# phi= 1.279694   sv2= 0.0008511489   df= 3.573064   lambda= 1503.49
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/appB/CR-TA_appB-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 11.71761   sv2= 0.02316742   df= 12.67294   lambda= 505.7797
# phi= 11.99766   sv2= 0.007614222   df= 5.298986   lambda= 1575.691
# phi= 12.29735   sv2= 0.005299066   df= 4.199842   lambda= 2320.664
# phi= 12.45127   sv2= 0.004354291   df= 3.890931   lambda= 2859.541
# phi= 12.54374   sv2= 0.003844275   df= 3.736148   lambda= 3262.966
# phi= 12.6047   sv2= 0.003529615   df= 3.642382   lambda= 3571.127
# phi= 12.6472   sv2= 0.003319902   df= 3.580033   lambda= 3809.511
# phi= 12.67793   sv2= 0.003173075   df= 3.536256   lambda= 3995.472
# phi= 12.7007   sv2= 0.003066777   df= 3.504428   lambda= 4141.386
# phi= 12.71789   sv2= 0.002987977   df= 3.480731   lambda= 4256.355
# phi= 12.73103   sv2= 0.002928544   df= 3.462787   lambda= 4347.221
# phi= 12.74117   sv2= 0.002883138   df= 3.449031   lambda= 4419.201
# phi= 12.74905   sv2= 0.002848111   df= 3.438389   lambda= 4476.319
# phi= 12.75522   sv2= 0.002820889   df= 3.430098   lambda= 4521.704
# phi= 12.76007   sv2= 0.002799609   df= 3.423605   lambda= 4557.803
# phi= 12.76389   sv2= 0.002782902   df= 3.418499   lambda= 4586.539
# phi= 12.76691   sv2= 0.002769737   df= 3.414471   lambda= 4609.428
# phi= 12.7693   sv2= 0.002759337   df= 3.411285   lambda= 4627.669
# phi= 12.77119   sv2= 0.002751101   df= 3.40876   lambda= 4642.211
# phi= 12.7727   sv2= 0.00274457   df= 3.406756   lambda= 4653.807
# phi= 12.7739   sv2= 0.002739382   df= 3.405164   lambda= 4663.058
# phi= 12.77485   sv2= 0.002735258   df= 3.403897   lambda= 4670.438
# phi= 12.77561   sv2= 0.002731975   df= 3.402889   lambda= 4676.327
# phi= 12.77621   sv2= 0.002729362   df= 3.402086   lambda= 4681.026
# phi= 12.7767   sv2= 0.00272728   df= 3.401446   lambda= 4684.777
# phi= 12.77708   sv2= 0.00272562   df= 3.400936   lambda= 4687.77
# phi= 12.77739   sv2= 0.002724297   df= 3.400529   lambda= 4690.16
# phi= 12.77763   sv2= 0.002723241   df= 3.400205   lambda= 4692.068
# phi= 12.77783   sv2= 0.002722399   df= 3.399946   lambda= 4693.59
# phi= 12.77798   sv2= 0.002721728   df= 3.399739   lambda= 4694.806
# phi= 12.77811   sv2= 0.002721192   df= 3.399574   lambda= 4695.776
# phi= 12.77821   sv2= 0.002720764   df= 3.399443   lambda= 4696.551
# phi= 12.77829   sv2= 0.002720422   df= 3.399338   lambda= 4697.17
# phi= 12.77835   sv2= 0.00272015   df= 3.399254   lambda= 4697.664
# phi= 12.7784   sv2= 0.002719932   df= 3.399187   lambda= 4698.058
# Iterations: relative error in phi-hat = 1e-04
# phi= 1.226836   sv2= 0.01854396   df= 10.44473   lambda= 66.15826
# phi= 1.252521   sv2= 0.003290251   df= 6.837782   lambda= 380.6766
# phi= 1.262591   sv2= 0.001737712   df= 4.708115   lambda= 726.5825
# phi= 1.268564   sv2= 0.001336954   df= 4.126264   lambda= 948.8458
# phi= 1.272116   sv2= 0.001157117   df= 3.911556   lambda= 1099.384
# phi= 1.274358   sv2= 0.001057321   df= 3.798993   lambda= 1205.271
# phi= 1.275851   sv2= 0.0009955634   df= 3.730763   lambda= 1281.537
# phi= 1.276884   sv2= 0.0009547974   df= 3.6861   lambda= 1337.335
# phi= 1.277618   sv2= 0.0009267495   df= 3.655478   lambda= 1378.601
# phi= 1.278149   sv2= 0.0009069049   df= 3.633842   lambda= 1409.352
# phi= 1.278538   sv2= 0.0008925876   df= 3.618239   lambda= 1432.395
# phi= 1.278826   sv2= 0.0008821131   df= 3.606825   lambda= 1449.73
# phi= 1.27904   sv2= 0.000874372   df= 3.598388   lambda= 1462.81
# phi= 1.279201   sv2= 0.0008686082   df= 3.592105   lambda= 1472.702
# phi= 1.279322   sv2= 0.000864293   df= 3.587401   lambda= 1480.195
# phi= 1.279414   sv2= 0.0008610489   df= 3.583863   lambda= 1485.878
# phi= 1.279483   sv2= 0.0008586025   df= 3.581195   lambda= 1490.192
# phi= 1.279535   sv2= 0.0008567534   df= 3.579178   lambda= 1493.469
# phi= 1.279575   sv2= 0.0008553533   df= 3.577651   lambda= 1495.96
# phi= 1.279605   sv2= 0.0008542917   df= 3.576493   lambda= 1497.854
# phi= 1.279628   sv2= 0.000853486   df= 3.575614   lambda= 1499.295
# phi= 1.279645   sv2= 0.0008528741   df= 3.574947   lambda= 1500.391
# phi= 1.279658   sv2= 0.000852409   df= 3.574439   lambda= 1501.225
# phi= 1.279668   sv2= 0.0008520554   df= 3.574053   lambda= 1501.86
# phi= 1.279676   sv2= 0.0008517865   df= 3.57376   lambda= 1502.343
# phi= 1.279682   sv2= 0.0008515819   df= 3.573537   lambda= 1502.711
# phi= 1.279686   sv2= 0.0008514262   df= 3.573367   lambda= 1502.991
# phi= 1.279689   sv2= 0.0008513078   df= 3.573238   lambda= 1503.204
# phi= 1.279692   sv2= 0.0008512176   df= 3.573139   lambda= 1503.366
# phi= 1.279694   sv2= 0.0008511489   df= 3.573064   lambda= 1503.49
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est     L95%       U95%       var
# lifespan  79.152197  78.0524  81.027242  0.000326, 1:                 est       L95%       U95%       var
# lifespan  86.229245  84.002586  89.228711  0.000712}
