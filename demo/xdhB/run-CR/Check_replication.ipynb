# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/TA_xdhB-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/TA_xdhB-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/TA_xdhB-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB']
#
# out_name_s  ['TA_xdhB-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/TA_xdhB-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/TA_xdhB-1_analysis_metadata.pickle
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 36-1.tif.mortality.tab
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 37-1.tif.mortality.tab
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 41-1.tif.mortality.tab
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 42-1.tif.mortality.tab
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 45-1.tif.mortality.tab
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 46-1.tif.mortality.tab
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 51-1.tif.mortality.tab
# MAX_02062014 Position 32-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# MAX_02062014 Position 36-1.tif.mortality.tab ------ MAX_02062014 Position 37-1.tif.mortality.tab
# MAX_02062014 Position 36-1.tif.mortality.tab ------ MAX_02062014 Position 41-1.tif.mortality.tab
# MAX_02062014 Position 36-1.tif.mortality.tab ------ MAX_02062014 Position 42-1.tif.mortality.tab
# MAX_02062014 Position 36-1.tif.mortality.tab ------ MAX_02062014 Position 45-1.tif.mortality.tab
# MAX_02062014 Position 36-1.tif.mortality.tab ------ MAX_02062014 Position 46-1.tif.mortality.tab
# MAX_02062014 Position 36-1.tif.mortality.tab ------ MAX_02062014 Position 51-1.tif.mortality.tab
# MAX_02062014 Position 36-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# MAX_02062014 Position 37-1.tif.mortality.tab ------ MAX_02062014 Position 41-1.tif.mortality.tab
# MAX_02062014 Position 37-1.tif.mortality.tab ------ MAX_02062014 Position 42-1.tif.mortality.tab
# MAX_02062014 Position 37-1.tif.mortality.tab ------ MAX_02062014 Position 45-1.tif.mortality.tab
# MAX_02062014 Position 37-1.tif.mortality.tab ------ MAX_02062014 Position 46-1.tif.mortality.tab
# MAX_02062014 Position 37-1.tif.mortality.tab ------ MAX_02062014 Position 51-1.tif.mortality.tab
# MAX_02062014 Position 37-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# MAX_02062014 Position 41-1.tif.mortality.tab ------ MAX_02062014 Position 42-1.tif.mortality.tab
# MAX_02062014 Position 41-1.tif.mortality.tab ------ MAX_02062014 Position 45-1.tif.mortality.tab
# MAX_02062014 Position 41-1.tif.mortality.tab ------ MAX_02062014 Position 46-1.tif.mortality.tab
# MAX_02062014 Position 41-1.tif.mortality.tab ------ MAX_02062014 Position 51-1.tif.mortality.tab
# MAX_02062014 Position 41-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# MAX_02062014 Position 42-1.tif.mortality.tab ------ MAX_02062014 Position 45-1.tif.mortality.tab
# MAX_02062014 Position 42-1.tif.mortality.tab ------ MAX_02062014 Position 46-1.tif.mortality.tab
# MAX_02062014 Position 42-1.tif.mortality.tab ------ MAX_02062014 Position 51-1.tif.mortality.tab
# MAX_02062014 Position 42-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# MAX_02062014 Position 45-1.tif.mortality.tab ------ MAX_02062014 Position 46-1.tif.mortality.tab
# MAX_02062014 Position 45-1.tif.mortality.tab ------ MAX_02062014 Position 51-1.tif.mortality.tab
# MAX_02062014 Position 45-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# MAX_02062014 Position 46-1.tif.mortality.tab ------ MAX_02062014 Position 51-1.tif.mortality.tab
# MAX_02062014 Position 46-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# MAX_02062014 Position 51-1.tif.mortality.tab ------ MAX_02062014 Position 58-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_dentrogram-all-files.eps
# [['MAX_02062014 Position 32-1.tif.mortality.tab', 'MAX_02062014 Position 36-1.tif.mortality.tab', 'MAX_02062014 Position 51-1.tif.mortality.tab'], ['MAX_02062014 Position 37-1.tif.mortality.tab', 'MAX_02062014 Position 41-1.tif.mortality.tab', 'MAX_02062014 Position 42-1.tif.mortality.tab', 'MAX_02062014 Position 45-1.tif.mortality.tab', 'MAX_02062014 Position 46-1.tif.mortality.tab', 'MAX_02062014 Position 58-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 15.05168   sv2= 0.0261947   df= 11.78669   lambda= 574.6078
# phi= 15.11843   sv2= 0.002064037   df= 4.78437   lambda= 7324.687
# phi= 15.38149   sv2= 0.0009453086   df= 2.920107   lambda= 16271.4
# Iterations: relative error in phi-hat = 1e-04
# phi= 3.631368   sv2= 0.04493657   df= 9.674713   lambda= 80.81098
# phi= 3.71736   sv2= 0.01300472   df= 6.13486   lambda= 285.847
# phi= 3.793855   sv2= 0.009137071   df= 4.695011   lambda= 415.2156
# phi= 3.832016   sv2= 0.008085479   df= 4.34095   lambda= 473.9381
# phi= 3.848228   sv2= 0.007675224   df= 4.221946   lambda= 501.3832
# phi= 3.855589   sv2= 0.007494945   df= 4.17229   lambda= 514.4252
# phi= 3.859039   sv2= 0.007411663   df= 4.149833   lambda= 520.6712
# phi= 3.860681   sv2= 0.007372308   df= 4.139321   lambda= 523.6733
# phi= 3.861468   sv2= 0.007353511   df= 4.134323   lambda= 525.1189
# phi= 3.861846   sv2= 0.007344489   df= 4.131929   lambda= 525.8155
# phi= 3.862028   sv2= 0.007340147   df= 4.130778   lambda= 526.1514
# phi= 3.862116   sv2= 0.007338055   df= 4.130224   lambda= 526.3133
# phi= 3.862158   sv2= 0.007337047   df= 4.129956   lambda= 526.3914
# phi= 3.862179   sv2= 0.007336561   df= 4.129828   lambda= 526.4291
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/xdhB/CR-TA_xdhB-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 10.64588   sv2= 0.04202974   df= 12.7817   lambda= 253.2941
# phi= 10.60561   sv2= 0.004252773   df= 6.196877   lambda= 2493.812
# phi= 10.59283   sv2= 0.002385918   df= 3.809355   lambda= 4439.728
# phi= 10.63289   sv2= 0.001847526   df= 3.400385   lambda= 5755.206
# phi= 10.65636   sv2= 0.001621372   df= 3.238033   lambda= 6572.433
# phi= 10.66941   sv2= 0.00151176   df= 3.15986   lambda= 7057.613
# phi= 10.67668   sv2= 0.001454796   df= 3.11925   lambda= 7338.953
# phi= 10.68074   sv2= 0.001424087   df= 3.097348   lambda= 7500.063
# phi= 10.68302   sv2= 0.001407198   df= 3.085298   lambda= 7591.697
# phi= 10.6843   sv2= 0.001397806   df= 3.078595   lambda= 7643.62
# phi= 10.68502   sv2= 0.001392551   df= 3.074845   lambda= 7672.98
# phi= 10.68542   sv2= 0.001389601   df= 3.072739   lambda= 7689.562
# phi= 10.68565   sv2= 0.001387942   df= 3.071554   lambda= 7698.921
# phi= 10.68578   sv2= 0.001387007   df= 3.070887   lambda= 7704.202
# phi= 10.68586   sv2= 0.001386481   df= 3.070511   lambda= 7707.18
# phi= 10.6859   sv2= 0.001386184   df= 3.070299   lambda= 7708.86
# phi= 10.68592   sv2= 0.001386016   df= 3.070179   lambda= 7709.808
# phi= 10.68593   sv2= 0.001385922   df= 3.070112   lambda= 7710.342
# No error in flxsrv_fit
# {0:                est       L95%       U95%       var
# lifespan  90.05289  89.002925  91.128185  0.000221}
