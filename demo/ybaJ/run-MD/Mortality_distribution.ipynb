# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/app/src/ms2'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/app/src/ms2/dataset/MS 2 Github data part 10/ybaJ'
ref_df_path = '/app/src/ms2/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/app/src/ms2/dataset/MS 2 Github data part 10/ybaJ/TA_ybaJ-1_df_relative_timegrid.pickle']]
# []
# [['/app/src/ms2/dataset/MS 2 Github data part 10/ybaJ/TA_ybaJ-1_timeseries_dataframe.pickle']]
# /app/src/ms2/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /app/src/ms2/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.32831027777777
# files will be written into :  /app/src/ms2/dataset/MS 2 Github data part 10/ybaJ
# Iterations: relative error in phi-hat = 1e-04
# phi= 72.80071   sv2= 0.1477619   df= 14.43005   lambda= 492.6893
# phi= 75.39525   sv2= 0.02446247   df= 6.265946   lambda= 3082.078
# phi= 76.02817   sv2= 0.01050386   df= 4.304158   lambda= 7238.115
# phi= 76.28561   sv2= 0.006043977   df= 3.623853   lambda= 12621.76
# save file prefixed name is : TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe
# biName is :  TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe
# getGGMfit_dict--(1) /app/src/ms2/demo/ybaJ/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ybaJ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /app/src/ms2/demo/ybaJ/run-MD
# getKMNABSfits_dict-- /app/src/ms2/demo/ybaJ/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ybaJ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 72.80071   sv2= 0.1477619   df= 14.43005   lambda= 492.6893
# phi= 75.39525   sv2= 0.02446247   df= 6.265946   lambda= 3082.078
# phi= 76.02817   sv2= 0.01050386   df= 4.304158   lambda= 7238.115
# phi= 76.28561   sv2= 0.006043977   df= 3.623853   lambda= 12621.76
# getKMNABSfits_dict-- /app/src/ms2/demo/ybaJ/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybaJ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ybaJ-1_df_relative_timegrid.pickle
# /app/src/ms2/dataset/MS 2 Github data part 10/ybaJ/MD-TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ybaJ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=23371.550567)
#                  est          L95%          U95%            se
# rate    1.818532e-01  1.674097e-01  1.975429e-01  7.678418e-03
# beta    9.655281e+06  3.175515e+06  2.935727e+07  5.478168e+06
# s       4.439330e-01  3.682801e-01  5.351267e-01  4.231709e-02
# lambda  3.891323e-04  3.164445e-04  4.785166e-04  4.105253e-05
#                 est       L95%       U95%       var
# lifespan  94.686548  94.531875  95.695593  0.000064
#
#
# /app/src/ms2/dataset/MS 2 Github data part 10/ybaJ/MD-TA_ybaJ-1_df_relative_timegrid-vs-TA_ybaJ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ybaJ-1_df_relative_timegrid.pickle
# working directory is :  /app/src/ms2/demo/ybaJ/run-MD
