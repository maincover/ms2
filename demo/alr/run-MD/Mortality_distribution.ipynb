# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/TA_alr-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/TA_alr-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.34063   sv2= 0.2593263   df= 16.92775   lambda= 116.9979
# phi= 31.37009   sv2= 0.06962816   df= 9.903603   lambda= 450.5374
# phi= 31.69705   sv2= 0.03314063   df= 7.374941   lambda= 956.4408
# phi= 31.75471   sv2= 0.02306866   df= 6.290436   lambda= 1376.53
# phi= 31.77768   sv2= 0.0192478   df= 5.835709   lambda= 1650.978
# phi= 31.79582   sv2= 0.01747915   df= 5.623829   lambda= 1819.072
# phi= 31.80843   sv2= 0.01656715   df= 5.514706   lambda= 1919.97
# phi= 31.81651   sv2= 0.01606845   df= 5.45508   lambda= 1980.061
# phi= 31.82148   sv2= 0.01578664   df= 5.421396   lambda= 2015.722
# phi= 31.82448   sv2= 0.01562438   df= 5.402003   lambda= 2036.847
# phi= 31.82628   sv2= 0.01552994   df= 5.390715   lambda= 2049.35
# phi= 31.82735   sv2= 0.01547462   df= 5.384103   lambda= 2056.745
# phi= 31.82799   sv2= 0.0154421   df= 5.380216   lambda= 2061.118
# phi= 31.82836   sv2= 0.01542293   df= 5.377926   lambda= 2063.703
# phi= 31.82858   sv2= 0.01541163   df= 5.376574   lambda= 2065.232
# phi= 31.82872   sv2= 0.01540495   df= 5.375776   lambda= 2066.135
# phi= 31.82879   sv2= 0.01540101   df= 5.375305   lambda= 2066.669
# phi= 31.82884   sv2= 0.01539868   df= 5.375027   lambda= 2066.985
# phi= 31.82887   sv2= 0.0153973   df= 5.374862   lambda= 2067.172
# save file prefixed name is : TA_alr-1_df_relative_timegrid-vs-TA_alr-1_timeseries_dataframe
# biName is :  TA_alr-1_df_relative_timegrid-vs-TA_alr-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/alr/run-MD
# No error in flxsrv_fit
# TA_alr-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/alr/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/alr/run-MD
# TA_alr-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.34063   sv2= 0.2593263   df= 16.92775   lambda= 116.9979
# phi= 31.37009   sv2= 0.06962816   df= 9.903603   lambda= 450.5374
# phi= 31.69705   sv2= 0.03314063   df= 7.374941   lambda= 956.4408
# phi= 31.75471   sv2= 0.02306866   df= 6.290436   lambda= 1376.53
# phi= 31.77768   sv2= 0.0192478   df= 5.835709   lambda= 1650.978
# phi= 31.79582   sv2= 0.01747915   df= 5.623829   lambda= 1819.072
# phi= 31.80843   sv2= 0.01656715   df= 5.514706   lambda= 1919.97
# phi= 31.81651   sv2= 0.01606845   df= 5.45508   lambda= 1980.061
# phi= 31.82148   sv2= 0.01578664   df= 5.421396   lambda= 2015.722
# phi= 31.82448   sv2= 0.01562438   df= 5.402003   lambda= 2036.847
# phi= 31.82628   sv2= 0.01552994   df= 5.390715   lambda= 2049.35
# phi= 31.82735   sv2= 0.01547462   df= 5.384103   lambda= 2056.745
# phi= 31.82799   sv2= 0.0154421   df= 5.380216   lambda= 2061.118
# phi= 31.82836   sv2= 0.01542293   df= 5.377926   lambda= 2063.703
# phi= 31.82858   sv2= 0.01541163   df= 5.376574   lambda= 2065.232
# phi= 31.82872   sv2= 0.01540495   df= 5.375776   lambda= 2066.135
# phi= 31.82879   sv2= 0.01540101   df= 5.375305   lambda= 2066.669
# phi= 31.82884   sv2= 0.01539868   df= 5.375027   lambda= 2066.985
# phi= 31.82887   sv2= 0.0153973   df= 5.374862   lambda= 2067.172
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/alr/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_alr-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_alr-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MD-TA_alr-1_df_relative_timegrid-vs-TA_alr-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_alr-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=27169.734228)
#                  est          L95%          U95%            se
# rate    2.097551e-01  1.800481e-01  2.443635e-01  1.634367e-02
# beta    1.959451e+10  6.612596e+08  5.806266e+11  3.387972e+10
# s       3.080956e-01  2.466624e-01  3.848293e-01  3.495843e-02
# lambda  2.235755e-03  2.063481e-03  2.422411e-03  9.146720e-05
#                  est        L95%        U95%       var
# lifespan  118.266497  117.366716  118.301704  0.000077
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MD-TA_alr-1_df_relative_timegrid-vs-TA_alr-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_alr-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/alr/run-MD
