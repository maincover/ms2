# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  831  Filtered files length (after MD5 check) :  44
# check line duplication(open file) :  50 / 831
# check line duplication(open file) :  100 / 831
# check line duplication(open file) :  150 / 831
# check line duplication(open file) :  200 / 831
# check line duplication(open file) :  250 / 831
# check line duplication(open file) :  300 / 831
# check line duplication(open file) :  350 / 831
# check line duplication(open file) :  400 / 831
# check line duplication(open file) :  450 / 831
# check line duplication(open file) :  500 / 831
# check line duplication(open file) :  550 / 831
# check line duplication(open file) :  600 / 831
# check line duplication(open file) :  650 / 831
# check line duplication(open file) :  700 / 831
# check line duplication(open file) :  750 / 831
# check line duplication(open file) :  800 / 831
# check line duplication:  0 / 831
# check line duplication:  50 / 831
# check line duplication:  100 / 831
# check line duplication:  150 / 831
# check line duplication:  200 / 831
# check line duplication:  250 / 831
# check line duplication:  300 / 831
# check line duplication:  350 / 831
# check line duplication:  400 / 831
# check line duplication:  450 / 831
# check line duplication:  500 / 831
# check line duplication:  550 / 831
# check line duplication:  600 / 831
# check line duplication:  650 / 831
# check line duplication:  700 / 831
# check line duplication:  750 / 831
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 116-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 117-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 118-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 119-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 120-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 121-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 122-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 123-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 124-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 125-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 126-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 127-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 128-1.tif.mortality.tab
# check line duplication:  800 / 831
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 129-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 130-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 133-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 134-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 137-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 141-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 142-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 143-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 144-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 145-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 146-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 147-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 149-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 150-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 151-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 152-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 153-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 159-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 184-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 186-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 196-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 197-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 198-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 199-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 206-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 210-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 212-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 213-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 29-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 38-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/alr/MAX_12072018 Position 4-1.tif.mortality.tab
