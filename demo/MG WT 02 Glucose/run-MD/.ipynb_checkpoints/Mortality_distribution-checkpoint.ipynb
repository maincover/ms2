# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose'
ref_df_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database/WT/WT-1_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/TA_MG WT 02 Glucose-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/TA_MG WT 02 Glucose-1_timeseries_dataframe.pickle']]
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# WT-1_df_relative_timegrid
# load reference pickle,  WT-1_df_relative_timegrid 112.602349444
# files will be written into :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.37408   sv2= 0.1630464   df= 21.29152   lambda= 204.6907
# phi= 33.82717   sv2= 0.02758153   df= 11.22593   lambda= 1226.442
# phi= 34.15136   sv2= 0.009420048   df= 7.536874   lambda= 3625.391
# phi= 34.43121   sv2= 0.004189088   df= 5.978077   lambda= 8219.264
# phi= 34.63867   sv2= 0.002258396   df= 5.048954   lambda= 15337.73
# /home/xsong/coliSurvivalAnalysis/xsong/main/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_MG WT 02 Glucose-1_df_relative_timegrid-vs-TA_MG WT 02 Glucose-1_timeseries_dataframe
# biName is :  TA_MG WT 02 Glucose-1_df_relative_timegrid-vs-TA_MG WT 02 Glucose-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG WT 02 Glucose/run-MD
# No error in flxsrv_fit
# TA_MG WT 02 Glucose-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# WT-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG WT 02 Glucose/run-MD
# getKMNABSfits_dict-- /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG WT 02 Glucose/run-MD
# TA_MG WT 02 Glucose-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.37408   sv2= 0.1630464   df= 21.29152   lambda= 204.6907
# phi= 33.82717   sv2= 0.02758153   df= 11.22593   lambda= 1226.442
# phi= 34.15136   sv2= 0.009420048   df= 7.536874   lambda= 3625.391
# phi= 34.43121   sv2= 0.004189088   df= 5.978077   lambda= 8219.264
# phi= 34.63867   sv2= 0.002258396   df= 5.048954   lambda= 15337.73
# WT-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.715   sv2= 0.42506   df= 17.31378   lambda= 119.3126
# phi= 55.04413   sv2= 0.04353927   df= 10.05507   lambda= 1264.241
# phi= 57.89357   sv2= 0.003954065   df= 5.965454   lambda= 14641.53
# getKMNABSfits_dict-- /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG WT 02 Glucose/run-MD
# 0 WT-1_df_relative_timegrid.pickle
# 1 TA_MG WT 02 Glucose-1_df_relative_timegrid.pickle
# TA_MG WT 02 Glucose-1_df_relative_timegrid.pickle
# WT-1_df_relative_timegrid.pickle
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MD-TA_MG WT 02 Glucose-1_df_relative_timegrid-vs-TA_MG WT 02 Glucose-1_timeseries_dataframe-vs-WT-1_df_relative_timegrid_GG_GGM_parameters.txt
# TA_MG WT 02 Glucose-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=78998.352219)
#                  est          L95%       U95%        se
# rate    4.277767e-02  4.049926e-02   0.045184  0.001195
# beta    6.266686e+01  5.662143e+01  69.357758  3.243557
# s       7.807100e-01  6.677902e-01   0.912724  0.062231
# lambda  4.560760e-07  8.726538e-12   0.023836  0.000003
#                  est        L95%        U95%       var
# lifespan  107.337394  106.105134  108.170254  0.000025
#
#
# WT-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=27003.675001)
#                est        L95%        U95%         se
# rate      0.070890    0.062119    0.080899   0.004777
# beta    208.286774  144.098661  301.067198  39.152006
# s         1.321167    0.957716    1.822546   0.216864
# lambda    0.000213    0.000017    0.002687   0.000275
#                 est      L95%       U95%       var
# lifespan  69.946437  68.94717  70.947297  0.000077
#
#
# /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MD-TA_MG WT 02 Glucose-1_df_relative_timegrid-vs-TA_MG WT 02 Glucose-1_timeseries_dataframe-vs-WT-1_df_relative_timegrid_GG_GGM_parameters.txt
# 0 WT-1_df_relative_timegrid.pickle
# 1 TA_MG WT 02 Glucose-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/coliSurvivalAnalysis/xsong/main/demo/MG WT 02 Glucose/run-MD
