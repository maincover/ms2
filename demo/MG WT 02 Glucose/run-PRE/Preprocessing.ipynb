# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/coliSurvivalAnalysis/xsong/main'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  817  Filtered files length (after MD5 check) :  30
# check line duplication(open file) :  50 / 817
# check line duplication(open file) :  100 / 817
# check line duplication(open file) :  150 / 817
# check line duplication(open file) :  200 / 817
# check line duplication(open file) :  250 / 817
# check line duplication(open file) :  300 / 817
# check line duplication(open file) :  350 / 817
# check line duplication(open file) :  400 / 817
# check line duplication(open file) :  450 / 817
# check line duplication(open file) :  500 / 817
# check line duplication(open file) :  550 / 817
# check line duplication(open file) :  600 / 817
# check line duplication(open file) :  650 / 817
# check line duplication(open file) :  700 / 817
# check line duplication(open file) :  750 / 817
# check line duplication(open file) :  800 / 817
# check line duplication:  0 / 817
# check line duplication:  50 / 817
# check line duplication:  100 / 817
# check line duplication:  150 / 817
# check line duplication:  200 / 817
# check line duplication:  250 / 817
# check line duplication:  300 / 817
# check line duplication:  350 / 817
# check line duplication:  400 / 817
# check line duplication:  450 / 817
# check line duplication:  500 / 817
# check line duplication:  550 / 817
# check line duplication:  600 / 817
# check line duplication:  650 / 817
# check line duplication:  700 / 817
# check line duplication:  750 / 817
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 10-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 12-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 13-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 14-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 15-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 154-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 155-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 16-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 177-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 193-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 202-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 215-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 242-1.tif.mortality.tab
# check line duplication:  800 / 817
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 244-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 245-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 246-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 262-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 264-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 3-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 4-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 42-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 49-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 50-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 51-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 6-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 7-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 8-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 87-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 88-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/coliSurvivalAnalysis/xsong/main/test dataset/05.10.2018/MG WT 02 Glucose/MAX_08112018 Position 9-1.tif.mortality.tab
