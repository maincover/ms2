# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/TA_agaV-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/TA_agaV-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/TA_agaV-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV']
#
# out_name_s  ['TA_agaV-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/TA_agaV-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/TA_agaV-1_analysis_metadata.pickle
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 104-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 18-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 19-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 21-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 24-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 53-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 7-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 10-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 18-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 19-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 21-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 24-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 53-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 7-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 104-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 18-1.tif.mortality.tab ------ MAX_01112018 Position 19-1.tif.mortality.tab
# MAX_01112018 Position 18-1.tif.mortality.tab ------ MAX_01112018 Position 21-1.tif.mortality.tab
# MAX_01112018 Position 18-1.tif.mortality.tab ------ MAX_01112018 Position 24-1.tif.mortality.tab
# MAX_01112018 Position 18-1.tif.mortality.tab ------ MAX_01112018 Position 53-1.tif.mortality.tab
# MAX_01112018 Position 18-1.tif.mortality.tab ------ MAX_01112018 Position 7-1.tif.mortality.tab
# MAX_01112018 Position 18-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 18-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 19-1.tif.mortality.tab ------ MAX_01112018 Position 21-1.tif.mortality.tab
# MAX_01112018 Position 19-1.tif.mortality.tab ------ MAX_01112018 Position 24-1.tif.mortality.tab
# MAX_01112018 Position 19-1.tif.mortality.tab ------ MAX_01112018 Position 53-1.tif.mortality.tab
# MAX_01112018 Position 19-1.tif.mortality.tab ------ MAX_01112018 Position 7-1.tif.mortality.tab
# MAX_01112018 Position 19-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 19-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 21-1.tif.mortality.tab ------ MAX_01112018 Position 24-1.tif.mortality.tab
# MAX_01112018 Position 21-1.tif.mortality.tab ------ MAX_01112018 Position 53-1.tif.mortality.tab
# MAX_01112018 Position 21-1.tif.mortality.tab ------ MAX_01112018 Position 7-1.tif.mortality.tab
# MAX_01112018 Position 21-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 21-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 24-1.tif.mortality.tab ------ MAX_01112018 Position 53-1.tif.mortality.tab
# MAX_01112018 Position 24-1.tif.mortality.tab ------ MAX_01112018 Position 7-1.tif.mortality.tab
# MAX_01112018 Position 24-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 24-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 53-1.tif.mortality.tab ------ MAX_01112018 Position 7-1.tif.mortality.tab
# MAX_01112018 Position 53-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 53-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 7-1.tif.mortality.tab ------ MAX_01112018 Position 8-1.tif.mortality.tab
# MAX_01112018 Position 7-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# MAX_01112018 Position 8-1.tif.mortality.tab ------ MAX_01112018 Position 9-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_dentrogram-all-files.eps
# [['MAX_01112018 Position 10-1.tif.mortality.tab', 'MAX_01112018 Position 19-1.tif.mortality.tab', 'MAX_01112018 Position 53-1.tif.mortality.tab', 'MAX_01112018 Position 7-1.tif.mortality.tab', 'MAX_01112018 Position 8-1.tif.mortality.tab', 'MAX_01112018 Position 9-1.tif.mortality.tab'], ['MAX_01112018 Position 21-1.tif.mortality.tab', 'MAX_01112018 Position 24-1.tif.mortality.tab'], ['MAX_01112018 Position 104-1.tif.mortality.tab', 'MAX_01112018 Position 18-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 72.60143   sv2= 0.1270804   df= 13.65964   lambda= 571.303
# phi= 77.09723   sv2= 0.0110211   df= 5.564409   lambda= 6995.422
# phi= 81.52278   sv2= 0.002536576   df= 3.412277   lambda= 32138.91
# Iterations: relative error in phi-hat = 1e-04
# phi= 5.382819   sv2= 0.08012622   df= 13.37628   lambda= 67.17925
# phi= 5.751889   sv2= 0.02165395   df= 8.751899   lambda= 265.6276
# phi= 6.037993   sv2= 0.00512974   df= 6.496803   lambda= 1177.056
# phi= 6.222233   sv2= 0.001034358   df= 4.761834   lambda= 6015.552
# phi= 6.361098   sv2= 0.0004101842   df= 3.471545   lambda= 15507.91
# Iterations: relative error in phi-hat = 1e-04
# phi= 106.8069   sv2= 0.1930129   df= 12.77331   lambda= 553.3667
# phi= 123.8623   sv2= 0.01044859   df= 5.350611   lambda= 11854.45
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaV/CR-TA_agaV-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 92.10334   sv2= 0.1361413   df= 16.68097   lambda= 676.5274
# phi= 99.35217   sv2= 0.01086748   df= 6.555111   lambda= 9142.153
# phi= 107.3401   sv2= 0.002377603   df= 3.835002   lambda= 45146.36
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  88.963129  87.524263  92.259952  0.000095}
