# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/TA_yoaF-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/TA_yoaF-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/TA_yoaF-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF']
#
# out_name_s  ['TA_yoaF-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/TA_yoaF-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/TA_yoaF-1_analysis_metadata.pickle
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 30-1.tif.mortality.tab
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 31-1.tif.mortality.tab
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 41-1.tif.mortality.tab
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 44-1.tif.mortality.tab
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 45-1.tif.mortality.tab
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 46-1.tif.mortality.tab
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 49-1.tif.mortality.tab
# MAX_12072015 Position 29-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# MAX_12072015 Position 30-1.tif.mortality.tab ------ MAX_12072015 Position 31-1.tif.mortality.tab
# MAX_12072015 Position 30-1.tif.mortality.tab ------ MAX_12072015 Position 41-1.tif.mortality.tab
# MAX_12072015 Position 30-1.tif.mortality.tab ------ MAX_12072015 Position 44-1.tif.mortality.tab
# MAX_12072015 Position 30-1.tif.mortality.tab ------ MAX_12072015 Position 45-1.tif.mortality.tab
# MAX_12072015 Position 30-1.tif.mortality.tab ------ MAX_12072015 Position 46-1.tif.mortality.tab
# MAX_12072015 Position 30-1.tif.mortality.tab ------ MAX_12072015 Position 49-1.tif.mortality.tab
# MAX_12072015 Position 30-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# MAX_12072015 Position 31-1.tif.mortality.tab ------ MAX_12072015 Position 41-1.tif.mortality.tab
# MAX_12072015 Position 31-1.tif.mortality.tab ------ MAX_12072015 Position 44-1.tif.mortality.tab
# MAX_12072015 Position 31-1.tif.mortality.tab ------ MAX_12072015 Position 45-1.tif.mortality.tab
# MAX_12072015 Position 31-1.tif.mortality.tab ------ MAX_12072015 Position 46-1.tif.mortality.tab
# MAX_12072015 Position 31-1.tif.mortality.tab ------ MAX_12072015 Position 49-1.tif.mortality.tab
# MAX_12072015 Position 31-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# MAX_12072015 Position 41-1.tif.mortality.tab ------ MAX_12072015 Position 44-1.tif.mortality.tab
# MAX_12072015 Position 41-1.tif.mortality.tab ------ MAX_12072015 Position 45-1.tif.mortality.tab
# MAX_12072015 Position 41-1.tif.mortality.tab ------ MAX_12072015 Position 46-1.tif.mortality.tab
# MAX_12072015 Position 41-1.tif.mortality.tab ------ MAX_12072015 Position 49-1.tif.mortality.tab
# MAX_12072015 Position 41-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# MAX_12072015 Position 44-1.tif.mortality.tab ------ MAX_12072015 Position 45-1.tif.mortality.tab
# MAX_12072015 Position 44-1.tif.mortality.tab ------ MAX_12072015 Position 46-1.tif.mortality.tab
# MAX_12072015 Position 44-1.tif.mortality.tab ------ MAX_12072015 Position 49-1.tif.mortality.tab
# MAX_12072015 Position 44-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# MAX_12072015 Position 45-1.tif.mortality.tab ------ MAX_12072015 Position 46-1.tif.mortality.tab
# MAX_12072015 Position 45-1.tif.mortality.tab ------ MAX_12072015 Position 49-1.tif.mortality.tab
# MAX_12072015 Position 45-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# MAX_12072015 Position 46-1.tif.mortality.tab ------ MAX_12072015 Position 49-1.tif.mortality.tab
# MAX_12072015 Position 46-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# MAX_12072015 Position 49-1.tif.mortality.tab ------ MAX_12072015 Position 50-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_dentrogram-all-files.eps
# [['MAX_12072015 Position 29-1.tif.mortality.tab', 'MAX_12072015 Position 49-1.tif.mortality.tab'], ['MAX_12072015 Position 30-1.tif.mortality.tab', 'MAX_12072015 Position 31-1.tif.mortality.tab'], ['MAX_12072015 Position 44-1.tif.mortality.tab', 'MAX_12072015 Position 45-1.tif.mortality.tab'], ['MAX_12072015 Position 41-1.tif.mortality.tab', 'MAX_12072015 Position 46-1.tif.mortality.tab', 'MAX_12072015 Position 50-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 78.14827   sv2= 0.2759867   df= 12.56103   lambda= 283.1595
# phi= 86.96044   sv2= 0.01790245   df= 6.052593   lambda= 4857.46
# phi= 98.06354   sv2= 0.00214989   df= 3.381399   lambda= 45613.29
# Iterations: relative error in phi-hat = 1e-04
# phi= 136.9772   sv2= 0.1985322   df= 11.93287   lambda= 689.9497
# phi= 159.4294   sv2= 0.008503951   df= 4.815573   lambda= 18747.69
# Iterations: relative error in phi-hat = 1e-04
# phi= 272.856   sv2= 0.11323   df= 9.523103   lambda= 2409.75
# phi= 371.9129   sv2= 0.002852903   df= 3.239007   lambda= 130363
# Iterations: relative error in phi-hat = 1e-04
# phi= 2.478262   sv2= 0.1732641   df= 9.335731   lambda= 14.30338
# phi= 2.574704   sv2= 0.1182084   df= 8.643283   lambda= 21.78106
# phi= 2.684817   sv2= 0.07400594   df= 7.896395   lambda= 36.2784
# phi= 2.803636   sv2= 0.04196014   df= 7.081068   lambda= 66.81665
# phi= 2.91748   sv2= 0.02234798   df= 6.224696   lambda= 130.5478
# phi= 3.010301   sv2= 0.0122485   df= 5.418931   lambda= 245.769
# phi= 3.077286   sv2= 0.007421005   df= 4.769247   lambda= 414.6724
# phi= 3.124194   sv2= 0.00513876   df= 4.302153   lambda= 607.9664
# phi= 3.156535   sv2= 0.004095099   df= 3.995438   lambda= 770.8079
# phi= 3.176901   sv2= 0.003640026   df= 3.818554   lambda= 872.7688
# phi= 3.18796   sv2= 0.003447508   df= 3.72975   lambda= 924.7142
# phi= 3.193247   sv2= 0.003366995   df= 3.689273   lambda= 948.3969
# phi= 3.195593   sv2= 0.003333434   df= 3.671733   lambda= 958.6489
# phi= 3.196597   sv2= 0.003319458   df= 3.664306   lambda= 962.9876
# phi= 3.19702   sv2= 0.003313639   df= 3.661193   lambda= 964.8063
# phi= 3.197197   sv2= 0.003311217   df= 3.659892   lambda= 965.5655
# phi= 3.197271   sv2= 0.003310209   df= 3.659351   lambda= 965.8819
# phi= 3.197301   sv2= 0.003309789   df= 3.659125   lambda= 966.0137
# phi= 3.197314   sv2= 0.003309614   df= 3.659031   lambda= 966.0686
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_mortality_dataframe_cluster2.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yoaF/CR-TA_yoaF-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 78.14827   sv2= 0.2759867   df= 12.56103   lambda= 283.1595
# phi= 86.96044   sv2= 0.01790245   df= 6.052593   lambda= 4857.46
# phi= 98.06354   sv2= 0.00214989   df= 3.381399   lambda= 45613.29
# Iterations: relative error in phi-hat = 1e-04
# phi= 86.39871   sv2= 0.19999   df= 11.07825   lambda= 432.0151
# phi= 100.3753   sv2= 0.01047008   df= 5.001315   lambda= 9586.868
# phi= 110.5008   sv2= 0.001380968   df= 2.828912   lambda= 80016.87
# Iterations: relative error in phi-hat = 1e-04
# phi= 136.9772   sv2= 0.1985322   df= 11.93287   lambda= 689.9497
# phi= 159.4294   sv2= 0.008503951   df= 4.815573   lambda= 18747.69
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  118.419703  114.327228  119.831696  0.000207, 1:                  est        L95%       U95%       var
# lifespan  129.501075  128.120568  134.87819  0.000383, 2:                  est       L95%        U95%       var
# lifespan  111.558699  104.68468  114.320249  0.000323}
