# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/TA_eutQ-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/TA_eutQ-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/TA_eutQ-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ']
#
# out_name_s  ['TA_eutQ-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/TA_eutQ-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/TA_eutQ-1_analysis_metadata.pickle
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 28-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 29-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 31-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 50-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 81-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 85-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 86-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 27-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 29-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 31-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 50-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 81-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 85-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 86-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 28-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 31-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 50-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 81-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 85-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 86-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 29-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 50-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 81-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 85-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 86-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 31-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 81-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 85-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 86-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 50-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 85-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 86-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 81-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 85-1.tif.mortality.tab ------ MAX_05072014 Position 86-1.tif.mortality.tab
# MAX_05072014 Position 85-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 85-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 85-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 85-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 85-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 85-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 86-1.tif.mortality.tab ------ MAX_05072014 Position 87-1.tif.mortality.tab
# MAX_05072014 Position 86-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 86-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 86-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 86-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 86-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 87-1.tif.mortality.tab ------ MAX_05072014 Position 88-1.tif.mortality.tab
# MAX_05072014 Position 87-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 87-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 87-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 87-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 88-1.tif.mortality.tab ------ MAX_05072014 Position 90-1.tif.mortality.tab
# MAX_05072014 Position 88-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 88-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 88-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 90-1.tif.mortality.tab ------ MAX_05072014 Position 91-1.tif.mortality.tab
# MAX_05072014 Position 90-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 90-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 91-1.tif.mortality.tab ------ MAX_05072014 Position 93-1.tif.mortality.tab
# MAX_05072014 Position 91-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# MAX_05072014 Position 93-1.tif.mortality.tab ------ MAX_05072014 Position 97-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_dentrogram-all-files.eps
# [['MAX_05072014 Position 27-1.tif.mortality.tab', 'MAX_05072014 Position 29-1.tif.mortality.tab', 'MAX_05072014 Position 86-1.tif.mortality.tab', 'MAX_05072014 Position 87-1.tif.mortality.tab', 'MAX_05072014 Position 93-1.tif.mortality.tab', 'MAX_05072014 Position 97-1.tif.mortality.tab'], ['MAX_05072014 Position 28-1.tif.mortality.tab', 'MAX_05072014 Position 31-1.tif.mortality.tab', 'MAX_05072014 Position 88-1.tif.mortality.tab', 'MAX_05072014 Position 90-1.tif.mortality.tab'], ['MAX_05072014 Position 50-1.tif.mortality.tab', 'MAX_05072014 Position 81-1.tif.mortality.tab', 'MAX_05072014 Position 85-1.tif.mortality.tab', 'MAX_05072014 Position 91-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 28.58495   sv2= 0.1015524   df= 11.8354   lambda= 281.4799
# phi= 32.09247   sv2= 0.005446738   df= 5.565835   lambda= 5892.054
# phi= 33.8744   sv2= 0.001409432   df= 3.04795   lambda= 24034.07
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.29185   sv2= 0.1019971   df= 11.24452   lambda= 385.2254
# phi= 39.4208   sv2= 0.003277453   df= 5.073574   lambda= 12027.88
# Iterations: relative error in phi-hat = 1e-04
# phi= 39.01659   sv2= 0.08601905   df= 10.49273   lambda= 453.5808
# phi= 39.33582   sv2= 0.003066817   df= 4.678199   lambda= 12826.27
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/eutQ/CR-TA_eutQ-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 40.14148   sv2= 0.1233593   df= 12.38694   lambda= 325.403
# phi= 43.17033   sv2= 0.006913856   df= 5.614517   lambda= 6244.03
# phi= 44.83987   sv2= 0.001314593   df= 3.122447   lambda= 34109.32
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.23666   sv2= 0.09664934   df= 12.02193   lambda= 343.8892
# phi= 34.1742   sv2= 0.003042155   df= 5.587106   lambda= 11233.55
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  123.358431  122.321711  125.356163  0.000234, 1:                  est        L95%        U95%      var
# lifespan  132.837017  131.366513  135.467522  0.00025}
