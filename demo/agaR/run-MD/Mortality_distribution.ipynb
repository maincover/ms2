# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/TA_agaR-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/TA_agaR-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR
# Iterations: relative error in phi-hat = 1e-04
# phi= 78.06503   sv2= 0.2361329   df= 20.16037   lambda= 330.5978
# phi= 79.84202   sv2= 0.01028818   df= 9.659558   lambda= 7760.556
# phi= 80.23639   sv2= 0.003150998   df= 4.882388   lambda= 25463.8
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# save file prefixed name is : TA_agaR-1_df_relative_timegrid-vs-TA_agaR-1_timeseries_dataframe
# biName is :  TA_agaR-1_df_relative_timegrid-vs-TA_agaR-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/agaR/run-MD
# No error in flxsrv_fit
# TA_agaR-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/agaR/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/agaR/run-MD
# TA_agaR-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 78.06503   sv2= 0.2361329   df= 20.16037   lambda= 330.5978
# phi= 79.84202   sv2= 0.01028818   df= 9.659558   lambda= 7760.556
# phi= 80.23639   sv2= 0.003150998   df= 4.882388   lambda= 25463.8
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/agaR/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_agaR-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_agaR-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/MD-TA_agaR-1_df_relative_timegrid-vs-TA_agaR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_agaR-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=77743.302406)
#                est        L95%        U95%         se
# rate      0.077640    0.074634    0.080767   0.001564
# beta    473.463753  415.048878  540.100064  31.809394
# s         1.052325    0.950226    1.165395   0.054796
# lambda    0.000008    0.000002    0.000044   0.000007
#                est       L95%       U95%       var
# lifespan  78.76263  77.836851  78.843376  0.000028
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/MD-TA_agaR-1_df_relative_timegrid-vs-TA_agaR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_agaR-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/agaR/run-MD
