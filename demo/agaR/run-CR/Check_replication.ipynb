# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/TA_agaR-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/TA_agaR-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/TA_agaR-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR']
#
# out_name_s  ['TA_agaR-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/TA_agaR-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/TA_agaR-1_analysis_metadata.pickle
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 62-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 63-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 64-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 65-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 70-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 71-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 72-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 61-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 63-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 64-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 65-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 70-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 71-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 72-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 62-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 63-1.tif.mortality.tab ------ MAX_28092014 Position 64-1.tif.mortality.tab
# MAX_28092014 Position 63-1.tif.mortality.tab ------ MAX_28092014 Position 65-1.tif.mortality.tab
# MAX_28092014 Position 63-1.tif.mortality.tab ------ MAX_28092014 Position 70-1.tif.mortality.tab
# MAX_28092014 Position 63-1.tif.mortality.tab ------ MAX_28092014 Position 71-1.tif.mortality.tab
# MAX_28092014 Position 63-1.tif.mortality.tab ------ MAX_28092014 Position 72-1.tif.mortality.tab
# MAX_28092014 Position 63-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 63-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 64-1.tif.mortality.tab ------ MAX_28092014 Position 65-1.tif.mortality.tab
# MAX_28092014 Position 64-1.tif.mortality.tab ------ MAX_28092014 Position 70-1.tif.mortality.tab
# MAX_28092014 Position 64-1.tif.mortality.tab ------ MAX_28092014 Position 71-1.tif.mortality.tab
# MAX_28092014 Position 64-1.tif.mortality.tab ------ MAX_28092014 Position 72-1.tif.mortality.tab
# MAX_28092014 Position 64-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 64-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 65-1.tif.mortality.tab ------ MAX_28092014 Position 70-1.tif.mortality.tab
# MAX_28092014 Position 65-1.tif.mortality.tab ------ MAX_28092014 Position 71-1.tif.mortality.tab
# MAX_28092014 Position 65-1.tif.mortality.tab ------ MAX_28092014 Position 72-1.tif.mortality.tab
# MAX_28092014 Position 65-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 65-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 70-1.tif.mortality.tab ------ MAX_28092014 Position 71-1.tif.mortality.tab
# MAX_28092014 Position 70-1.tif.mortality.tab ------ MAX_28092014 Position 72-1.tif.mortality.tab
# MAX_28092014 Position 70-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 70-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 71-1.tif.mortality.tab ------ MAX_28092014 Position 72-1.tif.mortality.tab
# MAX_28092014 Position 71-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 71-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 72-1.tif.mortality.tab ------ MAX_28092014 Position 81-1.tif.mortality.tab
# MAX_28092014 Position 72-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# MAX_28092014 Position 81-1.tif.mortality.tab ------ MAX_28092014 Position 82-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_dentrogram-all-files.eps
# [['MAX_28092014 Position 62-1.tif.mortality.tab', 'MAX_28092014 Position 71-1.tif.mortality.tab'], ['MAX_28092014 Position 63-1.tif.mortality.tab', 'MAX_28092014 Position 64-1.tif.mortality.tab', 'MAX_28092014 Position 65-1.tif.mortality.tab', 'MAX_28092014 Position 70-1.tif.mortality.tab', 'MAX_28092014 Position 81-1.tif.mortality.tab', 'MAX_28092014 Position 82-1.tif.mortality.tab'], ['MAX_28092014 Position 61-1.tif.mortality.tab'], ['MAX_28092014 Position 72-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 114.518   sv2= 0.2335329   df= 19.40413   lambda= 490.372
# phi= 120.0203   sv2= 0.005764222   df= 8.325977   lambda= 20821.59
# Iterations: relative error in phi-hat = 1e-04
# phi= 40.70898   sv2= 0.1776791   df= 14.60908   lambda= 229.1151
# phi= 41.94776   sv2= 0.01786778   df= 7.177404   lambda= 2347.676
# phi= 42.51875   sv2= 0.004593164   df= 4.460655   lambda= 9256.963
# phi= 41.88427   sv2= 0.002874974   df= 3.454802   lambda= 14568.57
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/agaR/CR-TA_agaR-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 94.50661   sv2= 0.2151952   df= 19.3554   lambda= 439.1669
# phi= 97.16398   sv2= 0.008561059   df= 8.623058   lambda= 11349.53
# No error in flxsrv_fit
# {0:                 est       L95%       U95%       var
# lifespan  79.784083  78.836229  79.915762  0.000037}
