# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/TA_yidH-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/TA_yidH-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/TA_yidH-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH']
#
# out_name_s  ['TA_yidH-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/TA_yidH-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/TA_yidH-1_analysis_metadata.pickle
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 119-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 120-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 121-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 122-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 125-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 126-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 129-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 117-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 120-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 121-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 122-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 125-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 126-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 129-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 119-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 121-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 122-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 125-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 126-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 129-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 120-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 122-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 125-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 126-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 129-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 121-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 122-1.tif.mortality.tab ------ MAX_07072016 Position 125-1.tif.mortality.tab
# MAX_07072016 Position 122-1.tif.mortality.tab ------ MAX_07072016 Position 126-1.tif.mortality.tab
# MAX_07072016 Position 122-1.tif.mortality.tab ------ MAX_07072016 Position 129-1.tif.mortality.tab
# MAX_07072016 Position 122-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 122-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 122-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 122-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 125-1.tif.mortality.tab ------ MAX_07072016 Position 126-1.tif.mortality.tab
# MAX_07072016 Position 125-1.tif.mortality.tab ------ MAX_07072016 Position 129-1.tif.mortality.tab
# MAX_07072016 Position 125-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 125-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 125-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 125-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 126-1.tif.mortality.tab ------ MAX_07072016 Position 129-1.tif.mortality.tab
# MAX_07072016 Position 126-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 126-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 126-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 126-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 129-1.tif.mortality.tab ------ MAX_07072016 Position 130-1.tif.mortality.tab
# MAX_07072016 Position 129-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 129-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 129-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 130-1.tif.mortality.tab ------ MAX_07072016 Position 131-1.tif.mortality.tab
# MAX_07072016 Position 130-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 130-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 131-1.tif.mortality.tab ------ MAX_07072016 Position 132-1.tif.mortality.tab
# MAX_07072016 Position 131-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# MAX_07072016 Position 132-1.tif.mortality.tab ------ MAX_07072016 Position 133-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_dentrogram-all-files.eps
# 3 [2 1 1]
# [['MAX_07072016 Position 117-1.tif.mortality.tab', 'MAX_07072016 Position 119-1.tif.mortality.tab', 'MAX_07072016 Position 120-1.tif.mortality.tab', 'MAX_07072016 Position 121-1.tif.mortality.tab', 'MAX_07072016 Position 122-1.tif.mortality.tab', 'MAX_07072016 Position 131-1.tif.mortality.tab', 'MAX_07072016 Position 132-1.tif.mortality.tab', 'MAX_07072016 Position 133-1.tif.mortality.tab'], ['MAX_07072016 Position 125-1.tif.mortality.tab', 'MAX_07072016 Position 126-1.tif.mortality.tab', 'MAX_07072016 Position 129-1.tif.mortality.tab', 'MAX_07072016 Position 130-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.21742   sv2= 0.2880155   df= 10.76389   lambda= 146.5804
# phi= 50.67054   sv2= 0.05386813   df= 6.144507   lambda= 940.6404
# phi= 55.37608   sv2= 0.01456   df= 4.21102   lambda= 3803.301
# phi= 57.65226   sv2= 0.00576601   df= 3.177021   lambda= 9998.639
# phi= 58.97661   sv2= 0.002698334   df= 2.688706   lambda= 21856.68
# Iterations: relative error in phi-hat = 1e-04
# phi= 89.63953   sv2= 0.1646805   df= 9.560833   lambda= 544.3239
# phi= 106.8394   sv2= 0.008172325   df= 4.235612   lambda= 13073.32
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in solve.default(opt$hessian) :
#   system is computationally singular: reciprocal condition number = 9.51455e-20
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: There were 41 warnings (use warnings() to see them)
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# Error in writeGGMtoFile
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/CR-TA_yidH-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 31.59233   sv2= 0.2901081   df= 11.51422   lambda= 108.8985
# phi= 36.08941   sv2= 0.071799   df= 6.958655   lambda= 502.645
# phi= 39.3312   sv2= 0.02156373   df= 5.082365   lambda= 1823.951
# phi= 40.88372   sv2= 0.009626095   df= 3.918572   lambda= 4247.177
# phi= 41.74465   sv2= 0.005186589   df= 3.307125   lambda= 8048.574
# phi= 42.36593   sv2= 0.002988195   df= 2.929521   lambda= 14177.76
# No error in flxsrv_fit
# {0:                  est       L95%        U95%       var
# lifespan  106.074647  106.03611  106.113018  0.000195}
