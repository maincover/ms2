# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/TA_yidH-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/TA_yidH-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.53534   sv2= 0.3127718   df= 11.73363   lambda= 97.62817
# phi= 34.79132   sv2= 0.08702648   df= 7.24777   lambda= 399.7786
# phi= 38.15964   sv2= 0.02748475   df= 5.419059   lambda= 1388.393
# phi= 40.04825   sv2= 0.01185608   df= 4.210705   lambda= 3377.865
# phi= 41.07818   sv2= 0.006481825   df= 3.518902   lambda= 6337.44
# phi= 41.76745   sv2= 0.003889956   df= 3.110508   lambda= 10737.26
# save file prefixed name is : TA_yidH-1_df_relative_timegrid-vs-TA_yidH-1_timeseries_dataframe
# biName is :  TA_yidH-1_df_relative_timegrid-vs-TA_yidH-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yidH/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yidH-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yidH/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yidH/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yidH-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 30.53534   sv2= 0.3127718   df= 11.73363   lambda= 97.62817
# phi= 34.79132   sv2= 0.08702648   df= 7.24777   lambda= 399.7786
# phi= 38.15964   sv2= 0.02748475   df= 5.419059   lambda= 1388.393
# phi= 40.04825   sv2= 0.01185608   df= 4.210705   lambda= 3377.865
# phi= 41.07818   sv2= 0.006481825   df= 3.518902   lambda= 6337.44
# phi= 41.76745   sv2= 0.003889956   df= 3.110508   lambda= 10737.26
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yidH/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yidH-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yidH-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/MD-TA_yidH-1_df_relative_timegrid-vs-TA_yidH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yidH-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=8974.107489)
#                  est           L95%          U95%            se
# rate    1.535959e-01       0.128960  1.829381e-01  1.370027e-02
# beta    1.491485e+06  188255.376896  1.181655e+07  1.575013e+06
# s       3.286382e-01       0.236861  4.559761e-01  5.491093e-02
# lambda  3.505822e-04       0.000242  5.076649e-04  6.622303e-05
#                  est        L95%        U95%       var
# lifespan  106.043619  106.013595  106.105405  0.000181
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yidH/MD-TA_yidH-1_df_relative_timegrid-vs-TA_yidH-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yidH-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yidH/run-MD
