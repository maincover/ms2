# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/TA_yhdX-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/TA_yhdX-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/TA_yhdX-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX']
#
# out_name_s  ['TA_yhdX-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/TA_yhdX-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/TA_yhdX-1_analysis_metadata.pickle
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 100-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 13-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 2-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 3-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 50-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 54-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 7-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 1-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 13-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 2-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 3-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 50-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 54-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 7-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 100-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 2-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 3-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 50-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 54-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 7-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 13-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 3-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 50-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 54-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 7-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 2-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 50-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 54-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 7-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 3-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 54-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 7-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 50-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 7-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 54-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 7-1.tif.mortality.tab ------ MAX_28062016 Position 8-1.tif.mortality.tab
# MAX_28062016 Position 7-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 7-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 7-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 7-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 7-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 7-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 8-1.tif.mortality.tab ------ MAX_28062016 Position 91-1.tif.mortality.tab
# MAX_28062016 Position 8-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 8-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 8-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 8-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 8-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 91-1.tif.mortality.tab ------ MAX_28062016 Position 92-1.tif.mortality.tab
# MAX_28062016 Position 91-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 91-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 91-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 91-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 92-1.tif.mortality.tab ------ MAX_28062016 Position 93-1.tif.mortality.tab
# MAX_28062016 Position 92-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 92-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 92-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 93-1.tif.mortality.tab ------ MAX_28062016 Position 94-1.tif.mortality.tab
# MAX_28062016 Position 93-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 93-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 94-1.tif.mortality.tab ------ MAX_28062016 Position 98-1.tif.mortality.tab
# MAX_28062016 Position 94-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# MAX_28062016 Position 98-1.tif.mortality.tab ------ MAX_28062016 Position 99-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_dentrogram-all-files.eps
# 6 [1 3 5 4 4 2]
# [['MAX_28062016 Position 91-1.tif.mortality.tab'], ['MAX_28062016 Position 3-1.tif.mortality.tab'], ['MAX_28062016 Position 92-1.tif.mortality.tab'], ['MAX_28062016 Position 100-1.tif.mortality.tab', 'MAX_28062016 Position 13-1.tif.mortality.tab', 'MAX_28062016 Position 2-1.tif.mortality.tab', 'MAX_28062016 Position 54-1.tif.mortality.tab', 'MAX_28062016 Position 98-1.tif.mortality.tab', 'MAX_28062016 Position 99-1.tif.mortality.tab'], ['MAX_28062016 Position 1-1.tif.mortality.tab', 'MAX_28062016 Position 50-1.tif.mortality.tab', 'MAX_28062016 Position 7-1.tif.mortality.tab', 'MAX_28062016 Position 8-1.tif.mortality.tab', 'MAX_28062016 Position 93-1.tif.mortality.tab', 'MAX_28062016 Position 94-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 75.98428   sv2= 0.2556634   df= 13.09555   lambda= 297.2044
# phi= 84.83729   sv2= 0.02041789   df= 6.328264   lambda= 4155.047
# phi= 94.36325   sv2= 0.007779088   df= 3.829714   lambda= 12130.37
# Iterations: relative error in phi-hat = 1e-04
# phi= 86.47296   sv2= 0.1139872   df= 11.82884   lambda= 758.62
# phi= 92.72192   sv2= 0.01849286   df= 4.70415   lambda= 5013.931
# phi= 101.3194   sv2= 0.004972821   df= 3.25276   lambda= 20374.62
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/CR-TA_yhdX-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 70.71562   sv2= 0.2557343   df= 13.4274   lambda= 276.5199
# phi= 78.43347   sv2= 0.02161975   df= 6.568755   lambda= 3627.863
# phi= 85.85793   sv2= 0.008716863   df= 3.994026   lambda= 9849.636
# phi= 92.20371   sv2= 0.00516004   df= 3.345802   lambda= 17868.8
# Iterations: relative error in phi-hat = 1e-04
# phi= 86.47296   sv2= 0.1139872   df= 11.82884   lambda= 758.62
# phi= 92.72192   sv2= 0.01849286   df= 4.70415   lambda= 5013.931
# phi= 101.3194   sv2= 0.004972821   df= 3.25276   lambda= 20374.62
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  117.677386  117.363879  119.206904  0.000217, 1:                  est        L95%        U95%       var
# lifespan  122.054256  121.199526  123.187584  0.000263}
