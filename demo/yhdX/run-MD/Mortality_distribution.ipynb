# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/TA_yhdX-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/TA_yhdX-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX
# Iterations: relative error in phi-hat = 1e-04
# phi= 84.92399   sv2= 0.1996244   df= 15.49909   lambda= 425.4188
# phi= 87.12846   sv2= 0.02535405   df= 6.935305   lambda= 3436.471
# phi= 90.33345   sv2= 0.01475426   df= 4.554774   lambda= 6122.535
# phi= 92.51149   sv2= 0.0117775   df= 4.086731   lambda= 7854.935
# phi= 93.75517   sv2= 0.01036561   df= 3.901483   lambda= 9044.828
# phi= 94.54523   sv2= 0.009558981   df= 3.800259   lambda= 9890.723
# phi= 95.07828   sv2= 0.009050892   df= 3.737332   lambda= 10504.85
# save file prefixed name is : TA_yhdX-1_df_relative_timegrid-vs-TA_yhdX-1_timeseries_dataframe
# biName is :  TA_yhdX-1_df_relative_timegrid-vs-TA_yhdX-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yhdX/run-MD
# No error in flxsrv_fit
# TA_yhdX-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yhdX/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yhdX/run-MD
# TA_yhdX-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 84.92399   sv2= 0.1996244   df= 15.49909   lambda= 425.4188
# phi= 87.12846   sv2= 0.02535405   df= 6.935305   lambda= 3436.471
# phi= 90.33345   sv2= 0.01475426   df= 4.554774   lambda= 6122.535
# phi= 92.51149   sv2= 0.0117775   df= 4.086731   lambda= 7854.935
# phi= 93.75517   sv2= 0.01036561   df= 3.901483   lambda= 9044.828
# phi= 94.54523   sv2= 0.009558981   df= 3.800259   lambda= 9890.723
# phi= 95.07828   sv2= 0.009050892   df= 3.737332   lambda= 10504.85
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yhdX/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhdX-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yhdX-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/MD-TA_yhdX-1_df_relative_timegrid-vs-TA_yhdX-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yhdX-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=24534.686810)
#                  est          L95%          U95%            se
# rate    1.329575e-01  1.222305e-01  1.446260e-01  5.706524e-03
# beta    3.486318e+06  1.174372e+06  1.034971e+07  1.935498e+06
# s       5.360725e-01  4.563870e-01  6.296711e-01  4.401570e-02
# lambda  7.768760e-04  6.667510e-04  9.051899e-04  6.059112e-05
#                  est        L95%        U95%       var
# lifespan  118.473075  117.976187  120.347354  0.000081
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yhdX/MD-TA_yhdX-1_df_relative_timegrid-vs-TA_yhdX-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yhdX-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yhdX/run-MD
