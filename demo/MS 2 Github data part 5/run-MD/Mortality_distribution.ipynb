# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS 2 Github data part 5'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/TA_rarD 2-1_df_relative_timegrid.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/TA_ygcQ 2-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/TA_rarD 2-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/TA_ygcQ 2-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.79784   sv2= 0.09431183   df= 13.21327   lambda= 199.3158
# phi= 19.11667   sv2= 0.007951318   df= 6.847926   lambda= 2404.214
# phi= 19.43102   sv2= 0.002951414   df= 4.145331   lambda= 6583.631
# phi= 19.59997   sv2= 0.002887983   df= 3.441135   lambda= 6786.733
# phi= 19.60772   sv2= 0.002885636   df= 3.422373   lambda= 6794.939
# phi= 19.60804   sv2= 0.002885537   df= 3.421629   lambda= 6795.281
# save file prefixed name is : TA_rarD 2-1_df_relative_timegrid-vs-TA_rarD 2-1_timeseries_dataframe
# biName is :  TA_rarD 2-1_df_relative_timegrid-vs-TA_rarD 2-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_rarD 2-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_rarD 2-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.79784   sv2= 0.09431183   df= 13.21327   lambda= 199.3158
# phi= 19.11667   sv2= 0.007951318   df= 6.847926   lambda= 2404.214
# phi= 19.43102   sv2= 0.002951414   df= 4.145331   lambda= 6583.631
# phi= 19.59997   sv2= 0.002887983   df= 3.441135   lambda= 6786.733
# phi= 19.60772   sv2= 0.002885636   df= 3.422373   lambda= 6794.939
# phi= 19.60804   sv2= 0.002885537   df= 3.421629   lambda= 6795.281
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_rarD 2-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_rarD 2-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/MD-TA_rarD 2-1_df_relative_timegrid-vs-TA_rarD 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_rarD 2-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7886.401652)
#                   est          L95%          U95%            se
# rate         0.122650      0.096448  1.559706e-01  1.503937e-02
# beta    929107.819720  96107.815456  8.982010e+06  1.075488e+06
# s            1.113979      0.464780  2.669971e+00  4.968263e-01
# lambda       0.002336      0.001977  2.758840e-03  1.984508e-04
#                  est        L95%        U95%       var
# lifespan  106.088744  105.087826  107.350159  0.000234
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/MD-TA_rarD 2-1_df_relative_timegrid-vs-TA_rarD 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_rarD 2-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2
# Iterations: relative error in phi-hat = 1e-04
# phi= 26.95043   sv2= 0.09785819   df= 13.42134   lambda= 275.403
# phi= 27.16232   sv2= 0.003758759   df= 6.510926   lambda= 7226.405
# phi= 27.01127   sv2= 0.0006422761   df= 3.388505   lambda= 42055.55
# save file prefixed name is : TA_ygcQ 2-1_df_relative_timegrid-vs-TA_ygcQ 2-1_timeseries_dataframe
# biName is :  TA_ygcQ 2-1_df_relative_timegrid-vs-TA_ygcQ 2-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ygcQ 2-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ygcQ 2-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 26.95043   sv2= 0.09785819   df= 13.42134   lambda= 275.403
# phi= 27.16232   sv2= 0.003758759   df= 6.510926   lambda= 7226.405
# phi= 27.01127   sv2= 0.0006422761   df= 3.388505   lambda= 42055.55
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ygcQ 2-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ygcQ 2-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/MD-TA_ygcQ 2-1_df_relative_timegrid-vs-TA_ygcQ 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ygcQ 2-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=9922.212551)
#                   est          L95%          U95%            se
# rate         0.073371  6.711880e-02  8.020670e-02  3.334401e-03
# beta    701952.762353  6.868915e-05  7.173443e+15  8.254379e+06
# s          193.148712  1.379241e-08  2.704852e+12  2.302317e+03
# lambda       0.000527  3.435760e-04  8.088683e-04  1.151494e-04
#                  est        L95%        U95%      var
# lifespan  105.997319  105.045727  107.068173  0.00018
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/MD-TA_ygcQ 2-1_df_relative_timegrid-vs-TA_ygcQ 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ygcQ 2-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/MS 2 Github data part 5/run-MD
