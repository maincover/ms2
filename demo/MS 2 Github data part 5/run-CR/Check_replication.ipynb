# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS 2 Github data part 5'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/TA_rarD 2-1_mortality_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/TA_ygcQ 2-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/TA_rarD 2-1_analysis_metadata.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/TA_ygcQ 2-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/TA_rarD 2-1_timeseries_dataframe.pickle'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/TA_ygcQ 2-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2', '/home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2']
#
# out_name_s  ['TA_rarD 2-1_', 'TA_ygcQ 2-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/TA_rarD 2-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/TA_rarD 2-1_analysis_metadata.pickle
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/TA_ygcQ 2-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/TA_ygcQ 2-1_analysis_metadata.pickle
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 124-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 125-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 126-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 127-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 128-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 20-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 24-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 110-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 125-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 126-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 127-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 128-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 20-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 24-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 124-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 126-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 127-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 128-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 20-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 24-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 125-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 127-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 128-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 20-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 24-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 126-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 127-1.tif.mortality.tab ------ MAX_10012014 Position 128-1.tif.mortality.tab
# MAX_10012014 Position 127-1.tif.mortality.tab ------ MAX_10012014 Position 20-1.tif.mortality.tab
# MAX_10012014 Position 127-1.tif.mortality.tab ------ MAX_10012014 Position 24-1.tif.mortality.tab
# MAX_10012014 Position 127-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 127-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 127-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 127-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 128-1.tif.mortality.tab ------ MAX_10012014 Position 20-1.tif.mortality.tab
# MAX_10012014 Position 128-1.tif.mortality.tab ------ MAX_10012014 Position 24-1.tif.mortality.tab
# MAX_10012014 Position 128-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 128-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 128-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 128-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 20-1.tif.mortality.tab ------ MAX_10012014 Position 24-1.tif.mortality.tab
# MAX_10012014 Position 20-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 20-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 20-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 20-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 24-1.tif.mortality.tab ------ MAX_10012014 Position 83-1.tif.mortality.tab
# MAX_10012014 Position 24-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 24-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 24-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 83-1.tif.mortality.tab ------ MAX_10012014 Position 84-1.tif.mortality.tab
# MAX_10012014 Position 83-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 83-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 84-1.tif.mortality.tab ------ MAX_10012014 Position 86-1.tif.mortality.tab
# MAX_10012014 Position 84-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 86-1.tif.mortality.tab ------ MAX_10012014 Position 88-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 111-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 113-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 114-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 25-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 77-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 80-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 81-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 109-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 113-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 114-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 25-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 77-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 80-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 81-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 111-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 114-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 25-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 77-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 80-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 81-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 113-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 114-1.tif.mortality.tab ------ MAX_10012014 Position 25-1.tif.mortality.tab
# MAX_10012014 Position 114-1.tif.mortality.tab ------ MAX_10012014 Position 77-1.tif.mortality.tab
# MAX_10012014 Position 114-1.tif.mortality.tab ------ MAX_10012014 Position 80-1.tif.mortality.tab
# MAX_10012014 Position 114-1.tif.mortality.tab ------ MAX_10012014 Position 81-1.tif.mortality.tab
# MAX_10012014 Position 114-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 114-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 114-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 25-1.tif.mortality.tab ------ MAX_10012014 Position 77-1.tif.mortality.tab
# MAX_10012014 Position 25-1.tif.mortality.tab ------ MAX_10012014 Position 80-1.tif.mortality.tab
# MAX_10012014 Position 25-1.tif.mortality.tab ------ MAX_10012014 Position 81-1.tif.mortality.tab
# MAX_10012014 Position 25-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 25-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 25-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 77-1.tif.mortality.tab ------ MAX_10012014 Position 80-1.tif.mortality.tab
# MAX_10012014 Position 77-1.tif.mortality.tab ------ MAX_10012014 Position 81-1.tif.mortality.tab
# MAX_10012014 Position 77-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 77-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 77-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 80-1.tif.mortality.tab ------ MAX_10012014 Position 81-1.tif.mortality.tab
# MAX_10012014 Position 80-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 80-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 80-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 81-1.tif.mortality.tab ------ MAX_10012014 Position 87-1.tif.mortality.tab
# MAX_10012014 Position 81-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 81-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 87-1.tif.mortality.tab ------ MAX_10012014 Position 89-1.tif.mortality.tab
# MAX_10012014 Position 87-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# MAX_10012014 Position 89-1.tif.mortality.tab ------ MAX_10012014 Position 90-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2
# save eps to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_dentrogram-all-files.eps
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2
# save eps to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_dentrogram-all-files.eps
# 4 [2 3 1 1]
# [['MAX_10012014 Position 83-1.tif.mortality.tab', 'MAX_10012014 Position 84-1.tif.mortality.tab', 'MAX_10012014 Position 86-1.tif.mortality.tab', 'MAX_10012014 Position 88-1.tif.mortality.tab'], ['MAX_10012014 Position 20-1.tif.mortality.tab', 'MAX_10012014 Position 24-1.tif.mortality.tab'], ['MAX_10012014 Position 110-1.tif.mortality.tab', 'MAX_10012014 Position 124-1.tif.mortality.tab', 'MAX_10012014 Position 125-1.tif.mortality.tab', 'MAX_10012014 Position 126-1.tif.mortality.tab', 'MAX_10012014 Position 127-1.tif.mortality.tab', 'MAX_10012014 Position 128-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.63198   sv2= 0.07154255   df= 9.396563   lambda= 595.8969
# phi= 44.03497   sv2= 0.01040446   df= 4.092221   lambda= 4232.317
# phi= 44.87419   sv2= 0.007930417   df= 2.81683   lambda= 5658.49
# phi= 45.35801   sv2= 0.007441388   df= 2.652977   lambda= 6095.369
# phi= 45.52036   sv2= 0.007301168   df= 2.612806   lambda= 6234.668
# phi= 45.57314   sv2= 0.007257381   df= 2.600797   lambda= 6279.557
# phi= 45.59025   sv2= 0.007243364   df= 2.597005   lambda= 6294.071
# phi= 45.59579   sv2= 0.007238842   df= 2.595786   lambda= 6298.768
# phi= 45.59758   sv2= 0.007237379   df= 2.595393   lambda= 6300.289
# phi= 45.59816   sv2= 0.007236906   df= 2.595266   lambda= 6300.782
# Iterations: relative error in phi-hat = 1e-04
# phi= 32.27453   sv2= 0.03565475   df= 11.11622   lambda= 905.1957
# phi= 33.63809   sv2= 0.0006167271   df= 4.271933   lambda= 54542.91
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_mortality_dataframe_cluster0.pickle
# 3 --c-- 1
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_mortality_dataframe_cluster1.pickle
# 3 --c-- 2
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/rarD 2/CR-TA_rarD 2-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.63198   sv2= 0.07154255   df= 9.396563   lambda= 595.8969
# phi= 44.03497   sv2= 0.01040446   df= 4.092221   lambda= 4232.317
# phi= 44.87419   sv2= 0.007930417   df= 2.81683   lambda= 5658.49
# phi= 45.35801   sv2= 0.007441388   df= 2.652977   lambda= 6095.369
# phi= 45.52036   sv2= 0.007301168   df= 2.612806   lambda= 6234.668
# phi= 45.57314   sv2= 0.007257381   df= 2.600797   lambda= 6279.557
# phi= 45.59025   sv2= 0.007243364   df= 2.597005   lambda= 6294.071
# phi= 45.59579   sv2= 0.007238842   df= 2.595786   lambda= 6298.768
# phi= 45.59758   sv2= 0.007237379   df= 2.595393   lambda= 6300.289
# phi= 45.59816   sv2= 0.007236906   df= 2.595266   lambda= 6300.782
# Iterations: relative error in phi-hat = 1e-04
# phi= 32.27453   sv2= 0.03565475   df= 11.11622   lambda= 905.1957
# phi= 33.63809   sv2= 0.0006167271   df= 4.271933   lambda= 54542.91
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  109.349317  108.347431  110.366719  0.000526, 1:                  est        L95%        U95%      var
# lifespan  102.059451  100.050442  105.052587  0.00052}
# [['MAX_10012014 Position 109-1.tif.mortality.tab', 'MAX_10012014 Position 111-1.tif.mortality.tab', 'MAX_10012014 Position 113-1.tif.mortality.tab', 'MAX_10012014 Position 25-1.tif.mortality.tab'], ['MAX_10012014 Position 114-1.tif.mortality.tab'], ['MAX_10012014 Position 87-1.tif.mortality.tab', 'MAX_10012014 Position 89-1.tif.mortality.tab'], ['MAX_10012014 Position 77-1.tif.mortality.tab', 'MAX_10012014 Position 80-1.tif.mortality.tab', 'MAX_10012014 Position 90-1.tif.mortality.tab'], ['MAX_10012014 Position 81-1.tif.mortality.tab']]
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 41.65391   sv2= 0.1478919   df= 9.567694   lambda= 281.651
# phi= 42.62778   sv2= 0.01176862   df= 4.84473   lambda= 3622.157
# phi= 42.18786   sv2= 0.004998628   df= 3.004432   lambda= 8439.889
# phi= 42.22592   sv2= 0.003912032   df= 2.547093   lambda= 10793.86
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.88171   sv2= 0.07353278   df= 10.78543   lambda= 256.7795
# phi= 20.80492   sv2= 0.005760429   df= 5.361701   lambda= 3611.697
# phi= 22.15829   sv2= 0.0009554552   df= 3.187516   lambda= 23191.35
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.48978   sv2= 0.02885368   df= 9.316853   lambda= 1576.568
# phi= 45.8988   sv2= 0.0007611552   df= 3.371493   lambda= 60301.49
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_mortality_dataframe_cluster2.pickle
# 4 --c-- 1
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 5/ygcQ 2/CR-TA_ygcQ 2-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.39944   sv2= 0.1878049   df= 10.07766   lambda= 268.3606
# phi= 54.45855   sv2= 0.01492254   df= 5.107461   lambda= 3649.415
# phi= 55.02902   sv2= 0.005350224   df= 3.127795   lambda= 10285.37
# Iterations: relative error in phi-hat = 1e-04
# phi= 18.88171   sv2= 0.07353278   df= 10.78543   lambda= 256.7795
# phi= 20.80492   sv2= 0.005760429   df= 5.361701   lambda= 3611.697
# phi= 22.15829   sv2= 0.0009554552   df= 3.187516   lambda= 23191.35
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.48978   sv2= 0.02885368   df= 9.316853   lambda= 1576.568
# phi= 45.8988   sv2= 0.0007611552   df= 3.371493   lambda= 60301.49
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# {0:                  est        L95%        U95%       var
# lifespan  111.214389  109.236469  111.235448  0.000419, 1:                 est       L95%       U95%       var
# lifespan  94.996952  91.996433  98.977186  0.000574, 2:                  est        L95%        U95%       var
# lifespan  104.046741  101.058875  107.061082  0.000926}
