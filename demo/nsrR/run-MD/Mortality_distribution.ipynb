# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/TA_nsrR-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/TA_nsrR-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.07033   sv2= 0.219945   df= 14.14355   lambda= 377.6868
# phi= 87.11655   sv2= 0.0254622   df= 6.385546   lambda= 3421.408
# phi= 91.74186   sv2= 0.009076548   df= 4.110326   lambda= 10107.57
# save file prefixed name is : TA_nsrR-1_df_relative_timegrid-vs-TA_nsrR-1_timeseries_dataframe
# biName is :  TA_nsrR-1_df_relative_timegrid-vs-TA_nsrR-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/nsrR/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_nsrR-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/nsrR/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/nsrR/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_nsrR-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 83.07033   sv2= 0.219945   df= 14.14355   lambda= 377.6868
# phi= 87.11655   sv2= 0.0254622   df= 6.385546   lambda= 3421.408
# phi= 91.74186   sv2= 0.009076548   df= 4.110326   lambda= 10107.57
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/nsrR/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_nsrR-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_nsrR-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/MD-TA_nsrR-1_df_relative_timegrid-vs-TA_nsrR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_nsrR-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=14264.420714)
#                  est          L95%          U95%            se
# rate    1.747576e-01  1.537143e-01  1.986818e-01  1.144011e-02
# beta    2.541261e+08  2.703909e+07  2.388397e+09  2.905061e+08
# s       4.200639e-01  3.363808e-01  5.245653e-01  4.761448e-02
# lambda  1.094343e-03  9.362083e-04  1.279187e-03  8.714208e-05
#                  est        L95%        U95%       var
# lifespan  116.935048  116.430624  117.631803  0.000132
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/MD-TA_nsrR-1_df_relative_timegrid-vs-TA_nsrR-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_nsrR-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/nsrR/run-MD
