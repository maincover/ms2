# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/TA_nsrR-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/TA_nsrR-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/TA_nsrR-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR']
#
# out_name_s  ['TA_nsrR-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/TA_nsrR-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/TA_nsrR-1_analysis_metadata.pickle
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 136-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 144-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 146-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 147-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 148-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 150-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 33-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 123-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 144-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 146-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 147-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 148-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 150-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 33-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 136-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 146-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 147-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 148-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 150-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 33-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 144-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 147-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 148-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 150-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 33-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 146-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 148-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 150-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 33-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 147-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 150-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 33-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 148-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 150-1.tif.mortality.tab ------ MAX_11102018 Position 33-1.tif.mortality.tab
# MAX_11102018 Position 150-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 150-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 150-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 150-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 150-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 150-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 33-1.tif.mortality.tab ------ MAX_11102018 Position 35-1.tif.mortality.tab
# MAX_11102018 Position 33-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 33-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 33-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 33-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 33-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 35-1.tif.mortality.tab ------ MAX_11102018 Position 37-1.tif.mortality.tab
# MAX_11102018 Position 35-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 35-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 35-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 35-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 37-1.tif.mortality.tab ------ MAX_11102018 Position 51-1.tif.mortality.tab
# MAX_11102018 Position 37-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 37-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 37-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 51-1.tif.mortality.tab ------ MAX_11102018 Position 52-1.tif.mortality.tab
# MAX_11102018 Position 51-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 51-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 52-1.tif.mortality.tab ------ MAX_11102018 Position 53-1.tif.mortality.tab
# MAX_11102018 Position 52-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# MAX_11102018 Position 53-1.tif.mortality.tab ------ MAX_11102018 Position 54-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_dentrogram-all-files.eps
# 7 [4 4 1 2 3 5 6]
# [['MAX_11102018 Position 53-1.tif.mortality.tab', 'MAX_11102018 Position 54-1.tif.mortality.tab'], ['MAX_11102018 Position 35-1.tif.mortality.tab'], ['MAX_11102018 Position 37-1.tif.mortality.tab', 'MAX_11102018 Position 51-1.tif.mortality.tab'], ['MAX_11102018 Position 123-1.tif.mortality.tab', 'MAX_11102018 Position 136-1.tif.mortality.tab', 'MAX_11102018 Position 144-1.tif.mortality.tab', 'MAX_11102018 Position 150-1.tif.mortality.tab'], ['MAX_11102018 Position 146-1.tif.mortality.tab', 'MAX_11102018 Position 147-1.tif.mortality.tab', 'MAX_11102018 Position 148-1.tif.mortality.tab', 'MAX_11102018 Position 52-1.tif.mortality.tab'], ['MAX_11102018 Position 33-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_relative_orig_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_colomap_all_files_cluster3.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_mortality_orig_dataframe_cluster3.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_relative_orig_timegrid_cluster3.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.5568   sv2= 0.249931   df= 11.19879   lambda= 170.2742
# phi= 47.93955   sv2= 0.01750026   df= 6.067114   lambda= 2739.363
# phi= 50.80403   sv2= 0.001600092   df= 3.468792   lambda= 31750.69
# Iterations: relative error in phi-hat = 1e-04
# phi= 302.833   sv2= 0.1531488   df= 9.152967   lambda= 1977.378
# phi= 359.6895   sv2= 0.006400709   df= 3.2825   lambda= 56195.26
# Iterations: relative error in phi-hat = 1e-04
# phi= 8.394245   sv2= 0.1267871   df= 8.730251   lambda= 66.2074
# phi= 8.730221   sv2= 0.06627087   df= 6.0871   lambda= 131.7354
# phi= 8.901202   sv2= 0.05181152   df= 5.370906   lambda= 171.7997
# phi= 9.011134   sv2= 0.04577339   df= 5.120233   lambda= 196.864
# phi= 9.079506   sv2= 0.04264713   df= 4.996191   lambda= 212.8984
# phi= 9.122678   sv2= 0.04085609   df= 4.926134   lambda= 223.2881
# phi= 9.150344   sv2= 0.03977181   df= 4.883934   lambda= 230.0711
# phi= 9.168261   sv2= 0.03909376   df= 4.857593   lambda= 234.5198
# phi= 9.179947   sv2= 0.03866119   df= 4.8408   lambda= 237.446
# phi= 9.187604   sv2= 0.03838174   df= 4.829953   lambda= 239.3743
# phi= 9.192637   sv2= 0.03819975   df= 4.82289   lambda= 240.6465
# phi= 9.195952   sv2= 0.0380806   df= 4.818265   lambda= 241.4865
# phi= 9.198138   sv2= 0.03800234   df= 4.815228   lambda= 242.0414
# phi= 9.199581   sv2= 0.0379508   df= 4.813228   lambda= 242.4081
# phi= 9.200534   sv2= 0.03791683   df= 4.811909   lambda= 242.6504
# phi= 9.201164   sv2= 0.0378944   df= 4.811039   lambda= 242.8106
# phi= 9.20158   sv2= 0.03787959   df= 4.810464   lambda= 242.9166
# phi= 9.201856   sv2= 0.03786981   df= 4.810084   lambda= 242.9866
# phi= 9.202038   sv2= 0.03786334   df= 4.809833   lambda= 243.0329
# phi= 9.202158   sv2= 0.03785907   df= 4.809667   lambda= 243.0635
# phi= 9.202237   sv2= 0.03785624   df= 4.809557   lambda= 243.0837
# Iterations: relative error in phi-hat = 1e-04
# phi= 683.5508   sv2= 0.179111   df= 9.247775   lambda= 3816.354
# phi= 865.6214   sv2= 0.002583721   df= 2.941731   lambda= 335028.9
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_mortality_dataframe_cluster1.pickle
# 5 --c-- 3
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_cluster1_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_mortality_dataframe_cluster2.pickle
# 5 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_relative_timegrid_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_timeseries_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/nsrR/CR-TA_nsrR-1_cluster2_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 42.5568   sv2= 0.249931   df= 11.19879   lambda= 170.2742
# phi= 47.93955   sv2= 0.01750026   df= 6.067114   lambda= 2739.363
# phi= 50.80403   sv2= 0.001600092   df= 3.468792   lambda= 31750.69
# Iterations: relative error in phi-hat = 1e-04
# phi= 135.6385   sv2= 0.1718028   df= 10.32395   lambda= 789.5009
# phi= 140.6063   sv2= 0.02314484   df= 4.320324   lambda= 6075.062
# phi= 146.7717   sv2= 0.005416916   df= 2.968402   lambda= 27095.06
# Iterations: relative error in phi-hat = 1e-04
# phi= 683.5508   sv2= 0.179111   df= 9.247775   lambda= 3816.354
# phi= 865.6214   sv2= 0.002583721   df= 2.941731   lambda= 335028.9
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  123.620004  122.400518  127.194829  0.000361, 1:                  est        L95%        U95%       var
# lifespan  115.734736  114.039021  116.935048  0.000408, 2:                  est        L95%        U95%       var
# lifespan  108.034613  104.375511  109.251653  0.000982}
