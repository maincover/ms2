# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/TA_gspL-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/TA_gspL-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL
# Iterations: relative error in phi-hat = 1e-04
# phi= 98.89025   sv2= 0.3514855   df= 16.86021   lambda= 281.3494
# phi= 112.1396   sv2= 0.06003391   df= 8.176435   lambda= 1867.938
# phi= 126.2068   sv2= 0.01324578   df= 5.520816   lambda= 9528.077
# phi= 135.3176   sv2= 0.002880398   df= 4.010732   lambda= 46978.79
# save file prefixed name is : TA_gspL-1_df_relative_timegrid-vs-TA_gspL-1_timeseries_dataframe
# biName is :  TA_gspL-1_df_relative_timegrid-vs-TA_gspL-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/gspL/run-MD
# No error in flxsrv_fit
# TA_gspL-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/gspL/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gspL/run-MD
# TA_gspL-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 98.89025   sv2= 0.3514855   df= 16.86021   lambda= 281.3494
# phi= 112.1396   sv2= 0.06003391   df= 8.176435   lambda= 1867.938
# phi= 126.2068   sv2= 0.01324578   df= 5.520816   lambda= 9528.077
# phi= 135.3176   sv2= 0.002880398   df= 4.010732   lambda= 46978.79
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/gspL/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gspL-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_gspL-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/MD-TA_gspL-1_df_relative_timegrid-vs-TA_gspL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_gspL-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=23136.188416)
#                  est          L95%          U95%            se
# rate    2.183261e-01  1.782463e-01  2.674182e-01  2.259313e-02
# beta    5.604310e+09  7.742340e+07  4.056692e+11  1.224393e+10
# s       4.045108e-01  2.995212e-01  5.463019e-01  6.201785e-02
# lambda  4.511936e-03  4.197212e-03  4.850260e-03  1.664519e-04
#                  est       L95%        U95%       var
# lifespan  102.573096  100.18198  102.919179  0.000093
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/MD-TA_gspL-1_df_relative_timegrid-vs-TA_gspL-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_gspL-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/gspL/run-MD
