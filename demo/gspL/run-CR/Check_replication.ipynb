# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/TA_gspL-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/TA_gspL-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/TA_gspL-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL']
#
# out_name_s  ['TA_gspL-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/TA_gspL-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/TA_gspL-1_analysis_metadata.pickle
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 116-1.tif.mortality.tab
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 128-1.tif.mortality.tab
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 129-1.tif.mortality.tab
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 168-1.tif.mortality.tab
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 189-1.tif.mortality.tab
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 190-1.tif.mortality.tab
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 47-1.tif.mortality.tab
# MAX_10092018 Position 115-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# MAX_10092018 Position 116-1.tif.mortality.tab ------ MAX_10092018 Position 128-1.tif.mortality.tab
# MAX_10092018 Position 116-1.tif.mortality.tab ------ MAX_10092018 Position 129-1.tif.mortality.tab
# MAX_10092018 Position 116-1.tif.mortality.tab ------ MAX_10092018 Position 168-1.tif.mortality.tab
# MAX_10092018 Position 116-1.tif.mortality.tab ------ MAX_10092018 Position 189-1.tif.mortality.tab
# MAX_10092018 Position 116-1.tif.mortality.tab ------ MAX_10092018 Position 190-1.tif.mortality.tab
# MAX_10092018 Position 116-1.tif.mortality.tab ------ MAX_10092018 Position 47-1.tif.mortality.tab
# MAX_10092018 Position 116-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# MAX_10092018 Position 128-1.tif.mortality.tab ------ MAX_10092018 Position 129-1.tif.mortality.tab
# MAX_10092018 Position 128-1.tif.mortality.tab ------ MAX_10092018 Position 168-1.tif.mortality.tab
# MAX_10092018 Position 128-1.tif.mortality.tab ------ MAX_10092018 Position 189-1.tif.mortality.tab
# MAX_10092018 Position 128-1.tif.mortality.tab ------ MAX_10092018 Position 190-1.tif.mortality.tab
# MAX_10092018 Position 128-1.tif.mortality.tab ------ MAX_10092018 Position 47-1.tif.mortality.tab
# MAX_10092018 Position 128-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# MAX_10092018 Position 129-1.tif.mortality.tab ------ MAX_10092018 Position 168-1.tif.mortality.tab
# MAX_10092018 Position 129-1.tif.mortality.tab ------ MAX_10092018 Position 189-1.tif.mortality.tab
# MAX_10092018 Position 129-1.tif.mortality.tab ------ MAX_10092018 Position 190-1.tif.mortality.tab
# MAX_10092018 Position 129-1.tif.mortality.tab ------ MAX_10092018 Position 47-1.tif.mortality.tab
# MAX_10092018 Position 129-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# MAX_10092018 Position 168-1.tif.mortality.tab ------ MAX_10092018 Position 189-1.tif.mortality.tab
# MAX_10092018 Position 168-1.tif.mortality.tab ------ MAX_10092018 Position 190-1.tif.mortality.tab
# MAX_10092018 Position 168-1.tif.mortality.tab ------ MAX_10092018 Position 47-1.tif.mortality.tab
# MAX_10092018 Position 168-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# MAX_10092018 Position 189-1.tif.mortality.tab ------ MAX_10092018 Position 190-1.tif.mortality.tab
# MAX_10092018 Position 189-1.tif.mortality.tab ------ MAX_10092018 Position 47-1.tif.mortality.tab
# MAX_10092018 Position 189-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# MAX_10092018 Position 190-1.tif.mortality.tab ------ MAX_10092018 Position 47-1.tif.mortality.tab
# MAX_10092018 Position 190-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# MAX_10092018 Position 47-1.tif.mortality.tab ------ MAX_10092018 Position 59-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_dentrogram-all-files.eps
# [['MAX_10092018 Position 115-1.tif.mortality.tab', 'MAX_10092018 Position 116-1.tif.mortality.tab'], ['MAX_10092018 Position 190-1.tif.mortality.tab'], ['MAX_10092018 Position 128-1.tif.mortality.tab', 'MAX_10092018 Position 129-1.tif.mortality.tab', 'MAX_10092018 Position 168-1.tif.mortality.tab', 'MAX_10092018 Position 47-1.tif.mortality.tab', 'MAX_10092018 Position 59-1.tif.mortality.tab'], ['MAX_10092018 Position 189-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.81147   sv2= 0.1165051   df= 13.73714   lambda= 410.3807
# phi= 53.10536   sv2= 0.009541888   df= 6.126283   lambda= 5565.498
# phi= 56.04306   sv2= 0.0007315368   df= 3.656993   lambda= 76610.04
# Iterations: relative error in phi-hat = 1e-04
# phi= 356.2561   sv2= 0.2401936   df= 11.12476   lambda= 1483.204
# phi= 545.5777   sv2= 0.01555235   df= 4.118772   lambda= 35080.08
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/gspL/CR-TA_gspL-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.81147   sv2= 0.1165051   df= 13.73714   lambda= 410.3807
# phi= 53.10536   sv2= 0.009541888   df= 6.126283   lambda= 5565.498
# phi= 56.04306   sv2= 0.0007315368   df= 3.656993   lambda= 76610.04
# Iterations: relative error in phi-hat = 1e-04
# phi= 356.2561   sv2= 0.2401936   df= 11.12476   lambda= 1483.204
# phi= 545.5777   sv2= 0.01555235   df= 4.118772   lambda= 35080.08
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                est       L95%       U95%       var
# lifespan  95.91391  93.091642  97.623003  0.000277, 1:                  est        L95%        U95%       var
# lifespan  103.863743  102.863831  104.857764  0.000395}
