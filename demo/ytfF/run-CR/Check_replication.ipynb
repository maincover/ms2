# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/TA_ytfF-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/TA_ytfF-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/TA_ytfF-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF']
#
# out_name_s  ['TA_ytfF-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/TA_ytfF-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/TA_ytfF-1_analysis_metadata.pickle
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 122-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 137-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 145-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 149-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 153-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 155-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 176-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 121-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 137-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 145-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 149-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 153-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 155-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 176-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 122-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 145-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 149-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 153-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 155-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 176-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 137-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 145-1.tif.mortality.tab ------ MAX_11102018 Position 149-1.tif.mortality.tab
# MAX_11102018 Position 145-1.tif.mortality.tab ------ MAX_11102018 Position 153-1.tif.mortality.tab
# MAX_11102018 Position 145-1.tif.mortality.tab ------ MAX_11102018 Position 155-1.tif.mortality.tab
# MAX_11102018 Position 145-1.tif.mortality.tab ------ MAX_11102018 Position 176-1.tif.mortality.tab
# MAX_11102018 Position 145-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 145-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 145-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 149-1.tif.mortality.tab ------ MAX_11102018 Position 153-1.tif.mortality.tab
# MAX_11102018 Position 149-1.tif.mortality.tab ------ MAX_11102018 Position 155-1.tif.mortality.tab
# MAX_11102018 Position 149-1.tif.mortality.tab ------ MAX_11102018 Position 176-1.tif.mortality.tab
# MAX_11102018 Position 149-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 149-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 149-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 153-1.tif.mortality.tab ------ MAX_11102018 Position 155-1.tif.mortality.tab
# MAX_11102018 Position 153-1.tif.mortality.tab ------ MAX_11102018 Position 176-1.tif.mortality.tab
# MAX_11102018 Position 153-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 153-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 153-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 155-1.tif.mortality.tab ------ MAX_11102018 Position 176-1.tif.mortality.tab
# MAX_11102018 Position 155-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 155-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 155-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 176-1.tif.mortality.tab ------ MAX_11102018 Position 178-1.tif.mortality.tab
# MAX_11102018 Position 176-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 176-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 178-1.tif.mortality.tab ------ MAX_11102018 Position 265-1.tif.mortality.tab
# MAX_11102018 Position 178-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# MAX_11102018 Position 265-1.tif.mortality.tab ------ MAX_11102018 Position 272-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_dentrogram-all-files.eps
# [['MAX_11102018 Position 145-1.tif.mortality.tab', 'MAX_11102018 Position 149-1.tif.mortality.tab', 'MAX_11102018 Position 155-1.tif.mortality.tab', 'MAX_11102018 Position 176-1.tif.mortality.tab', 'MAX_11102018 Position 178-1.tif.mortality.tab'], ['MAX_11102018 Position 121-1.tif.mortality.tab', 'MAX_11102018 Position 122-1.tif.mortality.tab', 'MAX_11102018 Position 137-1.tif.mortality.tab', 'MAX_11102018 Position 153-1.tif.mortality.tab', 'MAX_11102018 Position 265-1.tif.mortality.tab'], ['MAX_11102018 Position 272-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 144.0454   sv2= 0.08494092   df= 11.59517   lambda= 1695.831
# phi= 175.8756   sv2= 0.001851914   df= 3.93006   lambda= 94969.69
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.86909   sv2= 0.1018851   df= 11.23892   lambda= 332.4244
# phi= 35.59533   sv2= 0.009013108   df= 5.293534   lambda= 3949.285
# phi= 36.43165   sv2= 0.002853455   df= 3.294791   lambda= 12767.56
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/CR-TA_ytfF-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.9394   sv2= 0.09176497   df= 13.45128   lambda= 566.0047
# phi= 56.36147   sv2= 0.006188688   df= 5.585352   lambda= 9107.177
# phi= 59.27105   sv2= 0.002102323   df= 3.256364   lambda= 28193.12
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  128.028793  127.336264  129.194695  0.000184}
