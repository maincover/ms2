# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/TA_ytfF-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/TA_ytfF-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.27756   sv2= 0.1081441   df= 13.69873   lambda= 418.6779
# phi= 48.52525   sv2= 0.007540159   df= 6.045789   lambda= 6435.574
# phi= 50.93329   sv2= 0.002258644   df= 3.520731   lambda= 22550.38
# save file prefixed name is : TA_ytfF-1_df_relative_timegrid-vs-TA_ytfF-1_timeseries_dataframe
# biName is :  TA_ytfF-1_df_relative_timegrid-vs-TA_ytfF-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ytfF/run-MD
# No error in flxsrv_fit
# TA_ytfF-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ytfF/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ytfF/run-MD
# TA_ytfF-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 45.27756   sv2= 0.1081441   df= 13.69873   lambda= 418.6779
# phi= 48.52525   sv2= 0.007540159   df= 6.045789   lambda= 6435.574
# phi= 50.93329   sv2= 0.002258644   df= 3.520731   lambda= 22550.38
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ytfF/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ytfF-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ytfF-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/MD-TA_ytfF-1_df_relative_timegrid-vs-TA_ytfF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ytfF-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=11458.463928)
#                   est          L95%           U95%            se
# rate         0.078701      0.068235       0.090772      0.005730
# beta    143110.013640  66964.407149  305841.220372  55452.675098
# s            3.898754      1.052740      14.438785      2.604378
# lambda       0.000918      0.000727       0.001157      0.000109
#                  est        L95%       U95%       var
# lifespan  128.028793  127.336264  129.16097  0.000168
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ytfF/MD-TA_ytfF-1_df_relative_timegrid-vs-TA_ytfF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ytfF-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ytfF/run-MD
