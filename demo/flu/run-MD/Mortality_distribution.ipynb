# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/TA_flu-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/TA_flu-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu
# Iterations: relative error in phi-hat = 1e-04
# phi= 209.9497   sv2= 1.737265   df= 19.12195   lambda= 120.8507
# phi= 230.8599   sv2= 0.1541317   df= 11.885   lambda= 1497.81
# phi= 240.1599   sv2= 0.03916067   df= 7.012855   lambda= 6132.682
# phi= 247.5552   sv2= 0.02332072   df= 5.29354   lambda= 10615.25
# save file prefixed name is : TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe
# biName is :  TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/flu/run-MD
# No error in flxsrv_fit
# TA_flu-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/flu/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/flu/run-MD
# TA_flu-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 209.9497   sv2= 1.737265   df= 19.12195   lambda= 120.8507
# phi= 230.8599   sv2= 0.1541317   df= 11.885   lambda= 1497.81
# phi= 240.1599   sv2= 0.03916067   df= 7.012855   lambda= 6132.682
# phi= 247.5552   sv2= 0.02332072   df= 5.29354   lambda= 10615.25
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/flu/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_flu-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_flu-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/MD-TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_flu-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=90480.917110)
#                  est          L95%          U95%            se
# rate    1.519548e-01  1.452793e-01  1.589370e-01  3.482981e-03
# beta    2.433318e+07  1.255192e+07  4.717233e+07  8.218393e+06
# s       5.789983e-01  5.315177e-01  6.307203e-01  2.527642e-02
# lambda  9.373083e-04  8.730702e-04  1.006273e-03  3.395233e-05
#                  est        L95%        U95%       var
# lifespan  115.911386  115.771436  116.911176  0.000023
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/MD-TA_flu-1_df_relative_timegrid-vs-TA_flu-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_flu-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/flu/run-MD
