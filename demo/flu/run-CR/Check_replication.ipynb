# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/TA_flu-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/TA_flu-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/TA_flu-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu']
#
# out_name_s  ['TA_flu-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/TA_flu-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/TA_flu-1_analysis_metadata.pickle
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 25-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 26-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 27-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 39-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 40-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 41-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 42-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 24-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 26-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 27-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 39-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 40-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 41-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 42-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 25-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 26-1.tif.mortality.tab ------ MAX_17112015 Position 27-1.tif.mortality.tab
# MAX_17112015 Position 26-1.tif.mortality.tab ------ MAX_17112015 Position 39-1.tif.mortality.tab
# MAX_17112015 Position 26-1.tif.mortality.tab ------ MAX_17112015 Position 40-1.tif.mortality.tab
# MAX_17112015 Position 26-1.tif.mortality.tab ------ MAX_17112015 Position 41-1.tif.mortality.tab
# MAX_17112015 Position 26-1.tif.mortality.tab ------ MAX_17112015 Position 42-1.tif.mortality.tab
# MAX_17112015 Position 26-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 26-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 27-1.tif.mortality.tab ------ MAX_17112015 Position 39-1.tif.mortality.tab
# MAX_17112015 Position 27-1.tif.mortality.tab ------ MAX_17112015 Position 40-1.tif.mortality.tab
# MAX_17112015 Position 27-1.tif.mortality.tab ------ MAX_17112015 Position 41-1.tif.mortality.tab
# MAX_17112015 Position 27-1.tif.mortality.tab ------ MAX_17112015 Position 42-1.tif.mortality.tab
# MAX_17112015 Position 27-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 27-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 39-1.tif.mortality.tab ------ MAX_17112015 Position 40-1.tif.mortality.tab
# MAX_17112015 Position 39-1.tif.mortality.tab ------ MAX_17112015 Position 41-1.tif.mortality.tab
# MAX_17112015 Position 39-1.tif.mortality.tab ------ MAX_17112015 Position 42-1.tif.mortality.tab
# MAX_17112015 Position 39-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 39-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 40-1.tif.mortality.tab ------ MAX_17112015 Position 41-1.tif.mortality.tab
# MAX_17112015 Position 40-1.tif.mortality.tab ------ MAX_17112015 Position 42-1.tif.mortality.tab
# MAX_17112015 Position 40-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 40-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 41-1.tif.mortality.tab ------ MAX_17112015 Position 42-1.tif.mortality.tab
# MAX_17112015 Position 41-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 41-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 42-1.tif.mortality.tab ------ MAX_17112015 Position 44-1.tif.mortality.tab
# MAX_17112015 Position 42-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# MAX_17112015 Position 44-1.tif.mortality.tab ------ MAX_17112015 Position 46-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/flu/CR-TA_flu-1_dentrogram-all-files.eps
# [['MAX_17112015 Position 27-1.tif.mortality.tab'], ['MAX_17112015 Position 44-1.tif.mortality.tab'], ['MAX_17112015 Position 39-1.tif.mortality.tab'], ['MAX_17112015 Position 42-1.tif.mortality.tab'], ['MAX_17112015 Position 41-1.tif.mortality.tab'], ['MAX_17112015 Position 25-1.tif.mortality.tab'], ['MAX_17112015 Position 26-1.tif.mortality.tab'], ['MAX_17112015 Position 40-1.tif.mortality.tab'], ['MAX_17112015 Position 24-1.tif.mortality.tab'], ['MAX_17112015 Position 46-1.tif.mortality.tab']]
# plotStatsRefvsClusters2 : ERROR
# plotStatsRefvsClusters2 : ERROR
# {}
