# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/TA_rarD-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/TA_rarD-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.07712   sv2= 0.4152603   df= 12.98093   lambda= 113.3677
# phi= 48.78821   sv2= 0.1364281   df= 7.728122   lambda= 357.6111
# phi= 51.35994   sv2= 0.04848255   df= 6.089254   lambda= 1059.349
# phi= 53.75152   sv2= 0.01632531   df= 4.904975   lambda= 3292.527
# phi= 55.6901   sv2= 0.008490226   df= 3.974638   lambda= 6559.319
# phi= 56.948   sv2= 0.007577171   df= 3.528272   lambda= 7515.734
# phi= 57.24972   sv2= 0.00747599   df= 3.448649   lambda= 7657.811
# phi= 57.29335   sv2= 0.007462452   df= 3.437889   lambda= 7677.55
# phi= 57.29939   sv2= 0.007460594   df= 3.436414   lambda= 7680.272
# phi= 57.30023   sv2= 0.007460338   df= 3.436211   lambda= 7680.647
# save file prefixed name is : TA_rarD-1_df_relative_timegrid-vs-TA_rarD-1_timeseries_dataframe
# biName is :  TA_rarD-1_df_relative_timegrid-vs-TA_rarD-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/rarD/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_rarD-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/rarD/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/rarD/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_rarD-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 47.07712   sv2= 0.4152603   df= 12.98093   lambda= 113.3677
# phi= 48.78821   sv2= 0.1364281   df= 7.728122   lambda= 357.6111
# phi= 51.35994   sv2= 0.04848255   df= 6.089254   lambda= 1059.349
# phi= 53.75152   sv2= 0.01632531   df= 4.904975   lambda= 3292.527
# phi= 55.6901   sv2= 0.008490226   df= 3.974638   lambda= 6559.319
# phi= 56.948   sv2= 0.007577171   df= 3.528272   lambda= 7515.734
# phi= 57.24972   sv2= 0.00747599   df= 3.448649   lambda= 7657.811
# phi= 57.29335   sv2= 0.007462452   df= 3.437889   lambda= 7677.55
# phi= 57.29939   sv2= 0.007460594   df= 3.436414   lambda= 7680.272
# phi= 57.30023   sv2= 0.007460338   df= 3.436211   lambda= 7680.647
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/rarD/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_rarD-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_rarD-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/MD-TA_rarD-1_df_relative_timegrid-vs-TA_rarD-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_rarD-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=12291.837351)
#                 est  L95%  U95%  se
# rate       0.000130   NaN   NaN NaN
# beta    2020.569625   NaN   NaN NaN
# s       1258.178727   NaN   NaN NaN
# lambda     0.044970   NaN   NaN NaN
#                est      L95%      U95%      var
# lifespan  6.039977  6.000557  6.066163  0.00016
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/MD-TA_rarD-1_df_relative_timegrid-vs-TA_rarD-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_rarD-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/rarD/run-MD
