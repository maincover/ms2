# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/TA_rarD-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/TA_rarD-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/TA_rarD-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD']
#
# out_name_s  ['TA_rarD-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/TA_rarD-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/TA_rarD-1_analysis_metadata.pickle
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 34-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 35-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 36-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 37-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 38-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 42-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 44-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 32-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 35-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 36-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 37-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 38-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 42-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 44-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 34-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 36-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 37-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 38-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 42-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 44-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 35-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 36-1.tif.mortality.tab ------ MAX_09032016 Position 37-1.tif.mortality.tab
# MAX_09032016 Position 36-1.tif.mortality.tab ------ MAX_09032016 Position 38-1.tif.mortality.tab
# MAX_09032016 Position 36-1.tif.mortality.tab ------ MAX_09032016 Position 42-1.tif.mortality.tab
# MAX_09032016 Position 36-1.tif.mortality.tab ------ MAX_09032016 Position 44-1.tif.mortality.tab
# MAX_09032016 Position 36-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 36-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 36-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 37-1.tif.mortality.tab ------ MAX_09032016 Position 38-1.tif.mortality.tab
# MAX_09032016 Position 37-1.tif.mortality.tab ------ MAX_09032016 Position 42-1.tif.mortality.tab
# MAX_09032016 Position 37-1.tif.mortality.tab ------ MAX_09032016 Position 44-1.tif.mortality.tab
# MAX_09032016 Position 37-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 37-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 37-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 38-1.tif.mortality.tab ------ MAX_09032016 Position 42-1.tif.mortality.tab
# MAX_09032016 Position 38-1.tif.mortality.tab ------ MAX_09032016 Position 44-1.tif.mortality.tab
# MAX_09032016 Position 38-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 38-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 38-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 42-1.tif.mortality.tab ------ MAX_09032016 Position 44-1.tif.mortality.tab
# MAX_09032016 Position 42-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 42-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 42-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 44-1.tif.mortality.tab ------ MAX_09032016 Position 45-1.tif.mortality.tab
# MAX_09032016 Position 44-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 44-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 45-1.tif.mortality.tab ------ MAX_09032016 Position 50-1.tif.mortality.tab
# MAX_09032016 Position 45-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# MAX_09032016 Position 50-1.tif.mortality.tab ------ MAX_09032016 Position 62-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_dentrogram-all-files.eps
# 7 [1 2 5 3 3 4 6]
# [['MAX_09032016 Position 35-1.tif.mortality.tab'], ['MAX_09032016 Position 62-1.tif.mortality.tab'], ['MAX_09032016 Position 36-1.tif.mortality.tab', 'MAX_09032016 Position 37-1.tif.mortality.tab', 'MAX_09032016 Position 38-1.tif.mortality.tab', 'MAX_09032016 Position 44-1.tif.mortality.tab', 'MAX_09032016 Position 50-1.tif.mortality.tab'], ['MAX_09032016 Position 45-1.tif.mortality.tab'], ['MAX_09032016 Position 32-1.tif.mortality.tab', 'MAX_09032016 Position 34-1.tif.mortality.tab'], ['MAX_09032016 Position 42-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 64.23729   sv2= 0.3329581   df= 10.82715   lambda= 192.929
# phi= 67.33251   sv2= 0.06765516   df= 5.85609   lambda= 995.2309
# phi= 73.20634   sv2= 0.01943016   df= 4.335707   lambda= 3767.666
# phi= 77.68706   sv2= 0.01146616   df= 3.467374   lambda= 6775.333
# phi= 79.89368   sv2= 0.0101153   df= 3.155671   lambda= 7898.297
# phi= 80.60802   sv2= 0.00976578   df= 3.079834   lambda= 8254.13
# phi= 80.82984   sv2= 0.009662542   df= 3.058423   lambda= 8365.277
# phi= 80.8988   sv2= 0.009630913   df= 3.051957   lambda= 8399.91
# phi= 80.92026   sv2= 0.009621115   df= 3.049963   lambda= 8410.695
# phi= 80.92694   sv2= 0.009618069   df= 3.049344   lambda= 8414.053
# phi= 80.92902   sv2= 0.009617121   df= 3.049151   lambda= 8415.099
# phi= 80.92967   sv2= 0.009616826   df= 3.049091   lambda= 8415.424
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_mortality_dataframe_cluster0.pickle
# 5 --c-- 2
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/rarD/CR-TA_rarD-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 49.74583   sv2= 0.3655573   df= 11.48499   lambda= 136.0822
# phi= 51.81425   sv2= 0.08547412   df= 6.585862   lambda= 606.1981
# phi= 55.60185   sv2= 0.0240872   df= 4.909843   lambda= 2308.357
# phi= 58.83982   sv2= 0.01190204   df= 3.871503   lambda= 4943.677
# phi= 60.65039   sv2= 0.01027463   df= 3.411951   lambda= 5902.924
# phi= 61.13776   sv2= 0.01000165   df= 3.315668   lambda= 6112.767
# phi= 61.23936   sv2= 0.009947589   df= 3.297121   lambda= 6156.201
# phi= 61.26021   sv2= 0.009936586   df= 3.293378   lambda= 6165.117
# phi= 61.26448   sv2= 0.009934335   df= 3.292614   lambda= 6166.944
# phi= 61.26536   sv2= 0.009933874   df= 3.292457   lambda= 6167.318
# No error in flxsrv_fit
# {0:                est      L95%      U95%       var
# lifespan  6.033357  6.013633  6.039977  0.000254}
