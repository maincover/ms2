# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/TA_ydjQ-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/TA_ydjQ-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ
# Iterations: relative error in phi-hat = 1e-04
# phi= 69.5206   sv2= 0.4724243   df= 15.46736   lambda= 147.1571
# phi= 75.10379   sv2= 0.02294069   df= 8.655191   lambda= 3273.824
# phi= 76.31774   sv2= 0.002618334   df= 4.479803   lambda= 29147.44
# save file prefixed name is : TA_ydjQ-1_df_relative_timegrid-vs-TA_ydjQ-1_timeseries_dataframe
# biName is :  TA_ydjQ-1_df_relative_timegrid-vs-TA_ydjQ-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ydjQ/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ydjQ-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ydjQ/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ydjQ/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ydjQ-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 69.5206   sv2= 0.4724243   df= 15.46736   lambda= 147.1571
# phi= 75.10379   sv2= 0.02294069   df= 8.655191   lambda= 3273.824
# phi= 76.31774   sv2= 0.002618334   df= 4.479803   lambda= 29147.44
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ydjQ/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydjQ-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ydjQ-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/MD-TA_ydjQ-1_df_relative_timegrid-vs-TA_ydjQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ydjQ-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=24187.579952)
#                 est         L95%          U95%           se
# rate       0.068510     0.061614      0.076178     0.003708
# beta    7468.125944  4901.280417  11379.252026  1604.714889
# s          1.374688     0.851421      2.219544     0.336016
# lambda     0.000259     0.000176      0.000381     0.000051
#                  est        L95%        U95%       var
# lifespan  123.860244  122.731836  124.115251  0.000075
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/MD-TA_ydjQ-1_df_relative_timegrid-vs-TA_ydjQ-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ydjQ-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ydjQ/run-MD
