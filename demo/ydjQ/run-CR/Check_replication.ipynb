# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/TA_ydjQ-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/TA_ydjQ-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/TA_ydjQ-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ']
#
# out_name_s  ['TA_ydjQ-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/TA_ydjQ-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/TA_ydjQ-1_analysis_metadata.pickle
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 57-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 85-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 88-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 90-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 92-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 93-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 94-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 55-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 85-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 88-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 90-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 92-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 93-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 94-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 57-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 85-1.tif.mortality.tab ------ MAX_12072015 Position 88-1.tif.mortality.tab
# MAX_12072015 Position 85-1.tif.mortality.tab ------ MAX_12072015 Position 90-1.tif.mortality.tab
# MAX_12072015 Position 85-1.tif.mortality.tab ------ MAX_12072015 Position 92-1.tif.mortality.tab
# MAX_12072015 Position 85-1.tif.mortality.tab ------ MAX_12072015 Position 93-1.tif.mortality.tab
# MAX_12072015 Position 85-1.tif.mortality.tab ------ MAX_12072015 Position 94-1.tif.mortality.tab
# MAX_12072015 Position 85-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 85-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 88-1.tif.mortality.tab ------ MAX_12072015 Position 90-1.tif.mortality.tab
# MAX_12072015 Position 88-1.tif.mortality.tab ------ MAX_12072015 Position 92-1.tif.mortality.tab
# MAX_12072015 Position 88-1.tif.mortality.tab ------ MAX_12072015 Position 93-1.tif.mortality.tab
# MAX_12072015 Position 88-1.tif.mortality.tab ------ MAX_12072015 Position 94-1.tif.mortality.tab
# MAX_12072015 Position 88-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 88-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 90-1.tif.mortality.tab ------ MAX_12072015 Position 92-1.tif.mortality.tab
# MAX_12072015 Position 90-1.tif.mortality.tab ------ MAX_12072015 Position 93-1.tif.mortality.tab
# MAX_12072015 Position 90-1.tif.mortality.tab ------ MAX_12072015 Position 94-1.tif.mortality.tab
# MAX_12072015 Position 90-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 90-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 92-1.tif.mortality.tab ------ MAX_12072015 Position 93-1.tif.mortality.tab
# MAX_12072015 Position 92-1.tif.mortality.tab ------ MAX_12072015 Position 94-1.tif.mortality.tab
# MAX_12072015 Position 92-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 92-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 93-1.tif.mortality.tab ------ MAX_12072015 Position 94-1.tif.mortality.tab
# MAX_12072015 Position 93-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 93-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 94-1.tif.mortality.tab ------ MAX_12072015 Position 95-1.tif.mortality.tab
# MAX_12072015 Position 94-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# MAX_12072015 Position 95-1.tif.mortality.tab ------ MAX_12072015 Position 96-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_dentrogram-all-files.eps
# [['MAX_12072015 Position 88-1.tif.mortality.tab', 'MAX_12072015 Position 92-1.tif.mortality.tab', 'MAX_12072015 Position 93-1.tif.mortality.tab', 'MAX_12072015 Position 95-1.tif.mortality.tab', 'MAX_12072015 Position 96-1.tif.mortality.tab'], ['MAX_12072015 Position 85-1.tif.mortality.tab', 'MAX_12072015 Position 90-1.tif.mortality.tab', 'MAX_12072015 Position 94-1.tif.mortality.tab'], ['MAX_12072015 Position 55-1.tif.mortality.tab'], ['MAX_12072015 Position 57-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 145.8087   sv2= 0.2451742   df= 12.97081   lambda= 594.7148
# phi= 159.8332   sv2= 0.01044004   df= 5.375403   lambda= 15309.63
# Iterations: relative error in phi-hat = 1e-04
# phi= 48.65773   sv2= 0.2824453   df= 11.797   lambda= 172.2731
# phi= 54.48972   sv2= 0.01715188   df= 6.370415   lambda= 3176.895
# phi= 56.05376   sv2= 0.001804512   df= 3.568397   lambda= 31063.11
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ydjQ/CR-TA_ydjQ-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 70.29913   sv2= 0.4426315   df= 14.8061   lambda= 158.8209
# phi= 76.59463   sv2= 0.02591215   df= 8.151787   lambda= 2955.935
# phi= 79.37566   sv2= 0.003934594   df= 4.415978   lambda= 20173.79
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  124.101734  122.745629  125.226073  0.000085}
