# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ynaA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ynaA/TA_ynaA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ynaA/TA_ynaA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ynaA
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.76608   sv2= 0.1325223   df= 13.99176   lambda= 194.4283
# phi= 27.3337   sv2= 0.01768599   df= 7.264706   lambda= 1545.5
# phi= 27.78958   sv2= 0.00794823   df= 4.780179   lambda= 3496.323
# phi= 27.93209   sv2= 0.006468966   df= 4.105087   lambda= 4317.86
# phi= 27.99911   sv2= 0.00610267   df= 3.950978   lambda= 4588.009
# phi= 28.02151   sv2= 0.005997636   df= 3.90806   lambda= 4672.092
# phi= 28.02849   sv2= 0.005966243   df= 3.895334   lambda= 4697.846
# phi= 28.03063   sv2= 0.005956745   df= 3.891493   lambda= 4705.697
# phi= 28.03129   sv2= 0.00595386   df= 3.890327   lambda= 4708.086
# phi= 28.03149   sv2= 0.005952983   df= 3.889973   lambda= 4708.813
# phi= 28.03155   sv2= 0.005952717   df= 3.889865   lambda= 4709.034
# save file prefixed name is : TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe
# biName is :  TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/ynaA/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_ynaA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/ynaA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ynaA/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_ynaA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 25.76608   sv2= 0.1325223   df= 13.99176   lambda= 194.4283
# phi= 27.3337   sv2= 0.01768599   df= 7.264706   lambda= 1545.5
# phi= 27.78958   sv2= 0.00794823   df= 4.780179   lambda= 3496.323
# phi= 27.93209   sv2= 0.006468966   df= 4.105087   lambda= 4317.86
# phi= 27.99911   sv2= 0.00610267   df= 3.950978   lambda= 4588.009
# phi= 28.02151   sv2= 0.005997636   df= 3.90806   lambda= 4672.092
# phi= 28.02849   sv2= 0.005966243   df= 3.895334   lambda= 4697.846
# phi= 28.03063   sv2= 0.005956745   df= 3.891493   lambda= 4705.697
# phi= 28.03129   sv2= 0.00595386   df= 3.890327   lambda= 4708.086
# phi= 28.03149   sv2= 0.005952983   df= 3.889973   lambda= 4708.813
# phi= 28.03155   sv2= 0.005952717   df= 3.889865   lambda= 4709.034
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/ynaA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_ynaA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ynaA/MD-TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_ynaA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=9269.651125)
#                  est          L95%          U95%            se
# rate    1.793995e-01  1.325029e-01  2.428942e-01  2.773519e-02
# beta    4.080785e+10  5.151558e+07  3.232576e+13  1.389730e+11
# s       2.976405e-01  1.607610e-01  5.510658e-01  9.354098e-02
# lambda  7.193617e-03  6.615777e-03  7.821928e-03  3.073381e-04
#               est       L95%        U95%       var
# lifespan  93.0027  77.353529  114.550657  0.000242
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ynaA/MD-TA_ynaA-1_df_relative_timegrid-vs-TA_ynaA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_ynaA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/ynaA/run-MD
