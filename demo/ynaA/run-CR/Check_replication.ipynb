# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS Github data part 6/ynaA'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/TA_ynaA-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/TA_ynaA-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/TA_ynaA-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS Github data part 6/ynaA']
#
# out_name_s  ['TA_ynaA-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/TA_ynaA-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/TA_ynaA-1_analysis_metadata.pickle
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 108-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 109-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 32-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 42-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 44-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 55-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 56-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 102-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 109-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 32-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 42-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 44-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 55-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 56-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 108-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 32-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 42-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 44-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 55-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 56-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 109-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 42-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 44-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 55-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 56-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 32-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 44-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 55-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 56-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 42-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 44-1.tif.mortality.tab ------ MAX_06082014 Position 55-1.tif.mortality.tab
# MAX_06082014 Position 44-1.tif.mortality.tab ------ MAX_06082014 Position 56-1.tif.mortality.tab
# MAX_06082014 Position 44-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 44-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 44-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 44-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 44-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 55-1.tif.mortality.tab ------ MAX_06082014 Position 56-1.tif.mortality.tab
# MAX_06082014 Position 55-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 55-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 55-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 55-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 55-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 56-1.tif.mortality.tab ------ MAX_06082014 Position 63-1.tif.mortality.tab
# MAX_06082014 Position 56-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 56-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 56-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 56-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 63-1.tif.mortality.tab ------ MAX_06082014 Position 77-1.tif.mortality.tab
# MAX_06082014 Position 63-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 63-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 63-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 77-1.tif.mortality.tab ------ MAX_06082014 Position 79-1.tif.mortality.tab
# MAX_06082014 Position 77-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 77-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 79-1.tif.mortality.tab ------ MAX_06082014 Position 83-1.tif.mortality.tab
# MAX_06082014 Position 79-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# MAX_06082014 Position 83-1.tif.mortality.tab ------ MAX_06082014 Position 84-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA
# save eps to :  /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_dentrogram-all-files.eps
# 6 [1 2 4 5 3 3]
# 5 [1 2 3 4 3]
# 4 [2 3 1 1]
# [['MAX_06082014 Position 108-1.tif.mortality.tab', 'MAX_06082014 Position 79-1.tif.mortality.tab'], ['MAX_06082014 Position 55-1.tif.mortality.tab', 'MAX_06082014 Position 56-1.tif.mortality.tab', 'MAX_06082014 Position 77-1.tif.mortality.tab'], ['MAX_06082014 Position 32-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 84.36037   sv2= 0.04226927   df= 9.397577   lambda= 1995.785
# phi= 71.58692   sv2= 0.004026273   df= 3.263879   lambda= 17779.95
# Iterations: relative error in phi-hat = 1e-04
# phi= 7.538907   sv2= 0.0658197   df= 9.590601   lambda= 114.5388
# phi= 7.901456   sv2= 0.007352125   df= 5.687067   lambda= 1074.717
# phi= 8.13045   sv2= 0.002912763   df= 3.691013   lambda= 2791.319
# phi= 8.210398   sv2= 0.002785698   df= 3.124889   lambda= 2947.34
# phi= 8.21888   sv2= 0.002767677   df= 3.096228   lambda= 2969.595
# phi= 8.220107   sv2= 0.002765045   df= 3.092291   lambda= 2972.866
# phi= 8.220287   sv2= 0.002764657   df= 3.091715   lambda= 2973.348
# phi= 8.220314   sv2= 0.002764599   df= 3.09163   lambda= 2973.42
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_mortality_dataframe_cluster0.pickle
# 4 --c-- 2
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_mortality_dataframe_cluster1.pickle
# 4 --c-- 0
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS Github data part 6/ynaA/CR-TA_ynaA-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 110.755   sv2= 0.0675523   df= 13.40863   lambda= 1639.544
# phi= 113.7184   sv2= 0.002907999   df= 4.469046   lambda= 39105.38
# Iterations: relative error in phi-hat = 1e-04
# phi= 84.36037   sv2= 0.04226927   df= 9.397577   lambda= 1995.785
# phi= 71.58692   sv2= 0.004026273   df= 3.263879   lambda= 17779.95
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                 est      L95%       U95%       var
# lifespan  81.830001  80.82908  83.854251  0.000249, 1:                 est       L95%      U95%       var
# lifespan  94.799255  92.799091  97.79937  0.001021}
