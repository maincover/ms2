# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pfkA'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pfkA/TA_pfkA-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pfkA/TA_pfkA-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pfkA
# Iterations: relative error in phi-hat = 1e-04
# phi= 120.4527   sv2= 0.1023291   df= 16.52647   lambda= 1177.111
# phi= 126.7714   sv2= 0.001351595   df= 5.758684   lambda= 93793.89
# save file prefixed name is : TA_pfkA-1_df_relative_timegrid-vs-TA_pfkA-1_timeseries_dataframe
# biName is :  TA_pfkA-1_df_relative_timegrid-vs-TA_pfkA-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/pfkA/run-MD
# No error in flxsrv_fit
# TA_pfkA-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/pfkA/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/pfkA/run-MD
# TA_pfkA-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 120.4527   sv2= 0.1023291   df= 16.52647   lambda= 1177.111
# phi= 126.7714   sv2= 0.001351595   df= 5.758684   lambda= 93793.89
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/pfkA/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pfkA-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_pfkA-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pfkA/MD-TA_pfkA-1_df_relative_timegrid-vs-TA_pfkA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_pfkA-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=18421.739891)
#               est          L95%        U95%         se
# rate     0.039645  3.545735e-02    0.044328   0.002258
# beta    76.536759  5.770173e+01  101.519931  11.031024
# s        2.033630  1.268879e+00    3.259295   0.489417
# lambda   0.000001  8.694586e-15  180.624464   0.000012
#                 est       L95%       U95%       var
# lifespan  86.656844  84.821258  88.508191  0.000121
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/pfkA/MD-TA_pfkA-1_df_relative_timegrid-vs-TA_pfkA-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_pfkA-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/pfkA/run-MD
