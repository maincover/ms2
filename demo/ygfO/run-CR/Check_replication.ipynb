# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/TA_ygfO-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/TA_ygfO-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/TA_ygfO-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO']
#
# out_name_s  ['TA_ygfO-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/TA_ygfO-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/TA_ygfO-1_analysis_metadata.pickle
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 20-1.tif.mortality.tab
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 33-1.tif.mortality.tab
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 34-1.tif.mortality.tab
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 36-1.tif.mortality.tab
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 37-1.tif.mortality.tab
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 38-1.tif.mortality.tab
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 40-1.tif.mortality.tab
# MAX_05072014 Position 19-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# MAX_05072014 Position 20-1.tif.mortality.tab ------ MAX_05072014 Position 33-1.tif.mortality.tab
# MAX_05072014 Position 20-1.tif.mortality.tab ------ MAX_05072014 Position 34-1.tif.mortality.tab
# MAX_05072014 Position 20-1.tif.mortality.tab ------ MAX_05072014 Position 36-1.tif.mortality.tab
# MAX_05072014 Position 20-1.tif.mortality.tab ------ MAX_05072014 Position 37-1.tif.mortality.tab
# MAX_05072014 Position 20-1.tif.mortality.tab ------ MAX_05072014 Position 38-1.tif.mortality.tab
# MAX_05072014 Position 20-1.tif.mortality.tab ------ MAX_05072014 Position 40-1.tif.mortality.tab
# MAX_05072014 Position 20-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# MAX_05072014 Position 33-1.tif.mortality.tab ------ MAX_05072014 Position 34-1.tif.mortality.tab
# MAX_05072014 Position 33-1.tif.mortality.tab ------ MAX_05072014 Position 36-1.tif.mortality.tab
# MAX_05072014 Position 33-1.tif.mortality.tab ------ MAX_05072014 Position 37-1.tif.mortality.tab
# MAX_05072014 Position 33-1.tif.mortality.tab ------ MAX_05072014 Position 38-1.tif.mortality.tab
# MAX_05072014 Position 33-1.tif.mortality.tab ------ MAX_05072014 Position 40-1.tif.mortality.tab
# MAX_05072014 Position 33-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# MAX_05072014 Position 34-1.tif.mortality.tab ------ MAX_05072014 Position 36-1.tif.mortality.tab
# MAX_05072014 Position 34-1.tif.mortality.tab ------ MAX_05072014 Position 37-1.tif.mortality.tab
# MAX_05072014 Position 34-1.tif.mortality.tab ------ MAX_05072014 Position 38-1.tif.mortality.tab
# MAX_05072014 Position 34-1.tif.mortality.tab ------ MAX_05072014 Position 40-1.tif.mortality.tab
# MAX_05072014 Position 34-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# MAX_05072014 Position 36-1.tif.mortality.tab ------ MAX_05072014 Position 37-1.tif.mortality.tab
# MAX_05072014 Position 36-1.tif.mortality.tab ------ MAX_05072014 Position 38-1.tif.mortality.tab
# MAX_05072014 Position 36-1.tif.mortality.tab ------ MAX_05072014 Position 40-1.tif.mortality.tab
# MAX_05072014 Position 36-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# MAX_05072014 Position 37-1.tif.mortality.tab ------ MAX_05072014 Position 38-1.tif.mortality.tab
# MAX_05072014 Position 37-1.tif.mortality.tab ------ MAX_05072014 Position 40-1.tif.mortality.tab
# MAX_05072014 Position 37-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# MAX_05072014 Position 38-1.tif.mortality.tab ------ MAX_05072014 Position 40-1.tif.mortality.tab
# MAX_05072014 Position 38-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# MAX_05072014 Position 40-1.tif.mortality.tab ------ MAX_05072014 Position 45-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_dentrogram-all-files.eps
# 3 [2 1 1]
# [['MAX_05072014 Position 19-1.tif.mortality.tab', 'MAX_05072014 Position 20-1.tif.mortality.tab', 'MAX_05072014 Position 33-1.tif.mortality.tab', 'MAX_05072014 Position 34-1.tif.mortality.tab', 'MAX_05072014 Position 36-1.tif.mortality.tab', 'MAX_05072014 Position 45-1.tif.mortality.tab'], ['MAX_05072014 Position 37-1.tif.mortality.tab', 'MAX_05072014 Position 38-1.tif.mortality.tab', 'MAX_05072014 Position 40-1.tif.mortality.tab']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:96: RuntimeWarning: invalid value encountered in divide
#   rgb_line[:,0] = np.uint8((profile/np.float(profile.max()))*255)
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_relative_orig_timegrid_cluster1.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 38.97808   sv2= 0.06146739   df= 14.32485   lambda= 634.1261
# phi= 39.83064   sv2= 0.001614674   df= 5.704614   lambda= 24667.92
# Iterations: relative error in phi-hat = 1e-04
# phi= 169.1883   sv2= 0.1046925   df= 11.73566   lambda= 1616.05
# phi= 182.8051   sv2= 0.0005437479   df= 4.023029   lambda= 336194.5
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 1
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_cluster0_tabs.txt
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_mortality_dataframe_cluster1.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_relative_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_timeseries_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/ygfO/CR-TA_ygfO-1_cluster1_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 38.97808   sv2= 0.06146739   df= 14.32485   lambda= 634.1261
# phi= 39.83064   sv2= 0.001614674   df= 5.704614   lambda= 24667.92
# Iterations: relative error in phi-hat = 1e-04
# phi= 169.1883   sv2= 0.1046925   df= 11.73566   lambda= 1616.05
# phi= 182.8051   sv2= 0.0005437479   df= 4.023029   lambda= 336194.5
# No error in flxsrv_fit
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  115.979353  113.997034  117.837236  0.000168, 1:                 est        L95%        U95%      var
# lifespan  125.02888  123.029421  127.010963  0.00046}
