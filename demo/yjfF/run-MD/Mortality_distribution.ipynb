# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfF'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfF/TA_yjfF-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfF/TA_yjfF-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfF
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.08366   sv2= 0.4769832   df= 16.40738   lambda= 105.0009
# phi= 51.92115   sv2= 0.04054043   df= 9.747652   lambda= 1280.725
# phi= 53.14582   sv2= 0.006077367   df= 5.684053   lambda= 8744.875
# phi= 54.76198   sv2= 0.0009999289   df= 3.84939   lambda= 54765.87
# save file prefixed name is : TA_yjfF-1_df_relative_timegrid-vs-TA_yjfF-1_timeseries_dataframe
# biName is :  TA_yjfF-1_df_relative_timegrid-vs-TA_yjfF-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/yjfF/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_yjfF-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/yjfF/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjfF/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_yjfF-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.08366   sv2= 0.4769832   df= 16.40738   lambda= 105.0009
# phi= 51.92115   sv2= 0.04054043   df= 9.747652   lambda= 1280.725
# phi= 53.14582   sv2= 0.006077367   df= 5.684053   lambda= 8744.875
# phi= 54.76198   sv2= 0.0009999289   df= 3.84939   lambda= 54765.87
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/yjfF/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjfF-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_yjfF-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfF/MD-TA_yjfF-1_df_relative_timegrid-vs-TA_yjfF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_yjfF-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=18363.909403)
#                  est       L95%          U95%             se
# rate        0.039695   0.036669  4.296907e-02       0.001605
# beta    60297.951292  26.573564  1.368218e+08  237724.011475
# s         614.903790   0.262242  1.441824e+06    2434.547209
# lambda      0.001194   0.000782  1.822832e-03       0.000258
#                  est       L95%        U95%       var
# lifespan  103.029787  97.836894  104.270047  0.000129
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/yjfF/MD-TA_yjfF-1_df_relative_timegrid-vs-TA_yjfF-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_yjfF-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/yjfF/run-MD
