# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG-WT/CR-TA_MG-WT-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG-WT/CR-TA_MG-WT-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/TA_syd 2-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/TA_syd 2-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/TA_syd 2-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2']
#
# out_name_s  ['TA_syd 2-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/TA_syd 2-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/TA_syd 2-1_analysis_metadata.pickle
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 101-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 102-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 103-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 104-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 105-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 107-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 110-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 100-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 102-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 103-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 104-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 105-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 107-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 110-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 101-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 103-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 104-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 105-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 107-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 110-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 102-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 103-1.tif.mortality.tab ------ MAX_26022017 Position 104-1.tif.mortality.tab
# MAX_26022017 Position 103-1.tif.mortality.tab ------ MAX_26022017 Position 105-1.tif.mortality.tab
# MAX_26022017 Position 103-1.tif.mortality.tab ------ MAX_26022017 Position 107-1.tif.mortality.tab
# MAX_26022017 Position 103-1.tif.mortality.tab ------ MAX_26022017 Position 110-1.tif.mortality.tab
# MAX_26022017 Position 103-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 103-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 103-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 104-1.tif.mortality.tab ------ MAX_26022017 Position 105-1.tif.mortality.tab
# MAX_26022017 Position 104-1.tif.mortality.tab ------ MAX_26022017 Position 107-1.tif.mortality.tab
# MAX_26022017 Position 104-1.tif.mortality.tab ------ MAX_26022017 Position 110-1.tif.mortality.tab
# MAX_26022017 Position 104-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 104-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 104-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 105-1.tif.mortality.tab ------ MAX_26022017 Position 107-1.tif.mortality.tab
# MAX_26022017 Position 105-1.tif.mortality.tab ------ MAX_26022017 Position 110-1.tif.mortality.tab
# MAX_26022017 Position 105-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 105-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 105-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 107-1.tif.mortality.tab ------ MAX_26022017 Position 110-1.tif.mortality.tab
# MAX_26022017 Position 107-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 107-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 107-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 110-1.tif.mortality.tab ------ MAX_26022017 Position 111-1.tif.mortality.tab
# MAX_26022017 Position 110-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 110-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 111-1.tif.mortality.tab ------ MAX_26022017 Position 112-1.tif.mortality.tab
# MAX_26022017 Position 111-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# MAX_26022017 Position 112-1.tif.mortality.tab ------ MAX_26022017 Position 99-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2
# save eps to :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_dentrogram-all-files.eps
# [['MAX_26022017 Position 100-1.tif.mortality.tab', 'MAX_26022017 Position 101-1.tif.mortality.tab', 'MAX_26022017 Position 102-1.tif.mortality.tab', 'MAX_26022017 Position 103-1.tif.mortality.tab', 'MAX_26022017 Position 104-1.tif.mortality.tab', 'MAX_26022017 Position 105-1.tif.mortality.tab', 'MAX_26022017 Position 107-1.tif.mortality.tab', 'MAX_26022017 Position 110-1.tif.mortality.tab', 'MAX_26022017 Position 111-1.tif.mortality.tab', 'MAX_26022017 Position 112-1.tif.mortality.tab'], ['MAX_26022017 Position 99-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_relative_orig_timegrid_cluster0.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.41268   sv2= 0.6633407   df= 11.4456   lambda= 77.50568
# phi= 49.10473   sv2= 0.1498588   df= 7.478636   lambda= 327.6734
# phi= 50.1689   sv2= 0.04665226   df= 5.581834   lambda= 1075.38
# phi= 52.11744   sv2= 0.01478459   df= 4.39154   lambda= 3525.12
# phi= 53.3812   sv2= 0.006286162   df= 3.522006   lambda= 8491.858
# phi= 53.99797   sv2= 0.004697532   df= 3.036664   lambda= 11494.97
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_mortality_dataframe_cluster0.pickle
# 2 --c-- 0
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/CR-TA_syd 2-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.41268   sv2= 0.6633407   df= 11.4456   lambda= 77.50568
# phi= 49.10473   sv2= 0.1498588   df= 7.478636   lambda= 327.6734
# phi= 50.1689   sv2= 0.04665226   df= 5.581834   lambda= 1075.38
# phi= 52.11744   sv2= 0.01478459   df= 4.39154   lambda= 3525.12
# phi= 53.3812   sv2= 0.006286162   df= 3.522006   lambda= 8491.858
# phi= 53.99797   sv2= 0.004697532   df= 3.036664   lambda= 11494.97
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  132.569723  131.711534  133.381395  0.000265}
