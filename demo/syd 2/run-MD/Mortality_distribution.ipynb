# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/TA_syd 2-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/TA_syd 2-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.12111   sv2= 0.7095201   df= 11.67202   lambda= 70.64086
# phi= 48.69394   sv2= 0.1762831   df= 7.76475   lambda= 276.2258
# phi= 49.90201   sv2= 0.05997401   df= 5.88284   lambda= 832.0606
# phi= 52.03387   sv2= 0.0204997   df= 4.698508   lambda= 2538.275
# phi= 53.70565   sv2= 0.007418843   df= 3.791117   lambda= 7239.086
# phi= 54.47268   sv2= 0.004539042   df= 3.161425   lambda= 12000.92
# save file prefixed name is : TA_syd 2-1_df_relative_timegrid-vs-TA_syd 2-1_timeseries_dataframe
# biName is :  TA_syd 2-1_df_relative_timegrid-vs-TA_syd 2-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/syd 2/run-MD
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# TA_syd 2-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/syd 2/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/syd 2/run-MD
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# TA_syd 2-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.12111   sv2= 0.7095201   df= 11.67202   lambda= 70.64086
# phi= 48.69394   sv2= 0.1762831   df= 7.76475   lambda= 276.2258
# phi= 49.90201   sv2= 0.05997401   df= 5.88284   lambda= 832.0606
# phi= 52.03387   sv2= 0.0204997   df= 4.698508   lambda= 2538.275
# phi= 53.70565   sv2= 0.007418843   df= 3.791117   lambda= 7239.086
# phi= 54.47268   sv2= 0.004539042   df= 3.161425   lambda= 12000.92
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/syd 2/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_syd 2-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_syd 2-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/MD-TA_syd 2-1_df_relative_timegrid-vs-TA_syd 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_syd 2-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=7235.389232)
#                  est          L95%          U95%            se
# rate    9.774032e-02  8.848172e-02  1.079677e-01  4.962816e-03
# beta    1.781326e+09  6.926506e-02  4.581127e+19  2.178568e+10
# s       2.640099e+03  1.036422e-07  6.725175e+13  3.227565e+04
# lambda  1.243437e-03  1.015492e-03  1.522549e-03  1.284738e-04
#                  est        L95%        U95%       var
# lifespan  131.784193  130.906382  133.361459  0.000251
#
#
# /home/xsong/mg-wt/dataset/MS 2 Github data part 4/syd 2/MD-TA_syd 2-1_df_relative_timegrid-vs-TA_syd 2-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_syd 2-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/syd 2/run-MD
