# %% [markdown]
# # Check Replication and discard orphan files by clustering

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Check_Replication import CheckReplication
folderPath='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW'
path_ref_folder ='/home/xsong/mg-wt/dataset'
cutoff = -1
CR = CheckReplication(folderPath, refFolderPath=path_ref_folder, cutoff=cutoff)
CR.run()
# Out:
# path ref_df:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_mortality_dataframe_cluster0.pickle
# path ref_timegrid:  /home/xsong/mg-wt/dataset/MG WT 0.2% Glucose/CR-TA_MG WT 0.2% Glucose-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# Iterations: relative error in phi-hat = 1e-04
# phi= 44.08829   sv2= 0.1482503   df= 17.89218   lambda= 297.3909
# phi= 46.7982   sv2= 0.02310606   df= 8.389584   lambda= 2025.365
# phi= 48.97974   sv2= 0.004899383   df= 5.514179   lambda= 9997.123
# phi= 50.08814   sv2= 0.001654852   df= 3.979986   lambda= 30267.44
# No error in flxsrv_fit
# df_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/TA_norW-1_mortality_dataframe.pickle']]
# meta_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/TA_norW-1_analysis_metadata.pickle']]
# timeseries_paths:  [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/TA_norW-1_timeseries_dataframe.pickle']]
# -----------
# out_path_folder  ['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW']
#
# out_name_s  ['TA_norW-1_']
# check dataset type:  alcohol_indeces <type 'dict'>
# check dataset type:  time_indeces <type 'dict'>
# check dataset type:  corrected_illums <type 'dict'>
# check dataset type:  time_grid <type 'list'>
# check dataset type:  background_threshold <type 'int'>
# check dataset type:  alcohol_t <type 'datetime.datetime'>
# check dataset type:  all_illums <type 'dict'>
# check dataset type:  parameters <type 'dict'>
# check dataset type:  cells_included <type 'dict'>
# path df  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/TA_norW-1_mortality_dataframe.pickle
# path meta  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/TA_norW-1_analysis_metadata.pickle
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 27-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 30-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 39-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 41-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 43-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 45-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 70-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 26-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 30-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 39-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 41-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 43-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 45-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 70-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 27-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 39-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 41-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 43-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 45-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 70-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 30-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 41-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 43-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 45-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 70-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 39-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 43-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 45-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 70-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 41-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 45-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 70-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 43-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 70-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 45-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 72-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 70-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 74-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 72-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 75-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 74-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 77-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 75-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 78-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 77-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 78-1.tif.mortality.tab ------ MAX_30112014 Position 79-1.tif.mortality.tab
# MAX_30112014 Position 78-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 78-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 78-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 78-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 78-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 78-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 79-1.tif.mortality.tab ------ MAX_30112014 Position 80-1.tif.mortality.tab
# MAX_30112014 Position 79-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 79-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 79-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 79-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 79-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 80-1.tif.mortality.tab ------ MAX_30112014 Position 81-1.tif.mortality.tab
# MAX_30112014 Position 80-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 80-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 80-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 80-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 81-1.tif.mortality.tab ------ MAX_30112014 Position 82-1.tif.mortality.tab
# MAX_30112014 Position 81-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 81-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 81-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 82-1.tif.mortality.tab ------ MAX_30112014 Position 83-1.tif.mortality.tab
# MAX_30112014 Position 82-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 82-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 83-1.tif.mortality.tab ------ MAX_30112014 Position 84-1.tif.mortality.tab
# MAX_30112014 Position 83-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# MAX_30112014 Position 84-1.tif.mortality.tab ------ MAX_30112014 Position 85-1.tif.mortality.tab
# dendrogram will be saved to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW
# save eps to :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_dentrogram-all-files.eps
# [['MAX_30112014 Position 30-1.tif.mortality.tab', 'MAX_30112014 Position 39-1.tif.mortality.tab', 'MAX_30112014 Position 41-1.tif.mortality.tab', 'MAX_30112014 Position 43-1.tif.mortality.tab', 'MAX_30112014 Position 75-1.tif.mortality.tab', 'MAX_30112014 Position 77-1.tif.mortality.tab'], ['MAX_30112014 Position 26-1.tif.mortality.tab', 'MAX_30112014 Position 27-1.tif.mortality.tab', 'MAX_30112014 Position 78-1.tif.mortality.tab', 'MAX_30112014 Position 80-1.tif.mortality.tab', 'MAX_30112014 Position 81-1.tif.mortality.tab'], ['MAX_30112014 Position 45-1.tif.mortality.tab', 'MAX_30112014 Position 70-1.tif.mortality.tab', 'MAX_30112014 Position 72-1.tif.mortality.tab', 'MAX_30112014 Position 74-1.tif.mortality.tab', 'MAX_30112014 Position 79-1.tif.mortality.tab', 'MAX_30112014 Position 82-1.tif.mortality.tab', 'MAX_30112014 Position 83-1.tif.mortality.tab', 'MAX_30112014 Position 84-1.tif.mortality.tab', 'MAX_30112014 Position 85-1.tif.mortality.tab']]
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_colomap_all_files_cluster0.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_mortality_orig_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_relative_orig_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_colomap_all_files_cluster1.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_mortality_orig_dataframe_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_relative_orig_timegrid_cluster1.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_colomap_all_files_cluster2.png
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_mortality_orig_dataframe_cluster2.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_relative_orig_timegrid_cluster2.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 106.5908   sv2= 0.1623922   df= 14.561   lambda= 656.3785
# phi= 110.0948   sv2= 0.005579006   df= 5.817844   lambda= 19733.76
# Iterations: relative error in phi-hat = 1e-04
# phi= 78.50958   sv2= 0.1199298   df= 11.81551   lambda= 654.6297
# phi= 83.91931   sv2= 0.0166071   df= 4.794034   lambda= 5053.22
# phi= 86.23944   sv2= 0.005887061   df= 3.187701   lambda= 14648.98
# Iterations: relative error in phi-hat = 1e-04
# phi= 51.32503   sv2= 0.2331621   df= 11.85294   lambda= 220.126
# phi= 56.25223   sv2= 0.01533896   df= 6.122817   lambda= 3667.277
# phi= 59.6401   sv2= 0.002033562   df= 3.512075   lambda= 29327.9
# No error in flxsrv_fit
# No error in flxsrv_fit
# No error in flxsrv_fit
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_mortality_dataframe_cluster0.pickle
# 1 --c-- 0
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_relative_timegrid_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_timeseries_dataframe_cluster0.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/CR-TA_norW-1_cluster0_tabs.txt
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.19141   sv2= 0.3944158   df= 16.25247   lambda= 84.15335
# phi= 34.89855   sv2= 0.05210094   df= 10.3814   lambda= 669.8257
# phi= 36.01054   sv2= 0.008669813   df= 6.571231   lambda= 4153.555
# phi= 36.45008   sv2= 0.005817842   df= 4.442533   lambda= 6265.223
# phi= 36.57518   sv2= 0.005295105   df= 4.078359   lambda= 6907.356
# phi= 36.60846   sv2= 0.005155266   df= 3.997391   lambda= 7101.179
# phi= 36.6181   sv2= 0.005114672   df= 3.974806   lambda= 7159.423
# phi= 36.62096   sv2= 0.005102617   df= 3.968172   lambda= 7176.899
# phi= 36.62182   sv2= 0.005099012   df= 3.966195   lambda= 7182.14
# phi= 36.62207   sv2= 0.005097932   df= 3.965603   lambda= 7183.711
# phi= 36.62215   sv2= 0.005097609   df= 3.965426   lambda= 7184.182
# No error in flxsrv_fit
# {0:                  est        L95%        U95%       var
# lifespan  101.158327  101.137936  101.233548  0.000069}
