# %% [markdown]
# # Mortality Distribution, generate mortality curve, compare with reference(WT for example)
# This is an auto-generated notebook.

# %%
# %matplotlib inline
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Mortality_distribution import MortalityDistribution
folder_path='/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW'
ref_df_path = '/home/xsong/mg-wt/dataset/MG-WT/MG_WT_CLUSTER_0_df_relative_timegrid.pickle'
M_Distribution = MortalityDistribution(folder_path,ref_df_path)
M_Distribution.run()
# Out:
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/TA_norW-1_df_relative_timegrid.pickle']]
# []
# [['/home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/TA_norW-1_timeseries_dataframe.pickle']]
# /home/xsong/mg-wt/cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# /home/xsong/mg-wt/cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# MG_WT_CLUSTER_0_df_relative_timegrid
# load reference pickle,  MG_WT_CLUSTER_0_df_relative_timegrid 149.328310278
# files will be written into :  /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.19141   sv2= 0.3944158   df= 16.25247   lambda= 84.15335
# phi= 34.89855   sv2= 0.05210094   df= 10.3814   lambda= 669.8257
# phi= 36.01054   sv2= 0.008669813   df= 6.571231   lambda= 4153.555
# phi= 36.45008   sv2= 0.005817842   df= 4.442533   lambda= 6265.223
# phi= 36.57518   sv2= 0.005295105   df= 4.078359   lambda= 6907.356
# phi= 36.60846   sv2= 0.005155266   df= 3.997391   lambda= 7101.179
# phi= 36.6181   sv2= 0.005114672   df= 3.974806   lambda= 7159.423
# phi= 36.62096   sv2= 0.005102617   df= 3.968172   lambda= 7176.899
# phi= 36.62182   sv2= 0.005099012   df= 3.966195   lambda= 7182.14
# phi= 36.62207   sv2= 0.005097932   df= 3.965603   lambda= 7183.711
# phi= 36.62215   sv2= 0.005097609   df= 3.965426   lambda= 7184.182
# save file prefixed name is : TA_norW-1_df_relative_timegrid-vs-TA_norW-1_timeseries_dataframe
# biName is :  TA_norW-1_df_relative_timegrid-vs-TA_norW-1_timeseries_dataframe
# getGGMfit_dict--(1) /home/xsong/mg-wt/demo/norW/run-MD
# No error in flxsrv_fit
# TA_norW-1_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# No error in flxsrv_fit
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle ['tRisk', 'logLik', 'ML_cumulative_hazard', 'model_paras', 'ML_hazard', 'events', 'AIC', 'ML_survivorship']
# getGGMfit_dict--(2) /home/xsong/mg-wt/demo/norW/run-MD
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/norW/run-MD
# TA_norW-1_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 33.19141   sv2= 0.3944158   df= 16.25247   lambda= 84.15335
# phi= 34.89855   sv2= 0.05210094   df= 10.3814   lambda= 669.8257
# phi= 36.01054   sv2= 0.008669813   df= 6.571231   lambda= 4153.555
# phi= 36.45008   sv2= 0.005817842   df= 4.442533   lambda= 6265.223
# phi= 36.57518   sv2= 0.005295105   df= 4.078359   lambda= 6907.356
# phi= 36.60846   sv2= 0.005155266   df= 3.997391   lambda= 7101.179
# phi= 36.6181   sv2= 0.005114672   df= 3.974806   lambda= 7159.423
# phi= 36.62096   sv2= 0.005102617   df= 3.968172   lambda= 7176.899
# phi= 36.62182   sv2= 0.005099012   df= 3.966195   lambda= 7182.14
# phi= 36.62207   sv2= 0.005097932   df= 3.965603   lambda= 7183.711
# phi= 36.62215   sv2= 0.005097609   df= 3.965426   lambda= 7184.182
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# Iterations: relative error in phi-hat = 1e-04
# phi= 50.62065   sv2= 0.05183947   df= 15.67714   lambda= 976.4887
# phi= 52.67783   sv2= 0.002310922   df= 5.657281   lambda= 22795.16
# getKMNABSfits_dict-- /home/xsong/mg-wt/demo/norW/run-MD
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_norW-1_df_relative_timegrid.pickle
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# TA_norW-1_df_relative_timegrid.pickle
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/MD-TA_norW-1_df_relative_timegrid-vs-TA_norW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=15889.636442)
#                est       L95%        U95%         se
# rate      0.072927   0.061541    0.086420   0.006316
# beta    153.763745  85.211326  277.466509  46.309073
# s         0.956717   0.703579    1.300931   0.150016
# lambda    0.000656   0.000185    0.002323   0.000423
#                est       L95%       U95%       var
# lifespan  68.29953  66.625739  69.614456  0.000143
#
#
# TA_norW-1_df_relative_timegrid.pickle
# -------------------------------
# GGM(AIC=29505.046238)
#                  est          L95%          U95%            se
# rate        0.110475      0.101980      0.119678      0.004510
# beta    37321.261735  19009.732750  73271.760092  12845.835142
# s           0.609506      0.523637      0.709457      0.047222
# lambda      0.000369      0.000276      0.000492      0.000054
#                  est        L95%        U95%       var
# lifespan  101.158327  101.137936  101.233548  0.000069
#
#
# /home/xsong/mg-wt/dataset/MS2 for GitHub Updated 26.05.2019/norW/MD-TA_norW-1_df_relative_timegrid-vs-TA_norW-1_timeseries_dataframe-vs-MG_WT_CLUSTER_0_df_relative_timegrid_GG_GGM_parameters.txt
# 0 MG_WT_CLUSTER_0_df_relative_timegrid.pickle
# 1 TA_norW-1_df_relative_timegrid.pickle
# working directory is :  /home/xsong/mg-wt/demo/norW/run-MD
