# %% [markdown]
# # Preprocessing to detect duplication
# This is an auto-generated notebook.

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Preprocessing import PreprocessingTabFile
current_path = '/home/xsong/mg-wt/dataset/MS 2 Github data part 4'
prev_path = '/home/xsong/coliSurvivalAnalysis/xsong/Microfluidics Database'
filter_file_path = ''
selfFilter = True
pre = PreprocessingTabFile(current_path,prev_path,filterFile=filter_file_path,autoFilter = selfFilter,report_folder_name='report',showProgress = True)
pre.run()
# Out:
# Total files length :  921  Filtered files length (after MD5 check) :  134
# check line duplication(open file) :  50 / 921
# check line duplication(open file) :  100 / 921
# check line duplication(open file) :  150 / 921
# check line duplication(open file) :  200 / 921
# check line duplication(open file) :  250 / 921
# check line duplication(open file) :  300 / 921
# check line duplication(open file) :  350 / 921
# check line duplication(open file) :  400 / 921
# check line duplication(open file) :  450 / 921
# check line duplication(open file) :  500 / 921
# check line duplication(open file) :  550 / 921
# check line duplication(open file) :  600 / 921
# check line duplication(open file) :  650 / 921
# check line duplication(open file) :  700 / 921
# check line duplication(open file) :  750 / 921
# check line duplication(open file) :  800 / 921
# check line duplication(open file) :  850 / 921
# check line duplication(open file) :  900 / 921
# check line duplication:  0 / 921
# check line duplication:  50 / 921
# check line duplication:  100 / 921
# check line duplication:  150 / 921
# check line duplication:  200 / 921
# check line duplication:  250 / 921
# check line duplication:  300 / 921
# check line duplication:  350 / 921
# check line duplication:  400 / 921
# check line duplication:  450 / 921
# check line duplication:  500 / 921
# check line duplication:  550 / 921
# check line duplication:  600 / 921
# check line duplication:  650 / 921
# check line duplication:  700 / 921
# check line duplication:  750 / 921
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 211-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 218-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 221-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 223-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 236-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 241-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 242-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 254-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 255-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 256-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/ cynX 2/MAX_13052018 Position 31-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 209-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 210-1.tif.mortality.tab
# check line duplication:  800 / 921
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 213-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 214-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 217-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 219-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 220-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 222-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/MAX_13052018 Position 230-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 138-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 139-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 145-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 182-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 184-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 228-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 229-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 233-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 237-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 247-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/MAX_13052018 Position 248-1.tif.mortality.tab
# exclude fn(itself) :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4