# %% [markdown]
# # GG_GGM_SELECTOR Write the result to table

# %%
import sys,os
python_class_path='/home/xsong/mg-wt'
sys.path.insert(1, os.path.join(sys.path[0], python_class_path))
from Selector_GG_GGM import GG_GGM_Selector
data_folder = '/home/xsong/mg-wt/dataset/MS 2 Github data part 4'
out_folder = '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE'
gg_ggm_selector = GG_GGM_Selector(data_folder,out_folder)
gg_ggm_selector.run()
# Out:
# create output folder :  /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE
# [['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/yihV 2/CR-TA_yihV 2-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/yihV 2/CR-TA_yihV 2-1_mortality_dataframe_cluster0.pickle', 'CR-TA_yihV 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/yajQ 2/CR-TA_yajQ 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/yajQ 2/CR-TA_yajQ 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_yajQ 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/lysC 2/CR-TA_lysC 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/lysC 2/CR-TA_lysC 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_lysC 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/CR-TA_casE 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/casE 2/CR-TA_casE 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_casE 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/cynX 2/CR-TA_cynX 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/cynX 2/CR-TA_cynX 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_cynX 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/yjfF 2/CR-TA_yjfF 2-1_relative_timegrid_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/yjfF 2/CR-TA_yjfF 2-1_mortality_dataframe_cluster0.pickle', 'CR-TA_yjfF 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/flgD 2/CR-TA_flgD 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/flgD 2/CR-TA_flgD 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_flgD 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/CR-TA_agaA 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/agaA 2/CR-TA_agaA 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_agaA 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/fabR 2/CR-TA_fabR 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/fabR 2/CR-TA_fabR 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_fabR 2-1_'], ['/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ssuE 2/CR-TA_ssuE 2-1_mortality_dataframe_cluster0.pickle', '/home/xsong/mg-wt/dataset/MS 2 Github data part 4/ssuE 2/CR-TA_ssuE 2-1_relative_timegrid_cluster0.pickle', 'CR-TA_ssuE 2-1_']]
# CR-TA_yihV 2-1_
# ../../../cohortMortalitySummary.py:174: RuntimeWarning: invalid value encountered in divide
#   NA_lower = NelsonAalen * np.exp( norm.ppf(ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# ../../../cohortMortalitySummary.py:175: RuntimeWarning: invalid value encountered in divide
#   NA_upper = NelsonAalen * np.exp( norm.ppf(1-ALPHA/2)*np.sqrt(NA_var)/NelsonAalen )
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_yihV 2-1_.txt
# No error in flxsrv_fit
# 3827.16668011
# 3
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 1.45150298428e-06 0.957777777778
# No error in flxsrv_fit
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in (function (x, B, newdata = NULL, X = NULL, transform = FALSE,  :
#   Covariance matrix not available from non-converged model
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Warning messages:
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 1:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: In (function (formula, anc = NULL, data, weights, bhazard, subset,  :
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning:  Optimisation has probably not converged to the maximum likelihood - Hessian is not positive definite.
#
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 2:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 3:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 4:
#   warnings.warn(x, RRuntimeWarning)
# /home/xsong/miniconda2/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: 5:
#   warnings.warn(x, RRuntimeWarning)
# "ERROR in step ggmStats(df)"
# N/A, choose GGM due to AIC
# CR-TA_yajQ 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_yajQ 2-1_.txt
# No error in flxsrv_fit
# 9224.59085539
# 7
# 1 ['2016-06-10 00:00:00']
# No error in flxsrv_fit
# 0.000111841142098 0.973053892216
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_lysC 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_lysC 2-1_.txt
# No error in flxsrv_fit
# 7374.47427725
# 8
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 0.00797505662976 0.963636363636
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_casE 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_casE 2-1_.txt
# No error in flxsrv_fit
# 5438.04072537
# 6
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 2.44279176548e-05 0.86674391657
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_cynX 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_cynX 2-1_.txt
# No error in flxsrv_fit
# 13609.4000019
# 12
# 1 ['2014-07-18 00:00:00']
# No error in flxsrv_fit
# 0.297635525133 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_yjfF 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_yjfF 2-1_.txt
# No error in flxsrv_fit
# 6213.20828479
# 7
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 0.0447382206199 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_flgD 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_flgD 2-1_.txt
# No error in flxsrv_fit
# 4783.42852859
# 10
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 0.116935047598 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_agaA 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_agaA 2-1_.txt
# No error in flxsrv_fit
# 5191.38302323
# 8
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 4.78383710607e-06 0.873640167364
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_fabR 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_fabR 2-1_.txt
# No error in flxsrv_fit
# 2992.38515468
# 2
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 7.44864532047e-35 0.825342465753
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
# CR-TA_ssuE 2-1_
# ----------- /home/xsong/mg-wt/dataset/MS 2 Github data part 4/GG_GGM_TABLE/CR-TA_ssuE 2-1_.txt
# No error in flxsrv_fit
# 5224.54986531
# 7
# 1 ['2018-05-13 00:00:00']
# No error in flxsrv_fit
# 0.0821655651973 1.0
# No error in flxsrv_fit
# N/A, choose GGM due to AIC
